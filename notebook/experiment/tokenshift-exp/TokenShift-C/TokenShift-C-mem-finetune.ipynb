# %% [markdown]
# # RWKV Token Shift Experiment (Memory Finetune)
# This continues off from `./TokenShift-C-basemodel.ipynb` to perform the full memory finetune & testing process
#
# This is done generally in 3 Tune stages
# - Tune 1: Low ctx size (512), Training with only the input masked. This does very limited memory training, and is used primarily to train the instruction set.
# - Tune 2: Low ctx size (512), Training with instruction & input masked. This forces the actual memory training on the output tokens.
# - Tune 3: Mid ctx size (1024), stage 2, scaled up to 1024 context sizes.
# - Tune 4: Mid ctx size (4096), stage 3, scaled up to 4096 context sizes.
#
# In all cases, the input tokens is always masked. And we intentionally use the limited word set for memory training, which matches the same wordset used in the original memory evaluation of raven pretrained models. This is intentional to serve as both consistent comparision between experiments, and resonable training time.
#
# One of the issue faced previously with an excessive large word set, is that the model would be required to see "new words" atleast a few time before being able to train the memory process. This drastically slowed down the process as the large word list meant the model was constantly spending time learning new words (instead of memory training).
#
# If we want to increase the number / type of words the model can handle for memory training, that can be done later as a stage 4 memory tune if needed. But that exceeds the current requirements for the memory experiment process.
#
# > This project assumes you have the rwkv-infctx conda env setup, and you are executing in that environment - see the main README.md for the conda env setup steps

# %% [markdown]
# ## Optional: Download the pretrained model
# (if you want to skip the the basemodel train + instruct tune)

# %%
# # Init required dirs
# !mkdir -p ../../../../model/
# !mkdir -p ../../../../datapath/
# !mkdir -p ../../../../checkpoint/

# # Download the Stage2.pth file
# !rm -rf ../../../../model/TokenShift-C-Stage2.pth
# !cd ../../../../model/ && wget https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-C-Stage2.pth
# !ls -alh ../../../../model/TokenShift-C-Stage2.pth

# %% [markdown]
# ## Configure your environment settings
# (!Important: you will need to rerun the below cell, if you restart your kernel)

# %%
DEEPSPEED_STRAT="deepspeed_stage_1"
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="TokenShift-C"

print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v4wavenet/"))

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# DEEPSPEED_STRAT: deepspeed_stage_1
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /root/rwkv5x-tokenshift-exp-A/notebook/experiment/tokenshift-exp/TokenShift-C
# TRAINER_DIR: /root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet
# PROJECT_DIR: /root/rwkv5x-tokenshift-exp-A

# %% [markdown]
# ## Tune 1 : Simple Memory instruct finetuning
#
# - Tune 1: Low ctx size (512), Training with only the input masked. This does very limited memory training, and is used primarily to train the instruction set.

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# # We do a strong bias for smaller word count, to teach the concept from scratch
# # so that the model can learn the function.
# #
# # Note that all document samples, are randomized between the target word count,
# # to half of the target word count.
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-2-count.jsonl  2  5000 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-5-count.jsonl  5  5000 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-10-count.jsonl 10 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-15-count.jsonl 15 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-20-count.jsonl 20 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-25-count.jsonl 25 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-40-count.jsonl 40 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-50-count.jsonl 50 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-60-count.jsonl 80 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-80-count.jsonl 80 2500 &
#
# # With a slight mix of the larger word count
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-100-count.jsonl 100 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-200-count.jsonl 200 2500 &
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated JSONL file with - 10 max words, 2500 samples - at ./dataset/word-10-count.jsonl
# Generated JSONL file with - 15 max words, 2500 samples - at ./dataset/word-15-count.jsonl
# Generated JSONL file with - 20 max words, 2500 samples - at ./dataset/word-20-count.jsonl
# Generated JSONL file with - 2 max words, 5000 samples - at ./dataset/word-2-count.jsonl
# Generated JSONL file with - 25 max words, 2500 samples - at ./dataset/word-25-count.jsonl
# Generated JSONL file with - 5 max words, 5000 samples - at ./dataset/word-5-count.jsonl
# Generated JSONL file with - 40 max words, 2500 samples - at ./dataset/word-40-count.jsonl
# Generated JSONL file with - 50 max words, 2500 samples - at ./dataset/word-50-count.jsonl
# Generated JSONL file with - 80 max words, 2500 samples - at ./dataset/word-60-count.jsonl
# Generated JSONL file with - 80 max words, 2500 samples - at ./dataset/word-80-count.jsonl
# Generated JSONL file with - 100 max words, 2500 samples - at ./dataset/word-100-count.jsonl
# Generated JSONL file with - 200 max words, 2500 samples - at ./dataset/word-200-count.jsonl
# ## Done ##
# total 21M
# drwxr-xr-x 2 root root  330 Jul 21 14:31 .
# drwxr-xr-x 6 root root 4.0K Jul 21 11:17 ..
# -rw-r--r-- 1 root root 612K Jul 21 14:31 word-10-count.jsonl
# -rw-r--r-- 1 root root 2.8M Jul 21 14:31 word-100-count.jsonl
# -rw-r--r-- 1 root root 727K Jul 21 14:31 word-15-count.jsonl
# -rw-r--r-- 1 root root 839K Jul 21 14:31 word-2-count.jsonl
# -rw-r--r-- 1 root root 851K Jul 21 14:31 word-20-count.jsonl
# -rw-r--r-- 1 root root 5.2M Jul 21 14:31 word-200-count.jsonl
# -rw-r--r-- 1 root root 971K Jul 21 14:31 word-25-count.jsonl
# -rw-r--r-- 1 root root 1.4M Jul 21 14:31 word-40-count.jsonl
# -rw-r--r-- 1 root root 968K Jul 21 14:31 word-5-count.jsonl
# -rw-r--r-- 1 root root 1.6M Jul 21 14:31 word-50-count.jsonl
# -rw-r--r-- 1 root root 2.3M Jul 21 14:31 word-60-count.jsonl
# -rw-r--r-- 1 root root 2.3M Jul 21 14:31 word-80-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-1.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-C-mem-finetune-1/"
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-529a99486bbfe004/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|███████████████████| 1/1 [00:00<00:00, 6594.82it/s]
# Extracting data files: 100%|█████████████████████| 1/1 [00:00<00:00, 348.13it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-529a99486bbfe004/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 204.13it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-1.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-1 (bs=256, train-ctx=512, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=512
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 3496537533
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 3496537533
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230721_143206-gq5bz369
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run (8x3090) TokenShift-C - Mem-Finetune-1 (bs=256, train-ctx=512, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/gq5bz369
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-529a99486bbfe004/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 365.07it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-529a99486bbfe004/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-71dab13813818a53_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-529a99486bbfe004/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-62b17800e52b0ad9_*_of_00064.arrow
# [rank: 0] Global seed set to 3496537533
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-21 14:32:20,417] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [rank: 6] Global seed set to 3496537533
# [rank: 3] Global seed set to 3496537533
# [rank: 4] Global seed set to 3496537533
# [rank: 2] Global seed set to 3496537533
# [rank: 5] Global seed set to 3496537533
# [rank: 1] Global seed set to 3496537533
# [rank: 7] Global seed set to 3496537533
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# [rank: 6] Global seed set to 3496537533
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-21 14:32:35,928] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 3496537533
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-21 14:32:37,638] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 3496537533
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-21 14:32:39,924] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 3496537533
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-07-21 14:32:40,234] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 3496537533
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-21 14:32:40,254] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 3] Global seed set to 3496537533
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-21 14:32:40,266] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 3496537533
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-21 14:32:40,278] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 5.000e-04 (0.0005)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06313538551330566 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10096478462219238 seconds
# Time to load fused_adam op: 0.1014411449432373 seconds
# Time to load fused_adam op: 0.10147929191589355 seconds
# Time to load fused_adam op: 0.1011195182800293 seconds
# Time to load fused_adam op: 0.10112380981445312 seconds
# Time to load fused_adam op: 0.10131716728210449 seconds
# Time to load fused_adam op: 0.10142087936401367 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.06599926948547363 seconds
# Loading extension module utils...
# Time to load utils op: 0.10185551643371582 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10219097137451172 seconds
# Time to load utils op: 0.10140585899353027 seconds
# Time to load utils op: 0.10191750526428223 seconds
# Loading extension module utils...
# Time to load utils op: 0.10105586051940918 seconds
# Loading extension module utils...
# Time to load utils op: 0.10174012184143066 seconds
# Loading extension module utils...
# Time to load utils op: 0.10188961029052734 seconds
# Rank: 4 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 0 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 1 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 7 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 3 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002703666687011719 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00026798248291015625 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00025653839111328125 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.000362396240234375 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003490447998046875 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00033783912658691406 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00025844573974609375 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0004916191101074219 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0:  18%|▏| 800/4371 [05:05<22:41,  2.62it/s, v_num=z369, train/loss=1.220]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 4371/4371 [28:36<00:00,  2.55it/s, v_num=z369, train/loss=3.910
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|████                | 1/5 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  40%|████████            | 2/5 [00:00<00:00,  5.96it/s]
# Validation DataLoader 0:  60%|████████████        | 3/5 [00:00<00:00,  6.17it/s]
# Validation DataLoader 0:  80%|████████████████    | 4/5 [00:00<00:00,  6.26it/s]
# Epoch 0: 100%|█| 4371/4371 [28:44<00:00,  2.53it/s, v_num=z369, train/loss=3.910
# Epoch 0: 100%|█| 4371/4371 [28:44<00:00,  2.53it/s, v_num=z369, train/loss=3.910`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 4371/4371 [28:57<00:00,  2.52it/s, v_num=z369, train/loss=3.910
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▄▃▄▁▂▁▂▁█▁▅▁▃▂▁▁▃▃▂▁▃▁▃▅▂▁▃▂▁▅█▁▂▃▄▂▁▂▂▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ▆▄▆▇▂█▂▂▇▁██▅▃▅▇▁▆▇▆▁▇▂▅▆▆▁▁▄▄▄▁▁▁▁▂▁▁▁▁
# wandb:   trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 4
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 54
# wandb:               substep 32
# wandb:            train/loss 0.2373
# wandb:   trainer/global_step 136
# wandb: trainer/learning_rate 0.0005
# wandb:       validation/loss 1.23909
# wandb:
# wandb: 🚀 View run (8x3090) TokenShift-C - Mem-Finetune-1 (bs=256, train-ctx=512, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/gq5bz369
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230721_143206-gq5bz369/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-C-mem-finetune-1/last.ckpt" \
        "../model/TokenShift-C-Tune1.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-C-Tune1.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-C-mem-finetune-1/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 438 params 1515106304 elements
# Saving fp32 state dict to ../model/TokenShift-C-Tune1.pth
# -rw-r--r-- 1 root root 5.7G Jul 21 15:34 ../model/TokenShift-C-Tune1.pth

# %%
# Lets do a memory eval
#
# Note that the expected performance "is not that great", as the model seems to be only loosely
# learning the memorization task, and the instruction propmt. And is seem to be acting more
# like an RNG based on the instruct. (Instead of the actual memorization task)
# !python3 ../memory_script/eval_model_memory_guided.py "{PROJECT_DIR}/model/TokenShift-C-Tune1.pth"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 90.0% similarity, with 9 matched token, and 1 token mismatch
# ## Model validation for 15 tokens : 93.33333333333333% similarity, with 14 matched token, and 1 token mismatch
# ## Model validation for 20 tokens : 80.0% similarity, with 16 matched token, and 4 token mismatch
# ## Model validation for 25 tokens : 64.0% similarity, with 16 matched token, and 9 token mismatch
# ## Model validation for 30 tokens : 66.66666666666666% similarity, with 20 matched token, and 10 token mismatch
# ## Model validation for 35 tokens : 62.857142857142854% similarity, with 22 matched token, and 13 token mismatch
# ## Model validation for 40 tokens : 60.0% similarity, with 24 matched token, and 16 token mismatch
# ## Model validation for 45 tokens : 46.666666666666664% similarity, with 21 matched token, and 24 token mismatch
# ## Model validation for 50 tokens : 44.0% similarity, with 22 matched token, and 28 token mismatch
# ## Model validation for 55 tokens : 34.54545454545455% similarity, with 19 matched token, and 36 token mismatch
# ## Model validation for 60 tokens : 33.33333333333333% similarity, with 20 matched token, and 40 token mismatch
# ## Model validation for 65 tokens : 27.692307692307693% similarity, with 18 matched token, and 47 token mismatch
# ## Model validation for 70 tokens : 25.71428571428571% similarity, with 18 matched token, and 52 token mismatch
# ## Model validation for 75 tokens : 22.666666666666664% similarity, with 17 matched token, and 58 token mismatch
# ## Model validation for 80 tokens : 22.5% similarity, with 18 matched token, and 62 token mismatch
# ## Model validation for 85 tokens : 21.176470588235293% similarity, with 18 matched token, and 67 token mismatch
# ## Model validation for 90 tokens : 21.11111111111111% similarity, with 19 matched token, and 71 token mismatch
# ## Model validation for 95 tokens : 20.0% similarity, with 19 matched token, and 76 token mismatch
# ## Model validation for 100 tokens : 18.0% similarity, with 18 matched token, and 82 token mismatch
# ## Model validation for 105 tokens : 19.047619047619047% similarity, with 20 matched token, and 85 token mismatch
# ## Model validation for 110 tokens : 17.272727272727273% similarity, with 19 matched token, and 91 token mismatch
# ## Model validation for 115 tokens : 16.52173913043478% similarity, with 19 matched token, and 96 token mismatch
# ## Model validation for 120 tokens : 15.833333333333332% similarity, with 19 matched token, and 101 token mismatch
# ## Model validation for 125 tokens : 15.2% similarity, with 19 matched token, and 106 token mismatch
# ## Model validation for 130 tokens : 14.615384615384617% similarity, with 19 matched token, and 111 token mismatch
# ## Model validation for 135 tokens : 14.074074074074074% similarity, with 19 matched token, and 116 token mismatch
# ## Model validation for 140 tokens : 13.571428571428571% similarity, with 19 matched token, and 121 token mismatch
# ## Model validation for 145 tokens : 14.482758620689657% similarity, with 21 matched token, and 124 token mismatch
# ## Model validation for 150 tokens : 14.000000000000002% similarity, with 21 matched token, and 129 token mismatch
# ## Model validation for 160 tokens : 13.125% similarity, with 21 matched token, and 139 token mismatch
# ## Model validation for 170 tokens : 12.352941176470589% similarity, with 21 matched token, and 149 token mismatch
# ## Model validation for 180 tokens : 11.11111111111111% similarity, with 20 matched token, and 160 token mismatch
# ## Model validation for 190 tokens : 10.526315789473683% similarity, with 20 matched token, and 170 token mismatch
# ## Model validation for 200 tokens : 10.0% similarity, with 20 matched token, and 180 token mismatch
# ## Model validation for 210 tokens : 9.523809523809524% similarity, with 20 matched token, and 190 token mismatch
# ## Model validation for 220 tokens : 8.636363636363637% similarity, with 19 matched token, and 201 token mismatch
# ## Model validation for 230 tokens : 8.26086956521739% similarity, with 19 matched token, and 211 token mismatch
# ## Model validation for 240 tokens : 7.916666666666666% similarity, with 19 matched token, and 221 token mismatch
# ## Model validation for 250 tokens : 7.199999999999999% similarity, with 18 matched token, and 232 token mismatch
# ## Model validation for 260 tokens : 6.923076923076923% similarity, with 18 matched token, and 242 token mismatch
# ## Model validation for 270 tokens : 6.666666666666667% similarity, with 18 matched token, and 252 token mismatch
# ## Model validation for 280 tokens : 6.428571428571428% similarity, with 18 matched token, and 262 token mismatch
# ## Model validation for 290 tokens : 6.551724137931035% similarity, with 19 matched token, and 271 token mismatch
# ## Model validation for 300 tokens : 6.333333333333334% similarity, with 19 matched token, and 281 token mismatch
# ## Model validation for 325 tokens : 5.846153846153846% similarity, with 19 matched token, and 306 token mismatch
# ## Model validation for 350 tokens : 5.428571428571429% similarity, with 19 matched token, and 331 token mismatch
# ## Model validation for 375 tokens : 5.066666666666666% similarity, with 19 matched token, and 356 token mismatch
# ## Model validation for 400 tokens : 4.75% similarity, with 19 matched token, and 381 token mismatch
# ## Model validation for 425 tokens : 4.235294117647059% similarity, with 18 matched token, and 407 token mismatch
# ## Model validation for 450 tokens : 4.0% similarity, with 18 matched token, and 432 token mismatch
# ## Model validation for 475 tokens : 3.7894736842105265% similarity, with 18 matched token, and 457 token mismatch
# ## Model validation for 500 tokens : 3.8% similarity, with 19 matched token, and 481 token mismatch
# ## Model validation for 525 tokens : 3.619047619047619% similarity, with 19 matched token, and 506 token mismatch
# ## Model validation for 550 tokens : 3.090909090909091% similarity, with 17 matched token, and 533 token mismatch
# ## Model validation for 575 tokens : 2.782608695652174% similarity, with 16 matched token, and 559 token mismatch
# ## Model validation for 600 tokens : 2.5% similarity, with 15 matched token, and 585 token mismatch
# ## Model validation for 625 tokens : 2.4% similarity, with 15 matched token, and 610 token mismatch
# ## Model validation for 650 tokens : 2.6153846153846154% similarity, with 17 matched token, and 633 token mismatch
# ## Model validation for 675 tokens : 2.2222222222222223% similarity, with 15 matched token, and 660 token mismatch
# ## Model validation for 700 tokens : 2.142857142857143% similarity, with 15 matched token, and 685 token mismatch
# ## Model validation for 750 tokens : 2.2666666666666666% similarity, with 17 matched token, and 733 token mismatch
# ## Model validation for 800 tokens : 2.125% similarity, with 17 matched token, and 783 token mismatch
# ## Model validation for 850 tokens : 2.3529411764705883% similarity, with 20 matched token, and 830 token mismatch
# ## Model validation for 900 tokens : 2.111111111111111% similarity, with 19 matched token, and 881 token mismatch
# ## Model validation for 950 tokens : 2.1052631578947367% similarity, with 20 matched token, and 930 token mismatch
# ## Model validation for 1000 tokens : 2.1% similarity, with 21 matched token, and 979 token mismatch

# %% [markdown]
# ## Tune 2 : Low ctx size (512), memory training
#
# - Tune 2: Low ctx size (512), Training with instruction & input masked. This forces the actual memory training on the output tokens.

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# #
# # We switch over to fully masked instruct+input, to properly learn the memorization task
# #
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-2-count.jsonl  2  5000 &
# for i in {5..95..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 5000 &
# done
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-100-count.jsonl 100 5000 &
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-200-count.jsonl 200 5000 &
#
# #
# # We mixin the shuffled word list, so that we ensure all words / tokens are learned
# # however this might intrduce an exclusion bias (if seen this word, never repeat it),
# # so we limit the mixture of this data samples
# #
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-10-count.jsonl 10 20 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-15-count.jsonl 15 20 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-25-count.jsonl 25 30 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-50-count.jsonl 50 50 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-75-count.jsonl 75 50 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-100-count.jsonl 100 50 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-200-count.jsonl 200 50 &
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated JSONL file with - 2 max words, 5000 samples - at ./dataset/word-2-count.jsonl
# Generated JSONL file with - 5 max words, 5000 samples - at ./dataset/gen-word-5-count.jsonl
# Generated a single JSONL file with 3546 samples (20 token repeat) - 15 max words - at ./dataset/shuffle-word-15-count.jsonl
# Generated a single JSONL file with 3158 samples (30 token repeat) - 25 max words - at ./dataset/shuffle-word-25-count.jsonl
# Generated a single JSONL file with 675 samples (50 token repeat) - 200 max words - at ./dataset/shuffle-word-200-count.jsonl
# Generated JSONL file with - 10 max words, 5000 samples - at ./dataset/gen-word-10-count.jsonl
# Generated a single JSONL file with 1339 samples (50 token repeat) - 100 max words - at ./dataset/shuffle-word-100-count.jsonl
# Generated a single JSONL file with 5226 samples (20 token repeat) - 10 max words - at ./dataset/shuffle-word-10-count.jsonl
# Generated a single JSONL file with 2624 samples (50 token repeat) - 50 max words - at ./dataset/shuffle-word-50-count.jsonl
# Generated a single JSONL file with 1758 samples (50 token repeat) - 75 max words - at ./dataset/shuffle-word-75-count.jsonl
# Generated JSONL file with - 30 max words, 5000 samples - at ./dataset/gen-word-30-count.jsonl
# Generated JSONL file with - 35 max words, 5000 samples - at ./dataset/gen-word-35-count.jsonl
# Generated JSONL file with - 40 max words, 5000 samples - at ./dataset/gen-word-40-count.jsonl
# Generated JSONL file with - 45 max words, 5000 samples - at ./dataset/gen-word-45-count.jsonl
# Generated JSONL file with - 15 max words, 5000 samples - at ./dataset/gen-word-15-count.jsonl
# Generated JSONL file with - 50 max words, 5000 samples - at ./dataset/gen-word-50-count.jsonl
# Generated JSONL file with - 20 max words, 5000 samples - at ./dataset/gen-word-20-count.jsonl
# Generated JSONL file with - 25 max words, 5000 samples - at ./dataset/gen-word-25-count.jsonl
# Generated JSONL file with - 65 max words, 5000 samples - at ./dataset/gen-word-65-count.jsonl
# Generated JSONL file with - 95 max words, 5000 samples - at ./dataset/gen-word-95-count.jsonl
# Generated JSONL file with - 55 max words, 5000 samples - at ./dataset/gen-word-55-count.jsonl
# Generated JSONL file with - 75 max words, 5000 samples - at ./dataset/gen-word-75-count.jsonl
# Generated JSONL file with - 60 max words, 5000 samples - at ./dataset/gen-word-60-count.jsonl
# Generated JSONL file with - 90 max words, 5000 samples - at ./dataset/gen-word-90-count.jsonl
# Generated JSONL file with - 70 max words, 5000 samples - at ./dataset/gen-word-70-count.jsonl
# Generated JSONL file with - 85 max words, 5000 samples - at ./dataset/gen-word-85-count.jsonl
# Generated JSONL file with - 80 max words, 5000 samples - at ./dataset/gen-word-80-count.jsonl
# Generated JSONL file with - 100 max words, 5000 samples - at ./dataset/word-100-count.jsonl
# Generated JSONL file with - 200 max words, 5000 samples - at ./dataset/word-200-count.jsonl
# ## Done ##
# total 79M
# drwxr-xr-x 2 root root 4.0K Jul 21 15:50 .
# drwxr-xr-x 6 root root 4.0K Jul 21 15:49 ..
# -rw-r--r-- 1 root root 985K Jul 21 15:50 gen-word-10-count.jsonl
# -rw-r--r-- 1 root root 1.2M Jul 21 15:50 gen-word-15-count.jsonl
# -rw-r--r-- 1 root root 1.5M Jul 21 15:50 gen-word-20-count.jsonl
# -rw-r--r-- 1 root root 1.7M Jul 21 15:50 gen-word-25-count.jsonl
# -rw-r--r-- 1 root root 2.0M Jul 21 15:50 gen-word-30-count.jsonl
# -rw-r--r-- 1 root root 2.2M Jul 21 15:50 gen-word-35-count.jsonl
# -rw-r--r-- 1 root root 2.4M Jul 21 15:50 gen-word-40-count.jsonl
# -rw-r--r-- 1 root root 2.6M Jul 21 15:50 gen-word-45-count.jsonl
# -rw-r--r-- 1 root root 725K Jul 21 15:50 gen-word-5-count.jsonl
# -rw-r--r-- 1 root root 2.9M Jul 21 15:50 gen-word-50-count.jsonl
# -rw-r--r-- 1 root root 3.1M Jul 21 15:50 gen-word-55-count.jsonl
# -rw-r--r-- 1 root root 3.4M Jul 21 15:50 gen-word-60-count.jsonl
# -rw-r--r-- 1 root root 3.6M Jul 21 15:50 gen-word-65-count.jsonl
# -rw-r--r-- 1 root root 3.9M Jul 21 15:50 gen-word-70-count.jsonl
# -rw-r--r-- 1 root root 4.1M Jul 21 15:50 gen-word-75-count.jsonl
# -rw-r--r-- 1 root root 4.3M Jul 21 15:50 gen-word-80-count.jsonl
# -rw-r--r-- 1 root root 4.5M Jul 21 15:50 gen-word-85-count.jsonl
# -rw-r--r-- 1 root root 4.8M Jul 21 15:50 gen-word-90-count.jsonl
# -rw-r--r-- 1 root root 5.0M Jul 21 15:50 gen-word-95-count.jsonl
# -rw-r--r-- 1 root root 1.1M Jul 21 15:50 shuffle-word-10-count.jsonl
# -rw-r--r-- 1 root root 1.4M Jul 21 15:50 shuffle-word-100-count.jsonl
# -rw-r--r-- 1 root root 870K Jul 21 15:50 shuffle-word-15-count.jsonl
# -rw-r--r-- 1 root root 1.4M Jul 21 15:50 shuffle-word-200-count.jsonl
# -rw-r--r-- 1 root root 1.1M Jul 21 15:50 shuffle-word-25-count.jsonl
# -rw-r--r-- 1 root root 1.5M Jul 21 15:50 shuffle-word-50-count.jsonl
# -rw-r--r-- 1 root root 1.5M Jul 21 15:50 shuffle-word-75-count.jsonl
# -rw-r--r-- 1 root root 5.3M Jul 21 15:50 word-100-count.jsonl
# -rw-r--r-- 1 root root 596K Jul 21 15:50 word-2-count.jsonl
# -rw-r--r-- 1 root root  10M Jul 21 15:50 word-200-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-2.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-C-mem-finetune-2/"
# Out:
# Resolving data files: 100%|█████████████████| 29/29 [00:00<00:00, 262144.00it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-36d2f30971bcc82e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|███████████████████| 1/1 [00:00<00:00, 2071.26it/s]
# Extracting data files: 100%|█████████████████████| 1/1 [00:00<00:00, 105.15it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-36d2f30971bcc82e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 117.55it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-2.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-2 (bs=256, train-ctx=512, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=512
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 1176313930
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 1176313930
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230721_155034-agugd7u3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run (8x3090) TokenShift-C - Mem-Finetune-2 (bs=256, train-ctx=512, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/agugd7u3
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=wkv_512_bf16 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 --compiler-options '-fPIC' -t 4 -std=c++17 -res-usage --maxrregcount 60 --use_fast_math -O3 -Xptxas -O3 --extra-device-vectorization -DTmax=512 -c /root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/cuda/wkv_cuda_bf16.cu -o wkv_cuda_bf16.cuda.o
# ptxas info    : 1 bytes gmem
# ptxas info    : Compiling entry function '_Z15kernel_backwardiiiPKfPKN3c108BFloat16ES4_S4_S0_S4_S0_PS2_S5_S5_S5_Pf' for 'sm_86'
# ptxas info    : Function properties for _Z15kernel_backwardiiiPKfPKN3c108BFloat16ES4_S4_S0_S4_S0_PS2_S5_S5_S5_Pf
#     6144 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 56 registers, 464 bytes cmem[0], 8 bytes cmem[2]
# ptxas info    : Compiling entry function '_Z14kernel_forwardiiiPKfPKN3c108BFloat16ES4_S4_S0_PS2_Pf' for 'sm_86'
# ptxas info    : Function properties for _Z14kernel_forwardiiiPKfPKN3c108BFloat16ES4_S4_S0_PS2_Pf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 40 registers, 424 bytes cmem[0]
# [2/3] c++ -MMD -MF wkv_op_bf16.o.d -DTORCH_EXTENSION_NAME=wkv_512_bf16 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -std=c++17 -O3 -DTmax=512 -c /root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/cuda/wkv_op_bf16.cpp -o wkv_op_bf16.o
# [3/3] c++ wkv_op_bf16.o wkv_cuda_bf16.cuda.o -shared -L/usr/local/lib/python3.11/dist-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o wkv_512_bf16.so
# Loading extension module wkv_512_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Resolving data files: 100%|█████████████████| 29/29 [00:00<00:00, 100858.06it/s]
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-36d2f30971bcc82e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 134.47it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-36d2f30971bcc82e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-fac7e101a3d1bddf_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-36d2f30971bcc82e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-5f26cb3430ba052e_*_of_00064.arrow
# [rank: 0] Global seed set to 1176313930
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-21 15:51:07,165] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [rank: 6] Global seed set to 1176313930
# [rank: 2] Global seed set to 1176313930
# [rank: 3] Global seed set to 1176313930
# [rank: 5] Global seed set to 1176313930
# [rank: 7] Global seed set to 1176313930
# [rank: 4] Global seed set to 1176313930
# [rank: 1] Global seed set to 1176313930
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# [rank: 6] Global seed set to 1176313930
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-21 15:51:23,077] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 1176313930
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-21 15:51:26,926] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 3] Global seed set to 1176313930
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-21 15:51:26,993] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 1176313930
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-07-21 15:51:27,064] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 1176313930
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-21 15:51:27,078] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 1176313930
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-21 15:51:27,088] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 1176313930
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-21 15:51:27,092] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:612: UserWarning: Checkpoint directory /root/rwkv5x-tokenshift-exp-A/checkpoint/TokenShift-C-mem-finetune-2 exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  5.000e-04 (0.0005)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu118/fused_adam...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/includes -I/usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/adam -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 --compiler-options '-fPIC' -O3 -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -lineinfo --use_fast_math -gencode=arch=compute_86,code=sm_86 -gencode=arch=compute_86,code=compute_86 -DBF16_AVAILABLE -std=c++17 -c /usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/adam/multi_tensor_adam.cu -o multi_tensor_adam.cuda.o
# [2/3] c++ -MMD -MF fused_adam_frontend.o.d -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/includes -I/usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/adam -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -O3 -std=c++17 -g -Wno-reorder -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -DBF16_AVAILABLE -c /usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/adam/fused_adam_frontend.cpp -o fused_adam_frontend.o
# [3/3] c++ fused_adam_frontend.o multi_tensor_adam.cuda.o -shared -L/usr/local/lib/python3.11/dist-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o fused_adam.so
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.791274547576904 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.82239055633545 seconds
# Time to load fused_adam op: 20.822097778320312 seconds
# Time to load fused_adam op: 20.822311878204346 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.823126554489136 seconds
# Time to load fused_adam op: 20.82315945625305 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.825767755508423 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.829119443893433 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu118/utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -c /usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/usr/local/lib/python3.11/dist-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 11.361754417419434 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 11.413513422012329 seconds
# Time to load utils op: 11.413597583770752 seconds
# Loading extension module utils...
# Time to load utils op: 11.412655591964722 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 11.412747621536255 seconds
# Loading extension module utils...
# Time to load utils op: 11.413334369659424 seconds
# Time to load utils op: 11.413060188293457 seconds
# Loading extension module utils...
# Time to load utils op: 11.418599128723145 seconds
# Rank: 1 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 3 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 4 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 0 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 7 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Time to load utils op: 0.00025963783264160156 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00026488304138183594 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002799034118652344 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002675056457519531 seconds
# Time to load utils op: 0.00026226043701171875 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00025010108947753906 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00026798248291015625 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0004904270172119141 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0:   5%| | 800/16025 [05:04<1:36:37,  2.63it/s, v_num=d7u3, train/loss=0.0/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 16025/16025 [1:44:15<00:00,  2.56it/s, v_num=d7u3, train/loss=1
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/17 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|█                  | 1/17 [00:00<00:03,  4.86it/s]
# Validation DataLoader 0:  12%|██▏                | 2/17 [00:00<00:02,  5.39it/s]
# Validation DataLoader 0:  18%|███▎               | 3/17 [00:00<00:02,  5.59it/s]
# Validation DataLoader 0:  24%|████▍              | 4/17 [00:00<00:02,  5.69it/s]
# Validation DataLoader 0:  29%|█████▌             | 5/17 [00:00<00:02,  5.73it/s]
# Validation DataLoader 0:  35%|██████▋            | 6/17 [00:01<00:01,  5.76it/s]
# Validation DataLoader 0:  41%|███████▊           | 7/17 [00:01<00:01,  5.79it/s]
# Validation DataLoader 0:  47%|████████▉          | 8/17 [00:01<00:01,  5.80it/s]
# Validation DataLoader 0:  53%|██████████         | 9/17 [00:01<00:01,  5.85it/s]
# Validation DataLoader 0:  59%|██████████▌       | 10/17 [00:01<00:01,  5.89it/s]
# Validation DataLoader 0:  65%|███████████▋      | 11/17 [00:01<00:01,  5.92it/s]
# Validation DataLoader 0:  71%|████████████▋     | 12/17 [00:02<00:00,  5.94it/s]
# Validation DataLoader 0:  76%|█████████████▊    | 13/17 [00:02<00:00,  5.98it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 14/17 [00:02<00:00,  6.02it/s]
# Validation DataLoader 0:  88%|███████████████▉  | 15/17 [00:02<00:00,  6.05it/s]
# Validation DataLoader 0:  94%|████████████████▉ | 16/17 [00:02<00:00,  6.09it/s]
# Epoch 0: 100%|█| 16025/16025 [1:44:24<00:00,  2.56it/s, v_num=d7u3, train/loss=1
# Epoch 0: 100%|█| 16025/16025 [1:44:24<00:00,  2.56it/s, v_num=d7u3, train/loss=1`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 16025/16025 [1:44:24<00:00,  2.56it/s, v_num=d7u3, train/loss=1
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▄▂▅▁▄▂▁▃▂▂▁▂▂▂▁▃▁▃▄▃▂▃▃▃▂▅▄▃▄▂▄█▂▁▄▂▂▂▁▂
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ▂▄▆█▁▆▂▂▄▃▂▂▁▂▂▂▁▁▂▄▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▂▁▁▁
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 16
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 118
# wandb:               substep 128
# wandb:            train/loss 0.01892
# wandb:   trainer/global_step 500
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 0.14509
# wandb:
# wandb: 🚀 View run (8x3090) TokenShift-C - Mem-Finetune-2 (bs=256, train-ctx=512, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/agugd7u3
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230721_155034-agugd7u3/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-C-mem-finetune-2/last-v1.ckpt" \
        "../model/TokenShift-C-Tune2.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-C-Tune2.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-C-mem-finetune-2/last-v1.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 438 params 1515106304 elements
# Saving fp32 state dict to ../model/TokenShift-C-Tune2.pth
# -rw-r--r-- 1 root root 5.7G Jul 21 17:45 ../model/TokenShift-C-Tune2.pth

# %%
# Lets do a memory eval 
#
# While not at its full potential, its memory ability should start emerging
#
# !python3 ../memory_script/eval_model_memory_guided.py "{PROJECT_DIR}/model/TokenShift-C-Tune2.pth"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 100.0% similarity, with 15 matched token, and 0 token mismatch
# ## Model validation for 20 tokens : 100.0% similarity, with 20 matched token, and 0 token mismatch
# ## Model validation for 25 tokens : 100.0% similarity, with 25 matched token, and 0 token mismatch
# ## Model validation for 30 tokens : 100.0% similarity, with 30 matched token, and 0 token mismatch
# ## Model validation for 35 tokens : 100.0% similarity, with 35 matched token, and 0 token mismatch
# ## Model validation for 40 tokens : 100.0% similarity, with 40 matched token, and 0 token mismatch
# ## Model validation for 45 tokens : 100.0% similarity, with 45 matched token, and 0 token mismatch
# ## Model validation for 50 tokens : 100.0% similarity, with 50 matched token, and 0 token mismatch
# ## Model validation for 55 tokens : 100.0% similarity, with 55 matched token, and 0 token mismatch
# ## Model validation for 60 tokens : 100.0% similarity, with 60 matched token, and 0 token mismatch
# ## Model validation for 65 tokens : 98.46153846153847% similarity, with 64 matched token, and 1 token mismatch
# ## Model validation for 70 tokens : 98.57142857142858% similarity, with 69 matched token, and 1 token mismatch
# ## Model validation for 75 tokens : 98.66666666666667% similarity, with 74 matched token, and 1 token mismatch
# ## Model validation for 80 tokens : 95.0% similarity, with 76 matched token, and 4 token mismatch
# ## Model validation for 85 tokens : 92.94117647058823% similarity, with 79 matched token, and 6 token mismatch
# ## Model validation for 90 tokens : 91.11111111111111% similarity, with 82 matched token, and 8 token mismatch
# ## Model validation for 95 tokens : 88.42105263157895% similarity, with 84 matched token, and 11 token mismatch
# ## Model validation for 100 tokens : 84.0% similarity, with 84 matched token, and 16 token mismatch
# ## Model validation for 105 tokens : 79.04761904761905% similarity, with 83 matched token, and 22 token mismatch
# ## Model validation for 110 tokens : 75.45454545454545% similarity, with 83 matched token, and 27 token mismatch
# ## Model validation for 115 tokens : 73.91304347826086% similarity, with 85 matched token, and 30 token mismatch
# ## Model validation for 120 tokens : 72.5% similarity, with 87 matched token, and 33 token mismatch
# ## Model validation for 125 tokens : 70.39999999999999% similarity, with 88 matched token, and 37 token mismatch
# ## Model validation for 130 tokens : 67.6923076923077% similarity, with 88 matched token, and 42 token mismatch
# ## Model validation for 135 tokens : 62.22222222222222% similarity, with 84 matched token, and 51 token mismatch
# ## Model validation for 140 tokens : 60.71428571428571% similarity, with 85 matched token, and 55 token mismatch
# ## Model validation for 145 tokens : 60.0% similarity, with 87 matched token, and 58 token mismatch
# ## Model validation for 150 tokens : 56.00000000000001% similarity, with 84 matched token, and 66 token mismatch
# ## Model validation for 160 tokens : 54.37499999999999% similarity, with 87 matched token, and 73 token mismatch
# ## Model validation for 170 tokens : 50.588235294117645% similarity, with 86 matched token, and 84 token mismatch
# ## Model validation for 180 tokens : 43.888888888888886% similarity, with 79 matched token, and 101 token mismatch
# ## Model validation for 190 tokens : 40.526315789473685% similarity, with 77 matched token, and 113 token mismatch
# ## Model validation for 200 tokens : 34.0% similarity, with 68 matched token, and 132 token mismatch
# ## Model validation for 210 tokens : 31.428571428571427% similarity, with 66 matched token, and 144 token mismatch
# ## Model validation for 220 tokens : 30.454545454545457% similarity, with 67 matched token, and 153 token mismatch
# ## Model validation for 230 tokens : 28.695652173913043% similarity, with 66 matched token, and 164 token mismatch
# ## Model validation for 240 tokens : 25.0% similarity, with 60 matched token, and 180 token mismatch
# ## Model validation for 250 tokens : 23.200000000000003% similarity, with 58 matched token, and 192 token mismatch
# ## Model validation for 260 tokens : 23.846153846153847% similarity, with 62 matched token, and 198 token mismatch
# ## Model validation for 270 tokens : 22.22222222222222% similarity, with 60 matched token, and 210 token mismatch
# ## Model validation for 280 tokens : 20.0% similarity, with 56 matched token, and 224 token mismatch
# ## Model validation for 290 tokens : 18.96551724137931% similarity, with 55 matched token, and 235 token mismatch
# ## Model validation for 300 tokens : 16.666666666666664% similarity, with 50 matched token, and 250 token mismatch
# ## Model validation for 325 tokens : 14.76923076923077% similarity, with 48 matched token, and 277 token mismatch
# ## Model validation for 350 tokens : 14.285714285714285% similarity, with 50 matched token, and 300 token mismatch
# ## Model validation for 375 tokens : 13.333333333333334% similarity, with 50 matched token, and 325 token mismatch
# ## Model validation for 400 tokens : 10.75% similarity, with 43 matched token, and 357 token mismatch
# ## Model validation for 425 tokens : 10.117647058823529% similarity, with 43 matched token, and 382 token mismatch
# ## Model validation for 450 tokens : 9.555555555555555% similarity, with 43 matched token, and 407 token mismatch
# ## Model validation for 475 tokens : 8.842105263157894% similarity, with 42 matched token, and 433 token mismatch
# ## Model validation for 500 tokens : 7.8% similarity, with 39 matched token, and 461 token mismatch
# ## Model validation for 525 tokens : 7.6190476190476195% similarity, with 40 matched token, and 485 token mismatch
# ## Model validation for 550 tokens : 6.7272727272727275% similarity, with 37 matched token, and 513 token mismatch
# ## Model validation for 575 tokens : 6.956521739130435% similarity, with 40 matched token, and 535 token mismatch
# ## Model validation for 600 tokens : 6.666666666666667% similarity, with 40 matched token, and 560 token mismatch
# ## Model validation for 625 tokens : 6.5600000000000005% similarity, with 41 matched token, and 584 token mismatch
# ## Model validation for 650 tokens : 6.153846153846154% similarity, with 40 matched token, and 610 token mismatch
# ## Model validation for 675 tokens : 5.62962962962963% similarity, with 38 matched token, and 637 token mismatch
# ## Model validation for 700 tokens : 5.142857142857142% similarity, with 36 matched token, and 664 token mismatch
# ## Model validation for 750 tokens : 5.333333333333334% similarity, with 40 matched token, and 710 token mismatch
# ## Model validation for 800 tokens : 4.5% similarity, with 36 matched token, and 764 token mismatch
# ## Model validation for 850 tokens : 4.352941176470588% similarity, with 37 matched token, and 813 token mismatch
# ## Model validation for 900 tokens : 4.111111111111112% similarity, with 37 matched token, and 863 token mismatch
# ## Model validation for 950 tokens : 3.7894736842105265% similarity, with 36 matched token, and 914 token mismatch
# ## Model validation for 1000 tokens : 3.6999999999999997% similarity, with 37 matched token, and 963 token mismatch

# %% [markdown]
# ## Tune 3 : Ramping up the ctx size (1024), memory training
#
# - Tune 3: Mid ctx size (1024), same as tune 2, but extended in context size
#
# This intentionally a much larger dataset, and lower learning rate to help ensure we push the model to its absolute limits.

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# #
# # We reduce the training set for < 50 words - and shift the focus upwards
# # (aka 50-100 token * 2 : ~100 - 250 token ctx len)
# #
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-2-count.jsonl 2 1000 &
# for i in {5..45..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 1000 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 10 &
# done
#
# #
# # Ramping up the 50+ - 400 words dataset
# #
# for i in {50..450..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 2000 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 20 &
# done
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated JSONL file with - 5 max words, 1000 samples - at ./dataset/gen-word-5-count.jsonl
# Generated JSONL file with - 15 max words, 1000 samples - at ./dataset/gen-word-15-count.jsonl
# Generated a single JSONL file with 654 samples (10 token repeat) - 40 max words - at ./dataset/shuffle-word-40-count.jsonl
# Generated JSONL file with - 10 max words, 1000 samples - at ./dataset/gen-word-10-count.jsonl
# Generated a single JSONL file with 874 samples (10 token repeat) - 30 max words - at ./dataset/shuffle-word-30-count.jsonl
# Generated a single JSONL file with 765 samples (10 token repeat) - 35 max words - at ./dataset/shuffle-word-35-count.jsonl
# Generated JSONL file with - 2 max words, 1000 samples - at ./dataset/word-2-count.jsonl
# Generated a single JSONL file with 1770 samples (10 token repeat) - 15 max words - at ./dataset/shuffle-word-15-count.jsonl
# Generated a single JSONL file with 592 samples (10 token repeat) - 45 max words - at ./dataset/shuffle-word-45-count.jsonl
# Generated a single JSONL file with 1068 samples (10 token repeat) - 25 max words - at ./dataset/shuffle-word-25-count.jsonl
# Generated JSONL file with - 20 max words, 1000 samples - at ./dataset/gen-word-20-count.jsonl
# Generated a single JSONL file with 655 samples (20 token repeat) - 80 max words - at ./dataset/shuffle-word-80-count.jsonl
# Generated a single JSONL file with 625 samples (20 token repeat) - 85 max words - at ./dataset/shuffle-word-85-count.jsonl
# Generated JSONL file with - 35 max words, 1000 samples - at ./dataset/gen-word-35-count.jsonl
# Generated a single JSONL file with 1318 samples (10 token repeat) - 20 max words - at ./dataset/shuffle-word-20-count.jsonl
# Generated JSONL file with - 30 max words, 1000 samples - at ./dataset/gen-word-30-count.jsonl
# Generated a single JSONL file with 809 samples (20 token repeat) - 65 max words - at ./dataset/shuffle-word-65-count.jsonl
# Generated a single JSONL file with 184 samples (20 token repeat) - 285 max words - at ./dataset/shuffle-word-285-count.jsonl
# Generated a single JSONL file with 287 samples (20 token repeat) - 165 max words - at ./dataset/shuffle-word-165-count.jsonl
# Generated JSONL file with - 25 max words, 1000 samples - at ./dataset/gen-word-25-count.jsonl
# Generated JSONL file with - 45 max words, 1000 samples - at ./dataset/gen-word-45-count.jsonl
# Generated a single JSONL file with 408 samples (20 token repeat) - 105 max words - at ./dataset/shuffle-word-105-count.jsonl
# Generated a single JSONL file with 1041 samples (20 token repeat) - 50 max words - at ./dataset/shuffle-word-50-count.jsonl
# Generated a single JSONL file with 590 samples (20 token repeat) - 90 max words - at ./dataset/shuffle-word-90-count.jsonl
# Generated a single JSONL file with 150 samples (20 token repeat) - 305 max words - at ./dataset/shuffle-word-305-count.jsonl
# Generated a single JSONL file with 889 samples (20 token repeat) - 60 max words - at ./dataset/shuffle-word-60-count.jsonl
# Generated a single JSONL file with 2607 samples (10 token repeat) - 10 max words - at ./dataset/shuffle-word-10-count.jsonl
# Generated a single JSONL file with 558 samples (20 token repeat) - 95 max words - at ./dataset/shuffle-word-95-count.jsonl
# Generated a single JSONL file with 394 samples (20 token repeat) - 110 max words - at ./dataset/shuffle-word-110-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 410 max words - at ./dataset/shuffle-word-410-count.jsonl
# Generated a single JSONL file with 278 samples (20 token repeat) - 175 max words - at ./dataset/shuffle-word-175-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 425 max words - at ./dataset/shuffle-word-425-count.jsonl
# Generated a single JSONL file with 960 samples (20 token repeat) - 55 max words - at ./dataset/shuffle-word-55-count.jsonl
# Generated a single JSONL file with 277 samples (20 token repeat) - 190 max words - at ./dataset/shuffle-word-190-count.jsonl
# Generated a single JSONL file with 301 samples (20 token repeat) - 155 max words - at ./dataset/shuffle-word-155-count.jsonl
# Generated a single JSONL file with 290 samples (20 token repeat) - 160 max words - at ./dataset/shuffle-word-160-count.jsonl
# Generated a single JSONL file with 347 samples (20 token repeat) - 130 max words - at ./dataset/shuffle-word-130-count.jsonl
# Generated a single JSONL file with 370 samples (20 token repeat) - 120 max words - at ./dataset/shuffle-word-120-count.jsonl
# Generated a single JSONL file with 274 samples (20 token repeat) - 185 max words - at ./dataset/shuffle-word-185-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 340 max words - at ./dataset/shuffle-word-340-count.jsonl
# Generated JSONL file with - 40 max words, 1000 samples - at ./dataset/gen-word-40-count.jsonl
# Generated a single JSONL file with 755 samples (20 token repeat) - 70 max words - at ./dataset/shuffle-word-70-count.jsonl
# Generated a single JSONL file with 180 samples (20 token repeat) - 295 max words - at ./dataset/shuffle-word-295-count.jsonl
# Generated a single JSONL file with 703 samples (20 token repeat) - 75 max words - at ./dataset/shuffle-word-75-count.jsonl
# Generated a single JSONL file with 181 samples (20 token repeat) - 290 max words - at ./dataset/shuffle-word-290-count.jsonl
# Generated a single JSONL file with 383 samples (20 token repeat) - 115 max words - at ./dataset/shuffle-word-115-count.jsonl
# Generated a single JSONL file with 208 samples (20 token repeat) - 210 max words - at ./dataset/shuffle-word-210-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 335 max words - at ./dataset/shuffle-word-335-count.jsonl
# Generated a single JSONL file with 528 samples (20 token repeat) - 100 max words - at ./dataset/shuffle-word-100-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 320 max words - at ./dataset/shuffle-word-320-count.jsonl
# Generated a single JSONL file with 270 samples (20 token repeat) - 195 max words - at ./dataset/shuffle-word-195-count.jsonl
# Generated a single JSONL file with 205 samples (20 token repeat) - 215 max words - at ./dataset/shuffle-word-215-count.jsonl
# Generated a single JSONL file with 325 samples (20 token repeat) - 140 max words - at ./dataset/shuffle-word-140-count.jsonl
# Generated a single JSONL file with 139 samples (20 token repeat) - 395 max words - at ./dataset/shuffle-word-395-count.jsonl
# Generated a single JSONL file with 338 samples (20 token repeat) - 135 max words - at ./dataset/shuffle-word-135-count.jsonl
# Generated a single JSONL file with 271 samples (20 token repeat) - 200 max words - at ./dataset/shuffle-word-200-count.jsonl
# Generated a single JSONL file with 181 samples (20 token repeat) - 300 max words - at ./dataset/shuffle-word-300-count.jsonl
# Generated a single JSONL file with 5575 samples (10 token repeat) - 5 max words - at ./dataset/shuffle-word-5-count.jsonl
# Generated a single JSONL file with 188 samples (20 token repeat) - 245 max words - at ./dataset/shuffle-word-245-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 435 max words - at ./dataset/shuffle-word-435-count.jsonl
# Generated a single JSONL file with 142 samples (20 token repeat) - 325 max words - at ./dataset/shuffle-word-325-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 370 max words - at ./dataset/shuffle-word-370-count.jsonl
# Generated a single JSONL file with 200 samples (20 token repeat) - 225 max words - at ./dataset/shuffle-word-225-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 420 max words - at ./dataset/shuffle-word-420-count.jsonl
# Generated a single JSONL file with 183 samples (20 token repeat) - 270 max words - at ./dataset/shuffle-word-270-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 355 max words - at ./dataset/shuffle-word-355-count.jsonl
# Generated a single JSONL file with 182 samples (20 token repeat) - 265 max words - at ./dataset/shuffle-word-265-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 260 max words - at ./dataset/shuffle-word-260-count.jsonl
# Generated a single JSONL file with 139 samples (20 token repeat) - 385 max words - at ./dataset/shuffle-word-385-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 365 max words - at ./dataset/shuffle-word-365-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 275 max words - at ./dataset/shuffle-word-275-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 415 max words - at ./dataset/shuffle-word-415-count.jsonl
# Generated a single JSONL file with 189 samples (20 token repeat) - 240 max words - at ./dataset/shuffle-word-240-count.jsonl
# Generated a single JSONL file with 274 samples (20 token repeat) - 180 max words - at ./dataset/shuffle-word-180-count.jsonl
# Generated a single JSONL file with 115 samples (20 token repeat) - 440 max words - at ./dataset/shuffle-word-440-count.jsonl
# Generated JSONL file with - 80 max words, 2000 samples - at ./dataset/gen-word-80-count.jsonl
# Generated a single JSONL file with 357 samples (20 token repeat) - 125 max words - at ./dataset/shuffle-word-125-count.jsonl
# Generated a single JSONL file with 143 samples (20 token repeat) - 315 max words - at ./dataset/shuffle-word-315-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 450 max words - at ./dataset/shuffle-word-450-count.jsonl
# Generated a single JSONL file with 286 samples (20 token repeat) - 170 max words - at ./dataset/shuffle-word-170-count.jsonl
# Generated a single JSONL file with 199 samples (20 token repeat) - 235 max words - at ./dataset/shuffle-word-235-count.jsonl
# Generated a single JSONL file with 188 samples (20 token repeat) - 255 max words - at ./dataset/shuffle-word-255-count.jsonl
# Generated JSONL file with - 90 max words, 2000 samples - at ./dataset/gen-word-90-count.jsonl
# Generated JSONL file with - 65 max words, 2000 samples - at ./dataset/gen-word-65-count.jsonl
# Generated a single JSONL file with 139 samples (20 token repeat) - 375 max words - at ./dataset/shuffle-word-375-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 350 max words - at ./dataset/shuffle-word-350-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 400 max words - at ./dataset/shuffle-word-400-count.jsonl
# Generated JSONL file with - 100 max words, 2000 samples - at ./dataset/gen-word-100-count.jsonl
# Generated JSONL file with - 60 max words, 2000 samples - at ./dataset/gen-word-60-count.jsonl
# Generated a single JSONL file with 319 samples (20 token repeat) - 145 max words - at ./dataset/shuffle-word-145-count.jsonl
# Generated a single JSONL file with 217 samples (20 token repeat) - 205 max words - at ./dataset/shuffle-word-205-count.jsonl
# Generated JSONL file with - 55 max words, 2000 samples - at ./dataset/gen-word-55-count.jsonl
# Generated a single JSONL file with 310 samples (20 token repeat) - 150 max words - at ./dataset/shuffle-word-150-count.jsonl
# Generated a single JSONL file with 201 samples (20 token repeat) - 220 max words - at ./dataset/shuffle-word-220-count.jsonl
# Generated JSONL file with - 70 max words, 2000 samples - at ./dataset/gen-word-70-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 430 max words - at ./dataset/shuffle-word-430-count.jsonl
# Generated JSONL file with - 155 max words, 2000 samples - at ./dataset/gen-word-155-count.jsonl
# Generated JSONL file with - 160 max words, 2000 samples - at ./dataset/gen-word-160-count.jsonl
# Generated a single JSONL file with 115 samples (20 token repeat) - 445 max words - at ./dataset/shuffle-word-445-count.jsonl
# Generated a single JSONL file with 198 samples (20 token repeat) - 230 max words - at ./dataset/shuffle-word-230-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 390 max words - at ./dataset/shuffle-word-390-count.jsonl
# Generated a single JSONL file with 139 samples (20 token repeat) - 360 max words - at ./dataset/shuffle-word-360-count.jsonl
# Generated JSONL file with - 50 max words, 2000 samples - at ./dataset/gen-word-50-count.jsonl
# Generated a single JSONL file with 145 samples (20 token repeat) - 310 max words - at ./dataset/shuffle-word-310-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 345 max words - at ./dataset/shuffle-word-345-count.jsonl
# Generated a single JSONL file with 182 samples (20 token repeat) - 280 max words - at ./dataset/shuffle-word-280-count.jsonl
# Generated JSONL file with - 75 max words, 2000 samples - at ./dataset/gen-word-75-count.jsonl
# Generated JSONL file with - 170 max words, 2000 samples - at ./dataset/gen-word-170-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 330 max words - at ./dataset/shuffle-word-330-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 405 max words - at ./dataset/shuffle-word-405-count.jsonl
# Generated JSONL file with - 85 max words, 2000 samples - at ./dataset/gen-word-85-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 380 max words - at ./dataset/shuffle-word-380-count.jsonl
# Generated JSONL file with - 95 max words, 2000 samples - at ./dataset/gen-word-95-count.jsonl
# Generated a single JSONL file with 187 samples (20 token repeat) - 250 max words - at ./dataset/shuffle-word-250-count.jsonl
# Generated JSONL file with - 110 max words, 2000 samples - at ./dataset/gen-word-110-count.jsonl
# Generated JSONL file with - 120 max words, 2000 samples - at ./dataset/gen-word-120-count.jsonl
# Generated JSONL file with - 105 max words, 2000 samples - at ./dataset/gen-word-105-count.jsonl
# Generated JSONL file with - 115 max words, 2000 samples - at ./dataset/gen-word-115-count.jsonl
# Generated JSONL file with - 125 max words, 2000 samples - at ./dataset/gen-word-125-count.jsonl
# Generated JSONL file with - 130 max words, 2000 samples - at ./dataset/gen-word-130-count.jsonl
# Generated JSONL file with - 145 max words, 2000 samples - at ./dataset/gen-word-145-count.jsonl
# Generated JSONL file with - 200 max words, 2000 samples - at ./dataset/gen-word-200-count.jsonl
# Generated JSONL file with - 135 max words, 2000 samples - at ./dataset/gen-word-135-count.jsonl
# Generated JSONL file with - 175 max words, 2000 samples - at ./dataset/gen-word-175-count.jsonl
# Generated JSONL file with - 195 max words, 2000 samples - at ./dataset/gen-word-195-count.jsonl
# Generated JSONL file with - 185 max words, 2000 samples - at ./dataset/gen-word-185-count.jsonl
# Generated JSONL file with - 140 max words, 2000 samples - at ./dataset/gen-word-140-count.jsonl
# Generated JSONL file with - 205 max words, 2000 samples - at ./dataset/gen-word-205-count.jsonl
# Generated JSONL file with - 165 max words, 2000 samples - at ./dataset/gen-word-165-count.jsonl
# Generated JSONL file with - 180 max words, 2000 samples - at ./dataset/gen-word-180-count.jsonl
# Generated JSONL file with - 150 max words, 2000 samples - at ./dataset/gen-word-150-count.jsonl
# Generated JSONL file with - 310 max words, 2000 samples - at ./dataset/gen-word-310-count.jsonl
# Generated JSONL file with - 250 max words, 2000 samples - at ./dataset/gen-word-250-count.jsonl
# Generated JSONL file with - 315 max words, 2000 samples - at ./dataset/gen-word-315-count.jsonl
# Generated JSONL file with - 220 max words, 2000 samples - at ./dataset/gen-word-220-count.jsonl
# Generated JSONL file with - 210 max words, 2000 samples - at ./dataset/gen-word-210-count.jsonl
# Generated JSONL file with - 190 max words, 2000 samples - at ./dataset/gen-word-190-count.jsonl
# Generated JSONL file with - 270 max words, 2000 samples - at ./dataset/gen-word-270-count.jsonl
# Generated JSONL file with - 215 max words, 2000 samples - at ./dataset/gen-word-215-count.jsonl
# Generated JSONL file with - 235 max words, 2000 samples - at ./dataset/gen-word-235-count.jsonl
# Generated JSONL file with - 295 max words, 2000 samples - at ./dataset/gen-word-295-count.jsonl
# Generated JSONL file with - 275 max words, 2000 samples - at ./dataset/gen-word-275-count.jsonl
# Generated JSONL file with - 225 max words, 2000 samples - at ./dataset/gen-word-225-count.jsonl
# Generated JSONL file with - 285 max words, 2000 samples - at ./dataset/gen-word-285-count.jsonl
# Generated JSONL file with - 345 max words, 2000 samples - at ./dataset/gen-word-345-count.jsonl
# Generated JSONL file with - 290 max words, 2000 samples - at ./dataset/gen-word-290-count.jsonl
# Generated JSONL file with - 240 max words, 2000 samples - at ./dataset/gen-word-240-count.jsonl
# Generated JSONL file with - 375 max words, 2000 samples - at ./dataset/gen-word-375-count.jsonl
# Generated JSONL file with - 325 max words, 2000 samples - at ./dataset/gen-word-325-count.jsonl
# Generated JSONL file with - 300 max words, 2000 samples - at ./dataset/gen-word-300-count.jsonl
# Generated JSONL file with - 265 max words, 2000 samples - at ./dataset/gen-word-265-count.jsonl
# Generated JSONL file with - 245 max words, 2000 samples - at ./dataset/gen-word-245-count.jsonl
# Generated JSONL file with - 385 max words, 2000 samples - at ./dataset/gen-word-385-count.jsonl
# Generated JSONL file with - 320 max words, 2000 samples - at ./dataset/gen-word-320-count.jsonl
# Generated JSONL file with - 230 max words, 2000 samples - at ./dataset/gen-word-230-count.jsonl
# Generated JSONL file with - 260 max words, 2000 samples - at ./dataset/gen-word-260-count.jsonl
# Generated JSONL file with - 360 max words, 2000 samples - at ./dataset/gen-word-360-count.jsonl
# Generated JSONL file with - 255 max words, 2000 samples - at ./dataset/gen-word-255-count.jsonl
# Generated JSONL file with - 280 max words, 2000 samples - at ./dataset/gen-word-280-count.jsonl
# Generated JSONL file with - 340 max words, 2000 samples - at ./dataset/gen-word-340-count.jsonl
# Generated JSONL file with - 350 max words, 2000 samples - at ./dataset/gen-word-350-count.jsonl
# Generated JSONL file with - 410 max words, 2000 samples - at ./dataset/gen-word-410-count.jsonl
# Generated JSONL file with - 370 max words, 2000 samples - at ./dataset/gen-word-370-count.jsonl
# Generated JSONL file with - 355 max words, 2000 samples - at ./dataset/gen-word-355-count.jsonl
# Generated JSONL file with - 305 max words, 2000 samples - at ./dataset/gen-word-305-count.jsonl
# Generated JSONL file with - 430 max words, 2000 samples - at ./dataset/gen-word-430-count.jsonl
# Generated JSONL file with - 335 max words, 2000 samples - at ./dataset/gen-word-335-count.jsonl
# Generated JSONL file with - 420 max words, 2000 samples - at ./dataset/gen-word-420-count.jsonl
# Generated JSONL file with - 445 max words, 2000 samples - at ./dataset/gen-word-445-count.jsonl
# Generated JSONL file with - 365 max words, 2000 samples - at ./dataset/gen-word-365-count.jsonl
# Generated JSONL file with - 380 max words, 2000 samples - at ./dataset/gen-word-380-count.jsonl
# Generated JSONL file with - 390 max words, 2000 samples - at ./dataset/gen-word-390-count.jsonl
# Generated JSONL file with - 330 max words, 2000 samples - at ./dataset/gen-word-330-count.jsonl
# Generated JSONL file with - 440 max words, 2000 samples - at ./dataset/gen-word-440-count.jsonl
# Generated JSONL file with - 400 max words, 2000 samples - at ./dataset/gen-word-400-count.jsonl
# Generated JSONL file with - 415 max words, 2000 samples - at ./dataset/gen-word-415-count.jsonl
# Generated JSONL file with - 405 max words, 2000 samples - at ./dataset/gen-word-405-count.jsonl
# Generated JSONL file with - 435 max words, 2000 samples - at ./dataset/gen-word-435-count.jsonl
# Generated JSONL file with - 395 max words, 2000 samples - at ./dataset/gen-word-395-count.jsonl
# Generated JSONL file with - 450 max words, 2000 samples - at ./dataset/gen-word-450-count.jsonl
# Generated JSONL file with - 425 max words, 2000 samples - at ./dataset/gen-word-425-count.jsonl
# ## Done ##
# total 450M
# drwxr-xr-x 2 root root 8.0K Jul 21 17:52 .
# drwxr-xr-x 6 root root 4.0K Jul 21 17:51 ..
# -rw-r--r-- 1 root root 199K Jul 21 17:52 gen-word-10-count.jsonl
# -rw-r--r-- 1 root root 2.1M Jul 21 17:52 gen-word-100-count.jsonl
# -rw-r--r-- 1 root root 2.2M Jul 21 17:52 gen-word-105-count.jsonl
# -rw-r--r-- 1 root root 2.3M Jul 21 17:52 gen-word-110-count.jsonl
# -rw-r--r-- 1 root root 2.4M Jul 21 17:52 gen-word-115-count.jsonl
# -rw-r--r-- 1 root root 2.5M Jul 21 17:52 gen-word-120-count.jsonl
# -rw-r--r-- 1 root root 2.6M Jul 21 17:52 gen-word-125-count.jsonl
# -rw-r--r-- 1 root root 2.7M Jul 21 17:52 gen-word-130-count.jsonl
# -rw-r--r-- 1 root root 2.8M Jul 21 17:52 gen-word-135-count.jsonl
# -rw-r--r-- 1 root root 2.9M Jul 21 17:52 gen-word-140-count.jsonl
# -rw-r--r-- 1 root root 3.0M Jul 21 17:52 gen-word-145-count.jsonl
# -rw-r--r-- 1 root root 242K Jul 21 17:52 gen-word-15-count.jsonl
# -rw-r--r-- 1 root root 3.1M Jul 21 17:52 gen-word-150-count.jsonl
# -rw-r--r-- 1 root root 3.2M Jul 21 17:52 gen-word-155-count.jsonl
# -rw-r--r-- 1 root root 3.3M Jul 21 17:52 gen-word-160-count.jsonl
# -rw-r--r-- 1 root root 3.4M Jul 21 17:52 gen-word-165-count.jsonl
# -rw-r--r-- 1 root root 3.5M Jul 21 17:52 gen-word-170-count.jsonl
# -rw-r--r-- 1 root root 3.6M Jul 21 17:52 gen-word-175-count.jsonl
# -rw-r--r-- 1 root root 3.7M Jul 21 17:52 gen-word-180-count.jsonl
# -rw-r--r-- 1 root root 3.8M Jul 21 17:52 gen-word-185-count.jsonl
# -rw-r--r-- 1 root root 3.8M Jul 21 17:52 gen-word-190-count.jsonl
# -rw-r--r-- 1 root root 3.9M Jul 21 17:52 gen-word-195-count.jsonl
# -rw-r--r-- 1 root root 296K Jul 21 17:52 gen-word-20-count.jsonl
# -rw-r--r-- 1 root root 4.0M Jul 21 17:52 gen-word-200-count.jsonl
# -rw-r--r-- 1 root root 4.1M Jul 21 17:52 gen-word-205-count.jsonl
# -rw-r--r-- 1 root root 4.2M Jul 21 17:52 gen-word-210-count.jsonl
# -rw-r--r-- 1 root root 4.3M Jul 21 17:52 gen-word-215-count.jsonl
# -rw-r--r-- 1 root root 4.4M Jul 21 17:52 gen-word-220-count.jsonl
# -rw-r--r-- 1 root root 4.5M Jul 21 17:52 gen-word-225-count.jsonl
# -rw-r--r-- 1 root root 4.6M Jul 21 17:52 gen-word-230-count.jsonl
# -rw-r--r-- 1 root root 4.7M Jul 21 17:52 gen-word-235-count.jsonl
# -rw-r--r-- 1 root root 4.8M Jul 21 17:52 gen-word-240-count.jsonl
# -rw-r--r-- 1 root root 4.9M Jul 21 17:52 gen-word-245-count.jsonl
# -rw-r--r-- 1 root root 337K Jul 21 17:52 gen-word-25-count.jsonl
# -rw-r--r-- 1 root root 5.0M Jul 21 17:52 gen-word-250-count.jsonl
# -rw-r--r-- 1 root root 5.1M Jul 21 17:52 gen-word-255-count.jsonl
# -rw-r--r-- 1 root root 5.2M Jul 21 17:52 gen-word-260-count.jsonl
# -rw-r--r-- 1 root root 5.3M Jul 21 17:52 gen-word-265-count.jsonl
# -rw-r--r-- 1 root root 5.4M Jul 21 17:52 gen-word-270-count.jsonl
# -rw-r--r-- 1 root root 5.4M Jul 21 17:52 gen-word-275-count.jsonl
# -rw-r--r-- 1 root root 5.6M Jul 21 17:52 gen-word-280-count.jsonl
# -rw-r--r-- 1 root root 5.6M Jul 21 17:52 gen-word-285-count.jsonl
# -rw-r--r-- 1 root root 5.8M Jul 21 17:52 gen-word-290-count.jsonl
# -rw-r--r-- 1 root root 5.8M Jul 21 17:52 gen-word-295-count.jsonl
# -rw-r--r-- 1 root root 389K Jul 21 17:52 gen-word-30-count.jsonl
# -rw-r--r-- 1 root root 6.0M Jul 21 17:52 gen-word-300-count.jsonl
# -rw-r--r-- 1 root root 6.1M Jul 21 17:52 gen-word-305-count.jsonl
# -rw-r--r-- 1 root root 6.1M Jul 21 17:52 gen-word-310-count.jsonl
# -rw-r--r-- 1 root root 6.2M Jul 21 17:52 gen-word-315-count.jsonl
# -rw-r--r-- 1 root root 6.3M Jul 21 17:52 gen-word-320-count.jsonl
# -rw-r--r-- 1 root root 6.4M Jul 21 17:52 gen-word-325-count.jsonl
# -rw-r--r-- 1 root root 6.5M Jul 21 17:52 gen-word-330-count.jsonl
# -rw-r--r-- 1 root root 6.6M Jul 21 17:52 gen-word-335-count.jsonl
# -rw-r--r-- 1 root root 6.7M Jul 21 17:52 gen-word-340-count.jsonl
# -rw-r--r-- 1 root root 6.8M Jul 21 17:52 gen-word-345-count.jsonl
# -rw-r--r-- 1 root root 436K Jul 21 17:52 gen-word-35-count.jsonl
# -rw-r--r-- 1 root root 6.9M Jul 21 17:52 gen-word-350-count.jsonl
# -rw-r--r-- 1 root root 7.0M Jul 21 17:52 gen-word-355-count.jsonl
# -rw-r--r-- 1 root root 7.1M Jul 21 17:52 gen-word-360-count.jsonl
# -rw-r--r-- 1 root root 7.2M Jul 21 17:52 gen-word-365-count.jsonl
# -rw-r--r-- 1 root root 7.2M Jul 21 17:52 gen-word-370-count.jsonl
# -rw-r--r-- 1 root root 7.3M Jul 21 17:52 gen-word-375-count.jsonl
# -rw-r--r-- 1 root root 7.5M Jul 21 17:52 gen-word-380-count.jsonl
# -rw-r--r-- 1 root root 7.6M Jul 21 17:52 gen-word-385-count.jsonl
# -rw-r--r-- 1 root root 7.7M Jul 21 17:52 gen-word-390-count.jsonl
# -rw-r--r-- 1 root root 7.7M Jul 21 17:52 gen-word-395-count.jsonl
# -rw-r--r-- 1 root root 484K Jul 21 17:52 gen-word-40-count.jsonl
# -rw-r--r-- 1 root root 7.8M Jul 21 17:52 gen-word-400-count.jsonl
# -rw-r--r-- 1 root root 7.9M Jul 21 17:52 gen-word-405-count.jsonl
# -rw-r--r-- 1 root root 8.0M Jul 21 17:52 gen-word-410-count.jsonl
# -rw-r--r-- 1 root root 8.1M Jul 21 17:52 gen-word-415-count.jsonl
# -rw-r--r-- 1 root root 8.2M Jul 21 17:52 gen-word-420-count.jsonl
# -rw-r--r-- 1 root root 8.3M Jul 21 17:52 gen-word-425-count.jsonl
# -rw-r--r-- 1 root root 8.4M Jul 21 17:52 gen-word-430-count.jsonl
# -rw-r--r-- 1 root root 8.5M Jul 21 17:52 gen-word-435-count.jsonl
# -rw-r--r-- 1 root root 8.6M Jul 21 17:52 gen-word-440-count.jsonl
# -rw-r--r-- 1 root root 8.7M Jul 21 17:52 gen-word-445-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 21 17:52 gen-word-45-count.jsonl
# -rw-r--r-- 1 root root 8.8M Jul 21 17:52 gen-word-450-count.jsonl
# -rw-r--r-- 1 root root 146K Jul 21 17:52 gen-word-5-count.jsonl
# -rw-r--r-- 1 root root 1.2M Jul 21 17:52 gen-word-50-count.jsonl
# -rw-r--r-- 1 root root 1.3M Jul 21 17:52 gen-word-55-count.jsonl
# -rw-r--r-- 1 root root 1.4M Jul 21 17:52 gen-word-60-count.jsonl
# -rw-r--r-- 1 root root 1.5M Jul 21 17:52 gen-word-65-count.jsonl
# -rw-r--r-- 1 root root 1.6M Jul 21 17:52 gen-word-70-count.jsonl
# -rw-r--r-- 1 root root 1.6M Jul 21 17:52 gen-word-75-count.jsonl
# -rw-r--r-- 1 root root 1.8M Jul 21 17:52 gen-word-80-count.jsonl
# -rw-r--r-- 1 root root 1.8M Jul 21 17:52 gen-word-85-count.jsonl
# -rw-r--r-- 1 root root 1.9M Jul 21 17:52 gen-word-90-count.jsonl
# -rw-r--r-- 1 root root 2.0M Jul 21 17:52 gen-word-95-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 21 17:52 shuffle-word-10-count.jsonl
# -rw-r--r-- 1 root root 562K Jul 21 17:52 shuffle-word-100-count.jsonl
# -rw-r--r-- 1 root root 554K Jul 21 17:52 shuffle-word-105-count.jsonl
# -rw-r--r-- 1 root root 553K Jul 21 17:52 shuffle-word-110-count.jsonl
# -rw-r--r-- 1 root root 552K Jul 21 17:52 shuffle-word-115-count.jsonl
# -rw-r--r-- 1 root root 558K Jul 21 17:52 shuffle-word-120-count.jsonl
# -rw-r--r-- 1 root root 550K Jul 21 17:52 shuffle-word-125-count.jsonl
# -rw-r--r-- 1 root root 549K Jul 21 17:52 shuffle-word-130-count.jsonl
# -rw-r--r-- 1 root root 548K Jul 21 17:52 shuffle-word-135-count.jsonl
# -rw-r--r-- 1 root root 545K Jul 21 17:52 shuffle-word-140-count.jsonl
# -rw-r--r-- 1 root root 541K Jul 21 17:52 shuffle-word-145-count.jsonl
# -rw-r--r-- 1 root root 437K Jul 21 17:52 shuffle-word-15-count.jsonl
# -rw-r--r-- 1 root root 545K Jul 21 17:52 shuffle-word-150-count.jsonl
# -rw-r--r-- 1 root root 549K Jul 21 17:52 shuffle-word-155-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 21 17:52 shuffle-word-160-count.jsonl
# -rw-r--r-- 1 root root 548K Jul 21 17:52 shuffle-word-165-count.jsonl
# -rw-r--r-- 1 root root 541K Jul 21 17:52 shuffle-word-170-count.jsonl
# -rw-r--r-- 1 root root 548K Jul 21 17:52 shuffle-word-175-count.jsonl
# -rw-r--r-- 1 root root 542K Jul 21 17:52 shuffle-word-180-count.jsonl
# -rw-r--r-- 1 root root 539K Jul 21 17:52 shuffle-word-185-count.jsonl
# -rw-r--r-- 1 root root 542K Jul 21 17:52 shuffle-word-190-count.jsonl
# -rw-r--r-- 1 root root 544K Jul 21 17:52 shuffle-word-195-count.jsonl
# -rw-r--r-- 1 root root 379K Jul 21 17:52 shuffle-word-20-count.jsonl
# -rw-r--r-- 1 root root 549K Jul 21 17:52 shuffle-word-200-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 21 17:52 shuffle-word-205-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 21 17:52 shuffle-word-210-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 21 17:52 shuffle-word-215-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 21 17:52 shuffle-word-220-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 21 17:52 shuffle-word-225-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 21 17:52 shuffle-word-230-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 21 17:52 shuffle-word-235-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 21 17:52 shuffle-word-240-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 21 17:52 shuffle-word-245-count.jsonl
# -rw-r--r-- 1 root root 365K Jul 21 17:52 shuffle-word-25-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 21 17:52 shuffle-word-250-count.jsonl
# -rw-r--r-- 1 root root 539K Jul 21 17:52 shuffle-word-255-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 21 17:52 shuffle-word-260-count.jsonl
# -rw-r--r-- 1 root root 539K Jul 21 17:52 shuffle-word-265-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 21 17:52 shuffle-word-270-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 21 17:52 shuffle-word-275-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 21 17:52 shuffle-word-280-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 21 17:52 shuffle-word-285-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 21 17:52 shuffle-word-290-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 21 17:52 shuffle-word-295-count.jsonl
# -rw-r--r-- 1 root root 347K Jul 21 17:52 shuffle-word-30-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 21 17:52 shuffle-word-300-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 21 17:52 shuffle-word-305-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 21 17:52 shuffle-word-310-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 21 17:52 shuffle-word-315-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 21 17:52 shuffle-word-320-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 21 17:52 shuffle-word-325-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 21 17:52 shuffle-word-330-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 21 17:52 shuffle-word-335-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 21 17:52 shuffle-word-340-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 21 17:52 shuffle-word-345-count.jsonl
# -rw-r--r-- 1 root root 330K Jul 21 17:52 shuffle-word-35-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 21 17:52 shuffle-word-350-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 21 17:52 shuffle-word-355-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 21 17:52 shuffle-word-360-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 21 17:52 shuffle-word-365-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 21 17:52 shuffle-word-370-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 21 17:52 shuffle-word-375-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 21 17:52 shuffle-word-380-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 21 17:52 shuffle-word-385-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 21 17:52 shuffle-word-390-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 21 17:52 shuffle-word-395-count.jsonl
# -rw-r--r-- 1 root root 321K Jul 21 17:52 shuffle-word-40-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 21 17:52 shuffle-word-400-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 21 17:52 shuffle-word-405-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 21 17:52 shuffle-word-410-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 21 17:52 shuffle-word-415-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 21 17:52 shuffle-word-420-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 21 17:52 shuffle-word-425-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 21 17:52 shuffle-word-430-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 21 17:52 shuffle-word-435-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 21 17:52 shuffle-word-440-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 21 17:52 shuffle-word-445-count.jsonl
# -rw-r--r-- 1 root root 319K Jul 21 17:52 shuffle-word-45-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 21 17:52 shuffle-word-450-count.jsonl
# -rw-r--r-- 1 root root 806K Jul 21 17:52 shuffle-word-5-count.jsonl
# -rw-r--r-- 1 root root 615K Jul 21 17:52 shuffle-word-50-count.jsonl
# -rw-r--r-- 1 root root 605K Jul 21 17:52 shuffle-word-55-count.jsonl
# -rw-r--r-- 1 root root 591K Jul 21 17:52 shuffle-word-60-count.jsonl
# -rw-r--r-- 1 root root 585K Jul 21 17:52 shuffle-word-65-count.jsonl
# -rw-r--r-- 1 root root 592K Jul 21 17:52 shuffle-word-70-count.jsonl
# -rw-r--r-- 1 root root 583K Jul 21 17:52 shuffle-word-75-count.jsonl
# -rw-r--r-- 1 root root 579K Jul 21 17:52 shuffle-word-80-count.jsonl
# -rw-r--r-- 1 root root 578K Jul 21 17:52 shuffle-word-85-count.jsonl
# -rw-r--r-- 1 root root 567K Jul 21 17:52 shuffle-word-90-count.jsonl
# -rw-r--r-- 1 root root 571K Jul 21 17:52 shuffle-word-95-count.jsonl
# -rw-r--r-- 1 root root 121K Jul 21 17:52 word-2-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-3.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-C-mem-finetune-3/"
# Out:
# Resolving data files: 100%|████████████████| 181/181 [00:00<00:00, 49804.44it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-1985c72b4ac3e8cc/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|████████████████████| 1/1 [00:00<00:00, 727.93it/s]
# Extracting data files: 100%|██████████████████████| 1/1 [00:00<00:00, 26.76it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-1985c72b4ac3e8cc/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 78.69it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-3.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-3 (bs=256, train-ctx=1024, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=1024
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 177105619
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 177105619
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230721_175235-vn0y3b4n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run (8x3090) TokenShift-C - Mem-Finetune-3 (bs=256, train-ctx=1024, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/vn0y3b4n
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Resolving data files: 100%|████████████████| 181/181 [00:00<00:00, 79719.52it/s]
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-1985c72b4ac3e8cc/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 108.47it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-1985c72b4ac3e8cc/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-723c19ed6b9748bc_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-1985c72b4ac3e8cc/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-d764fddb44119f47_*_of_00064.arrow
# [rank: 0] Global seed set to 177105619
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-21 17:52:50,672] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [rank: 6] Global seed set to 177105619
# [rank: 2] Global seed set to 177105619
# [rank: 4] Global seed set to 177105619
# [rank: 5] Global seed set to 177105619
# [rank: 1] Global seed set to 177105619
# [rank: 3] Global seed set to 177105619
# [rank: 7] Global seed set to 177105619
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# [rank: 6] Global seed set to 177105619
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-21 17:53:04,202] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 177105619
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-21 17:53:08,166] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 177105619
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-07-21 17:53:09,029] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 177105619
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-21 17:53:09,066] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 177105619
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-21 17:53:09,086] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 177105619
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-21 17:53:09,104] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 3] Global seed set to 177105619
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-21 17:53:09,115] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  4.000e-04 (0.0004)
#     - lr_final: 1.000e-04 (0.0001)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.0634164810180664 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10140419006347656 seconds
# Time to load fused_adam op: 0.10142350196838379 seconds
# Time to load fused_adam op: 0.10185837745666504 seconds
# Time to load fused_adam op: 0.10186576843261719 seconds
# Time to load fused_adam op: 0.10169625282287598 seconds
# Time to load fused_adam op: 0.10181307792663574 seconds
# Time to load fused_adam op: 0.10171675682067871 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.0672149658203125 seconds
# Loading extension module utils...
# Time to load utils op: 0.10180187225341797 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10191893577575684 seconds
# Time to load utils op: 0.10140180587768555 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10139799118041992 seconds
# Time to load utils op: 0.10162854194641113 seconds
# Time to load utils op: 0.10178470611572266 seconds
# Time to load utils op: 0.10214924812316895 seconds
# Rank: 0 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 4 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 3 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 7 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 1 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00025725364685058594 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002658367156982422 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002434253692626953 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00026488304138183594 seconds
# Time to load utils op: 0.0002562999725341797 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00026607513427734375 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.000347137451171875 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00048232078552246094 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0:   3%| | 800/26164 [05:43<3:01:19,  2.33it/s, v_num=3b4n, train/loss=4.6/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 26164/26164 [3:17:24<00:00,  2.21it/s, v_num=3b4n, train/loss=0
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/27 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/27 [00:00<?, ?it/s]
# Validation DataLoader 0:   4%|▋                  | 1/27 [00:00<00:05,  4.73it/s]
# Validation DataLoader 0:   7%|█▍                 | 2/27 [00:00<00:04,  5.23it/s]
# Validation DataLoader 0:  11%|██                 | 3/27 [00:00<00:04,  5.43it/s]
# Validation DataLoader 0:  15%|██▊                | 4/27 [00:00<00:04,  5.55it/s]
# Validation DataLoader 0:  19%|███▌               | 5/27 [00:00<00:03,  5.61it/s]
# Validation DataLoader 0:  22%|████▏              | 6/27 [00:01<00:03,  5.66it/s]
# Validation DataLoader 0:  26%|████▉              | 7/27 [00:01<00:03,  5.68it/s]
# Validation DataLoader 0:  30%|█████▋             | 8/27 [00:01<00:03,  5.71it/s]
# Validation DataLoader 0:  33%|██████▎            | 9/27 [00:01<00:03,  5.73it/s]
# Validation DataLoader 0:  37%|██████▋           | 10/27 [00:01<00:02,  5.74it/s]
# Validation DataLoader 0:  41%|███████▎          | 11/27 [00:01<00:02,  5.76it/s]
# Validation DataLoader 0:  44%|████████          | 12/27 [00:02<00:02,  5.78it/s]
# Validation DataLoader 0:  48%|████████▋         | 13/27 [00:02<00:02,  5.81it/s]
# Validation DataLoader 0:  52%|█████████▎        | 14/27 [00:02<00:02,  5.84it/s]
# Validation DataLoader 0:  56%|██████████        | 15/27 [00:02<00:02,  5.86it/s]
# Validation DataLoader 0:  59%|██████████▋       | 16/27 [00:02<00:01,  5.88it/s]
# Validation DataLoader 0:  63%|███████████▎      | 17/27 [00:02<00:01,  5.88it/s]
# Validation DataLoader 0:  67%|████████████      | 18/27 [00:03<00:01,  5.90it/s]
# Validation DataLoader 0:  70%|████████████▋     | 19/27 [00:03<00:01,  5.92it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 20/27 [00:03<00:01,  5.93it/s]
# Validation DataLoader 0:  78%|██████████████    | 21/27 [00:03<00:01,  5.94it/s]
# Validation DataLoader 0:  81%|██████████████▋   | 22/27 [00:03<00:00,  5.96it/s]
# Validation DataLoader 0:  85%|███████████████▎  | 23/27 [00:03<00:00,  5.98it/s]
# Validation DataLoader 0:  89%|████████████████  | 24/27 [00:04<00:00,  6.00it/s]
# Validation DataLoader 0:  93%|████████████████▋ | 25/27 [00:04<00:00,  6.02it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 26/27 [00:04<00:00,  6.04it/s]
# Epoch 0: 100%|█| 26164/26164 [3:17:34<00:00,  2.21it/s, v_num=3b4n, train/loss=0
# Epoch 0: 100%|█| 26164/26164 [3:17:34<00:00,  2.21it/s, v_num=3b4n, train/loss=0`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 26164/26164 [3:17:47<00:00,  2.20it/s, v_num=3b4n, train/loss=0
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▆▅▂▄▂▆▂▅█▂▅▇▇▃▃▆▃▇▂▅▃▁▆▂▇█▇▁▇▃▇▆▂▄▂▃▆▆▁▂
# wandb:               substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss █▂▁▆▆▁▂▂▁▁▃▄▄▄▁▁▁▁▁▁▂▂▃▁▁▁▁▂▁▁▁▁▃▁▂▂▂▂▁▁
# wandb:   trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 26
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 154
# wandb:               substep 208
# wandb:            train/loss 0.0054
# wandb:   trainer/global_step 817
# wandb: trainer/learning_rate 0.0001
# wandb:       validation/loss 0.221
# wandb:
# wandb: 🚀 View run (8x3090) TokenShift-C - Mem-Finetune-3 (bs=256, train-ctx=1024, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/vn0y3b4n
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230721_175235-vn0y3b4n/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-C-mem-finetune-3/last.ckpt" \
        "../model/TokenShift-C-Tune3.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-C-Tune3.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-C-mem-finetune-3/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 438 params 1515106304 elements
# Saving fp32 state dict to ../model/TokenShift-C-Tune3.pth
# -rw-r--r-- 1 root root 5.7G Jul 21 21:12 ../model/TokenShift-C-Tune3.pth

# %%
# Lets do a memory eval 
#
# We should start approaching the full potential of the model, unless its able to exceed 250 tokens of memory
#
# !python3 ../memory_script/eval_model_memory_guided.py "{PROJECT_DIR}/model/TokenShift-C-Tune3.pth"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 100.0% similarity, with 15 matched token, and 0 token mismatch
# ## Model validation for 20 tokens : 100.0% similarity, with 20 matched token, and 0 token mismatch
# ## Model validation for 25 tokens : 100.0% similarity, with 25 matched token, and 0 token mismatch
# ## Model validation for 30 tokens : 100.0% similarity, with 30 matched token, and 0 token mismatch
# ## Model validation for 35 tokens : 100.0% similarity, with 35 matched token, and 0 token mismatch
# ## Model validation for 40 tokens : 100.0% similarity, with 40 matched token, and 0 token mismatch
# ## Model validation for 45 tokens : 100.0% similarity, with 45 matched token, and 0 token mismatch
# ## Model validation for 50 tokens : 100.0% similarity, with 50 matched token, and 0 token mismatch
# ## Model validation for 55 tokens : 100.0% similarity, with 55 matched token, and 0 token mismatch
# ## Model validation for 60 tokens : 100.0% similarity, with 60 matched token, and 0 token mismatch
# ## Model validation for 65 tokens : 100.0% similarity, with 65 matched token, and 0 token mismatch
# ## Model validation for 70 tokens : 98.57142857142858% similarity, with 69 matched token, and 1 token mismatch
# ## Model validation for 75 tokens : 100.0% similarity, with 75 matched token, and 0 token mismatch
# ## Model validation for 80 tokens : 100.0% similarity, with 80 matched token, and 0 token mismatch
# ## Model validation for 85 tokens : 100.0% similarity, with 85 matched token, and 0 token mismatch
# ## Model validation for 90 tokens : 100.0% similarity, with 90 matched token, and 0 token mismatch
# ## Model validation for 95 tokens : 100.0% similarity, with 95 matched token, and 0 token mismatch
# ## Model validation for 100 tokens : 100.0% similarity, with 100 matched token, and 0 token mismatch
# ## Model validation for 105 tokens : 100.0% similarity, with 105 matched token, and 0 token mismatch
# ## Model validation for 110 tokens : 100.0% similarity, with 110 matched token, and 0 token mismatch
# ## Model validation for 115 tokens : 99.1304347826087% similarity, with 114 matched token, and 1 token mismatch
# ## Model validation for 120 tokens : 99.16666666666667% similarity, with 119 matched token, and 1 token mismatch
# ## Model validation for 125 tokens : 100.0% similarity, with 125 matched token, and 0 token mismatch
# ## Model validation for 130 tokens : 100.0% similarity, with 130 matched token, and 0 token mismatch
# ## Model validation for 135 tokens : 100.0% similarity, with 135 matched token, and 0 token mismatch
# ## Model validation for 140 tokens : 100.0% similarity, with 140 matched token, and 0 token mismatch
# ## Model validation for 145 tokens : 100.0% similarity, with 145 matched token, and 0 token mismatch
# ## Model validation for 150 tokens : 100.0% similarity, with 150 matched token, and 0 token mismatch
# ## Model validation for 160 tokens : 98.75% similarity, with 158 matched token, and 2 token mismatch
# ## Model validation for 170 tokens : 98.82352941176471% similarity, with 168 matched token, and 2 token mismatch
# ## Model validation for 180 tokens : 98.33333333333333% similarity, with 177 matched token, and 3 token mismatch
# ## Model validation for 190 tokens : 97.89473684210527% similarity, with 186 matched token, and 4 token mismatch
# ## Model validation for 200 tokens : 97.0% similarity, with 194 matched token, and 6 token mismatch
# ## Model validation for 210 tokens : 95.71428571428572% similarity, with 201 matched token, and 9 token mismatch
# ## Model validation for 220 tokens : 94.0909090909091% similarity, with 207 matched token, and 13 token mismatch
# ## Model validation for 230 tokens : 94.34782608695652% similarity, with 217 matched token, and 13 token mismatch
# ## Model validation for 240 tokens : 93.75% similarity, with 225 matched token, and 15 token mismatch
# ## Model validation for 250 tokens : 94.39999999999999% similarity, with 236 matched token, and 14 token mismatch
# ## Model validation for 260 tokens : 92.3076923076923% similarity, with 240 matched token, and 20 token mismatch
# ## Model validation for 270 tokens : 91.11111111111111% similarity, with 246 matched token, and 24 token mismatch
# ## Model validation for 280 tokens : 90.35714285714286% similarity, with 253 matched token, and 27 token mismatch
# ## Model validation for 290 tokens : 90.6896551724138% similarity, with 263 matched token, and 27 token mismatch
# ## Model validation for 300 tokens : 88.33333333333333% similarity, with 265 matched token, and 35 token mismatch
# ## Model validation for 325 tokens : 81.84615384615384% similarity, with 266 matched token, and 59 token mismatch
# ## Model validation for 350 tokens : 75.42857142857143% similarity, with 264 matched token, and 86 token mismatch
# ## Model validation for 375 tokens : 70.93333333333334% similarity, with 266 matched token, and 109 token mismatch
# ## Model validation for 400 tokens : 64.5% similarity, with 258 matched token, and 142 token mismatch
# ## Model validation for 425 tokens : 58.58823529411765% similarity, with 249 matched token, and 176 token mismatch
# ## Model validation for 450 tokens : 50.44444444444445% similarity, with 227 matched token, and 223 token mismatch
# ## Model validation for 475 tokens : 42.31578947368421% similarity, with 201 matched token, and 274 token mismatch
# ## Model validation for 500 tokens : 37.0% similarity, with 185 matched token, and 315 token mismatch
# ## Model validation for 525 tokens : 32.57142857142858% similarity, with 171 matched token, and 354 token mismatch
# ## Model validation for 550 tokens : 28.72727272727273% similarity, with 158 matched token, and 392 token mismatch
# ## Model validation for 575 tokens : 24.173913043478258% similarity, with 139 matched token, and 436 token mismatch
# ## Model validation for 600 tokens : 22.0% similarity, with 132 matched token, and 468 token mismatch
# ## Model validation for 625 tokens : 19.2% similarity, with 120 matched token, and 505 token mismatch
# ## Model validation for 650 tokens : 17.53846153846154% similarity, with 114 matched token, and 536 token mismatch
# ## Model validation for 675 tokens : 16.74074074074074% similarity, with 113 matched token, and 562 token mismatch
# ## Model validation for 700 tokens : 15.285714285714286% similarity, with 107 matched token, and 593 token mismatch
# ## Model validation for 750 tokens : 13.866666666666665% similarity, with 104 matched token, and 646 token mismatch
# ## Model validation for 800 tokens : 11.625% similarity, with 93 matched token, and 707 token mismatch
# ## Model validation for 850 tokens : 10.470588235294118% similarity, with 89 matched token, and 761 token mismatch
# ## Model validation for 900 tokens : 9.0% similarity, with 81 matched token, and 819 token mismatch
# ## Model validation for 950 tokens : 7.684210526315789% similarity, with 73 matched token, and 877 token mismatch
# ## Model validation for 1000 tokens : 7.1% similarity, with 71 matched token, and 929 token mismatch

# %% [markdown]
# ## Tune 4 : Ramping up the ctx size (4096), memory training
#
# - Tune 4: Mid ctx size (4096), same as tune 4, but extended in context size
#
# This intentionally a much larger dataset, and lower learning rate to help ensure we push the model to its absolute limits (supposingly)

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# #
# # We reduce the training set for < 50 words - and shift the focus upwards
# # (aka 50-100 token * 2 : ~100 - 250 token ctx len)
# #
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-2-count.jsonl 2 1000 &
# for i in {5..45..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 100 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 1 &
# done
#
# #
# # Ramping up the 50+ - 2000 words dataset
# #
# for i in {50..2000..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 2000 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 20 &
# done
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated a single JSONL file with 107 samples (1 token repeat) - 25 max words - at ./dataset/shuffle-word-25-count.jsonl
# Generated a single JSONL file with 562 samples (1 token repeat) - 5 max words - at ./dataset/shuffle-word-5-count.jsonl
# Generated JSONL file with - 10 max words, 100 samples - at ./dataset/gen-word-10-count.jsonl
# Generated JSONL file with - 30 max words, 100 samples - at ./dataset/gen-word-30-count.jsonl
# Generated JSONL file with - 20 max words, 100 samples - at ./dataset/gen-word-20-count.jsonl
# Generated JSONL file with - 5 max words, 100 samples - at ./dataset/gen-word-5-count.jsonl
# Generated a single JSONL file with 64 samples (1 token repeat) - 40 max words - at ./dataset/shuffle-word-40-count.jsonl
# Generated a single JSONL file with 77 samples (1 token repeat) - 35 max words - at ./dataset/shuffle-word-35-count.jsonl
# Generated JSONL file with - 35 max words, 100 samples - at ./dataset/gen-word-35-count.jsonl
# Generated JSONL file with - 25 max words, 100 samples - at ./dataset/gen-word-25-count.jsonl
# Generated JSONL file with - 45 max words, 100 samples - at ./dataset/gen-word-45-count.jsonl
# Generated JSONL file with - 40 max words, 100 samples - at ./dataset/gen-word-40-count.jsonl
# Generated a single JSONL file with 131 samples (1 token repeat) - 20 max words - at ./dataset/shuffle-word-20-count.jsonl
# Generated a single JSONL file with 174 samples (1 token repeat) - 15 max words - at ./dataset/shuffle-word-15-count.jsonl
# Generated JSONL file with - 2 max words, 1000 samples - at ./dataset/word-2-count.jsonl
# Generated a single JSONL file with 283 samples (20 token repeat) - 170 max words - at ./dataset/shuffle-word-170-count.jsonl
# Generated a single JSONL file with 89 samples (1 token repeat) - 30 max words - at ./dataset/shuffle-word-30-count.jsonl
# Generated JSONL file with - 15 max words, 100 samples - at ./dataset/gen-word-15-count.jsonl
# Generated a single JSONL file with 263 samples (1 token repeat) - 10 max words - at ./dataset/shuffle-word-10-count.jsonl
# Generated a single JSONL file with 357 samples (20 token repeat) - 125 max words - at ./dataset/shuffle-word-125-count.jsonl
# Generated a single JSONL file with 370 samples (20 token repeat) - 120 max words - at ./dataset/shuffle-word-120-count.jsonl
# Generated a single JSONL file with 381 samples (20 token repeat) - 115 max words - at ./dataset/shuffle-word-115-count.jsonl
# Generated a single JSONL file with 565 samples (20 token repeat) - 95 max words - at ./dataset/shuffle-word-95-count.jsonl
# Generated a single JSONL file with 58 samples (1 token repeat) - 45 max words - at ./dataset/shuffle-word-45-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 370 max words - at ./dataset/shuffle-word-370-count.jsonl
# Generated a single JSONL file with 213 samples (20 token repeat) - 210 max words - at ./dataset/shuffle-word-210-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 470 max words - at ./dataset/shuffle-word-470-count.jsonl
# Generated a single JSONL file with 286 samples (20 token repeat) - 165 max words - at ./dataset/shuffle-word-165-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 515 max words - at ./dataset/shuffle-word-515-count.jsonl
# Generated a single JSONL file with 197 samples (20 token repeat) - 235 max words - at ./dataset/shuffle-word-235-count.jsonl
# Generated a single JSONL file with 876 samples (20 token repeat) - 60 max words - at ./dataset/shuffle-word-60-count.jsonl
# Generated a single JSONL file with 659 samples (20 token repeat) - 80 max words - at ./dataset/shuffle-word-80-count.jsonl
# Generated a single JSONL file with 622 samples (20 token repeat) - 85 max words - at ./dataset/shuffle-word-85-count.jsonl
# Generated a single JSONL file with 711 samples (20 token repeat) - 75 max words - at ./dataset/shuffle-word-75-count.jsonl
# Generated a single JSONL file with 811 samples (20 token repeat) - 65 max words - at ./dataset/shuffle-word-65-count.jsonl
# Generated a single JSONL file with 1064 samples (20 token repeat) - 50 max words - at ./dataset/shuffle-word-50-count.jsonl
# Generated a single JSONL file with 195 samples (20 token repeat) - 240 max words - at ./dataset/shuffle-word-240-count.jsonl
# Generated a single JSONL file with 276 samples (20 token repeat) - 180 max words - at ./dataset/shuffle-word-180-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 560 max words - at ./dataset/shuffle-word-560-count.jsonl
# Generated a single JSONL file with 331 samples (20 token repeat) - 135 max words - at ./dataset/shuffle-word-135-count.jsonl
# Generated a single JSONL file with 200 samples (20 token repeat) - 225 max words - at ./dataset/shuffle-word-225-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 565 max words - at ./dataset/shuffle-word-565-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 340 max words - at ./dataset/shuffle-word-340-count.jsonl
# Generated a single JSONL file with 325 samples (20 token repeat) - 140 max words - at ./dataset/shuffle-word-140-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 325 max words - at ./dataset/shuffle-word-325-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 390 max words - at ./dataset/shuffle-word-390-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 445 max words - at ./dataset/shuffle-word-445-count.jsonl
# Generated a single JSONL file with 182 samples (20 token repeat) - 285 max words - at ./dataset/shuffle-word-285-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 345 max words - at ./dataset/shuffle-word-345-count.jsonl
# Generated a single JSONL file with 144 samples (20 token repeat) - 315 max words - at ./dataset/shuffle-word-315-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 510 max words - at ./dataset/shuffle-word-510-count.jsonl
# Generated a single JSONL file with 397 samples (20 token repeat) - 110 max words - at ./dataset/shuffle-word-110-count.jsonl
# Generated a single JSONL file with 960 samples (20 token repeat) - 55 max words - at ./dataset/shuffle-word-55-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 310 max words - at ./dataset/shuffle-word-310-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 590 max words - at ./dataset/shuffle-word-590-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 540 max words - at ./dataset/shuffle-word-540-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 330 max words - at ./dataset/shuffle-word-330-count.jsonl
# Generated a single JSONL file with 349 samples (20 token repeat) - 130 max words - at ./dataset/shuffle-word-130-count.jsonl
# Generated a single JSONL file with 190 samples (20 token repeat) - 245 max words - at ./dataset/shuffle-word-245-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 295 max words - at ./dataset/shuffle-word-295-count.jsonl
# Generated a single JSONL file with 405 samples (20 token repeat) - 105 max words - at ./dataset/shuffle-word-105-count.jsonl
# Generated JSONL file with - 50 max words, 2000 samples - at ./dataset/gen-word-50-count.jsonl
# Generated a single JSONL file with 186 samples (20 token repeat) - 270 max words - at ./dataset/shuffle-word-270-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 275 max words - at ./dataset/shuffle-word-275-count.jsonl
# Generated a single JSONL file with 755 samples (20 token repeat) - 70 max words - at ./dataset/shuffle-word-70-count.jsonl
# Generated JSONL file with - 60 max words, 2000 samples - at ./dataset/gen-word-60-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 400 max words - at ./dataset/shuffle-word-400-count.jsonl
# Generated a single JSONL file with 204 samples (20 token repeat) - 215 max words - at ./dataset/shuffle-word-215-count.jsonl
# Generated a single JSONL file with 533 samples (20 token repeat) - 100 max words - at ./dataset/shuffle-word-100-count.jsonl
# Generated a single JSONL file with 316 samples (20 token repeat) - 145 max words - at ./dataset/shuffle-word-145-count.jsonl
# Generated a single JSONL file with 144 samples (20 token repeat) - 305 max words - at ./dataset/shuffle-word-305-count.jsonl
# Generated a single JSONL file with 217 samples (20 token repeat) - 205 max words - at ./dataset/shuffle-word-205-count.jsonl
# Generated a single JSONL file with 119 samples (20 token repeat) - 435 max words - at ./dataset/shuffle-word-435-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 610 max words - at ./dataset/shuffle-word-610-count.jsonl
# Generated a single JSONL file with 269 samples (20 token repeat) - 195 max words - at ./dataset/shuffle-word-195-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 550 max words - at ./dataset/shuffle-word-550-count.jsonl
# Generated JSONL file with - 115 max words, 2000 samples - at ./dataset/gen-word-115-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 490 max words - at ./dataset/shuffle-word-490-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 395 max words - at ./dataset/shuffle-word-395-count.jsonl
# Generated a single JSONL file with 278 samples (20 token repeat) - 175 max words - at ./dataset/shuffle-word-175-count.jsonl
# Generated a single JSONL file with 119 samples (20 token repeat) - 425 max words - at ./dataset/shuffle-word-425-count.jsonl
# Generated a single JSONL file with 184 samples (20 token repeat) - 260 max words - at ./dataset/shuffle-word-260-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 535 max words - at ./dataset/shuffle-word-535-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 555 max words - at ./dataset/shuffle-word-555-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 525 max words - at ./dataset/shuffle-word-525-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 450 max words - at ./dataset/shuffle-word-450-count.jsonl
# Generated a single JSONL file with 276 samples (20 token repeat) - 185 max words - at ./dataset/shuffle-word-185-count.jsonl
# Generated a single JSONL file with 200 samples (20 token repeat) - 230 max words - at ./dataset/shuffle-word-230-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 365 max words - at ./dataset/shuffle-word-365-count.jsonl
# Generated a single JSONL file with 271 samples (20 token repeat) - 190 max words - at ./dataset/shuffle-word-190-count.jsonl
# Generated a single JSONL file with 99 samples (20 token repeat) - 545 max words - at ./dataset/shuffle-word-545-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 455 max words - at ./dataset/shuffle-word-455-count.jsonl
# Generated a single JSONL file with 184 samples (20 token repeat) - 280 max words - at ./dataset/shuffle-word-280-count.jsonl
# Generated a single JSONL file with 300 samples (20 token repeat) - 155 max words - at ./dataset/shuffle-word-155-count.jsonl
# Generated a single JSONL file with 139 samples (20 token repeat) - 355 max words - at ./dataset/shuffle-word-355-count.jsonl
# Generated a single JSONL file with 183 samples (20 token repeat) - 290 max words - at ./dataset/shuffle-word-290-count.jsonl
# Generated a single JSONL file with 114 samples (20 token repeat) - 495 max words - at ./dataset/shuffle-word-495-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 265 max words - at ./dataset/shuffle-word-265-count.jsonl
# Generated a single JSONL file with 600 samples (20 token repeat) - 90 max words - at ./dataset/shuffle-word-90-count.jsonl
# Generated a single JSONL file with 308 samples (20 token repeat) - 150 max words - at ./dataset/shuffle-word-150-count.jsonl
# Generated a single JSONL file with 183 samples (20 token repeat) - 300 max words - at ./dataset/shuffle-word-300-count.jsonl
# Generated a single JSONL file with 288 samples (20 token repeat) - 160 max words - at ./dataset/shuffle-word-160-count.jsonl
# Generated a single JSONL file with 142 samples (20 token repeat) - 335 max words - at ./dataset/shuffle-word-335-count.jsonl
# Generated a single JSONL file with 99 samples (20 token repeat) - 595 max words - at ./dataset/shuffle-word-595-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 350 max words - at ./dataset/shuffle-word-350-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 465 max words - at ./dataset/shuffle-word-465-count.jsonl
# Generated a single JSONL file with 139 samples (20 token repeat) - 380 max words - at ./dataset/shuffle-word-380-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 530 max words - at ./dataset/shuffle-word-530-count.jsonl
# Generated JSONL file with - 95 max words, 2000 samples - at ./dataset/gen-word-95-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 405 max words - at ./dataset/shuffle-word-405-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 770 max words - at ./dataset/shuffle-word-770-count.jsonl
# Generated JSONL file with - 75 max words, 2000 samples - at ./dataset/gen-word-75-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 600 max words - at ./dataset/shuffle-word-600-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 430 max words - at ./dataset/shuffle-word-430-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 620 max words - at ./dataset/shuffle-word-620-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 360 max words - at ./dataset/shuffle-word-360-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 375 max words - at ./dataset/shuffle-word-375-count.jsonl
# Generated a single JSONL file with 201 samples (20 token repeat) - 220 max words - at ./dataset/shuffle-word-220-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 480 max words - at ./dataset/shuffle-word-480-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 615 max words - at ./dataset/shuffle-word-615-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 575 max words - at ./dataset/shuffle-word-575-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 655 max words - at ./dataset/shuffle-word-655-count.jsonl
# Generated a single JSONL file with 119 samples (20 token repeat) - 485 max words - at ./dataset/shuffle-word-485-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 520 max words - at ./dataset/shuffle-word-520-count.jsonl
# Generated JSONL file with - 55 max words, 2000 samples - at ./dataset/gen-word-55-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 385 max words - at ./dataset/shuffle-word-385-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 475 max words - at ./dataset/shuffle-word-475-count.jsonl
# Generated a single JSONL file with 186 samples (20 token repeat) - 250 max words - at ./dataset/shuffle-word-250-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 410 max words - at ./dataset/shuffle-word-410-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 440 max words - at ./dataset/shuffle-word-440-count.jsonl
# Generated a single JSONL file with 270 samples (20 token repeat) - 200 max words - at ./dataset/shuffle-word-200-count.jsonl
# Generated a single JSONL file with 66 samples (20 token repeat) - 820 max words - at ./dataset/shuffle-word-820-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 570 max words - at ./dataset/shuffle-word-570-count.jsonl
# Generated a single JSONL file with 119 samples (20 token repeat) - 415 max words - at ./dataset/shuffle-word-415-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 460 max words - at ./dataset/shuffle-word-460-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 625 max words - at ./dataset/shuffle-word-625-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 920 max words - at ./dataset/shuffle-word-920-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 840 max words - at ./dataset/shuffle-word-840-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 580 max words - at ./dataset/shuffle-word-580-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 630 max words - at ./dataset/shuffle-word-630-count.jsonl
# Generated a single JSONL file with 99 samples (20 token repeat) - 585 max words - at ./dataset/shuffle-word-585-count.jsonl
# Generated JSONL file with - 65 max words, 2000 samples - at ./dataset/gen-word-65-count.jsonl
# Generated a single JSONL file with 82 samples (20 token repeat) - 660 max words - at ./dataset/shuffle-word-660-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 745 max words - at ./dataset/shuffle-word-745-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 255 max words - at ./dataset/shuffle-word-255-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 500 max words - at ./dataset/shuffle-word-500-count.jsonl
# Generated a single JSONL file with 79 samples (20 token repeat) - 735 max words - at ./dataset/shuffle-word-735-count.jsonl
# Generated JSONL file with - 70 max words, 2000 samples - at ./dataset/gen-word-70-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 975 max words - at ./dataset/shuffle-word-975-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 605 max words - at ./dataset/shuffle-word-605-count.jsonl
# Generated JSONL file with - 85 max words, 2000 samples - at ./dataset/gen-word-85-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 505 max words - at ./dataset/shuffle-word-505-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 765 max words - at ./dataset/shuffle-word-765-count.jsonl
# Generated a single JSONL file with 47 samples (20 token repeat) - 1230 max words - at ./dataset/shuffle-word-1230-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 875 max words - at ./dataset/shuffle-word-875-count.jsonl
# Generated JSONL file with - 80 max words, 2000 samples - at ./dataset/gen-word-80-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 905 max words - at ./dataset/shuffle-word-905-count.jsonl
# Generated a single JSONL file with 78 samples (20 token repeat) - 790 max words - at ./dataset/shuffle-word-790-count.jsonl
# Generated a single JSONL file with 61 samples (20 token repeat) - 860 max words - at ./dataset/shuffle-word-860-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 910 max words - at ./dataset/shuffle-word-910-count.jsonl
# Generated a single JSONL file with 65 samples (20 token repeat) - 870 max words - at ./dataset/shuffle-word-870-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 635 max words - at ./dataset/shuffle-word-635-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 320 max words - at ./dataset/shuffle-word-320-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 985 max words - at ./dataset/shuffle-word-985-count.jsonl
# Generated a single JSONL file with 79 samples (20 token repeat) - 725 max words - at ./dataset/shuffle-word-725-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 710 max words - at ./dataset/shuffle-word-710-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 675 max words - at ./dataset/shuffle-word-675-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 930 max words - at ./dataset/shuffle-word-930-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1000 max words - at ./dataset/shuffle-word-1000-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 420 max words - at ./dataset/shuffle-word-420-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 645 max words - at ./dataset/shuffle-word-645-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1065 max words - at ./dataset/shuffle-word-1065-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 850 max words - at ./dataset/shuffle-word-850-count.jsonl
# Generated JSONL file with - 120 max words, 2000 samples - at ./dataset/gen-word-120-count.jsonl
# Generated a single JSONL file with 58 samples (20 token repeat) - 1140 max words - at ./dataset/shuffle-word-1140-count.jsonl
# Generated a single JSONL file with 67 samples (20 token repeat) - 805 max words - at ./dataset/shuffle-word-805-count.jsonl
# Generated a single JSONL file with 64 samples (20 token repeat) - 900 max words - at ./dataset/shuffle-word-900-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 665 max words - at ./dataset/shuffle-word-665-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 885 max words - at ./dataset/shuffle-word-885-count.jsonl
# Generated a single JSONL file with 78 samples (20 token repeat) - 760 max words - at ./dataset/shuffle-word-760-count.jsonl
# Generated a single JSONL file with 48 samples (20 token repeat) - 1210 max words - at ./dataset/shuffle-word-1210-count.jsonl
# Generated JSONL file with - 170 max words, 2000 samples - at ./dataset/gen-word-170-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 895 max words - at ./dataset/shuffle-word-895-count.jsonl
# Generated a single JSONL file with 51 samples (20 token repeat) - 1220 max words - at ./dataset/shuffle-word-1220-count.jsonl
# Generated JSONL file with - 145 max words, 2000 samples - at ./dataset/gen-word-145-count.jsonl
# Generated a single JSONL file with 65 samples (20 token repeat) - 825 max words - at ./dataset/shuffle-word-825-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1060 max words - at ./dataset/shuffle-word-1060-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 845 max words - at ./dataset/shuffle-word-845-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 690 max words - at ./dataset/shuffle-word-690-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 680 max words - at ./dataset/shuffle-word-680-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 730 max words - at ./dataset/shuffle-word-730-count.jsonl
# Generated a single JSONL file with 82 samples (20 token repeat) - 695 max words - at ./dataset/shuffle-word-695-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 740 max words - at ./dataset/shuffle-word-740-count.jsonl
# Generated a single JSONL file with 79 samples (20 token repeat) - 715 max words - at ./dataset/shuffle-word-715-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 980 max words - at ./dataset/shuffle-word-980-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1015 max words - at ./dataset/shuffle-word-1015-count.jsonl
# Generated JSONL file with - 90 max words, 2000 samples - at ./dataset/gen-word-90-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1120 max words - at ./dataset/shuffle-word-1120-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 935 max words - at ./dataset/shuffle-word-935-count.jsonl
# Generated a single JSONL file with 64 samples (20 token repeat) - 880 max words - at ./dataset/shuffle-word-880-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1160 max words - at ./dataset/shuffle-word-1160-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 705 max words - at ./dataset/shuffle-word-705-count.jsonl
# Generated JSONL file with - 105 max words, 2000 samples - at ./dataset/gen-word-105-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 780 max words - at ./dataset/shuffle-word-780-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1115 max words - at ./dataset/shuffle-word-1115-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1105 max words - at ./dataset/shuffle-word-1105-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1050 max words - at ./dataset/shuffle-word-1050-count.jsonl
# Generated a single JSONL file with 61 samples (20 token repeat) - 830 max words - at ./dataset/shuffle-word-830-count.jsonl
# Generated a single JSONL file with 83 samples (20 token repeat) - 670 max words - at ./dataset/shuffle-word-670-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 720 max words - at ./dataset/shuffle-word-720-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 755 max words - at ./dataset/shuffle-word-755-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 750 max words - at ./dataset/shuffle-word-750-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 685 max words - at ./dataset/shuffle-word-685-count.jsonl
# Generated a single JSONL file with 62 samples (20 token repeat) - 855 max words - at ./dataset/shuffle-word-855-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1170 max words - at ./dataset/shuffle-word-1170-count.jsonl
# Generated a single JSONL file with 82 samples (20 token repeat) - 640 max words - at ./dataset/shuffle-word-640-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 700 max words - at ./dataset/shuffle-word-700-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 650 max words - at ./dataset/shuffle-word-650-count.jsonl
# Generated a single JSONL file with 53 samples (20 token repeat) - 1300 max words - at ./dataset/shuffle-word-1300-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1055 max words - at ./dataset/shuffle-word-1055-count.jsonl
# Generated JSONL file with - 100 max words, 2000 samples - at ./dataset/gen-word-100-count.jsonl
# Generated a single JSONL file with 61 samples (20 token repeat) - 835 max words - at ./dataset/shuffle-word-835-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1040 max words - at ./dataset/shuffle-word-1040-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 810 max words - at ./dataset/shuffle-word-810-count.jsonl
# Generated a single JSONL file with 62 samples (20 token repeat) - 815 max words - at ./dataset/shuffle-word-815-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1185 max words - at ./dataset/shuffle-word-1185-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 775 max words - at ./dataset/shuffle-word-775-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 925 max words - at ./dataset/shuffle-word-925-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1035 max words - at ./dataset/shuffle-word-1035-count.jsonl
# Generated JSONL file with - 130 max words, 2000 samples - at ./dataset/gen-word-130-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1125 max words - at ./dataset/shuffle-word-1125-count.jsonl
# Generated a single JSONL file with 64 samples (20 token repeat) - 865 max words - at ./dataset/shuffle-word-865-count.jsonl
# Generated JSONL file with - 110 max words, 2000 samples - at ./dataset/gen-word-110-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1180 max words - at ./dataset/shuffle-word-1180-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1315 max words - at ./dataset/shuffle-word-1315-count.jsonl
# Generated a single JSONL file with 53 samples (20 token repeat) - 1205 max words - at ./dataset/shuffle-word-1205-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 800 max words - at ./dataset/shuffle-word-800-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1310 max words - at ./dataset/shuffle-word-1310-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 990 max words - at ./dataset/shuffle-word-990-count.jsonl
# Generated JSONL file with - 345 max words, 2000 samples - at ./dataset/gen-word-345-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 945 max words - at ./dataset/shuffle-word-945-count.jsonl
# Generated JSONL file with - 275 max words, 2000 samples - at ./dataset/gen-word-275-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1085 max words - at ./dataset/shuffle-word-1085-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 795 max words - at ./dataset/shuffle-word-795-count.jsonl
# Generated JSONL file with - 235 max words, 2000 samples - at ./dataset/gen-word-235-count.jsonl
# Generated a single JSONL file with 79 samples (20 token repeat) - 785 max words - at ./dataset/shuffle-word-785-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 940 max words - at ./dataset/shuffle-word-940-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1200 max words - at ./dataset/shuffle-word-1200-count.jsonl
# Generated JSONL file with - 165 max words, 2000 samples - at ./dataset/gen-word-165-count.jsonl
# Generated JSONL file with - 265 max words, 2000 samples - at ./dataset/gen-word-265-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1005 max words - at ./dataset/shuffle-word-1005-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1175 max words - at ./dataset/shuffle-word-1175-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1070 max words - at ./dataset/shuffle-word-1070-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 915 max words - at ./dataset/shuffle-word-915-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1415 max words - at ./dataset/shuffle-word-1415-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1130 max words - at ./dataset/shuffle-word-1130-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1640 max words - at ./dataset/shuffle-word-1640-count.jsonl
# Generated a single JSONL file with 51 samples (20 token repeat) - 1215 max words - at ./dataset/shuffle-word-1215-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1030 max words - at ./dataset/shuffle-word-1030-count.jsonl
# Generated a single JSONL file with 42 samples (20 token repeat) - 1330 max words - at ./dataset/shuffle-word-1330-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1025 max words - at ./dataset/shuffle-word-1025-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 965 max words - at ./dataset/shuffle-word-965-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1095 max words - at ./dataset/shuffle-word-1095-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1080 max words - at ./dataset/shuffle-word-1080-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1090 max words - at ./dataset/shuffle-word-1090-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1020 max words - at ./dataset/shuffle-word-1020-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1155 max words - at ./dataset/shuffle-word-1155-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1370 max words - at ./dataset/shuffle-word-1370-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1100 max words - at ./dataset/shuffle-word-1100-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 955 max words - at ./dataset/shuffle-word-955-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1985 max words - at ./dataset/shuffle-word-1985-count.jsonl
# Generated a single JSONL file with 54 samples (20 token repeat) - 1290 max words - at ./dataset/shuffle-word-1290-count.jsonl
# Generated JSONL file with - 195 max words, 2000 samples - at ./dataset/gen-word-195-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 970 max words - at ./dataset/shuffle-word-970-count.jsonl
# Generated a single JSONL file with 51 samples (20 token repeat) - 1245 max words - at ./dataset/shuffle-word-1245-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1340 max words - at ./dataset/shuffle-word-1340-count.jsonl
# Generated a single JSONL file with 65 samples (20 token repeat) - 890 max words - at ./dataset/shuffle-word-890-count.jsonl
# Generated JSONL file with - 200 max words, 2000 samples - at ./dataset/gen-word-200-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1195 max words - at ./dataset/shuffle-word-1195-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 950 max words - at ./dataset/shuffle-word-950-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1455 max words - at ./dataset/shuffle-word-1455-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1550 max words - at ./dataset/shuffle-word-1550-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1010 max words - at ./dataset/shuffle-word-1010-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1430 max words - at ./dataset/shuffle-word-1430-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1335 max words - at ./dataset/shuffle-word-1335-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1525 max words - at ./dataset/shuffle-word-1525-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1485 max words - at ./dataset/shuffle-word-1485-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1410 max words - at ./dataset/shuffle-word-1410-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1745 max words - at ./dataset/shuffle-word-1745-count.jsonl
# Generated a single JSONL file with 51 samples (20 token repeat) - 1295 max words - at ./dataset/shuffle-word-1295-count.jsonl
# Generated JSONL file with - 125 max words, 2000 samples - at ./dataset/gen-word-125-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1760 max words - at ./dataset/shuffle-word-1760-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 995 max words - at ./dataset/shuffle-word-995-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1435 max words - at ./dataset/shuffle-word-1435-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1045 max words - at ./dataset/shuffle-word-1045-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1075 max words - at ./dataset/shuffle-word-1075-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1110 max words - at ./dataset/shuffle-word-1110-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1535 max words - at ./dataset/shuffle-word-1535-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 960 max words - at ./dataset/shuffle-word-960-count.jsonl
# Generated JSONL file with - 185 max words, 2000 samples - at ./dataset/gen-word-185-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1680 max words - at ./dataset/shuffle-word-1680-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1150 max words - at ./dataset/shuffle-word-1150-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1145 max words - at ./dataset/shuffle-word-1145-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1865 max words - at ./dataset/shuffle-word-1865-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1860 max words - at ./dataset/shuffle-word-1860-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1595 max words - at ./dataset/shuffle-word-1595-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1785 max words - at ./dataset/shuffle-word-1785-count.jsonl
# Generated JSONL file with - 245 max words, 2000 samples - at ./dataset/gen-word-245-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1390 max words - at ./dataset/shuffle-word-1390-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1385 max words - at ./dataset/shuffle-word-1385-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1530 max words - at ./dataset/shuffle-word-1530-count.jsonl
# Generated JSONL file with - 140 max words, 2000 samples - at ./dataset/gen-word-140-count.jsonl
# Generated JSONL file with - 410 max words, 2000 samples - at ./dataset/gen-word-410-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1710 max words - at ./dataset/shuffle-word-1710-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1635 max words - at ./dataset/shuffle-word-1635-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1730 max words - at ./dataset/shuffle-word-1730-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1400 max words - at ./dataset/shuffle-word-1400-count.jsonl
# Generated JSONL file with - 205 max words, 2000 samples - at ./dataset/gen-word-205-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1465 max words - at ./dataset/shuffle-word-1465-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1450 max words - at ./dataset/shuffle-word-1450-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1445 max words - at ./dataset/shuffle-word-1445-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1715 max words - at ./dataset/shuffle-word-1715-count.jsonl
# Generated a single JSONL file with 42 samples (20 token repeat) - 1360 max words - at ./dataset/shuffle-word-1360-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1565 max words - at ./dataset/shuffle-word-1565-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1790 max words - at ./dataset/shuffle-word-1790-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1650 max words - at ./dataset/shuffle-word-1650-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1810 max words - at ./dataset/shuffle-word-1810-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1990 max words - at ./dataset/shuffle-word-1990-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1480 max words - at ./dataset/shuffle-word-1480-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1855 max words - at ./dataset/shuffle-word-1855-count.jsonl
# Generated JSONL file with - 435 max words, 2000 samples - at ./dataset/gen-word-435-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1440 max words - at ./dataset/shuffle-word-1440-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1780 max words - at ./dataset/shuffle-word-1780-count.jsonl
# Generated a single JSONL file with 52 samples (20 token repeat) - 1285 max words - at ./dataset/shuffle-word-1285-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1305 max words - at ./dataset/shuffle-word-1305-count.jsonl
# Generated a single JSONL file with 54 samples (20 token repeat) - 1255 max words - at ./dataset/shuffle-word-1255-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1420 max words - at ./dataset/shuffle-word-1420-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1425 max words - at ./dataset/shuffle-word-1425-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1460 max words - at ./dataset/shuffle-word-1460-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1190 max words - at ./dataset/shuffle-word-1190-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1755 max words - at ./dataset/shuffle-word-1755-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1520 max words - at ./dataset/shuffle-word-1520-count.jsonl
# Generated a single JSONL file with 52 samples (20 token repeat) - 1270 max words - at ./dataset/shuffle-word-1270-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1560 max words - at ./dataset/shuffle-word-1560-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1395 max words - at ./dataset/shuffle-word-1395-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1825 max words - at ./dataset/shuffle-word-1825-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1955 max words - at ./dataset/shuffle-word-1955-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1490 max words - at ./dataset/shuffle-word-1490-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1625 max words - at ./dataset/shuffle-word-1625-count.jsonl
# Generated a single JSONL file with 42 samples (20 token repeat) - 1345 max words - at ./dataset/shuffle-word-1345-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1950 max words - at ./dataset/shuffle-word-1950-count.jsonl
# Generated JSONL file with - 135 max words, 2000 samples - at ./dataset/gen-word-135-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1885 max words - at ./dataset/shuffle-word-1885-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1815 max words - at ./dataset/shuffle-word-1815-count.jsonl
# Generated a single JSONL file with 50 samples (20 token repeat) - 1240 max words - at ./dataset/shuffle-word-1240-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1805 max words - at ./dataset/shuffle-word-1805-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1685 max words - at ./dataset/shuffle-word-1685-count.jsonl
# Generated a single JSONL file with 51 samples (20 token repeat) - 1225 max words - at ./dataset/shuffle-word-1225-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1845 max words - at ./dataset/shuffle-word-1845-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1475 max words - at ./dataset/shuffle-word-1475-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1670 max words - at ./dataset/shuffle-word-1670-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1405 max words - at ./dataset/shuffle-word-1405-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1630 max words - at ./dataset/shuffle-word-1630-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1895 max words - at ./dataset/shuffle-word-1895-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1980 max words - at ./dataset/shuffle-word-1980-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1720 max words - at ./dataset/shuffle-word-1720-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1890 max words - at ./dataset/shuffle-word-1890-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1605 max words - at ./dataset/shuffle-word-1605-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1920 max words - at ./dataset/shuffle-word-1920-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1600 max words - at ./dataset/shuffle-word-1600-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1320 max words - at ./dataset/shuffle-word-1320-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1900 max words - at ./dataset/shuffle-word-1900-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1495 max words - at ./dataset/shuffle-word-1495-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1700 max words - at ./dataset/shuffle-word-1700-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1375 max words - at ./dataset/shuffle-word-1375-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1575 max words - at ./dataset/shuffle-word-1575-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1695 max words - at ./dataset/shuffle-word-1695-count.jsonl
# Generated JSONL file with - 175 max words, 2000 samples - at ./dataset/gen-word-175-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1820 max words - at ./dataset/shuffle-word-1820-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1515 max words - at ./dataset/shuffle-word-1515-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1765 max words - at ./dataset/shuffle-word-1765-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1690 max words - at ./dataset/shuffle-word-1690-count.jsonl
# Generated a single JSONL file with 53 samples (20 token repeat) - 1275 max words - at ./dataset/shuffle-word-1275-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1965 max words - at ./dataset/shuffle-word-1965-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1935 max words - at ./dataset/shuffle-word-1935-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1505 max words - at ./dataset/shuffle-word-1505-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1770 max words - at ./dataset/shuffle-word-1770-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1615 max words - at ./dataset/shuffle-word-1615-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1945 max words - at ./dataset/shuffle-word-1945-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1655 max words - at ./dataset/shuffle-word-1655-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1930 max words - at ./dataset/shuffle-word-1930-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1870 max words - at ./dataset/shuffle-word-1870-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1620 max words - at ./dataset/shuffle-word-1620-count.jsonl
# Generated a single JSONL file with 47 samples (20 token repeat) - 1235 max words - at ./dataset/shuffle-word-1235-count.jsonl
# ...
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-1775-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-1780-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-1785-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 22 01:42 shuffle-word-1790-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 22 01:42 shuffle-word-1795-count.jsonl
# -rw-r--r-- 1 root root 542K Jul 22 01:42 shuffle-word-180-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1800-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1805-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 22 01:42 shuffle-word-1810-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 22 01:42 shuffle-word-1815-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 22 01:42 shuffle-word-1820-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1825-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1830-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1835-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1840-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-1845-count.jsonl
# -rw-r--r-- 1 root root 546K Jul 22 01:42 shuffle-word-185-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-1850-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-1855-count.jsonl
# -rw-r--r-- 1 root root 517K Jul 22 01:42 shuffle-word-1860-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 22 01:42 shuffle-word-1865-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-1870-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-1875-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-1880-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1885-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 22 01:42 shuffle-word-1890-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-1895-count.jsonl
# -rw-r--r-- 1 root root 543K Jul 22 01:42 shuffle-word-190-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 22 01:42 shuffle-word-1900-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-1905-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-1910-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-1915-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1920-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-1925-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-1930-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 22 01:42 shuffle-word-1935-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 22 01:42 shuffle-word-1940-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-1945-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 22 01:42 shuffle-word-195-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 22 01:42 shuffle-word-1950-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1955-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 22 01:42 shuffle-word-1960-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-1965-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-1970-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 22 01:42 shuffle-word-1975-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1980-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-1985-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 22 01:42 shuffle-word-1990-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-1995-count.jsonl
# -rw-r--r-- 1 root root  38K Jul 22 01:42 shuffle-word-20-count.jsonl
# -rw-r--r-- 1 root root 542K Jul 22 01:42 shuffle-word-200-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-2000-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 22 01:42 shuffle-word-205-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 22 01:42 shuffle-word-210-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 22 01:42 shuffle-word-215-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 22 01:42 shuffle-word-220-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 22 01:42 shuffle-word-225-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 22 01:42 shuffle-word-230-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 22 01:42 shuffle-word-235-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 22 01:42 shuffle-word-240-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 22 01:42 shuffle-word-245-count.jsonl
# -rw-r--r-- 1 root root  38K Jul 22 01:42 shuffle-word-25-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-250-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 22 01:42 shuffle-word-255-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 22 01:42 shuffle-word-260-count.jsonl
# -rw-r--r-- 1 root root 540K Jul 22 01:42 shuffle-word-265-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 22 01:42 shuffle-word-270-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 22 01:42 shuffle-word-275-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 22 01:42 shuffle-word-280-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 22 01:42 shuffle-word-285-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-290-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 22 01:42 shuffle-word-295-count.jsonl
# -rw-r--r-- 1 root root  36K Jul 22 01:42 shuffle-word-30-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 22 01:42 shuffle-word-300-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-305-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-310-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 22 01:42 shuffle-word-315-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-320-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-325-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-330-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-335-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-340-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-345-count.jsonl
# -rw-r--r-- 1 root root  35K Jul 22 01:42 shuffle-word-35-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 22 01:42 shuffle-word-350-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-355-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 22 01:42 shuffle-word-360-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-365-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-370-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-375-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-380-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-385-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-390-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-395-count.jsonl
# -rw-r--r-- 1 root root  32K Jul 22 01:42 shuffle-word-40-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-400-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-405-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-410-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-415-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 22 01:42 shuffle-word-420-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-425-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-430-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-435-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 22 01:42 shuffle-word-440-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-445-count.jsonl
# -rw-r--r-- 1 root root  30K Jul 22 01:42 shuffle-word-45-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-450-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 22 01:42 shuffle-word-455-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-460-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-465-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-470-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-475-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-480-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 22 01:42 shuffle-word-485-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-490-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-495-count.jsonl
# -rw-r--r-- 1 root root  79K Jul 22 01:42 shuffle-word-5-count.jsonl
# -rw-r--r-- 1 root root 618K Jul 22 01:42 shuffle-word-50-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-500-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-505-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-510-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-515-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-520-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-525-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-530-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-535-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-540-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-545-count.jsonl
# -rw-r--r-- 1 root root 604K Jul 22 01:42 shuffle-word-55-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-550-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 22 01:42 shuffle-word-555-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-560-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-565-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-570-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-575-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-580-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-585-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-590-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 22 01:42 shuffle-word-595-count.jsonl
# -rw-r--r-- 1 root root 603K Jul 22 01:42 shuffle-word-60-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 22 01:42 shuffle-word-600-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-605-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-610-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-615-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-620-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-625-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-630-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-635-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-640-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-645-count.jsonl
# -rw-r--r-- 1 root root 594K Jul 22 01:42 shuffle-word-65-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-650-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-655-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-660-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-665-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-670-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-675-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-680-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-685-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-690-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 22 01:42 shuffle-word-695-count.jsonl
# -rw-r--r-- 1 root root 588K Jul 22 01:42 shuffle-word-70-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-700-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-705-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-710-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-715-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-720-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-725-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-730-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-735-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-740-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-745-count.jsonl
# -rw-r--r-- 1 root root 580K Jul 22 01:42 shuffle-word-75-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-750-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 22 01:42 shuffle-word-755-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-760-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-765-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-770-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-775-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-780-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-785-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-790-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-795-count.jsonl
# -rw-r--r-- 1 root root 575K Jul 22 01:42 shuffle-word-80-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-800-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-805-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-810-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-815-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-820-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-825-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-830-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-835-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-840-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-845-count.jsonl
# -rw-r--r-- 1 root root 568K Jul 22 01:42 shuffle-word-85-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-850-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-855-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-860-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-865-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-870-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-875-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-880-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-885-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-890-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-895-count.jsonl
# -rw-r--r-- 1 root root 571K Jul 22 01:42 shuffle-word-90-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-900-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-905-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-910-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-915-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-920-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-925-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-930-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-935-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-940-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-945-count.jsonl
# -rw-r--r-- 1 root root 568K Jul 22 01:42 shuffle-word-95-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 22 01:42 shuffle-word-950-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-955-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-960-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 22 01:42 shuffle-word-965-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-970-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-975-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 22 01:42 shuffle-word-980-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 22 01:42 shuffle-word-985-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 22 01:42 shuffle-word-990-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 22 01:42 shuffle-word-995-count.jsonl
# -rw-r--r-- 1 root root 121K Jul 22 01:42 word-2-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-4.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-C-mem-finetune-4/"
# Out:
# Resolving data files: 100%|███████████████| 801/801 [00:00<00:00, 149743.16it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-a0397e82a786e7cd/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|████████████████████| 1/1 [00:00<00:00, 160.69it/s]
# Extracting data files: 100%|██████████████████████| 1/1 [00:00<00:00,  5.98it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-a0397e82a786e7cd/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 36.63it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-4.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-4 (bs=256, train-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=4096
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 648556424
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 648556424
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230722_014605-1q3iyzf8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run (8x3090) TokenShift-C - Mem-Finetune-4 (bs=256, train-ctx=4096, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/1q3iyzf8
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16/build.ninja...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_4096_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Resolving data files: 100%|███████████████| 801/801 [00:00<00:00, 192916.31it/s]
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-a0397e82a786e7cd/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 37.81it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-a0397e82a786e7cd/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-757c7256fcf9e562_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-a0397e82a786e7cd/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-3c93fda6ba3567b2_*_of_00064.arrow
# Saving the dataset (0/16 shards):   5%| | 39000/824813 [00:00<00:11, 69815.80 exSetting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Saving the dataset (1/16 shards):   6%| | 51551/824813 [00:00<00:10, 74239.85 ex[RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Saving the dataset (1/16 shards):   7%| | 60551/824813 [00:01<00:14, 51092.01 ex[RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Saving the dataset (1/16 shards):  12%| | 100551/824813 [00:01<00:09, 77812.99 e[rank: 1] Global seed set to 648556424
# Saving the dataset (2/16 shards):  13%|▏| 103102/824813 [00:01<00:09, 77812.99 e[rank: 4] Global seed set to 648556424
# [rank: 3] Global seed set to 648556424
# [rank: 7] Global seed set to 648556424
# [rank: 6] Global seed set to 648556424
# [rank: 2] Global seed set to 648556424
# [rank: 5] Global seed set to 648556424
# Saving the dataset (2/16 shards):  17%|▏| 143102/824813 [00:02<00:08, 77698.91 eUsing /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16/build.ninja...
# Saving the dataset (2/16 shards):  19%|▏| 153102/824813 [00:02<00:08, 81472.12 eUsing /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# ninja: no work to do.
# Saving the dataset (3/16 shards):  19%|▏| 154653/824813 [00:02<00:08, 81472.12 eLoading extension module wkv_4096_bf16...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16/build.ninja...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_4096_bf16...
# Saving the dataset (3/16 shards):  20%|▏| 164653/824813 [00:02<00:09, 72887.16 eLoading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# [rank: 0] Global seed set to 648556424
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-22 01:46:30,095] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 648556424
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-22 01:46:34,324] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 648556424
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-22 01:46:34,404] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 3] Global seed set to 648556424
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-22 01:46:36,982] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 648556424
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-22 01:46:38,005] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 6] Global seed set to 648556424
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-22 01:46:38,030] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 648556424
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-07-22 01:46:38,057] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 648556424
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-22 01:46:38,062] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  4.000e-04 (0.0004)
#     - lr_final: 1.000e-04 (0.0001)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06854677200317383 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1015481948852539 seconds
# Time to load fused_adam op: 0.10152268409729004 seconds
# Time to load fused_adam op: 0.10152363777160645 seconds
# Time to load fused_adam op: 0.10144758224487305 seconds
# Time to load fused_adam op: 0.10136914253234863 seconds
# Time to load fused_adam op: 0.10137081146240234 seconds
# Time to load fused_adam op: 0.10185408592224121 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.06821846961975098 seconds
# Loading extension module utils...
# Time to load utils op: 0.1018056869506836 seconds
# Loading extension module utils...
# Time to load utils op: 0.10176658630371094 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10188150405883789 seconds
# Time to load utils op: 0.10211563110351562 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10140109062194824 seconds
# Time to load utils op: 0.10185694694519043 seconds
# Loading extension module utils...
# Time to load utils op: 0.10188055038452148 seconds
# Rank: 0 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 7 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 1 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 4 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 3 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00026535987854003906 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002682209014892578 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002646446228027344 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Time to load utils op: 0.0002758502960205078 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00026702880859375 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00034236907958984375 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003495216369628906 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0004949569702148438 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0:   1%| | 800/103102 [09:36<20:27:52,  1.39it/s, v_num=yzf8, train/loss=6/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 103102/103102 [20:54:51<00:00,  1.37it/s, v_num=yzf8, train/los
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                       | 0/104 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/104 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/104 [00:00<00:22,  4.55it/s]
# Validation DataLoader 0:   2%|▎                 | 2/104 [00:00<00:22,  4.48it/s]
# Validation DataLoader 0:   3%|▌                 | 3/104 [00:00<00:22,  4.59it/s]
# Validation DataLoader 0:   4%|▋                 | 4/104 [00:00<00:20,  4.81it/s]
# Validation DataLoader 0:   5%|▊                 | 5/104 [00:01<00:19,  4.99it/s]
# Validation DataLoader 0:   6%|█                 | 6/104 [00:01<00:19,  5.13it/s]
# Validation DataLoader 0:   7%|█▏                | 7/104 [00:01<00:18,  5.23it/s]
# Validation DataLoader 0:   8%|█▍                | 8/104 [00:01<00:18,  5.32it/s]
# Validation DataLoader 0:   9%|█▌                | 9/104 [00:01<00:17,  5.40it/s]
# Validation DataLoader 0:  10%|█▋               | 10/104 [00:01<00:17,  5.45it/s]
# Validation DataLoader 0:  11%|█▊               | 11/104 [00:02<00:16,  5.50it/s]
# Validation DataLoader 0:  12%|█▉               | 12/104 [00:02<00:16,  5.53it/s]
# Validation DataLoader 0:  12%|██▏              | 13/104 [00:02<00:16,  5.57it/s]
# Validation DataLoader 0:  13%|██▎              | 14/104 [00:02<00:16,  5.60it/s]
# Validation DataLoader 0:  14%|██▍              | 15/104 [00:02<00:15,  5.62it/s]
# Validation DataLoader 0:  15%|██▌              | 16/104 [00:02<00:15,  5.64it/s]
# Validation DataLoader 0:  16%|██▊              | 17/104 [00:03<00:15,  5.56it/s]
# Validation DataLoader 0:  17%|██▉              | 18/104 [00:03<00:15,  5.56it/s]
# Validation DataLoader 0:  18%|███              | 19/104 [00:03<00:15,  5.57it/s]
# Validation DataLoader 0:  19%|███▎             | 20/104 [00:03<00:15,  5.58it/s]
# Validation DataLoader 0:  20%|███▍             | 21/104 [00:03<00:14,  5.59it/s]
# Validation DataLoader 0:  21%|███▌             | 22/104 [00:03<00:14,  5.61it/s]
# Validation DataLoader 0:  22%|███▊             | 23/104 [00:04<00:14,  5.59it/s]
# Validation DataLoader 0:  23%|███▉             | 24/104 [00:04<00:14,  5.60it/s]
# Validation DataLoader 0:  24%|████             | 25/104 [00:04<00:14,  5.61it/s]
# Validation DataLoader 0:  25%|████▎            | 26/104 [00:04<00:13,  5.58it/s]
# Validation DataLoader 0:  26%|████▍            | 27/104 [00:04<00:13,  5.60it/s]
# Validation DataLoader 0:  27%|████▌            | 28/104 [00:04<00:13,  5.61it/s]
# Validation DataLoader 0:  28%|████▋            | 29/104 [00:05<00:13,  5.60it/s]
# Validation DataLoader 0:  29%|████▉            | 30/104 [00:05<00:13,  5.61it/s]
# Validation DataLoader 0:  30%|█████            | 31/104 [00:05<00:12,  5.62it/s]
# Validation DataLoader 0:  31%|█████▏           | 32/104 [00:05<00:12,  5.63it/s]
# Validation DataLoader 0:  32%|█████▍           | 33/104 [00:05<00:12,  5.64it/s]
# Validation DataLoader 0:  33%|█████▌           | 34/104 [00:06<00:12,  5.65it/s]
# Validation DataLoader 0:  34%|█████▋           | 35/104 [00:06<00:12,  5.66it/s]
# Validation DataLoader 0:  35%|█████▉           | 36/104 [00:06<00:11,  5.67it/s]
# Validation DataLoader 0:  36%|██████           | 37/104 [00:06<00:11,  5.68it/s]
# Validation DataLoader 0:  37%|██████▏          | 38/104 [00:06<00:11,  5.68it/s]
# Validation DataLoader 0:  38%|██████▍          | 39/104 [00:06<00:11,  5.69it/s]
# Validation DataLoader 0:  38%|██████▌          | 40/104 [00:07<00:11,  5.70it/s]
# Validation DataLoader 0:  39%|██████▋          | 41/104 [00:07<00:11,  5.70it/s]
# Validation DataLoader 0:  40%|██████▊          | 42/104 [00:07<00:10,  5.68it/s]
# Validation DataLoader 0:  41%|███████          | 43/104 [00:07<00:10,  5.69it/s]
# Validation DataLoader 0:  42%|███████▏         | 44/104 [00:07<00:10,  5.70it/s]
# Validation DataLoader 0:  43%|███████▎         | 45/104 [00:07<00:10,  5.69it/s]
# Validation DataLoader 0:  44%|███████▌         | 46/104 [00:08<00:10,  5.70it/s]
# Validation DataLoader 0:  45%|███████▋         | 47/104 [00:08<00:09,  5.71it/s]
# Validation DataLoader 0:  46%|███████▊         | 48/104 [00:08<00:09,  5.69it/s]
# Validation DataLoader 0:  47%|████████         | 49/104 [00:08<00:09,  5.68it/s]
# Validation DataLoader 0:  48%|████████▏        | 50/104 [00:08<00:09,  5.66it/s]
# Validation DataLoader 0:  49%|████████▎        | 51/104 [00:09<00:09,  5.67it/s]
# Validation DataLoader 0:  50%|████████▌        | 52/104 [00:09<00:09,  5.65it/s]
# Validation DataLoader 0:  51%|████████▋        | 53/104 [00:09<00:09,  5.63it/s]
# Validation DataLoader 0:  52%|████████▊        | 54/104 [00:09<00:08,  5.62it/s]
# Validation DataLoader 0:  53%|████████▉        | 55/104 [00:09<00:08,  5.63it/s]
# Validation DataLoader 0:  54%|█████████▏       | 56/104 [00:09<00:08,  5.63it/s]
# Validation DataLoader 0:  55%|█████████▎       | 57/104 [00:10<00:08,  5.64it/s]
# Validation DataLoader 0:  56%|█████████▍       | 58/104 [00:10<00:08,  5.62it/s]
# Validation DataLoader 0:  57%|█████████▋       | 59/104 [00:10<00:07,  5.63it/s]
# Validation DataLoader 0:  58%|█████████▊       | 60/104 [00:10<00:07,  5.64it/s]
# Validation DataLoader 0:  59%|█████████▉       | 61/104 [00:10<00:07,  5.64it/s]
# Validation DataLoader 0:  60%|██████████▏      | 62/104 [00:10<00:07,  5.65it/s]
# Validation DataLoader 0:  61%|██████████▎      | 63/104 [00:11<00:07,  5.65it/s]
# Validation DataLoader 0:  62%|██████████▍      | 64/104 [00:11<00:07,  5.66it/s]
# Validation DataLoader 0:  62%|██████████▋      | 65/104 [00:11<00:06,  5.66it/s]
# Validation DataLoader 0:  63%|██████████▊      | 66/104 [00:11<00:06,  5.66it/s]
# Validation DataLoader 0:  64%|██████████▉      | 67/104 [00:11<00:06,  5.66it/s]
# Validation DataLoader 0:  65%|███████████      | 68/104 [00:12<00:06,  5.67it/s]
# Validation DataLoader 0:  66%|███████████▎     | 69/104 [00:12<00:06,  5.67it/s]
# Validation DataLoader 0:  67%|███████████▍     | 70/104 [00:12<00:05,  5.68it/s]
# Validation DataLoader 0:  68%|███████████▌     | 71/104 [00:12<00:05,  5.68it/s]
# Validation DataLoader 0:  69%|███████████▊     | 72/104 [00:12<00:05,  5.68it/s]
# Validation DataLoader 0:  70%|███████████▉     | 73/104 [00:12<00:05,  5.69it/s]
# Validation DataLoader 0:  71%|████████████     | 74/104 [00:13<00:05,  5.69it/s]
# Validation DataLoader 0:  72%|████████████▎    | 75/104 [00:13<00:05,  5.69it/s]
# Validation DataLoader 0:  73%|████████████▍    | 76/104 [00:13<00:04,  5.69it/s]
# Validation DataLoader 0:  74%|████████████▌    | 77/104 [00:13<00:04,  5.70it/s]
# Validation DataLoader 0:  75%|████████████▊    | 78/104 [00:13<00:04,  5.70it/s]
# Validation DataLoader 0:  76%|████████████▉    | 79/104 [00:13<00:04,  5.70it/s]
# Validation DataLoader 0:  77%|█████████████    | 80/104 [00:14<00:04,  5.71it/s]
# Validation DataLoader 0:  78%|█████████████▏   | 81/104 [00:14<00:04,  5.71it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 82/104 [00:14<00:03,  5.71it/s]
# Validation DataLoader 0:  80%|█████████████▌   | 83/104 [00:14<00:03,  5.72it/s]
# Validation DataLoader 0:  81%|█████████████▋   | 84/104 [00:14<00:03,  5.72it/s]
# Validation DataLoader 0:  82%|█████████████▉   | 85/104 [00:14<00:03,  5.72it/s]
# Validation DataLoader 0:  83%|██████████████   | 86/104 [00:15<00:03,  5.72it/s]
# Validation DataLoader 0:  84%|██████████████▏  | 87/104 [00:15<00:02,  5.72it/s]
# Validation DataLoader 0:  85%|██████████████▍  | 88/104 [00:15<00:02,  5.73it/s]
# Validation DataLoader 0:  86%|██████████████▌  | 89/104 [00:15<00:02,  5.73it/s]
# Validation DataLoader 0:  87%|██████████████▋  | 90/104 [00:15<00:02,  5.73it/s]
# Validation DataLoader 0:  88%|██████████████▉  | 91/104 [00:15<00:02,  5.73it/s]
# Validation DataLoader 0:  88%|███████████████  | 92/104 [00:16<00:02,  5.73it/s]
# Validation DataLoader 0:  89%|███████████████▏ | 93/104 [00:16<00:01,  5.73it/s]
# Validation DataLoader 0:  90%|███████████████▎ | 94/104 [00:16<00:01,  5.74it/s]
# Validation DataLoader 0:  91%|███████████████▌ | 95/104 [00:16<00:01,  5.74it/s]
# Validation DataLoader 0:  92%|███████████████▋ | 96/104 [00:16<00:01,  5.75it/s]
# Validation DataLoader 0:  93%|███████████████▊ | 97/104 [00:16<00:01,  5.75it/s]
# Validation DataLoader 0:  94%|████████████████ | 98/104 [00:17<00:01,  5.76it/s]
# Validation DataLoader 0:  95%|████████████████▏| 99/104 [00:17<00:00,  5.76it/s]
# Validation DataLoader 0:  96%|███████████████▍| 100/104 [00:17<00:00,  5.76it/s]
# Validation DataLoader 0:  97%|███████████████▌| 101/104 [00:17<00:00,  5.76it/s]
# Validation DataLoader 0:  98%|███████████████▋| 102/104 [00:17<00:00,  5.77it/s]
# Validation DataLoader 0:  99%|███████████████▊| 103/104 [00:17<00:00,  5.76it/s]
# Epoch 0: 100%|█| 103102/103102 [20:55:13<00:00,  1.37it/s, v_num=yzf8, train/los
# Epoch 0: 100%|█| 103102/103102 [20:55:13<00:00,  1.37it/s, v_num=yzf8, train/los`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 103102/103102 [20:55:26<00:00,  1.37it/s, v_num=yzf8, train/los
# wandb: Waiting for W&B process to finish... (success).
# wandb: / 0.009 MB of 0.009 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:              batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▅▃▄▃▅▁▄▃▅▇▁▂▂▄█▂▂█▄▄▅▅▅▃▃▁▄▆▇▇▄▁▂▂▆▅▅▂▅▇
# wandb:               substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ▇▃▂█▁▂▁▃▁▇▇▁▅▄▃▇▃▃▇▂▄▂▂▂▁▁▁▃▆▆▁▂▁▁▆▄▂▁▁▁
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 103
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 1909
# wandb:               substep 824
# wandb:            train/loss 0.87109
# wandb:   trainer/global_step 3221
# wandb: trainer/learning_rate 0.0001
# wandb:       validation/loss 1.01469
# wandb:
# wandb: 🚀 View run (8x3090) TokenShift-C - Mem-Finetune-4 (bs=256, train-ctx=4096, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/1q3iyzf8
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230722_014605-1q3iyzf8/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-C-mem-finetune-4/last.ckpt" \
        "../model/TokenShift-C-Tune4.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-C-Tune4.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-C-mem-finetune-4/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 438 params 1515106304 elements
# Saving fp32 state dict to ../model/TokenShift-C-Tune4.pth
# -rw-r--r-- 1 root root 5.7G Jul 22 22:43 ../model/TokenShift-C-Tune4.pth

# %%
# Lets do a memory eval 
# !python3 ../memory_script/eval_model_memory_guided.py "{PROJECT_DIR}/model/TokenShift-C-Tune4.pth"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 100.0% similarity, with 15 matched token, and 0 token mismatch
# ## Model validation for 20 tokens : 100.0% similarity, with 20 matched token, and 0 token mismatch
# ## Model validation for 25 tokens : 100.0% similarity, with 25 matched token, and 0 token mismatch
# ## Model validation for 30 tokens : 100.0% similarity, with 30 matched token, and 0 token mismatch
# ## Model validation for 35 tokens : 100.0% similarity, with 35 matched token, and 0 token mismatch
# ## Model validation for 40 tokens : 100.0% similarity, with 40 matched token, and 0 token mismatch
# ## Model validation for 45 tokens : 100.0% similarity, with 45 matched token, and 0 token mismatch
# ## Model validation for 50 tokens : 100.0% similarity, with 50 matched token, and 0 token mismatch
# ## Model validation for 55 tokens : 100.0% similarity, with 55 matched token, and 0 token mismatch
# ## Model validation for 60 tokens : 100.0% similarity, with 60 matched token, and 0 token mismatch
# ## Model validation for 65 tokens : 100.0% similarity, with 65 matched token, and 0 token mismatch
# ## Model validation for 70 tokens : 100.0% similarity, with 70 matched token, and 0 token mismatch
# ## Model validation for 75 tokens : 100.0% similarity, with 75 matched token, and 0 token mismatch
# ## Model validation for 80 tokens : 100.0% similarity, with 80 matched token, and 0 token mismatch
# ## Model validation for 85 tokens : 100.0% similarity, with 85 matched token, and 0 token mismatch
# ## Model validation for 90 tokens : 100.0% similarity, with 90 matched token, and 0 token mismatch
# ## Model validation for 95 tokens : 100.0% similarity, with 95 matched token, and 0 token mismatch
# ## Model validation for 100 tokens : 100.0% similarity, with 100 matched token, and 0 token mismatch
# ## Model validation for 105 tokens : 100.0% similarity, with 105 matched token, and 0 token mismatch
# ## Model validation for 110 tokens : 100.0% similarity, with 110 matched token, and 0 token mismatch
# ## Model validation for 115 tokens : 100.0% similarity, with 115 matched token, and 0 token mismatch
# ## Model validation for 120 tokens : 100.0% similarity, with 120 matched token, and 0 token mismatch
# ## Model validation for 125 tokens : 100.0% similarity, with 125 matched token, and 0 token mismatch
# ## Model validation for 130 tokens : 100.0% similarity, with 130 matched token, and 0 token mismatch
# ## Model validation for 135 tokens : 100.0% similarity, with 135 matched token, and 0 token mismatch
# ## Model validation for 140 tokens : 100.0% similarity, with 140 matched token, and 0 token mismatch
# ## Model validation for 145 tokens : 100.0% similarity, with 145 matched token, and 0 token mismatch
# ## Model validation for 150 tokens : 100.0% similarity, with 150 matched token, and 0 token mismatch
# ## Model validation for 160 tokens : 100.0% similarity, with 160 matched token, and 0 token mismatch
# ## Model validation for 170 tokens : 100.0% similarity, with 170 matched token, and 0 token mismatch
# ## Model validation for 180 tokens : 100.0% similarity, with 180 matched token, and 0 token mismatch
# ## Model validation for 190 tokens : 99.47368421052632% similarity, with 189 matched token, and 1 token mismatch
# ## Model validation for 200 tokens : 100.0% similarity, with 200 matched token, and 0 token mismatch
# ## Model validation for 210 tokens : 99.52380952380952% similarity, with 209 matched token, and 1 token mismatch
# ## Model validation for 220 tokens : 99.54545454545455% similarity, with 219 matched token, and 1 token mismatch
# ## Model validation for 230 tokens : 99.56521739130434% similarity, with 229 matched token, and 1 token mismatch
# ## Model validation for 240 tokens : 100.0% similarity, with 240 matched token, and 0 token mismatch
# ## Model validation for 250 tokens : 100.0% similarity, with 250 matched token, and 0 token mismatch
# ## Model validation for 260 tokens : 100.0% similarity, with 260 matched token, and 0 token mismatch
# ## Model validation for 270 tokens : 99.62962962962963% similarity, with 269 matched token, and 1 token mismatch
# ## Model validation for 280 tokens : 99.64285714285714% similarity, with 279 matched token, and 1 token mismatch
# ## Model validation for 290 tokens : 99.6551724137931% similarity, with 289 matched token, and 1 token mismatch
# ## Model validation for 300 tokens : 99.66666666666667% similarity, with 299 matched token, and 1 token mismatch
# ## Model validation for 325 tokens : 99.07692307692308% similarity, with 322 matched token, and 3 token mismatch
# ## Model validation for 350 tokens : 98.0% similarity, with 343 matched token, and 7 token mismatch
# ## Model validation for 375 tokens : 98.66666666666667% similarity, with 370 matched token, and 5 token mismatch
# ## Model validation for 400 tokens : 98.25% similarity, with 393 matched token, and 7 token mismatch
# ## Model validation for 425 tokens : 97.6470588235294% similarity, with 415 matched token, and 10 token mismatch
# ## Model validation for 450 tokens : 97.77777777777777% similarity, with 440 matched token, and 10 token mismatch
# ## Model validation for 475 tokens : 96.63157894736842% similarity, with 459 matched token, and 16 token mismatch
# ## Model validation for 500 tokens : 96.6% similarity, with 483 matched token, and 17 token mismatch
# ## Model validation for 525 tokens : 96.38095238095238% similarity, with 506 matched token, and 19 token mismatch
# ## Model validation for 550 tokens : 95.27272727272728% similarity, with 524 matched token, and 26 token mismatch
# ## Model validation for 575 tokens : 94.26086956521739% similarity, with 542 matched token, and 33 token mismatch
# ## Model validation for 600 tokens : 93.33333333333333% similarity, with 560 matched token, and 40 token mismatch
# ## Model validation for 625 tokens : 93.44% similarity, with 584 matched token, and 41 token mismatch
# ## Model validation for 650 tokens : 90.3076923076923% similarity, with 587 matched token, and 63 token mismatch
# ## Model validation for 675 tokens : 88.44444444444444% similarity, with 597 matched token, and 78 token mismatch
# ## Model validation for 700 tokens : 88.42857142857142% similarity, with 619 matched token, and 81 token mismatch
# ## Model validation for 750 tokens : 86.93333333333332% similarity, with 652 matched token, and 98 token mismatch
# ## Model validation for 800 tokens : 84.625% similarity, with 677 matched token, and 123 token mismatch
# ## Model validation for 850 tokens : 82.0% similarity, with 697 matched token, and 153 token mismatch
# ## Model validation for 900 tokens : 78.66666666666666% similarity, with 708 matched token, and 192 token mismatch
# ## Model validation for 950 tokens : 74.10526315789474% similarity, with 704 matched token, and 246 token mismatch
# ## Model validation for 1000 tokens : 70.7% similarity, with 707 matched token, and 293 token mismatch

# %% [markdown]
# ## Tune 5 : Ramping up the ctx size (8192), memory training
#
# - Tune 5: Mid ctx size (8192), same as tune 4, but extended in context size again!
#
# This intentionally a much larger dataset, with increased leaarning rate, specifically for L24+ tokenshift models, who have been shown to clear Tune 4

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# #
# # We reduce the training set for < 50 words - and shift the focus upwards
# # (aka 50-100 token * 2 : ~100 - 250 token ctx len)
# #
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-2-count.jsonl 2 1000 &
# for i in {5..95..10}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 100 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 1 &
# done
#
# #
# # Ramping up the 100+ - 8200 words dataset
# #
# for i in {100..8200..100}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 1000 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 10 &
# done
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated JSONL file with - 45 max words, 100 samples - at ../dataset/gen-word-45-count.jsonl
# Generated JSONL file with - 75 max words, 100 samples - at ../dataset/gen-word-75-count.jsonl
# Generated JSONL file with - 5 max words, 100 samples - at ../dataset/gen-word-5-count.jsonl
# Generated a single JSONL file with 75 samples (1 token repeat) - 35 max words - at ../dataset/shuffle-word-35-count.jsonl
# Generated a single JSONL file with 59 samples (1 token repeat) - 45 max words - at ../dataset/shuffle-word-45-count.jsonl
# Generated a single JSONL file with 562 samples (1 token repeat) - 5 max words - at ../dataset/shuffle-word-5-count.jsonl
# Generated JSONL file with - 35 max words, 100 samples - at ../dataset/gen-word-35-count.jsonl
# Generated a single JSONL file with 182 samples (1 token repeat) - 15 max words - at ../dataset/shuffle-word-15-count.jsonl
# Generated JSONL file with - 15 max words, 100 samples - at ../dataset/gen-word-15-count.jsonl
# Generated JSONL file with - 2 max words, 1000 samples - at ../dataset/word-2-count.jsonl
# Generated a single JSONL file with 43 samples (1 token repeat) - 65 max words - at ../dataset/shuffle-word-65-count.jsonl
# Generated a single JSONL file with 31 samples (1 token repeat) - 85 max words - at ../dataset/shuffle-word-85-count.jsonl
# Generated a single JSONL file with 46 samples (1 token repeat) - 55 max words - at ../dataset/shuffle-word-55-count.jsonl
# Generated JSONL file with - 25 max words, 100 samples - at ../dataset/gen-word-25-count.jsonl
# Generated JSONL file with - 55 max words, 100 samples - at ../dataset/gen-word-55-count.jsonl
# Generated JSONL file with - 65 max words, 100 samples - at ../dataset/gen-word-65-count.jsonl
# Generated a single JSONL file with 107 samples (1 token repeat) - 25 max words - at ../dataset/shuffle-word-25-count.jsonl
# Generated JSONL file with - 95 max words, 100 samples - at ../dataset/gen-word-95-count.jsonl
# Generated a single JSONL file with 36 samples (1 token repeat) - 75 max words - at ../dataset/shuffle-word-75-count.jsonl
# Generated a single JSONL file with 24 samples (10 token repeat) - 1300 max words - at ../dataset/shuffle-word-1300-count.jsonl
# Generated a single JSONL file with 28 samples (10 token repeat) - 1200 max words - at ../dataset/shuffle-word-1200-count.jsonl
# Generated a single JSONL file with 29 samples (1 token repeat) - 95 max words - at ../dataset/shuffle-word-95-count.jsonl
# Generated JSONL file with - 85 max words, 100 samples - at ../dataset/gen-word-85-count.jsonl
# Generated a single JSONL file with 59 samples (10 token repeat) - 500 max words - at ../dataset/shuffle-word-500-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 1800 max words - at ../dataset/shuffle-word-1800-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 1600 max words - at ../dataset/shuffle-word-1600-count.jsonl
# Generated a single JSONL file with 262 samples (10 token repeat) - 100 max words - at ../dataset/shuffle-word-100-count.jsonl
# Generated a single JSONL file with 91 samples (10 token repeat) - 300 max words - at ../dataset/shuffle-word-300-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 2200 max words - at ../dataset/shuffle-word-2200-count.jsonl
# Generated a single JSONL file with 50 samples (10 token repeat) - 600 max words - at ../dataset/shuffle-word-600-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 1500 max words - at ../dataset/shuffle-word-1500-count.jsonl
# Generated a single JSONL file with 30 samples (10 token repeat) - 1000 max words - at ../dataset/shuffle-word-1000-count.jsonl
# Generated a single JSONL file with 70 samples (10 token repeat) - 400 max words - at ../dataset/shuffle-word-400-count.jsonl
# Generated a single JSONL file with 30 samples (10 token repeat) - 1100 max words - at ../dataset/shuffle-word-1100-count.jsonl
# Generated a single JSONL file with 135 samples (10 token repeat) - 200 max words - at ../dataset/shuffle-word-200-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4200 max words - at ../dataset/shuffle-word-4200-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 1400 max words - at ../dataset/shuffle-word-1400-count.jsonl
# Generated a single JSONL file with 33 samples (10 token repeat) - 900 max words - at ../dataset/shuffle-word-900-count.jsonl
# Generated a single JSONL file with 15 samples (10 token repeat) - 2600 max words - at ../dataset/shuffle-word-2600-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3400 max words - at ../dataset/shuffle-word-3400-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4100 max words - at ../dataset/shuffle-word-4100-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4900 max words - at ../dataset/shuffle-word-4900-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3900 max words - at ../dataset/shuffle-word-3900-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6000 max words - at ../dataset/shuffle-word-6000-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3600 max words - at ../dataset/shuffle-word-3600-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 2900 max words - at ../dataset/shuffle-word-2900-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5800 max words - at ../dataset/shuffle-word-5800-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7800 max words - at ../dataset/shuffle-word-7800-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7300 max words - at ../dataset/shuffle-word-7300-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 8000 max words - at ../dataset/shuffle-word-8000-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 2000 max words - at ../dataset/shuffle-word-2000-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4500 max words - at ../dataset/shuffle-word-4500-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4700 max words - at ../dataset/shuffle-word-4700-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5000 max words - at ../dataset/shuffle-word-5000-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3100 max words - at ../dataset/shuffle-word-3100-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7200 max words - at ../dataset/shuffle-word-7200-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6500 max words - at ../dataset/shuffle-word-6500-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 2400 max words - at ../dataset/shuffle-word-2400-count.jsonl
# Generated a single JSONL file with 41 samples (10 token repeat) - 700 max words - at ../dataset/shuffle-word-700-count.jsonl
# Generated a single JSONL file with 11 samples (10 token repeat) - 2800 max words - at ../dataset/shuffle-word-2800-count.jsonl
# Generated JSONL file with - 100 max words, 1000 samples - at ../dataset/gen-word-100-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6100 max words - at ../dataset/shuffle-word-6100-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5100 max words - at ../dataset/shuffle-word-5100-count.jsonl
# Generated a single JSONL file with 19 samples (10 token repeat) - 2500 max words - at ../dataset/shuffle-word-2500-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4300 max words - at ../dataset/shuffle-word-4300-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7100 max words - at ../dataset/shuffle-word-7100-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 8200 max words - at ../dataset/shuffle-word-8200-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 2300 max words - at ../dataset/shuffle-word-2300-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3700 max words - at ../dataset/shuffle-word-3700-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4600 max words - at ../dataset/shuffle-word-4600-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 1900 max words - at ../dataset/shuffle-word-1900-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 8100 max words - at ../dataset/shuffle-word-8100-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7500 max words - at ../dataset/shuffle-word-7500-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6400 max words - at ../dataset/shuffle-word-6400-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5700 max words - at ../dataset/shuffle-word-5700-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6600 max words - at ../dataset/shuffle-word-6600-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6700 max words - at ../dataset/shuffle-word-6700-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5300 max words - at ../dataset/shuffle-word-5300-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6800 max words - at ../dataset/shuffle-word-6800-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7000 max words - at ../dataset/shuffle-word-7000-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4400 max words - at ../dataset/shuffle-word-4400-count.jsonl
# Generated a single JSONL file with 39 samples (10 token repeat) - 800 max words - at ../dataset/shuffle-word-800-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3000 max words - at ../dataset/shuffle-word-3000-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7900 max words - at ../dataset/shuffle-word-7900-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5600 max words - at ../dataset/shuffle-word-5600-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4000 max words - at ../dataset/shuffle-word-4000-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6300 max words - at ../dataset/shuffle-word-6300-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3500 max words - at ../dataset/shuffle-word-3500-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5900 max words - at ../dataset/shuffle-word-5900-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 1700 max words - at ../dataset/shuffle-word-1700-count.jsonl
# Generated a single JSONL file with 12 samples (10 token repeat) - 2700 max words - at ../dataset/shuffle-word-2700-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5500 max words - at ../dataset/shuffle-word-5500-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3300 max words - at ../dataset/shuffle-word-3300-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6200 max words - at ../dataset/shuffle-word-6200-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7400 max words - at ../dataset/shuffle-word-7400-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7600 max words - at ../dataset/shuffle-word-7600-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3800 max words - at ../dataset/shuffle-word-3800-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5400 max words - at ../dataset/shuffle-word-5400-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 6900 max words - at ../dataset/shuffle-word-6900-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 3200 max words - at ../dataset/shuffle-word-3200-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 4800 max words - at ../dataset/shuffle-word-4800-count.jsonl
# Generated a single JSONL file with 20 samples (10 token repeat) - 2100 max words - at ../dataset/shuffle-word-2100-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 5200 max words - at ../dataset/shuffle-word-5200-count.jsonl
# Generated JSONL file with - 200 max words, 1000 samples - at ../dataset/gen-word-200-count.jsonl
# Generated a single JSONL file with 10 samples (10 token repeat) - 7700 max words - at ../dataset/shuffle-word-7700-count.jsonl
# Generated JSONL file with - 400 max words, 1000 samples - at ../dataset/gen-word-400-count.jsonl
# Generated JSONL file with - 500 max words, 1000 samples - at ../dataset/gen-word-500-count.jsonl
# Generated JSONL file with - 300 max words, 1000 samples - at ../dataset/gen-word-300-count.jsonl
# Generated JSONL file with - 600 max words, 1000 samples - at ../dataset/gen-word-600-count.jsonl
# Generated JSONL file with - 800 max words, 1000 samples - at ../dataset/gen-word-800-count.jsonl
# Generated JSONL file with - 700 max words, 1000 samples - at ../dataset/gen-word-700-count.jsonl
# Generated JSONL file with - 1100 max words, 1000 samples - at ../dataset/gen-word-1100-count.jsonl
# Generated JSONL file with - 1400 max words, 1000 samples - at ../dataset/gen-word-1400-count.jsonl
# Generated JSONL file with - 1000 max words, 1000 samples - at ../dataset/gen-word-1000-count.jsonl
# Generated JSONL file with - 900 max words, 1000 samples - at ../dataset/gen-word-900-count.jsonl
# Generated JSONL file with - 1500 max words, 1000 samples - at ../dataset/gen-word-1500-count.jsonl
# Generated JSONL file with - 1700 max words, 1000 samples - at ../dataset/gen-word-1700-count.jsonl
# Generated JSONL file with - 1600 max words, 1000 samples - at ../dataset/gen-word-1600-count.jsonl
# Generated JSONL file with - 1900 max words, 1000 samples - at ../dataset/gen-word-1900-count.jsonl
# Generated JSONL file with - 1800 max words, 1000 samples - at ../dataset/gen-word-1800-count.jsonl
# Generated JSONL file with - 1300 max words, 1000 samples - at ../dataset/gen-word-1300-count.jsonl
# Generated JSONL file with - 1200 max words, 1000 samples - at ../dataset/gen-word-1200-count.jsonl
# Generated JSONL file with - 2300 max words, 1000 samples - at ../dataset/gen-word-2300-count.jsonl
# Generated JSONL file with - 2100 max words, 1000 samples - at ../dataset/gen-word-2100-count.jsonl
# Generated JSONL file with - 2200 max words, 1000 samples - at ../dataset/gen-word-2200-count.jsonl
# Generated JSONL file with - 2600 max words, 1000 samples - at ../dataset/gen-word-2600-count.jsonl
# Generated JSONL file with - 2000 max words, 1000 samples - at ../dataset/gen-word-2000-count.jsonl
# Generated JSONL file with - 2800 max words, 1000 samples - at ../dataset/gen-word-2800-count.jsonl
# Generated JSONL file with - 2900 max words, 1000 samples - at ../dataset/gen-word-2900-count.jsonl
# Generated JSONL file with - 2500 max words, 1000 samples - at ../dataset/gen-word-2500-count.jsonl
# Generated JSONL file with - 2400 max words, 1000 samples - at ../dataset/gen-word-2400-count.jsonl
# Generated JSONL file with - 3600 max words, 1000 samples - at ../dataset/gen-word-3600-count.jsonl
# Generated JSONL file with - 3200 max words, 1000 samples - at ../dataset/gen-word-3200-count.jsonl
# Generated JSONL file with - 3300 max words, 1000 samples - at ../dataset/gen-word-3300-count.jsonl
# Generated JSONL file with - 3000 max words, 1000 samples - at ../dataset/gen-word-3000-count.jsonl
# Generated JSONL file with - 3700 max words, 1000 samples - at ../dataset/gen-word-3700-count.jsonl
# Generated JSONL file with - 3100 max words, 1000 samples - at ../dataset/gen-word-3100-count.jsonl
# Generated JSONL file with - 3400 max words, 1000 samples - at ../dataset/gen-word-3400-count.jsonl
# Generated JSONL file with - 2700 max words, 1000 samples - at ../dataset/gen-word-2700-count.jsonl
# Generated JSONL file with - 4300 max words, 1000 samples - at ../dataset/gen-word-4300-count.jsonl
# Generated JSONL file with - 4000 max words, 1000 samples - at ../dataset/gen-word-4000-count.jsonl
# Generated JSONL file with - 5100 max words, 1000 samples - at ../dataset/gen-word-5100-count.jsonl
# Generated JSONL file with - 3500 max words, 1000 samples - at ../dataset/gen-word-3500-count.jsonl
# Generated JSONL file with - 4500 max words, 1000 samples - at ../dataset/gen-word-4500-count.jsonl
# Generated JSONL file with - 4100 max words, 1000 samples - at ../dataset/gen-word-4100-count.jsonl
# Generated JSONL file with - 4200 max words, 1000 samples - at ../dataset/gen-word-4200-count.jsonl
# Generated JSONL file with - 4700 max words, 1000 samples - at ../dataset/gen-word-4700-count.jsonl
# Generated JSONL file with - 4600 max words, 1000 samples - at ../dataset/gen-word-4600-count.jsonl
# Generated JSONL file with - 5600 max words, 1000 samples - at ../dataset/gen-word-5600-count.jsonl
# Generated JSONL file with - 4400 max words, 1000 samples - at ../dataset/gen-word-4400-count.jsonl
# Generated JSONL file with - 3900 max words, 1000 samples - at ../dataset/gen-word-3900-count.jsonl
# Generated JSONL file with - 5300 max words, 1000 samples - at ../dataset/gen-word-5300-count.jsonl
# Generated JSONL file with - 3800 max words, 1000 samples - at ../dataset/gen-word-3800-count.jsonl
# Generated JSONL file with - 6600 max words, 1000 samples - at ../dataset/gen-word-6600-count.jsonl
# Generated JSONL file with - 5500 max words, 1000 samples - at ../dataset/gen-word-5500-count.jsonl
# Generated JSONL file with - 4900 max words, 1000 samples - at ../dataset/gen-word-4900-count.jsonl
# Generated JSONL file with - 5400 max words, 1000 samples - at ../dataset/gen-word-5400-count.jsonl
# Generated JSONL file with - 5700 max words, 1000 samples - at ../dataset/gen-word-5700-count.jsonl
# Generated JSONL file with - 5800 max words, 1000 samples - at ../dataset/gen-word-5800-count.jsonl
# Generated JSONL file with - 4800 max words, 1000 samples - at ../dataset/gen-word-4800-count.jsonl
# Generated JSONL file with - 5000 max words, 1000 samples - at ../dataset/gen-word-5000-count.jsonl
# Generated JSONL file with - 6100 max words, 1000 samples - at ../dataset/gen-word-6100-count.jsonl
# Generated JSONL file with - 6000 max words, 1000 samples - at ../dataset/gen-word-6000-count.jsonl
# Generated JSONL file with - 5200 max words, 1000 samples - at ../dataset/gen-word-5200-count.jsonl
# Generated JSONL file with - 6300 max words, 1000 samples - at ../dataset/gen-word-6300-count.jsonl
# Generated JSONL file with - 6200 max words, 1000 samples - at ../dataset/gen-word-6200-count.jsonl
# Generated JSONL file with - 5900 max words, 1000 samples - at ../dataset/gen-word-5900-count.jsonl
# Generated JSONL file with - 6400 max words, 1000 samples - at ../dataset/gen-word-6400-count.jsonl
# Generated JSONL file with - 7300 max words, 1000 samples - at ../dataset/gen-word-7300-count.jsonl
# Generated JSONL file with - 6700 max words, 1000 samples - at ../dataset/gen-word-6700-count.jsonl
# Generated JSONL file with - 6800 max words, 1000 samples - at ../dataset/gen-word-6800-count.jsonl
# Generated JSONL file with - 7000 max words, 1000 samples - at ../dataset/gen-word-7000-count.jsonl
# Generated JSONL file with - 6500 max words, 1000 samples - at ../dataset/gen-word-6500-count.jsonl
# Generated JSONL file with - 6900 max words, 1000 samples - at ../dataset/gen-word-6900-count.jsonl
# Generated JSONL file with - 7100 max words, 1000 samples - at ../dataset/gen-word-7100-count.jsonl
# Generated JSONL file with - 7400 max words, 1000 samples - at ../dataset/gen-word-7400-count.jsonl
# Generated JSONL file with - 7800 max words, 1000 samples - at ../dataset/gen-word-7800-count.jsonl
# Generated JSONL file with - 7200 max words, 1000 samples - at ../dataset/gen-word-7200-count.jsonl
# Generated JSONL file with - 7600 max words, 1000 samples - at ../dataset/gen-word-7600-count.jsonl
# Generated JSONL file with - 8100 max words, 1000 samples - at ../dataset/gen-word-8100-count.jsonl
# Generated JSONL file with - 7500 max words, 1000 samples - at ../dataset/gen-word-7500-count.jsonl
# Generated JSONL file with - 8000 max words, 1000 samples - at ../dataset/gen-word-8000-count.jsonl
# Generated JSONL file with - 7900 max words, 1000 samples - at ../dataset/gen-word-7900-count.jsonl
# Generated JSONL file with - 7700 max words, 1000 samples - at ../dataset/gen-word-7700-count.jsonl
# Generated JSONL file with - 8200 max words, 1000 samples - at ../dataset/gen-word-8200-count.jsonl
# ## Done ##
# total 3.2G
# drwxr-xr-x  2 root root 8.0K Jul 23 03:37 .
# drwxr-xr-x 10 root root  171 Jul 23 03:35 ..
# -rw-r--r--  1 root root 1.1M Jul 23 03:37 gen-word-100-count.jsonl
# -rw-r--r--  1 root root 9.7M Jul 23 03:37 gen-word-1000-count.jsonl
# -rw-r--r--  1 root root  11M Jul 23 03:37 gen-word-1100-count.jsonl
# -rw-r--r--  1 root root  12M Jul 23 03:37 gen-word-1200-count.jsonl
# -rw-r--r--  1 root root  13M Jul 23 03:37 gen-word-1300-count.jsonl
# -rw-r--r--  1 root root  14M Jul 23 03:37 gen-word-1400-count.jsonl
# -rw-r--r--  1 root root  25K Jul 23 03:37 gen-word-15-count.jsonl
# -rw-r--r--  1 root root  15M Jul 23 03:37 gen-word-1500-count.jsonl
# -rw-r--r--  1 root root  16M Jul 23 03:37 gen-word-1600-count.jsonl
# -rw-r--r--  1 root root  17M Jul 23 03:37 gen-word-1700-count.jsonl
# -rw-r--r--  1 root root  18M Jul 23 03:37 gen-word-1800-count.jsonl
# -rw-r--r--  1 root root  19M Jul 23 03:37 gen-word-1900-count.jsonl
# -rw-r--r--  1 root root 2.0M Jul 23 03:37 gen-word-200-count.jsonl
# -rw-r--r--  1 root root  20M Jul 23 03:37 gen-word-2000-count.jsonl
# -rw-r--r--  1 root root  21M Jul 23 03:37 gen-word-2100-count.jsonl
# -rw-r--r--  1 root root  21M Jul 23 03:37 gen-word-2200-count.jsonl
# -rw-r--r--  1 root root  22M Jul 23 03:37 gen-word-2300-count.jsonl
# -rw-r--r--  1 root root  23M Jul 23 03:37 gen-word-2400-count.jsonl
# -rw-r--r--  1 root root  35K Jul 23 03:37 gen-word-25-count.jsonl
# -rw-r--r--  1 root root  24M Jul 23 03:37 gen-word-2500-count.jsonl
# -rw-r--r--  1 root root  25M Jul 23 03:37 gen-word-2600-count.jsonl
# -rw-r--r--  1 root root  26M Jul 23 03:37 gen-word-2700-count.jsonl
# -rw-r--r--  1 root root  27M Jul 23 03:37 gen-word-2800-count.jsonl
# -rw-r--r--  1 root root  28M Jul 23 03:37 gen-word-2900-count.jsonl
# -rw-r--r--  1 root root 3.0M Jul 23 03:37 gen-word-300-count.jsonl
# -rw-r--r--  1 root root  29M Jul 23 03:37 gen-word-3000-count.jsonl
# -rw-r--r--  1 root root  30M Jul 23 03:37 gen-word-3100-count.jsonl
# -rw-r--r--  1 root root  31M Jul 23 03:37 gen-word-3200-count.jsonl
# -rw-r--r--  1 root root  32M Jul 23 03:37 gen-word-3300-count.jsonl
# -rw-r--r--  1 root root  33M Jul 23 03:37 gen-word-3400-count.jsonl
# -rw-r--r--  1 root root  45K Jul 23 03:37 gen-word-35-count.jsonl
# -rw-r--r--  1 root root  34M Jul 23 03:37 gen-word-3500-count.jsonl
# -rw-r--r--  1 root root  35M Jul 23 03:37 gen-word-3600-count.jsonl
# -rw-r--r--  1 root root  36M Jul 23 03:37 gen-word-3700-count.jsonl
# -rw-r--r--  1 root root  37M Jul 23 03:37 gen-word-3800-count.jsonl
# -rw-r--r--  1 root root  38M Jul 23 03:37 gen-word-3900-count.jsonl
# -rw-r--r--  1 root root 3.9M Jul 23 03:37 gen-word-400-count.jsonl
# -rw-r--r--  1 root root  39M Jul 23 03:37 gen-word-4000-count.jsonl
# -rw-r--r--  1 root root  40M Jul 23 03:37 gen-word-4100-count.jsonl
# -rw-r--r--  1 root root  40M Jul 23 03:37 gen-word-4200-count.jsonl
# -rw-r--r--  1 root root  41M Jul 23 03:37 gen-word-4300-count.jsonl
# -rw-r--r--  1 root root  42M Jul 23 03:37 gen-word-4400-count.jsonl
# -rw-r--r--  1 root root  55K Jul 23 03:37 gen-word-45-count.jsonl
# -rw-r--r--  1 root root  43M Jul 23 03:37 gen-word-4500-count.jsonl
# -rw-r--r--  1 root root  44M Jul 23 03:37 gen-word-4600-count.jsonl
# -rw-r--r--  1 root root  45M Jul 23 03:37 gen-word-4700-count.jsonl
# -rw-r--r--  1 root root  46M Jul 23 03:37 gen-word-4800-count.jsonl
# -rw-r--r--  1 root root  47M Jul 23 03:37 gen-word-4900-count.jsonl
# -rw-r--r--  1 root root  15K Jul 23 03:37 gen-word-5-count.jsonl
# -rw-r--r--  1 root root 4.9M Jul 23 03:37 gen-word-500-count.jsonl
# -rw-r--r--  1 root root  48M Jul 23 03:37 gen-word-5000-count.jsonl
# -rw-r--r--  1 root root  49M Jul 23 03:37 gen-word-5100-count.jsonl
# -rw-r--r--  1 root root  50M Jul 23 03:37 gen-word-5200-count.jsonl
# -rw-r--r--  1 root root  51M Jul 23 03:37 gen-word-5300-count.jsonl
# -rw-r--r--  1 root root  52M Jul 23 03:37 gen-word-5400-count.jsonl
# -rw-r--r--  1 root root  62K Jul 23 03:37 gen-word-55-count.jsonl
# -rw-r--r--  1 root root  53M Jul 23 03:37 gen-word-5500-count.jsonl
# -rw-r--r--  1 root root  54M Jul 23 03:37 gen-word-5600-count.jsonl
# -rw-r--r--  1 root root  55M Jul 23 03:37 gen-word-5700-count.jsonl
# -rw-r--r--  1 root root  56M Jul 23 03:37 gen-word-5800-count.jsonl
# -rw-r--r--  1 root root  57M Jul 23 03:37 gen-word-5900-count.jsonl
# -rw-r--r--  1 root root 5.8M Jul 23 03:37 gen-word-600-count.jsonl
# -rw-r--r--  1 root root  58M Jul 23 03:37 gen-word-6000-count.jsonl
# -rw-r--r--  1 root root  59M Jul 23 03:37 gen-word-6100-count.jsonl
# -rw-r--r--  1 root root  60M Jul 23 03:37 gen-word-6200-count.jsonl
# -rw-r--r--  1 root root  60M Jul 23 03:37 gen-word-6300-count.jsonl
# -rw-r--r--  1 root root  61M Jul 23 03:37 gen-word-6400-count.jsonl
# -rw-r--r--  1 root root  71K Jul 23 03:37 gen-word-65-count.jsonl
# -rw-r--r--  1 root root  62M Jul 23 03:37 gen-word-6500-count.jsonl
# -rw-r--r--  1 root root  63M Jul 23 03:37 gen-word-6600-count.jsonl
# -rw-r--r--  1 root root  64M Jul 23 03:37 gen-word-6700-count.jsonl
# -rw-r--r--  1 root root  65M Jul 23 03:37 gen-word-6800-count.jsonl
# -rw-r--r--  1 root root  66M Jul 23 03:37 gen-word-6900-count.jsonl
# -rw-r--r--  1 root root 6.8M Jul 23 03:37 gen-word-700-count.jsonl
# -rw-r--r--  1 root root  67M Jul 23 03:37 gen-word-7000-count.jsonl
# -rw-r--r--  1 root root  68M Jul 23 03:37 gen-word-7100-count.jsonl
# -rw-r--r--  1 root root  69M Jul 23 03:37 gen-word-7200-count.jsonl
# -rw-r--r--  1 root root  70M Jul 23 03:37 gen-word-7300-count.jsonl
# -rw-r--r--  1 root root  71M Jul 23 03:37 gen-word-7400-count.jsonl
# -rw-r--r--  1 root root  83K Jul 23 03:37 gen-word-75-count.jsonl
# -rw-r--r--  1 root root  72M Jul 23 03:37 gen-word-7500-count.jsonl
# -rw-r--r--  1 root root  73M Jul 23 03:37 gen-word-7600-count.jsonl
# -rw-r--r--  1 root root  74M Jul 23 03:37 gen-word-7700-count.jsonl
# -rw-r--r--  1 root root  75M Jul 23 03:37 gen-word-7800-count.jsonl
# -rw-r--r--  1 root root  76M Jul 23 03:37 gen-word-7900-count.jsonl
# -rw-r--r--  1 root root 7.7M Jul 23 03:37 gen-word-800-count.jsonl
# -rw-r--r--  1 root root  77M Jul 23 03:37 gen-word-8000-count.jsonl
# -rw-r--r--  1 root root  78M Jul 23 03:37 gen-word-8100-count.jsonl
# -rw-r--r--  1 root root  78M Jul 23 03:37 gen-word-8200-count.jsonl
# -rw-r--r--  1 root root  89K Jul 23 03:37 gen-word-85-count.jsonl
# -rw-r--r--  1 root root 8.7M Jul 23 03:37 gen-word-900-count.jsonl
# -rw-r--r--  1 root root 101K Jul 23 03:37 gen-word-95-count.jsonl
# -rw-r--r--  1 root root 284K Jul 23 03:37 shuffle-word-100-count.jsonl
# -rw-r--r--  1 root root 260K Jul 23 03:37 shuffle-word-1000-count.jsonl
# -rw-r--r--  1 root root 262K Jul 23 03:37 shuffle-word-1100-count.jsonl
# -rw-r--r--  1 root root 261K Jul 23 03:37 shuffle-word-1200-count.jsonl
# -rw-r--r--  1 root root 260K Jul 23 03:37 shuffle-word-1300-count.jsonl
# -rw-r--r--  1 root root 260K Jul 23 03:37 shuffle-word-1400-count.jsonl
# -rw-r--r--  1 root root  42K Jul 23 03:37 shuffle-word-15-count.jsonl
# -rw-r--r--  1 root root 261K Jul 23 03:37 shuffle-word-1500-count.jsonl
# -rw-r--r--  1 root root 259K Jul 23 03:37 shuffle-word-1600-count.jsonl
# -rw-r--r--  1 root root 261K Jul 23 03:37 shuffle-word-1700-count.jsonl
# -rw-r--r--  1 root root 261K Jul 23 03:37 shuffle-word-1800-count.jsonl
# -rw-r--r--  1 root root 259K Jul 23 03:37 shuffle-word-1900-count.jsonl
# -rw-r--r--  1 root root 269K Jul 23 03:37 shuffle-word-200-count.jsonl
# -rw-r--r--  1 root root 261K Jul 23 03:37 shuffle-word-2000-count.jsonl
# -rw-r--r--  1 root root 260K Jul 23 03:37 shuffle-word-2100-count.jsonl
# -rw-r--r--  1 root root 260K Jul 23 03:37 shuffle-word-2200-count.jsonl
# -rw-r--r--  1 root root 260K Jul 23 03:37 shuffle-word-2300-count.jsonl
# -rw-r--r--  1 root root 263K Jul 23 03:37 shuffle-word-2400-count.jsonl
# -rw-r--r--  1 root root  34K Jul 23 03:37 shuffle-word-25-count.jsonl
# -rw-r--r--  1 root root 258K Jul 23 03:37 shuffle-word-2500-count.jsonl
# -rw-r--r--  1 root root 257K Jul 23 03:37 shuffle-word-2600-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-2700-count.jsonl
# -rw-r--r--  1 root root 256K Jul 23 03:37 shuffle-word-2800-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-2900-count.jsonl
# -rw-r--r--  1 root root 268K Jul 23 03:37 shuffle-word-300-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-3000-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-3100-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-3200-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-3300-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-3400-count.jsonl
# -rw-r--r--  1 root root  33K Jul 23 03:37 shuffle-word-35-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-3500-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-3600-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-3700-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-3800-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-3900-count.jsonl
# -rw-r--r--  1 root root 266K Jul 23 03:37 shuffle-word-400-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-4000-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-4100-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-4200-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-4300-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-4400-count.jsonl
# -rw-r--r--  1 root root  31K Jul 23 03:37 shuffle-word-45-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-4500-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-4600-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-4700-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-4800-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-4900-count.jsonl
# -rw-r--r--  1 root root  80K Jul 23 03:37 shuffle-word-5-count.jsonl
# -rw-r--r--  1 root root 267K Jul 23 03:37 shuffle-word-500-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-5000-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-5100-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-5200-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-5300-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-5400-count.jsonl
# -rw-r--r--  1 root root  31K Jul 23 03:37 shuffle-word-55-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-5500-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-5600-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-5700-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-5800-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-5900-count.jsonl
# -rw-r--r--  1 root root 263K Jul 23 03:37 shuffle-word-600-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-6000-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-6100-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-6200-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-6300-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-6400-count.jsonl
# -rw-r--r--  1 root root  31K Jul 23 03:37 shuffle-word-65-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-6500-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-6600-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-6700-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-6800-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-6900-count.jsonl
# -rw-r--r--  1 root root 262K Jul 23 03:37 shuffle-word-700-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-7000-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-7100-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-7200-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-7300-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-7400-count.jsonl
# -rw-r--r--  1 root root  30K Jul 23 03:37 shuffle-word-75-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-7500-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-7600-count.jsonl
# -rw-r--r--  1 root root 254K Jul 23 03:37 shuffle-word-7700-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-7800-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-7900-count.jsonl
# -rw-r--r--  1 root root 264K Jul 23 03:37 shuffle-word-800-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-8000-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-8100-count.jsonl
# -rw-r--r--  1 root root 255K Jul 23 03:37 shuffle-word-8200-count.jsonl
# -rw-r--r--  1 root root  30K Jul 23 03:37 shuffle-word-85-count.jsonl
# -rw-r--r--  1 root root 263K Jul 23 03:37 shuffle-word-900-count.jsonl
# -rw-r--r--  1 root root  30K Jul 23 03:37 shuffle-word-95-count.jsonl
# -rw-r--r--  1 root root 120K Jul 23 03:37 word-2-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-5.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-C-mem-finetune-5/"
# Out:
# Resolving data files: 100%|███████████████| 185/185 [00:00<00:00, 142062.66it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-1b31283c754b0ad4/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|████████████████████| 1/1 [00:00<00:00, 696.84it/s]
# Extracting data files: 100%|██████████████████████| 1/1 [00:00<00:00, 26.07it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-1b31283c754b0ad4/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 80.12it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-C-mem-finetune-5.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-5 (bs=256, train-ctx=4096*2, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=4096
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 3501854959
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 3501854959
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230723_060224-tiak1hk1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run TokenShift-C - Mem-Finetune-5 (bs=256, train-ctx=4096*2, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/tiak1hk1
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16/build.ninja...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=wkv_4096_bf16 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 --compiler-options '-fPIC' -t 4 -std=c++17 -res-usage --maxrregcount 60 --use_fast_math -O3 -Xptxas -O3 --extra-device-vectorization -DTmax=4096 -c /root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/cuda/wkv_cuda_bf16.cu -o wkv_cuda_bf16.cuda.o
# ptxas info    : 1 bytes gmem
# ptxas info    : Compiling entry function '_Z15kernel_backwardiiiPKfPKN3c108BFloat16ES4_S4_S0_S4_S0_PS2_S5_S5_S5_Pf' for 'sm_86'
# ptxas info    : Function properties for _Z15kernel_backwardiiiPKfPKN3c108BFloat16ES4_S4_S0_S4_S0_PS2_S5_S5_S5_Pf
#     49152 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 56 registers, 464 bytes cmem[0], 8 bytes cmem[2]
# ptxas info    : Compiling entry function '_Z14kernel_forwardiiiPKfPKN3c108BFloat16ES4_S4_S0_PS2_Pf' for 'sm_86'
# ptxas info    : Function properties for _Z14kernel_forwardiiiPKfPKN3c108BFloat16ES4_S4_S0_PS2_Pf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 40 registers, 424 bytes cmem[0]
# [2/3] c++ -MMD -MF wkv_op_bf16.o.d -DTORCH_EXTENSION_NAME=wkv_4096_bf16 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -std=c++17 -O3 -DTmax=4096 -c /root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/cuda/wkv_op_bf16.cpp -o wkv_op_bf16.o
# [3/3] c++ wkv_op_bf16.o wkv_cuda_bf16.cuda.o -shared -L/usr/local/lib/python3.11/dist-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o wkv_4096_bf16.so
# Loading extension module wkv_4096_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Resolving data files: 100%|███████████████| 185/185 [00:00<00:00, 212181.09it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-1b31283c754b0ad4/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|████████████████████| 1/1 [00:00<00:00, 616.45it/s]
# Extracting data files: 100%|██████████████████████| 1/1 [00:00<00:00, 24.92it/s]
# Generating train split: 0 examples [00:00, ? examples/s]Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [rank: 4] Global seed set to 3501854959
# [rank: 2] Global seed set to 3501854959
# [rank: 5] Global seed set to 3501854959
# [rank: 6] Global seed set to 3501854959
# [rank: 7] Global seed set to 3501854959
# [rank: 1] Global seed set to 3501854959
# [rank: 3] Global seed set to 3501854959
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-1b31283c754b0ad4/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 65.45it/s]
# [rank: 1] Global seed set to 3501854959
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-23 06:03:12,150] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Map (num_proc=64):   0%|                       | 0/86879 [00:00<?, ? examples/s][rank: 4] Global seed set to 3501854959
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-23 06:03:14,572] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Map (num_proc=64):   1%|           | 668/86879 [00:00<00:52, 1628.30 examples/s][rank: 7] Global seed set to 3501854959
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-23 06:03:14,860] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Map (num_proc=64):   1%|          | 1013/86879 [00:00<00:39, 2173.49 examples/s][rank: 5] Global seed set to 3501854959
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-23 06:03:14,935] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 3501854959
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 6] Global seed set to 3501854959
# [2023-07-23 06:03:14,945] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-23 06:03:14,946] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 3] Global seed set to 3501854959
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-23 06:03:14,948] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 0] Global seed set to 3501854959
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-23 06:04:51,171] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:612: UserWarning: Checkpoint directory /root/rwkv5x-tokenshift-exp-A/checkpoint/TokenShift-C-mem-finetune-5 exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  4.000e-04 (0.0004)
#     - lr_final: 1.000e-04 (0.0001)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu118/fused_adam...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/includes -I/usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/adam -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 --compiler-options '-fPIC' -O3 -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -lineinfo --use_fast_math -gencode=arch=compute_86,code=sm_86 -gencode=arch=compute_86,code=compute_86 -DBF16_AVAILABLE -std=c++17 -c /usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/adam/multi_tensor_adam.cu -o multi_tensor_adam.cuda.o
# [2/3] c++ -MMD -MF fused_adam_frontend.o.d -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/includes -I/usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/adam -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -O3 -std=c++17 -g -Wno-reorder -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -DBF16_AVAILABLE -c /usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/adam/fused_adam_frontend.cpp -o fused_adam_frontend.o
# [3/3] c++ fused_adam_frontend.o multi_tensor_adam.cuda.o -shared -L/usr/local/lib/python3.11/dist-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o fused_adam.so
# Loading extension module fused_adam...
# Time to load fused_adam op: 21.051258325576782 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 21.12156343460083 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 21.12287974357605 seconds
# Time to load fused_adam op: 21.123579502105713 seconds
# Time to load fused_adam op: 21.123566150665283 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 21.124879837036133 seconds
# Time to load fused_adam op: 21.12513542175293 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 21.13184142112732 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu118/utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /usr/local/lib/python3.11/dist-packages/torch/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -isystem /usr/local/lib/python3.11/dist-packages/torch/include/TH -isystem /usr/local/lib/python3.11/dist-packages/torch/include/THC -isystem /usr/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -c /usr/local/lib/python3.11/dist-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/usr/local/lib/python3.11/dist-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 11.514719009399414 seconds
# Loading extension module utils...
# Time to load utils op: 11.514506578445435 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 11.513642311096191 seconds
# Time to load utils op: 11.511933088302612 seconds
# Loading extension module utils...
# Time to load utils op: 11.514458417892456 seconds
# Loading extension module utils...
# Time to load utils op: 11.514321327209473 seconds
# Time to load utils op: 11.513095617294312 seconds
# Time to load utils op: 11.517306327819824 seconds
# Rank: 3 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 1 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 7 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 0 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 4 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(189376000, False), (6144, False), (6144, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002593994140625 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002741813659667969 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002758502960205078 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00020742416381835938 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002582073211669922 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00024962425231933594 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002961158752441406 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005176067352294922 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.11/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/usr/lib/python3.11/shutil.py", line 738, in rmtree
#     onerror(os.rmdir, path, sys.exc_info())
#   File "/usr/lib/python3.11/shutil.py", line 736, in rmtree
#     os.rmdir(path, dir_fd=dir_fd)
# OSError: [Errno 39] Directory not empty: '/tmp/pymp-cmcw1eil'
# Epoch 0:  11%| | 800/7090 [29:58<3:55:38,  2.25s/it, v_num=1hk1, train/loss=0.55/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 7090/7090 [4:25:42<00:00,  2.25s/it, v_num=1hk1, train/loss=0.2
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:03,  1.89it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:01<00:03,  1.95it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:01<00:01,  2.53it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:01<00:01,  2.67it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:01<00:01,  2.65it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:02<00:00,  2.93it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:02<00:00,  3.17it/s]
# Epoch 0: 100%|█| 7090/7090 [4:25:51<00:00,  2.25s/it, v_num=1hk1, train/loss=0.2
# Epoch 0: 100%|█| 7090/7090 [4:25:51<00:00,  2.25s/it, v_num=1hk1, train/loss=0.2`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 7090/7090 [4:26:04<00:00,  2.25s/it, v_num=1hk1, train/loss=0.2
# wandb: Waiting for W&B process to finish... (success).
# wandb: \ 0.009 MB of 0.009 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▅▆▄▆▆▃▂▆▇█▂▅▅▅▁▇▆▁█▅▂▂▃▆▅▃▇▁▇▇▆▁▄▂▂▂▃▆▄▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss █▇▇▇▂▆▇▇▇▁▇▁▄▅▆▄▂▇▆▁▇▄▆▄▃▄▂▃▆▄▆▁▇▁▁▄▇▁▇▁
# wandb:   trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 7
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 7438
# wandb:               substep 56
# wandb:            train/loss 6.5625
# wandb:   trainer/global_step 221
# wandb: trainer/learning_rate 0.0001
# wandb:       validation/loss 3.42112
# wandb:
# wandb: 🚀 View run TokenShift-C - Mem-Finetune-5 (bs=256, train-ctx=4096*2, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/tiak1hk1
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230723_060224-tiak1hk1/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-C-mem-finetune-5/last.ckpt" \
        "../model/TokenShift-C-Tune5.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-C-Tune5.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-C-mem-finetune-5/last-v1.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 438 params 1515106304 elements
# Saving fp32 state dict to ../model/TokenShift-C-Tune5.pth
# -rw-r--r-- 1 root root 5.7G Jul 23 10:32 ../model/TokenShift-C-Tune5.pth

# %%
# Lets do a memory eval 
# !python3 ../memory_script/eval_model_memory_guided.py "{PROJECT_DIR}/model/TokenShift-C-Tune5.pth"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 100.0% similarity, with 15 matched token, and 0 token mismatch
# ## Model validation for 20 tokens : 100.0% similarity, with 20 matched token, and 0 token mismatch
# ## Model validation for 25 tokens : 100.0% similarity, with 25 matched token, and 0 token mismatch
# ## Model validation for 30 tokens : 100.0% similarity, with 30 matched token, and 0 token mismatch
# ## Model validation for 35 tokens : 100.0% similarity, with 35 matched token, and 0 token mismatch
# ## Model validation for 40 tokens : 100.0% similarity, with 40 matched token, and 0 token mismatch
# ## Model validation for 45 tokens : 100.0% similarity, with 45 matched token, and 0 token mismatch
# ## Model validation for 50 tokens : 100.0% similarity, with 50 matched token, and 0 token mismatch
# ## Model validation for 55 tokens : 100.0% similarity, with 55 matched token, and 0 token mismatch
# ## Model validation for 60 tokens : 100.0% similarity, with 60 matched token, and 0 token mismatch
# ## Model validation for 65 tokens : 100.0% similarity, with 65 matched token, and 0 token mismatch
# ## Model validation for 70 tokens : 100.0% similarity, with 70 matched token, and 0 token mismatch
# ## Model validation for 75 tokens : 100.0% similarity, with 75 matched token, and 0 token mismatch
# ## Model validation for 80 tokens : 100.0% similarity, with 80 matched token, and 0 token mismatch
# ## Model validation for 85 tokens : 100.0% similarity, with 85 matched token, and 0 token mismatch
# ## Model validation for 90 tokens : 100.0% similarity, with 90 matched token, and 0 token mismatch
# ## Model validation for 95 tokens : 100.0% similarity, with 95 matched token, and 0 token mismatch
# ## Model validation for 100 tokens : 100.0% similarity, with 100 matched token, and 0 token mismatch
# ## Model validation for 105 tokens : 100.0% similarity, with 105 matched token, and 0 token mismatch
# ## Model validation for 110 tokens : 100.0% similarity, with 110 matched token, and 0 token mismatch
# ## Model validation for 115 tokens : 100.0% similarity, with 115 matched token, and 0 token mismatch
# ## Model validation for 120 tokens : 100.0% similarity, with 120 matched token, and 0 token mismatch
# ## Model validation for 125 tokens : 100.0% similarity, with 125 matched token, and 0 token mismatch
# ## Model validation for 130 tokens : 100.0% similarity, with 130 matched token, and 0 token mismatch
# ## Model validation for 135 tokens : 100.0% similarity, with 135 matched token, and 0 token mismatch
# ## Model validation for 140 tokens : 100.0% similarity, with 140 matched token, and 0 token mismatch
# ## Model validation for 145 tokens : 100.0% similarity, with 145 matched token, and 0 token mismatch
# ## Model validation for 150 tokens : 100.0% similarity, with 150 matched token, and 0 token mismatch
# ## Model validation for 160 tokens : 100.0% similarity, with 160 matched token, and 0 token mismatch
# ## Model validation for 170 tokens : 100.0% similarity, with 170 matched token, and 0 token mismatch
# ## Model validation for 180 tokens : 99.44444444444444% similarity, with 179 matched token, and 1 token mismatch
# ## Model validation for 190 tokens : 98.94736842105263% similarity, with 188 matched token, and 2 token mismatch
# ## Model validation for 200 tokens : 99.5% similarity, with 199 matched token, and 1 token mismatch
# ## Model validation for 210 tokens : 99.52380952380952% similarity, with 209 matched token, and 1 token mismatch
# ## Model validation for 220 tokens : 99.54545454545455% similarity, with 219 matched token, and 1 token mismatch
# ## Model validation for 230 tokens : 99.1304347826087% similarity, with 228 matched token, and 2 token mismatch
# ## Model validation for 240 tokens : 98.33333333333333% similarity, with 236 matched token, and 4 token mismatch
# ## Model validation for 250 tokens : 98.4% similarity, with 246 matched token, and 4 token mismatch
# ## Model validation for 260 tokens : 98.46153846153847% similarity, with 256 matched token, and 4 token mismatch
# ## Model validation for 270 tokens : 98.88888888888889% similarity, with 267 matched token, and 3 token mismatch
# ## Model validation for 280 tokens : 98.57142857142858% similarity, with 276 matched token, and 4 token mismatch
# ## Model validation for 290 tokens : 98.27586206896551% similarity, with 285 matched token, and 5 token mismatch
# ## Model validation for 300 tokens : 98.33333333333333% similarity, with 295 matched token, and 5 token mismatch
# ## Model validation for 325 tokens : 97.53846153846155% similarity, with 317 matched token, and 8 token mismatch
# ## Model validation for 350 tokens : 97.42857142857143% similarity, with 341 matched token, and 9 token mismatch
# ## Model validation for 375 tokens : 97.06666666666666% similarity, with 364 matched token, and 11 token mismatch
# ## Model validation for 400 tokens : 97.0% similarity, with 388 matched token, and 12 token mismatch
# ## Model validation for 425 tokens : 96.70588235294117% similarity, with 411 matched token, and 14 token mismatch
# ## Model validation for 450 tokens : 95.77777777777777% similarity, with 431 matched token, and 19 token mismatch
# ## Model validation for 475 tokens : 95.36842105263158% similarity, with 453 matched token, and 22 token mismatch
# ## Model validation for 500 tokens : 95.19999999999999% similarity, with 476 matched token, and 24 token mismatch
# ## Model validation for 525 tokens : 94.28571428571428% similarity, with 495 matched token, and 30 token mismatch
# ## Model validation for 550 tokens : 93.0909090909091% similarity, with 512 matched token, and 38 token mismatch
# ## Model validation for 575 tokens : 91.82608695652173% similarity, with 528 matched token, and 47 token mismatch
# ## Model validation for 600 tokens : 90.83333333333333% similarity, with 545 matched token, and 55 token mismatch
# ## Model validation for 625 tokens : 89.12% similarity, with 557 matched token, and 68 token mismatch
# ## Model validation for 650 tokens : 87.53846153846155% similarity, with 569 matched token, and 81 token mismatch
# ## Model validation for 675 tokens : 87.70370370370371% similarity, with 592 matched token, and 83 token mismatch
# ## Model validation for 700 tokens : 87.14285714285714% similarity, with 610 matched token, and 90 token mismatch
# ## Model validation for 750 tokens : 85.86666666666667% similarity, with 644 matched token, and 106 token mismatch
# ## Model validation for 800 tokens : 82.75% similarity, with 662 matched token, and 138 token mismatch
# ## Model validation for 850 tokens : 78.82352941176471% similarity, with 670 matched token, and 180 token mismatch
# ## Model validation for 900 tokens : 75.22222222222223% similarity, with 677 matched token, and 223 token mismatch
# ## Model validation for 950 tokens : 71.36842105263158% similarity, with 678 matched token, and 272 token mismatch
# ## Model validation for 1000 tokens : 67.4% similarity, with 674 matched token, and 326 token mismatch
