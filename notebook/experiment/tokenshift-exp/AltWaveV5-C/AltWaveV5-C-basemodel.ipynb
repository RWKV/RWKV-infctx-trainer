# %% [markdown]
# # RWKV v5 Wavnet C
# This model is based on the RWKV standard 1B5 model
#
# - 24 layers
# - 2048 embedding size
#
# Going through the same memory training process as TokenShift, but using the v5 code
#
# See `./notes.md` for how the init model was initilaized.
#
# **Note:** This project assumes you have the rwkv-infctx conda env setup
#
# ---
#
# ```bash
# # ninja-build is required for the new trainer
# sudo apt-get install ninja-build
#
# # Update conda & its package listings
# # Conda install script can be found here :
# # https://docs.anaconda.com/free/anaconda/install/linux/#installation
# conda update conda
#
# # Virtual env, with python 3.10
# # python 3.11 have issues with torch.compile / h100s
# # and if you want to use 3.11, you will need to do a nightly build install
# conda create -n rwkv-infctx python=3.11 pip
# conda activate rwkv-infctx
#
# # Install pytorch (>=2.0.1)
# conda install -y pytorch==2.0.1 torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
#
# # Verify your pytorch version
# python -c "import torch; print(torch.__version__)"
#
# # We use python -m pip, instead of pip directly, as it resolve issues with venv not loading the right pip
# python -m pip install datasets transformers
# python -m pip install lightning==2.0.4 deepspeed==0.9.5
# python -m pip install ninja numexpr jsonargparse 'jsonargparse[signatures]'
# python -m pip install lm-dataformat ftfy sentencepiece tokenizers wandb
# ```
# ---

# %% [markdown]
# # Basic Setup

# %%
# First lets setup the various directories, and init the model
# !mkdir -p ../../../../model/
# !mkdir -p ../../../../datapath/
# !mkdir -p ../../../../checkpoint/

# Init the model
# !cd ../../../../RWKV-v5altwavenet && python3 ./init_model.py --n_layer 24 --n_embd 2048 --vocab_size neox --skip-if-exists ../model/L24-D2048-neox-v5altwavenet-init.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# ---- Initializing model ----
# No of layers: 24
# Embedding size: 2048
# Output model path: ../model/L24-D2048-neox-v5altwavenet-init.pth
# Vocab size: 50277
# ---- ----- ----
# 50277 2048  -0.0001 emb.weight
# 2048  2048  1.0  blocks.0.att.receptance.weight
# 2048  2048  1.0  blocks.0.att.key.weight
# 2048  2048  1.0  blocks.0.att.value.weight
# 2048  2048  0    blocks.0.att.output.weight
# 8192  2048  1.0  blocks.0.ffn.key.weight
# 2048  2048  0    blocks.0.ffn.receptance.weight
# 2048  8192  0    blocks.0.ffn.value.weight
# 2048  2048  1.0  blocks.1.att.receptance.weight
# 2048  2048  1.0  blocks.1.att.key.weight
# 2048  2048  1.0  blocks.1.att.value.weight
# 2048  2048  0    blocks.1.att.output.weight
# 8192  2048  1.0  blocks.1.ffn.key.weight
# 2048  2048  0    blocks.1.ffn.receptance.weight
# 2048  8192  0    blocks.1.ffn.value.weight
# 2048  2048  1.0  blocks.2.att.receptance.weight
# 2048  2048  1.0  blocks.2.att.key.weight
# 2048  2048  1.0  blocks.2.att.value.weight
# 2048  2048  0    blocks.2.att.output.weight
# 8192  2048  1.0  blocks.2.ffn.key.weight
# 2048  2048  0    blocks.2.ffn.receptance.weight
# 2048  8192  0    blocks.2.ffn.value.weight
# 2048  2048  1.0  blocks.3.att.receptance.weight
# 2048  2048  1.0  blocks.3.att.key.weight
# 2048  2048  1.0  blocks.3.att.value.weight
# 2048  2048  0    blocks.3.att.output.weight
# 8192  2048  1.0  blocks.3.ffn.key.weight
# 2048  2048  0    blocks.3.ffn.receptance.weight
# 2048  8192  0    blocks.3.ffn.value.weight
# 2048  2048  1.0  blocks.4.att.receptance.weight
# 2048  2048  1.0  blocks.4.att.key.weight
# 2048  2048  1.0  blocks.4.att.value.weight
# 2048  2048  0    blocks.4.att.output.weight
# 8192  2048  1.0  blocks.4.ffn.key.weight
# 2048  2048  0    blocks.4.ffn.receptance.weight
# 2048  8192  0    blocks.4.ffn.value.weight
# 2048  2048  1.0  blocks.5.att.receptance.weight
# 2048  2048  1.0  blocks.5.att.key.weight
# 2048  2048  1.0  blocks.5.att.value.weight
# 2048  2048  0    blocks.5.att.output.weight
# 8192  2048  1.0  blocks.5.ffn.key.weight
# 2048  2048  0    blocks.5.ffn.receptance.weight
# 2048  8192  0    blocks.5.ffn.value.weight
# 2048  2048  1.0  blocks.6.att.receptance.weight
# 2048  2048  1.0  blocks.6.att.key.weight
# 2048  2048  1.0  blocks.6.att.value.weight
# 2048  2048  0    blocks.6.att.output.weight
# 8192  2048  1.0  blocks.6.ffn.key.weight
# 2048  2048  0    blocks.6.ffn.receptance.weight
# 2048  8192  0    blocks.6.ffn.value.weight
# 2048  2048  1.0  blocks.7.att.receptance.weight
# 2048  2048  1.0  blocks.7.att.key.weight
# 2048  2048  1.0  blocks.7.att.value.weight
# 2048  2048  0    blocks.7.att.output.weight
# 8192  2048  1.0  blocks.7.ffn.key.weight
# 2048  2048  0    blocks.7.ffn.receptance.weight
# 2048  8192  0    blocks.7.ffn.value.weight
# 2048  2048  1.0  blocks.8.att.receptance.weight
# 2048  2048  1.0  blocks.8.att.key.weight
# 2048  2048  1.0  blocks.8.att.value.weight
# 2048  2048  0    blocks.8.att.output.weight
# 8192  2048  1.0  blocks.8.ffn.key.weight
# 2048  2048  0    blocks.8.ffn.receptance.weight
# 2048  8192  0    blocks.8.ffn.value.weight
# 2048  2048  1.0  blocks.9.att.receptance.weight
# 2048  2048  1.0  blocks.9.att.key.weight
# 2048  2048  1.0  blocks.9.att.value.weight
# 2048  2048  0    blocks.9.att.output.weight
# 8192  2048  1.0  blocks.9.ffn.key.weight
# 2048  2048  0    blocks.9.ffn.receptance.weight
# 2048  8192  0    blocks.9.ffn.value.weight
# 2048  2048  1.0  blocks.10.att.receptance.weight
# 2048  2048  1.0  blocks.10.att.key.weight
# 2048  2048  1.0  blocks.10.att.value.weight
# 2048  2048  0    blocks.10.att.output.weight
# 8192  2048  1.0  blocks.10.ffn.key.weight
# 2048  2048  0    blocks.10.ffn.receptance.weight
# 2048  8192  0    blocks.10.ffn.value.weight
# 2048  2048  1.0  blocks.11.att.receptance.weight
# 2048  2048  1.0  blocks.11.att.key.weight
# 2048  2048  1.0  blocks.11.att.value.weight
# 2048  2048  0    blocks.11.att.output.weight
# 8192  2048  1.0  blocks.11.ffn.key.weight
# 2048  2048  0    blocks.11.ffn.receptance.weight
# 2048  8192  0    blocks.11.ffn.value.weight
# 2048  2048  1.0  blocks.12.att.receptance.weight
# 2048  2048  1.0  blocks.12.att.key.weight
# 2048  2048  1.0  blocks.12.att.value.weight
# 2048  2048  0    blocks.12.att.output.weight
# 8192  2048  1.0  blocks.12.ffn.key.weight
# 2048  2048  0    blocks.12.ffn.receptance.weight
# 2048  8192  0    blocks.12.ffn.value.weight
# 2048  2048  1.0  blocks.13.att.receptance.weight
# 2048  2048  1.0  blocks.13.att.key.weight
# 2048  2048  1.0  blocks.13.att.value.weight
# 2048  2048  0    blocks.13.att.output.weight
# 8192  2048  1.0  blocks.13.ffn.key.weight
# 2048  2048  0    blocks.13.ffn.receptance.weight
# 2048  8192  0    blocks.13.ffn.value.weight
# 2048  2048  1.0  blocks.14.att.receptance.weight
# 2048  2048  1.0  blocks.14.att.key.weight
# 2048  2048  1.0  blocks.14.att.value.weight
# 2048  2048  0    blocks.14.att.output.weight
# 8192  2048  1.0  blocks.14.ffn.key.weight
# 2048  2048  0    blocks.14.ffn.receptance.weight
# 2048  8192  0    blocks.14.ffn.value.weight
# 2048  2048  1.0  blocks.15.att.receptance.weight
# 2048  2048  1.0  blocks.15.att.key.weight
# 2048  2048  1.0  blocks.15.att.value.weight
# 2048  2048  0    blocks.15.att.output.weight
# 8192  2048  1.0  blocks.15.ffn.key.weight
# 2048  2048  0    blocks.15.ffn.receptance.weight
# 2048  8192  0    blocks.15.ffn.value.weight
# 2048  2048  1.0  blocks.16.att.receptance.weight
# 2048  2048  1.0  blocks.16.att.key.weight
# 2048  2048  1.0  blocks.16.att.value.weight
# 2048  2048  0    blocks.16.att.output.weight
# 8192  2048  1.0  blocks.16.ffn.key.weight
# 2048  2048  0    blocks.16.ffn.receptance.weight
# 2048  8192  0    blocks.16.ffn.value.weight
# 2048  2048  1.0  blocks.17.att.receptance.weight
# 2048  2048  1.0  blocks.17.att.key.weight
# 2048  2048  1.0  blocks.17.att.value.weight
# 2048  2048  0    blocks.17.att.output.weight
# 8192  2048  1.0  blocks.17.ffn.key.weight
# 2048  2048  0    blocks.17.ffn.receptance.weight
# 2048  8192  0    blocks.17.ffn.value.weight
# 2048  2048  1.0  blocks.18.att.receptance.weight
# 2048  2048  1.0  blocks.18.att.key.weight
# 2048  2048  1.0  blocks.18.att.value.weight
# 2048  2048  0    blocks.18.att.output.weight
# 8192  2048  1.0  blocks.18.ffn.key.weight
# 2048  2048  0    blocks.18.ffn.receptance.weight
# 2048  8192  0    blocks.18.ffn.value.weight
# 2048  2048  1.0  blocks.19.att.receptance.weight
# 2048  2048  1.0  blocks.19.att.key.weight
# 2048  2048  1.0  blocks.19.att.value.weight
# 2048  2048  0    blocks.19.att.output.weight
# 8192  2048  1.0  blocks.19.ffn.key.weight
# 2048  2048  0    blocks.19.ffn.receptance.weight
# 2048  8192  0    blocks.19.ffn.value.weight
# 2048  2048  1.0  blocks.20.att.receptance.weight
# 2048  2048  1.0  blocks.20.att.key.weight
# 2048  2048  1.0  blocks.20.att.value.weight
# 2048  2048  0    blocks.20.att.output.weight
# 8192  2048  1.0  blocks.20.ffn.key.weight
# 2048  2048  0    blocks.20.ffn.receptance.weight
# 2048  8192  0    blocks.20.ffn.value.weight
# 2048  2048  1.0  blocks.21.att.receptance.weight
# 2048  2048  1.0  blocks.21.att.key.weight
# 2048  2048  1.0  blocks.21.att.value.weight
# 2048  2048  0    blocks.21.att.output.weight
# 8192  2048  1.0  blocks.21.ffn.key.weight
# 2048  2048  0    blocks.21.ffn.receptance.weight
# 2048  8192  0    blocks.21.ffn.value.weight
# 2048  2048  1.0  blocks.22.att.receptance.weight
# 2048  2048  1.0  blocks.22.att.key.weight
# 2048  2048  1.0  blocks.22.att.value.weight
# 2048  2048  0    blocks.22.att.output.weight
# 8192  2048  1.0  blocks.22.ffn.key.weight
# 2048  2048  0    blocks.22.ffn.receptance.weight
# 2048  8192  0    blocks.22.ffn.value.weight
# 2048  2048  1.0  blocks.23.att.receptance.weight
# 2048  2048  1.0  blocks.23.att.key.weight
# 2048  2048  1.0  blocks.23.att.value.weight
# 2048  2048  0    blocks.23.att.output.weight
# 8192  2048  1.0  blocks.23.ffn.key.weight
# 2048  2048  0    blocks.23.ffn.receptance.weight
# 2048  8192  0    blocks.23.ffn.value.weight
# 50277 2048  0.5  head.weight

# %%
DEEPSPEED_STRAT="deepspeed_stage_1"
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="AltWaveV5-C"

print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5altwavenet/"))
INFERENCE_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5altwavenet/"))

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("INFERENCE_DIR:", INFERENCE_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# DEEPSPEED_STRAT: deepspeed_stage_1
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /root/rwkv-x-playground/notebook/experiment/tokenshift-exp/AltWaveV5-C
# INFERENCE_DIR: /root/rwkv-x-playground/RWKV-v5altwavenet
# TRAINER_DIR: /root/rwkv-x-playground/RWKV-v5altwavenet
# PROJECT_DIR: /root/rwkv-x-playground

# %% [markdown]
# ## Stage 1 : Foundation model training

# %%
# Lets preload the requried dataset (enwiki_100k)
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/AltWaveV5-C-enwiki.yaml"
# Out:
# Found cached dataset parquet (/root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  3.67it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-f7b060a194034cc1_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-5130e0b5cfea4510_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-8cf337c8a178675e_*_of_00064.arrow
# Loading cached split indices for dataset at /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-54959cfaa7f1c967.arrow and /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-b4bfa876eaace3ed.arrow

# %%
# Start the foundation model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/AltWaveV5-C-enwiki.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Enwiki Foundation (ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py:484: UserWarning: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/root/rwkv-x-playground/notebook/experiment/tokenshift-exp/AltWaveV5-C/AltWaveV5-C-enwiki.yaml', '--trainer.logger.init_args.name=AltWaveV5-C - Enwiki Foundation (ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto'], args=['fit', '-c', '/root/rwkv-x-playground/notebook/experiment/tokenshift-exp/AltWaveV5-C/AltWaveV5-C-enwiki.yaml', '--trainer.logger.init_args.name=AltWaveV5-C - Enwiki Foundation (ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto'].
#   rank_zero_warn(
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 308861138
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 308861138
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230808_075958-303rkf67
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run AltWaveV5-C - Enwiki Foundation (ctx=4096, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/303rkf67
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       32
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 4
#    - effective_batch_size:    32
#
# Found cached dataset parquet (/root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 78.84it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-f7b060a194034cc1_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-5130e0b5cfea4510_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-8cf337c8a178675e_*_of_00064.arrow
# Loading cached split indices for dataset at /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-54959cfaa7f1c967.arrow and /root/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-b4bfa876eaace3ed.arrow
# Saving the dataset (1/5 shards):  20%|▏| 16298/81487 [00:00<00:01, 36746.54 examSetting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Saving the dataset (1/5 shards):  38%|▍| 31298/81487 [00:00<00:01, 38406.61 exam[RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Saving the dataset (3/5 shards):  71%|▋| 57893/81487 [00:01<00:00, 37003.02 exam[rank: 3] Global seed set to 308861138
# [rank: 6] Global seed set to 308861138
# [rank: 2] Global seed set to 308861138
# [rank: 4] Global seed set to 308861138
# [rank: 1] Global seed set to 308861138
# Saving the dataset (3/5 shards):  78%|▊| 63893/81487 [00:01<00:00, 39975.78 exam[rank: 7] Global seed set to 308861138
# [rank: 5] Global seed set to 308861138
# [rank: 0] Global seed set to 308861138
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-08-08 08:00:15,246] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 308861138
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-08-08 08:00:31,272] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 308861138
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-08-08 08:00:31,708] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 308861138
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-08-08 08:00:31,730] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 3] Global seed set to 308861138
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-08-08 08:00:31,737] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 308861138
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-08-08 08:00:31,772] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 308861138
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-08-08 08:00:31,776] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 6] Global seed set to 308861138
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-08-08 08:00:31,781] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  6.000e-04 (0.0006)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.0711050033569336 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10171627998352051 seconds
# Time to load fused_adam op: 0.10123848915100098 seconds
# Time to load fused_adam op: 0.10156440734863281 seconds
# Time to load fused_adam op: 0.1016380786895752 seconds
# Time to load fused_adam op: 0.10146737098693848 seconds
# Time to load fused_adam op: 0.10157012939453125 seconds
# Time to load fused_adam op: 0.10149860382080078 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.07463860511779785 seconds
# Loading extension module utils...
# Time to load utils op: 0.10190296173095703 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10111284255981445 seconds
# Time to load utils op: 0.10169291496276855 seconds
# Time to load utils op: 0.10200381278991699 seconds
# Time to load utils op: 0.10159730911254883 seconds
# Time to load utils op: 0.10151791572570801 seconds
# Time to load utils op: 0.10171008110046387 seconds
# Rank: 0 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 4 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 3 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 7 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 2 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 6 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 5 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 1 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002722740173339844 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00023317337036132812 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003590583801269531 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003516674041748047 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003502368927001953 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00029850006103515625 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00036597251892089844 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005495548248291016 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.431 Total estimated model params size (MB)
# Epoch 0:  10%| | 1000/10186 [43:22<6:38:29,  2.60s/it, v_num=kf67, train/loss=5./usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 10186/10186 [7:25:21<00:00,  2.62s/it, v_num=kf67, train/loss=3
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/52 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/52 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/52 [00:00<00:27,  1.85it/s]
# Validation DataLoader 0:   4%|▋                  | 2/52 [00:01<00:26,  1.91it/s]
# Validation DataLoader 0:   6%|█                  | 3/52 [00:01<00:25,  1.92it/s]
# Validation DataLoader 0:   8%|█▍                 | 4/52 [00:02<00:24,  1.94it/s]
# Validation DataLoader 0:  10%|█▊                 | 5/52 [00:02<00:24,  1.95it/s]
# Validation DataLoader 0:  12%|██▏                | 6/52 [00:03<00:23,  1.95it/s]
# Validation DataLoader 0:  13%|██▌                | 7/52 [00:03<00:23,  1.96it/s]
# Validation DataLoader 0:  15%|██▉                | 8/52 [00:04<00:22,  1.96it/s]
# Validation DataLoader 0:  17%|███▎               | 9/52 [00:04<00:21,  1.96it/s]
# Validation DataLoader 0:  19%|███▍              | 10/52 [00:05<00:21,  1.96it/s]
# Validation DataLoader 0:  21%|███▊              | 11/52 [00:05<00:20,  1.96it/s]
# Validation DataLoader 0:  23%|████▏             | 12/52 [00:06<00:20,  1.96it/s]
# Validation DataLoader 0:  25%|████▌             | 13/52 [00:06<00:19,  1.96it/s]
# Validation DataLoader 0:  27%|████▊             | 14/52 [00:07<00:19,  1.96it/s]
# Validation DataLoader 0:  29%|█████▏            | 15/52 [00:07<00:18,  1.96it/s]
# Validation DataLoader 0:  31%|█████▌            | 16/52 [00:08<00:18,  1.96it/s]
# Validation DataLoader 0:  33%|█████▉            | 17/52 [00:08<00:17,  1.96it/s]
# Validation DataLoader 0:  35%|██████▏           | 18/52 [00:09<00:17,  1.96it/s]
# Validation DataLoader 0:  37%|██████▌           | 19/52 [00:09<00:16,  1.96it/s]
# Validation DataLoader 0:  38%|██████▉           | 20/52 [00:10<00:16,  1.96it/s]
# Validation DataLoader 0:  40%|███████▎          | 21/52 [00:10<00:15,  1.96it/s]
# Validation DataLoader 0:  42%|███████▌          | 22/52 [00:11<00:15,  1.96it/s]
# Validation DataLoader 0:  44%|███████▉          | 23/52 [00:11<00:14,  1.96it/s]
# Validation DataLoader 0:  46%|████████▎         | 24/52 [00:12<00:14,  1.96it/s]
# Validation DataLoader 0:  48%|████████▋         | 25/52 [00:12<00:13,  1.96it/s]
# Validation DataLoader 0:  50%|█████████         | 26/52 [00:13<00:13,  1.96it/s]
# Validation DataLoader 0:  52%|█████████▎        | 27/52 [00:13<00:12,  1.96it/s]
# Validation DataLoader 0:  54%|█████████▋        | 28/52 [00:14<00:12,  1.96it/s]
# Validation DataLoader 0:  56%|██████████        | 29/52 [00:14<00:11,  1.96it/s]
# Validation DataLoader 0:  58%|██████████▍       | 30/52 [00:15<00:11,  1.95it/s]
# Validation DataLoader 0:  60%|██████████▋       | 31/52 [00:15<00:10,  1.96it/s]
# Validation DataLoader 0:  62%|███████████       | 32/52 [00:16<00:10,  1.96it/s]
# Validation DataLoader 0:  63%|███████████▍      | 33/52 [00:16<00:09,  1.96it/s]
# Validation DataLoader 0:  65%|███████████▊      | 34/52 [00:17<00:09,  1.96it/s]
# Validation DataLoader 0:  67%|████████████      | 35/52 [00:17<00:08,  1.96it/s]
# Validation DataLoader 0:  69%|████████████▍     | 36/52 [00:18<00:08,  1.96it/s]
# Validation DataLoader 0:  71%|████████████▊     | 37/52 [00:18<00:07,  1.96it/s]
# Validation DataLoader 0:  73%|█████████████▏    | 38/52 [00:19<00:07,  1.96it/s]
# Validation DataLoader 0:  75%|█████████████▌    | 39/52 [00:19<00:06,  1.96it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 40/52 [00:20<00:06,  1.96it/s]
# Validation DataLoader 0:  79%|██████████████▏   | 41/52 [00:20<00:05,  1.96it/s]
# Validation DataLoader 0:  81%|██████████████▌   | 42/52 [00:21<00:05,  1.96it/s]
# Validation DataLoader 0:  83%|██████████████▉   | 43/52 [00:21<00:04,  1.96it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 44/52 [00:22<00:04,  1.96it/s]
# Validation DataLoader 0:  87%|███████████████▌  | 45/52 [00:22<00:03,  1.96it/s]
# Validation DataLoader 0:  88%|███████████████▉  | 46/52 [00:23<00:03,  1.96it/s]
# Validation DataLoader 0:  90%|████████████████▎ | 47/52 [00:23<00:02,  1.96it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 48/52 [00:24<00:02,  1.96it/s]
# Validation DataLoader 0:  94%|████████████████▉ | 49/52 [00:25<00:01,  1.96it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 50/52 [00:25<00:01,  1.96it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 51/52 [00:26<00:00,  1.96it/s]
# Epoch 0: 100%|█| 10186/10186 [7:25:55<00:00,  2.63s/it, v_num=kf67, train/loss=3
# Epoch 0: 100%|█| 10186/10186 [7:25:55<00:00,  2.63s/it, v_num=kf67, train/loss=3`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 10186/10186 [7:26:07<00:00,  2.63s/it, v_num=kf67, train/loss=3
# wandb: Waiting for W&B process to finish... (success).
# wandb: - 0.009 MB of 0.009 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss █▇▆▅▄▅▄▃▄▄▃▃▄▃▃▃▃▃▃▃▂▃▂▃▃▃▂▂▂▃▂▂▂▂▁▂▃▂▂▁
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 51
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 4095
# wandb:               substep 408
# wandb:            train/loss 3.84375
# wandb:   trainer/global_step 2546
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 3.51769
# wandb:
# wandb: 🚀 View run AltWaveV5-C - Enwiki Foundation (ctx=4096, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/303rkf67
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230808_075958-303rkf67/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/AltWaveV5-C-enwiki/last.ckpt" "../model/AltWaveV5-C-Stage1.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/AltWaveV5-C-Stage1.pth"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/AltWaveV5-C-enwiki/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 486 params 1515107840 elements
# Saving fp32 state dict to ../model/AltWaveV5-C-Stage1.pth
# -rw-r--r-- 1 root root 5.7G Aug  8 15:27 ../model/AltWaveV5-C-Stage1.pth

# %%
# # Lets do a quick dragon prompt validation
# !cd "{INFERENCE_DIR}" && python3 dragon_test.py ../model/AltWaveV5-C-Stage1.pth "cuda fp32"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# --- DRAGON PROMPT ---
# In a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese. The researchers had tried to reconstruct this by searching for more and more deer, but discovered that these seals had been covered by the Danish cougars, and that the possibility that they were unlikely to reach a common ancestor could have been more of a threat than the king's hunting of cattle. However, a more recent scenario of this explanation is presented in the German historian and researcher Ernst Wolfgang von Hölling, who was in Berlin at the time the prefect of the Norwegian crown prince.
#
# The Ráklind Kordalind Kordalind Kordalind proxy was among the earliest known searches of the Thracian Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kordalind Kord

# %%
# # Lets do a quick memory test
# # (We dun expect this to work, as we have not finetune for memory recall, but its a baseline)
# !python3 ../memory_script/eval_v5_memory_guided.py "{PROJECT_DIR}/model/AltWaveV5-C-Stage1.pth"

# %% [markdown]
# # Stage 2 : Instruct Tuning

# %%
# Lets preload the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/AltWaveV5-C-instruct.yaml"
# Out:
# Found cached dataset parquet (/root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 541.48it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-e4df40d582f09838_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-6d5405ad1f265e84_*_of_00064.arrow
# Loading cached split indices for dataset at /root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-9f578061a1feb072.arrow and /root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-f0249c95fb8af247.arrow

# %%
# Start the instruct finetuning
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/AltWaveV5-C-instruct.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Instruct (train-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py:484: UserWarning: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/root/rwkv-x-playground/notebook/experiment/tokenshift-exp/AltWaveV5-C/AltWaveV5-C-instruct.yaml', '--trainer.logger.init_args.name=AltWaveV5-C - Instruct (train-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto'], args=['fit', '-c', '/root/rwkv-x-playground/notebook/experiment/tokenshift-exp/AltWaveV5-C/AltWaveV5-C-instruct.yaml', '--trainer.logger.init_args.name=AltWaveV5-C - Instruct (train-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto'].
#   rank_zero_warn(
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 3977103680
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 3977103680
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230808_152843-8898dzax
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run AltWaveV5-C - Instruct (train-ctx=4096, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/8898dzax
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       32
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 4
#    - effective_batch_size:    32
#
# Found cached dataset parquet (/root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 780.92it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-e4df40d582f09838_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-6d5405ad1f265e84_*_of_00064.arrow
# Loading cached split indices for dataset at /root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-9f578061a1feb072.arrow and /root/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-f0249c95fb8af247.arrow
# [rank: 0] Global seed set to 3977103680
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-08-08 15:28:58,342] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [rank: 1] Global seed set to 3977103680
# [rank: 6] Global seed set to 3977103680
# [rank: 5] Global seed set to 3977103680
# [rank: 7] Global seed set to 3977103680
# [rank: 3] Global seed set to 3977103680
# [rank: 2] Global seed set to 3977103680
# [rank: 4] Global seed set to 3977103680
# [rank: 6] Global seed set to 3977103680
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-08-08 15:29:18,503] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 3977103680
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-08-08 15:29:19,012] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 3] Global seed set to 3977103680
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-08-08 15:29:19,038] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 3977103680
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-08-08 15:29:19,057] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 3977103680
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-08-08 15:29:19,110] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 3977103680
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-08-08 15:29:19,111] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 3977103680
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-08-08 15:29:19,118] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  4.000e-04 (0.0004)
#     - lr_final: 3.000e-04 (0.0003)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.07129144668579102 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10116696357727051 seconds
# Time to load fused_adam op: 0.10116696357727051 seconds
# Time to load fused_adam op: 0.10134243965148926 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading `train_dataloader` to estimate number of stepping batches.
# Time to load fused_adam op: 0.1021566390991211 seconds
# Time to load fused_adam op: 0.10210347175598145 seconds
# Time to load fused_adam op: 0.10210943222045898 seconds
# Time to load fused_adam op: 0.10211539268493652 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.07247662544250488 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10138320922851562 seconds
# Loading extension module utils...
# Time to load utils op: 0.10199689865112305 seconds
# Time to load utils op: 0.10168194770812988 seconds
# Time to load utils op: 0.1019902229309082 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10170984268188477 seconds
# Time to load utils op: 0.1019594669342041 seconds
# Time to load utils op: 0.10162091255187988 seconds
# Rank: 0 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 6 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 1 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 2 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 7 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 5 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 3 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Rank: 4 partition count [8, 8] and sizes[(189388288, False), (192, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00027441978454589844 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Time to load utils op: 0.0002732276916503906 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00027298927307128906 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00022840499877929688 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00022745132446289062 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Time to load utils op: 0.00036072731018066406 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002841949462890625 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00047898292541503906 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.431 Total estimated model params size (MB)
# Epoch 0:  54%|▌| 1000/1867 [18:46<16:17,  1.13s/it, v_num=dzax, train/loss=2.860/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 1867/1867 [34:22<00:00,  1.10s/it, v_num=dzax, train/loss=2.660
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:  10%|█▉                 | 1/10 [00:00<00:02,  4.00it/s]
# Validation DataLoader 0:  20%|███▊               | 2/10 [00:00<00:01,  4.56it/s]
# Validation DataLoader 0:  30%|█████▋             | 3/10 [00:00<00:01,  4.69it/s]
# Validation DataLoader 0:  40%|███████▌           | 4/10 [00:00<00:01,  4.84it/s]
# Validation DataLoader 0:  50%|█████████▌         | 5/10 [00:01<00:01,  4.93it/s]
# Validation DataLoader 0:  60%|███████████▍       | 6/10 [00:01<00:00,  4.99it/s]
# Validation DataLoader 0:  70%|█████████████▎     | 7/10 [00:01<00:00,  5.05it/s]
# Validation DataLoader 0:  80%|███████████████▏   | 8/10 [00:01<00:00,  5.06it/s]
# Validation DataLoader 0:  90%|█████████████████  | 9/10 [00:01<00:00,  5.13it/s]
# Epoch 0: 100%|█| 1867/1867 [34:31<00:00,  1.11s/it, v_num=dzax, train/loss=2.660
# Epoch 0: 100%|█| 1867/1867 [34:31<00:00,  1.11s/it, v_num=dzax, train/loss=2.660`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 1867/1867 [34:47<00:00,  1.12s/it, v_num=dzax, train/loss=2.660
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▅▁▃▁█▅▂▆▁▁▁▂▁▁▁▁▃▂▅▁▁▁▁▂▂▃▁▅▂▂▁▂▂▁▄▁▁▂▃▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:            train/loss ▇▇▆▃▄▄▅▁▄▃▂▃█▅▅▄▁▄▄▇▄▄▄▅▅▄▅▆▅▅▆▃▆▂▆▄▂▃▆▅
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 9
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 85
# wandb:               substep 72
# wandb:            train/loss 3.65625
# wandb:   trainer/global_step 466
# wandb: trainer/learning_rate 0.0003
# wandb:       validation/loss 3.10767
# wandb:
# wandb: 🚀 View run AltWaveV5-C - Instruct (train-ctx=4096, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/8898dzax
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230808_152843-8898dzax/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/AltWaveV5-C-instruct/last.ckpt" "../model/AltWaveV5-C-Stage2.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/AltWaveV5-C-Stage2.pth"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/AltWaveV5-C-instruct/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 486 params 1515107840 elements
# Saving fp32 state dict to ../model/AltWaveV5-C-Stage2.pth
# -rw-r--r-- 1 root root 5.7G Aug  8 16:05 ../model/AltWaveV5-C-Stage2.pth

# %%
# Lets do a quick dragon prompt validation
# !cd "{INFERENCE_DIR}" && python3 dragon_test.py "../model/AltWaveV5-C-Stage2.pth" "cuda fp32"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# --- DRAGON PROMPT ---
# In a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese. They can't do so because they're indeed afraid of the ones living in the wilderness. For example, the wolves will likely never find the monsters in a single circle. The wolves were able to answer the question of how long the platypus and the swallows they ate. The cats did not understand why the fox got the name "watch" and the fox would look out like a tiger in the leaves of the wolf. The dog's prey then died in the forest. The cat may no longer call the snakes. The owner's animal would have done a hunt, and if it was still friendly, the fox would attack the fox in the game. The cacodua group called the Tiger in the forest. The fox was able to make a pack of ground beef that the fox would look after. The fox may have died in the wildfire of the wolf. The fox would suggest the wolf would travel with the goat to hunt the deer as a pack of cattle. The dog would

# %%
# # Lets do a quick memory test
# # (We dun expect this to work, as we have not finetune for memory recall, but its a baseline)
# !python3 ../memory_script/eval_v5_memory_guided.py "{PROJECT_DIR}/model/AltWaveV5-C-Stage2.pth"
