# %% [markdown]
# # RWKV Token Shift Experiment A (Memory Finetune)
# This continues off from `./TokenShift-A-basemodel.ipynb` to perform the full memory finetune & testing process
#
# This is done generally in 3 Tune stages
# - Tune 1: Low ctx size (512), Training with only the input masked. This does very limited memory training, and is used primarily to train the instruction set.
# - Tune 2: Low ctx size (512), Training with instruction & input masked. This forces the actual memory training on the output tokens.
# - Tune 3: Mid ctx size (1024), stage 2, scaled up to 1024 context sizes.
# - Tune 4: Mid ctx size (4096), stage 3, scaled up to 4096 context sizes.
#
# In all cases, the input tokens is always masked. And we intentionally use the limited word set for memory training, which matches the same wordset used in the original memory evaluation of raven pretrained models. This is intentional to serve as both consistent comparision between experiments, and resonable training time.
#
# One of the issue faced previously with an excessive large word set, is that the model would be required to see "new words" atleast a few time before being able to train the memory process. This drastically slowed down the process as the large word list meant the model was constantly spending time learning new words (instead of memory training).
#
# If we want to increase the number / type of words the model can handle for memory training, that can be done later as a stage 4 memory tune if needed. But that exceeds the current requirements for the memory experiment process.
#
# > This project assumes you have the rwkv-infctx conda env setup, and you are executing in that environment - see the main README.md for the conda env setup steps

# %% [markdown]
# ## Optional: Download the pretrained model
# (if you want to skip the the basemodel train + instruct tune)

# %%
# # Init required dirs
# !mkdir -p ../../../../model/
# !mkdir -p ../../../../datapath/
# !mkdir -p ../../../../checkpoint/

# # Download the Stage2.pth file
# !rm -rf ../../../../model/TokenShift-A-Stage2.pth
# !cd ../../../../model/ && wget -nc https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/TokenShift-A-Stage2.pth
# !ls -alh ../../../../model/TokenShift-A-Stage2.pth

# %% [markdown]
# ## Configure your environment settings
# (!Important: you will need to rerun the below cell, if you restart your kernel)

# %%
DEEPSPEED_STRAT="deepspeed_stage_1"
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="TokenShift-A"

print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v4wavenet/"))

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# DEEPSPEED_STRAT: deepspeed_stage_1
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /root/rwkv5x-tokenshift-exp-A/notebook/experiment/tokenshift-exp
# TRAINER_DIR: /root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet
# PROJECT_DIR: /root/rwkv5x-tokenshift-exp-A

# %% [markdown]
# ## Tune 1 : Simple Memory instruct finetuning
#
# - Tune 1: Low ctx size (512), Training with only the input masked. This does very limited memory training, and is used primarily to train the instruction set.

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# # We do a strong bias for smaller word count, to teach the concept from scratch
# # so that the model can learn the function.
# #
# # Note that all document samples, are randomized between the target word count,
# # to half of the target word count.
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-2-count.jsonl  2  5000 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-5-count.jsonl  5  5000 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-10-count.jsonl 10 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-15-count.jsonl 15 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-20-count.jsonl 20 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-25-count.jsonl 25 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-40-count.jsonl 40 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-50-count.jsonl 50 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-60-count.jsonl 80 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-80-count.jsonl 80 2500 &
#
# # With a slight mix of the larger word count
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-100-count.jsonl 100 2500 &
# python ../memory_script/gen_limited_segmented_jsonl.py ../dataset/word-200-count.jsonl 200 2500 &
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated JSONL file with - 10 max words, 2500 samples - at ../dataset/word-10-count.jsonl
# Generated JSONL file with - 15 max words, 2500 samples - at ../dataset/word-15-count.jsonl
# Generated JSONL file with - 2 max words, 5000 samples - at ../dataset/word-2-count.jsonl
# Generated JSONL file with - 25 max words, 2500 samples - at ../dataset/word-25-count.jsonl
# Generated JSONL file with - 5 max words, 5000 samples - at ../dataset/word-5-count.jsonl
# Generated JSONL file with - 40 max words, 2500 samples - at ../dataset/word-40-count.jsonl
# Generated JSONL file with - 50 max words, 2500 samples - at ../dataset/word-50-count.jsonl
# Generated JSONL file with - 20 max words, 2500 samples - at ../dataset/word-20-count.jsonl
# Generated JSONL file with - 80 max words, 2500 samples - at ../dataset/word-60-count.jsonl
# Generated JSONL file with - 100 max words, 2500 samples - at ../dataset/word-100-count.jsonl
# Generated JSONL file with - 80 max words, 2500 samples - at ../dataset/word-80-count.jsonl
# Generated JSONL file with - 200 max words, 2500 samples - at ../dataset/word-200-count.jsonl
# ## Done ##
# total 21M
# drwxr-xr-x 2 root root  330 Jul 15 15:00 .
# drwxr-xr-x 6 root root 4.0K Jul 15 14:59 ..
# -rw-r--r-- 1 root root 614K Jul 15 15:00 word-10-count.jsonl
# -rw-r--r-- 1 root root 2.8M Jul 15 15:00 word-100-count.jsonl
# -rw-r--r-- 1 root root 724K Jul 15 15:00 word-15-count.jsonl
# -rw-r--r-- 1 root root 838K Jul 15 15:00 word-2-count.jsonl
# -rw-r--r-- 1 root root 850K Jul 15 15:00 word-20-count.jsonl
# -rw-r--r-- 1 root root 5.2M Jul 15 15:00 word-200-count.jsonl
# -rw-r--r-- 1 root root 966K Jul 15 15:00 word-25-count.jsonl
# -rw-r--r-- 1 root root 1.4M Jul 15 15:00 word-40-count.jsonl
# -rw-r--r-- 1 root root 967K Jul 15 15:00 word-5-count.jsonl
# -rw-r--r-- 1 root root 1.6M Jul 15 15:00 word-50-count.jsonl
# -rw-r--r-- 1 root root 2.3M Jul 15 15:00 word-60-count.jsonl
# -rw-r--r-- 1 root root 2.3M Jul 15 15:00 word-80-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-A-mem-finetune-1.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-A-mem-finetune-1/"
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-248374da0b936b0e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|███████████████████| 1/1 [00:00<00:00, 6710.89it/s]
# Extracting data files: 100%|█████████████████████| 1/1 [00:00<00:00, 243.94it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-248374da0b936b0e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 349.32it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-A-mem-finetune-1.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-1 (bs=256, train-ctx=512, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=512
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 3204158003
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 3204158003
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230715_150021-ty4q0dit
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run TokenShift-A - Mem-Finetune-1 (bs=256, train-ctx=512, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/ty4q0dit
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-248374da0b936b0e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 383.01it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-248374da0b936b0e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-e572802ff6d91321_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-248374da0b936b0e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-7eb1dc89687ef4f7_*_of_00064.arrow
# [rank: 0] Global seed set to 3204158003
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-15 15:00:32,842] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [rank: 3] Global seed set to 3204158003
# [rank: 7] Global seed set to 3204158003
# [rank: 4] Global seed set to 3204158003
# [rank: 1] Global seed set to 3204158003
# [rank: 2] Global seed set to 3204158003
# [rank: 5] Global seed set to 3204158003
# [rank: 6] Global seed set to 3204158003
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# [rank: 3] Global seed set to 3204158003
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-15 15:00:45,752] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 3204158003
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-07-15 15:00:47,122] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 3204158003
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-15 15:00:48,272] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 6] Global seed set to 3204158003
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-15 15:00:48,308] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 3204158003
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-15 15:00:48,331] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 3204158003
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-15 15:00:48,342] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 3204158003
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-15 15:00:48,344] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 5.000e-04 (0.0005)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.0629432201385498 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10141539573669434 seconds
# Time to load fused_adam op: 0.10141992568969727 seconds
# Time to load fused_adam op: 0.10138535499572754 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10131621360778809 seconds
# Time to load fused_adam op: 0.10173511505126953 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Time to load fused_adam op: 0.10178208351135254 seconds
# Time to load fused_adam op: 0.10178065299987793 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.06490588188171387 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10177087783813477 seconds
# Loading extension module utils...
# Time to load utils op: 0.10184836387634277 seconds
# Time to load utils op: 0.1020956039428711 seconds
# Time to load utils op: 0.10180974006652832 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10141897201538086 seconds
# Time to load utils op: 0.1015629768371582 seconds
# Time to load utils op: 0.1015312671661377 seconds
# Rank: 1 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 4 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 0 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 7 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 3 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Time to load utils op: 0.0002601146697998047 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00025200843811035156 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.000247955322265625 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002906322479248047 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.000213623046875 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00034809112548828125 seconds
# Time to load utils op: 0.0003554821014404297 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005235671997070312 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 128 M
# 1 | blocks | ModuleList | 1.0 B
# 2 | ln_out | LayerNorm  | 5.1 K
# 3 | head   | Linear     | 128 M
# --------------------------------------
# 1.3 B     Trainable params
# 0         Non-trainable params
# 1.3 B     Total params
# 5,120.512 Total estimated model params size (MB)
# Epoch 0:  18%|▏| 800/4371 [04:04<18:13,  3.27it/s, v_num=0dit, train/loss=5.940]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 4371/4371 [22:34<00:00,  3.23it/s, v_num=0dit, train/loss=4.940
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/5 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▃▂▁▂▂▁▇▁▁▁▁▄▂▂▂▇█▄▃▁▄▃▁▃▇▃▁▂▂▇▁▂▂▁▂▁▁▁▅▂
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss █▇▃▄▇▃▄▃▅▆▂▇▄▁▂▇▃▆▃▁▄▁▁▂▆▆▁▆▃▂▁▁▃▇▃▂▅▁▄▆
# wandb:   trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 4370
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 142
# wandb:               substep 34960
# wandb:            train/loss 4.9375
# wandb:   trainer/global_step 136
# wandb: trainer/learning_rate 0.0005
# wandb:
# wandb: 🚀 View run TokenShift-A - Mem-Finetune-1 (bs=256, train-ctx=512, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/ty4q0dit
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230715_150021-ty4q0dit/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-A-mem-finetune-1/last.ckpt" \
        "../model/TokenShift-A-Tune1.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-A-Tune1.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-A-mem-finetune-1/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 222 params 1280128000 elements
# Saving fp32 state dict to ../model/TokenShift-A-Tune1.pth
# -rw-r--r-- 1 root root 4.8G Jul 15 15:24 ../model/TokenShift-A-Tune1.pth

# %%
# Lets do a memory eval
#
# Note that the expected performance "is not that great", as the model seems to be only loosely
# learning the memorization task, and the instruction propmt. And is seem to be acting more
# like an RNG based on the instruct. (Instead of the actual memorization task)
# !python3 ../memory_script/eval_memory_guided.py "{PROJECT_DIR}/model/TokenShift-A-Tune1.pth"
# Out:
# RWKV_HEAD_QK_DIM 0 RWKV_JIT_ON 1
#
# blocks.0.att.key.weight                  float32    cuda:0
# blocks.0.att.output.weight               float32    cuda:0
# blocks.0.att.receptance.weight           float32    cuda:0
# blocks.0.att.time_mix_k                  float32    cuda:0
# blocks.0.att.time_mix_r                  float32    cuda:0
# blocks.0.att.time_mix_v                  float32    cuda:0
# blocks.0.att.value.weight                float32    cuda:0
# blocks.0.ffn.key.weight                  float32    cuda:0
# blocks.0.ffn.receptance.weight           float32    cuda:0
# blocks.0.ffn.time_mix_k                  float32    cuda:0
# blocks.0.ffn.time_mix_r                  float32    cuda:0
# blocks.0.ffn.value.weight                float32    cuda:0
# blocks.0.ln0.bias                        float32    cuda:0
# blocks.0.ln0.weight                      float32    cuda:0
# blocks.0.ln1.bias                        float32    cuda:0
# blocks.0.ln1.weight                      float32    cuda:0
# blocks.0.ln2.bias                        float32    cuda:0
# blocks.0.ln2.weight                      float32    cuda:0
# ................................................................................................................................................................................
# emb.weight                               float32    cpu
# head.weight                              float32    cuda:0
# ln_out.bias                              float32    cuda:0
# ln_out.weight                            float32    cuda:0
# blocks.0.att.time_decay                  float32    cuda:0
# ...........
# blocks.0.att.time_first                  float32    cuda:0
# ...........###
# ### Model validation start ###
# ###
# Model validation at 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# Model validation at 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# Model validation at 15 tokens : 66.66666666666666% similarity, with 10 matched token, and 5 token mismatch
# Model validation at 20 tokens : 55.00000000000001% similarity, with 11 matched token, and 9 token mismatch
# Model validation at 25 tokens : 40.0% similarity, with 10 matched token, and 15 token mismatch
# Model validation at 30 tokens : 30.0% similarity, with 9 matched token, and 21 token mismatch
# Model validation at 35 tokens : 22.857142857142858% similarity, with 8 matched token, and 27 token mismatch
# Model validation at 40 tokens : 20.0% similarity, with 8 matched token, and 32 token mismatch
# Model validation at 45 tokens : 17.77777777777778% similarity, with 8 matched token, and 37 token mismatch
# Model validation at 50 tokens : 18.0% similarity, with 9 matched token, and 41 token mismatch
# Model validation at 55 tokens : 14.545454545454545% similarity, with 8 matched token, and 47 token mismatch
# Model validation at 60 tokens : 16.666666666666664% similarity, with 10 matched token, and 50 token mismatch
# Model validation at 65 tokens : 15.384615384615385% similarity, with 10 matched token, and 55 token mismatch
# Model validation at 70 tokens : 11.428571428571429% similarity, with 8 matched token, and 62 token mismatch
# Model validation at 75 tokens : 12.0% similarity, with 9 matched token, and 66 token mismatch
# Model validation at 80 tokens : 11.25% similarity, with 9 matched token, and 71 token mismatch
# Model validation at 85 tokens : 11.76470588235294% similarity, with 10 matched token, and 75 token mismatch
# Model validation at 90 tokens : 12.222222222222221% similarity, with 11 matched token, and 79 token mismatch
# Model validation at 95 tokens : 10.526315789473683% similarity, with 10 matched token, and 85 token mismatch
# Model validation at 100 tokens : 10.0% similarity, with 10 matched token, and 90 token mismatch
# Model validation at 110 tokens : 9.090909090909092% similarity, with 10 matched token, and 100 token mismatch
# Model validation at 120 tokens : 8.333333333333332% similarity, with 10 matched token, and 110 token mismatch
# Model validation at 130 tokens : 5.384615384615385% similarity, with 7 matched token, and 123 token mismatch
# Model validation at 140 tokens : 6.428571428571428% similarity, with 9 matched token, and 131 token mismatch
# Model validation at 150 tokens : 8.0% similarity, with 12 matched token, and 138 token mismatch
# Model validation at 175 tokens : 6.857142857142858% similarity, with 12 matched token, and 163 token mismatch
# Model validation at 200 tokens : 6.5% similarity, with 13 matched token, and 187 token mismatch
# Model validation at 225 tokens : 6.666666666666667% similarity, with 15 matched token, and 210 token mismatch
# Model validation at 250 tokens : 5.2% similarity, with 13 matched token, and 237 token mismatch
# Model validation at 275 tokens : 4.7272727272727275% similarity, with 13 matched token, and 262 token mismatch
# Model validation at 300 tokens : 4.333333333333334% similarity, with 13 matched token, and 287 token mismatch
# Model validation at 325 tokens : 4.0% similarity, with 13 matched token, and 312 token mismatch
# Model validation at 350 tokens : 3.7142857142857144% similarity, with 13 matched token, and 337 token mismatch
# Model validation at 375 tokens : 3.4666666666666663% similarity, with 13 matched token, and 362 token mismatch
# Model validation at 400 tokens : 3.75% similarity, with 15 matched token, and 385 token mismatch
# Model validation at 425 tokens : 3.058823529411765% similarity, with 13 matched token, and 412 token mismatch
# Model validation at 450 tokens : 2.888888888888889% similarity, with 13 matched token, and 437 token mismatch
# Model validation at 475 tokens : 2.736842105263158% similarity, with 13 matched token, and 462 token mismatch
# Model validation at 500 tokens : 2.6% similarity, with 13 matched token, and 487 token mismatch
# Model validation at 550 tokens : 2.5454545454545454% similarity, with 14 matched token, and 536 token mismatch
# Model validation at 600 tokens : 2.166666666666667% similarity, with 13 matched token, and 587 token mismatch
# Model validation at 650 tokens : 2.1538461538461537% similarity, with 14 matched token, and 636 token mismatch
# Model validation at 700 tokens : 2.0% similarity, with 14 matched token, and 686 token mismatch

# %% [markdown]
# ## Tune 2 : Low ctx size (512), memory training
#
# - Tune 2: Low ctx size (512), Training with instruction & input masked. This forces the actual memory training on the output tokens.

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# #
# # We switch over to fully masked instruct+input, to properly learn the memorization task
# #
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-2-count.jsonl  2  5000 &
# for i in {5..95..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 5000 &
# done
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-100-count.jsonl 100 5000 &
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-200-count.jsonl 200 5000 &
#
# #
# # We mixin the shuffled word list, so that we ensure all words / tokens are learned
# # however this might intrduce an exclusion bias (if seen this word, never repeat it),
# # so we limit the mixture of this data samples
# #
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-10-count.jsonl 10 20 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-15-count.jsonl 15 20 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-25-count.jsonl 25 30 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-50-count.jsonl 50 50 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-75-count.jsonl 75 50 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-100-count.jsonl 100 50 &
# python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-200-count.jsonl 200 50 &
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated a single JSONL file with 3558 samples (20 token repeat) - 15 max words - at ../dataset/shuffle-word-15-count.jsonl
# Generated JSONL file with - 2 max words, 5000 samples - at ../dataset/word-2-count.jsonl
# Generated JSONL file with - 5 max words, 5000 samples - at ../dataset/gen-word-5-count.jsonl
# Generated a single JSONL file with 676 samples (50 token repeat) - 200 max words - at ../dataset/shuffle-word-200-count.jsonl
# Generated a single JSONL file with 1320 samples (50 token repeat) - 100 max words - at ../dataset/shuffle-word-100-count.jsonl
# Generated JSONL file with - 10 max words, 5000 samples - at ../dataset/gen-word-10-count.jsonl
# Generated a single JSONL file with 2633 samples (50 token repeat) - 50 max words - at ../dataset/shuffle-word-50-count.jsonl
# Generated JSONL file with - 15 max words, 5000 samples - at ../dataset/gen-word-15-count.jsonl
# Generated a single JSONL file with 1771 samples (50 token repeat) - 75 max words - at ../dataset/shuffle-word-75-count.jsonl
# Generated a single JSONL file with 3169 samples (30 token repeat) - 25 max words - at ../dataset/shuffle-word-25-count.jsonl
# Generated a single JSONL file with 5222 samples (20 token repeat) - 10 max words - at ../dataset/shuffle-word-10-count.jsonl
# Generated JSONL file with - 30 max words, 5000 samples - at ../dataset/gen-word-30-count.jsonl
# Generated JSONL file with - 35 max words, 5000 samples - at ../dataset/gen-word-35-count.jsonl
# Generated JSONL file with - 40 max words, 5000 samples - at ../dataset/gen-word-40-count.jsonl
# Generated JSONL file with - 45 max words, 5000 samples - at ../dataset/gen-word-45-count.jsonl
# Generated JSONL file with - 50 max words, 5000 samples - at ../dataset/gen-word-50-count.jsonl
# Generated JSONL file with - 20 max words, 5000 samples - at ../dataset/gen-word-20-count.jsonl
# Generated JSONL file with - 55 max words, 5000 samples - at ../dataset/gen-word-55-count.jsonl
# Generated JSONL file with - 60 max words, 5000 samples - at ../dataset/gen-word-60-count.jsonl
# Generated JSONL file with - 25 max words, 5000 samples - at ../dataset/gen-word-25-count.jsonl
# Generated JSONL file with - 75 max words, 5000 samples - at ../dataset/gen-word-75-count.jsonl
# Generated JSONL file with - 80 max words, 5000 samples - at ../dataset/gen-word-80-count.jsonl
# Generated JSONL file with - 85 max words, 5000 samples - at ../dataset/gen-word-85-count.jsonl
# Generated JSONL file with - 65 max words, 5000 samples - at ../dataset/gen-word-65-count.jsonl
# Generated JSONL file with - 70 max words, 5000 samples - at ../dataset/gen-word-70-count.jsonl
# Generated JSONL file with - 95 max words, 5000 samples - at ../dataset/gen-word-95-count.jsonl
# Generated JSONL file with - 90 max words, 5000 samples - at ../dataset/gen-word-90-count.jsonl
# Generated JSONL file with - 100 max words, 5000 samples - at ../dataset/word-100-count.jsonl
# Generated JSONL file with - 200 max words, 5000 samples - at ../dataset/word-200-count.jsonl
# ## Done ##
# total 79M
# drwxr-xr-x 2 root root  4.0K Jul 15 15:24 .
# drwxr-xr-x 6 root root  4.0K Jul 15 15:23 ..
# -rw-r--r-- 1 root root  985K Jul 15 15:24 gen-word-10-count.jsonl
# -rw-r--r-- 1 root root  1.2M Jul 15 15:24 gen-word-15-count.jsonl
# -rw-r--r-- 1 root root  1.5M Jul 15 15:24 gen-word-20-count.jsonl
# -rw-r--r-- 1 root root  1.7M Jul 15 15:24 gen-word-25-count.jsonl
# -rw-r--r-- 1 root root  2.0M Jul 15 15:24 gen-word-30-count.jsonl
# -rw-r--r-- 1 root root  2.2M Jul 15 15:24 gen-word-35-count.jsonl
# -rw-r--r-- 1 root root  2.4M Jul 15 15:24 gen-word-40-count.jsonl
# -rw-r--r-- 1 root root  2.6M Jul 15 15:24 gen-word-45-count.jsonl
# -rw-r--r-- 1 root root  726K Jul 15 15:24 gen-word-5-count.jsonl
# -rw-r--r-- 1 root root  2.9M Jul 15 15:24 gen-word-50-count.jsonl
# -rw-r--r-- 1 root root  3.1M Jul 15 15:24 gen-word-55-count.jsonl
# -rw-r--r-- 1 root root  3.4M Jul 15 15:24 gen-word-60-count.jsonl
# -rw-r--r-- 1 root root  3.6M Jul 15 15:24 gen-word-65-count.jsonl
# -rw-r--r-- 1 root root  3.8M Jul 15 15:24 gen-word-70-count.jsonl
# -rw-r--r-- 1 root root  4.0M Jul 15 15:24 gen-word-75-count.jsonl
# -rw-r--r-- 1 root root  4.3M Jul 15 15:24 gen-word-80-count.jsonl
# -rw-r--r-- 1 root root  4.5M Jul 15 15:24 gen-word-85-count.jsonl
# -rw-r--r-- 1 root root  4.8M Jul 15 15:24 gen-word-90-count.jsonl
# -rw-r--r-- 1 root root  5.0M Jul 15 15:24 gen-word-95-count.jsonl
# -rw-r--r-- 1 root root 1018K Jul 15 15:24 shuffle-word-10-count.jsonl
# -rw-r--r-- 1 root root  1.4M Jul 15 15:24 shuffle-word-100-count.jsonl
# -rw-r--r-- 1 root root  865K Jul 15 15:24 shuffle-word-15-count.jsonl
# -rw-r--r-- 1 root root  1.4M Jul 15 15:24 shuffle-word-200-count.jsonl
# -rw-r--r-- 1 root root  1.1M Jul 15 15:24 shuffle-word-25-count.jsonl
# -rw-r--r-- 1 root root  1.5M Jul 15 15:24 shuffle-word-50-count.jsonl
# -rw-r--r-- 1 root root  1.5M Jul 15 15:24 shuffle-word-75-count.jsonl
# -rw-r--r-- 1 root root  5.3M Jul 15 15:24 word-100-count.jsonl
# -rw-r--r-- 1 root root  601K Jul 15 15:24 word-2-count.jsonl
# -rw-r--r-- 1 root root   10M Jul 15 15:24 word-200-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-A-mem-finetune-2.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-A-mem-finetune-2/"
# Out:
# Resolving data files: 100%|██████████████████| 29/29 [00:00<00:00, 36461.28it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-d816d1b1ca075f1e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|███████████████████| 1/1 [00:00<00:00, 2054.02it/s]
# Extracting data files: 100%|█████████████████████| 1/1 [00:00<00:00, 144.20it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-d816d1b1ca075f1e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 123.13it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-A-mem-finetune-2.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-2 (bs=256, train-ctx=512, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=512
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 1171926168
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 1171926168
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230715_170253-boah6u52
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run TokenShift-A - Mem-Finetune-2 (bs=256, train-ctx=512, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/boah6u52
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Resolving data files: 100%|█████████████████| 29/29 [00:00<00:00, 104587.12it/s]
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-d816d1b1ca075f1e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 10.65it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-d816d1b1ca075f1e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-a428f3fb8cfcf218_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-d816d1b1ca075f1e/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-c512f3954ad6145e_*_of_00064.arrow
# [rank: 0] Global seed set to 1171926168
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-15 17:03:06,038] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [rank: 1] Global seed set to 1171926168
# [rank: 5] Global seed set to 1171926168
# [rank: 2] Global seed set to 1171926168
# [rank: 7] Global seed set to 1171926168
# [rank: 6] Global seed set to 1171926168
# [rank: 3] Global seed set to 1171926168
# [rank: 4] Global seed set to 1171926168
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# Loading extension module wkv_512_bf16...
# [rank: 3] Global seed set to 1171926168
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-15 17:03:21,712] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 1171926168
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-15 17:03:21,724] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 1171926168
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-15 17:03:21,748] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 1171926168
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-15 17:03:21,762] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 6] Global seed set to 1171926168
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-15 17:03:21,765] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 1171926168
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-15 17:03:21,772] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 1171926168
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-07-15 17:03:21,774] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:612: UserWarning: Checkpoint directory /root/rwkv5x-tokenshift-exp-A/checkpoint/TokenShift-A-mem-finetune-2 exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  5.000e-04 (0.0005)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.05961108207702637 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10184049606323242 seconds
# Time to load fused_adam op: 0.1012277603149414 seconds
# Time to load fused_adam op: 0.10138106346130371 seconds
# Time to load fused_adam op: 0.10128521919250488 seconds
# Time to load fused_adam op: 0.1013641357421875 seconds
# Time to load fused_adam op: 0.10136771202087402 seconds
# Time to load fused_adam op: 0.10143780708312988 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.07016420364379883 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10381054878234863 seconds
# Time to load utils op: 0.10200834274291992 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10164117813110352 seconds
# Time to load utils op: 0.10142946243286133 seconds
# Time to load utils op: 0.10173439979553223 seconds
# Time to load utils op: 0.1017758846282959 seconds
# Time to load utils op: 0.10176992416381836 seconds
# Rank: 7 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 0 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 3 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 1 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 4 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Time to load utils op: 0.00034880638122558594 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003407001495361328 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00020051002502441406 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002529621124267578 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00025463104248046875 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002551078796386719 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002551078796386719 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0004754066467285156 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 128 M
# 1 | blocks | ModuleList | 1.0 B
# 2 | ln_out | LayerNorm  | 5.1 K
# 3 | head   | Linear     | 128 M
# --------------------------------------
# 1.3 B     Trainable params
# 0         Non-trainable params
# 1.3 B     Total params
# 5,120.512 Total estimated model params size (MB)
# Epoch 0:   5%| | 800/16028 [04:04<1:17:35,  3.27it/s, v_num=6u52, train/loss=2.9/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 16028/16028 [1:23:15<00:00,  3.21it/s, v_num=6u52, train/loss=0
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/17 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/17 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.shift_states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▂█▃▅▂▂▂▄▂▃▁▄▁▂▂▂▄▄▂▅▂▅▂▅▄▅▃▃▂▂▁▂▃▄▂▂▂▅▃▄
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ▂▇▅█▁▃▄▁▁▄▃▃▁▁▁▂▁▁▂▁▁▁▆▇▂▁▂▁▆▁▁▁▁▁▁▁▁▁▁▁
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 16027
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 49
# wandb:               substep 128216
# wandb:            train/loss 0.00922
# wandb:   trainer/global_step 500
# wandb: trainer/learning_rate 0.0004
# wandb:
# wandb: 🚀 View run TokenShift-A - Mem-Finetune-2 (bs=256, train-ctx=512, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/boah6u52
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230715_170253-boah6u52/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-A-mem-finetune-2/last.ckpt" \
        "../model/TokenShift-A-Tune2.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-A-Tune2.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-A-mem-finetune-2/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 222 params 1280128000 elements
# Saving fp32 state dict to ../model/TokenShift-A-Tune2.pth
# -rw-r--r-- 1 root root 4.8G Jul 15 18:27 ../model/TokenShift-A-Tune2.pth

# %%
# Lets do a memory eval 
#
# While not at its full potential, its memory ability should start emerging
#
# !python3 ../memory_script/eval_memory_guided.py "{PROJECT_DIR}/model/TokenShift-A-Tune2.pth"
# Out:
# RWKV_HEAD_QK_DIM 0 RWKV_JIT_ON 1
#
# blocks.0.att.key.weight                  float32    cuda:0
# blocks.0.att.output.weight               float32    cuda:0
# blocks.0.att.receptance.weight           float32    cuda:0
# blocks.0.att.time_mix_k                  float32    cuda:0
# blocks.0.att.time_mix_r                  float32    cuda:0
# blocks.0.att.time_mix_v                  float32    cuda:0
# blocks.0.att.value.weight                float32    cuda:0
# blocks.0.ffn.key.weight                  float32    cuda:0
# blocks.0.ffn.receptance.weight           float32    cuda:0
# blocks.0.ffn.time_mix_k                  float32    cuda:0
# blocks.0.ffn.time_mix_r                  float32    cuda:0
# blocks.0.ffn.value.weight                float32    cuda:0
# blocks.0.ln0.bias                        float32    cuda:0
# blocks.0.ln0.weight                      float32    cuda:0
# blocks.0.ln1.bias                        float32    cuda:0
# blocks.0.ln1.weight                      float32    cuda:0
# blocks.0.ln2.bias                        float32    cuda:0
# blocks.0.ln2.weight                      float32    cuda:0
# ................................................................................................................................................................................
# emb.weight                               float32    cpu
# head.weight                              float32    cuda:0
# ln_out.bias                              float32    cuda:0
# ln_out.weight                            float32    cuda:0
# blocks.0.att.time_decay                  float32    cuda:0
# ...........
# blocks.0.att.time_first                  float32    cuda:0
# ...........###
# ### Model validation start ###
# ###
# Model validation at 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# Model validation at 10 tokens : 90.0% similarity, with 9 matched token, and 1 token mismatch
# Model validation at 15 tokens : 60.0% similarity, with 9 matched token, and 6 token mismatch
# Model validation at 20 tokens : 50.0% similarity, with 10 matched token, and 10 token mismatch
# Model validation at 25 tokens : 60.0% similarity, with 15 matched token, and 10 token mismatch
# Model validation at 30 tokens : 63.33333333333333% similarity, with 19 matched token, and 11 token mismatch
# Model validation at 35 tokens : 68.57142857142857% similarity, with 24 matched token, and 11 token mismatch
# Model validation at 40 tokens : 62.5% similarity, with 25 matched token, and 15 token mismatch
# Model validation at 45 tokens : 60.0% similarity, with 27 matched token, and 18 token mismatch
# Model validation at 50 tokens : 62.0% similarity, with 31 matched token, and 19 token mismatch
# Model validation at 55 tokens : 58.18181818181818% similarity, with 32 matched token, and 23 token mismatch
# Model validation at 60 tokens : 58.333333333333336% similarity, with 35 matched token, and 25 token mismatch
# Model validation at 65 tokens : 56.92307692307692% similarity, with 37 matched token, and 28 token mismatch
# Model validation at 70 tokens : 52.85714285714286% similarity, with 37 matched token, and 33 token mismatch
# Model validation at 75 tokens : 48.0% similarity, with 36 matched token, and 39 token mismatch
# Model validation at 80 tokens : 45.0% similarity, with 36 matched token, and 44 token mismatch
# Model validation at 85 tokens : 36.470588235294116% similarity, with 31 matched token, and 54 token mismatch
# Model validation at 90 tokens : 33.33333333333333% similarity, with 30 matched token, and 60 token mismatch
# Model validation at 95 tokens : 35.78947368421053% similarity, with 34 matched token, and 61 token mismatch
# Model validation at 100 tokens : 33.0% similarity, with 33 matched token, and 67 token mismatch
# Model validation at 110 tokens : 29.09090909090909% similarity, with 32 matched token, and 78 token mismatch
# Model validation at 120 tokens : 25.0% similarity, with 30 matched token, and 90 token mismatch
# Model validation at 130 tokens : 23.076923076923077% similarity, with 30 matched token, and 100 token mismatch
# Model validation at 140 tokens : 20.0% similarity, with 28 matched token, and 112 token mismatch
# Model validation at 150 tokens : 18.666666666666668% similarity, with 28 matched token, and 122 token mismatch
# Model validation at 175 tokens : 14.857142857142858% similarity, with 26 matched token, and 149 token mismatch
# Model validation at 200 tokens : 12.0% similarity, with 24 matched token, and 176 token mismatch
# Model validation at 225 tokens : 10.222222222222223% similarity, with 23 matched token, and 202 token mismatch
# Model validation at 250 tokens : 9.2% similarity, with 23 matched token, and 227 token mismatch
# Model validation at 275 tokens : 6.909090909090909% similarity, with 19 matched token, and 256 token mismatch
# Model validation at 300 tokens : 6.333333333333334% similarity, with 19 matched token, and 281 token mismatch
# Model validation at 325 tokens : 6.153846153846154% similarity, with 20 matched token, and 305 token mismatch
# Model validation at 350 tokens : 5.142857142857142% similarity, with 18 matched token, and 332 token mismatch
# Model validation at 375 tokens : 5.066666666666666% similarity, with 19 matched token, and 356 token mismatch
# Model validation at 400 tokens : 4.75% similarity, with 19 matched token, and 381 token mismatch
# Model validation at 425 tokens : 4.235294117647059% similarity, with 18 matched token, and 407 token mismatch
# Model validation at 450 tokens : 4.0% similarity, with 18 matched token, and 432 token mismatch
# Model validation at 475 tokens : 3.578947368421052% similarity, with 17 matched token, and 458 token mismatch
# Model validation at 500 tokens : 3.8% similarity, with 19 matched token, and 481 token mismatch
# Model validation at 550 tokens : 3.4545454545454546% similarity, with 19 matched token, and 531 token mismatch
# Model validation at 600 tokens : 3.166666666666667% similarity, with 19 matched token, and 581 token mismatch
# Model validation at 650 tokens : 2.769230769230769% similarity, with 18 matched token, and 632 token mismatch
# Model validation at 700 tokens : 2.2857142857142856% similarity, with 16 matched token, and 684 token mismatch

# %% [markdown]
# ## Tune 3 : Ramping up the ctx size (1024), memory training
#
# - Tune 3: Mid ctx size (1024), same as tune 2, but extended in context size
#
# This intentionally a much larger dataset, and lower learning rate to help ensure we push the model to its absolute limits.

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# #
# # We reduce the training set for < 50 words - and shift the focus upwards
# # (aka 50-100 token * 2 : ~100 - 250 token ctx len)
# #
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-2-count.jsonl 2 1000 &
# for i in {5..45..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 1000 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 10 &
# done
#
# #
# # Ramping up the 50+ - 400 words dataset
# #
# for i in {50..450..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 2000 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 20 &
# done
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated JSONL file with - 2 max words, 1000 samples - at ../dataset/word-2-count.jsonl
# Generated JSONL file with - 5 max words, 1000 samples - at ../dataset/gen-word-5-count.jsonl
# Generated JSONL file with - 10 max words, 1000 samples - at ../dataset/gen-word-10-count.jsonl
# Generated a single JSONL file with 667 samples (10 token repeat) - 40 max words - at ../dataset/shuffle-word-40-count.jsonl
# Generated JSONL file with - 25 max words, 1000 samples - at ../dataset/gen-word-25-count.jsonl
# Generated JSONL file with - 15 max words, 1000 samples - at ../dataset/gen-word-15-count.jsonl
# Generated a single JSONL file with 587 samples (10 token repeat) - 45 max words - at ../dataset/shuffle-word-45-count.jsonl
# Generated JSONL file with - 20 max words, 1000 samples - at ../dataset/gen-word-20-count.jsonl
# Generated JSONL file with - 30 max words, 1000 samples - at ../dataset/gen-word-30-count.jsonl
# Generated a single JSONL file with 1784 samples (10 token repeat) - 15 max words - at ../dataset/shuffle-word-15-count.jsonl
# Generated a single JSONL file with 557 samples (20 token repeat) - 95 max words - at ../dataset/shuffle-word-95-count.jsonl
# Generated a single JSONL file with 961 samples (20 token repeat) - 55 max words - at ../dataset/shuffle-word-55-count.jsonl
# Generated a single JSONL file with 524 samples (20 token repeat) - 100 max words - at ../dataset/shuffle-word-100-count.jsonl
# Generated JSONL file with - 45 max words, 1000 samples - at ../dataset/gen-word-45-count.jsonl
# Generated a single JSONL file with 1317 samples (10 token repeat) - 20 max words - at ../dataset/shuffle-word-20-count.jsonl
# Generated JSONL file with - 40 max words, 1000 samples - at ../dataset/gen-word-40-count.jsonl
# Generated a single JSONL file with 184 samples (20 token repeat) - 275 max words - at ../dataset/shuffle-word-275-count.jsonl
# Generated a single JSONL file with 617 samples (20 token repeat) - 85 max words - at ../dataset/shuffle-word-85-count.jsonl
# Generated a single JSONL file with 1062 samples (10 token repeat) - 25 max words - at ../dataset/shuffle-word-25-count.jsonl
# Generated a single JSONL file with 655 samples (20 token repeat) - 80 max words - at ../dataset/shuffle-word-80-count.jsonl
# Generated a single JSONL file with 588 samples (20 token repeat) - 90 max words - at ../dataset/shuffle-word-90-count.jsonl
# Generated a single JSONL file with 873 samples (10 token repeat) - 30 max words - at ../dataset/shuffle-word-30-count.jsonl
# Generated a single JSONL file with 757 samples (10 token repeat) - 35 max words - at ../dataset/shuffle-word-35-count.jsonl
# Generated a single JSONL file with 272 samples (20 token repeat) - 190 max words - at ../dataset/shuffle-word-190-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 415 max words - at ../dataset/shuffle-word-415-count.jsonl
# Generated a single JSONL file with 873 samples (20 token repeat) - 60 max words - at ../dataset/shuffle-word-60-count.jsonl
# Generated a single JSONL file with 399 samples (20 token repeat) - 110 max words - at ../dataset/shuffle-word-110-count.jsonl
# Generated a single JSONL file with 325 samples (20 token repeat) - 140 max words - at ../dataset/shuffle-word-140-count.jsonl
# Generated a single JSONL file with 362 samples (20 token repeat) - 125 max words - at ../dataset/shuffle-word-125-count.jsonl
# Generated a single JSONL file with 709 samples (20 token repeat) - 75 max words - at ../dataset/shuffle-word-75-count.jsonl
# Generated a single JSONL file with 205 samples (20 token repeat) - 215 max words - at ../dataset/shuffle-word-215-count.jsonl
# Generated a single JSONL file with 409 samples (20 token repeat) - 105 max words - at ../dataset/shuffle-word-105-count.jsonl
# Generated a single JSONL file with 269 samples (20 token repeat) - 195 max words - at ../dataset/shuffle-word-195-count.jsonl
# Generated a single JSONL file with 294 samples (20 token repeat) - 155 max words - at ../dataset/shuffle-word-155-count.jsonl
# Generated a single JSONL file with 186 samples (20 token repeat) - 250 max words - at ../dataset/shuffle-word-250-count.jsonl
# Generated a single JSONL file with 368 samples (20 token repeat) - 120 max words - at ../dataset/shuffle-word-120-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 255 max words - at ../dataset/shuffle-word-255-count.jsonl
# Generated a single JSONL file with 219 samples (20 token repeat) - 205 max words - at ../dataset/shuffle-word-205-count.jsonl
# Generated a single JSONL file with 747 samples (20 token repeat) - 70 max words - at ../dataset/shuffle-word-70-count.jsonl
# Generated a single JSONL file with 199 samples (20 token repeat) - 230 max words - at ../dataset/shuffle-word-230-count.jsonl
# Generated a single JSONL file with 201 samples (20 token repeat) - 220 max words - at ../dataset/shuffle-word-220-count.jsonl
# Generated a single JSONL file with 2627 samples (10 token repeat) - 10 max words - at ../dataset/shuffle-word-10-count.jsonl
# Generated a single JSONL file with 195 samples (20 token repeat) - 240 max words - at ../dataset/shuffle-word-240-count.jsonl
# Generated a single JSONL file with 119 samples (20 token repeat) - 435 max words - at ../dataset/shuffle-word-435-count.jsonl
# Generated JSONL file with - 35 max words, 1000 samples - at ../dataset/gen-word-35-count.jsonl
# Generated a single JSONL file with 182 samples (20 token repeat) - 295 max words - at ../dataset/shuffle-word-295-count.jsonl
# Generated a single JSONL file with 142 samples (20 token repeat) - 315 max words - at ../dataset/shuffle-word-315-count.jsonl
# Generated a single JSONL file with 184 samples (20 token repeat) - 280 max words - at ../dataset/shuffle-word-280-count.jsonl
# Generated a single JSONL file with 276 samples (20 token repeat) - 185 max words - at ../dataset/shuffle-word-185-count.jsonl
# Generated a single JSONL file with 5568 samples (10 token repeat) - 5 max words - at ../dataset/shuffle-word-5-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 335 max words - at ../dataset/shuffle-word-335-count.jsonl
# Generated a single JSONL file with 811 samples (20 token repeat) - 65 max words - at ../dataset/shuffle-word-65-count.jsonl
# Generated a single JSONL file with 348 samples (20 token repeat) - 130 max words - at ../dataset/shuffle-word-130-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 395 max words - at ../dataset/shuffle-word-395-count.jsonl
# Generated a single JSONL file with 1049 samples (20 token repeat) - 50 max words - at ../dataset/shuffle-word-50-count.jsonl
# Generated a single JSONL file with 186 samples (20 token repeat) - 260 max words - at ../dataset/shuffle-word-260-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 345 max words - at ../dataset/shuffle-word-345-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 285 max words - at ../dataset/shuffle-word-285-count.jsonl
# Generated a single JSONL file with 188 samples (20 token repeat) - 245 max words - at ../dataset/shuffle-word-245-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 420 max words - at ../dataset/shuffle-word-420-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 330 max words - at ../dataset/shuffle-word-330-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 325 max words - at ../dataset/shuffle-word-325-count.jsonl
# Generated a single JSONL file with 115 samples (20 token repeat) - 445 max words - at ../dataset/shuffle-word-445-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 375 max words - at ../dataset/shuffle-word-375-count.jsonl
# Generated JSONL file with - 60 max words, 2000 samples - at ../dataset/gen-word-60-count.jsonl
# Generated JSONL file with - 55 max words, 2000 samples - at ../dataset/gen-word-55-count.jsonl
# Generated a single JSONL file with 150 samples (20 token repeat) - 305 max words - at ../dataset/shuffle-word-305-count.jsonl
# Generated a single JSONL file with 142 samples (20 token repeat) - 310 max words - at ../dataset/shuffle-word-310-count.jsonl
# Generated a single JSONL file with 294 samples (20 token repeat) - 160 max words - at ../dataset/shuffle-word-160-count.jsonl
# Generated a single JSONL file with 308 samples (20 token repeat) - 150 max words - at ../dataset/shuffle-word-150-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 365 max words - at ../dataset/shuffle-word-365-count.jsonl
# Generated a single JSONL file with 119 samples (20 token repeat) - 410 max words - at ../dataset/shuffle-word-410-count.jsonl
# Generated JSONL file with - 50 max words, 2000 samples - at ../dataset/gen-word-50-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 425 max words - at ../dataset/shuffle-word-425-count.jsonl
# Generated a single JSONL file with 139 samples (20 token repeat) - 390 max words - at ../dataset/shuffle-word-390-count.jsonl
# Generated JSONL file with - 85 max words, 2000 samples - at ../dataset/gen-word-85-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 300 max words - at ../dataset/shuffle-word-300-count.jsonl
# Generated a single JSONL file with 282 samples (20 token repeat) - 175 max words - at ../dataset/shuffle-word-175-count.jsonl
# Generated a single JSONL file with 137 samples (20 token repeat) - 370 max words - at ../dataset/shuffle-word-370-count.jsonl
# Generated a single JSONL file with 143 samples (20 token repeat) - 320 max words - at ../dataset/shuffle-word-320-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 450 max words - at ../dataset/shuffle-word-450-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 265 max words - at ../dataset/shuffle-word-265-count.jsonl
# Generated JSONL file with - 70 max words, 2000 samples - at ../dataset/gen-word-70-count.jsonl
# Generated JSONL file with - 95 max words, 2000 samples - at ../dataset/gen-word-95-count.jsonl
# Generated a single JSONL file with 143 samples (20 token repeat) - 355 max words - at ../dataset/shuffle-word-355-count.jsonl
# Generated a single JSONL file with 213 samples (20 token repeat) - 210 max words - at ../dataset/shuffle-word-210-count.jsonl
# Generated a single JSONL file with 199 samples (20 token repeat) - 235 max words - at ../dataset/shuffle-word-235-count.jsonl
# Generated a single JSONL file with 318 samples (20 token repeat) - 145 max words - at ../dataset/shuffle-word-145-count.jsonl
# Generated a single JSONL file with 287 samples (20 token repeat) - 165 max words - at ../dataset/shuffle-word-165-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 405 max words - at ../dataset/shuffle-word-405-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 350 max words - at ../dataset/shuffle-word-350-count.jsonl
# Generated a single JSONL file with 142 samples (20 token repeat) - 380 max words - at ../dataset/shuffle-word-380-count.jsonl
# Generated a single JSONL file with 142 samples (20 token repeat) - 400 max words - at ../dataset/shuffle-word-400-count.jsonl
# Generated a single JSONL file with 119 samples (20 token repeat) - 430 max words - at ../dataset/shuffle-word-430-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 440 max words - at ../dataset/shuffle-word-440-count.jsonl
# Generated a single JSONL file with 277 samples (20 token repeat) - 200 max words - at ../dataset/shuffle-word-200-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 340 max words - at ../dataset/shuffle-word-340-count.jsonl
# Generated a single JSONL file with 142 samples (20 token repeat) - 360 max words - at ../dataset/shuffle-word-360-count.jsonl
# Generated a single JSONL file with 182 samples (20 token repeat) - 290 max words - at ../dataset/shuffle-word-290-count.jsonl
# Generated a single JSONL file with 336 samples (20 token repeat) - 135 max words - at ../dataset/shuffle-word-135-count.jsonl
# Generated a single JSONL file with 200 samples (20 token repeat) - 225 max words - at ../dataset/shuffle-word-225-count.jsonl
# Generated a single JSONL file with 186 samples (20 token repeat) - 270 max words - at ../dataset/shuffle-word-270-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 385 max words - at ../dataset/shuffle-word-385-count.jsonl
# Generated JSONL file with - 100 max words, 2000 samples - at ../dataset/gen-word-100-count.jsonl
# Generated a single JSONL file with 274 samples (20 token repeat) - 180 max words - at ../dataset/shuffle-word-180-count.jsonl
# Generated a single JSONL file with 284 samples (20 token repeat) - 170 max words - at ../dataset/shuffle-word-170-count.jsonl
# Generated a single JSONL file with 382 samples (20 token repeat) - 115 max words - at ../dataset/shuffle-word-115-count.jsonl
# Generated JSONL file with - 80 max words, 2000 samples - at ../dataset/gen-word-80-count.jsonl
# Generated JSONL file with - 105 max words, 2000 samples - at ../dataset/gen-word-105-count.jsonl
# Generated JSONL file with - 140 max words, 2000 samples - at ../dataset/gen-word-140-count.jsonl
# Generated JSONL file with - 90 max words, 2000 samples - at ../dataset/gen-word-90-count.jsonl
# Generated JSONL file with - 160 max words, 2000 samples - at ../dataset/gen-word-160-count.jsonl
# Generated JSONL file with - 65 max words, 2000 samples - at ../dataset/gen-word-65-count.jsonl
# Generated JSONL file with - 145 max words, 2000 samples - at ../dataset/gen-word-145-count.jsonl
# Generated JSONL file with - 75 max words, 2000 samples - at ../dataset/gen-word-75-count.jsonl
# Generated JSONL file with - 115 max words, 2000 samples - at ../dataset/gen-word-115-count.jsonl
# Generated JSONL file with - 180 max words, 2000 samples - at ../dataset/gen-word-180-count.jsonl
# Generated JSONL file with - 175 max words, 2000 samples - at ../dataset/gen-word-175-count.jsonl
# Generated JSONL file with - 130 max words, 2000 samples - at ../dataset/gen-word-130-count.jsonl
# Generated JSONL file with - 155 max words, 2000 samples - at ../dataset/gen-word-155-count.jsonl
# Generated JSONL file with - 185 max words, 2000 samples - at ../dataset/gen-word-185-count.jsonl
# Generated JSONL file with - 220 max words, 2000 samples - at ../dataset/gen-word-220-count.jsonl
# Generated JSONL file with - 125 max words, 2000 samples - at ../dataset/gen-word-125-count.jsonl
# Generated JSONL file with - 120 max words, 2000 samples - at ../dataset/gen-word-120-count.jsonl
# Generated JSONL file with - 110 max words, 2000 samples - at ../dataset/gen-word-110-count.jsonl
# Generated JSONL file with - 135 max words, 2000 samples - at ../dataset/gen-word-135-count.jsonl
# Generated JSONL file with - 225 max words, 2000 samples - at ../dataset/gen-word-225-count.jsonl
# Generated JSONL file with - 190 max words, 2000 samples - at ../dataset/gen-word-190-count.jsonl
# Generated JSONL file with - 200 max words, 2000 samples - at ../dataset/gen-word-200-count.jsonl
# Generated JSONL file with - 165 max words, 2000 samples - at ../dataset/gen-word-165-count.jsonl
# Generated JSONL file with - 150 max words, 2000 samples - at ../dataset/gen-word-150-count.jsonl
# Generated JSONL file with - 230 max words, 2000 samples - at ../dataset/gen-word-230-count.jsonl
# Generated JSONL file with - 235 max words, 2000 samples - at ../dataset/gen-word-235-count.jsonl
# Generated JSONL file with - 195 max words, 2000 samples - at ../dataset/gen-word-195-count.jsonl
# Generated JSONL file with - 205 max words, 2000 samples - at ../dataset/gen-word-205-count.jsonl
# Generated JSONL file with - 170 max words, 2000 samples - at ../dataset/gen-word-170-count.jsonl
# Generated JSONL file with - 260 max words, 2000 samples - at ../dataset/gen-word-260-count.jsonl
# Generated JSONL file with - 275 max words, 2000 samples - at ../dataset/gen-word-275-count.jsonl
# Generated JSONL file with - 210 max words, 2000 samples - at ../dataset/gen-word-210-count.jsonl
# Generated JSONL file with - 245 max words, 2000 samples - at ../dataset/gen-word-245-count.jsonl
# Generated JSONL file with - 250 max words, 2000 samples - at ../dataset/gen-word-250-count.jsonl
# Generated JSONL file with - 345 max words, 2000 samples - at ../dataset/gen-word-345-count.jsonl
# Generated JSONL file with - 370 max words, 2000 samples - at ../dataset/gen-word-370-count.jsonl
# Generated JSONL file with - 320 max words, 2000 samples - at ../dataset/gen-word-320-count.jsonl
# Generated JSONL file with - 295 max words, 2000 samples - at ../dataset/gen-word-295-count.jsonl
# Generated JSONL file with - 280 max words, 2000 samples - at ../dataset/gen-word-280-count.jsonl
# Generated JSONL file with - 270 max words, 2000 samples - at ../dataset/gen-word-270-count.jsonl
# Generated JSONL file with - 290 max words, 2000 samples - at ../dataset/gen-word-290-count.jsonl
# Generated JSONL file with - 240 max words, 2000 samples - at ../dataset/gen-word-240-count.jsonl
# Generated JSONL file with - 265 max words, 2000 samples - at ../dataset/gen-word-265-count.jsonl
# Generated JSONL file with - 340 max words, 2000 samples - at ../dataset/gen-word-340-count.jsonl
# Generated JSONL file with - 215 max words, 2000 samples - at ../dataset/gen-word-215-count.jsonl
# Generated JSONL file with - 305 max words, 2000 samples - at ../dataset/gen-word-305-count.jsonl
# Generated JSONL file with - 420 max words, 2000 samples - at ../dataset/gen-word-420-count.jsonl
# Generated JSONL file with - 335 max words, 2000 samples - at ../dataset/gen-word-335-count.jsonl
# Generated JSONL file with - 395 max words, 2000 samples - at ../dataset/gen-word-395-count.jsonl
# Generated JSONL file with - 330 max words, 2000 samples - at ../dataset/gen-word-330-count.jsonl
# Generated JSONL file with - 400 max words, 2000 samples - at ../dataset/gen-word-400-count.jsonl
# Generated JSONL file with - 310 max words, 2000 samples - at ../dataset/gen-word-310-count.jsonl
# Generated JSONL file with - 380 max words, 2000 samples - at ../dataset/gen-word-380-count.jsonl
# Generated JSONL file with - 410 max words, 2000 samples - at ../dataset/gen-word-410-count.jsonl
# Generated JSONL file with - 375 max words, 2000 samples - at ../dataset/gen-word-375-count.jsonl
# Generated JSONL file with - 360 max words, 2000 samples - at ../dataset/gen-word-360-count.jsonl
# Generated JSONL file with - 255 max words, 2000 samples - at ../dataset/gen-word-255-count.jsonl
# Generated JSONL file with - 325 max words, 2000 samples - at ../dataset/gen-word-325-count.jsonl
# Generated JSONL file with - 285 max words, 2000 samples - at ../dataset/gen-word-285-count.jsonl
# Generated JSONL file with - 390 max words, 2000 samples - at ../dataset/gen-word-390-count.jsonl
# Generated JSONL file with - 300 max words, 2000 samples - at ../dataset/gen-word-300-count.jsonl
# Generated JSONL file with - 385 max words, 2000 samples - at ../dataset/gen-word-385-count.jsonl
# Generated JSONL file with - 405 max words, 2000 samples - at ../dataset/gen-word-405-count.jsonl
# Generated JSONL file with - 315 max words, 2000 samples - at ../dataset/gen-word-315-count.jsonl
# Generated JSONL file with - 440 max words, 2000 samples - at ../dataset/gen-word-440-count.jsonl
# Generated JSONL file with - 350 max words, 2000 samples - at ../dataset/gen-word-350-count.jsonl
# Generated JSONL file with - 365 max words, 2000 samples - at ../dataset/gen-word-365-count.jsonl
# Generated JSONL file with - 430 max words, 2000 samples - at ../dataset/gen-word-430-count.jsonl
# Generated JSONL file with - 355 max words, 2000 samples - at ../dataset/gen-word-355-count.jsonl
# Generated JSONL file with - 435 max words, 2000 samples - at ../dataset/gen-word-435-count.jsonl
# Generated JSONL file with - 415 max words, 2000 samples - at ../dataset/gen-word-415-count.jsonl
# Generated JSONL file with - 445 max words, 2000 samples - at ../dataset/gen-word-445-count.jsonl
# Generated JSONL file with - 450 max words, 2000 samples - at ../dataset/gen-word-450-count.jsonl
# Generated JSONL file with - 425 max words, 2000 samples - at ../dataset/gen-word-425-count.jsonl
# ## Done ##
# total 450M
# drwxr-xr-x 2 root root 8.0K Jul 15 18:43 .
# drwxr-xr-x 6 root root 4.0K Jul 15 18:41 ..
# -rw-r--r-- 1 root root 198K Jul 15 18:43 gen-word-10-count.jsonl
# -rw-r--r-- 1 root root 2.1M Jul 15 18:43 gen-word-100-count.jsonl
# -rw-r--r-- 1 root root 2.2M Jul 15 18:43 gen-word-105-count.jsonl
# -rw-r--r-- 1 root root 2.3M Jul 15 18:43 gen-word-110-count.jsonl
# -rw-r--r-- 1 root root 2.4M Jul 15 18:43 gen-word-115-count.jsonl
# -rw-r--r-- 1 root root 2.5M Jul 15 18:43 gen-word-120-count.jsonl
# -rw-r--r-- 1 root root 2.6M Jul 15 18:43 gen-word-125-count.jsonl
# -rw-r--r-- 1 root root 2.7M Jul 15 18:43 gen-word-130-count.jsonl
# -rw-r--r-- 1 root root 2.8M Jul 15 18:43 gen-word-135-count.jsonl
# -rw-r--r-- 1 root root 2.9M Jul 15 18:43 gen-word-140-count.jsonl
# -rw-r--r-- 1 root root 3.0M Jul 15 18:43 gen-word-145-count.jsonl
# -rw-r--r-- 1 root root 245K Jul 15 18:43 gen-word-15-count.jsonl
# -rw-r--r-- 1 root root 3.1M Jul 15 18:43 gen-word-150-count.jsonl
# -rw-r--r-- 1 root root 3.2M Jul 15 18:43 gen-word-155-count.jsonl
# -rw-r--r-- 1 root root 3.3M Jul 15 18:43 gen-word-160-count.jsonl
# -rw-r--r-- 1 root root 3.4M Jul 15 18:43 gen-word-165-count.jsonl
# -rw-r--r-- 1 root root 3.4M Jul 15 18:43 gen-word-170-count.jsonl
# -rw-r--r-- 1 root root 3.5M Jul 15 18:43 gen-word-175-count.jsonl
# -rw-r--r-- 1 root root 3.7M Jul 15 18:43 gen-word-180-count.jsonl
# -rw-r--r-- 1 root root 3.8M Jul 15 18:43 gen-word-185-count.jsonl
# -rw-r--r-- 1 root root 3.8M Jul 15 18:43 gen-word-190-count.jsonl
# -rw-r--r-- 1 root root 3.9M Jul 15 18:43 gen-word-195-count.jsonl
# -rw-r--r-- 1 root root 293K Jul 15 18:43 gen-word-20-count.jsonl
# -rw-r--r-- 1 root root 4.0M Jul 15 18:43 gen-word-200-count.jsonl
# -rw-r--r-- 1 root root 4.1M Jul 15 18:43 gen-word-205-count.jsonl
# -rw-r--r-- 1 root root 4.2M Jul 15 18:43 gen-word-210-count.jsonl
# -rw-r--r-- 1 root root 4.3M Jul 15 18:43 gen-word-215-count.jsonl
# -rw-r--r-- 1 root root 4.4M Jul 15 18:43 gen-word-220-count.jsonl
# -rw-r--r-- 1 root root 4.5M Jul 15 18:43 gen-word-225-count.jsonl
# -rw-r--r-- 1 root root 4.6M Jul 15 18:43 gen-word-230-count.jsonl
# -rw-r--r-- 1 root root 4.7M Jul 15 18:43 gen-word-235-count.jsonl
# -rw-r--r-- 1 root root 4.8M Jul 15 18:43 gen-word-240-count.jsonl
# -rw-r--r-- 1 root root 4.9M Jul 15 18:43 gen-word-245-count.jsonl
# -rw-r--r-- 1 root root 339K Jul 15 18:43 gen-word-25-count.jsonl
# -rw-r--r-- 1 root root 5.0M Jul 15 18:43 gen-word-250-count.jsonl
# -rw-r--r-- 1 root root 5.1M Jul 15 18:43 gen-word-255-count.jsonl
# -rw-r--r-- 1 root root 5.2M Jul 15 18:43 gen-word-260-count.jsonl
# -rw-r--r-- 1 root root 5.3M Jul 15 18:43 gen-word-265-count.jsonl
# -rw-r--r-- 1 root root 5.4M Jul 15 18:43 gen-word-270-count.jsonl
# -rw-r--r-- 1 root root 5.5M Jul 15 18:43 gen-word-275-count.jsonl
# -rw-r--r-- 1 root root 5.5M Jul 15 18:43 gen-word-280-count.jsonl
# -rw-r--r-- 1 root root 5.7M Jul 15 18:43 gen-word-285-count.jsonl
# -rw-r--r-- 1 root root 5.8M Jul 15 18:43 gen-word-290-count.jsonl
# -rw-r--r-- 1 root root 5.8M Jul 15 18:43 gen-word-295-count.jsonl
# -rw-r--r-- 1 root root 391K Jul 15 18:43 gen-word-30-count.jsonl
# -rw-r--r-- 1 root root 5.9M Jul 15 18:43 gen-word-300-count.jsonl
# -rw-r--r-- 1 root root 6.1M Jul 15 18:43 gen-word-305-count.jsonl
# -rw-r--r-- 1 root root 6.1M Jul 15 18:43 gen-word-310-count.jsonl
# -rw-r--r-- 1 root root 6.2M Jul 15 18:43 gen-word-315-count.jsonl
# -rw-r--r-- 1 root root 6.3M Jul 15 18:43 gen-word-320-count.jsonl
# -rw-r--r-- 1 root root 6.4M Jul 15 18:43 gen-word-325-count.jsonl
# -rw-r--r-- 1 root root 6.5M Jul 15 18:43 gen-word-330-count.jsonl
# -rw-r--r-- 1 root root 6.6M Jul 15 18:43 gen-word-335-count.jsonl
# -rw-r--r-- 1 root root 6.7M Jul 15 18:43 gen-word-340-count.jsonl
# -rw-r--r-- 1 root root 6.8M Jul 15 18:43 gen-word-345-count.jsonl
# -rw-r--r-- 1 root root 435K Jul 15 18:43 gen-word-35-count.jsonl
# -rw-r--r-- 1 root root 6.9M Jul 15 18:43 gen-word-350-count.jsonl
# -rw-r--r-- 1 root root 7.0M Jul 15 18:43 gen-word-355-count.jsonl
# -rw-r--r-- 1 root root 7.1M Jul 15 18:43 gen-word-360-count.jsonl
# -rw-r--r-- 1 root root 7.1M Jul 15 18:43 gen-word-365-count.jsonl
# -rw-r--r-- 1 root root 7.3M Jul 15 18:43 gen-word-370-count.jsonl
# -rw-r--r-- 1 root root 7.4M Jul 15 18:43 gen-word-375-count.jsonl
# -rw-r--r-- 1 root root 7.4M Jul 15 18:43 gen-word-380-count.jsonl
# -rw-r--r-- 1 root root 7.6M Jul 15 18:43 gen-word-385-count.jsonl
# -rw-r--r-- 1 root root 7.6M Jul 15 18:43 gen-word-390-count.jsonl
# -rw-r--r-- 1 root root 7.7M Jul 15 18:43 gen-word-395-count.jsonl
# -rw-r--r-- 1 root root 484K Jul 15 18:43 gen-word-40-count.jsonl
# -rw-r--r-- 1 root root 7.8M Jul 15 18:43 gen-word-400-count.jsonl
# -rw-r--r-- 1 root root 7.9M Jul 15 18:43 gen-word-405-count.jsonl
# -rw-r--r-- 1 root root 8.0M Jul 15 18:43 gen-word-410-count.jsonl
# -rw-r--r-- 1 root root 8.1M Jul 15 18:43 gen-word-415-count.jsonl
# -rw-r--r-- 1 root root 8.2M Jul 15 18:43 gen-word-420-count.jsonl
# -rw-r--r-- 1 root root 8.3M Jul 15 18:43 gen-word-425-count.jsonl
# -rw-r--r-- 1 root root 8.4M Jul 15 18:43 gen-word-430-count.jsonl
# -rw-r--r-- 1 root root 8.5M Jul 15 18:43 gen-word-435-count.jsonl
# -rw-r--r-- 1 root root 8.6M Jul 15 18:43 gen-word-440-count.jsonl
# -rw-r--r-- 1 root root 8.7M Jul 15 18:43 gen-word-445-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 18:43 gen-word-45-count.jsonl
# -rw-r--r-- 1 root root 8.8M Jul 15 18:43 gen-word-450-count.jsonl
# -rw-r--r-- 1 root root 147K Jul 15 18:43 gen-word-5-count.jsonl
# -rw-r--r-- 1 root root 1.2M Jul 15 18:43 gen-word-50-count.jsonl
# -rw-r--r-- 1 root root 1.3M Jul 15 18:43 gen-word-55-count.jsonl
# -rw-r--r-- 1 root root 1.4M Jul 15 18:43 gen-word-60-count.jsonl
# -rw-r--r-- 1 root root 1.5M Jul 15 18:43 gen-word-65-count.jsonl
# -rw-r--r-- 1 root root 1.6M Jul 15 18:43 gen-word-70-count.jsonl
# -rw-r--r-- 1 root root 1.7M Jul 15 18:43 gen-word-75-count.jsonl
# -rw-r--r-- 1 root root 1.8M Jul 15 18:43 gen-word-80-count.jsonl
# -rw-r--r-- 1 root root 1.8M Jul 15 18:43 gen-word-85-count.jsonl
# -rw-r--r-- 1 root root 1.9M Jul 15 18:43 gen-word-90-count.jsonl
# -rw-r--r-- 1 root root 2.0M Jul 15 18:43 gen-word-95-count.jsonl
# -rw-r--r-- 1 root root 514K Jul 15 18:43 shuffle-word-10-count.jsonl
# -rw-r--r-- 1 root root 567K Jul 15 18:43 shuffle-word-100-count.jsonl
# -rw-r--r-- 1 root root 559K Jul 15 18:43 shuffle-word-105-count.jsonl
# -rw-r--r-- 1 root root 553K Jul 15 18:43 shuffle-word-110-count.jsonl
# -rw-r--r-- 1 root root 550K Jul 15 18:43 shuffle-word-115-count.jsonl
# -rw-r--r-- 1 root root 557K Jul 15 18:43 shuffle-word-120-count.jsonl
# -rw-r--r-- 1 root root 547K Jul 15 18:43 shuffle-word-125-count.jsonl
# -rw-r--r-- 1 root root 548K Jul 15 18:43 shuffle-word-130-count.jsonl
# -rw-r--r-- 1 root root 541K Jul 15 18:43 shuffle-word-135-count.jsonl
# -rw-r--r-- 1 root root 547K Jul 15 18:43 shuffle-word-140-count.jsonl
# -rw-r--r-- 1 root root 546K Jul 15 18:43 shuffle-word-145-count.jsonl
# -rw-r--r-- 1 root root 427K Jul 15 18:43 shuffle-word-15-count.jsonl
# -rw-r--r-- 1 root root 543K Jul 15 18:43 shuffle-word-150-count.jsonl
# -rw-r--r-- 1 root root 541K Jul 15 18:43 shuffle-word-155-count.jsonl
# -rw-r--r-- 1 root root 547K Jul 15 18:43 shuffle-word-160-count.jsonl
# -rw-r--r-- 1 root root 546K Jul 15 18:43 shuffle-word-165-count.jsonl
# -rw-r--r-- 1 root root 545K Jul 15 18:43 shuffle-word-170-count.jsonl
# -rw-r--r-- 1 root root 542K Jul 15 18:43 shuffle-word-175-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 15 18:43 shuffle-word-180-count.jsonl
# -rw-r--r-- 1 root root 539K Jul 15 18:43 shuffle-word-185-count.jsonl
# -rw-r--r-- 1 root root 542K Jul 15 18:43 shuffle-word-190-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 15 18:43 shuffle-word-195-count.jsonl
# -rw-r--r-- 1 root root 380K Jul 15 18:43 shuffle-word-20-count.jsonl
# -rw-r--r-- 1 root root 546K Jul 15 18:43 shuffle-word-200-count.jsonl
# -rw-r--r-- 1 root root 544K Jul 15 18:43 shuffle-word-205-count.jsonl
# -rw-r--r-- 1 root root 542K Jul 15 18:43 shuffle-word-210-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 15 18:43 shuffle-word-215-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 15 18:43 shuffle-word-220-count.jsonl
# -rw-r--r-- 1 root root 540K Jul 15 18:43 shuffle-word-225-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 15 18:43 shuffle-word-230-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 15 18:43 shuffle-word-235-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 15 18:43 shuffle-word-240-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 15 18:43 shuffle-word-245-count.jsonl
# -rw-r--r-- 1 root root 368K Jul 15 18:43 shuffle-word-25-count.jsonl
# -rw-r--r-- 1 root root 537K Jul 15 18:43 shuffle-word-250-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 15 18:43 shuffle-word-255-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 15 18:43 shuffle-word-260-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 15 18:43 shuffle-word-265-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 15 18:43 shuffle-word-270-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 15 18:43 shuffle-word-275-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 15 18:43 shuffle-word-280-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 15 18:43 shuffle-word-285-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 18:43 shuffle-word-290-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 15 18:43 shuffle-word-295-count.jsonl
# -rw-r--r-- 1 root root 341K Jul 15 18:43 shuffle-word-30-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 15 18:43 shuffle-word-300-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 15 18:43 shuffle-word-305-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 18:43 shuffle-word-310-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 18:43 shuffle-word-315-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 18:43 shuffle-word-320-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 18:43 shuffle-word-325-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 15 18:43 shuffle-word-330-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 18:43 shuffle-word-335-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 18:43 shuffle-word-340-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 18:43 shuffle-word-345-count.jsonl
# -rw-r--r-- 1 root root 330K Jul 15 18:43 shuffle-word-35-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 15 18:43 shuffle-word-350-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 18:43 shuffle-word-355-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 15 18:43 shuffle-word-360-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 18:43 shuffle-word-365-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 18:43 shuffle-word-370-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 18:43 shuffle-word-375-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 15 18:43 shuffle-word-380-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 18:43 shuffle-word-385-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 18:43 shuffle-word-390-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 18:43 shuffle-word-395-count.jsonl
# -rw-r--r-- 1 root root 319K Jul 15 18:43 shuffle-word-40-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 18:43 shuffle-word-400-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 15 18:43 shuffle-word-405-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 18:43 shuffle-word-410-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 18:43 shuffle-word-415-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 18:43 shuffle-word-420-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 15 18:43 shuffle-word-425-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 18:43 shuffle-word-430-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 18:43 shuffle-word-435-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 18:43 shuffle-word-440-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 18:43 shuffle-word-445-count.jsonl
# -rw-r--r-- 1 root root 311K Jul 15 18:43 shuffle-word-45-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 18:43 shuffle-word-450-count.jsonl
# -rw-r--r-- 1 root root 790K Jul 15 18:43 shuffle-word-5-count.jsonl
# -rw-r--r-- 1 root root 612K Jul 15 18:43 shuffle-word-50-count.jsonl
# -rw-r--r-- 1 root root 609K Jul 15 18:43 shuffle-word-55-count.jsonl
# -rw-r--r-- 1 root root 591K Jul 15 18:43 shuffle-word-60-count.jsonl
# -rw-r--r-- 1 root root 593K Jul 15 18:43 shuffle-word-65-count.jsonl
# -rw-r--r-- 1 root root 586K Jul 15 18:43 shuffle-word-70-count.jsonl
# -rw-r--r-- 1 root root 575K Jul 15 18:43 shuffle-word-75-count.jsonl
# -rw-r--r-- 1 root root 577K Jul 15 18:43 shuffle-word-80-count.jsonl
# -rw-r--r-- 1 root root 581K Jul 15 18:43 shuffle-word-85-count.jsonl
# -rw-r--r-- 1 root root 574K Jul 15 18:43 shuffle-word-90-count.jsonl
# -rw-r--r-- 1 root root 566K Jul 15 18:43 shuffle-word-95-count.jsonl
# -rw-r--r-- 1 root root 119K Jul 15 18:43 word-2-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-A-mem-finetune-3.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-A-mem-finetune-3/"
# Out:
# Resolving data files: 100%|███████████████| 181/181 [00:00<00:00, 145741.80it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-5a26de720865b5a0/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|████████████████████| 1/1 [00:00<00:00, 714.65it/s]
# Extracting data files: 100%|██████████████████████| 1/1 [00:00<00:00, 26.73it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-5a26de720865b5a0/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 77.87it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-A-mem-finetune-3.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-3 (bs=256, train-ctx=1024, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=1024
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 1554592689
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 1554592689
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230715_184416-bj1jhqvn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run TokenShift-A - Mem-Finetune-3 (bs=256, train-ctx=1024, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/bj1jhqvn
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Resolving data files: 100%|███████████████| 181/181 [00:00<00:00, 183241.38it/s]
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-5a26de720865b5a0/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 80.49it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-5a26de720865b5a0/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-20a0968589ab321e_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-5a26de720865b5a0/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-651b58d9197388e4_*_of_00064.arrow
# [rank: 0] Global seed set to 1554592689
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-15 18:44:28,898] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [rank: 5] Global seed set to 1554592689
# [rank: 4] Global seed set to 1554592689
# [rank: 3] Global seed set to 1554592689
# [rank: 7] Global seed set to 1554592689
# [rank: 1] Global seed set to 1554592689
# [rank: 2] Global seed set to 1554592689
# [rank: 6] Global seed set to 1554592689
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# Loading extension module wkv_1024_bf16...
# [rank: 3] Global seed set to 1554592689
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-15 18:44:42,623] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 4] Global seed set to 1554592689
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-15 18:44:43,295] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 1554592689
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-15 18:44:43,354] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 6] Global seed set to 1554592689
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-15 18:44:43,378] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 1554592689
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-15 18:44:43,387] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 1554592689
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-15 18:44:43,394] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 1554592689
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-07-15 18:44:43,400] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  4.000e-04 (0.0004)
#     - lr_final: 1.000e-04 (0.0001)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06323957443237305 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1011955738067627 seconds
# Time to load fused_adam op: 0.10132074356079102 seconds
# Time to load fused_adam op: 0.10139703750610352 seconds
# Time to load fused_adam op: 0.10124039649963379 seconds
# Time to load fused_adam op: 0.10135793685913086 seconds
# Time to load fused_adam op: 0.10123896598815918 seconds
# Time to load fused_adam op: 0.10177493095397949 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.0656278133392334 seconds
# Loading extension module utils...
# Time to load utils op: 0.10212206840515137 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10141730308532715 seconds
# Time to load utils op: 0.1013784408569336 seconds
# Loading extension module utils...
# Time to load utils op: 0.10180497169494629 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10181164741516113 seconds
# Time to load utils op: 0.10139942169189453 seconds
# Time to load utils op: 0.10174298286437988 seconds
# Rank: 0 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 7 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 4 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 3 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 1 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002593994140625 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Time to load utils op: 0.0002498626708984375 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002624988555908203 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00019216537475585938 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00034332275390625 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003325939178466797 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003380775451660156 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0004937648773193359 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 128 M
# 1 | blocks | ModuleList | 1.0 B
# 2 | ln_out | LayerNorm  | 5.1 K
# 3 | head   | Linear     | 128 M
# --------------------------------------
# 1.3 B     Trainable params
# 0         Non-trainable params
# 1.3 B     Total params
# 5,120.512 Total estimated model params size (MB)
# Epoch 0:   3%| | 800/26168 [04:36<2:26:00,  2.90it/s, v_num=hqvn, train/loss=1.8/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 26168/26168 [2:33:24<00:00,  2.84it/s, v_num=hqvn, train/loss=0
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/27 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/27 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     cli_main()
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     self._run(model, ckpt_path=ckpt_path)
#     output = fn(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     return forward_call(*args, **kwargs)
#     total_loss = self.compute_loss(batch, batch_idx, False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'. Did you mean: 'att_shift_states'?
# Traceback (most recent call last):
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 69, in <module>
#     cli_main()
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/lightning_trainer.py", line 62, in cli_main
#     LightningCLI(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 353, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/cli.py", line 642, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 42, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 92, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 134, in run
#     self.on_advance_end()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py", line 248, in on_advance_end
#     self.val_loop.run()
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/utilities.py", line 177, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 115, in run
#     self._evaluation_step(batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/evaluation_loop.py", line 375, in _evaluation_step
#     output = call._call_strategy_hook(trainer, hook_name, *step_kwargs.values())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py", line 288, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/deepspeed.py", line 906, in validation_step
#     return self.model(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/deepspeed/runtime/engine.py", line 1736, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/lightning/pytorch/overrides/base.py", line 102, in forward
#     return self._forward_module.validation_step(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1101, in validation_step
#     total_loss = self.compute_loss(batch, batch_idx, False)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/rwkv5x-tokenshift-exp-A/RWKV-v4wavenet/src/model.py", line 1058, in compute_loss
#     states.att_shift_states,
#     ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BlockStateList' object has no attribute 'shift_states'
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# wandb: / 0.027 MB of 0.027 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:              batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▄▇▂▇█▆▂▆▃▃▅▁▄▇▄▁▂▁▅▇▂█▅▇▂▇▅▁▃▆▄██▃▆▆▆▅▁▄
# wandb:               substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ▂▅█▃▄▁▂▄▁▃▇▂▂▃▁▅▃▄▄▂▁▁▆▂▆▃▂▂▁▁▁▄▁▅▁▁▁▂▆▁
# wandb:   trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 26167
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 70
# wandb:               substep 209336
# wandb:            train/loss 0.00922
# wandb:   trainer/global_step 817
# wandb: trainer/learning_rate 0.0001
# wandb:
# wandb: 🚀 View run TokenShift-A - Mem-Finetune-3 (bs=256, train-ctx=1024, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/bj1jhqvn
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230715_184416-bj1jhqvn/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-A-mem-finetune-3/last.ckpt" \
        "../model/TokenShift-A-Tune3.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-A-Tune3.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-A-mem-finetune-3/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 222 params 1280128000 elements
# Saving fp32 state dict to ../model/TokenShift-A-Tune3.pth
# -rw-r--r-- 1 root root 4.8G Jul 15 21:18 ../model/TokenShift-A-Tune3.pth

# %%
# Lets do a memory eval 
#
# We should start approaching the full potential of the model, unless its able to exceed 250 tokens of memory
#
# !python3 ../memory_script/eval_memory_guided.py "{PROJECT_DIR}/model/TokenShift-A-Tune3.pth"
# Out:
# RWKV_HEAD_QK_DIM 0 RWKV_JIT_ON 1
#
# blocks.0.att.key.weight                  float32    cuda:0
# blocks.0.att.output.weight               float32    cuda:0
# blocks.0.att.receptance.weight           float32    cuda:0
# blocks.0.att.time_mix_k                  float32    cuda:0
# blocks.0.att.time_mix_r                  float32    cuda:0
# blocks.0.att.time_mix_v                  float32    cuda:0
# blocks.0.att.value.weight                float32    cuda:0
# blocks.0.ffn.key.weight                  float32    cuda:0
# blocks.0.ffn.receptance.weight           float32    cuda:0
# blocks.0.ffn.time_mix_k                  float32    cuda:0
# blocks.0.ffn.time_mix_r                  float32    cuda:0
# blocks.0.ffn.value.weight                float32    cuda:0
# blocks.0.ln0.bias                        float32    cuda:0
# blocks.0.ln0.weight                      float32    cuda:0
# blocks.0.ln1.bias                        float32    cuda:0
# blocks.0.ln1.weight                      float32    cuda:0
# blocks.0.ln2.bias                        float32    cuda:0
# blocks.0.ln2.weight                      float32    cuda:0
# ................................................................................................................................................................................
# emb.weight                               float32    cpu
# head.weight                              float32    cuda:0
# ln_out.bias                              float32    cuda:0
# ln_out.weight                            float32    cuda:0
# blocks.0.att.time_decay                  float32    cuda:0
# ...........
# blocks.0.att.time_first                  float32    cuda:0
# ...........###
# ### Model validation start ###
# ###
# Model validation at 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# Model validation at 10 tokens : 70.0% similarity, with 7 matched token, and 3 token mismatch
# Model validation at 15 tokens : 53.333333333333336% similarity, with 8 matched token, and 7 token mismatch
# Model validation at 20 tokens : 55.00000000000001% similarity, with 11 matched token, and 9 token mismatch
# Model validation at 25 tokens : 40.0% similarity, with 10 matched token, and 15 token mismatch
# Model validation at 30 tokens : 30.0% similarity, with 9 matched token, and 21 token mismatch
# Model validation at 35 tokens : 25.71428571428571% similarity, with 9 matched token, and 26 token mismatch
# Model validation at 40 tokens : 22.5% similarity, with 9 matched token, and 31 token mismatch
# Model validation at 45 tokens : 20.0% similarity, with 9 matched token, and 36 token mismatch
# Model validation at 50 tokens : 20.0% similarity, with 10 matched token, and 40 token mismatch
# Model validation at 55 tokens : 20.0% similarity, with 11 matched token, and 44 token mismatch
# Model validation at 60 tokens : 23.333333333333332% similarity, with 14 matched token, and 46 token mismatch
# Model validation at 65 tokens : 26.153846153846157% similarity, with 17 matched token, and 48 token mismatch
# Model validation at 70 tokens : 28.57142857142857% similarity, with 20 matched token, and 50 token mismatch
# Model validation at 75 tokens : 29.333333333333332% similarity, with 22 matched token, and 53 token mismatch
# Model validation at 80 tokens : 30.0% similarity, with 24 matched token, and 56 token mismatch
# Model validation at 85 tokens : 24.705882352941178% similarity, with 21 matched token, and 64 token mismatch
# Model validation at 90 tokens : 28.888888888888886% similarity, with 26 matched token, and 64 token mismatch
# Model validation at 95 tokens : 27.368421052631582% similarity, with 26 matched token, and 69 token mismatch
# Model validation at 100 tokens : 26.0% similarity, with 26 matched token, and 74 token mismatch
# Model validation at 110 tokens : 22.727272727272727% similarity, with 25 matched token, and 85 token mismatch
# Model validation at 120 tokens : 24.166666666666668% similarity, with 29 matched token, and 91 token mismatch
# Model validation at 130 tokens : 20.0% similarity, with 26 matched token, and 104 token mismatch
# Model validation at 140 tokens : 20.714285714285715% similarity, with 29 matched token, and 111 token mismatch
# Model validation at 150 tokens : 22.666666666666664% similarity, with 34 matched token, and 116 token mismatch
# Model validation at 175 tokens : 20.57142857142857% similarity, with 36 matched token, and 139 token mismatch
# Model validation at 200 tokens : 21.5% similarity, with 43 matched token, and 157 token mismatch
# Model validation at 225 tokens : 20.0% similarity, with 45 matched token, and 180 token mismatch
# Model validation at 250 tokens : 16.400000000000002% similarity, with 41 matched token, and 209 token mismatch
# Model validation at 275 tokens : 13.454545454545455% similarity, with 37 matched token, and 238 token mismatch
# Model validation at 300 tokens : 13.333333333333334% similarity, with 40 matched token, and 260 token mismatch
# Model validation at 325 tokens : 11.692307692307692% similarity, with 38 matched token, and 287 token mismatch
# Model validation at 350 tokens : 10.857142857142858% similarity, with 38 matched token, and 312 token mismatch
# Model validation at 375 tokens : 9.6% similarity, with 36 matched token, and 339 token mismatch
# Model validation at 400 tokens : 9.0% similarity, with 36 matched token, and 364 token mismatch
# Model validation at 425 tokens : 8.0% similarity, with 34 matched token, and 391 token mismatch
# Model validation at 450 tokens : 6.888888888888889% similarity, with 31 matched token, and 419 token mismatch
# Model validation at 475 tokens : 6.526315789473684% similarity, with 31 matched token, and 444 token mismatch
# Model validation at 500 tokens : 6.4% similarity, with 32 matched token, and 468 token mismatch
# Model validation at 550 tokens : 5.090909090909091% similarity, with 28 matched token, and 522 token mismatch
# Model validation at 600 tokens : 4.5% similarity, with 27 matched token, and 573 token mismatch
# Model validation at 650 tokens : 4.3076923076923075% similarity, with 28 matched token, and 622 token mismatch
# Model validation at 700 tokens : 3.571428571428571% similarity, with 25 matched token, and 675 token mismatch

# %% [markdown]
# ## Tune 4 : Ramping up the ctx size (4096), memory training
#
# - Tune 4: Mid ctx size (4096), same as tune 4, but extended in context size
#
# This intentionally a much larger dataset, and lower learning rate to help ensure we push the model to its absolute limits.

# %%
# %%script bash
#
# ########################################
# # Generate the required jsonl dataset
# ########################################
#
# # Reset the dataset dir
# mkdir -p ../dataset
# rm -rf ../dataset/*.jsonl
#
# # Generate the various datasets
# echo "## Generating word reptition dataset ##"
#
# #
# # We reduce the training set for < 50 words - and shift the focus upwards
# # (aka 50-100 token * 2 : ~100 - 250 token ctx len)
# #
# python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/word-2-count.jsonl 2 1000 &
# for i in {5..45..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 100 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 1 &
# done
#
# #
# # Ramping up the 50+ - 2000 words dataset
# #
# for i in {50..2000..5}
# do
#     python ../memory_script/gen_limited_prompt_completion_jsonl.py ../dataset/gen-word-$i-count.jsonl $i 2000 &
#     python ../memory_script/shuffle_limited_prompt_completion_jsonl.py ../dataset/shuffle-word-$i-count.jsonl $i 20 &
# done
#
# wait
# echo "## Done ##"
#
# ls -alh ../dataset/
# Out:
# ## Generating word reptition dataset ##
# Generated JSONL file with - 40 max words, 100 samples - at ../dataset/gen-word-40-count.jsonl
# Generated a single JSONL file with 87 samples (1 token repeat) - 30 max words - at ../dataset/shuffle-word-30-count.jsonl
# Generated JSONL file with - 5 max words, 100 samples - at ../dataset/gen-word-5-count.jsonl
# Generated a single JSONL file with 129 samples (1 token repeat) - 20 max words - at ../dataset/shuffle-word-20-count.jsonl
# Generated JSONL file with - 25 max words, 100 samples - at ../dataset/gen-word-25-count.jsonl
# Generated a single JSONL file with 263 samples (1 token repeat) - 10 max words - at ../dataset/shuffle-word-10-count.jsonl
# Generated JSONL file with - 35 max words, 100 samples - at ../dataset/gen-word-35-count.jsonl
# Generated JSONL file with - 45 max words, 100 samples - at ../dataset/gen-word-45-count.jsonl
# Generated JSONL file with - 20 max words, 100 samples - at ../dataset/gen-word-20-count.jsonl
# Generated JSONL file with - 30 max words, 100 samples - at ../dataset/gen-word-30-count.jsonl
# Generated a single JSONL file with 67 samples (1 token repeat) - 40 max words - at ../dataset/shuffle-word-40-count.jsonl
# Generated a single JSONL file with 77 samples (1 token repeat) - 35 max words - at ../dataset/shuffle-word-35-count.jsonl
# Generated a single JSONL file with 106 samples (1 token repeat) - 25 max words - at ../dataset/shuffle-word-25-count.jsonl
# Generated a single JSONL file with 58 samples (1 token repeat) - 45 max words - at ../dataset/shuffle-word-45-count.jsonl
# Generated JSONL file with - 10 max words, 100 samples - at ../dataset/gen-word-10-count.jsonl
# Generated JSONL file with - 15 max words, 100 samples - at ../dataset/gen-word-15-count.jsonl
# Generated a single JSONL file with 180 samples (1 token repeat) - 15 max words - at ../dataset/shuffle-word-15-count.jsonl
# Generated a single JSONL file with 574 samples (1 token repeat) - 5 max words - at ../dataset/shuffle-word-5-count.jsonl
# Generated JSONL file with - 2 max words, 1000 samples - at ../dataset/word-2-count.jsonl
# Generated a single JSONL file with 410 samples (20 token repeat) - 105 max words - at ../dataset/shuffle-word-105-count.jsonl
# Generated a single JSONL file with 628 samples (20 token repeat) - 85 max words - at ../dataset/shuffle-word-85-count.jsonl
# Generated a single JSONL file with 1055 samples (20 token repeat) - 50 max words - at ../dataset/shuffle-word-50-count.jsonl
# Generated a single JSONL file with 357 samples (20 token repeat) - 125 max words - at ../dataset/shuffle-word-125-count.jsonl
# Generated a single JSONL file with 762 samples (20 token repeat) - 70 max words - at ../dataset/shuffle-word-70-count.jsonl
# Generated a single JSONL file with 534 samples (20 token repeat) - 100 max words - at ../dataset/shuffle-word-100-count.jsonl
# Generated a single JSONL file with 561 samples (20 token repeat) - 95 max words - at ../dataset/shuffle-word-95-count.jsonl
# Generated a single JSONL file with 193 samples (20 token repeat) - 240 max words - at ../dataset/shuffle-word-240-count.jsonl
# Generated a single JSONL file with 659 samples (20 token repeat) - 80 max words - at ../dataset/shuffle-word-80-count.jsonl
# Generated a single JSONL file with 589 samples (20 token repeat) - 90 max words - at ../dataset/shuffle-word-90-count.jsonl
# Generated a single JSONL file with 707 samples (20 token repeat) - 75 max words - at ../dataset/shuffle-word-75-count.jsonl
# Generated a single JSONL file with 370 samples (20 token repeat) - 120 max words - at ../dataset/shuffle-word-120-count.jsonl
# Generated a single JSONL file with 399 samples (20 token repeat) - 110 max words - at ../dataset/shuffle-word-110-count.jsonl
# Generated a single JSONL file with 323 samples (20 token repeat) - 140 max words - at ../dataset/shuffle-word-140-count.jsonl
# Generated a single JSONL file with 283 samples (20 token repeat) - 170 max words - at ../dataset/shuffle-word-170-count.jsonl
# Generated a single JSONL file with 380 samples (20 token repeat) - 115 max words - at ../dataset/shuffle-word-115-count.jsonl
# Generated a single JSONL file with 184 samples (20 token repeat) - 275 max words - at ../dataset/shuffle-word-275-count.jsonl
# Generated a single JSONL file with 271 samples (20 token repeat) - 185 max words - at ../dataset/shuffle-word-185-count.jsonl
# Generated a single JSONL file with 145 samples (20 token repeat) - 305 max words - at ../dataset/shuffle-word-305-count.jsonl
# Generated a single JSONL file with 806 samples (20 token repeat) - 65 max words - at ../dataset/shuffle-word-65-count.jsonl
# Generated a single JSONL file with 317 samples (20 token repeat) - 145 max words - at ../dataset/shuffle-word-145-count.jsonl
# Generated a single JSONL file with 299 samples (20 token repeat) - 155 max words - at ../dataset/shuffle-word-155-count.jsonl
# Generated a single JSONL file with 289 samples (20 token repeat) - 165 max words - at ../dataset/shuffle-word-165-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 410 max words - at ../dataset/shuffle-word-410-count.jsonl
# Generated a single JSONL file with 184 samples (20 token repeat) - 285 max words - at ../dataset/shuffle-word-285-count.jsonl
# Generated a single JSONL file with 202 samples (20 token repeat) - 220 max words - at ../dataset/shuffle-word-220-count.jsonl
# Generated JSONL file with - 50 max words, 2000 samples - at ../dataset/gen-word-50-count.jsonl
# Generated JSONL file with - 60 max words, 2000 samples - at ../dataset/gen-word-60-count.jsonl
# Generated JSONL file with - 80 max words, 2000 samples - at ../dataset/gen-word-80-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 335 max words - at ../dataset/shuffle-word-335-count.jsonl
# Generated a single JSONL file with 183 samples (20 token repeat) - 290 max words - at ../dataset/shuffle-word-290-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 360 max words - at ../dataset/shuffle-word-360-count.jsonl
# Generated a single JSONL file with 343 samples (20 token repeat) - 130 max words - at ../dataset/shuffle-word-130-count.jsonl
# Generated a single JSONL file with 115 samples (20 token repeat) - 440 max words - at ../dataset/shuffle-word-440-count.jsonl
# Generated a single JSONL file with 192 samples (20 token repeat) - 250 max words - at ../dataset/shuffle-word-250-count.jsonl
# Generated JSONL file with - 75 max words, 2000 samples - at ../dataset/gen-word-75-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 395 max words - at ../dataset/shuffle-word-395-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 910 max words - at ../dataset/shuffle-word-910-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1825 max words - at ../dataset/shuffle-word-1825-count.jsonl
# Generated a single JSONL file with 876 samples (20 token repeat) - 60 max words - at ../dataset/shuffle-word-60-count.jsonl
# Generated a single JSONL file with 200 samples (20 token repeat) - 225 max words - at ../dataset/shuffle-word-225-count.jsonl
# Generated a single JSONL file with 270 samples (20 token repeat) - 200 max words - at ../dataset/shuffle-word-200-count.jsonl
# Generated a single JSONL file with 203 samples (20 token repeat) - 215 max words - at ../dataset/shuffle-word-215-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 650 max words - at ../dataset/shuffle-word-650-count.jsonl
# Generated JSONL file with - 110 max words, 2000 samples - at ../dataset/gen-word-110-count.jsonl
# Generated a single JSONL file with 197 samples (20 token repeat) - 235 max words - at ../dataset/shuffle-word-235-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 645 max words - at ../dataset/shuffle-word-645-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1335 max words - at ../dataset/shuffle-word-1335-count.jsonl
# Generated a single JSONL file with 79 samples (20 token repeat) - 720 max words - at ../dataset/shuffle-word-720-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1450 max words - at ../dataset/shuffle-word-1450-count.jsonl
# Generated a single JSONL file with 139 samples (20 token repeat) - 355 max words - at ../dataset/shuffle-word-355-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1340 max words - at ../dataset/shuffle-word-1340-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 495 max words - at ../dataset/shuffle-word-495-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 615 max words - at ../dataset/shuffle-word-615-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 735 max words - at ../dataset/shuffle-word-735-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1015 max words - at ../dataset/shuffle-word-1015-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1600 max words - at ../dataset/shuffle-word-1600-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 385 max words - at ../dataset/shuffle-word-385-count.jsonl
# Generated a single JSONL file with 53 samples (20 token repeat) - 1240 max words - at ../dataset/shuffle-word-1240-count.jsonl
# Generated JSONL file with - 55 max words, 2000 samples - at ../dataset/gen-word-55-count.jsonl
# Generated a single JSONL file with 181 samples (20 token repeat) - 295 max words - at ../dataset/shuffle-word-295-count.jsonl
# Generated a single JSONL file with 182 samples (20 token repeat) - 280 max words - at ../dataset/shuffle-word-280-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 445 max words - at ../dataset/shuffle-word-445-count.jsonl
# Generated a single JSONL file with 296 samples (20 token repeat) - 160 max words - at ../dataset/shuffle-word-160-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 665 max words - at ../dataset/shuffle-word-665-count.jsonl
# Generated a single JSONL file with 145 samples (20 token repeat) - 310 max words - at ../dataset/shuffle-word-310-count.jsonl
# Generated JSONL file with - 120 max words, 2000 samples - at ../dataset/gen-word-120-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 330 max words - at ../dataset/shuffle-word-330-count.jsonl
# Generated a single JSONL file with 186 samples (20 token repeat) - 245 max words - at ../dataset/shuffle-word-245-count.jsonl
# Generated JSONL file with - 90 max words, 2000 samples - at ../dataset/gen-word-90-count.jsonl
# Generated a single JSONL file with 207 samples (20 token repeat) - 210 max words - at ../dataset/shuffle-word-210-count.jsonl
# Generated JSONL file with - 70 max words, 2000 samples - at ../dataset/gen-word-70-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1555 max words - at ../dataset/shuffle-word-1555-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 785 max words - at ../dataset/shuffle-word-785-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 950 max words - at ../dataset/shuffle-word-950-count.jsonl
# Generated JSONL file with - 95 max words, 2000 samples - at ../dataset/gen-word-95-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 985 max words - at ../dataset/shuffle-word-985-count.jsonl
# Generated a single JSONL file with 272 samples (20 token repeat) - 195 max words - at ../dataset/shuffle-word-195-count.jsonl
# Generated a single JSONL file with 65 samples (20 token repeat) - 890 max words - at ../dataset/shuffle-word-890-count.jsonl
# Generated a single JSONL file with 308 samples (20 token repeat) - 150 max words - at ../dataset/shuffle-word-150-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1930 max words - at ../dataset/shuffle-word-1930-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 760 max words - at ../dataset/shuffle-word-760-count.jsonl
# Generated a single JSONL file with 199 samples (20 token repeat) - 230 max words - at ../dataset/shuffle-word-230-count.jsonl
# Generated a single JSONL file with 50 samples (20 token repeat) - 1300 max words - at ../dataset/shuffle-word-1300-count.jsonl
# Generated a single JSONL file with 965 samples (20 token repeat) - 55 max words - at ../dataset/shuffle-word-55-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 870 max words - at ../dataset/shuffle-word-870-count.jsonl
# Generated a single JSONL file with 50 samples (20 token repeat) - 1295 max words - at ../dataset/shuffle-word-1295-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1130 max words - at ../dataset/shuffle-word-1130-count.jsonl
# Generated a single JSONL file with 142 samples (20 token repeat) - 345 max words - at ../dataset/shuffle-word-345-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 560 max words - at ../dataset/shuffle-word-560-count.jsonl
# Generated a single JSONL file with 99 samples (20 token repeat) - 535 max words - at ../dataset/shuffle-word-535-count.jsonl
# Generated a single JSONL file with 183 samples (20 token repeat) - 255 max words - at ../dataset/shuffle-word-255-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 340 max words - at ../dataset/shuffle-word-340-count.jsonl
# Generated a single JSONL file with 336 samples (20 token repeat) - 135 max words - at ../dataset/shuffle-word-135-count.jsonl
# Generated a single JSONL file with 182 samples (20 token repeat) - 270 max words - at ../dataset/shuffle-word-270-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 470 max words - at ../dataset/shuffle-word-470-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1005 max words - at ../dataset/shuffle-word-1005-count.jsonl
# Generated a single JSONL file with 65 samples (20 token repeat) - 865 max words - at ../dataset/shuffle-word-865-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 725 max words - at ../dataset/shuffle-word-725-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1900 max words - at ../dataset/shuffle-word-1900-count.jsonl
# Generated a single JSONL file with 184 samples (20 token repeat) - 260 max words - at ../dataset/shuffle-word-260-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 740 max words - at ../dataset/shuffle-word-740-count.jsonl
# Generated a single JSONL file with 99 samples (20 token repeat) - 555 max words - at ../dataset/shuffle-word-555-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 575 max words - at ../dataset/shuffle-word-575-count.jsonl
# Generated a single JSONL file with 120 samples (20 token repeat) - 405 max words - at ../dataset/shuffle-word-405-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 545 max words - at ../dataset/shuffle-word-545-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 315 max words - at ../dataset/shuffle-word-315-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 460 max words - at ../dataset/shuffle-word-460-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 960 max words - at ../dataset/shuffle-word-960-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1510 max words - at ../dataset/shuffle-word-1510-count.jsonl
# Generated a single JSONL file with 217 samples (20 token repeat) - 205 max words - at ../dataset/shuffle-word-205-count.jsonl
# Generated a single JSONL file with 275 samples (20 token repeat) - 175 max words - at ../dataset/shuffle-word-175-count.jsonl
# Generated a single JSONL file with 181 samples (20 token repeat) - 300 max words - at ../dataset/shuffle-word-300-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 420 max words - at ../dataset/shuffle-word-420-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1475 max words - at ../dataset/shuffle-word-1475-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1115 max words - at ../dataset/shuffle-word-1115-count.jsonl
# Generated a single JSONL file with 62 samples (20 token repeat) - 825 max words - at ../dataset/shuffle-word-825-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1895 max words - at ../dataset/shuffle-word-1895-count.jsonl
# Generated a single JSONL file with 51 samples (20 token repeat) - 1250 max words - at ../dataset/shuffle-word-1250-count.jsonl
# Generated a single JSONL file with 99 samples (20 token repeat) - 530 max words - at ../dataset/shuffle-word-530-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 520 max words - at ../dataset/shuffle-word-520-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1020 max words - at ../dataset/shuffle-word-1020-count.jsonl
# Generated a single JSONL file with 115 samples (20 token repeat) - 480 max words - at ../dataset/shuffle-word-480-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 380 max words - at ../dataset/shuffle-word-380-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 580 max words - at ../dataset/shuffle-word-580-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1090 max words - at ../dataset/shuffle-word-1090-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 450 max words - at ../dataset/shuffle-word-450-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 565 max words - at ../dataset/shuffle-word-565-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 415 max words - at ../dataset/shuffle-word-415-count.jsonl
# Generated JSONL file with - 100 max words, 2000 samples - at ../dataset/gen-word-100-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1985 max words - at ../dataset/shuffle-word-1985-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 505 max words - at ../dataset/shuffle-word-505-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 905 max words - at ../dataset/shuffle-word-905-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1430 max words - at ../dataset/shuffle-word-1430-count.jsonl
# Generated JSONL file with - 65 max words, 2000 samples - at ../dataset/gen-word-65-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 945 max words - at ../dataset/shuffle-word-945-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1030 max words - at ../dataset/shuffle-word-1030-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 715 max words - at ../dataset/shuffle-word-715-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 810 max words - at ../dataset/shuffle-word-810-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 675 max words - at ../dataset/shuffle-word-675-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1725 max words - at ../dataset/shuffle-word-1725-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 350 max words - at ../dataset/shuffle-word-350-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1375 max words - at ../dataset/shuffle-word-1375-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 525 max words - at ../dataset/shuffle-word-525-count.jsonl
# Generated a single JSONL file with 67 samples (20 token repeat) - 830 max words - at ../dataset/shuffle-word-830-count.jsonl
# Generated a single JSONL file with 50 samples (20 token repeat) - 1285 max words - at ../dataset/shuffle-word-1285-count.jsonl
# Generated a single JSONL file with 116 samples (20 token repeat) - 435 max words - at ../dataset/shuffle-word-435-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 755 max words - at ../dataset/shuffle-word-755-count.jsonl
# Generated a single JSONL file with 45 samples (20 token repeat) - 1230 max words - at ../dataset/shuffle-word-1230-count.jsonl
# Generated a single JSONL file with 143 samples (20 token repeat) - 325 max words - at ../dataset/shuffle-word-325-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1655 max words - at ../dataset/shuffle-word-1655-count.jsonl
# Generated a single JSONL file with 82 samples (20 token repeat) - 670 max words - at ../dataset/shuffle-word-670-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1800 max words - at ../dataset/shuffle-word-1800-count.jsonl
# Generated JSONL file with - 135 max words, 2000 samples - at ../dataset/gen-word-135-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 860 max words - at ../dataset/shuffle-word-860-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 920 max words - at ../dataset/shuffle-word-920-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1815 max words - at ../dataset/shuffle-word-1815-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1095 max words - at ../dataset/shuffle-word-1095-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1795 max words - at ../dataset/shuffle-word-1795-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 745 max words - at ../dataset/shuffle-word-745-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1530 max words - at ../dataset/shuffle-word-1530-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1060 max words - at ../dataset/shuffle-word-1060-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 365 max words - at ../dataset/shuffle-word-365-count.jsonl
# Generated JSONL file with - 140 max words, 2000 samples - at ../dataset/gen-word-140-count.jsonl
# Generated a single JSONL file with 280 samples (20 token repeat) - 180 max words - at ../dataset/shuffle-word-180-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1495 max words - at ../dataset/shuffle-word-1495-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 640 max words - at ../dataset/shuffle-word-640-count.jsonl
# Generated a single JSONL file with 270 samples (20 token repeat) - 190 max words - at ../dataset/shuffle-word-190-count.jsonl
# Generated a single JSONL file with 64 samples (20 token repeat) - 840 max words - at ../dataset/shuffle-word-840-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 625 max words - at ../dataset/shuffle-word-625-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 400 max words - at ../dataset/shuffle-word-400-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 730 max words - at ../dataset/shuffle-word-730-count.jsonl
# Generated a single JSONL file with 79 samples (20 token repeat) - 705 max words - at ../dataset/shuffle-word-705-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 390 max words - at ../dataset/shuffle-word-390-count.jsonl
# Generated a single JSONL file with 61 samples (20 token repeat) - 815 max words - at ../dataset/shuffle-word-815-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1080 max words - at ../dataset/shuffle-word-1080-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1435 max words - at ../dataset/shuffle-word-1435-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1155 max words - at ../dataset/shuffle-word-1155-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1820 max words - at ../dataset/shuffle-word-1820-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1330 max words - at ../dataset/shuffle-word-1330-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 590 max words - at ../dataset/shuffle-word-590-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 975 max words - at ../dataset/shuffle-word-975-count.jsonl
# Generated JSONL file with - 130 max words, 2000 samples - at ../dataset/gen-word-130-count.jsonl
# Generated JSONL file with - 260 max words, 2000 samples - at ../dataset/gen-word-260-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 620 max words - at ../dataset/shuffle-word-620-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 430 max words - at ../dataset/shuffle-word-430-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1185 max words - at ../dataset/shuffle-word-1185-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1630 max words - at ../dataset/shuffle-word-1630-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 790 max words - at ../dataset/shuffle-word-790-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 475 max words - at ../dataset/shuffle-word-475-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 610 max words - at ../dataset/shuffle-word-610-count.jsonl
# Generated a single JSONL file with 51 samples (20 token repeat) - 1235 max words - at ../dataset/shuffle-word-1235-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1745 max words - at ../dataset/shuffle-word-1745-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 900 max words - at ../dataset/shuffle-word-900-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1380 max words - at ../dataset/shuffle-word-1380-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1685 max words - at ../dataset/shuffle-word-1685-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1075 max words - at ../dataset/shuffle-word-1075-count.jsonl
# Generated JSONL file with - 125 max words, 2000 samples - at ../dataset/gen-word-125-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 695 max words - at ../dataset/shuffle-word-695-count.jsonl
# Generated a single JSONL file with 52 samples (20 token repeat) - 1225 max words - at ../dataset/shuffle-word-1225-count.jsonl
# Generated a single JSONL file with 144 samples (20 token repeat) - 320 max words - at ../dataset/shuffle-word-320-count.jsonl
# Generated JSONL file with - 105 max words, 2000 samples - at ../dataset/gen-word-105-count.jsonl
# Generated JSONL file with - 115 max words, 2000 samples - at ../dataset/gen-word-115-count.jsonl
# Generated JSONL file with - 160 max words, 2000 samples - at ../dataset/gen-word-160-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1350 max words - at ../dataset/shuffle-word-1350-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 700 max words - at ../dataset/shuffle-word-700-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1065 max words - at ../dataset/shuffle-word-1065-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 500 max words - at ../dataset/shuffle-word-500-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 805 max words - at ../dataset/shuffle-word-805-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1320 max words - at ../dataset/shuffle-word-1320-count.jsonl
# Generated JSONL file with - 85 max words, 2000 samples - at ../dataset/gen-word-85-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 630 max words - at ../dataset/shuffle-word-630-count.jsonl
# Generated JSONL file with - 450 max words, 2000 samples - at ../dataset/gen-word-450-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1805 max words - at ../dataset/shuffle-word-1805-count.jsonl
# Generated a single JSONL file with 52 samples (20 token repeat) - 1265 max words - at ../dataset/shuffle-word-1265-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1980 max words - at ../dataset/shuffle-word-1980-count.jsonl
# Generated JSONL file with - 320 max words, 2000 samples - at ../dataset/gen-word-320-count.jsonl
# Generated a single JSONL file with 119 samples (20 token repeat) - 425 max words - at ../dataset/shuffle-word-425-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1395 max words - at ../dataset/shuffle-word-1395-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1200 max words - at ../dataset/shuffle-word-1200-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1050 max words - at ../dataset/shuffle-word-1050-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1960 max words - at ../dataset/shuffle-word-1960-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1635 max words - at ../dataset/shuffle-word-1635-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 750 max words - at ../dataset/shuffle-word-750-count.jsonl
# Generated a single JSONL file with 49 samples (20 token repeat) - 1290 max words - at ../dataset/shuffle-word-1290-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1535 max words - at ../dataset/shuffle-word-1535-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1665 max words - at ../dataset/shuffle-word-1665-count.jsonl
# Generated a single JSONL file with 185 samples (20 token repeat) - 265 max words - at ../dataset/shuffle-word-265-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1400 max words - at ../dataset/shuffle-word-1400-count.jsonl
# Generated a single JSONL file with 50 samples (20 token repeat) - 1260 max words - at ../dataset/shuffle-word-1260-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1150 max words - at ../dataset/shuffle-word-1150-count.jsonl
# Generated a single JSONL file with 117 samples (20 token repeat) - 490 max words - at ../dataset/shuffle-word-490-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1670 max words - at ../dataset/shuffle-word-1670-count.jsonl
# Generated a single JSONL file with 82 samples (20 token repeat) - 680 max words - at ../dataset/shuffle-word-680-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 690 max words - at ../dataset/shuffle-word-690-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1840 max words - at ../dataset/shuffle-word-1840-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1660 max words - at ../dataset/shuffle-word-1660-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1365 max words - at ../dataset/shuffle-word-1365-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1325 max words - at ../dataset/shuffle-word-1325-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1990 max words - at ../dataset/shuffle-word-1990-count.jsonl
# Generated a single JSONL file with 49 samples (20 token repeat) - 1245 max words - at ../dataset/shuffle-word-1245-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1605 max words - at ../dataset/shuffle-word-1605-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1390 max words - at ../dataset/shuffle-word-1390-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1590 max words - at ../dataset/shuffle-word-1590-count.jsonl
# Generated a single JSONL file with 118 samples (20 token repeat) - 455 max words - at ../dataset/shuffle-word-455-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1440 max words - at ../dataset/shuffle-word-1440-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 915 max words - at ../dataset/shuffle-word-915-count.jsonl
# Generated a single JSONL file with 116 samples (20 token repeat) - 485 max words - at ../dataset/shuffle-word-485-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 970 max words - at ../dataset/shuffle-word-970-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1615 max words - at ../dataset/shuffle-word-1615-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1890 max words - at ../dataset/shuffle-word-1890-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1715 max words - at ../dataset/shuffle-word-1715-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 765 max words - at ../dataset/shuffle-word-765-count.jsonl
# Generated a single JSONL file with 50 samples (20 token repeat) - 1255 max words - at ../dataset/shuffle-word-1255-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1680 max words - at ../dataset/shuffle-word-1680-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1920 max words - at ../dataset/shuffle-word-1920-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1345 max words - at ../dataset/shuffle-word-1345-count.jsonl
# Generated a single JSONL file with 42 samples (20 token repeat) - 1305 max words - at ../dataset/shuffle-word-1305-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1850 max words - at ../dataset/shuffle-word-1850-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1195 max words - at ../dataset/shuffle-word-1195-count.jsonl
# Generated a single JSONL file with 99 samples (20 token repeat) - 510 max words - at ../dataset/shuffle-word-510-count.jsonl
# Generated JSONL file with - 175 max words, 2000 samples - at ../dataset/gen-word-175-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1575 max words - at ../dataset/shuffle-word-1575-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1425 max words - at ../dataset/shuffle-word-1425-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 515 max words - at ../dataset/shuffle-word-515-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1580 max words - at ../dataset/shuffle-word-1580-count.jsonl
# Generated a single JSONL file with 62 samples (20 token repeat) - 820 max words - at ../dataset/shuffle-word-820-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1550 max words - at ../dataset/shuffle-word-1550-count.jsonl
# Generated a single JSONL file with 64 samples (20 token repeat) - 895 max words - at ../dataset/shuffle-word-895-count.jsonl
# Generated JSONL file with - 225 max words, 2000 samples - at ../dataset/gen-word-225-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1045 max words - at ../dataset/shuffle-word-1045-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1785 max words - at ../dataset/shuffle-word-1785-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1755 max words - at ../dataset/shuffle-word-1755-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1360 max words - at ../dataset/shuffle-word-1360-count.jsonl
# Generated JSONL file with - 185 max words, 2000 samples - at ../dataset/gen-word-185-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 710 max words - at ../dataset/shuffle-word-710-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 600 max words - at ../dataset/shuffle-word-600-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1010 max words - at ../dataset/shuffle-word-1010-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1190 max words - at ../dataset/shuffle-word-1190-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1780 max words - at ../dataset/shuffle-word-1780-count.jsonl
# Generated a single JSONL file with 64 samples (20 token repeat) - 875 max words - at ../dataset/shuffle-word-875-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1570 max words - at ../dataset/shuffle-word-1570-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 980 max words - at ../dataset/shuffle-word-980-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1775 max words - at ../dataset/shuffle-word-1775-count.jsonl
# Generated a single JSONL file with 62 samples (20 token repeat) - 835 max words - at ../dataset/shuffle-word-835-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1110 max words - at ../dataset/shuffle-word-1110-count.jsonl
# Generated a single JSONL file with 81 samples (20 token repeat) - 635 max words - at ../dataset/shuffle-word-635-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1865 max words - at ../dataset/shuffle-word-1865-count.jsonl
# Generated a single JSONL file with 63 samples (20 token repeat) - 845 max words - at ../dataset/shuffle-word-845-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1385 max words - at ../dataset/shuffle-word-1385-count.jsonl
# Generated a single JSONL file with 42 samples (20 token repeat) - 1315 max words - at ../dataset/shuffle-word-1315-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1120 max words - at ../dataset/shuffle-word-1120-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1700 max words - at ../dataset/shuffle-word-1700-count.jsonl
# Generated a single JSONL file with 62 samples (20 token repeat) - 885 max words - at ../dataset/shuffle-word-885-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1415 max words - at ../dataset/shuffle-word-1415-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1500 max words - at ../dataset/shuffle-word-1500-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1835 max words - at ../dataset/shuffle-word-1835-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1405 max words - at ../dataset/shuffle-word-1405-count.jsonl
# Generated JSONL file with - 145 max words, 2000 samples - at ../dataset/gen-word-145-count.jsonl
# Generated a single JSONL file with 141 samples (20 token repeat) - 375 max words - at ../dataset/shuffle-word-375-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1610 max words - at ../dataset/shuffle-word-1610-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 770 max words - at ../dataset/shuffle-word-770-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 540 max words - at ../dataset/shuffle-word-540-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1055 max words - at ../dataset/shuffle-word-1055-count.jsonl
# Generated a single JSONL file with 140 samples (20 token repeat) - 370 max words - at ../dataset/shuffle-word-370-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1480 max words - at ../dataset/shuffle-word-1480-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1945 max words - at ../dataset/shuffle-word-1945-count.jsonl
# Generated JSONL file with - 385 max words, 2000 samples - at ../dataset/gen-word-385-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1180 max words - at ../dataset/shuffle-word-1180-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1485 max words - at ../dataset/shuffle-word-1485-count.jsonl
# Generated JSONL file with - 165 max words, 2000 samples - at ../dataset/gen-word-165-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1025 max words - at ../dataset/shuffle-word-1025-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 585 max words - at ../dataset/shuffle-word-585-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1545 max words - at ../dataset/shuffle-word-1545-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1770 max words - at ../dataset/shuffle-word-1770-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1470 max words - at ../dataset/shuffle-word-1470-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 935 max words - at ../dataset/shuffle-word-935-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 780 max words - at ../dataset/shuffle-word-780-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1955 max words - at ../dataset/shuffle-word-1955-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1645 max words - at ../dataset/shuffle-word-1645-count.jsonl
# Generated a single JSONL file with 52 samples (20 token repeat) - 1275 max words - at ../dataset/shuffle-word-1275-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1310 max words - at ../dataset/shuffle-word-1310-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1515 max words - at ../dataset/shuffle-word-1515-count.jsonl
# Generated a single JSONL file with 41 samples (20 token repeat) - 1370 max words - at ../dataset/shuffle-word-1370-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 655 max words - at ../dataset/shuffle-word-655-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1040 max words - at ../dataset/shuffle-word-1040-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 930 max words - at ../dataset/shuffle-word-930-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1520 max words - at ../dataset/shuffle-word-1520-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1690 max words - at ../dataset/shuffle-word-1690-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 965 max words - at ../dataset/shuffle-word-965-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1810 max words - at ../dataset/shuffle-word-1810-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1420 max words - at ../dataset/shuffle-word-1420-count.jsonl
# Generated a single JSONL file with 116 samples (20 token repeat) - 465 max words - at ../dataset/shuffle-word-465-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 995 max words - at ../dataset/shuffle-word-995-count.jsonl
# Generated JSONL file with - 210 max words, 2000 samples - at ../dataset/gen-word-210-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1145 max words - at ../dataset/shuffle-word-1145-count.jsonl
# Generated a single JSONL file with 51 samples (20 token repeat) - 1270 max words - at ../dataset/shuffle-word-1270-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 605 max words - at ../dataset/shuffle-word-605-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1750 max words - at ../dataset/shuffle-word-1750-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 940 max words - at ../dataset/shuffle-word-940-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1595 max words - at ../dataset/shuffle-word-1595-count.jsonl
# Generated JSONL file with - 180 max words, 2000 samples - at ../dataset/gen-word-180-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1925 max words - at ../dataset/shuffle-word-1925-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1105 max words - at ../dataset/shuffle-word-1105-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1620 max words - at ../dataset/shuffle-word-1620-count.jsonl
# Generated a single JSONL file with 48 samples (20 token repeat) - 1215 max words - at ../dataset/shuffle-word-1215-count.jsonl
# Generated a single JSONL file with 100 samples (20 token repeat) - 570 max words - at ../dataset/shuffle-word-570-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1460 max words - at ../dataset/shuffle-word-1460-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 990 max words - at ../dataset/shuffle-word-990-count.jsonl
# Generated a single JSONL file with 47 samples (20 token repeat) - 1280 max words - at ../dataset/shuffle-word-1280-count.jsonl
# Generated JSONL file with - 390 max words, 2000 samples - at ../dataset/gen-word-390-count.jsonl
# Generated a single JSONL file with 65 samples (20 token repeat) - 880 max words - at ../dataset/shuffle-word-880-count.jsonl
# Generated JSONL file with - 360 max words, 2000 samples - at ../dataset/gen-word-360-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1540 max words - at ../dataset/shuffle-word-1540-count.jsonl
# Generated JSONL file with - 330 max words, 2000 samples - at ../dataset/gen-word-330-count.jsonl
# Generated JSONL file with - 285 max words, 2000 samples - at ../dataset/gen-word-285-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1525 max words - at ../dataset/shuffle-word-1525-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1490 max words - at ../dataset/shuffle-word-1490-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1085 max words - at ../dataset/shuffle-word-1085-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1760 max words - at ../dataset/shuffle-word-1760-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 795 max words - at ../dataset/shuffle-word-795-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1160 max words - at ../dataset/shuffle-word-1160-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1905 max words - at ../dataset/shuffle-word-1905-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1565 max words - at ../dataset/shuffle-word-1565-count.jsonl
# Generated a single JSONL file with 59 samples (20 token repeat) - 1125 max words - at ../dataset/shuffle-word-1125-count.jsonl
# Generated JSONL file with - 170 max words, 2000 samples - at ../dataset/gen-word-170-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1950 max words - at ../dataset/shuffle-word-1950-count.jsonl
# Generated a single JSONL file with 66 samples (20 token repeat) - 855 max words - at ../dataset/shuffle-word-855-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1140 max words - at ../dataset/shuffle-word-1140-count.jsonl
# Generated a single JSONL file with 80 samples (20 token repeat) - 800 max words - at ../dataset/shuffle-word-800-count.jsonl
# Generated a single JSONL file with 40 samples (20 token repeat) - 1445 max words - at ../dataset/shuffle-word-1445-count.jsonl
# Generated a single JSONL file with 60 samples (20 token repeat) - 1135 max words - at ../dataset/shuffle-word-1135-count.jsonl
# ...
# -rw-r--r-- 1 root root 518K Jul 15 21:32 shuffle-word-1775-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1780-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-1785-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:33 shuffle-word-1790-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-1795-count.jsonl
# -rw-r--r-- 1 root root 541K Jul 15 21:32 shuffle-word-180-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-1800-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-1805-count.jsonl
# -rw-r--r-- 1 root root 517K Jul 15 21:32 shuffle-word-1810-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-1815-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 15 21:32 shuffle-word-1820-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-1825-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:33 shuffle-word-1830-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-1835-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-1840-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:33 shuffle-word-1845-count.jsonl
# -rw-r--r-- 1 root root 543K Jul 15 21:32 shuffle-word-185-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-1850-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:33 shuffle-word-1855-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:33 shuffle-word-1860-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1865-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:33 shuffle-word-1870-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1875-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:33 shuffle-word-1880-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:33 shuffle-word-1885-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-1890-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-1895-count.jsonl
# -rw-r--r-- 1 root root 542K Jul 15 21:32 shuffle-word-190-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-1900-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-1905-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:33 shuffle-word-1910-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 15 21:33 shuffle-word-1915-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 15 21:32 shuffle-word-1920-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1925-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1930-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-1935-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:33 shuffle-word-1940-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 15 21:32 shuffle-word-1945-count.jsonl
# -rw-r--r-- 1 root root 544K Jul 15 21:32 shuffle-word-195-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-1950-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 15 21:32 shuffle-word-1955-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 15 21:32 shuffle-word-1960-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 15 21:33 shuffle-word-1965-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 15 21:33 shuffle-word-1970-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 15 21:32 shuffle-word-1975-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1980-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1985-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1990-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-1995-count.jsonl
# -rw-r--r-- 1 root root  37K Jul 15 21:32 shuffle-word-20-count.jsonl
# -rw-r--r-- 1 root root 543K Jul 15 21:32 shuffle-word-200-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:33 shuffle-word-2000-count.jsonl
# -rw-r--r-- 1 root root 539K Jul 15 21:32 shuffle-word-205-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 15 21:32 shuffle-word-210-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 15 21:32 shuffle-word-215-count.jsonl
# -rw-r--r-- 1 root root 538K Jul 15 21:32 shuffle-word-220-count.jsonl
# -rw-r--r-- 1 root root 539K Jul 15 21:32 shuffle-word-225-count.jsonl
# -rw-r--r-- 1 root root 536K Jul 15 21:32 shuffle-word-230-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 15 21:32 shuffle-word-235-count.jsonl
# -rw-r--r-- 1 root root 534K Jul 15 21:32 shuffle-word-240-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-245-count.jsonl
# -rw-r--r-- 1 root root  35K Jul 15 21:32 shuffle-word-25-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 15 21:32 shuffle-word-250-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 15 21:32 shuffle-word-255-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-260-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-265-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 15 21:32 shuffle-word-270-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 15 21:32 shuffle-word-275-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-280-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 15 21:32 shuffle-word-285-count.jsonl
# -rw-r--r-- 1 root root 535K Jul 15 21:32 shuffle-word-290-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 15 21:32 shuffle-word-295-count.jsonl
# -rw-r--r-- 1 root root  34K Jul 15 21:32 shuffle-word-30-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-300-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-305-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-310-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-315-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 15 21:32 shuffle-word-320-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 15 21:32 shuffle-word-325-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-330-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 15 21:32 shuffle-word-335-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 15 21:32 shuffle-word-340-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-345-count.jsonl
# -rw-r--r-- 1 root root  32K Jul 15 21:32 shuffle-word-35-count.jsonl
# -rw-r--r-- 1 root root 533K Jul 15 21:32 shuffle-word-350-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-355-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-360-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-365-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 21:32 shuffle-word-370-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-375-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-380-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-385-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-390-count.jsonl
# -rw-r--r-- 1 root root 531K Jul 15 21:32 shuffle-word-395-count.jsonl
# -rw-r--r-- 1 root root  33K Jul 15 21:32 shuffle-word-40-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-400-count.jsonl
# -rw-r--r-- 1 root root 532K Jul 15 21:32 shuffle-word-405-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-410-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-415-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-420-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-425-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-430-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-435-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-440-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-445-count.jsonl
# -rw-r--r-- 1 root root  33K Jul 15 21:32 shuffle-word-45-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-450-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-455-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 21:32 shuffle-word-460-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-465-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-470-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 21:32 shuffle-word-475-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-480-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-485-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-490-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-495-count.jsonl
# -rw-r--r-- 1 root root  80K Jul 15 21:32 shuffle-word-5-count.jsonl
# -rw-r--r-- 1 root root 604K Jul 15 21:32 shuffle-word-50-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-500-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-505-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-510-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-515-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-520-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-525-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-530-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-535-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 21:32 shuffle-word-540-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-545-count.jsonl
# -rw-r--r-- 1 root root 598K Jul 15 21:32 shuffle-word-55-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-550-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-555-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-560-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-565-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-570-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-575-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-580-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-585-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-590-count.jsonl
# -rw-r--r-- 1 root root 530K Jul 15 21:32 shuffle-word-595-count.jsonl
# -rw-r--r-- 1 root root 600K Jul 15 21:32 shuffle-word-60-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-600-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-605-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-610-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-615-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-620-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-625-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-630-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-635-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-640-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-645-count.jsonl
# -rw-r--r-- 1 root root 586K Jul 15 21:32 shuffle-word-65-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-650-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-655-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-660-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-665-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-670-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-675-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-680-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:33 shuffle-word-685-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-690-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-695-count.jsonl
# -rw-r--r-- 1 root root 583K Jul 15 21:32 shuffle-word-70-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-700-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-705-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-710-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-715-count.jsonl
# -rw-r--r-- 1 root root 529K Jul 15 21:32 shuffle-word-720-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-725-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-730-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-735-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-740-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-745-count.jsonl
# -rw-r--r-- 1 root root 579K Jul 15 21:32 shuffle-word-75-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-750-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-755-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-760-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-765-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-770-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:33 shuffle-word-775-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-780-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-785-count.jsonl
# -rw-r--r-- 1 root root 528K Jul 15 21:32 shuffle-word-790-count.jsonl
# -rw-r--r-- 1 root root 526K Jul 15 21:32 shuffle-word-795-count.jsonl
# -rw-r--r-- 1 root root 578K Jul 15 21:32 shuffle-word-80-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-800-count.jsonl
# -rw-r--r-- 1 root root 518K Jul 15 21:32 shuffle-word-805-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-810-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-815-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-820-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-825-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-830-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-835-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-840-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-845-count.jsonl
# -rw-r--r-- 1 root root 574K Jul 15 21:32 shuffle-word-85-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:33 shuffle-word-850-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-855-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-860-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-865-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-870-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-875-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-880-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-885-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-890-count.jsonl
# -rw-r--r-- 1 root root 525K Jul 15 21:32 shuffle-word-895-count.jsonl
# -rw-r--r-- 1 root root 572K Jul 15 21:32 shuffle-word-90-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-900-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-905-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-910-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-915-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-920-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:33 shuffle-word-925-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-930-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-935-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-940-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-945-count.jsonl
# -rw-r--r-- 1 root root 575K Jul 15 21:32 shuffle-word-95-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-950-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:33 shuffle-word-955-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-960-count.jsonl
# -rw-r--r-- 1 root root 521K Jul 15 21:32 shuffle-word-965-count.jsonl
# -rw-r--r-- 1 root root 523K Jul 15 21:32 shuffle-word-970-count.jsonl
# -rw-r--r-- 1 root root 520K Jul 15 21:32 shuffle-word-975-count.jsonl
# -rw-r--r-- 1 root root 522K Jul 15 21:32 shuffle-word-980-count.jsonl
# -rw-r--r-- 1 root root 524K Jul 15 21:32 shuffle-word-985-count.jsonl
# -rw-r--r-- 1 root root 527K Jul 15 21:32 shuffle-word-990-count.jsonl
# -rw-r--r-- 1 root root 519K Jul 15 21:32 shuffle-word-995-count.jsonl
# -rw-r--r-- 1 root root 120K Jul 15 21:32 word-2-count.jsonl

# %%
# Lets pre tokenize the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/TokenShift-A-mem-finetune-4.yaml"

# Ensure the checkpoint directory exists
# !cd "{TRAINER_DIR}" && mkdir -p "../checkpoint/TokenShift-A-mem-finetune-4/"
# Out:
# Resolving data files: 100%|███████████████| 801/801 [00:00<00:00, 170800.08it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-13aea2ede1fc73f3/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96...
# Downloading data files: 100%|████████████████████| 1/1 [00:00<00:00, 160.12it/s]
# Extracting data files: 100%|██████████████████████| 1/1 [00:00<00:00,  6.03it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-13aea2ede1fc73f3/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 35.93it/s]

# %%
# Start the finetune model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/TokenShift-A-mem-finetune-4.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Mem-Finetune-4 (bs=256, train-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"  \
        --model.ctx_len=4096
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 1933959050
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 1933959050
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230715_213639-zn4g9z06
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run TokenShift-A - Mem-Finetune-4 (bs=256, train-ctx=4096, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/zn4g9z06
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16/build.ninja...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_4096_bf16...
# /usr/local/lib/python3.11/dist-packages/lightning/fabric/connector.py:562: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    256
#
# Resolving data files: 100%|███████████████| 801/801 [00:00<00:00, 270262.85it/s]
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-13aea2ede1fc73f3/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 38.65it/s]
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-13aea2ede1fc73f3/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-00ba408b71eb9918_*_of_00064.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-13aea2ede1fc73f3/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96/cache-08d3773df4f64c50_*_of_00064.arrow
# Saving the dataset (0/16 shards):   5%| | 40000/824786 [00:00<00:10, 71848.39 exSetting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Setting ds_accelerator to cuda (auto detect)
# Saving the dataset (1/16 shards):   6%| | 51550/824786 [00:00<00:10, 75758.95 ex[RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Saving the dataset (1/16 shards):   7%| | 60550/824786 [00:01<00:15, 49183.26 ex[RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1+cu118'
# Saving the dataset (1/16 shards):  12%| | 100550/824786 [00:01<00:09, 77977.99 e[rank: 6] Global seed set to 1933959050
# Saving the dataset (2/16 shards):  13%|▏| 103100/824786 [00:01<00:09, 77977.99 e[rank: 2] Global seed set to 1933959050
# [rank: 3] Global seed set to 1933959050
# [rank: 7] Global seed set to 1933959050
# [rank: 5] Global seed set to 1933959050
# [rank: 1] Global seed set to 1933959050
# [rank: 4] Global seed set to 1933959050
# Saving the dataset (2/16 shards):  19%|▏| 153100/824786 [00:02<00:08, 79552.31 eUsing /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16/build.ninja...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Saving the dataset (3/16 shards):  19%|▏| 154649/824786 [00:02<00:08, 79552.31 eUsing /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module wkv_4096_bf16...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/wkv_4096_bf16/build.ninja...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Loading extension module wkv_4096_bf16...
# Saving the dataset (14/16 shards):  92%|▉| 756688/824786 [00:12<00:01, 40549.53 [rank: 6] Global seed set to 1933959050
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [2023-07-15 21:37:03,953] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Saving the dataset (14/16 shards):  93%|▉| 763688/824786 [00:12<00:01, 44279.30 [rank: 4] Global seed set to 1933959050
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [2023-07-15 21:37:04,112] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 1] Global seed set to 1933959050
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [2023-07-15 21:37:05,882] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 0] Global seed set to 1933959050
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2023-07-15 21:37:05,895] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 3] Global seed set to 1933959050
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [2023-07-15 21:37:06,065] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 7] Global seed set to 1933959050
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [2023-07-15 21:37:06,136] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 5] Global seed set to 1933959050
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [2023-07-15 21:37:06,177] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [rank: 2] Global seed set to 1933959050
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [2023-07-15 21:37:06,193] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  2.000e-04 (0.0002)
#     - lr_final: 1.000e-04 (0.0001)
#
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06602096557617188 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10082292556762695 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10085797309875488 seconds
# Time to load fused_adam op: 0.10101079940795898 seconds
# Time to load fused_adam op: 0.10099411010742188 seconds
# Time to load fused_adam op: 0.10106396675109863 seconds
# Time to load fused_adam op: 0.10138106346130371 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Time to load fused_adam op: 0.10121011734008789 seconds
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.11/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/usr/lib/python3.11/shutil.py", line 738, in rmtree
#     onerror(os.rmdir, path, sys.exc_info())
#   File "/usr/lib/python3.11/shutil.py", line 736, in rmtree
#     os.rmdir(path, dir_fd=dir_fd)
# OSError: [Errno 39] Directory not empty: '/tmp/pymp-0ts872o2'
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.06830263137817383 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.10132837295532227 seconds
# Time to load utils op: 0.10144972801208496 seconds
# Time to load utils op: 0.10099053382873535 seconds
# Loading extension module utils...
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.1022040843963623 seconds
# Loading extension module utils...
# Time to load utils op: 0.10173988342285156 seconds
# Time to load utils op: 0.10191488265991211 seconds
# Time to load utils op: 0.10173559188842773 seconds
# Rank: 7 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 1 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 2 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 4 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 6 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 0 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 5 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Rank: 3 partition count [8, 8, 8] and sizes[(160008320, False), (3840, False), (3840, False)]
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002567768096923828 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002582073211669922 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002639293670654297 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002598762512207031 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0002028942108154297 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003294944763183594 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003342628479003906 seconds
# Using /root/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0004742145538330078 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 128 M
# 1 | blocks | ModuleList | 1.0 B
# 2 | ln_out | LayerNorm  | 5.1 K
# 3 | head   | Linear     | 128 M
# --------------------------------------
# 1.3 B     Trainable params
# 0         Non-trainable params
# 1.3 B     Total params
# 5,120.512 Total estimated model params size (MB)
# Epoch 0:   1%| | 800/103099 [07:25<15:49:29,  1.80it/s, v_num=9z06, train/loss=3/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0:  34%|▎| 34854/103099 [5:29:25<10:45:01,  1.76it/s, v_num=9z06, train/lo
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Epoch 0:  41%|▍| 42573/103099 [6:42:46<9:32:37,  1.76it/s, v_num=9z06, train/los
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Epoch 0:  53%|▌| 54946/103099 [8:40:03<7:35:46,  1.76it/s, v_num=9z06, train/los

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py \
        "../checkpoint/TokenShift-A-mem-finetune-4/last.ckpt" \
        "../model/TokenShift-A-Tune4.pth"
# !cd "{TRAINER_DIR}" && ls -alh ../model/TokenShift-A-Tune4.pth
# Out:
# Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/TokenShift-A-mem-finetune-4/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.optimizer_states, world_size: 8
# Parsing checkpoint created by deepspeed==0.9.3
# Reconstructed fp32 state dict with 222 params 1280128000 elements
# Saving fp32 state dict to ../model/TokenShift-A-Tune4.pth
# -rw-r--r-- 1 root root 4.8G Jul 16 13:59 ../model/TokenShift-A-Tune4.pth

# %%
# Lets do a memory eval 
# !python3 ../memory_script/eval_memory_guided.py "{PROJECT_DIR}/model/TokenShift-A-Tune4.pth" "verbose"
# Out:
# RWKV_HEAD_QK_DIM 0 RWKV_JIT_ON 1
#
# blocks.0.att.key.weight                  float32    cuda:0
# blocks.0.att.output.weight               float32    cuda:0
# blocks.0.att.receptance.weight           float32    cuda:0
# blocks.0.att.time_mix_k                  float32    cuda:0
# blocks.0.att.time_mix_r                  float32    cuda:0
# blocks.0.att.time_mix_v                  float32    cuda:0
# blocks.0.att.value.weight                float32    cuda:0
# blocks.0.ffn.key.weight                  float32    cuda:0
# blocks.0.ffn.receptance.weight           float32    cuda:0
# blocks.0.ffn.time_mix_k                  float32    cuda:0
# blocks.0.ffn.time_mix_r                  float32    cuda:0
# blocks.0.ffn.value.weight                float32    cuda:0
# blocks.0.ln0.bias                        float32    cuda:0
# blocks.0.ln0.weight                      float32    cuda:0
# blocks.0.ln1.bias                        float32    cuda:0
# blocks.0.ln1.weight                      float32    cuda:0
# blocks.0.ln2.bias                        float32    cuda:0
# blocks.0.ln2.weight                      float32    cuda:0
# ................................................................................................................................................................................
# emb.weight                               float32    cpu
# head.weight                              float32    cuda:0
# ln_out.bias                              float32    cuda:0
# ln_out.weight                            float32    cuda:0
# blocks.0.att.time_decay                  float32    cuda:0
# ...........
# blocks.0.att.time_first                  float32    cuda:0
# ...........###
# ### Model validation start ###
# ###
# Model validation at 5 tokens : 40.0% similarity, with 2 matched token, and 3 token mismatch
# Model validation at 10 tokens : 60.0% similarity, with 6 matched token, and 4 token mismatch
# Model validation at 15 tokens : 40.0% similarity, with 6 matched token, and 9 token mismatch
# Model validation at 20 tokens : 35.0% similarity, with 7 matched token, and 13 token mismatch
# Model validation at 25 tokens : 32.0% similarity, with 8 matched token, and 17 token mismatch
# Model validation at 30 tokens : 33.33333333333333% similarity, with 10 matched token, and 20 token mismatch
# Model validation at 35 tokens : 28.57142857142857% similarity, with 10 matched token, and 25 token mismatch
# Model validation at 40 tokens : 27.500000000000004% similarity, with 11 matched token, and 29 token mismatch
# Model validation at 45 tokens : 20.0% similarity, with 9 matched token, and 36 token mismatch
# Model validation at 50 tokens : 22.0% similarity, with 11 matched token, and 39 token mismatch
# Model validation at 55 tokens : 20.0% similarity, with 11 matched token, and 44 token mismatch
# Model validation at 60 tokens : 15.0% similarity, with 9 matched token, and 51 token mismatch
# Model validation at 65 tokens : 13.846153846153847% similarity, with 9 matched token, and 56 token mismatch
# Model validation at 70 tokens : 12.857142857142856% similarity, with 9 matched token, and 61 token mismatch
# Model validation at 75 tokens : 12.0% similarity, with 9 matched token, and 66 token mismatch
# Model validation at 80 tokens : 11.25% similarity, with 9 matched token, and 71 token mismatch
# Model validation at 85 tokens : 10.588235294117647% similarity, with 9 matched token, and 76 token mismatch
# Model validation at 90 tokens : 11.11111111111111% similarity, with 10 matched token, and 80 token mismatch
# Model validation at 95 tokens : 10.526315789473683% similarity, with 10 matched token, and 85 token mismatch
# Model validation at 100 tokens : 10.0% similarity, with 10 matched token, and 90 token mismatch
# Model validation at 110 tokens : 9.090909090909092% similarity, with 10 matched token, and 100 token mismatch
# Model validation at 120 tokens : 6.666666666666667% similarity, with 8 matched token, and 112 token mismatch
# Model validation at 130 tokens : 6.153846153846154% similarity, with 8 matched token, and 122 token mismatch
# Model validation at 140 tokens : 5.714285714285714% similarity, with 8 matched token, and 132 token mismatch
# Model validation at 150 tokens : 6.666666666666667% similarity, with 10 matched token, and 140 token mismatch
# Model validation at 175 tokens : 9.142857142857142% similarity, with 16 matched token, and 159 token mismatch
# Model validation at 200 tokens : 11.0% similarity, with 22 matched token, and 178 token mismatch
# Model validation at 225 tokens : 9.777777777777779% similarity, with 22 matched token, and 203 token mismatch
# Model validation at 250 tokens : 8.4% similarity, with 21 matched token, and 229 token mismatch
# Model validation at 275 tokens : 6.545454545454546% similarity, with 18 matched token, and 257 token mismatch
# Model validation at 300 tokens : 6.666666666666667% similarity, with 20 matched token, and 280 token mismatch
# Model validation at 325 tokens : 5.538461538461538% similarity, with 18 matched token, and 307 token mismatch
# Model validation at 350 tokens : 5.428571428571429% similarity, with 19 matched token, and 331 token mismatch
# Model validation at 375 tokens : 6.4% similarity, with 24 matched token, and 351 token mismatch
# Model validation at 400 tokens : 4.75% similarity, with 19 matched token, and 381 token mismatch
# Model validation at 425 tokens : 4.705882352941177% similarity, with 20 matched token, and 405 token mismatch
# Model validation at 450 tokens : 5.111111111111112% similarity, with 23 matched token, and 427 token mismatch
# Model validation at 475 tokens : 6.947368421052631% similarity, with 33 matched token, and 442 token mismatch
# Model validation at 500 tokens : 5.6000000000000005% similarity, with 28 matched token, and 472 token mismatch
# Model validation at 550 tokens : 6.181818181818182% similarity, with 34 matched token, and 516 token mismatch
# Model validation at 600 tokens : 6.0% similarity, with 36 matched token, and 564 token mismatch
# Model validation at 650 tokens : 5.846153846153846% similarity, with 38 matched token, and 612 token mismatch
# Model validation at 700 tokens : 5.285714285714286% similarity, with 37 matched token, and 663 token mismatch
