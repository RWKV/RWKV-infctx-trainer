# %% [markdown]
# # RWKV Token Shift - From an existing raven model
# Due to the weights overlap, what if we take an existing raven model, and finetune it to the tokenshift format?
# What will happen?
#
# **Note:** This project assumes you have the rwkv-infctx conda env setup

# %% [markdown]
# # Basic Setup

# %%
# Setup the various required folders
# !mkdir -p ../../../../model/
# !mkdir -p ../../../../datapath/
# !mkdir -p ../../../../checkpoint/

# Intialize the modelwqa0sxz
# !cd ../../../../model/ && wget -nc https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-1B5-v12-Eng98%25-Other2%25-20230520-ctx4096.pth
# Out:
# File ‘RWKV-4-Raven-1B5-v12-Eng98%-Other2%-20230520-ctx4096.pth’ already there; not retrieving.

# %%
DEEPSPEED_STRAT="deepspeed_stage_2_offload"
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="FrankenShift-1B5"

# Use for low vram / single GPU trianing
SUBSTEP_CUDA_CACHE_CLEAR=True

print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("SUBSTEP_CUDA_CACHE_CLEAR:", SUBSTEP_CUDA_CACHE_CLEAR)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v4wavenet/"))
INFERENCE_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v4wavenet/"))

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("INFERENCE_DIR:", INFERENCE_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# DEEPSPEED_STRAT: deepspeed_stage_2_offload
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# SUBSTEP_CUDA_CACHE_CLEAR: True
# NOTEBOOK_DIR: /home/picocreator/rwkv-proj/picocreator-memory-experiment/notebook/experiment/tokenshift-exp/FrankenShift-1B5
# INFERENCE_DIR: /home/picocreator/rwkv-proj/picocreator-memory-experiment/RWKV-v4wavenet
# TRAINER_DIR: /home/picocreator/rwkv-proj/picocreator-memory-experiment/RWKV-v4wavenet
# PROJECT_DIR: /home/picocreator/rwkv-proj/picocreator-memory-experiment

# %% [markdown]
# ## Stage 1 : Foundation model training

# %%
# Lets preload the requried dataset (enwiki_100k)
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/FrankenShift-1B5-enwiki.yaml"
# Out:
# [2023-08-02 17:10:34,241] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 108.15it/s]

# %%
# Start the foundation model training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/FrankenShift-1B5-enwiki.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Enwiki Retrain (train-ctx=2048, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --model.substep_cuda_cache_clear="{SUBSTEP_CUDA_CACHE_CLEAR}"
# Out:
# [RWKV.lightning_trainer.py]: Running with PYTORCH_CUDA_ALLOC_CONF=backend:cudaMallocAsync
# [2023-08-02 22:54:09,624] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 3366454673
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 3366454673
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.5
# wandb: Run data is saved locally in ./wandb/run-20230802_225412-g7s2by82
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run FrankenShift-1B5 - Enwiki Retrain (train-ctx=2048, deepspeed_stage_2_offload)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/g7s2by82
# [RWKV.model]: Preloading model from '../model/RWKV-4-Raven-1B5-v12-Eng98%-Other2%-20230520-ctx4096.pth'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_2048_bf16/build.ninja...
# Building extension module wkv_2048_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_2048_bf16...
# [RWKV.model]: Loading model weights ( L24-D2048-V50277 )
# [RWKV.model]: Finished initial model load
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       32
#    - num_nodes:               1
#    - num_devices:             1
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    32
#
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 75.50it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-60c26d6a6f9cd26f_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-c92cd00168a8cffe_*_of_00016.arrow
# Loading cached split indices for dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-789215a0fc0a112c.arrow and /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_100k-1359e81b212c2dd6/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-488441f43c35d0da.arrow
# [rank: 0] Global seed set to 3366454673
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-08-02 22:54:29,911] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [RWKV.model][rank=0] Configuring optimizer ...
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  3.000e-04 (0.0003)
#     - lr_final: 3.000e-04 (0.0003)
#
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.343127965927124 seconds
# Rank: 0 partition count [1, 1, 1] and sizes[(1515008000, False), (49152, False), (49152, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0:   6%| | 8000/135740 [1:43:34<27:33:48,  1.29it/s, v_num=by82, train/los/home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 135740/135740 [30:44:39<00:00,  1.23it/s, v_num=by82, train/los
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                       | 0/683 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/683 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                  | 1/683 [00:00<02:13,  5.10it/s]
# Validation DataLoader 0:   0%|                  | 2/683 [00:00<02:52,  3.96it/s]
# Validation DataLoader 0:   0%|                  | 3/683 [00:00<02:27,  4.60it/s]
# Validation DataLoader 0:   1%|                  | 4/683 [00:00<02:15,  5.02it/s]
# Validation DataLoader 0:   1%|▏                 | 5/683 [00:00<02:07,  5.31it/s]
# Validation DataLoader 0:   1%|▏                 | 6/683 [00:01<03:07,  3.61it/s]
# Validation DataLoader 0:   1%|▏                 | 7/683 [00:01<02:54,  3.87it/s]
# Validation DataLoader 0:   1%|▏                 | 8/683 [00:01<02:45,  4.09it/s]
# Validation DataLoader 0:   1%|▏                 | 9/683 [00:02<02:37,  4.28it/s]
# Validation DataLoader 0:   1%|▏                | 10/683 [00:02<02:50,  3.94it/s]
# Validation DataLoader 0:   2%|▎                | 11/683 [00:02<02:44,  4.09it/s]
# Validation DataLoader 0:   2%|▎                | 12/683 [00:03<02:54,  3.84it/s]
# Validation DataLoader 0:   2%|▎                | 13/683 [00:03<02:56,  3.81it/s]
# Validation DataLoader 0:   2%|▎                | 14/683 [00:03<02:57,  3.77it/s]
# Validation DataLoader 0:   2%|▎                | 15/683 [00:03<02:51,  3.89it/s]
# Validation DataLoader 0:   2%|▍                | 16/683 [00:04<02:52,  3.86it/s]
# Validation DataLoader 0:   2%|▍                | 17/683 [00:04<02:53,  3.83it/s]
# Validation DataLoader 0:   3%|▍                | 18/683 [00:05<03:37,  3.06it/s]
# Validation DataLoader 0:   3%|▍                | 19/683 [00:06<03:30,  3.15it/s]
# Validation DataLoader 0:   3%|▍                | 20/683 [00:06<03:24,  3.24it/s]
# Validation DataLoader 0:   3%|▌                | 21/683 [00:06<03:23,  3.25it/s]
# Validation DataLoader 0:   3%|▌                | 22/683 [00:06<03:23,  3.25it/s]
# Validation DataLoader 0:   3%|▌                | 23/683 [00:06<03:18,  3.33it/s]
# Validation DataLoader 0:   4%|▌                | 24/683 [00:07<03:13,  3.40it/s]
# Validation DataLoader 0:   4%|▌                | 25/683 [00:07<03:17,  3.33it/s]
# Validation DataLoader 0:   4%|▋                | 26/683 [00:07<03:16,  3.34it/s]
# Validation DataLoader 0:   4%|▋                | 27/683 [00:08<03:30,  3.12it/s]
# Validation DataLoader 0:   4%|▋                | 28/683 [00:08<03:25,  3.18it/s]
# Validation DataLoader 0:   4%|▋                | 29/683 [00:08<03:21,  3.24it/s]
# Validation DataLoader 0:   4%|▋                | 30/683 [00:09<03:23,  3.20it/s]
# Validation DataLoader 0:   5%|▊                | 31/683 [00:09<03:20,  3.26it/s]
# Validation DataLoader 0:   5%|▊                | 32/683 [00:09<03:19,  3.26it/s]
# Validation DataLoader 0:   5%|▊                | 33/683 [00:10<03:21,  3.22it/s]
# Validation DataLoader 0:   5%|▊                | 34/683 [00:10<03:18,  3.27it/s]
# Validation DataLoader 0:   5%|▊                | 35/683 [00:10<03:17,  3.27it/s]
# Validation DataLoader 0:   5%|▉                | 36/683 [00:10<03:14,  3.32it/s]
# Validation DataLoader 0:   5%|▉                | 37/683 [00:10<03:11,  3.37it/s]
# Validation DataLoader 0:   6%|▉                | 38/683 [00:11<03:08,  3.41it/s]
# Validation DataLoader 0:   6%|▉                | 39/683 [00:11<03:06,  3.46it/s]
# Validation DataLoader 0:   6%|▉                | 40/683 [00:11<03:06,  3.45it/s]
# Validation DataLoader 0:   6%|█                | 41/683 [00:11<03:05,  3.45it/s]
# Validation DataLoader 0:   6%|█                | 42/683 [00:12<03:03,  3.49it/s]
# Validation DataLoader 0:   6%|█                | 43/683 [00:12<03:01,  3.53it/s]
# Validation DataLoader 0:   6%|█                | 44/683 [00:12<03:00,  3.53it/s]
# Validation DataLoader 0:   7%|█                | 45/683 [00:12<02:58,  3.57it/s]
# Validation DataLoader 0:   7%|█▏               | 46/683 [00:13<03:00,  3.52it/s]
# Validation DataLoader 0:   7%|█▏               | 47/683 [00:13<03:00,  3.52it/s]
# Validation DataLoader 0:   7%|█▏               | 48/683 [00:13<02:58,  3.56it/s]
# Validation DataLoader 0:   7%|█▏               | 49/683 [00:13<02:56,  3.59it/s]
# Validation DataLoader 0:   7%|█▏               | 50/683 [00:14<03:03,  3.44it/s]
# Validation DataLoader 0:   7%|█▎               | 51/683 [00:14<03:05,  3.41it/s]
# Validation DataLoader 0:   8%|█▎               | 52/683 [00:15<03:03,  3.44it/s]
# Validation DataLoader 0:   8%|█▎               | 53/683 [00:15<03:01,  3.47it/s]
# Validation DataLoader 0:   8%|█▎               | 54/683 [00:15<02:59,  3.50it/s]
# Validation DataLoader 0:   8%|█▎               | 55/683 [00:15<02:57,  3.54it/s]
# Validation DataLoader 0:   8%|█▍               | 56/683 [00:15<02:58,  3.50it/s]
# Validation DataLoader 0:   8%|█▍               | 57/683 [00:16<02:57,  3.53it/s]
# Validation DataLoader 0:   8%|█▍               | 58/683 [00:16<02:55,  3.56it/s]
# Validation DataLoader 0:   9%|█▍               | 59/683 [00:16<02:53,  3.59it/s]
# Validation DataLoader 0:   9%|█▍               | 60/683 [00:16<02:53,  3.59it/s]
# Validation DataLoader 0:   9%|█▌               | 61/683 [00:16<02:51,  3.62it/s]
# Validation DataLoader 0:   9%|█▌               | 62/683 [00:17<02:50,  3.64it/s]
# Validation DataLoader 0:   9%|█▌               | 63/683 [00:17<02:48,  3.67it/s]
# Validation DataLoader 0:   9%|█▌               | 64/683 [00:17<02:48,  3.66it/s]
# Validation DataLoader 0:  10%|█▌               | 65/683 [00:17<02:47,  3.69it/s]
# Validation DataLoader 0:  10%|█▋               | 66/683 [00:17<02:46,  3.72it/s]
# Validation DataLoader 0:  10%|█▋               | 67/683 [00:17<02:44,  3.74it/s]
# Validation DataLoader 0:  10%|█▋               | 68/683 [00:18<02:44,  3.73it/s]
# Validation DataLoader 0:  10%|█▋               | 69/683 [00:18<02:43,  3.76it/s]
# Validation DataLoader 0:  10%|█▋               | 70/683 [00:18<02:44,  3.72it/s]
# Validation DataLoader 0:  10%|█▊               | 71/683 [00:18<02:43,  3.75it/s]
# Validation DataLoader 0:  11%|█▊               | 72/683 [00:19<02:43,  3.74it/s]
# Validation DataLoader 0:  11%|█▊               | 73/683 [00:19<02:41,  3.77it/s]
# Validation DataLoader 0:  11%|█▊               | 74/683 [00:19<02:40,  3.79it/s]
# Validation DataLoader 0:  11%|█▊               | 75/683 [00:20<02:43,  3.73it/s]
# Validation DataLoader 0:  11%|█▉               | 76/683 [00:20<02:42,  3.72it/s]
# Validation DataLoader 0:  11%|█▉               | 77/683 [00:20<02:45,  3.67it/s]
# Validation DataLoader 0:  11%|█▉               | 78/683 [00:21<02:43,  3.69it/s]
# Validation DataLoader 0:  12%|█▉               | 79/683 [00:21<02:42,  3.71it/s]
# Validation DataLoader 0:  12%|█▉               | 80/683 [00:21<02:42,  3.71it/s]
# Validation DataLoader 0:  12%|██               | 81/683 [00:21<02:41,  3.73it/s]
# Validation DataLoader 0:  12%|██               | 82/683 [00:22<02:41,  3.72it/s]
# Validation DataLoader 0:  12%|██               | 83/683 [00:22<02:40,  3.74it/s]
# Validation DataLoader 0:  12%|██               | 84/683 [00:22<02:40,  3.74it/s]
# Validation DataLoader 0:  12%|██               | 85/683 [00:22<02:39,  3.76it/s]
# Validation DataLoader 0:  13%|██▏              | 86/683 [00:22<02:38,  3.76it/s]
# Validation DataLoader 0:  13%|██▏              | 87/683 [00:23<02:38,  3.75it/s]
# Validation DataLoader 0:  13%|██▏              | 88/683 [00:23<02:37,  3.77it/s]
# Validation DataLoader 0:  13%|██▏              | 89/683 [00:23<02:37,  3.77it/s]
# Validation DataLoader 0:  13%|██▏              | 90/683 [00:23<02:36,  3.78it/s]
# Validation DataLoader 0:  13%|██▎              | 91/683 [00:24<02:40,  3.69it/s]
# Validation DataLoader 0:  13%|██▎              | 92/683 [00:24<02:39,  3.71it/s]
# Validation DataLoader 0:  14%|██▎              | 93/683 [00:24<02:38,  3.73it/s]
# Validation DataLoader 0:  14%|██▎              | 94/683 [00:25<02:39,  3.70it/s]
# Validation DataLoader 0:  14%|██▎              | 95/683 [00:25<02:38,  3.72it/s]
# Validation DataLoader 0:  14%|██▍              | 96/683 [00:25<02:37,  3.72it/s]
# Validation DataLoader 0:  14%|██▍              | 97/683 [00:25<02:36,  3.73it/s]
# Validation DataLoader 0:  14%|██▍              | 98/683 [00:26<02:37,  3.71it/s]
# Validation DataLoader 0:  14%|██▍              | 99/683 [00:26<02:36,  3.73it/s]
# Validation DataLoader 0:  15%|██▎             | 100/683 [00:26<02:36,  3.72it/s]
# Validation DataLoader 0:  15%|██▎             | 101/683 [00:27<02:35,  3.74it/s]
# Validation DataLoader 0:  15%|██▍             | 102/683 [00:27<02:35,  3.74it/s]
# Validation DataLoader 0:  15%|██▍             | 103/683 [00:27<02:34,  3.75it/s]
# Validation DataLoader 0:  15%|██▍             | 104/683 [00:27<02:33,  3.77it/s]
# Validation DataLoader 0:  15%|██▍             | 105/683 [00:27<02:32,  3.78it/s]
# Validation DataLoader 0:  16%|██▍             | 106/683 [00:27<02:31,  3.80it/s]
# Validation DataLoader 0:  16%|██▌             | 107/683 [00:28<02:33,  3.75it/s]
# Validation DataLoader 0:  16%|██▌             | 108/683 [00:28<02:33,  3.73it/s]
# Validation DataLoader 0:  16%|██▌             | 109/683 [00:29<02:33,  3.74it/s]
# Validation DataLoader 0:  16%|██▌             | 110/683 [00:29<02:33,  3.72it/s]
# Validation DataLoader 0:  16%|██▌             | 111/683 [00:29<02:33,  3.73it/s]
# Validation DataLoader 0:  16%|██▌             | 112/683 [00:29<02:32,  3.74it/s]
# Validation DataLoader 0:  17%|██▋             | 113/683 [00:30<02:32,  3.74it/s]
# Validation DataLoader 0:  17%|██▋             | 114/683 [00:30<02:32,  3.73it/s]
# Validation DataLoader 0:  17%|██▋             | 115/683 [00:31<02:33,  3.71it/s]
# Validation DataLoader 0:  17%|██▋             | 116/683 [00:31<02:32,  3.71it/s]
# Validation DataLoader 0:  17%|██▋             | 117/683 [00:31<02:32,  3.72it/s]
# Validation DataLoader 0:  17%|██▊             | 118/683 [00:31<02:31,  3.73it/s]
# Validation DataLoader 0:  17%|██▊             | 119/683 [00:31<02:31,  3.73it/s]
# Validation DataLoader 0:  18%|██▊             | 120/683 [00:32<02:30,  3.74it/s]
# Validation DataLoader 0:  18%|██▊             | 121/683 [00:32<02:29,  3.75it/s]
# Validation DataLoader 0:  18%|██▊             | 122/683 [00:32<02:31,  3.71it/s]
# Validation DataLoader 0:  18%|██▉             | 123/683 [00:33<02:31,  3.69it/s]
# Validation DataLoader 0:  18%|██▉             | 124/683 [00:33<02:31,  3.70it/s]
# Validation DataLoader 0:  18%|██▉             | 125/683 [00:33<02:30,  3.70it/s]
# Validation DataLoader 0:  18%|██▉             | 126/683 [00:34<02:31,  3.69it/s]
# Validation DataLoader 0:  19%|██▉             | 127/683 [00:34<02:30,  3.69it/s]
# Validation DataLoader 0:  19%|██▉             | 128/683 [00:34<02:30,  3.68it/s]
# Validation DataLoader 0:  19%|███             | 129/683 [00:34<02:30,  3.69it/s]
# Validation DataLoader 0:  19%|███             | 130/683 [00:35<02:31,  3.64it/s]
# Validation DataLoader 0:  19%|███             | 131/683 [00:35<02:31,  3.64it/s]
# Validation DataLoader 0:  19%|███             | 132/683 [00:36<02:30,  3.65it/s]
# Validation DataLoader 0:  19%|███             | 133/683 [00:36<02:32,  3.61it/s]
# Validation DataLoader 0:  20%|███▏            | 134/683 [00:37<02:32,  3.61it/s]
# Validation DataLoader 0:  20%|███▏            | 135/683 [00:37<02:31,  3.62it/s]
# Validation DataLoader 0:  20%|███▏            | 136/683 [00:37<02:32,  3.59it/s]
# Validation DataLoader 0:  20%|███▏            | 137/683 [00:38<02:31,  3.60it/s]
# Validation DataLoader 0:  20%|███▏            | 138/683 [00:38<02:30,  3.62it/s]
# Validation DataLoader 0:  20%|███▎            | 139/683 [00:38<02:30,  3.62it/s]
# Validation DataLoader 0:  20%|███▎            | 140/683 [00:38<02:29,  3.63it/s]
# Validation DataLoader 0:  21%|███▎            | 141/683 [00:38<02:28,  3.64it/s]
# Validation DataLoader 0:  21%|███▎            | 142/683 [00:39<02:28,  3.64it/s]
# Validation DataLoader 0:  21%|███▎            | 143/683 [00:39<02:28,  3.65it/s]
# Validation DataLoader 0:  21%|███▎            | 144/683 [00:39<02:27,  3.65it/s]
# Validation DataLoader 0:  21%|███▍            | 145/683 [00:39<02:27,  3.66it/s]
# Validation DataLoader 0:  21%|███▍            | 146/683 [00:39<02:26,  3.67it/s]
# Validation DataLoader 0:  22%|███▍            | 147/683 [00:39<02:25,  3.68it/s]
# Validation DataLoader 0:  22%|███▍            | 148/683 [00:40<02:25,  3.68it/s]
# Validation DataLoader 0:  22%|███▍            | 149/683 [00:40<02:24,  3.69it/s]
# Validation DataLoader 0:  22%|███▌            | 150/683 [00:40<02:24,  3.69it/s]
# Validation DataLoader 0:  22%|███▌            | 151/683 [00:40<02:23,  3.70it/s]
# Validation DataLoader 0:  22%|███▌            | 152/683 [00:41<02:24,  3.68it/s]
# Validation DataLoader 0:  22%|███▌            | 153/683 [00:41<02:23,  3.70it/s]
# Validation DataLoader 0:  23%|███▌            | 154/683 [00:41<02:22,  3.71it/s]
# Validation DataLoader 0:  23%|███▋            | 155/683 [00:41<02:22,  3.72it/s]
# Validation DataLoader 0:  23%|███▋            | 156/683 [00:41<02:21,  3.73it/s]
# Validation DataLoader 0:  23%|███▋            | 157/683 [00:42<02:20,  3.74it/s]
# Validation DataLoader 0:  23%|███▋            | 158/683 [00:42<02:21,  3.72it/s]
# Validation DataLoader 0:  23%|███▋            | 159/683 [00:42<02:20,  3.73it/s]
# Validation DataLoader 0:  23%|███▋            | 160/683 [00:42<02:19,  3.74it/s]
# Validation DataLoader 0:  24%|███▊            | 161/683 [00:42<02:19,  3.75it/s]
# Validation DataLoader 0:  24%|███▊            | 162/683 [00:43<02:18,  3.75it/s]
# Validation DataLoader 0:  24%|███▊            | 163/683 [00:43<02:20,  3.71it/s]
# Validation DataLoader 0:  24%|███▊            | 164/683 [00:44<02:19,  3.71it/s]
# Validation DataLoader 0:  24%|███▊            | 165/683 [00:44<02:19,  3.72it/s]
# Validation DataLoader 0:  24%|███▉            | 166/683 [00:44<02:18,  3.73it/s]
# Validation DataLoader 0:  24%|███▉            | 167/683 [00:44<02:18,  3.72it/s]
# Validation DataLoader 0:  25%|███▉            | 168/683 [00:45<02:18,  3.73it/s]
# Validation DataLoader 0:  25%|███▉            | 169/683 [00:45<02:18,  3.72it/s]
# Validation DataLoader 0:  25%|███▉            | 170/683 [00:45<02:17,  3.73it/s]
# Validation DataLoader 0:  25%|████            | 171/683 [00:45<02:16,  3.74it/s]
# Validation DataLoader 0:  25%|████            | 172/683 [00:45<02:16,  3.75it/s]
# Validation DataLoader 0:  25%|████            | 173/683 [00:45<02:15,  3.76it/s]
# Validation DataLoader 0:  25%|████            | 174/683 [00:46<02:14,  3.77it/s]
# Validation DataLoader 0:  26%|████            | 175/683 [00:46<02:14,  3.78it/s]
# Validation DataLoader 0:  26%|████            | 176/683 [00:46<02:13,  3.79it/s]
# Validation DataLoader 0:  26%|████▏           | 177/683 [00:46<02:13,  3.80it/s]
# Validation DataLoader 0:  26%|████▏           | 178/683 [00:46<02:12,  3.80it/s]
# Validation DataLoader 0:  26%|████▏           | 179/683 [00:46<02:12,  3.81it/s]
# Validation DataLoader 0:  26%|████▏           | 180/683 [00:47<02:12,  3.81it/s]
# Validation DataLoader 0:  27%|████▏           | 181/683 [00:47<02:11,  3.82it/s]
# Validation DataLoader 0:  27%|████▎           | 182/683 [00:47<02:11,  3.81it/s]
# Validation DataLoader 0:  27%|████▎           | 183/683 [00:48<02:12,  3.79it/s]
# Validation DataLoader 0:  27%|████▎           | 184/683 [00:48<02:11,  3.80it/s]
# Validation DataLoader 0:  27%|████▎           | 185/683 [00:48<02:11,  3.79it/s]
# Validation DataLoader 0:  27%|████▎           | 186/683 [00:49<02:11,  3.79it/s]
# Validation DataLoader 0:  27%|████▍           | 187/683 [00:49<02:10,  3.80it/s]
# Validation DataLoader 0:  28%|████▍           | 188/683 [00:49<02:09,  3.81it/s]
# Validation DataLoader 0:  28%|████▍           | 189/683 [00:49<02:10,  3.80it/s]
# Validation DataLoader 0:  28%|████▍           | 190/683 [00:49<02:09,  3.80it/s]
# Validation DataLoader 0:  28%|████▍           | 191/683 [00:50<02:09,  3.80it/s]
# Validation DataLoader 0:  28%|████▍           | 192/683 [00:50<02:08,  3.81it/s]
# Validation DataLoader 0:  28%|████▌           | 193/683 [00:50<02:08,  3.82it/s]
# Validation DataLoader 0:  28%|████▌           | 194/683 [00:50<02:07,  3.83it/s]
# Validation DataLoader 0:  29%|████▌           | 195/683 [00:50<02:07,  3.84it/s]
# Validation DataLoader 0:  29%|████▌           | 196/683 [00:50<02:06,  3.84it/s]
# Validation DataLoader 0:  29%|████▌           | 197/683 [00:51<02:06,  3.84it/s]
# Validation DataLoader 0:  29%|████▋           | 198/683 [00:51<02:06,  3.84it/s]
# Validation DataLoader 0:  29%|████▋           | 199/683 [00:51<02:05,  3.85it/s]
# Validation DataLoader 0:  29%|████▋           | 200/683 [00:51<02:05,  3.86it/s]
# Validation DataLoader 0:  29%|████▋           | 201/683 [00:53<02:07,  3.78it/s]
# Validation DataLoader 0:  30%|████▋           | 202/683 [00:53<02:06,  3.79it/s]
# Validation DataLoader 0:  30%|████▊           | 203/683 [00:53<02:06,  3.80it/s]
# Validation DataLoader 0:  30%|████▊           | 204/683 [00:53<02:06,  3.80it/s]
# Validation DataLoader 0:  30%|████▊           | 205/683 [00:53<02:05,  3.80it/s]
# Validation DataLoader 0:  30%|████▊           | 206/683 [00:54<02:05,  3.80it/s]
# Validation DataLoader 0:  30%|████▊           | 207/683 [00:54<02:06,  3.77it/s]
# Validation DataLoader 0:  30%|████▊           | 208/683 [00:55<02:05,  3.78it/s]
# Validation DataLoader 0:  31%|████▉           | 209/683 [00:55<02:05,  3.78it/s]
# Validation DataLoader 0:  31%|████▉           | 210/683 [00:55<02:05,  3.78it/s]
# Validation DataLoader 0:  31%|████▉           | 211/683 [00:55<02:04,  3.79it/s]
# Validation DataLoader 0:  31%|████▉           | 212/683 [00:55<02:03,  3.80it/s]
# Validation DataLoader 0:  31%|████▉           | 213/683 [00:57<02:07,  3.69it/s]
# Validation DataLoader 0:  31%|█████           | 214/683 [00:57<02:06,  3.70it/s]
# Validation DataLoader 0:  31%|█████           | 215/683 [00:58<02:06,  3.70it/s]
# Validation DataLoader 0:  32%|█████           | 216/683 [00:58<02:05,  3.71it/s]
# Validation DataLoader 0:  32%|█████           | 217/683 [00:58<02:05,  3.72it/s]
# Validation DataLoader 0:  32%|█████           | 218/683 [00:58<02:05,  3.71it/s]
# Validation DataLoader 0:  32%|█████▏          | 219/683 [00:58<02:04,  3.72it/s]
# Validation DataLoader 0:  32%|█████▏          | 220/683 [00:59<02:04,  3.72it/s]
# Validation DataLoader 0:  32%|█████▏          | 221/683 [00:59<02:03,  3.73it/s]
# Validation DataLoader 0:  33%|█████▏          | 222/683 [00:59<02:03,  3.73it/s]
# Validation DataLoader 0:  33%|█████▏          | 223/683 [00:59<02:02,  3.74it/s]
# Validation DataLoader 0:  33%|█████▏          | 224/683 [00:59<02:02,  3.75it/s]
# Validation DataLoader 0:  33%|█████▎          | 225/683 [00:59<02:01,  3.76it/s]
# Validation DataLoader 0:  33%|█████▎          | 226/683 [01:00<02:01,  3.76it/s]
# Validation DataLoader 0:  33%|█████▎          | 227/683 [01:00<02:01,  3.76it/s]
# Validation DataLoader 0:  33%|█████▎          | 228/683 [01:00<02:00,  3.77it/s]
# Validation DataLoader 0:  34%|█████▎          | 229/683 [01:00<02:00,  3.78it/s]
# Validation DataLoader 0:  34%|█████▍          | 230/683 [01:00<01:59,  3.78it/s]
# Validation DataLoader 0:  34%|█████▍          | 231/683 [01:01<01:59,  3.78it/s]
# Validation DataLoader 0:  34%|█████▍          | 232/683 [01:01<01:59,  3.78it/s]
# Validation DataLoader 0:  34%|█████▍          | 233/683 [01:01<01:59,  3.78it/s]
# Validation DataLoader 0:  34%|█████▍          | 234/683 [01:01<01:58,  3.79it/s]
# Validation DataLoader 0:  34%|█████▌          | 235/683 [01:01<01:58,  3.79it/s]
# Validation DataLoader 0:  35%|█████▌          | 236/683 [01:02<01:57,  3.79it/s]
# Validation DataLoader 0:  35%|█████▌          | 237/683 [01:02<01:57,  3.79it/s]
# Validation DataLoader 0:  35%|█████▌          | 238/683 [01:02<01:57,  3.80it/s]
# Validation DataLoader 0:  35%|█████▌          | 239/683 [01:02<01:56,  3.80it/s]
# Validation DataLoader 0:  35%|█████▌          | 240/683 [01:03<01:56,  3.80it/s]
# Validation DataLoader 0:  35%|█████▋          | 241/683 [01:03<01:56,  3.81it/s]
# Validation DataLoader 0:  35%|█████▋          | 242/683 [01:03<01:55,  3.81it/s]
# Validation DataLoader 0:  36%|█████▋          | 243/683 [01:03<01:55,  3.81it/s]
# Validation DataLoader 0:  36%|█████▋          | 244/683 [01:03<01:54,  3.82it/s]
# Validation DataLoader 0:  36%|█████▋          | 245/683 [01:04<01:54,  3.81it/s]
# Validation DataLoader 0:  36%|█████▊          | 246/683 [01:04<01:54,  3.82it/s]
# Validation DataLoader 0:  36%|█████▊          | 247/683 [01:04<01:54,  3.82it/s]
# Validation DataLoader 0:  36%|█████▊          | 248/683 [01:04<01:53,  3.83it/s]
# Validation DataLoader 0:  36%|█████▊          | 249/683 [01:04<01:53,  3.84it/s]
# Validation DataLoader 0:  37%|█████▊          | 250/683 [01:05<01:52,  3.84it/s]
# Validation DataLoader 0:  37%|█████▉          | 251/683 [01:05<01:52,  3.85it/s]
# Validation DataLoader 0:  37%|█████▉          | 252/683 [01:05<01:51,  3.86it/s]
# Validation DataLoader 0:  37%|█████▉          | 253/683 [01:05<01:51,  3.85it/s]
# Validation DataLoader 0:  37%|█████▉          | 254/683 [01:05<01:51,  3.86it/s]
# Validation DataLoader 0:  37%|█████▉          | 255/683 [01:05<01:50,  3.87it/s]
# Validation DataLoader 0:  37%|█████▉          | 256/683 [01:06<01:50,  3.87it/s]
# Validation DataLoader 0:  38%|██████          | 257/683 [01:06<01:49,  3.88it/s]
# Validation DataLoader 0:  38%|██████          | 258/683 [01:06<01:49,  3.89it/s]
# Validation DataLoader 0:  38%|██████          | 259/683 [01:06<01:48,  3.89it/s]
# Validation DataLoader 0:  38%|██████          | 260/683 [01:06<01:48,  3.88it/s]
# Validation DataLoader 0:  38%|██████          | 261/683 [01:07<01:48,  3.89it/s]
# Validation DataLoader 0:  38%|██████▏         | 262/683 [01:07<01:48,  3.89it/s]
# Validation DataLoader 0:  39%|██████▏         | 263/683 [01:07<01:48,  3.89it/s]
# Validation DataLoader 0:  39%|██████▏         | 264/683 [01:07<01:47,  3.89it/s]
# Validation DataLoader 0:  39%|██████▏         | 265/683 [01:08<01:48,  3.87it/s]
# Validation DataLoader 0:  39%|██████▏         | 266/683 [01:08<01:47,  3.87it/s]
# Validation DataLoader 0:  39%|██████▎         | 267/683 [01:09<01:47,  3.86it/s]
# Validation DataLoader 0:  39%|██████▎         | 268/683 [01:09<01:47,  3.85it/s]
# Validation DataLoader 0:  39%|██████▎         | 269/683 [01:09<01:47,  3.86it/s]
# Validation DataLoader 0:  40%|██████▎         | 270/683 [01:09<01:47,  3.86it/s]
# Validation DataLoader 0:  40%|██████▎         | 271/683 [01:10<01:46,  3.86it/s]
# Validation DataLoader 0:  40%|██████▎         | 272/683 [01:10<01:46,  3.84it/s]
# Validation DataLoader 0:  40%|██████▍         | 273/683 [01:11<01:46,  3.83it/s]
# Validation DataLoader 0:  40%|██████▍         | 274/683 [01:11<01:46,  3.83it/s]
# Validation DataLoader 0:  40%|██████▍         | 275/683 [01:12<01:46,  3.82it/s]
# Validation DataLoader 0:  40%|██████▍         | 276/683 [01:12<01:46,  3.82it/s]
# Validation DataLoader 0:  41%|██████▍         | 277/683 [01:12<01:46,  3.81it/s]
# Validation DataLoader 0:  41%|██████▌         | 278/683 [01:13<01:46,  3.81it/s]
# Validation DataLoader 0:  41%|██████▌         | 279/683 [01:13<01:45,  3.81it/s]
# Validation DataLoader 0:  41%|██████▌         | 280/683 [01:13<01:45,  3.82it/s]
# Validation DataLoader 0:  41%|██████▌         | 281/683 [01:13<01:45,  3.82it/s]
# Validation DataLoader 0:  41%|██████▌         | 282/683 [01:13<01:44,  3.82it/s]
# Validation DataLoader 0:  41%|██████▋         | 283/683 [01:14<01:44,  3.82it/s]
# Validation DataLoader 0:  42%|██████▋         | 284/683 [01:14<01:44,  3.83it/s]
# Validation DataLoader 0:  42%|██████▋         | 285/683 [01:14<01:43,  3.83it/s]
# Validation DataLoader 0:  42%|██████▋         | 286/683 [01:14<01:43,  3.84it/s]
# Validation DataLoader 0:  42%|██████▋         | 287/683 [01:14<01:43,  3.84it/s]
# Validation DataLoader 0:  42%|██████▋         | 288/683 [01:14<01:42,  3.85it/s]
# Validation DataLoader 0:  42%|██████▊         | 289/683 [01:15<01:42,  3.85it/s]
# Validation DataLoader 0:  42%|██████▊         | 290/683 [01:15<01:42,  3.85it/s]
# Validation DataLoader 0:  43%|██████▊         | 291/683 [01:15<01:42,  3.84it/s]
# Validation DataLoader 0:  43%|██████▊         | 292/683 [01:16<01:41,  3.83it/s]
# Validation DataLoader 0:  43%|██████▊         | 293/683 [01:16<01:41,  3.84it/s]
# Validation DataLoader 0:  43%|██████▉         | 294/683 [01:16<01:41,  3.82it/s]
# Validation DataLoader 0:  43%|██████▉         | 295/683 [01:17<01:41,  3.83it/s]
# Validation DataLoader 0:  43%|██████▉         | 296/683 [01:17<01:40,  3.84it/s]
# Validation DataLoader 0:  43%|██████▉         | 297/683 [01:17<01:40,  3.84it/s]
# Validation DataLoader 0:  44%|██████▉         | 298/683 [01:17<01:40,  3.85it/s]
# Validation DataLoader 0:  44%|███████         | 299/683 [01:17<01:39,  3.85it/s]
# Validation DataLoader 0:  44%|███████         | 300/683 [01:18<01:39,  3.84it/s]
# Validation DataLoader 0:  44%|███████         | 301/683 [01:18<01:39,  3.84it/s]
# Validation DataLoader 0:  44%|███████         | 302/683 [01:18<01:39,  3.84it/s]
# Validation DataLoader 0:  44%|███████         | 303/683 [01:18<01:38,  3.85it/s]
# Validation DataLoader 0:  45%|███████         | 304/683 [01:19<01:39,  3.81it/s]
# Validation DataLoader 0:  45%|███████▏        | 305/683 [01:19<01:39,  3.81it/s]
# Validation DataLoader 0:  45%|███████▏        | 306/683 [01:20<01:39,  3.81it/s]
# Validation DataLoader 0:  45%|███████▏        | 307/683 [01:20<01:38,  3.80it/s]
# Validation DataLoader 0:  45%|███████▏        | 308/683 [01:20<01:38,  3.80it/s]
# Validation DataLoader 0:  45%|███████▏        | 309/683 [01:21<01:38,  3.81it/s]
# Validation DataLoader 0:  45%|███████▎        | 310/683 [01:21<01:37,  3.81it/s]
# Validation DataLoader 0:  46%|███████▎        | 311/683 [01:21<01:37,  3.81it/s]
# Validation DataLoader 0:  46%|███████▎        | 312/683 [01:21<01:37,  3.81it/s]
# Validation DataLoader 0:  46%|███████▎        | 313/683 [01:22<01:36,  3.82it/s]
# Validation DataLoader 0:  46%|███████▎        | 314/683 [01:22<01:36,  3.82it/s]
# Validation DataLoader 0:  46%|███████▍        | 315/683 [01:22<01:36,  3.83it/s]
# Validation DataLoader 0:  46%|███████▍        | 316/683 [01:22<01:35,  3.83it/s]
# Validation DataLoader 0:  46%|███████▍        | 317/683 [01:22<01:35,  3.82it/s]
# Validation DataLoader 0:  47%|███████▍        | 318/683 [01:23<01:36,  3.79it/s]
# Validation DataLoader 0:  47%|███████▍        | 319/683 [01:24<01:35,  3.80it/s]
# Validation DataLoader 0:  47%|███████▍        | 320/683 [01:24<01:35,  3.79it/s]
# Validation DataLoader 0:  47%|███████▌        | 321/683 [01:24<01:35,  3.79it/s]
# Validation DataLoader 0:  47%|███████▌        | 322/683 [01:24<01:35,  3.79it/s]
# Validation DataLoader 0:  47%|███████▌        | 323/683 [01:25<01:34,  3.80it/s]
# Validation DataLoader 0:  47%|███████▌        | 324/683 [01:25<01:34,  3.80it/s]
# Validation DataLoader 0:  48%|███████▌        | 325/683 [01:25<01:34,  3.81it/s]
# Validation DataLoader 0:  48%|███████▋        | 326/683 [01:25<01:33,  3.81it/s]
# Validation DataLoader 0:  48%|███████▋        | 327/683 [01:26<01:34,  3.78it/s]
# Validation DataLoader 0:  48%|███████▋        | 328/683 [01:26<01:33,  3.78it/s]
# Validation DataLoader 0:  48%|███████▋        | 329/683 [01:26<01:33,  3.79it/s]
# Validation DataLoader 0:  48%|███████▋        | 330/683 [01:26<01:33,  3.79it/s]
# Validation DataLoader 0:  48%|███████▊        | 331/683 [01:27<01:32,  3.79it/s]
# Validation DataLoader 0:  49%|███████▊        | 332/683 [01:27<01:32,  3.80it/s]
# Validation DataLoader 0:  49%|███████▊        | 333/683 [01:28<01:32,  3.78it/s]
# Validation DataLoader 0:  49%|███████▊        | 334/683 [01:28<01:32,  3.78it/s]
# Validation DataLoader 0:  49%|███████▊        | 335/683 [01:28<01:32,  3.78it/s]
# Validation DataLoader 0:  49%|███████▊        | 336/683 [01:28<01:31,  3.78it/s]
# Validation DataLoader 0:  49%|███████▉        | 337/683 [01:29<01:31,  3.79it/s]
# Validation DataLoader 0:  49%|███████▉        | 338/683 [01:29<01:31,  3.78it/s]
# Validation DataLoader 0:  50%|███████▉        | 339/683 [01:30<01:31,  3.76it/s]
# Validation DataLoader 0:  50%|███████▉        | 340/683 [01:30<01:31,  3.76it/s]
# Validation DataLoader 0:  50%|███████▉        | 341/683 [01:30<01:30,  3.76it/s]
# Validation DataLoader 0:  50%|████████        | 342/683 [01:31<01:30,  3.75it/s]
# Validation DataLoader 0:  50%|████████        | 343/683 [01:31<01:30,  3.76it/s]
# Validation DataLoader 0:  50%|████████        | 344/683 [01:31<01:30,  3.76it/s]
# Validation DataLoader 0:  51%|████████        | 345/683 [01:31<01:29,  3.76it/s]
# Validation DataLoader 0:  51%|████████        | 346/683 [01:31<01:29,  3.77it/s]
# Validation DataLoader 0:  51%|████████▏       | 347/683 [01:31<01:29,  3.77it/s]
# Validation DataLoader 0:  51%|████████▏       | 348/683 [01:32<01:28,  3.77it/s]
# Validation DataLoader 0:  51%|████████▏       | 349/683 [01:32<01:28,  3.78it/s]
# Validation DataLoader 0:  51%|████████▏       | 350/683 [01:32<01:28,  3.78it/s]
# Validation DataLoader 0:  51%|████████▏       | 351/683 [01:32<01:27,  3.79it/s]
# Validation DataLoader 0:  52%|████████▏       | 352/683 [01:33<01:27,  3.76it/s]
# Validation DataLoader 0:  52%|████████▎       | 353/683 [01:34<01:27,  3.75it/s]
# Validation DataLoader 0:  52%|████████▎       | 354/683 [01:34<01:27,  3.75it/s]
# Validation DataLoader 0:  52%|████████▎       | 355/683 [01:34<01:27,  3.75it/s]
# Validation DataLoader 0:  52%|████████▎       | 356/683 [01:34<01:27,  3.75it/s]
# Validation DataLoader 0:  52%|████████▎       | 357/683 [01:35<01:26,  3.76it/s]
# Validation DataLoader 0:  52%|████████▍       | 358/683 [01:35<01:26,  3.76it/s]
# Validation DataLoader 0:  53%|████████▍       | 359/683 [01:35<01:26,  3.77it/s]
# Validation DataLoader 0:  53%|████████▍       | 360/683 [01:35<01:25,  3.76it/s]
# Validation DataLoader 0:  53%|████████▍       | 361/683 [01:35<01:25,  3.76it/s]
# Validation DataLoader 0:  53%|████████▍       | 362/683 [01:36<01:25,  3.77it/s]
# Validation DataLoader 0:  53%|████████▌       | 363/683 [01:36<01:24,  3.77it/s]
# Validation DataLoader 0:  53%|████████▌       | 364/683 [01:36<01:24,  3.77it/s]
# Validation DataLoader 0:  53%|████████▌       | 365/683 [01:36<01:24,  3.77it/s]
# Validation DataLoader 0:  54%|████████▌       | 366/683 [01:36<01:23,  3.77it/s]
# Validation DataLoader 0:  54%|████████▌       | 367/683 [01:37<01:23,  3.78it/s]
# Validation DataLoader 0:  54%|████████▌       | 368/683 [01:37<01:23,  3.78it/s]
# Validation DataLoader 0:  54%|████████▋       | 369/683 [01:37<01:23,  3.77it/s]
# Validation DataLoader 0:  54%|████████▋       | 370/683 [01:38<01:23,  3.77it/s]
# Validation DataLoader 0:  54%|████████▋       | 371/683 [01:38<01:22,  3.77it/s]
# Validation DataLoader 0:  54%|████████▋       | 372/683 [01:38<01:22,  3.76it/s]
# Validation DataLoader 0:  55%|████████▋       | 373/683 [01:39<01:22,  3.77it/s]
# Validation DataLoader 0:  55%|████████▊       | 374/683 [01:39<01:21,  3.77it/s]
# Validation DataLoader 0:  55%|████████▊       | 375/683 [01:39<01:21,  3.78it/s]
# Validation DataLoader 0:  55%|████████▊       | 376/683 [01:39<01:21,  3.78it/s]
# Validation DataLoader 0:  55%|████████▊       | 377/683 [01:39<01:20,  3.78it/s]
# Validation DataLoader 0:  55%|████████▊       | 378/683 [01:40<01:20,  3.78it/s]
# Validation DataLoader 0:  55%|████████▉       | 379/683 [01:40<01:20,  3.78it/s]
# Validation DataLoader 0:  56%|████████▉       | 380/683 [01:40<01:20,  3.77it/s]
# Validation DataLoader 0:  56%|████████▉       | 381/683 [01:41<01:20,  3.76it/s]
# Validation DataLoader 0:  56%|████████▉       | 382/683 [01:41<01:19,  3.77it/s]
# Validation DataLoader 0:  56%|████████▉       | 383/683 [01:41<01:19,  3.77it/s]
# Validation DataLoader 0:  56%|████████▉       | 384/683 [01:42<01:19,  3.75it/s]
# Validation DataLoader 0:  56%|█████████       | 385/683 [01:42<01:19,  3.74it/s]
# Validation DataLoader 0:  57%|█████████       | 386/683 [01:42<01:19,  3.75it/s]
# Validation DataLoader 0:  57%|█████████       | 387/683 [01:43<01:19,  3.74it/s]
# Validation DataLoader 0:  57%|█████████       | 388/683 [01:43<01:18,  3.75it/s]
# Validation DataLoader 0:  57%|█████████       | 389/683 [01:43<01:18,  3.75it/s]
# Validation DataLoader 0:  57%|█████████▏      | 390/683 [01:43<01:18,  3.75it/s]
# Validation DataLoader 0:  57%|█████████▏      | 391/683 [01:44<01:17,  3.75it/s]
# Validation DataLoader 0:  57%|█████████▏      | 392/683 [01:44<01:17,  3.76it/s]
# Validation DataLoader 0:  58%|█████████▏      | 393/683 [01:44<01:17,  3.75it/s]
# Validation DataLoader 0:  58%|█████████▏      | 394/683 [01:44<01:16,  3.76it/s]
# Validation DataLoader 0:  58%|█████████▎      | 395/683 [01:45<01:16,  3.76it/s]
# Validation DataLoader 0:  58%|█████████▎      | 396/683 [01:45<01:16,  3.76it/s]
# Validation DataLoader 0:  58%|█████████▎      | 397/683 [01:45<01:16,  3.75it/s]
# Validation DataLoader 0:  58%|█████████▎      | 398/683 [01:46<01:15,  3.75it/s]
# Validation DataLoader 0:  58%|█████████▎      | 399/683 [01:46<01:15,  3.76it/s]
# Validation DataLoader 0:  59%|█████████▎      | 400/683 [01:46<01:15,  3.75it/s]
# Validation DataLoader 0:  59%|█████████▍      | 401/683 [01:47<01:15,  3.74it/s]
# Validation DataLoader 0:  59%|█████████▍      | 402/683 [01:47<01:15,  3.74it/s]
# Validation DataLoader 0:  59%|█████████▍      | 403/683 [01:47<01:14,  3.74it/s]
# Validation DataLoader 0:  59%|█████████▍      | 404/683 [01:47<01:14,  3.75it/s]
# Validation DataLoader 0:  59%|█████████▍      | 405/683 [01:48<01:14,  3.74it/s]
# Validation DataLoader 0:  59%|█████████▌      | 406/683 [01:48<01:14,  3.74it/s]
# Validation DataLoader 0:  60%|█████████▌      | 407/683 [01:49<01:13,  3.73it/s]
# Validation DataLoader 0:  60%|█████████▌      | 408/683 [01:49<01:13,  3.73it/s]
# Validation DataLoader 0:  60%|█████████▌      | 409/683 [01:49<01:13,  3.73it/s]
# Validation DataLoader 0:  60%|█████████▌      | 410/683 [01:49<01:13,  3.73it/s]
# Validation DataLoader 0:  60%|█████████▋      | 411/683 [01:50<01:12,  3.73it/s]
# Validation DataLoader 0:  60%|█████████▋      | 412/683 [01:50<01:12,  3.73it/s]
# Validation DataLoader 0:  60%|█████████▋      | 413/683 [01:50<01:12,  3.73it/s]
# Validation DataLoader 0:  61%|█████████▋      | 414/683 [01:50<01:11,  3.74it/s]
# Validation DataLoader 0:  61%|█████████▋      | 415/683 [01:51<01:11,  3.74it/s]
# Validation DataLoader 0:  61%|█████████▋      | 416/683 [01:51<01:11,  3.74it/s]
# Validation DataLoader 0:  61%|█████████▊      | 417/683 [01:51<01:10,  3.75it/s]
# Validation DataLoader 0:  61%|█████████▊      | 418/683 [01:51<01:10,  3.75it/s]
# Validation DataLoader 0:  61%|█████████▊      | 419/683 [01:51<01:10,  3.75it/s]
# Validation DataLoader 0:  61%|█████████▊      | 420/683 [01:51<01:09,  3.76it/s]
# Validation DataLoader 0:  62%|█████████▊      | 421/683 [01:52<01:09,  3.76it/s]
# Validation DataLoader 0:  62%|█████████▉      | 422/683 [01:52<01:09,  3.76it/s]
# Validation DataLoader 0:  62%|█████████▉      | 423/683 [01:52<01:09,  3.76it/s]
# Validation DataLoader 0:  62%|█████████▉      | 424/683 [01:52<01:08,  3.76it/s]
# Validation DataLoader 0:  62%|█████████▉      | 425/683 [01:52<01:08,  3.77it/s]
# Validation DataLoader 0:  62%|█████████▉      | 426/683 [01:53<01:08,  3.76it/s]
# Validation DataLoader 0:  63%|██████████      | 427/683 [01:53<01:07,  3.77it/s]
# Validation DataLoader 0:  63%|██████████      | 428/683 [01:53<01:07,  3.76it/s]
# Validation DataLoader 0:  63%|██████████      | 429/683 [01:53<01:07,  3.76it/s]
# Validation DataLoader 0:  63%|██████████      | 430/683 [01:54<01:07,  3.76it/s]
# Validation DataLoader 0:  63%|██████████      | 431/683 [01:55<01:07,  3.74it/s]
# Validation DataLoader 0:  63%|██████████      | 432/683 [01:55<01:07,  3.74it/s]
# Validation DataLoader 0:  63%|██████████▏     | 433/683 [01:55<01:06,  3.75it/s]
# Validation DataLoader 0:  64%|██████████▏     | 434/683 [01:55<01:06,  3.75it/s]
# Validation DataLoader 0:  64%|██████████▏     | 435/683 [01:56<01:06,  3.75it/s]
# Validation DataLoader 0:  64%|██████████▏     | 436/683 [01:56<01:05,  3.75it/s]
# Validation DataLoader 0:  64%|██████████▏     | 437/683 [01:56<01:05,  3.76it/s]
# Validation DataLoader 0:  64%|██████████▎     | 438/683 [01:56<01:05,  3.76it/s]
# Validation DataLoader 0:  64%|██████████▎     | 439/683 [01:56<01:04,  3.76it/s]
# Validation DataLoader 0:  64%|██████████▎     | 440/683 [01:56<01:04,  3.76it/s]
# Validation DataLoader 0:  65%|██████████▎     | 441/683 [01:57<01:04,  3.76it/s]
# Validation DataLoader 0:  65%|██████████▎     | 442/683 [01:57<01:04,  3.76it/s]
# Validation DataLoader 0:  65%|██████████▍     | 443/683 [01:57<01:03,  3.77it/s]
# Validation DataLoader 0:  65%|██████████▍     | 444/683 [01:57<01:03,  3.77it/s]
# Validation DataLoader 0:  65%|██████████▍     | 445/683 [01:57<01:03,  3.77it/s]
# Validation DataLoader 0:  65%|██████████▍     | 446/683 [01:58<01:02,  3.78it/s]
# Validation DataLoader 0:  65%|██████████▍     | 447/683 [01:58<01:02,  3.77it/s]
# Validation DataLoader 0:  66%|██████████▍     | 448/683 [01:58<01:02,  3.77it/s]
# Validation DataLoader 0:  66%|██████████▌     | 449/683 [01:59<01:02,  3.77it/s]
# Validation DataLoader 0:  66%|██████████▌     | 450/683 [01:59<01:01,  3.78it/s]
# Validation DataLoader 0:  66%|██████████▌     | 451/683 [01:59<01:01,  3.78it/s]
# Validation DataLoader 0:  66%|██████████▌     | 452/683 [01:59<01:01,  3.78it/s]
# Validation DataLoader 0:  66%|██████████▌     | 453/683 [01:59<01:00,  3.78it/s]
# Validation DataLoader 0:  66%|██████████▋     | 454/683 [02:00<01:00,  3.78it/s]
# Validation DataLoader 0:  67%|██████████▋     | 455/683 [02:00<01:00,  3.79it/s]
# Validation DataLoader 0:  67%|██████████▋     | 456/683 [02:00<00:59,  3.78it/s]
# Validation DataLoader 0:  67%|██████████▋     | 457/683 [02:00<00:59,  3.78it/s]
# Validation DataLoader 0:  67%|██████████▋     | 458/683 [02:01<00:59,  3.78it/s]
# Validation DataLoader 0:  67%|██████████▊     | 459/683 [02:01<00:59,  3.78it/s]
# Validation DataLoader 0:  67%|██████████▊     | 460/683 [02:01<00:58,  3.79it/s]
# Validation DataLoader 0:  67%|██████████▊     | 461/683 [02:01<00:58,  3.79it/s]
# Validation DataLoader 0:  68%|██████████▊     | 462/683 [02:01<00:58,  3.79it/s]
# Validation DataLoader 0:  68%|██████████▊     | 463/683 [02:02<00:58,  3.79it/s]
# Validation DataLoader 0:  68%|██████████▊     | 464/683 [02:02<00:57,  3.80it/s]
# Validation DataLoader 0:  68%|██████████▉     | 465/683 [02:02<00:57,  3.80it/s]
# Validation DataLoader 0:  68%|██████████▉     | 466/683 [02:02<00:57,  3.80it/s]
# Validation DataLoader 0:  68%|██████████▉     | 467/683 [02:02<00:56,  3.81it/s]
# Validation DataLoader 0:  69%|██████████▉     | 468/683 [02:02<00:56,  3.81it/s]
# Validation DataLoader 0:  69%|██████████▉     | 469/683 [02:02<00:56,  3.81it/s]
# Validation DataLoader 0:  69%|███████████     | 470/683 [02:03<00:55,  3.81it/s]
# Validation DataLoader 0:  69%|███████████     | 471/683 [02:03<00:55,  3.81it/s]
# Validation DataLoader 0:  69%|███████████     | 472/683 [02:04<00:55,  3.81it/s]
# Validation DataLoader 0:  69%|███████████     | 473/683 [02:04<00:55,  3.81it/s]
# Validation DataLoader 0:  69%|███████████     | 474/683 [02:04<00:54,  3.81it/s]
# Validation DataLoader 0:  70%|███████████▏    | 475/683 [02:04<00:54,  3.82it/s]
# Validation DataLoader 0:  70%|███████████▏    | 476/683 [02:04<00:54,  3.82it/s]
# Validation DataLoader 0:  70%|███████████▏    | 477/683 [02:04<00:53,  3.82it/s]
# Validation DataLoader 0:  70%|███████████▏    | 478/683 [02:05<00:53,  3.82it/s]
# Validation DataLoader 0:  70%|███████████▏    | 479/683 [02:05<00:53,  3.83it/s]
# Validation DataLoader 0:  70%|███████████▏    | 480/683 [02:05<00:53,  3.82it/s]
# Validation DataLoader 0:  70%|███████████▎    | 481/683 [02:05<00:52,  3.82it/s]
# Validation DataLoader 0:  71%|███████████▎    | 482/683 [02:05<00:52,  3.83it/s]
# Validation DataLoader 0:  71%|███████████▎    | 483/683 [02:06<00:52,  3.83it/s]
# Validation DataLoader 0:  71%|███████████▎    | 484/683 [02:06<00:51,  3.83it/s]
# Validation DataLoader 0:  71%|███████████▎    | 485/683 [02:06<00:51,  3.84it/s]
# Validation DataLoader 0:  71%|███████████▍    | 486/683 [02:06<00:51,  3.84it/s]
# Validation DataLoader 0:  71%|███████████▍    | 487/683 [02:06<00:50,  3.84it/s]
# Validation DataLoader 0:  71%|███████████▍    | 488/683 [02:06<00:50,  3.84it/s]
# Validation DataLoader 0:  72%|███████████▍    | 489/683 [02:07<00:50,  3.85it/s]
# Validation DataLoader 0:  72%|███████████▍    | 490/683 [02:07<00:50,  3.85it/s]
# Validation DataLoader 0:  72%|███████████▌    | 491/683 [02:07<00:49,  3.85it/s]
# Validation DataLoader 0:  72%|███████████▌    | 492/683 [02:07<00:49,  3.86it/s]
# Validation DataLoader 0:  72%|███████████▌    | 493/683 [02:07<00:49,  3.85it/s]
# Validation DataLoader 0:  72%|███████████▌    | 494/683 [02:08<00:49,  3.85it/s]
# Validation DataLoader 0:  72%|███████████▌    | 495/683 [02:08<00:48,  3.85it/s]
# Validation DataLoader 0:  73%|███████████▌    | 496/683 [02:08<00:48,  3.86it/s]
# Validation DataLoader 0:  73%|███████████▋    | 497/683 [02:08<00:48,  3.85it/s]
# Validation DataLoader 0:  73%|███████████▋    | 498/683 [02:09<00:47,  3.86it/s]
# Validation DataLoader 0:  73%|███████████▋    | 499/683 [02:09<00:47,  3.86it/s]
# Validation DataLoader 0:  73%|███████████▋    | 500/683 [02:09<00:47,  3.85it/s]
# Validation DataLoader 0:  73%|███████████▋    | 501/683 [02:09<00:47,  3.85it/s]
# Validation DataLoader 0:  73%|███████████▊    | 502/683 [02:10<00:46,  3.86it/s]
# Validation DataLoader 0:  74%|███████████▊    | 503/683 [02:10<00:46,  3.86it/s]
# Validation DataLoader 0:  74%|███████████▊    | 504/683 [02:10<00:46,  3.86it/s]
# Validation DataLoader 0:  74%|███████████▊    | 505/683 [02:10<00:46,  3.86it/s]
# Validation DataLoader 0:  74%|███████████▊    | 506/683 [02:10<00:45,  3.86it/s]
# Validation DataLoader 0:  74%|███████████▉    | 507/683 [02:11<00:45,  3.86it/s]
# Validation DataLoader 0:  74%|███████████▉    | 508/683 [02:11<00:45,  3.86it/s]
# Validation DataLoader 0:  75%|███████████▉    | 509/683 [02:11<00:44,  3.87it/s]
# Validation DataLoader 0:  75%|███████████▉    | 510/683 [02:11<00:44,  3.87it/s]
# Validation DataLoader 0:  75%|███████████▉    | 511/683 [02:12<00:44,  3.87it/s]
# Validation DataLoader 0:  75%|███████████▉    | 512/683 [02:12<00:44,  3.87it/s]
# Validation DataLoader 0:  75%|████████████    | 513/683 [02:12<00:43,  3.87it/s]
# Validation DataLoader 0:  75%|████████████    | 514/683 [02:13<00:43,  3.86it/s]
# Validation DataLoader 0:  75%|████████████    | 515/683 [02:13<00:43,  3.87it/s]
# Validation DataLoader 0:  76%|████████████    | 516/683 [02:13<00:43,  3.87it/s]
# Validation DataLoader 0:  76%|████████████    | 517/683 [02:13<00:42,  3.87it/s]
# Validation DataLoader 0:  76%|████████████▏   | 518/683 [02:13<00:42,  3.87it/s]
# Validation DataLoader 0:  76%|████████████▏   | 519/683 [02:13<00:42,  3.88it/s]
# Validation DataLoader 0:  76%|████████████▏   | 520/683 [02:14<00:42,  3.88it/s]
# Validation DataLoader 0:  76%|████████████▏   | 521/683 [02:14<00:41,  3.88it/s]
# Validation DataLoader 0:  76%|████████████▏   | 522/683 [02:14<00:41,  3.88it/s]
# Validation DataLoader 0:  77%|████████████▎   | 523/683 [02:14<00:41,  3.88it/s]
# Validation DataLoader 0:  77%|████████████▎   | 524/683 [02:14<00:40,  3.89it/s]
# Validation DataLoader 0:  77%|████████████▎   | 525/683 [02:14<00:40,  3.89it/s]
# Validation DataLoader 0:  77%|████████████▎   | 526/683 [02:15<00:40,  3.89it/s]
# Validation DataLoader 0:  77%|████████████▎   | 527/683 [02:15<00:40,  3.89it/s]
# Validation DataLoader 0:  77%|████████████▎   | 528/683 [02:15<00:39,  3.89it/s]
# Validation DataLoader 0:  77%|████████████▍   | 529/683 [02:15<00:39,  3.90it/s]
# Validation DataLoader 0:  78%|████████████▍   | 530/683 [02:15<00:39,  3.90it/s]
# Validation DataLoader 0:  78%|████████████▍   | 531/683 [02:16<00:38,  3.90it/s]
# Validation DataLoader 0:  78%|████████████▍   | 532/683 [02:16<00:38,  3.90it/s]
# Validation DataLoader 0:  78%|████████████▍   | 533/683 [02:16<00:38,  3.91it/s]
# Validation DataLoader 0:  78%|████████████▌   | 534/683 [02:16<00:38,  3.91it/s]
# Validation DataLoader 0:  78%|████████████▌   | 535/683 [02:16<00:37,  3.91it/s]
# Validation DataLoader 0:  78%|████████████▌   | 536/683 [02:16<00:37,  3.92it/s]
# Validation DataLoader 0:  79%|████████████▌   | 537/683 [02:17<00:37,  3.91it/s]
# Validation DataLoader 0:  79%|████████████▌   | 538/683 [02:17<00:37,  3.91it/s]
# Validation DataLoader 0:  79%|████████████▋   | 539/683 [02:17<00:36,  3.92it/s]
# Validation DataLoader 0:  79%|████████████▋   | 540/683 [02:17<00:36,  3.91it/s]
# Validation DataLoader 0:  79%|████████████▋   | 541/683 [02:18<00:36,  3.92it/s]
# Validation DataLoader 0:  79%|████████████▋   | 542/683 [02:18<00:35,  3.92it/s]
# Validation DataLoader 0:  80%|████████████▋   | 543/683 [02:18<00:35,  3.92it/s]
# Validation DataLoader 0:  80%|████████████▋   | 544/683 [02:19<00:35,  3.91it/s]
# Validation DataLoader 0:  80%|████████████▊   | 545/683 [02:19<00:35,  3.92it/s]
# Validation DataLoader 0:  80%|████████████▊   | 546/683 [02:19<00:34,  3.92it/s]
# Validation DataLoader 0:  80%|████████████▊   | 547/683 [02:19<00:34,  3.92it/s]
# Validation DataLoader 0:  80%|████████████▊   | 548/683 [02:19<00:34,  3.93it/s]
# Validation DataLoader 0:  80%|████████████▊   | 549/683 [02:19<00:34,  3.93it/s]
# Validation DataLoader 0:  81%|████████████▉   | 550/683 [02:19<00:33,  3.93it/s]
# Validation DataLoader 0:  81%|████████████▉   | 551/683 [02:20<00:33,  3.93it/s]
# Validation DataLoader 0:  81%|████████████▉   | 552/683 [02:20<00:33,  3.94it/s]
# Validation DataLoader 0:  81%|████████████▉   | 553/683 [02:20<00:32,  3.94it/s]
# Validation DataLoader 0:  81%|████████████▉   | 554/683 [02:20<00:32,  3.94it/s]
# Validation DataLoader 0:  81%|█████████████   | 555/683 [02:20<00:32,  3.94it/s]
# Validation DataLoader 0:  81%|█████████████   | 556/683 [02:21<00:32,  3.94it/s]
# Validation DataLoader 0:  82%|█████████████   | 557/683 [02:21<00:31,  3.94it/s]
# Validation DataLoader 0:  82%|█████████████   | 558/683 [02:21<00:31,  3.94it/s]
# Validation DataLoader 0:  82%|█████████████   | 559/683 [02:21<00:31,  3.95it/s]
# Validation DataLoader 0:  82%|█████████████   | 560/683 [02:21<00:31,  3.94it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 561/683 [02:22<00:30,  3.94it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 562/683 [02:22<00:30,  3.95it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 563/683 [02:22<00:30,  3.95it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 564/683 [02:22<00:30,  3.95it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 565/683 [02:23<00:29,  3.95it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 566/683 [02:23<00:29,  3.95it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 567/683 [02:23<00:29,  3.95it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 568/683 [02:23<00:29,  3.96it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 569/683 [02:23<00:28,  3.96it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 570/683 [02:24<00:28,  3.96it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 571/683 [02:24<00:28,  3.95it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 572/683 [02:24<00:28,  3.95it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 573/683 [02:24<00:27,  3.96it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 574/683 [02:25<00:27,  3.96it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 575/683 [02:25<00:27,  3.96it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 576/683 [02:25<00:27,  3.95it/s]
# Validation DataLoader 0:  84%|█████████████▌  | 577/683 [02:25<00:26,  3.95it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 578/683 [02:26<00:26,  3.95it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 579/683 [02:26<00:26,  3.94it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 580/683 [02:27<00:26,  3.94it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 581/683 [02:27<00:25,  3.94it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 582/683 [02:27<00:25,  3.94it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 583/683 [02:27<00:25,  3.95it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 584/683 [02:27<00:25,  3.95it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 585/683 [02:28<00:24,  3.95it/s]
# Validation DataLoader 0:  86%|█████████████▋  | 586/683 [02:28<00:24,  3.95it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 587/683 [02:28<00:24,  3.95it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 588/683 [02:28<00:24,  3.96it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 589/683 [02:28<00:23,  3.95it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 590/683 [02:29<00:23,  3.96it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 591/683 [02:29<00:23,  3.96it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 592/683 [02:29<00:22,  3.96it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 593/683 [02:29<00:22,  3.96it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 594/683 [02:29<00:22,  3.96it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 595/683 [02:30<00:22,  3.96it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 596/683 [02:30<00:21,  3.97it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 597/683 [02:30<00:21,  3.97it/s]
# Validation DataLoader 0:  88%|██████████████  | 598/683 [02:30<00:21,  3.97it/s]
# Validation DataLoader 0:  88%|██████████████  | 599/683 [02:30<00:21,  3.97it/s]
# Validation DataLoader 0:  88%|██████████████  | 600/683 [02:31<00:20,  3.97it/s]
# Validation DataLoader 0:  88%|██████████████  | 601/683 [02:31<00:20,  3.97it/s]
# Validation DataLoader 0:  88%|██████████████  | 602/683 [02:31<00:20,  3.97it/s]
# Validation DataLoader 0:  88%|██████████████▏ | 603/683 [02:32<00:20,  3.96it/s]
# Validation DataLoader 0:  88%|██████████████▏ | 604/683 [02:32<00:19,  3.96it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 605/683 [02:32<00:19,  3.96it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 606/683 [02:32<00:19,  3.96it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 607/683 [02:33<00:19,  3.96it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 608/683 [02:33<00:18,  3.96it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 609/683 [02:33<00:18,  3.96it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 610/683 [02:33<00:18,  3.97it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 611/683 [02:33<00:18,  3.97it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 612/683 [02:34<00:17,  3.97it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 613/683 [02:34<00:17,  3.97it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 614/683 [02:34<00:17,  3.97it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 615/683 [02:34<00:17,  3.97it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 616/683 [02:35<00:16,  3.97it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 617/683 [02:35<00:16,  3.97it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 618/683 [02:35<00:16,  3.97it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 619/683 [02:35<00:16,  3.97it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 620/683 [02:36<00:15,  3.97it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 621/683 [02:36<00:15,  3.98it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 622/683 [02:36<00:15,  3.98it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 623/683 [02:37<00:15,  3.97it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 624/683 [02:37<00:14,  3.97it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 625/683 [02:37<00:14,  3.97it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 626/683 [02:37<00:14,  3.97it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 627/683 [02:37<00:14,  3.97it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 628/683 [02:38<00:13,  3.97it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 629/683 [02:38<00:13,  3.97it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 630/683 [02:38<00:13,  3.97it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 631/683 [02:38<00:13,  3.97it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 632/683 [02:38<00:12,  3.97it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 633/683 [02:39<00:12,  3.97it/s]
# Validation DataLoader 0:  93%|██████████████▊ | 634/683 [02:39<00:12,  3.97it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 635/683 [02:40<00:12,  3.96it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 636/683 [02:40<00:11,  3.96it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 637/683 [02:40<00:11,  3.96it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 638/683 [02:41<00:11,  3.96it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 639/683 [02:41<00:11,  3.96it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 640/683 [02:41<00:10,  3.96it/s]
# Validation DataLoader 0:  94%|███████████████ | 641/683 [02:41<00:10,  3.97it/s]
# Validation DataLoader 0:  94%|███████████████ | 642/683 [02:41<00:10,  3.97it/s]
# Validation DataLoader 0:  94%|███████████████ | 643/683 [02:42<00:10,  3.97it/s]
# Validation DataLoader 0:  94%|███████████████ | 644/683 [02:42<00:09,  3.97it/s]
# Validation DataLoader 0:  94%|███████████████ | 645/683 [02:42<00:09,  3.97it/s]
# Validation DataLoader 0:  95%|███████████████▏| 646/683 [02:42<00:09,  3.98it/s]
# Validation DataLoader 0:  95%|███████████████▏| 647/683 [02:42<00:09,  3.97it/s]
# Validation DataLoader 0:  95%|███████████████▏| 648/683 [02:42<00:08,  3.98it/s]
# Validation DataLoader 0:  95%|███████████████▏| 649/683 [02:43<00:08,  3.98it/s]
# Validation DataLoader 0:  95%|███████████████▏| 650/683 [02:43<00:08,  3.97it/s]
# Validation DataLoader 0:  95%|███████████████▎| 651/683 [02:43<00:08,  3.97it/s]
# Validation DataLoader 0:  95%|███████████████▎| 652/683 [02:44<00:07,  3.97it/s]
# Validation DataLoader 0:  96%|███████████████▎| 653/683 [02:44<00:07,  3.97it/s]
# Validation DataLoader 0:  96%|███████████████▎| 654/683 [02:44<00:07,  3.97it/s]
# Validation DataLoader 0:  96%|███████████████▎| 655/683 [02:44<00:07,  3.97it/s]
# Validation DataLoader 0:  96%|███████████████▎| 656/683 [02:45<00:06,  3.97it/s]
# Validation DataLoader 0:  96%|███████████████▍| 657/683 [02:45<00:06,  3.97it/s]
# Validation DataLoader 0:  96%|███████████████▍| 658/683 [02:45<00:06,  3.98it/s]
# Validation DataLoader 0:  96%|███████████████▍| 659/683 [02:46<00:06,  3.97it/s]
# Validation DataLoader 0:  97%|███████████████▍| 660/683 [02:46<00:05,  3.97it/s]
# Validation DataLoader 0:  97%|███████████████▍| 661/683 [02:46<00:05,  3.97it/s]
# Validation DataLoader 0:  97%|███████████████▌| 662/683 [02:46<00:05,  3.98it/s]
# Validation DataLoader 0:  97%|███████████████▌| 663/683 [02:46<00:05,  3.98it/s]
# Validation DataLoader 0:  97%|███████████████▌| 664/683 [02:46<00:04,  3.98it/s]
# Validation DataLoader 0:  97%|███████████████▌| 665/683 [02:47<00:04,  3.98it/s]
# Validation DataLoader 0:  98%|███████████████▌| 666/683 [02:47<00:04,  3.98it/s]
# Validation DataLoader 0:  98%|███████████████▋| 667/683 [02:47<00:04,  3.98it/s]
# Validation DataLoader 0:  98%|███████████████▋| 668/683 [02:47<00:03,  3.98it/s]
# Validation DataLoader 0:  98%|███████████████▋| 669/683 [02:48<00:03,  3.98it/s]
# Validation DataLoader 0:  98%|███████████████▋| 670/683 [02:48<00:03,  3.98it/s]
# Validation DataLoader 0:  98%|███████████████▋| 671/683 [02:48<00:03,  3.97it/s]
# Validation DataLoader 0:  98%|███████████████▋| 672/683 [02:49<00:02,  3.97it/s]
# Validation DataLoader 0:  99%|███████████████▊| 673/683 [02:49<00:02,  3.97it/s]
# Validation DataLoader 0:  99%|███████████████▊| 674/683 [02:49<00:02,  3.97it/s]
# Validation DataLoader 0:  99%|███████████████▊| 675/683 [02:50<00:02,  3.97it/s]
# Validation DataLoader 0:  99%|███████████████▊| 676/683 [02:50<00:01,  3.97it/s]
# Validation DataLoader 0:  99%|███████████████▊| 677/683 [02:50<00:01,  3.97it/s]
# Validation DataLoader 0:  99%|███████████████▉| 678/683 [02:50<00:01,  3.97it/s]
# Validation DataLoader 0:  99%|███████████████▉| 679/683 [02:51<00:01,  3.97it/s]
# Validation DataLoader 0: 100%|███████████████▉| 680/683 [02:51<00:00,  3.97it/s]
# Validation DataLoader 0: 100%|███████████████▉| 681/683 [02:51<00:00,  3.97it/s]
# Validation DataLoader 0: 100%|███████████████▉| 682/683 [02:51<00:00,  3.97it/s]
# Epoch 0: 100%|█| 135740/135740 [30:47:33<00:00,  1.22it/s, v_num=by82, train/los
# Epoch 0: 100%|█| 135740/135740 [30:47:33<00:00,  1.22it/s, v_num=by82, train/los`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 135740/135740 [30:48:03<00:00,  1.22it/s, v_num=by82, train/los
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▂▂▁▂▂▆▂▁▁▁▄▁▁█▂▁▁▂▃▂▁▄▁▁▁▁▂▁▁▃▁▂▃▇
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:            train/loss ▆▅▅▇▆▅▇█▅▅▄▇▇▄▇▇▇▆▆▆▁▄▆▆▆█▆▅▆▆▇▆▆▆▆▇█▆▇▅
# wandb:   trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 682
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 1347
# wandb:               substep 682
# wandb:            train/loss 2.65625
# wandb:   trainer/global_step 4241
# wandb: trainer/learning_rate 0.0003
# wandb:       validation/loss 2.5626
# wandb:
# wandb: 🚀 View run FrankenShift-1B5 - Enwiki Retrain (train-ctx=2048, deepspeed_stage_2_offload) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/g7s2by82
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230802_225412-g7s2by82/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/FrankenShift-1B5-enwiki/last.ckpt" "../model/FrankenShift-1B5-Stage1.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/FrankenShift-1B5-Stage1.pth"
# Out:
# [2023-08-04 05:43:20,490] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/FrankenShift-1B5-enwiki/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.gradients, world_size: 1
# Parsing checkpoint created by deepspeed==0.9.5
# Reconstructed fp32 state dict with 438 params 1515106304 elements
# Saving fp32 state dict to ../model/FrankenShift-1B5-Stage1.pth
# -rw-rw-r-- 1 picocreator picocreator 5.7G Aug  4 05:43 ../model/FrankenShift-1B5-Stage1.pth

# %%
# # Lets do a quick dragon prompt validation
# !cd "{INFERENCE_DIR}" && python3 dragon_test.py ../model/FrankenShift-1B5-Stage1.pth "cuda fp32"
# Out:
# [2023-08-04 05:43:47,016] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# [RWKV.model]: Preloading model from '../model/FrankenShift-1B5-Stage1.pth'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# [RWKV.model]: Loading model weights ( L24-D2048-V50277 )
# [RWKV.model]: Finished initial model load
# --- DRAGON PROMPT ---
# In a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese..... the history of God
#
# (Alma is in) is a man's been hard, is a very I
# chymology and stu...(Shug) is a video-game console medium work of a video game
# film series
# ...emperor'says, from Egypt is an Egyptian movie, is a science fiction film, from the TV series of HBO, a New York City movie by Stephen King
# is a video-admission is a film where a character character in a video game film is a work of a video or video, video of, or material produced by or of the video character of a fictional character, and also a medium, a work of art that a character is not a work, a work, or is, follic
# a character that an English language, also known as a play, film, or play, is a media-ad game,[n] is a film video, is a media video game adaptation of the Stephen Bees

# %%
# Lets do a quick memory test
# (We dun expect this to work, as we have not finetune for memory recall, but its a baseline)
# !python3 ../memory_script/eval_model_memory_guided.py "{PROJECT_DIR}/model/FrankenShift-1B5-Stage1.pth"
# Out:
# [2023-08-04 05:44:50,621] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# [RWKV.model]: Preloading model from '/home/picocreator/rwkv-proj/picocreator-memory-experiment/model/FrankenShift-1B5-Stage1.pth'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# [RWKV.model]: Loading model weights ( L24-D2048-V50277 )
# [RWKV.model]: Finished initial model load
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 80.0% similarity, with 4 matched token, and 1 token mismatch
# ## Model validation for 10 tokens : 90.0% similarity, with 9 matched token, and 1 token mismatch
# ## Model validation for 15 tokens : 80.0% similarity, with 12 matched token, and 3 token mismatch
# ## Model validation for 20 tokens : 75.0% similarity, with 15 matched token, and 5 token mismatch
# ## Model validation for 25 tokens : 72.0% similarity, with 18 matched token, and 7 token mismatch
# ## Model validation for 30 tokens : 63.33333333333333% similarity, with 19 matched token, and 11 token mismatch
# ## Model validation for 35 tokens : 48.57142857142857% similarity, with 17 matched token, and 18 token mismatch
# ## Model validation for 40 tokens : 47.5% similarity, with 19 matched token, and 21 token mismatch
# ## Model validation for 45 tokens : 40.0% similarity, with 18 matched token, and 27 token mismatch
# ## Model validation for 50 tokens : 40.0% similarity, with 20 matched token, and 30 token mismatch
# ## Model validation for 55 tokens : 36.36363636363637% similarity, with 20 matched token, and 35 token mismatch
# ## Model validation for 60 tokens : 31.666666666666664% similarity, with 19 matched token, and 41 token mismatch
# ## Model validation for 65 tokens : 36.92307692307693% similarity, with 24 matched token, and 41 token mismatch
# ## Model validation for 70 tokens : 32.857142857142854% similarity, with 23 matched token, and 47 token mismatch
# ## Model validation for 75 tokens : 28.000000000000004% similarity, with 21 matched token, and 54 token mismatch
# ## Model validation for 80 tokens : 26.25% similarity, with 21 matched token, and 59 token mismatch
# ## Model validation for 85 tokens : 20.0% similarity, with 17 matched token, and 68 token mismatch
# ## Model validation for 90 tokens : 18.88888888888889% similarity, with 17 matched token, and 73 token mismatch
# ## Model validation for 95 tokens : 17.894736842105264% similarity, with 17 matched token, and 78 token mismatch
# ## Model validation for 100 tokens : 17.0% similarity, with 17 matched token, and 83 token mismatch
# ## Model validation for 105 tokens : 17.142857142857142% similarity, with 18 matched token, and 87 token mismatch
# ## Model validation for 110 tokens : 16.363636363636363% similarity, with 18 matched token, and 92 token mismatch
# ## Model validation for 115 tokens : 15.65217391304348% similarity, with 18 matched token, and 97 token mismatch
# ## Model validation for 120 tokens : 14.166666666666666% similarity, with 17 matched token, and 103 token mismatch
# ## Model validation for 125 tokens : 14.399999999999999% similarity, with 18 matched token, and 107 token mismatch
# ## Model validation for 130 tokens : 13.076923076923078% similarity, with 17 matched token, and 113 token mismatch
# ## Model validation for 135 tokens : 12.592592592592592% similarity, with 17 matched token, and 118 token mismatch
# ## Model validation for 140 tokens : 12.857142857142856% similarity, with 18 matched token, and 122 token mismatch
# ## Model validation for 145 tokens : 14.482758620689657% similarity, with 21 matched token, and 124 token mismatch
# ## Model validation for 150 tokens : 13.333333333333334% similarity, with 20 matched token, and 130 token mismatch
# ## Model validation for 160 tokens : 11.875% similarity, with 19 matched token, and 141 token mismatch
# ## Model validation for 170 tokens : 11.176470588235295% similarity, with 19 matched token, and 151 token mismatch
# ## Model validation for 180 tokens : 9.444444444444445% similarity, with 17 matched token, and 163 token mismatch
# ## Model validation for 190 tokens : 10.0% similarity, with 19 matched token, and 171 token mismatch
# ## Model validation for 200 tokens : 8.5% similarity, with 17 matched token, and 183 token mismatch
# ## Model validation for 210 tokens : 9.047619047619047% similarity, with 19 matched token, and 191 token mismatch
# ## Model validation for 220 tokens : 8.181818181818182% similarity, with 18 matched token, and 202 token mismatch
# ## Model validation for 230 tokens : 8.695652173913043% similarity, with 20 matched token, and 210 token mismatch
# ## Model validation for 240 tokens : 7.916666666666666% similarity, with 19 matched token, and 221 token mismatch
# ## Model validation for 250 tokens : 8.0% similarity, with 20 matched token, and 230 token mismatch
# ## Model validation for 260 tokens : 7.307692307692308% similarity, with 19 matched token, and 241 token mismatch
# ## Model validation for 270 tokens : 6.666666666666667% similarity, with 18 matched token, and 252 token mismatch
# ## Model validation for 280 tokens : 5.714285714285714% similarity, with 16 matched token, and 264 token mismatch
# ## Model validation for 290 tokens : 5.517241379310345% similarity, with 16 matched token, and 274 token mismatch
# ## Model validation for 300 tokens : 5.666666666666666% similarity, with 17 matched token, and 283 token mismatch
# ## Model validation for 325 tokens : 5.846153846153846% similarity, with 19 matched token, and 306 token mismatch
# ## Model validation for 350 tokens : 4.285714285714286% similarity, with 15 matched token, and 335 token mismatch
# ## Model validation for 375 tokens : 4.266666666666667% similarity, with 16 matched token, and 359 token mismatch
# ## Model validation for 400 tokens : 3.25% similarity, with 13 matched token, and 387 token mismatch
# ## Model validation for 425 tokens : 3.294117647058824% similarity, with 14 matched token, and 411 token mismatch
# ## Model validation for 450 tokens : 3.111111111111111% similarity, with 14 matched token, and 436 token mismatch
# ## Model validation for 475 tokens : 2.1052631578947367% similarity, with 10 matched token, and 465 token mismatch
# ## Model validation for 500 tokens : 2.1999999999999997% similarity, with 11 matched token, and 489 token mismatch
# ## Model validation for 525 tokens : 1.9047619047619049% similarity, with 10 matched token, and 515 token mismatch
# ## Model validation for 550 tokens : 2.3636363636363638% similarity, with 13 matched token, and 537 token mismatch
# ## Model validation for 575 tokens : 2.2608695652173916% similarity, with 13 matched token, and 562 token mismatch
# ## Model validation for 600 tokens : 2.166666666666667% similarity, with 13 matched token, and 587 token mismatch
# ## Model validation for 625 tokens : 2.2399999999999998% similarity, with 14 matched token, and 611 token mismatch
# ## Model validation for 650 tokens : 2.1538461538461537% similarity, with 14 matched token, and 636 token mismatch
# ## Model validation for 675 tokens : 2.2222222222222223% similarity, with 15 matched token, and 660 token mismatch
# ## Model validation for 700 tokens : 2.0% similarity, with 14 matched token, and 686 token mismatch
# ## Model validation for 750 tokens : 2.0% similarity, with 15 matched token, and 735 token mismatch
# ## Model validation for 800 tokens : 1.7500000000000002% similarity, with 14 matched token, and 786 token mismatch
# ## Model validation for 850 tokens : 1.8823529411764703% similarity, with 16 matched token, and 834 token mismatch
# ## Model validation for 900 tokens : 1.8888888888888888% similarity, with 17 matched token, and 883 token mismatch
# ## Model validation for 950 tokens : 2.0% similarity, with 19 matched token, and 931 token mismatch
# ## Model validation for 1000 tokens : 2.1% similarity, with 21 matched token, and 979 token mismatch

# %% [markdown]
# # Stage 2 : Instruct Tuning

# %%
# Lets preload the requried dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/FrankenShift-1B5-instruct.yaml"
# Out:
# [2023-08-04 05:49:45,370] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 35.93it/s]

# %%
# Start the instruct finetuning
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/FrankenShift-1B5-instruct.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Instruct Retrain (train-ctx=2048, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"\
        --model.substep_cuda_cache_clear="{SUBSTEP_CUDA_CACHE_CLEAR}"
# Out:
# [RWKV.lightning_trainer.py] Running with PYTORCH_CUDA_ALLOC_CONF=backend:cudaMallocAsync
# [2023-08-04 05:50:02,631] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:484: UserWarning: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/picocreator/rwkv-proj/picocreator-memory-experiment/notebook/experiment/tokenshift-exp/FrankenShift-1B5/FrankenShift-1B5-instruct.yaml', '--trainer.logger.init_args.name=FrankenShift-1B5 - Instruct Retrain (train-ctx=2048, deepspeed_stage_2_offload)', '--trainer.strategy=deepspeed_stage_2_offload', '--trainer.devices=auto', '--model.substep_cuda_cache_clear=True'], args=['fit', '-c', '/home/picocreator/rwkv-proj/picocreator-memory-experiment/notebook/experiment/tokenshift-exp/FrankenShift-1B5/FrankenShift-1B5-instruct.yaml', '--trainer.logger.init_args.name=FrankenShift-1B5 - Instruct Retrain (train-ctx=2048, deepspeed_stage_2_offload)', '--trainer.strategy=deepspeed_stage_2_offload', '--trainer.devices=auto', '--model.substep_cuda_cache_clear=True'].
#   rank_zero_warn(
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/utilities/seed.py:39: UserWarning: No seed found, seed set to 77600742
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 77600742
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.5
# wandb: Run data is saved locally in ./wandb/run-20230804_055005-2s04ectf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run FrankenShift-1B5 - Instruct Retrain (train-ctx=2048, deepspeed_stage_2_offload)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-5X-Experiments
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/2s04ectf
# [RWKV.model]: Preloading model from '../model/FrankenShift-1B5-Stage1.pth'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_4096_bf16/build.ninja...
# Building extension module wkv_4096_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_4096_bf16...
# [RWKV.model]: Loading model weights ( L24-D2048-V50277 )
# [RWKV.model]: Finished initial model load
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       32
#    - num_nodes:               1
#    - num_devices:             1
#    - accumulate_grad_batches: 32
#    - effective_batch_size:    32
#
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 833.69it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-3d2847a277205fc6_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-e4bba898f7026801_*_of_00016.arrow
# Loading cached split indices for dataset at /home/picocreator/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-54cefd0e1317ce25.arrow and /home/picocreator/.cache/huggingface/datasets/c-s-ale___parquet/c-s-ale--dolly-15k-instruction-alpaca-format-9dfbb23260d63d9d/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-d3088ccb887b23bf.arrow
# [rank: 0] Global seed set to 77600742
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-08-04 05:50:26,995] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [RWKV.model][rank=0] Configuring optimizer ...
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  3.000e-04 (0.0003)
#     - lr_final: 2.000e-04 (0.0002)
#
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.323194980621338 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# [RWKV.model][rank=0] Loaded optimizer (linear schedule) ...
# Rank: 0 partition count [1, 1, 1] and sizes[(1515008000, False), (49152, False), (49152, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0:  54%|▌| 8000/14939 [1:10:12<1:00:53,  1.90it/s, v_num=ectf, train/loss=/home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1802: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 14939/14939 [2:16:04<00:00,  1.83it/s, v_num=ectf, train/loss=0
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/76 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/76 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▎                  | 1/76 [00:00<00:13,  5.50it/s]
# Validation DataLoader 0:   3%|▌                  | 2/76 [00:00<00:12,  6.08it/s]
# Validation DataLoader 0:   4%|▊                  | 3/76 [00:00<00:11,  6.33it/s]
# Validation DataLoader 0:   5%|█                  | 4/76 [00:00<00:11,  6.45it/s]
# Validation DataLoader 0:   7%|█▎                 | 5/76 [00:00<00:10,  6.50it/s]
# Validation DataLoader 0:   8%|█▌                 | 6/76 [00:00<00:10,  6.53it/s]
# Validation DataLoader 0:   9%|█▊                 | 7/76 [00:01<00:10,  6.57it/s]
# Validation DataLoader 0:  11%|██                 | 8/76 [00:01<00:10,  6.60it/s]
# Validation DataLoader 0:  12%|██▎                | 9/76 [00:01<00:10,  6.62it/s]
# Validation DataLoader 0:  13%|██▎               | 10/76 [00:01<00:09,  6.64it/s]
# Validation DataLoader 0:  14%|██▌               | 11/76 [00:01<00:09,  6.65it/s]
# Validation DataLoader 0:  16%|██▊               | 12/76 [00:01<00:09,  6.66it/s]
# Validation DataLoader 0:  17%|███               | 13/76 [00:01<00:09,  6.67it/s]
# Validation DataLoader 0:  18%|███▎              | 14/76 [00:02<00:09,  6.68it/s]
# Validation DataLoader 0:  20%|███▌              | 15/76 [00:02<00:09,  6.69it/s]
# Validation DataLoader 0:  21%|███▊              | 16/76 [00:02<00:08,  6.69it/s]
# Validation DataLoader 0:  22%|████              | 17/76 [00:02<00:08,  6.71it/s]
# Validation DataLoader 0:  24%|████▎             | 18/76 [00:02<00:08,  6.71it/s]
# Validation DataLoader 0:  25%|████▌             | 19/76 [00:02<00:08,  6.72it/s]
# Validation DataLoader 0:  26%|████▋             | 20/76 [00:02<00:08,  6.72it/s]
# Validation DataLoader 0:  28%|████▉             | 21/76 [00:03<00:08,  6.73it/s]
# Validation DataLoader 0:  29%|█████▏            | 22/76 [00:03<00:08,  6.73it/s]
# Validation DataLoader 0:  30%|█████▍            | 23/76 [00:03<00:07,  6.73it/s]
# Validation DataLoader 0:  32%|█████▋            | 24/76 [00:03<00:07,  6.73it/s]
# Validation DataLoader 0:  33%|█████▉            | 25/76 [00:03<00:07,  6.73it/s]
# Validation DataLoader 0:  34%|██████▏           | 26/76 [00:03<00:07,  6.74it/s]
# Validation DataLoader 0:  36%|██████▍           | 27/76 [00:04<00:07,  6.75it/s]
# Validation DataLoader 0:  37%|██████▋           | 28/76 [00:04<00:07,  6.75it/s]
# Validation DataLoader 0:  38%|██████▊           | 29/76 [00:04<00:06,  6.75it/s]
# Validation DataLoader 0:  39%|███████           | 30/76 [00:04<00:06,  6.75it/s]
# Validation DataLoader 0:  41%|███████▎          | 31/76 [00:04<00:06,  6.76it/s]
# Validation DataLoader 0:  42%|███████▌          | 32/76 [00:04<00:06,  6.76it/s]
# Validation DataLoader 0:  43%|███████▊          | 33/76 [00:04<00:06,  6.77it/s]
# Validation DataLoader 0:  45%|████████          | 34/76 [00:05<00:06,  6.77it/s]
# Validation DataLoader 0:  46%|████████▎         | 35/76 [00:05<00:06,  6.77it/s]
# Validation DataLoader 0:  47%|████████▌         | 36/76 [00:05<00:05,  6.77it/s]
# Validation DataLoader 0:  49%|████████▊         | 37/76 [00:05<00:05,  6.77it/s]
# Validation DataLoader 0:  50%|█████████         | 38/76 [00:05<00:05,  6.77it/s]
# Validation DataLoader 0:  51%|█████████▏        | 39/76 [00:05<00:05,  6.77it/s]
# Validation DataLoader 0:  53%|█████████▍        | 40/76 [00:05<00:05,  6.77it/s]
# Validation DataLoader 0:  54%|█████████▋        | 41/76 [00:06<00:05,  6.77it/s]
# Validation DataLoader 0:  55%|█████████▉        | 42/76 [00:06<00:05,  6.77it/s]
# Validation DataLoader 0:  57%|██████████▏       | 43/76 [00:06<00:04,  6.77it/s]
# Validation DataLoader 0:  58%|██████████▍       | 44/76 [00:06<00:04,  6.77it/s]
# Validation DataLoader 0:  59%|██████████▋       | 45/76 [00:06<00:04,  6.77it/s]
# Validation DataLoader 0:  61%|██████████▉       | 46/76 [00:06<00:04,  6.77it/s]
# Validation DataLoader 0:  62%|███████████▏      | 47/76 [00:06<00:04,  6.78it/s]
# Validation DataLoader 0:  63%|███████████▎      | 48/76 [00:07<00:04,  6.78it/s]
# Validation DataLoader 0:  64%|███████████▌      | 49/76 [00:07<00:03,  6.78it/s]
# Validation DataLoader 0:  66%|███████████▊      | 50/76 [00:07<00:03,  6.78it/s]
# Validation DataLoader 0:  67%|████████████      | 51/76 [00:07<00:03,  6.77it/s]
# Validation DataLoader 0:  68%|████████████▎     | 52/76 [00:07<00:03,  6.77it/s]
# Validation DataLoader 0:  70%|████████████▌     | 53/76 [00:07<00:03,  6.76it/s]
# Validation DataLoader 0:  71%|████████████▊     | 54/76 [00:07<00:03,  6.76it/s]
# Validation DataLoader 0:  72%|█████████████     | 55/76 [00:08<00:03,  6.76it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 56/76 [00:08<00:02,  6.76it/s]
# Validation DataLoader 0:  75%|█████████████▌    | 57/76 [00:08<00:02,  6.76it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 58/76 [00:08<00:02,  6.76it/s]
# Validation DataLoader 0:  78%|█████████████▉    | 59/76 [00:08<00:02,  6.76it/s]
# Validation DataLoader 0:  79%|██████████████▏   | 60/76 [00:08<00:02,  6.76it/s]
# Validation DataLoader 0:  80%|██████████████▍   | 61/76 [00:09<00:02,  6.75it/s]
# Validation DataLoader 0:  82%|██████████████▋   | 62/76 [00:09<00:02,  6.76it/s]
# Validation DataLoader 0:  83%|██████████████▉   | 63/76 [00:09<00:01,  6.75it/s]
# Validation DataLoader 0:  84%|███████████████▏  | 64/76 [00:09<00:01,  6.75it/s]
# Validation DataLoader 0:  86%|███████████████▍  | 65/76 [00:09<00:01,  6.75it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 66/76 [00:09<00:01,  6.75it/s]
# Validation DataLoader 0:  88%|███████████████▊  | 67/76 [00:09<00:01,  6.74it/s]
# Validation DataLoader 0:  89%|████████████████  | 68/76 [00:10<00:01,  6.74it/s]
# Validation DataLoader 0:  91%|████████████████▎ | 69/76 [00:10<00:01,  6.74it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 70/76 [00:10<00:00,  6.74it/s]
# Validation DataLoader 0:  93%|████████████████▊ | 71/76 [00:10<00:00,  6.74it/s]
# Validation DataLoader 0:  95%|█████████████████ | 72/76 [00:10<00:00,  6.74it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 73/76 [00:10<00:00,  6.74it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 74/76 [00:10<00:00,  6.74it/s]
# Validation DataLoader 0:  99%|█████████████████▊| 75/76 [00:11<00:00,  6.73it/s]
# Epoch 0: 100%|█| 14939/14939 [2:16:18<00:00,  1.83it/s, v_num=ectf, train/loss=0
# Epoch 0: 100%|█| 14939/14939 [2:16:18<00:00,  1.83it/s, v_num=ectf, train/loss=0`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 14939/14939 [2:17:46<00:00,  1.81it/s, v_num=ectf, train/loss=0
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▃▁▂▂▃▄▂▂▃█▂▂▂▁▁▁▂▃▁▁█▃▂▄▁▁▂▁▃▂▁▁▂▁▂▂▂▂
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:            train/loss ▄▇▇▅▃▂█▆▅▇▃▄▆▄▁▂▆▆▆▅▄▅▅▆▃▁▅▃▅▆▂▆▆▄█▅▅▆▇▂
# wandb:   trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 75
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 37
# wandb:               substep 75
# wandb:            train/loss 1.21094
# wandb:   trainer/global_step 466
# wandb: trainer/learning_rate 0.0002
# wandb:       validation/loss 2.10465
# wandb:
# wandb: 🚀 View run FrankenShift-1B5 - Instruct Retrain (train-ctx=2048, deepspeed_stage_2_offload) at: https://wandb.ai/picocreator/RWKV-5X-Experiments/runs/2s04ectf
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230804_055005-2s04ectf/logs

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/FrankenShift-1B5-instruct/last.ckpt" "../model/FrankenShift-1B5-Stage2.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/FrankenShift-1B5-Stage2.pth"
# Out:
# [2023-08-04 08:08:57,178] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/FrankenShift-1B5-instruct/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.gradients, world_size: 1
# Parsing checkpoint created by deepspeed==0.9.5
# Reconstructed fp32 state dict with 438 params 1515106304 elements
# Saving fp32 state dict to ../model/FrankenShift-1B5-Stage2.pth
# -rw-rw-r-- 1 picocreator picocreator 5.7G Aug  4 08:09 ../model/FrankenShift-1B5-Stage2.pth

# %%
# Lets do a quick dragon prompt validation
# !cd "{INFERENCE_DIR}" && python3 dragon_test.py "../model/FrankenShift-1B5-Stage2.pth" "cuda fp32"
# Out:
# [2023-08-04 08:09:21,937] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# [RWKV.model]: Preloading model from '../model/FrankenShift-1B5-Stage2.pth'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# [RWKV.model]: Loading model weights ( L24-D2048-V50277 )
# [RWKV.model]: Finished initial model load
# --- DRAGON PROMPT ---
# In a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese. This discovery led to the idea that the people in the area had the ability to communicate with the dragons in Tibetan and with it the ability to use dragons as magical allies. The team was named The World Dragons.
#
# While a dragon is not alive, it is not uncommon for the world to have a species of dragon that it does not recognize. Instead, it is the most famous of the dragons that humans call dragons, and they are the perfect heroes. They are the all-powerful beings that rule over all the rest of the world. The world has an entire history of contact with the dragons.
#
# The discovery of a species of dragon with the power to speak, for example, is one of the key moments in the development of humanity. When it was discovered, the dragons were no longer considered magical. This discovery caused an international stir, with governments and scientists declaring that the world was flat. This discovery also set a precedent for the future development of intelligent life in our world.

# %%
# Lets do a quick memory test
# (We dun expect this to work, as we have not finetune for memory recall, but its a baseline)
# !python3 ../memory_script/eval_model_memory_guided.py "{PROJECT_DIR}/model/FrankenShift-1B5-Stage2.pth"
# Out:
# [2023-08-04 08:10:26,234] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# [RWKV.model]: Preloading model from '/home/picocreator/rwkv-proj/picocreator-memory-experiment/model/FrankenShift-1B5-Stage2.pth'
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# [RWKV.model]: Loading model weights ( L24-D2048-V50277 )
# [RWKV.model]: Finished initial model load
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 90.0% similarity, with 9 matched token, and 1 token mismatch
# ## Model validation for 15 tokens : 86.66666666666667% similarity, with 13 matched token, and 2 token mismatch
# ## Model validation for 20 tokens : 75.0% similarity, with 15 matched token, and 5 token mismatch
# ## Model validation for 25 tokens : 68.0% similarity, with 17 matched token, and 8 token mismatch
# ## Model validation for 30 tokens : 73.33333333333333% similarity, with 22 matched token, and 8 token mismatch
# ## Model validation for 35 tokens : 62.857142857142854% similarity, with 22 matched token, and 13 token mismatch
# ## Model validation for 40 tokens : 57.49999999999999% similarity, with 23 matched token, and 17 token mismatch
# ## Model validation for 45 tokens : 60.0% similarity, with 27 matched token, and 18 token mismatch
# ## Model validation for 50 tokens : 54.0% similarity, with 27 matched token, and 23 token mismatch
# ## Model validation for 55 tokens : 45.45454545454545% similarity, with 25 matched token, and 30 token mismatch
# ## Model validation for 60 tokens : 40.0% similarity, with 24 matched token, and 36 token mismatch
# ## Model validation for 65 tokens : 40.0% similarity, with 26 matched token, and 39 token mismatch
# ## Model validation for 70 tokens : 32.857142857142854% similarity, with 23 matched token, and 47 token mismatch
# ## Model validation for 75 tokens : 34.66666666666667% similarity, with 26 matched token, and 49 token mismatch
# ## Model validation for 80 tokens : 35.0% similarity, with 28 matched token, and 52 token mismatch
# ## Model validation for 85 tokens : 29.411764705882355% similarity, with 25 matched token, and 60 token mismatch
# ## Model validation for 90 tokens : 27.77777777777778% similarity, with 25 matched token, and 65 token mismatch
# ## Model validation for 95 tokens : 24.210526315789473% similarity, with 23 matched token, and 72 token mismatch
# ## Model validation for 100 tokens : 21.0% similarity, with 21 matched token, and 79 token mismatch
# ## Model validation for 105 tokens : 20.952380952380953% similarity, with 22 matched token, and 83 token mismatch
# ## Model validation for 110 tokens : 20.0% similarity, with 22 matched token, and 88 token mismatch
# ## Model validation for 115 tokens : 16.52173913043478% similarity, with 19 matched token, and 96 token mismatch
# ## Model validation for 120 tokens : 16.666666666666664% similarity, with 20 matched token, and 100 token mismatch
# ## Model validation for 125 tokens : 18.4% similarity, with 23 matched token, and 102 token mismatch
# ## Model validation for 130 tokens : 16.923076923076923% similarity, with 22 matched token, and 108 token mismatch
# ## Model validation for 135 tokens : 15.555555555555555% similarity, with 21 matched token, and 114 token mismatch
# ## Model validation for 140 tokens : 15.0% similarity, with 21 matched token, and 119 token mismatch
# ## Model validation for 145 tokens : 13.10344827586207% similarity, with 19 matched token, and 126 token mismatch
# ## Model validation for 150 tokens : 12.666666666666668% similarity, with 19 matched token, and 131 token mismatch
# ## Model validation for 160 tokens : 10.625% similarity, with 17 matched token, and 143 token mismatch
# ## Model validation for 170 tokens : 10.588235294117647% similarity, with 18 matched token, and 152 token mismatch
# ## Model validation for 180 tokens : 11.11111111111111% similarity, with 20 matched token, and 160 token mismatch
# ## Model validation for 190 tokens : 11.052631578947368% similarity, with 21 matched token, and 169 token mismatch
# ## Model validation for 200 tokens : 11.5% similarity, with 23 matched token, and 177 token mismatch
# ## Model validation for 210 tokens : 11.428571428571429% similarity, with 24 matched token, and 186 token mismatch
# ## Model validation for 220 tokens : 10.0% similarity, with 22 matched token, and 198 token mismatch
# ## Model validation for 230 tokens : 9.130434782608695% similarity, with 21 matched token, and 209 token mismatch
# ## Model validation for 240 tokens : 8.333333333333332% similarity, with 20 matched token, and 220 token mismatch
# ## Model validation for 250 tokens : 7.6% similarity, with 19 matched token, and 231 token mismatch
# ## Model validation for 260 tokens : 6.923076923076923% similarity, with 18 matched token, and 242 token mismatch
# ## Model validation for 270 tokens : 6.666666666666667% similarity, with 18 matched token, and 252 token mismatch
# ## Model validation for 280 tokens : 6.785714285714286% similarity, with 19 matched token, and 261 token mismatch
# ## Model validation for 290 tokens : 5.862068965517241% similarity, with 17 matched token, and 273 token mismatch
# ## Model validation for 300 tokens : 6.333333333333334% similarity, with 19 matched token, and 281 token mismatch
# ## Model validation for 325 tokens : 4.615384615384616% similarity, with 15 matched token, and 310 token mismatch
# ## Model validation for 350 tokens : 4.0% similarity, with 14 matched token, and 336 token mismatch
# ## Model validation for 375 tokens : 4.0% similarity, with 15 matched token, and 360 token mismatch
# ## Model validation for 400 tokens : 3.0% similarity, with 12 matched token, and 388 token mismatch
# ## Model validation for 425 tokens : 2.823529411764706% similarity, with 12 matched token, and 413 token mismatch
# ## Model validation for 450 tokens : 2.888888888888889% similarity, with 13 matched token, and 437 token mismatch
# ## Model validation for 475 tokens : 2.736842105263158% similarity, with 13 matched token, and 462 token mismatch
# ## Model validation for 500 tokens : 2.4% similarity, with 12 matched token, and 488 token mismatch
# ## Model validation for 525 tokens : 2.0952380952380953% similarity, with 11 matched token, and 514 token mismatch
# ## Model validation for 550 tokens : 2.181818181818182% similarity, with 12 matched token, and 538 token mismatch
# ## Model validation for 575 tokens : 2.086956521739131% similarity, with 12 matched token, and 563 token mismatch
# ## Model validation for 600 tokens : 1.8333333333333333% similarity, with 11 matched token, and 589 token mismatch
# ## Model validation for 625 tokens : 2.56% similarity, with 16 matched token, and 609 token mismatch
# ## Model validation for 650 tokens : 2.307692307692308% similarity, with 15 matched token, and 635 token mismatch
# ## Model validation for 675 tokens : 2.2222222222222223% similarity, with 15 matched token, and 660 token mismatch
# ## Model validation for 700 tokens : 2.142857142857143% similarity, with 15 matched token, and 685 token mismatch
# ## Model validation for 750 tokens : 2.1333333333333333% similarity, with 16 matched token, and 734 token mismatch
# ## Model validation for 800 tokens : 2.125% similarity, with 17 matched token, and 783 token mismatch
# ## Model validation for 850 tokens : 2.588235294117647% similarity, with 22 matched token, and 828 token mismatch
# ## Model validation for 900 tokens : 2.555555555555556% similarity, with 23 matched token, and 877 token mismatch
# ## Model validation for 950 tokens : 2.4210526315789473% similarity, with 23 matched token, and 927 token mismatch
# ## Model validation for 1000 tokens : 2.4% similarity, with 24 matched token, and 976 token mismatch
