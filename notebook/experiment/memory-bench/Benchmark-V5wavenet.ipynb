# %% [markdown]
# ## Custom Experimental Memory benchmarking
#
# The following is meant to observe the memory performance in a more verbose CSV logging mode, for the baseline raven models

# %%
# Lets download the custom models
# !mkdir -p ../../../model/
# !cd ../../../model/ && wget -nc "https://huggingface.co/picocreator/memory-size-experiment-for-rwkv/resolve/main/v5-Wave/WaveV5-C-Tune5.pth"
# !cd ../../../model/ && wget -nc "https://huggingface.co/picocreator/RWKV-x-playground/resolve/main/V5-16k/v5wave-1B5-E0_1-ctx-16k-preview-30p.pth"
# Out:
# File ‘WaveV5-C-Tune5.pth’ already there; not retrieving.
# File ‘v5wave-1B5-E0_1-ctx-16k-preview-30p.pth’ already there; not retrieving.

# %%
# !ls -lh ../../../model/

# %%
# !python -m pip install aiocsv aiofiles

# %% [markdown]
# # 1B5 Wavenet V5 benchmark

# %%
# !python3 ./memory_script/eval_v5wavenet_memory_guided.py "../../../model/WaveV5-C-Tune5.pth" "./logs/WavenetV5-C-Tune5-4k.csv" 1100 4000
# Out:
# [2023-08-17 09:35:05,481] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# ###
# ### Model validation start ###
# ###
# ## Model validation for 1100 tokens : 82.45454545454545% similarity, with 907 matched token, and 193 token mismatch
# ## Model validation for 1150 tokens : 83.47826086956522% similarity, with 960 matched token, and 190 token mismatch
# ## Model validation for 1200 tokens : 84.08333333333333% similarity, with 1009 matched token, and 191 token mismatch
# ## Model validation for 1250 tokens : 84.39999999999999% similarity, with 1055 matched token, and 195 token mismatch
# ## Model validation for 1300 tokens : 84.6923076923077% similarity, with 1101 matched token, and 199 token mismatch
# ## Model validation for 1350 tokens : 85.4074074074074% similarity, with 1153 matched token, and 197 token mismatch
# ...

# %%
# !python3 ./memory_script/eval_v5wavenet_memory_guided.py "../../../model/WaveV5-C-Tune5.pth" "./logs/WavenetV5-C-Tune5-16k.csv" 4100 16000
# Out:
# [2023-08-17 08:36:25,210] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# ###
# ### Model validation start ###
# ###
# ## Model validation for 4100 tokens : 31.585365853658537% similarity, with 1295 matched token, and 2805 token mismatch
# ## Model validation for 4200 tokens : 30.80952380952381% similarity, with 1294 matched token, and 2906 token mismatch
# ## Model validation for 4300 tokens : 29.511627906976745% similarity, with 1269 matched token, and 3031 token mismatch
# ## Model validation for 4400 tokens : 28.204545454545453% similarity, with 1241 matched token, and 3159 token mismatch
# ## Model validation for 4500 tokens : 27.244444444444444% similarity, with 1226 matched token, and 3274 token mismatch
# ## Model validation for 4600 tokens : 26.043478260869563% similarity, with 1198 matched token, and 3402 token mismatch
# ...

# %% [markdown]
# # 1B5 Wavenet Ctx 16k - V5 benchmark

# %%
# !export RWKV_WAVENET_LAYERS="13" && \
    python3 ./memory_script/eval_v5wavenet_memory_guided.py "../../../model/v5wave-1B5-E0_1-ctx-16k-preview-30p.pth" "./logs/v5wave-1B5-E0_1-ctx-16k-1k.csv"
# Out:
# [2023-08-17 10:23:28,646] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 100.0% similarity, with 15 matched token, and 0 token mismatch
# ## Model validation for 20 tokens : 100.0% similarity, with 20 matched token, and 0 token mismatch
# ## Model validation for 25 tokens : 100.0% similarity, with 25 matched token, and 0 token mismatch
# ## Model validation for 30 tokens : 100.0% similarity, with 30 matched token, and 0 token mismatch
# ## Model validation for 35 tokens : 100.0% similarity, with 35 matched token, and 0 token mismatch
# ...

# %%
# !export RWKV_WAVENET_LAYERS="13" && \
    python3 ./memory_script/eval_v5wavenet_memory_guided.py "../../../model/v5wave-1B5-E0_1-ctx-16k-preview-30p.pth" "./logs/v5wave-1B5-E0_1-ctx-16k-4k.csv" 1100 4000
# Out:
# [2023-08-17 10:24:37,842] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# ###
# ### Model validation start ###
# ###
# ## Model validation for 1100 tokens : 95.45454545454545% similarity, with 1050 matched token, and 50 token mismatch
# ## Model validation for 1150 tokens : 95.1304347826087% similarity, with 1094 matched token, and 56 token mismatch
# ## Model validation for 1200 tokens : 94.08333333333333% similarity, with 1129 matched token, and 71 token mismatch
# ## Model validation for 1250 tokens : 94.32000000000001% similarity, with 1179 matched token, and 71 token mismatch
# ## Model validation for 1300 tokens : 94.07692307692308% similarity, with 1223 matched token, and 77 token mismatch
# ## Model validation for 1350 tokens : 94.0% similarity, with 1269 matched token, and 81 token mismatch
# ...

# %%
# !export RWKV_WAVENET_LAYERS="13" && \
    python3 ./memory_script/eval_v5wavenet_memory_guided.py "../../../model/v5wave-1B5-E0_1-ctx-16k-preview-30p.pth" "./logs/v5wave-1B5-E0_1-ctx-16k-16k.csv" 4100 16000
# Out:
# [2023-08-17 10:28:40,785] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.0.1'
# ###
# ### Model validation start ###
# ###
# ## Model validation for 4100 tokens : 31.5609756097561% similarity, with 1294 matched token, and 2806 token mismatch
# ## Model validation for 4200 tokens : 30.0952380952381% similarity, with 1264 matched token, and 2936 token mismatch
# ## Model validation for 4300 tokens : 28.55813953488372% similarity, with 1228 matched token, and 3072 token mismatch
# ## Model validation for 4400 tokens : 27.18181818181818% similarity, with 1196 matched token, and 3204 token mismatch
# ## Model validation for 4500 tokens : 25.68888888888889% similarity, with 1156 matched token, and 3344 token mismatch
# ## Model validation for 4600 tokens : 24.0% similarity, with 1104 matched token, and 3496 token mismatch
# ...
