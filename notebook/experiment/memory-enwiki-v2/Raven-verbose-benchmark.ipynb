# %% [markdown]
# ## Raven Verbose benchmarking
#
# The following is meant to observe the memory performance in a more verbose logging mode, for the baseline raven models

# %%
# Lets download the raven model
# !mkdir -p ../../../model/
# !cd ../../../model/ && wget "https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-3B-v12-Eng98%25-Other2%25-20230520-ctx4096.pth"
# !cd ../../../model/ && wget "https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-1B5-v12-Eng98%25-Other2%25-20230520-ctx4096.pth"
# Out:
# --2023-07-16 08:14:41--  https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-3B-v12-Eng98%25-Other2%25-20230520-ctx4096.pth
# Resolving huggingface.co (huggingface.co)... 18.154.227.7, 18.154.227.87, 18.154.227.67, ...
# Connecting to huggingface.co (huggingface.co)|18.154.227.7|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/41/55/4155c7aaff64e0f4b926df1a8fff201f8ee3653c39ba67b31e4973ae97828633/1eea1845acfe9729dfdaec66a8d1aeb91a1287d94bebbca5529c13c050540b33?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27RWKV-4-Raven-3B-v12-Eng98%2525-Other2%2525-20230520-ctx4096.pth%3B+filename%3D%22RWKV-4-Raven-3B-v12-Eng98%25-Other2%25-20230520-ctx4096.pth%22%3B&Expires=1689754481&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=v7ZdRD2FlgxZ%7Ey2RBKcwNgtuS23r62gtIjc57YhZ5BjwLaOwWDvtz7CJCUUh2aNbNOGz5y1%7ERFV0ErxwOsxw3HL5YST%7ETzSLxDEZnsOf5h9ttiCagaosBbrS5cCA2pYQT4Bzj2whARWEypS9WB9fJX-lbVoR0rzmioZsmCCxcK4d7gFFMr2pufeP2YCwn2IIbBmu4tzhimPZU7XA0EvCDx1kFs4TqvH4CNibaZtNnFvG4cxqEqs2x-6dCrDTattFsCkUIX74OsATkepf3MaciXbODELp49toH0CLRAYYiK61yvaIo%7E3qid7NFYWUBHRa22Sn3g1uLcB7TMHcmjV0Xg__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-07-16 08:14:41--  https://cdn-lfs.huggingface.co/repos/41/55/4155c7aaff64e0f4b926df1a8fff201f8ee3653c39ba67b31e4973ae97828633/1eea1845acfe9729dfdaec66a8d1aeb91a1287d94bebbca5529c13c050540b33?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27RWKV-4-Raven-3B-v12-Eng98%2525-Other2%2525-20230520-ctx4096.pth%3B+filename%3D%22RWKV-4-Raven-3B-v12-Eng98%25-Other2%25-20230520-ctx4096.pth%22%3B&Expires=1689754481&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=v7ZdRD2FlgxZ%7Ey2RBKcwNgtuS23r62gtIjc57YhZ5BjwLaOwWDvtz7CJCUUh2aNbNOGz5y1%7ERFV0ErxwOsxw3HL5YST%7ETzSLxDEZnsOf5h9ttiCagaosBbrS5cCA2pYQT4Bzj2whARWEypS9WB9fJX-lbVoR0rzmioZsmCCxcK4d7gFFMr2pufeP2YCwn2IIbBmu4tzhimPZU7XA0EvCDx1kFs4TqvH4CNibaZtNnFvG4cxqEqs2x-6dCrDTattFsCkUIX74OsATkepf3MaciXbODELp49toH0CLRAYYiK61yvaIo%7E3qid7NFYWUBHRa22Sn3g1uLcB7TMHcmjV0Xg__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.138.64.49, 108.138.64.111, 108.138.64.121, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.138.64.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5969345074 (5.6G) [binary/octet-stream]
# Saving to: ‘RWKV-4-Raven-3B-v12-Eng98%-Other2%-20230520-ctx4096.pth’
#
# RWKV-4-Raven-3B-v12 100%[===================>]   5.56G  59.4MB/s    in 95s
#
# 2023-07-16 08:16:16 (60.2 MB/s) - ‘RWKV-4-Raven-3B-v12-Eng98%-Other2%-20230520-ctx4096.pth’ saved [5969345074/5969345074]

# %%
# !python -m pip install rwkv
# Out:
# Collecting rwkv
#   Downloading rwkv-0.8.0-py3-none-any.whl (395 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.4/395.4 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages (from rwkv) (0.13.3)
# Installing collected packages: rwkv
# Successfully installed rwkv-0.8.0

# %%
# Memory benchmarking of the 1.5B model
# !cd ./memory_script/ && python3 eval_memory_guided.py "../../../../model/RWKV-4-Raven-1B5-v12-Eng98%25-Other2%25-20230520-ctx4096.pth" "verbose"

# %%
# Memory benchmarking of the 3B model
# !cd ./memory_script/ && python3 eval_memory_guided.py "../../../../model/RWKV-4-Raven-3B-v12-Eng98%-Other2%-20230520-ctx4096.pth" "verbose"
# Out:
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_cuda/build.ninja...
# Building extension module wkv_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_cuda...
# RWKV_JIT_ON 1 RWKV_CUDA_ON 1 RESCALE_LAYER 0
#
# Loading ../../../../model/RWKV-4-Raven-3B-v12-Eng98%-Other2%-20230520-ctx4096.pth ...
# Strategy: (total 32+1=33 layers)
# * cuda [float32, float32], store 33 layers
# 0-cuda-float32-float32 1-cuda-float32-float32 2-cuda-float32-float32 3-cuda-float32-float32 4-cuda-float32-float32 5-cuda-float32-float32 6-cuda-float32-float32 7-cuda-float32-float32 8-cuda-float32-float32 9-cuda-float32-float32 10-cuda-float32-float32 11-cuda-float32-float32 12-cuda-float32-float32 13-cuda-float32-float32 14-cuda-float32-float32 15-cuda-float32-float32 16-cuda-float32-float32 17-cuda-float32-float32 18-cuda-float32-float32 19-cuda-float32-float32 20-cuda-float32-float32 21-cuda-float32-float32 22-cuda-float32-float32 23-cuda-float32-float32 24-cuda-float32-float32 25-cuda-float32-float32 26-cuda-float32-float32 27-cuda-float32-float32 28-cuda-float32-float32 29-cuda-float32-float32 30-cuda-float32-float32 31-cuda-float32-float32 32-cuda-float32-float32
# emb.weight                        f32      cpu  50277  2560
# blocks.0.ln1.weight               f32   cuda:0   2560
# blocks.0.ln1.bias                 f32   cuda:0   2560
# blocks.0.ln2.weight               f32   cuda:0   2560
# blocks.0.ln2.bias                 f32   cuda:0   2560
# blocks.0.att.time_decay           f32   cuda:0   2560
# blocks.0.att.time_first           f32   cuda:0   2560
# blocks.0.att.time_mix_k           f32   cuda:0   2560
# blocks.0.att.time_mix_v           f32   cuda:0   2560
# blocks.0.att.time_mix_r           f32   cuda:0   2560
# blocks.0.att.key.weight           f32   cuda:0   2560  2560
# blocks.0.att.value.weight         f32   cuda:0   2560  2560
# blocks.0.att.receptance.weight    f32   cuda:0   2560  2560
# blocks.0.att.output.weight        f32   cuda:0   2560  2560
# blocks.0.ffn.time_mix_k           f32   cuda:0   2560
# blocks.0.ffn.time_mix_r           f32   cuda:0   2560
# blocks.0.ffn.key.weight           f32   cuda:0   2560 10240
# blocks.0.ffn.receptance.weight    f32   cuda:0   2560  2560
# blocks.0.ffn.value.weight         f32   cuda:0  10240  2560
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# blocks.31.ln1.weight              f32   cuda:0   2560
# blocks.31.ln1.bias                f32   cuda:0   2560
# blocks.31.ln2.weight              f32   cuda:0   2560
# blocks.31.ln2.bias                f32   cuda:0   2560
# blocks.31.att.time_decay          f32   cuda:0   2560
# blocks.31.att.time_first          f32   cuda:0   2560
# blocks.31.att.time_mix_k          f32   cuda:0   2560
# blocks.31.att.time_mix_v          f32   cuda:0   2560
# blocks.31.att.time_mix_r          f32   cuda:0   2560
# blocks.31.att.key.weight          f32   cuda:0   2560  2560
# blocks.31.att.value.weight        f32   cuda:0   2560  2560
# blocks.31.att.receptance.weight   f32   cuda:0   2560  2560
# blocks.31.att.output.weight       f32   cuda:0   2560  2560
# blocks.31.ffn.time_mix_k          f32   cuda:0   2560
# blocks.31.ffn.time_mix_r          f32   cuda:0   2560
# blocks.31.ffn.key.weight          f32   cuda:0   2560 10240
# blocks.31.ffn.receptance.weight   f32   cuda:0   2560  2560
# blocks.31.ffn.value.weight        f32   cuda:0  10240  2560
# ln_out.weight                     f32   cuda:0   2560
# ln_out.bias                       f32   cuda:0   2560
# head.weight                       f32   cuda:0   2560 50277
# ###
# ### Model validation start ###
# ###
# ## ------------------
#  - token 0 (hit) : "ad" (98.14%)
#  - token 1 (hit) : "jective" (99.33%)
#  - token 2 (hit) : " we" (89.75%)
#  - token 3 (hit) : " shallow" (96.48%)
#  - token 4 (hit) : " become" (92.03%)
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (98.07%)
#  - token 1 (hit) : "jective" (99.41%)
#  - token 2 (hit) : " we" (90.31%)
#  - token 3 (hit) : " shallow" (97.82%)
#  - token 4 (hit) : " become" (95.03%)
#  - token 5 (hit) : " steady" (96.91%)
#  - token 6 (hit) : " phrase" (56.63%)
#  - token 7 (hit) : " poetry" (94.63%)
#  - token 8 (hit) : " carry" (88.80%)
#  - token 9 (hit) : " respect" (96.21%)
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (96.63%)
#  - token 1 (hit) : "jective" (99.55%)
#  - token 2 (hit) : " we" (85.76%)
#  - token 3 (hit) : " shallow" (98.06%)
#  - token 4 (hit) : " become" (93.37%)
#  - token 5 (hit) : " steady" (97.30%)
#  - token 6 (hit) : " phrase" (45.72%)
#  - token 7 (hit) : " poetry" (96.58%)
#  - token 8 (hit) : " carry" (84.34%)
#  - token 9 (hit) : " respect" (98.85%)
#  - token 10 (hit) : " afraid" (98.10%)
#  - token 11 (miss): " thrown" (89.17%) | " threw" pos=1 (9.27%)
#  - token 12 (hit) : " positive" (98.05%)
#  - token 13 (hit) : " century" (98.22%)
#  - token 14 (hit) : " principal" (87.47%)
# ## Model validation for 15 tokens : 93.33333333333333% similarity, with 14 matched token, and 1 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (94.04%)
#  - token 1 (hit) : "jective" (99.36%)
#  - token 2 (hit) : " we" (79.68%)
#  - token 3 (hit) : " shallow" (99.17%)
#  - token 4 (hit) : " become" (95.17%)
#  - token 5 (hit) : " steady" (97.27%)
#  - token 6 (hit) : " phrase" (48.49%)
#  - token 7 (hit) : " poetry" (96.12%)
#  - token 8 (hit) : " carry" (93.46%)
#  - token 9 (hit) : " respect" (98.42%)
#  - token 10 (hit) : " afraid" (98.54%)
#  - token 11 (miss): " thrown" (89.11%) | " threw" pos=1 (9.97%)
#  - token 12 (hit) : " positive" (97.34%)
#  - token 13 (hit) : " century" (95.79%)
#  - token 14 (hit) : " principal" (87.11%)
#  - token 15 (hit) : " join" (92.58%)
#  - token 16 (hit) : " wall" (98.75%)
#  - token 17 (hit) : " he" (95.55%)
#  - token 18 (hit) : " has" (98.85%)
#  - token 19 (hit) : " everything" (98.14%)
# ## Model validation for 20 tokens : 95.0% similarity, with 19 matched token, and 1 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (94.64%)
#  - token 1 (hit) : "jective" (99.16%)
#  - token 2 (hit) : " we" (81.72%)
#  - token 3 (hit) : " shallow" (98.99%)
#  - token 4 (hit) : " become" (95.74%)
#  - token 5 (hit) : " steady" (95.13%)
#  - token 6 (hit) : " phrase" (62.82%)
#  - token 7 (hit) : " poetry" (93.47%)
#  - token 8 (hit) : " carry" (94.48%)
#  - token 9 (hit) : " respect" (98.06%)
#  - token 10 (hit) : " afraid" (97.80%)
#  - token 11 (miss): " thrown" (82.26%) | " threw" pos=1 (14.60%)
#  - token 12 (hit) : " positive" (98.25%)
#  - token 13 (hit) : " century" (88.06%)
#  - token 14 (hit) : " principal" (82.39%)
#  - token 15 (hit) : " join" (92.71%)
#  - token 16 (hit) : " wall" (98.79%)
#  - token 17 (hit) : " he" (92.56%)
#  - token 18 (hit) : " has" (95.92%)
#  - token 19 (hit) : " everything" (96.70%)
#  - token 20 (hit) : " this" (99.49%)
#  - token 21 (hit) : " had" (90.90%)
#  - token 22 (hit) : " pair" (91.71%)
#  - token 23 (hit) : " tonight" (98.75%)
#  - token 24 (hit) : " solve" (96.04%)
# ## Model validation for 25 tokens : 96.0% similarity, with 24 matched token, and 1 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (94.15%)
#  - token 1 (hit) : "jective" (99.21%)
#  - token 2 (hit) : " we" (81.58%)
#  - token 3 (hit) : " shallow" (98.54%)
#  - token 4 (hit) : " become" (96.09%)
#  - token 5 (hit) : " steady" (94.01%)
#  - token 6 (hit) : " phrase" (75.58%)
#  - token 7 (hit) : " poetry" (78.65%)
#  - token 8 (hit) : " carry" (97.85%)
#  - token 9 (hit) : " respect" (98.97%)
#  - token 10 (hit) : " afraid" (98.57%)
#  - token 11 (miss): " thrown" (74.90%) | " threw" pos=1 (12.86%)
#  - token 12 (hit) : " positive" (98.93%)
#  - token 13 (hit) : " century" (93.87%)
#  - token 14 (hit) : " principal" (84.24%)
#  - token 15 (hit) : " join" (98.09%)
#  - token 16 (hit) : " wall" (99.28%)
#  - token 17 (hit) : " he" (90.94%)
#  - token 18 (hit) : " has" (97.02%)
#  - token 19 (hit) : " everything" (96.62%)
#  - token 20 (hit) : " this" (99.68%)
#  - token 21 (hit) : " had" (93.52%)
#  - token 22 (hit) : " pair" (95.01%)
#  - token 23 (hit) : " tonight" (97.54%)
#  - token 24 (hit) : " solve" (98.49%)
#  - token 25 (hit) : " allow" (98.49%)
#  - token 26 (hit) : " fish" (99.64%)
#  - token 27 (hit) : " kitchen" (99.27%)
#  - token 28 (hit) : " snow" (88.29%)
#  - token 29 (hit) : " build" (90.63%)
# ## Model validation for 30 tokens : 96.66666666666667% similarity, with 29 matched token, and 1 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (94.69%)
#  - token 1 (hit) : "jective" (99.21%)
#  - token 2 (hit) : " we" (85.23%)
#  - token 3 (hit) : " shallow" (96.57%)
#  - token 4 (hit) : " become" (98.25%)
#  - token 5 (hit) : " steady" (95.07%)
#  - token 6 (hit) : " phrase" (81.79%)
#  - token 7 (hit) : " poetry" (68.29%)
#  - token 8 (hit) : " carry" (96.08%)
#  - token 9 (hit) : " respect" (99.69%)
#  - token 10 (hit) : " afraid" (98.05%)
#  - token 11 (miss): " thrown" (37.50%) | " threw" pos=2 (26.91%)
#  - token 12 (hit) : " positive" (98.34%)
#  - token 13 (hit) : " century" (91.35%)
#  - token 14 (hit) : " principal" (84.45%)
#  - token 15 (hit) : " join" (99.41%)
#  - token 16 (hit) : " wall" (98.99%)
#  - token 17 (hit) : " he" (96.64%)
#  - token 18 (hit) : " has" (98.30%)
#  - token 19 (hit) : " everything" (98.45%)
#  - token 20 (hit) : " this" (99.81%)
#  - token 21 (hit) : " had" (94.28%)
#  - token 22 (hit) : " pair" (98.33%)
#  - token 23 (hit) : " tonight" (98.28%)
#  - token 24 (hit) : " solve" (99.22%)
#  - token 25 (miss): " better" (43.58%) | " allow" pos=1 (31.78%)
#  - token 26 (hit) : " fish" (99.58%)
#  - token 27 (hit) : " kitchen" (99.63%)
#  - token 28 (hit) : " snow" (65.41%)
#  - token 29 (hit) : " build" (99.34%)
#  - token 30 (hit) : " imagine" (93.53%)
#  - token 31 (hit) : " better" (99.95%)
#  - token 32 (hit) : " rough" (92.59%)
#  - token 33 (hit) : " indicate" (79.31%)
#  - token 34 (hit) : " answer" (99.00%)
# ## Model validation for 35 tokens : 94.28571428571428% similarity, with 33 matched token, and 2 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (96.61%)
#  - token 1 (hit) : "jective" (99.47%)
#  - token 2 (hit) : " we" (81.66%)
#  - token 3 (hit) : " shallow" (97.44%)
#  - token 4 (hit) : " become" (98.63%)
#  - token 5 (hit) : " steady" (98.71%)
#  - token 6 (hit) : " phrase" (79.07%)
#  - token 7 (hit) : " poetry" (79.42%)
#  - token 8 (hit) : " carry" (97.44%)
#  - token 9 (hit) : " respect" (99.72%)
#  - token 10 (hit) : " afraid" (98.09%)
#  - token 11 (miss): " throw" (40.47%) | " threw" pos=2 (15.71%)
#  - token 12 (hit) : " positive" (97.78%)
#  - token 13 (hit) : " century" (94.03%)
#  - token 14 (hit) : " principal" (84.33%)
#  - token 15 (hit) : " join" (99.70%)
#  - token 16 (hit) : " wall" (99.21%)
#  - token 17 (hit) : " he" (95.80%)
#  - token 18 (hit) : " has" (98.02%)
#  - token 19 (hit) : " everything" (98.99%)
#  - token 20 (hit) : " this" (99.84%)
#  - token 21 (hit) : " had" (95.29%)
#  - token 22 (hit) : " pair" (99.46%)
#  - token 23 (hit) : " tonight" (99.40%)
#  - token 24 (hit) : " solve" (96.78%)
#  - token 25 (miss): " better" (68.71%) | " allow" pos=1 (20.63%)
#  - token 26 (hit) : " fish" (99.74%)
#  - token 27 (hit) : " kitchen" (99.82%)
#  - token 28 (hit) : " snow" (94.17%)
#  - token 29 (hit) : " build" (99.54%)
#  - token 30 (hit) : " imagine" (93.95%)
#  - token 31 (hit) : " better" (99.98%)
#  - token 32 (hit) : " rough" (96.85%)
#  - token 33 (hit) : " indicate" (82.40%)
#  - token 34 (hit) : " answer" (99.88%)
#  - token 35 (hit) : " tell" (99.72%)
#  - token 36 (hit) : " wonder" (94.08%)
#  - token 37 (hit) : " card" (99.00%)
#  - token 38 (hit) : " orbit" (93.94%)
#  - token 39 (hit) : " because" (98.67%)
# ## Model validation for 40 tokens : 95.0% similarity, with 38 matched token, and 2 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (96.98%)
#  - token 1 (hit) : "jective" (99.21%)
#  - token 2 (hit) : " we" (83.04%)
#  - token 3 (hit) : " shallow" (96.18%)
#  - token 4 (hit) : " become" (98.41%)
#  - token 5 (hit) : " steady" (97.30%)
#  - token 6 (hit) : " phrase" (74.11%)
#  - token 7 (hit) : " poetry" (55.45%)
#  - token 8 (hit) : " carry" (97.65%)
#  - token 9 (hit) : " respect" (99.58%)
#  - token 10 (hit) : " afraid" (94.25%)
#  - token 11 (miss): " throw" (47.60%) | " threw" pos=3 (12.15%)
#  - token 12 (hit) : " positive" (95.70%)
#  - token 13 (hit) : " century" (68.89%)
#  - token 14 (hit) : " principal" (81.55%)
#  - token 15 (hit) : " join" (99.78%)
#  - token 16 (hit) : " wall" (98.63%)
#  - token 17 (hit) : " he" (97.00%)
#  - token 18 (hit) : " has" (98.34%)
#  - token 19 (hit) : " everything" (98.15%)
#  - token 20 (hit) : " this" (99.70%)
#  - token 21 (hit) : " had" (96.45%)
#  - token 22 (hit) : " pair" (97.96%)
#  - token 23 (hit) : " tonight" (85.98%)
#  - token 24 (hit) : " solve" (90.89%)
#  - token 25 (miss): " better" (84.60%) | " allow" pos=1 (11.90%)
#  - token 26 (hit) : " fish" (99.58%)
#  - token 27 (hit) : " kitchen" (99.89%)
#  - token 28 (hit) : " snow" (93.74%)
#  - token 29 (hit) : " build" (99.43%)
#  - token 30 (hit) : " imagine" (92.83%)
#  - token 31 (hit) : " better" (99.99%)
#  - token 32 (hit) : " rough" (97.99%)
#  - token 33 (hit) : " indicate" (81.47%)
#  - token 34 (hit) : " answer" (99.91%)
#  - token 35 (hit) : " tell" (99.57%)
#  - token 36 (hit) : " wonder" (92.87%)
#  - token 37 (hit) : " card" (97.82%)
#  - token 38 (hit) : " orbit" (96.87%)
#  - token 39 (hit) : " because" (99.13%)
#  - token 40 (hit) : " simply" (97.47%)
#  - token 41 (hit) : " busy" (83.27%)
#  - token 42 (hit) : " nearer" (63.54%)
#  - token 43 (hit) : " nothing" (99.83%)
#  - token 44 (hit) : " stage" (91.19%)
# ## Model validation for 45 tokens : 95.55555555555556% similarity, with 43 matched token, and 2 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (96.45%)
#  - token 1 (hit) : "jective" (99.59%)
#  - token 2 (hit) : " we" (85.00%)
#  - token 3 (hit) : " shallow" (93.91%)
#  - token 4 (hit) : " become" (98.63%)
#  - token 5 (hit) : " steady" (97.94%)
#  - token 6 (hit) : " phrase" (94.99%)
#  - token 7 (miss): "
# " (40.89%) | " poetry" pos=1 (19.31%)
#  - token 8 (hit) : " carry" (94.28%)
#  - token 9 (hit) : " respect" (99.26%)
#  - token 10 (hit) : " afraid" (95.34%)
#  - token 11 (miss): " thrown" (41.06%) | " threw" pos=3 (9.63%)
#  - token 12 (hit) : " positive" (98.07%)
#  - token 13 (hit) : " century" (77.02%)
#  - token 14 (hit) : " principal" (69.77%)
#  - token 15 (hit) : " join" (99.71%)
#  - token 16 (hit) : " wall" (98.30%)
#  - token 17 (hit) : " he" (97.28%)
#  - token 18 (hit) : " has" (98.84%)
#  - token 19 (hit) : " everything" (98.85%)
#  - token 20 (hit) : " this" (99.75%)
#  - token 21 (hit) : " had" (97.45%)
#  - token 22 (hit) : " pair" (98.72%)
#  - token 23 (miss): " kitchen" (82.41%) | " tonight" pos=1 (13.31%)
#  - token 24 (hit) : " solve" (95.50%)
#  - token 25 (miss): " better" (86.10%) | " allow" pos=1 (7.83%)
#  - token 26 (hit) : " fish" (99.71%)
#  - token 27 (hit) : " kitchen" (99.91%)
#  - token 28 (hit) : " snow" (97.81%)
#  - token 29 (hit) : " build" (99.55%)
#  - token 30 (hit) : " imagine" (95.14%)
#  - token 31 (hit) : " better" (99.99%)
#  - token 32 (hit) : " rough" (96.25%)
#  - token 33 (hit) : " indicate" (82.78%)
#  - token 34 (hit) : " answer" (99.94%)
#  - token 35 (hit) : " tell" (99.65%)
#  - token 36 (hit) : " wonder" (94.44%)
#  - token 37 (hit) : " card" (98.54%)
#  - token 38 (hit) : " orbit" (98.31%)
#  - token 39 (hit) : " because" (99.57%)
#  - token 40 (hit) : " simply" (99.19%)
#  - token 41 (hit) : " busy" (78.70%)
#  - token 42 (hit) : " nearer" (69.97%)
#  - token 43 (hit) : " nothing" (99.95%)
#  - token 44 (hit) : " stage" (98.83%)
#  - token 45 (hit) : " composed" (87.25%)
#  - token 46 (miss): " tomorrow" (52.11%) | " afternoon" pos=2 (9.13%)
#  - token 47 (hit) : " fall" (98.18%)
#  - token 48 (hit) : " under" (99.70%)
#  - token 49 (hit) : "line" (99.98%)
# ## Model validation for 50 tokens : 90.0% similarity, with 45 matched token, and 5 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (96.76%)
#  - token 1 (hit) : "jective" (99.63%)
#  - token 2 (hit) : " we" (87.87%)
#  - token 3 (hit) : " shallow" (93.54%)
#  - token 4 (hit) : " become" (97.37%)
#  - token 5 (hit) : " steady" (97.12%)
#  - token 6 (hit) : " phrase" (96.00%)
#  - token 7 (miss): "
# " (50.79%) | " poetry" pos=1 (15.11%)
#  - token 8 (hit) : " carry" (91.39%)
#  - token 9 (hit) : " respect" (89.22%)
#  - token 10 (hit) : " afraid" (88.11%)
#  - token 11 (miss): " thrown" (75.28%) | " threw" pos=2 (8.76%)
#  - token 12 (hit) : " positive" (98.43%)
#  - token 13 (hit) : " century" (82.14%)
#  - token 14 (hit) : " principal" (45.81%)
#  - token 15 (hit) : " join" (78.84%)
#  - token 16 (hit) : " wall" (98.61%)
#  - token 17 (hit) : " he" (97.73%)
#  - token 18 (hit) : " has" (99.10%)
#  - token 19 (hit) : " everything" (98.68%)
#  - token 20 (hit) : " this" (99.74%)
#  - token 21 (hit) : " had" (97.91%)
#  - token 22 (hit) : " pair" (97.45%)
#  - token 23 (hit) : " tonight" (62.51%)
#  - token 24 (hit) : " solve" (91.60%)
#  - token 25 (miss): " better" (80.43%) | " allow" pos=2 (5.27%)
#  - token 26 (hit) : " fish" (99.53%)
#  - token 27 (hit) : " kitchen" (99.95%)
#  - token 28 (hit) : " snow" (99.10%)
#  - token 29 (hit) : " build" (99.41%)
#  - token 30 (hit) : " imagine" (91.81%)
#  - token 31 (hit) : " better" (99.99%)
#  - token 32 (hit) : " rough" (92.86%)
#  - token 33 (hit) : " indicate" (47.48%)
#  - token 34 (hit) : " answer" (99.92%)
#  - token 35 (hit) : " tell" (99.56%)
#  - token 36 (hit) : " wonder" (98.70%)
#  - token 37 (hit) : " card" (98.80%)
#  - token 38 (hit) : " orbit" (98.51%)
#  - token 39 (hit) : " because" (99.87%)
#  - token 40 (hit) : " simply" (99.11%)
#  - token 41 (hit) : " busy" (81.99%)
#  - token 42 (hit) : " nearer" (85.43%)
#  - token 43 (hit) : " nothing" (99.96%)
#  - token 44 (hit) : " stage" (98.88%)
#  - token 45 (hit) : " composed" (96.64%)
#  - token 46 (miss): "" (45.58%) | " afternoon" pos=2 (10.85%)
#  - token 47 (hit) : " fall" (99.21%)
#  - token 48 (hit) : " under" (99.94%)
#  - token 49 (hit) : "line" (99.98%)
#  - token 50 (hit) : " personal" (99.78%)
#  - token 51 (hit) : " carried" (99.61%)
#  - token 52 (hit) : " alone" (47.83%)
#  - token 53 (hit) : " wonder" (40.28%)
#  - token 54 (hit) : " conversation" (92.76%)
# ## Model validation for 55 tokens : 92.72727272727272% similarity, with 51 matched token, and 4 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (94.66%)
#  - token 1 (hit) : "jective" (99.82%)
#  - token 2 (hit) : " we" (88.76%)
#  - token 3 (hit) : " shallow" (95.13%)
#  - token 4 (hit) : " become" (97.99%)
#  - token 5 (hit) : " steady" (96.19%)
#  - token 6 (hit) : " phrase" (97.64%)
#  - token 7 (miss): "
# " (34.79%) | " poetry" pos=1 (20.68%)
#  - token 8 (hit) : " carry" (90.15%)
#  - token 9 (hit) : " respect" (81.03%)
#  - token 10 (hit) : " afraid" (82.43%)
#  - token 11 (miss): " thrown" (68.97%) | " threw" pos=1 (10.31%)
#  - token 12 (hit) : " positive" (97.96%)
#  - token 13 (hit) : " century" (68.90%)
#  - token 14 (miss): " stage" (55.56%) | " principal" pos=1 (32.52%)
#  - token 15 (hit) : " join" (91.82%)
#  - token 16 (hit) : " wall" (98.26%)
#  - token 17 (hit) : " he" (98.25%)
#  - token 18 (hit) : " has" (99.25%)
#  - token 19 (hit) : " everything" (98.99%)
#  - token 20 (hit) : " this" (99.68%)
#  - token 21 (hit) : " had" (98.09%)
#  - token 22 (hit) : " pair" (96.88%)
#  - token 23 (hit) : " tonight" (50.89%)
#  - token 24 (hit) : " solve" (88.09%)
#  - token 25 (miss): " better" (90.24%) | " allow" pos=2 (1.92%)
#  - token 26 (hit) : " fish" (99.60%)
#  - token 27 (hit) : " kitchen" (99.96%)
#  - token 28 (hit) : " snow" (99.00%)
#  - token 29 (hit) : " build" (99.25%)
#  - token 30 (hit) : " imagine" (92.17%)
#  - token 31 (hit) : " better" (99.99%)
#  - token 32 (hit) : " rough" (92.89%)
#  - token 33 (miss): " indication" (43.53%) | " indicate" pos=1 (42.14%)
#  - token 34 (hit) : " answer" (99.90%)
#  - token 35 (hit) : " tell" (98.77%)
#  - token 36 (hit) : " wonder" (98.05%)
#  - token 37 (hit) : " card" (99.59%)
#  - token 38 (hit) : " orbit" (94.48%)
#  - token 39 (hit) : " because" (99.87%)
#  - token 40 (hit) : " simply" (99.44%)
#  - token 41 (hit) : " busy" (90.58%)
#  - token 42 (hit) : " nearer" (92.66%)
#  - token 43 (hit) : " nothing" (99.95%)
#  - token 44 (hit) : " stage" (99.29%)
#  - token 45 (hit) : " composed" (95.33%)
#  - token 46 (miss): " first" (72.51%) | " afternoon" pos=14 (0.64%)
#  - token 47 (hit) : " fall" (99.83%)
#  - token 48 (hit) : " under" (99.97%)
#  - token 49 (hit) : "line" (99.99%)
#  - token 50 (hit) : " personal" (99.91%)
#  - token 51 (hit) : " carried" (94.16%)
#  - token 52 (hit) : " alone" (56.61%)
#  - token 53 (hit) : " wonder" (60.80%)
#  - token 54 (hit) : " conversation" (92.69%)
#  - token 55 (hit) : " regular" (99.60%)
#  - token 56 (hit) : " function" (99.67%)
#  - token 57 (hit) : " blue" (99.95%)
#  - token 58 (hit) : " crack" (99.64%)
#  - token 59 (hit) : " first" (99.31%)
# ## Model validation for 60 tokens : 90.0% similarity, with 54 matched token, and 6 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (96.35%)
#  - token 1 (hit) : "jective" (99.60%)
#  - token 2 (hit) : " we" (90.62%)
#  - token 3 (hit) : " shallow" (93.94%)
#  - token 4 (hit) : " become" (97.67%)
#  - token 5 (hit) : " steady" (96.32%)
#  - token 6 (hit) : " phrase" (96.42%)
#  - token 7 (miss): "
# " (39.15%) | " poetry" pos=1 (21.16%)
#  - token 8 (hit) : " carry" (83.09%)
#  - token 9 (hit) : " respect" (69.19%)
#  - token 10 (hit) : " afraid" (81.79%)
#  - token 11 (miss): " thrown" (53.76%) | " threw" pos=1 (15.36%)
#  - token 12 (hit) : " positive" (97.78%)
#  - token 13 (hit) : " century" (65.29%)
#  - token 14 (miss): " stage" (66.54%) | " principal" pos=1 (20.91%)
#  - token 15 (hit) : " join" (95.88%)
#  - token 16 (hit) : " wall" (98.19%)
#  - token 17 (hit) : " he" (98.79%)
#  - token 18 (hit) : " has" (99.33%)
#  - token 19 (hit) : " everything" (99.00%)
#  - token 20 (hit) : " this" (99.40%)
#  - token 21 (hit) : " had" (96.98%)
#  - token 22 (hit) : " pair" (90.68%)
#  - token 23 (miss): " kitchen" (83.28%) | " tonight" pos=1 (12.50%)
#  - token 24 (hit) : " solve" (82.96%)
#  - token 25 (miss): " better" (80.95%) | " allow" pos=2 (3.97%)
#  - token 26 (hit) : " fish" (99.59%)
#  - token 27 (hit) : " kitchen" (99.96%)
#  - token 28 (hit) : " snow" (98.47%)
#  - token 29 (hit) : " build" (99.35%)
#  - token 30 (hit) : " imagine" (93.03%)
#  - token 31 (hit) : " better" (99.99%)
#  - token 32 (hit) : " rough" (91.20%)
#  - token 33 (miss): " indication" (58.45%) | " indicate" pos=1 (34.23%)
#  - token 34 (hit) : " answer" (99.96%)
#  - token 35 (hit) : " tell" (98.55%)
#  - token 36 (hit) : " wonder" (99.17%)
#  - token 37 (hit) : " card" (99.75%)
#  - token 38 (hit) : " orbit" (96.49%)
#  - token 39 (hit) : " because" (99.89%)
#  - token 40 (hit) : " simply" (99.46%)
#  - token 41 (hit) : " busy" (75.56%)
#  - token 42 (hit) : " nearer" (86.39%)
#  - token 43 (hit) : " nothing" (99.90%)
#  - token 44 (hit) : " stage" (95.55%)
#  - token 45 (hit) : " composed" (97.64%)
#  - token 46 (miss): " first" (72.30%) | " afternoon" pos=18 (0.36%)
#  - token 47 (hit) : " fall" (92.95%)
#  - token 48 (hit) : " under" (99.95%)
#  - token 49 (hit) : "line" (100.00%)
#  - token 50 (hit) : " personal" (99.22%)
#  - token 51 (miss): " carry" (79.83%) | " carried" pos=1 (15.41%)
#  - token 52 (hit) : " alone" (63.30%)
#  - token 53 (miss): " kitchen" (44.52%) | " wonder" pos=31 (0.24%)
#  - token 54 (hit) : " conversation" (82.66%)
#  - token 55 (hit) : " regular" (99.21%)
#  - token 56 (hit) : " function" (99.28%)
#  - token 57 (hit) : " blue" (99.96%)
#  - token 58 (hit) : " crack" (99.91%)
#  - token 59 (hit) : " first" (99.88%)
#  - token 60 (hit) : " unknown" (92.60%)
#  - token 61 (hit) : " local" (97.20%)
#  - token 62 (hit) : " total" (88.64%)
#  - token 63 (hit) : " pie" (99.83%)
#  - token 64 (hit) : " audience" (92.57%)
# ## Model validation for 65 tokens : 86.15384615384616% similarity, with 56 matched token, and 9 token mismatch
# ## ------------------
# ## ------------------
#  - token 0 (hit) : "ad" (96.47%)
#  - token 1 (hit) : "jective" (99.69%)
#  - token 2 (hit) : " we" (91.65%)
#  - token 3 (hit) : " shallow" (96.27%)
#  - token 4 (hit) : " become" (97.66%)
#  - token 5 (hit) : " steady" (89.09%)
#  - token 6 (hit) : " phrase" (96.73%)
#  - token 7 (miss): "
# " (32.43%) | " poetry" pos=4 (5.00%)
#  - token 8 (hit) : " carry" (68.36%)
