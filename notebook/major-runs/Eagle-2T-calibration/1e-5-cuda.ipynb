# %% [markdown]
# # Eagle 1T - 2nd stage calibration
#
# Various smaller runs to figure out the optimal settings for the model calibration

# %%
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="C2-7B2T"
DEEPSPEED_STRAT="deepspeed_stage_2"

EXPERIMENT_NAME="1e-5-with-cuda"
LEARNING_RATE="1e-5"

print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# The model sizing
MODEL_PATH="/workspace/main-models/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /workspace/picocreator/RWKV-infctx-trainer/notebook/major-runs/Eagle-2T-calibration
# TRAINER_DIR: /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/picocreator/RWKV-infctx-trainer

# %% [markdown]
# # 1e-5 with WITH CUDA

# %%
# !cd "{TRAINER_DIR}" && \
    export RWKV_NO_CUDA=0 && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/ref-3e-5.yaml" \
        --model.load_model="{MODEL_PATH}" \
        --model.lr_init={LEARNING_RATE} \
        --model.lr_final={LEARNING_RATE} \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="/checkpoint/calibration/Eagle-2T/{EXPERIMENT_NAME}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - {EXPERIMENT_NAME} ({DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.target_batch_size=1024 \
        --trainer.microbatch_size=8 \
        --model.ctx_len=4096 \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-04 00:40:55,793] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/major-runs/Eagle-2T-calibration/ref-3e-5.yaml', '--model.load_model=/workspace/main-models/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--model.lr_init=5e-5', '--model.lr_final=5e-5', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/calibration/Eagle-2T/5e-5-with-cuda/', '--trainer.logger.init_args.name=C2-7B2T - 5e-5-with-cuda (deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=1024', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/major-runs/Eagle-2T-calibration/ref-3e-5.yaml', '--model.load_model=/workspace/main-models/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--model.lr_init=5e-5', '--model.lr_final=5e-5', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/calibration/Eagle-2T/5e-5-with-cuda/', '--trainer.logger.init_args.name=C2-7B2T - 5e-5-with-cuda (deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=1024', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'].
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/utilities/seed.py:40: No seed found, seed set to 3880732906
# Seed set to 3880732906
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       1024
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         8
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    1024
#
# [rank: 0] Seed set to 3880732906
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-04 00:41:41,369] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 00:41:41,382] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 00:41:41,390] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 00:41:41,403] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 00:41:41,413] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 00:41:41,425] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 00:41:41,426] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [rank: 1] Seed set to 3880732906
# [rank: 6] Seed set to 3880732906
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3880732906
# [rank: 4] Seed set to 3880732906
# [rank: 7] Seed set to 3880732906
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3880732906
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3880732906
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# [rank: 3] Seed set to 3880732906
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 1] Seed set to 3880732906
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [rank: 4] Seed set to 3880732906
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [rank: 7] Seed set to 3880732906
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 2] Seed set to 3880732906
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 5] Seed set to 3880732906
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 6] Seed set to 3880732906
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240204_004243-yird9p2p
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run C2-7B2T - 5e-5-with-cuda (deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-V5-Eagle-2T-exp
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-V5-Eagle-2T-exp/runs/yird9p2p
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  5.000e-05 (5e-05)
#     - lr_final: 5.000e-05 (5e-05)
#
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.048421382904052734 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...Loading extension module fused_adam...
#
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10109210014343262 seconds
# Time to load fused_adam op: 0.1010277271270752 secondsTime to load fused_adam op: 0.10103988647460938 seconds
#
# Time to load fused_adam op: 0.10115718841552734 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10231208801269531 seconds
# Loading extension module fused_adam...
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10158920288085938 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10155797004699707 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 268 M
# 1 | blocks | ModuleList | 7.0 B
# 2 | ln_out | LayerNorm  | 8.2 K
# 3 | head   | Linear     | 268 M
# --------------------------------------
# 7.5 B     Trainable params
# 0         Non-trainable params
# 7.5 B     Total params
# 30,072.177Total estimated model params size (MB)
# Epoch 0:   0%|                                        | 0/13278 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 296, in <module>
#     cli_main()
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 271, in cli_main
#     LightningCLI(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 386, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 677, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 43, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 102, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 989, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 1035, in _run_stage
#     self.fit_loop.run()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 202, in run
#     self.advance()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 359, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 136, in run
#     self.advance(data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 240, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 187, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 265, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 157, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/module.py", line 1291, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/optimizer.py", line 151, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/ddp.py", line 265, in optimizer_step
#     optimizer_output = super().optimizer_step(optimizer, closure, model, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 230, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/plugins/precision/deepspeed.py", line 123, in optimizer_step
#     closure_result = closure()
#                      ^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 140, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 126, in closure
#     step_output = self._step_fn()
#                   ^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 315, in _training_step
#     training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 381, in training_step
#     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 633, in __call__
#     wrapper_output = wrapper_module(*args, **kwargs)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/runtime/engine.py", line 1833, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 626, in wrapped_forward
#     out = method(*_args, **_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 1323, in training_step
#     sampling_loss, training_loss = self.compute_loss(batch, batch_idx, True, False)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 916, in compute_loss
#     avg_mask_sum = ( total_mask_sum / B.item() )
#                                       ^^^^^^
# AttributeError: 'int' object has no attribute 'item'
# Traceback (most recent call last):
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 296, in <module>
#     cli_main()
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 271, in cli_main
#     LightningCLI(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 386, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 677, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 43, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 102, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 989, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 1035, in _run_stage
#     self.fit_loop.run()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 202, in run
#     self.advance()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 359, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 136, in run
#     self.advance(data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 240, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 187, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 265, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 157, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/module.py", line 1291, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/optimizer.py", line 151, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/ddp.py", line 265, in optimizer_step
#     optimizer_output = super().optimizer_step(optimizer, closure, model, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 230, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/plugins/precision/deepspeed.py", line 123, in optimizer_step
#     closure_result = closure()
#                      ^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 140, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 126, in closure
#     step_output = self._step_fn()
#                   ^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 315, in _training_step
#     training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 381, in training_step
#     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 633, in __call__
#     wrapper_output = wrapper_module(*args, **kwargs)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/runtime/engine.py", line 1833, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 626, in wrapped_forward
#     out = method(*_args, **_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 1323, in training_step
#     sampling_loss, training_loss = self.compute_loss(batch, batch_idx, True, False)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 916, in compute_loss
#     avg_mask_sum = ( total_mask_sum / B.item() )
#                                       ^^^^^^
# AttributeError: 'int' object has no attribute 'item'
# Traceback (most recent call last):
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 296, in <module>
#     cli_main()
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 271, in cli_main
#     LightningCLI(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 386, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 677, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 43, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 102, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 989, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 1035, in _run_stage
#     self.fit_loop.run()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 202, in run
#     self.advance()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 359, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 136, in run
#     self.advance(data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 240, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 187, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 265, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 157, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/module.py", line 1291, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/optimizer.py", line 151, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/ddp.py", line 265, in optimizer_step
#     optimizer_output = super().optimizer_step(optimizer, closure, model, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 230, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/plugins/precision/deepspeed.py", line 123, in optimizer_step
#     closure_result = closure()
#                      ^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 140, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 126, in closure
#     step_output = self._step_fn()
#                   ^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 315, in _training_step
#     training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 381, in training_step
#     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 633, in __call__
#     wrapper_output = wrapper_module(*args, **kwargs)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/runtime/engine.py", line 1833, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 626, in wrapped_forward
#     out = method(*_args, **_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 1323, in training_step
#     sampling_loss, training_loss = self.compute_loss(batch, batch_idx, True, False)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 916, in compute_loss
#     avg_mask_sum = ( total_mask_sum / B.item() )
#                                       ^^^^^^
# AttributeError: 'int' object has no attribute 'item'
# Traceback (most recent call last):
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 296, in <module>
#     cli_main()
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 271, in cli_main
#     LightningCLI(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 386, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 677, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 43, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 102, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 989, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 1035, in _run_stage
#     self.fit_loop.run()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 202, in run
#     self.advance()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 359, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 136, in run
#     self.advance(data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 240, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 187, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 265, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 157, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/module.py", line 1291, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/optimizer.py", line 151, in step
# ...
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 102, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 989, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 1035, in _run_stage
#     self.fit_loop.run()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 202, in run
#     self.advance()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 359, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 136, in run
#     self.advance(data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 240, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 187, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 265, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 157, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/module.py", line 1291, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/optimizer.py", line 151, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/ddp.py", line 265, in optimizer_step
#     optimizer_output = super().optimizer_step(optimizer, closure, model, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 230, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/plugins/precision/deepspeed.py", line 123, in optimizer_step
#     closure_result = closure()
#                      ^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 140, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 126, in closure
#     step_output = self._step_fn()
#                   ^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 315, in _training_step
#     training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 381, in training_step
#     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 633, in __call__
#     wrapper_output = wrapper_module(*args, **kwargs)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/runtime/engine.py", line 1833, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 626, in wrapped_forward
#     out = method(*_args, **_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 1323, in training_step
#     sampling_loss, training_loss = self.compute_loss(batch, batch_idx, True, False)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 916, in compute_loss
#     avg_mask_sum = ( total_mask_sum / B.item() )
#                                       ^^^^^^
# AttributeError: 'int' object has no attribute 'item'
# Traceback (most recent call last):
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 296, in <module>
#     cli_main()
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/lightning_trainer.py", line 271, in cli_main
#     LightningCLI(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 386, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py", line 677, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 544, in fit
#     call._call_and_handle_interrupt(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 43, in _call_and_handle_interrupt
#     return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/launchers/subprocess_script.py", line 102, in launch
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 580, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 989, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py", line 1035, in _run_stage
#     self.fit_loop.run()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 202, in run
#     self.advance()
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py", line 359, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 136, in run
#     self.advance(data_fetcher)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 240, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 187, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 265, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 157, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/module.py", line 1291, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/core/optimizer.py", line 151, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/ddp.py", line 265, in optimizer_step
#     optimizer_output = super().optimizer_step(optimizer, closure, model, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 230, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/plugins/precision/deepspeed.py", line 123, in optimizer_step
#     closure_result = closure()
#                      ^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 140, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 126, in closure
#     step_output = self._step_fn()
#                   ^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 315, in _training_step
#     training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py", line 309, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 381, in training_step
#     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 633, in __call__
#     wrapper_output = wrapper_module(*args, **kwargs)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/utils/nvtx.py", line 15, in wrapped_fn
#     ret_val = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/runtime/engine.py", line 1833, in forward
#     loss = self.module(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/strategies/strategy.py", line 626, in wrapped_forward
#     out = method(*_args, **_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 1323, in training_step
#     sampling_loss, training_loss = self.compute_loss(batch, batch_idx, True, False)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 916, in compute_loss
#     avg_mask_sum = ( total_mask_sum / B.item() )
#                                       ^^^^^^
# AttributeError: 'int' object has no attribute 'item'
# [rank: 1] Child process with PID 174618 terminated with code 1. Forcefully terminating all other processes to avoid zombies 🧟
# wandb: | 0.018 MB of 0.018 MB uploaded
