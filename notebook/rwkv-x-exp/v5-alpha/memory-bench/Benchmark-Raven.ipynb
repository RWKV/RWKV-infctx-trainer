# %% [markdown]
# ## Raven Memory benchmarking
#
# The following is meant to observe the memory performance in a heavily CSV logged mode, for the baseline raven models. So that the data can be used for analysis seperately

# %%
# Lets download the raven model
# !mkdir -p ../../../model/
# !cd ../../../model/ && wget "https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-1B5-v12-Eng98%25-Other2%25-20230520-ctx4096.pth"
# !cd ../../../model/ && wget "https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-3B-v12-Eng98%25-Other2%25-20230520-ctx4096.pth"
# !cd ../../../model/ && wget "https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-7B-v12-Eng98%25-Other2%25-20230521-ctx8192.pth"
# !cd ../../../model/ && wget "https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-14B-v12-Eng98%25-Other2%25-20230523-ctx8192.pth"
# Out:
# --2023-07-18 14:41:32--  https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-7B-v12-Eng98%25-Other2%25-20230521-ctx8192.pth
# Resolving huggingface.co (huggingface.co)... 18.154.227.69, 18.154.227.67, 18.154.227.7, ...
# Connecting to huggingface.co (huggingface.co)|18.154.227.69|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/41/55/4155c7aaff64e0f4b926df1a8fff201f8ee3653c39ba67b31e4973ae97828633/5a725eaeb9e09b724de6c97e6845dd0283097c7920acd05b46852ab7afa9ec32?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27RWKV-4-Raven-7B-v12-Eng98%2525-Other2%2525-20230521-ctx8192.pth%3B+filename%3D%22RWKV-4-Raven-7B-v12-Eng98%25-Other2%25-20230521-ctx8192.pth%22%3B&Expires=1689950492&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=bZWWulv2NSTu3jNhWad9lrLxSKItlzpxq5t0WMCTPFYbq6movw6iYWIjaVTQ9%7EWyU9wi9ymAeVSOO2AdUa6PH4B-suG4XZFju4%7Ev7d7u0ba-pnBCZ3ZPPPNPFhUEcoDzR6E8ccIbYofiP7gfbZsi4mOfJ72zbCUcCSYxVhk7s7cEm2ys9GflaFPLIOn2cAeFEH7iAas4yXr8LrBKFVXWlytY2zlb7SkhLFO07gyG8xXmUlxmKyEyQbHjfw8x7NEE%7EKd%7EAJtjtN0mfurG06RWApptvH2FXONtname-f4ytBL0B%7EO2xQX33zQo1Rfzh3IuN0KfxjVjr0Idf-X2gXhE1g__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-07-18 14:41:32--  https://cdn-lfs.huggingface.co/repos/41/55/4155c7aaff64e0f4b926df1a8fff201f8ee3653c39ba67b31e4973ae97828633/5a725eaeb9e09b724de6c97e6845dd0283097c7920acd05b46852ab7afa9ec32?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27RWKV-4-Raven-7B-v12-Eng98%2525-Other2%2525-20230521-ctx8192.pth%3B+filename%3D%22RWKV-4-Raven-7B-v12-Eng98%25-Other2%25-20230521-ctx8192.pth%22%3B&Expires=1689950492&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=bZWWulv2NSTu3jNhWad9lrLxSKItlzpxq5t0WMCTPFYbq6movw6iYWIjaVTQ9%7EWyU9wi9ymAeVSOO2AdUa6PH4B-suG4XZFju4%7Ev7d7u0ba-pnBCZ3ZPPPNPFhUEcoDzR6E8ccIbYofiP7gfbZsi4mOfJ72zbCUcCSYxVhk7s7cEm2ys9GflaFPLIOn2cAeFEH7iAas4yXr8LrBKFVXWlytY2zlb7SkhLFO07gyG8xXmUlxmKyEyQbHjfw8x7NEE%7EKd%7EAJtjtN0mfurG06RWApptvH2FXONtname-f4ytBL0B%7EO2xQX33zQo1Rfzh3IuN0KfxjVjr0Idf-X2gXhE1g__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.138.64.121, 108.138.64.36, 108.138.64.49, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.138.64.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14785389618 (14G) [binary/octet-stream]
# Saving to: ‘RWKV-4-Raven-7B-v12-Eng98%-Other2%-20230521-ctx8192.pth’
#
# -Eng98%-Other2%-202   7%[>                   ] 991.82M  47.7MB/s    eta 5m 27s
# RWKV-4-Raven-7B-v12 100%[===================>]  13.77G  38.5MB/s    in 5m 3s
#
# 2023-07-18 14:46:35 (46.6 MB/s) - ‘RWKV-4-Raven-7B-v12-Eng98%-Other2%-20230521-ctx8192.pth’ saved [14785389618/14785389618]
#
# --2023-07-18 14:46:35--  https://huggingface.co/BlinkDL/rwkv-4-raven/resolve/main/RWKV-4-Raven-14B-v12-Eng98%25-Other2%25-20230523-ctx8192.pth
# Resolving huggingface.co (huggingface.co)... 18.154.227.87, 18.154.227.7, 18.154.227.67, ...
# Connecting to huggingface.co (huggingface.co)|18.154.227.87|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/41/55/4155c7aaff64e0f4b926df1a8fff201f8ee3653c39ba67b31e4973ae97828633/1193b5a9ceab572e4dbb9ed1d798eab7bf4793d18904d08bd4bf183579338ae7?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27RWKV-4-Raven-14B-v12-Eng98%2525-Other2%2525-20230523-ctx8192.pth%3B+filename%3D%22RWKV-4-Raven-14B-v12-Eng98%25-Other2%25-20230523-ctx8192.pth%22%3B&Expires=1689950795&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=F29lGK4tcIlhlrF%7EWEh4R7MnbyujT890BSi3hAtbXih2ycc05sB22Hm54WwU6e4kcRrde5WBJ6bMQUFE4IUviJnP%7ERLRvLjAOARQKLLncwp374dPTgvx8bmWUZk3ConnyYh0uZa-mWKO5Y4UlnbdoesSA5iEOsdrKp889UZ-DxbD70wkHWVVc6Fzxp6VHARbcRl7lD4rwvoKyr2Wy%7E9AlSOu%7EY2-tnMWQ2hZmTitlV4n29iVvd0xyOvFSpRBjvl-Edv1yJPLdTCb3L2eKHY9my9LJlI6Av9XGus%7Ekz0dxvyh1sxYZro9jMpkz7ZH3xslMmT7XC9LxqxL%7EJwK5wNabg__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-07-18 14:46:35--  https://cdn-lfs.huggingface.co/repos/41/55/4155c7aaff64e0f4b926df1a8fff201f8ee3653c39ba67b31e4973ae97828633/1193b5a9ceab572e4dbb9ed1d798eab7bf4793d18904d08bd4bf183579338ae7?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27RWKV-4-Raven-14B-v12-Eng98%2525-Other2%2525-20230523-ctx8192.pth%3B+filename%3D%22RWKV-4-Raven-14B-v12-Eng98%25-Other2%25-20230523-ctx8192.pth%22%3B&Expires=1689950795&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=F29lGK4tcIlhlrF%7EWEh4R7MnbyujT890BSi3hAtbXih2ycc05sB22Hm54WwU6e4kcRrde5WBJ6bMQUFE4IUviJnP%7ERLRvLjAOARQKLLncwp374dPTgvx8bmWUZk3ConnyYh0uZa-mWKO5Y4UlnbdoesSA5iEOsdrKp889UZ-DxbD70wkHWVVc6Fzxp6VHARbcRl7lD4rwvoKyr2Wy%7E9AlSOu%7EY2-tnMWQ2hZmTitlV4n29iVvd0xyOvFSpRBjvl-Edv1yJPLdTCb3L2eKHY9my9LJlI6Av9XGus%7Ekz0dxvyh1sxYZro9jMpkz7ZH3xslMmT7XC9LxqxL%7EJwK5wNabg__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.138.64.36, 108.138.64.111, 108.138.64.49, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.138.64.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28297309490 (26G) [binary/octet-stream]
# Saving to: ‘RWKV-4-Raven-14B-v12-Eng98%-Other2%-20230523-ctx8192.pth’
#
# RWKV-4-Raven-14B-v1 100%[===================>]  26.35G  52.5MB/s    in 8m 15s
#
# 2023-07-18 14:54:50 (54.5 MB/s) - ‘RWKV-4-Raven-14B-v12-Eng98%-Other2%-20230523-ctx8192.pth’ saved [28297309490/28297309490]

# %%
# !ls ../../../model/
# Out:
# Echo-A-1B5-Init.pth    RWKV-4-Raven-1B5-v12-Eng98%-Other2%-20230520-ctx4096.pth
# Echo-B-1B4-Stage1.pth  RWKV-4-Raven-3B-v12-Eng98%-Other2%-20230520-ctx4096.pth

# %%
# !python -m pip install rwkv
# Out:
# Collecting rwkv
#   Downloading rwkv-0.8.0-py3-none-any.whl (395 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.4/395.4 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages (from rwkv) (0.13.3)
# Installing collected packages: rwkv
# Successfully installed rwkv-0.8.0

# %%
# Memory benchmarking of the 1.5B model
# !python3 ./memory_script/eval_memory_guided.py "../../../model/RWKV-4-Raven-1B5-v12-Eng98%-Other2%-20230520-ctx4096.pth" "./logs/Raven-1B5-v12.csv"
# Out:
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_cuda/build.ninja...
# Building extension module wkv_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_cuda...
# RWKV_JIT_ON 1 RWKV_CUDA_ON 1 RESCALE_LAYER 0
#
# Loading ../../../model/RWKV-4-Raven-1B5-v12-Eng98%-Other2%-20230520-ctx4096.pth ...
# Strategy: (total 24+1=25 layers)
# * cuda [float32, float32], store 25 layers
# 0-cuda-float32-float32 1-cuda-float32-float32 2-cuda-float32-float32 3-cuda-float32-float32 4-cuda-float32-float32 5-cuda-float32-float32 6-cuda-float32-float32 7-cuda-float32-float32 8-cuda-float32-float32 9-cuda-float32-float32 10-cuda-float32-float32 11-cuda-float32-float32 12-cuda-float32-float32 13-cuda-float32-float32 14-cuda-float32-float32 15-cuda-float32-float32 16-cuda-float32-float32 17-cuda-float32-float32 18-cuda-float32-float32 19-cuda-float32-float32 20-cuda-float32-float32 21-cuda-float32-float32 22-cuda-float32-float32 23-cuda-float32-float32 24-cuda-float32-float32
# emb.weight                        f32      cpu  50277  2048
# blocks.0.ln1.weight               f32   cuda:0   2048
# blocks.0.ln1.bias                 f32   cuda:0   2048
# blocks.0.ln2.weight               f32   cuda:0   2048
# blocks.0.ln2.bias                 f32   cuda:0   2048
# blocks.0.att.time_decay           f32   cuda:0   2048
# blocks.0.att.time_first           f32   cuda:0   2048
# blocks.0.att.time_mix_k           f32   cuda:0   2048
# blocks.0.att.time_mix_v           f32   cuda:0   2048
# blocks.0.att.time_mix_r           f32   cuda:0   2048
# blocks.0.att.key.weight           f32   cuda:0   2048  2048
# blocks.0.att.value.weight         f32   cuda:0   2048  2048
# blocks.0.att.receptance.weight    f32   cuda:0   2048  2048
# blocks.0.att.output.weight        f32   cuda:0   2048  2048
# blocks.0.ffn.time_mix_k           f32   cuda:0   2048
# blocks.0.ffn.time_mix_r           f32   cuda:0   2048
# blocks.0.ffn.key.weight           f32   cuda:0   2048  8192
# blocks.0.ffn.receptance.weight    f32   cuda:0   2048  2048
# blocks.0.ffn.value.weight         f32   cuda:0   8192  2048
# ............................................................................................................................................................................................................................................................................................................................................................................................................
# blocks.23.ln1.weight              f32   cuda:0   2048
# blocks.23.ln1.bias                f32   cuda:0   2048
# blocks.23.ln2.weight              f32   cuda:0   2048
# blocks.23.ln2.bias                f32   cuda:0   2048
# blocks.23.att.time_decay          f32   cuda:0   2048
# blocks.23.att.time_first          f32   cuda:0   2048
# blocks.23.att.time_mix_k          f32   cuda:0   2048
# blocks.23.att.time_mix_v          f32   cuda:0   2048
# blocks.23.att.time_mix_r          f32   cuda:0   2048
# blocks.23.att.key.weight          f32   cuda:0   2048  2048
# blocks.23.att.value.weight        f32   cuda:0   2048  2048
# blocks.23.att.receptance.weight   f32   cuda:0   2048  2048
# blocks.23.att.output.weight       f32   cuda:0   2048  2048
# blocks.23.ffn.time_mix_k          f32   cuda:0   2048
# blocks.23.ffn.time_mix_r          f32   cuda:0   2048
# blocks.23.ffn.key.weight          f32   cuda:0   2048  8192
# blocks.23.ffn.receptance.weight   f32   cuda:0   2048  2048
# blocks.23.ffn.value.weight        f32   cuda:0   8192  2048
# ln_out.weight                     f32   cuda:0   2048
# ln_out.bias                       f32   cuda:0   2048
# head.weight                       f32   cuda:0   2048 50277
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 93.33333333333333% similarity, with 14 matched token, and 1 token mismatch
# ## Model validation for 20 tokens : 95.0% similarity, with 19 matched token, and 1 token mismatch
# ## Model validation for 25 tokens : 92.0% similarity, with 23 matched token, and 2 token mismatch
# ## Model validation for 30 tokens : 90.0% similarity, with 27 matched token, and 3 token mismatch
# ## Model validation for 35 tokens : 91.42857142857143% similarity, with 32 matched token, and 3 token mismatch
# ## Model validation for 40 tokens : 92.5% similarity, with 37 matched token, and 3 token mismatch
# ## Model validation for 45 tokens : 88.88888888888889% similarity, with 40 matched token, and 5 token mismatch
# ## Model validation for 50 tokens : 92.0% similarity, with 46 matched token, and 4 token mismatch
# ## Model validation for 55 tokens : 89.0909090909091% similarity, with 49 matched token, and 6 token mismatch
# ## Model validation for 60 tokens : 85.0% similarity, with 51 matched token, and 9 token mismatch
# ## Model validation for 65 tokens : 80.0% similarity, with 52 matched token, and 13 token mismatch
# ## Model validation for 70 tokens : 72.85714285714285% similarity, with 51 matched token, and 19 token mismatch
# ## Model validation for 75 tokens : 68.0% similarity, with 51 matched token, and 24 token mismatch
# ## Model validation for 80 tokens : 66.25% similarity, with 53 matched token, and 27 token mismatch
# ## Model validation for 85 tokens : 58.82352941176471% similarity, with 50 matched token, and 35 token mismatch
# ## Model validation for 90 tokens : 55.55555555555556% similarity, with 50 matched token, and 40 token mismatch
# ## Model validation for 95 tokens : 55.78947368421052% similarity, with 53 matched token, and 42 token mismatch
# ## Model validation for 100 tokens : 52.0% similarity, with 52 matched token, and 48 token mismatch
# ## Model validation for 105 tokens : 49.523809523809526% similarity, with 52 matched token, and 53 token mismatch
# ## Model validation for 110 tokens : 49.09090909090909% similarity, with 54 matched token, and 56 token mismatch
# ## Model validation for 115 tokens : 46.08695652173913% similarity, with 53 matched token, and 62 token mismatch
# ## Model validation for 120 tokens : 45.83333333333333% similarity, with 55 matched token, and 65 token mismatch
# ## Model validation for 125 tokens : 40.8% similarity, with 51 matched token, and 74 token mismatch
# ## Model validation for 130 tokens : 40.76923076923077% similarity, with 53 matched token, and 77 token mismatch
# ## Model validation for 135 tokens : 40.0% similarity, with 54 matched token, and 81 token mismatch
# ## Model validation for 140 tokens : 41.42857142857143% similarity, with 58 matched token, and 82 token mismatch
# ## Model validation for 145 tokens : 37.93103448275862% similarity, with 55 matched token, and 90 token mismatch
# ## Model validation for 150 tokens : 34.0% similarity, with 51 matched token, and 99 token mismatch
# ## Model validation for 160 tokens : 33.125% similarity, with 53 matched token, and 107 token mismatch
# ## Model validation for 170 tokens : 30.58823529411765% similarity, with 52 matched token, and 118 token mismatch
# ## Model validation for 180 tokens : 26.111111111111114% similarity, with 47 matched token, and 133 token mismatch
# ## Model validation for 190 tokens : 25.263157894736842% similarity, with 48 matched token, and 142 token mismatch
# ## Model validation for 200 tokens : 21.5% similarity, with 43 matched token, and 157 token mismatch
# ## Model validation for 210 tokens : 21.904761904761905% similarity, with 46 matched token, and 164 token mismatch
# ## Model validation for 220 tokens : 20.909090909090907% similarity, with 46 matched token, and 174 token mismatch
# ## Model validation for 230 tokens : 19.130434782608695% similarity, with 44 matched token, and 186 token mismatch
# ## Model validation for 240 tokens : 18.75% similarity, with 45 matched token, and 195 token mismatch
# ## Model validation for 250 tokens : 16.0% similarity, with 40 matched token, and 210 token mismatch
# ## Model validation for 260 tokens : 15.0% similarity, with 39 matched token, and 221 token mismatch
# ## Model validation for 270 tokens : 11.851851851851853% similarity, with 32 matched token, and 238 token mismatch
# ## Model validation for 280 tokens : 12.142857142857142% similarity, with 34 matched token, and 246 token mismatch
# ## Model validation for 290 tokens : 14.827586206896552% similarity, with 43 matched token, and 247 token mismatch
# ## Model validation for 300 tokens : 13.333333333333334% similarity, with 40 matched token, and 260 token mismatch
# ## Model validation for 325 tokens : 10.153846153846153% similarity, with 33 matched token, and 292 token mismatch
# ## Model validation for 350 tokens : 9.428571428571429% similarity, with 33 matched token, and 317 token mismatch
# ## Model validation for 375 tokens : 7.466666666666668% similarity, with 28 matched token, and 347 token mismatch
# ## Model validation for 400 tokens : 6.5% similarity, with 26 matched token, and 374 token mismatch
# ## Model validation for 425 tokens : 6.588235294117648% similarity, with 28 matched token, and 397 token mismatch
# ## Model validation for 450 tokens : 6.222222222222222% similarity, with 28 matched token, and 422 token mismatch
# ## Model validation for 475 tokens : 5.263157894736842% similarity, with 25 matched token, and 450 token mismatch
# ## Model validation for 500 tokens : 4.8% similarity, with 24 matched token, and 476 token mismatch
# ## Model validation for 525 tokens : 4.761904761904762% similarity, with 25 matched token, and 500 token mismatch
# ## Model validation for 550 tokens : 4.363636363636364% similarity, with 24 matched token, and 526 token mismatch
# ## Model validation for 575 tokens : 4.521739130434783% similarity, with 26 matched token, and 549 token mismatch
# ## Model validation for 600 tokens : 4.666666666666667% similarity, with 28 matched token, and 572 token mismatch
# ## Model validation for 625 tokens : 4.64% similarity, with 29 matched token, and 596 token mismatch
# ## Model validation for 650 tokens : 4.153846153846154% similarity, with 27 matched token, and 623 token mismatch
# ## Model validation for 675 tokens : 4.0% similarity, with 27 matched token, and 648 token mismatch
# ## Model validation for 700 tokens : 3.8571428571428568% similarity, with 27 matched token, and 673 token mismatch
# ## Model validation for 750 tokens : 4.0% similarity, with 30 matched token, and 720 token mismatch
# ## Model validation for 800 tokens : 3.875% similarity, with 31 matched token, and 769 token mismatch
# ## Model validation for 850 tokens : 3.6470588235294117% similarity, with 31 matched token, and 819 token mismatch
# ## Model validation for 900 tokens : 3.5555555555555554% similarity, with 32 matched token, and 868 token mismatch
# ## Model validation for 950 tokens : 3.3684210526315788% similarity, with 32 matched token, and 918 token mismatch
# ## Finished baseline model to eval output predictive matching (aka 0 memory?), for 1000 tokens

# %%
# Memory benchmarking of the 3B model
# !python3 ./memory_script/eval_memory_guided.py "../../../model/RWKV-4-Raven-3B-v12-Eng98%-Other2%-20230520-ctx4096.pth" "./logs/Raven-3B-v12.csv"
# Out:
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_cuda/build.ninja...
# Building extension module wkv_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_cuda...
# RWKV_JIT_ON 1 RWKV_CUDA_ON 1 RESCALE_LAYER 0
#
# Loading ../../../model/RWKV-4-Raven-3B-v12-Eng98%-Other2%-20230520-ctx4096.pth ...
# Strategy: (total 32+1=33 layers)
# * cuda [float32, float32], store 24 layers, stream 9 layers
# 0-cuda-float32-float32 1-cuda-float32-float32 2-cuda-float32-float32 3-cuda-float32-float32 4-cuda-float32-float32 5-cuda-float32-float32 6-cuda-float32-float32 7-cuda-float32-float32 8-cuda-float32-float32 9-cuda-float32-float32 10-cuda-float32-float32 11-cuda-float32-float32 12-cuda-float32-float32 13-cuda-float32-float32 14-cuda-float32-float32 15-cuda-float32-float32 16-cuda-float32-float32 17-cuda-float32-float32 18-cuda-float32-float32 19-cuda-float32-float32 20-cuda-float32-float32 21-cuda-float32-float32 22-cuda-float32-float32 23-cuda-float32-float32 24-cuda-float32-float32-stream 25-cuda-float32-float32-stream 26-cuda-float32-float32-stream 27-cuda-float32-float32-stream 28-cuda-float32-float32-stream 29-cuda-float32-float32-stream 30-cuda-float32-float32-stream 31-cuda-float32-float32-stream 32-cuda-float32-float32-stream
# emb.weight                        f32      cpu  50277  2560
# blocks.0.ln1.weight               f32   cuda:0   2560
# blocks.0.ln1.bias                 f32   cuda:0   2560
# blocks.0.ln2.weight               f32   cuda:0   2560
# blocks.0.ln2.bias                 f32   cuda:0   2560
# blocks.0.att.time_decay           f32   cuda:0   2560
# blocks.0.att.time_first           f32   cuda:0   2560
# blocks.0.att.time_mix_k           f32   cuda:0   2560
# blocks.0.att.time_mix_v           f32   cuda:0   2560
# blocks.0.att.time_mix_r           f32   cuda:0   2560
# blocks.0.att.key.weight           f32   cuda:0   2560  2560
# blocks.0.att.value.weight         f32   cuda:0   2560  2560
# blocks.0.att.receptance.weight    f32   cuda:0   2560  2560
# blocks.0.att.output.weight        f32   cuda:0   2560  2560
# blocks.0.ffn.time_mix_k           f32   cuda:0   2560
# blocks.0.ffn.time_mix_r           f32   cuda:0   2560
# blocks.0.ffn.key.weight           f32   cuda:0   2560 10240
# blocks.0.ffn.receptance.weight    f32   cuda:0   2560  2560
# blocks.0.ffn.value.weight         f32   cuda:0  10240  2560
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# blocks.31.ln1.weight              f32   cuda:0   2560
# blocks.31.ln1.bias                f32   cuda:0   2560
# blocks.31.ln2.weight              f32   cuda:0   2560
# blocks.31.ln2.bias                f32   cuda:0   2560
# blocks.31.att.time_decay          f32   cuda:0   2560
# blocks.31.att.time_first          f32   cuda:0   2560
# blocks.31.att.time_mix_k          f32   cuda:0   2560
# blocks.31.att.time_mix_v          f32   cuda:0   2560
# blocks.31.att.time_mix_r          f32   cuda:0   2560
# blocks.31.att.key.weight          f32      cpu   2560  2560  (pinned)
# blocks.31.att.value.weight        f32      cpu   2560  2560  (pinned)
# blocks.31.att.receptance.weight   f32      cpu   2560  2560  (pinned)
# blocks.31.att.output.weight       f32      cpu   2560  2560  (pinned)
# blocks.31.ffn.time_mix_k          f32   cuda:0   2560
# blocks.31.ffn.time_mix_r          f32   cuda:0   2560
# blocks.31.ffn.key.weight          f32      cpu   2560 10240  (pinned)
# blocks.31.ffn.receptance.weight   f32      cpu   2560  2560  (pinned)
# blocks.31.ffn.value.weight        f32      cpu  10240  2560  (pinned)
# ln_out.weight                     f32   cuda:0   2560
# ln_out.bias                       f32   cuda:0   2560
# head.weight                       f32   cuda:0   2560 50277
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 93.33333333333333% similarity, with 14 matched token, and 1 token mismatch
# ## Model validation for 20 tokens : 95.0% similarity, with 19 matched token, and 1 token mismatch
# ## Model validation for 25 tokens : 96.0% similarity, with 24 matched token, and 1 token mismatch
# ## Model validation for 30 tokens : 96.66666666666667% similarity, with 29 matched token, and 1 token mismatch
# ## Model validation for 35 tokens : 94.28571428571428% similarity, with 33 matched token, and 2 token mismatch
# ## Model validation for 40 tokens : 95.0% similarity, with 38 matched token, and 2 token mismatch
# ## Model validation for 45 tokens : 95.55555555555556% similarity, with 43 matched token, and 2 token mismatch
# ## Model validation for 50 tokens : 90.0% similarity, with 45 matched token, and 5 token mismatch
# ## Model validation for 55 tokens : 92.72727272727272% similarity, with 51 matched token, and 4 token mismatch
# ## Model validation for 60 tokens : 90.0% similarity, with 54 matched token, and 6 token mismatch
# ## Model validation for 65 tokens : 86.15384615384616% similarity, with 56 matched token, and 9 token mismatch
# ## Model validation for 70 tokens : 88.57142857142857% similarity, with 62 matched token, and 8 token mismatch
# ## Model validation for 75 tokens : 82.66666666666667% similarity, with 62 matched token, and 13 token mismatch
# ## Model validation for 80 tokens : 82.5% similarity, with 66 matched token, and 14 token mismatch
# ## Model validation for 85 tokens : 77.64705882352942% similarity, with 66 matched token, and 19 token mismatch
# ## Model validation for 90 tokens : 75.55555555555556% similarity, with 68 matched token, and 22 token mismatch
# ## Model validation for 95 tokens : 74.73684210526315% similarity, with 71 matched token, and 24 token mismatch
# ## Model validation for 100 tokens : 71.0% similarity, with 71 matched token, and 29 token mismatch
# ## Model validation for 105 tokens : 65.71428571428571% similarity, with 69 matched token, and 36 token mismatch
# ## Model validation for 110 tokens : 67.27272727272727% similarity, with 74 matched token, and 36 token mismatch
# ## Model validation for 115 tokens : 66.95652173913044% similarity, with 77 matched token, and 38 token mismatch
# ## Model validation for 120 tokens : 61.66666666666667% similarity, with 74 matched token, and 46 token mismatch
# ## Model validation for 125 tokens : 61.6% similarity, with 77 matched token, and 48 token mismatch
# ## Model validation for 130 tokens : 62.30769230769231% similarity, with 81 matched token, and 49 token mismatch
# ## Model validation for 135 tokens : 59.25925925925925% similarity, with 80 matched token, and 55 token mismatch
# ## Model validation for 140 tokens : 59.285714285714285% similarity, with 83 matched token, and 57 token mismatch
# ## Model validation for 145 tokens : 55.172413793103445% similarity, with 80 matched token, and 65 token mismatch
# ## Model validation for 150 tokens : 54.666666666666664% similarity, with 82 matched token, and 68 token mismatch
# ## Model validation for 160 tokens : 48.125% similarity, with 77 matched token, and 83 token mismatch
# ## Model validation for 170 tokens : 42.35294117647059% similarity, with 72 matched token, and 98 token mismatch
# ## Model validation for 180 tokens : 38.88888888888889% similarity, with 70 matched token, and 110 token mismatch
# ## Model validation for 190 tokens : 36.31578947368421% similarity, with 69 matched token, and 121 token mismatch
# ## Model validation for 200 tokens : 35.0% similarity, with 70 matched token, and 130 token mismatch
# ## Model validation for 210 tokens : 32.857142857142854% similarity, with 69 matched token, and 141 token mismatch
# ## Model validation for 220 tokens : 30.0% similarity, with 66 matched token, and 154 token mismatch
# ## Model validation for 230 tokens : 26.956521739130434% similarity, with 62 matched token, and 168 token mismatch
# ## Model validation for 240 tokens : 26.25% similarity, with 63 matched token, and 177 token mismatch
# ## Model validation for 250 tokens : 23.599999999999998% similarity, with 59 matched token, and 191 token mismatch
# ## Model validation for 260 tokens : 21.923076923076923% similarity, with 57 matched token, and 203 token mismatch
# ## Model validation for 270 tokens : 19.62962962962963% similarity, with 53 matched token, and 217 token mismatch
# ## Model validation for 280 tokens : 20.357142857142858% similarity, with 57 matched token, and 223 token mismatch
# ## Model validation for 290 tokens : 17.93103448275862% similarity, with 52 matched token, and 238 token mismatch
# ## Model validation for 300 tokens : 18.0% similarity, with 54 matched token, and 246 token mismatch
# ## Model validation for 325 tokens : 14.76923076923077% similarity, with 48 matched token, and 277 token mismatch
# ## Model validation for 350 tokens : 14.000000000000002% similarity, with 49 matched token, and 301 token mismatch
# ## Model validation for 375 tokens : 13.333333333333334% similarity, with 50 matched token, and 325 token mismatch
# ## Model validation for 400 tokens : 11.0% similarity, with 44 matched token, and 356 token mismatch
# ## Model validation for 425 tokens : 10.823529411764705% similarity, with 46 matched token, and 379 token mismatch
# ## Model validation for 450 tokens : 9.555555555555555% similarity, with 43 matched token, and 407 token mismatch
# ## Model validation for 475 tokens : 8.0% similarity, with 38 matched token, and 437 token mismatch
# ## Model validation for 500 tokens : 8.200000000000001% similarity, with 41 matched token, and 459 token mismatch
# ## Model validation for 525 tokens : 6.476190476190475% similarity, with 34 matched token, and 491 token mismatch
# ## Model validation for 550 tokens : 6.363636363636363% similarity, with 35 matched token, and 515 token mismatch
# ## Model validation for 575 tokens : 6.434782608695652% similarity, with 37 matched token, and 538 token mismatch
# ## Model validation for 600 tokens : 6.166666666666667% similarity, with 37 matched token, and 563 token mismatch
# ## Model validation for 625 tokens : 5.4399999999999995% similarity, with 34 matched token, and 591 token mismatch
# ## Model validation for 650 tokens : 5.230769230769231% similarity, with 34 matched token, and 616 token mismatch
# ## Model validation for 675 tokens : 5.037037037037037% similarity, with 34 matched token, and 641 token mismatch
# ## Model validation for 700 tokens : 5.0% similarity, with 35 matched token, and 665 token mismatch
# ## Model validation for 750 tokens : 4.933333333333334% similarity, with 37 matched token, and 713 token mismatch
# ## Model validation for 800 tokens : 4.5% similarity, with 36 matched token, and 764 token mismatch
# ## Model validation for 850 tokens : 4.0% similarity, with 34 matched token, and 816 token mismatch
# ## Model validation for 900 tokens : 3.7777777777777777% similarity, with 34 matched token, and 866 token mismatch
# ## Model validation for 950 tokens : 3.7894736842105265% similarity, with 36 matched token, and 914 token mismatch
# ## Finished baseline model to eval output predictive matching (aka 0 memory?), for 1000 tokens

# %%
# Memory benchmarking of the 7B model
# !python3 ./memory_script/eval_memory_guided.py "../../../model/RWKV-4-Raven-7B-v12-Eng98%-Other2%-20230521-ctx8192.pth" "./logs/Raven-7B-v12.csv"
# Out:
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_cuda/build.ninja...
# Building extension module wkv_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_cuda...
# RWKV_JIT_ON 1 RWKV_CUDA_ON 1 RESCALE_LAYER 0
#
# Loading ../../../model/RWKV-4-Raven-7B-v12-Eng98%-Other2%-20230521-ctx8192.pth ...
# Strategy: (total 32+1=33 layers)
# * cuda [float32, float32], store 11 layers, stream 22 layers
# 0-cuda-float32-float32 1-cuda-float32-float32 2-cuda-float32-float32 3-cuda-float32-float32 4-cuda-float32-float32 5-cuda-float32-float32 6-cuda-float32-float32 7-cuda-float32-float32 8-cuda-float32-float32 9-cuda-float32-float32 10-cuda-float32-float32 11-cuda-float32-float32-stream 12-cuda-float32-float32-stream 13-cuda-float32-float32-stream 14-cuda-float32-float32-stream 15-cuda-float32-float32-stream 16-cuda-float32-float32-stream 17-cuda-float32-float32-stream 18-cuda-float32-float32-stream 19-cuda-float32-float32-stream 20-cuda-float32-float32-stream 21-cuda-float32-float32-stream 22-cuda-float32-float32-stream 23-cuda-float32-float32-stream 24-cuda-float32-float32-stream 25-cuda-float32-float32-stream 26-cuda-float32-float32-stream 27-cuda-float32-float32-stream 28-cuda-float32-float32-stream 29-cuda-float32-float32-stream 30-cuda-float32-float32-stream 31-cuda-float32-float32-stream 32-cuda-float32-float32-stream
# emb.weight                        f32      cpu  50277  4096
# blocks.0.ln1.weight               f32   cuda:0   4096
# blocks.0.ln1.bias                 f32   cuda:0   4096
# blocks.0.ln2.weight               f32   cuda:0   4096
# blocks.0.ln2.bias                 f32   cuda:0   4096
# blocks.0.att.time_decay           f32   cuda:0   4096
# blocks.0.att.time_first           f32   cuda:0   4096
# blocks.0.att.time_mix_k           f32   cuda:0   4096
# blocks.0.att.time_mix_v           f32   cuda:0   4096
# blocks.0.att.time_mix_r           f32   cuda:0   4096
# blocks.0.att.key.weight           f32   cuda:0   4096  4096
# blocks.0.att.value.weight         f32   cuda:0   4096  4096
# blocks.0.att.receptance.weight    f32   cuda:0   4096  4096
# blocks.0.att.output.weight        f32   cuda:0   4096  4096
# blocks.0.ffn.time_mix_k           f32   cuda:0   4096
# blocks.0.ffn.time_mix_r           f32   cuda:0   4096
# blocks.0.ffn.key.weight           f32   cuda:0   4096 16384
# blocks.0.ffn.receptance.weight    f32   cuda:0   4096  4096
# blocks.0.ffn.value.weight         f32   cuda:0  16384  4096
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# blocks.31.ln1.weight              f32   cuda:0   4096
# blocks.31.ln1.bias                f32   cuda:0   4096
# blocks.31.ln2.weight              f32   cuda:0   4096
# blocks.31.ln2.bias                f32   cuda:0   4096
# blocks.31.att.time_decay          f32   cuda:0   4096
# blocks.31.att.time_first          f32   cuda:0   4096
# blocks.31.att.time_mix_k          f32   cuda:0   4096
# blocks.31.att.time_mix_v          f32   cuda:0   4096
# blocks.31.att.time_mix_r          f32   cuda:0   4096
# blocks.31.att.key.weight          f32      cpu   4096  4096  (pinned)
# blocks.31.att.value.weight        f32      cpu   4096  4096  (pinned)
# blocks.31.att.receptance.weight   f32      cpu   4096  4096  (pinned)
# blocks.31.att.output.weight       f32      cpu   4096  4096  (pinned)
# blocks.31.ffn.time_mix_k          f32   cuda:0   4096
# blocks.31.ffn.time_mix_r          f32   cuda:0   4096
# blocks.31.ffn.key.weight          f32      cpu   4096 16384  (pinned)
# blocks.31.ffn.receptance.weight   f32      cpu   4096  4096  (pinned)
# blocks.31.ffn.value.weight        f32      cpu  16384  4096  (pinned)
# ln_out.weight                     f32   cuda:0   4096
# ln_out.bias                       f32   cuda:0   4096
# head.weight                       f32   cuda:0   4096 50277
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 100.0% similarity, with 15 matched token, and 0 token mismatch
# ## Model validation for 20 tokens : 100.0% similarity, with 20 matched token, and 0 token mismatch
# ## Model validation for 25 tokens : 100.0% similarity, with 25 matched token, and 0 token mismatch
# ## Model validation for 30 tokens : 100.0% similarity, with 30 matched token, and 0 token mismatch
# ## Model validation for 35 tokens : 100.0% similarity, with 35 matched token, and 0 token mismatch
# ## Model validation for 40 tokens : 97.5% similarity, with 39 matched token, and 1 token mismatch
# ## Model validation for 45 tokens : 97.77777777777777% similarity, with 44 matched token, and 1 token mismatch
# ## Model validation for 50 tokens : 100.0% similarity, with 50 matched token, and 0 token mismatch
# ## Model validation for 55 tokens : 96.36363636363636% similarity, with 53 matched token, and 2 token mismatch
# ## Model validation for 60 tokens : 93.33333333333333% similarity, with 56 matched token, and 4 token mismatch
# ## Model validation for 65 tokens : 93.84615384615384% similarity, with 61 matched token, and 4 token mismatch
# ## Model validation for 70 tokens : 91.42857142857143% similarity, with 64 matched token, and 6 token mismatch
# ## Model validation for 75 tokens : 90.66666666666666% similarity, with 68 matched token, and 7 token mismatch
# ## Model validation for 80 tokens : 88.75% similarity, with 71 matched token, and 9 token mismatch
# ## Model validation for 85 tokens : 85.88235294117646% similarity, with 73 matched token, and 12 token mismatch
# ## Model validation for 90 tokens : 84.44444444444444% similarity, with 76 matched token, and 14 token mismatch
# ## Model validation for 95 tokens : 81.05263157894737% similarity, with 77 matched token, and 18 token mismatch
# ## Model validation for 100 tokens : 83.0% similarity, with 83 matched token, and 17 token mismatch
# ## Model validation for 105 tokens : 83.80952380952381% similarity, with 88 matched token, and 17 token mismatch
# ## Model validation for 110 tokens : 81.81818181818183% similarity, with 90 matched token, and 20 token mismatch
# ## Model validation for 115 tokens : 81.73913043478261% similarity, with 94 matched token, and 21 token mismatch
# ## Model validation for 120 tokens : 80.83333333333333% similarity, with 97 matched token, and 23 token mismatch
# ## Model validation for 125 tokens : 81.6% similarity, with 102 matched token, and 23 token mismatch
# ## Model validation for 130 tokens : 81.53846153846153% similarity, with 106 matched token, and 24 token mismatch
# ## Model validation for 135 tokens : 81.48148148148148% similarity, with 110 matched token, and 25 token mismatch
# ## Model validation for 140 tokens : 79.28571428571428% similarity, with 111 matched token, and 29 token mismatch
# ## Model validation for 145 tokens : 75.86206896551724% similarity, with 110 matched token, and 35 token mismatch
# ## Model validation for 150 tokens : 74.66666666666667% similarity, with 112 matched token, and 38 token mismatch
# ## Model validation for 160 tokens : 65.0% similarity, with 104 matched token, and 56 token mismatch
# ## Model validation for 170 tokens : 64.11764705882354% similarity, with 109 matched token, and 61 token mismatch
# ## Model validation for 180 tokens : 61.66666666666667% similarity, with 111 matched token, and 69 token mismatch
# ## Model validation for 190 tokens : 55.26315789473685% similarity, with 105 matched token, and 85 token mismatch
# ## Model validation for 200 tokens : 53.5% similarity, with 107 matched token, and 93 token mismatch
# ## Model validation for 210 tokens : 53.80952380952381% similarity, with 113 matched token, and 97 token mismatch
# ## Model validation for 220 tokens : 50.0% similarity, with 110 matched token, and 110 token mismatch
# ## Model validation for 230 tokens : 47.82608695652174% similarity, with 110 matched token, and 120 token mismatch
# ## Model validation for 240 tokens : 44.583333333333336% similarity, with 107 matched token, and 133 token mismatch
# ## Model validation for 250 tokens : 40.400000000000006% similarity, with 101 matched token, and 149 token mismatch
# ## Model validation for 260 tokens : 37.69230769230769% similarity, with 98 matched token, and 162 token mismatch
# ## Model validation for 270 tokens : 34.44444444444444% similarity, with 93 matched token, and 177 token mismatch
# ## Model validation for 280 tokens : 31.785714285714285% similarity, with 89 matched token, and 191 token mismatch
# ## Model validation for 290 tokens : 34.82758620689655% similarity, with 101 matched token, and 189 token mismatch
# ## Model validation for 300 tokens : 29.333333333333332% similarity, with 88 matched token, and 212 token mismatch
# ## Model validation for 325 tokens : 25.23076923076923% similarity, with 82 matched token, and 243 token mismatch
# ## Model validation for 350 tokens : 22.285714285714285% similarity, with 78 matched token, and 272 token mismatch
# ## Model validation for 375 tokens : 21.6% similarity, with 81 matched token, and 294 token mismatch
# ## Model validation for 400 tokens : 19.25% similarity, with 77 matched token, and 323 token mismatch
# ## Model validation for 425 tokens : 16.705882352941178% similarity, with 71 matched token, and 354 token mismatch
# ## Model validation for 450 tokens : 16.22222222222222% similarity, with 73 matched token, and 377 token mismatch
# ## Model validation for 475 tokens : 15.789473684210526% similarity, with 75 matched token, and 400 token mismatch
# ## Model validation for 500 tokens : 15.6% similarity, with 78 matched token, and 422 token mismatch
# ## Model validation for 525 tokens : 14.285714285714285% similarity, with 75 matched token, and 450 token mismatch
# ## Model validation for 550 tokens : 14.181818181818182% similarity, with 78 matched token, and 472 token mismatch
# ## Model validation for 575 tokens : 13.043478260869565% similarity, with 75 matched token, and 500 token mismatch
# ## Model validation for 600 tokens : 12.666666666666668% similarity, with 76 matched token, and 524 token mismatch
# ## Model validation for 625 tokens : 12.0% similarity, with 75 matched token, and 550 token mismatch
# ## Model validation for 650 tokens : 11.692307692307692% similarity, with 76 matched token, and 574 token mismatch
# ## Model validation for 675 tokens : 10.814814814814815% similarity, with 73 matched token, and 602 token mismatch
# ## Model validation for 700 tokens : 10.428571428571429% similarity, with 73 matched token, and 627 token mismatch
# ## Model validation for 750 tokens : 10.4% similarity, with 78 matched token, and 672 token mismatch
# ## Model validation for 800 tokens : 9.375% similarity, with 75 matched token, and 725 token mismatch
# ## Model validation for 850 tokens : 9.294117647058824% similarity, with 79 matched token, and 771 token mismatch
# ## Model validation for 900 tokens : 9.444444444444445% similarity, with 85 matched token, and 815 token mismatch
# ## Model validation for 950 tokens : 9.05263157894737% similarity, with 86 matched token, and 864 token mismatch
# ## Finished baseline model to eval output predictive matching (aka 0 memory?), for 1000 tokens

# %%
# Memory benchmarking of the 14B model
# !python3 ./memory_script/eval_memory_guided.py "../../../model/RWKV-4-Raven-14B-v12-Eng98%-Other2%-20230523-ctx8192.pth" "./logs/Raven-14B-v12.csv"
# Out:
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_cuda/build.ninja...
# Building extension module wkv_cuda...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_cuda...
# RWKV_JIT_ON 1 RWKV_CUDA_ON 1 RESCALE_LAYER 0
#
# Loading ../../../model/RWKV-4-Raven-14B-v12-Eng98%-Other2%-20230523-ctx8192.pth ...
# Strategy: (total 40+1=41 layers)
# * cuda [float32, float32], store 6 layers, stream 35 layers
# 0-cuda-float32-float32 1-cuda-float32-float32 2-cuda-float32-float32 3-cuda-float32-float32 4-cuda-float32-float32 5-cuda-float32-float32 6-cuda-float32-float32-stream 7-cuda-float32-float32-stream 8-cuda-float32-float32-stream 9-cuda-float32-float32-stream 10-cuda-float32-float32-stream 11-cuda-float32-float32-stream 12-cuda-float32-float32-stream 13-cuda-float32-float32-stream 14-cuda-float32-float32-stream 15-cuda-float32-float32-stream 16-cuda-float32-float32-stream 17-cuda-float32-float32-stream 18-cuda-float32-float32-stream 19-cuda-float32-float32-stream 20-cuda-float32-float32-stream 21-cuda-float32-float32-stream 22-cuda-float32-float32-stream 23-cuda-float32-float32-stream 24-cuda-float32-float32-stream 25-cuda-float32-float32-stream 26-cuda-float32-float32-stream 27-cuda-float32-float32-stream 28-cuda-float32-float32-stream 29-cuda-float32-float32-stream 30-cuda-float32-float32-stream 31-cuda-float32-float32-stream 32-cuda-float32-float32-stream 33-cuda-float32-float32-stream 34-cuda-float32-float32-stream 35-cuda-float32-float32-stream 36-cuda-float32-float32-stream 37-cuda-float32-float32-stream 38-cuda-float32-float32-stream 39-cuda-float32-float32-stream 40-cuda-float32-float32-stream
# emb.weight                        f32      cpu  50277  5120
# blocks.0.ln1.weight               f32   cuda:0   5120
# blocks.0.ln1.bias                 f32   cuda:0   5120
# blocks.0.ln2.weight               f32   cuda:0   5120
# blocks.0.ln2.bias                 f32   cuda:0   5120
# blocks.0.att.time_decay           f32   cuda:0   5120
# blocks.0.att.time_first           f32   cuda:0   5120
# blocks.0.att.time_mix_k           f32   cuda:0   5120
# blocks.0.att.time_mix_v           f32   cuda:0   5120
# blocks.0.att.time_mix_r           f32   cuda:0   5120
# blocks.0.att.key.weight           f32   cuda:0   5120  5120
# blocks.0.att.value.weight         f32   cuda:0   5120  5120
# blocks.0.att.receptance.weight    f32   cuda:0   5120  5120
# blocks.0.att.output.weight        f32   cuda:0   5120  5120
# blocks.0.ffn.time_mix_k           f32   cuda:0   5120
# blocks.0.ffn.time_mix_r           f32   cuda:0   5120
# blocks.0.ffn.key.weight           f32   cuda:0   5120 20480
# blocks.0.ffn.receptance.weight    f32   cuda:0   5120  5120
# blocks.0.ffn.value.weight         f32   cuda:0  20480  5120
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# blocks.39.ln1.weight              f32   cuda:0   5120
# blocks.39.ln1.bias                f32   cuda:0   5120
# blocks.39.ln2.weight              f32   cuda:0   5120
# blocks.39.ln2.bias                f32   cuda:0   5120
# blocks.39.att.time_decay          f32   cuda:0   5120
# blocks.39.att.time_first          f32   cuda:0   5120
# blocks.39.att.time_mix_k          f32   cuda:0   5120
# blocks.39.att.time_mix_v          f32   cuda:0   5120
# blocks.39.att.time_mix_r          f32   cuda:0   5120
# blocks.39.att.key.weight          f32      cpu   5120  5120  (pinned)
# blocks.39.att.value.weight        f32      cpu   5120  5120  (pinned)
# blocks.39.att.receptance.weight   f32      cpu   5120  5120  (pinned)
# blocks.39.att.output.weight       f32      cpu   5120  5120  (pinned)
# blocks.39.ffn.time_mix_k          f32   cuda:0   5120
# blocks.39.ffn.time_mix_r          f32   cuda:0   5120
# blocks.39.ffn.key.weight          f32      cpu   5120 20480  (pinned)
# blocks.39.ffn.receptance.weight   f32      cpu   5120  5120  (pinned)
# blocks.39.ffn.value.weight        f32      cpu  20480  5120  (pinned)
# ln_out.weight                     f32   cuda:0   5120
# ln_out.bias                       f32   cuda:0   5120
# head.weight                       f32   cuda:0   5120 50277
# ###
# ### Model validation start ###
# ###
# ## Model validation for 5 tokens : 100.0% similarity, with 5 matched token, and 0 token mismatch
# ## Model validation for 10 tokens : 100.0% similarity, with 10 matched token, and 0 token mismatch
# ## Model validation for 15 tokens : 100.0% similarity, with 15 matched token, and 0 token mismatch
# ## Model validation for 20 tokens : 100.0% similarity, with 20 matched token, and 0 token mismatch
# ## Model validation for 25 tokens : 100.0% similarity, with 25 matched token, and 0 token mismatch
# ## Model validation for 30 tokens : 100.0% similarity, with 30 matched token, and 0 token mismatch
# ## Model validation for 35 tokens : 100.0% similarity, with 35 matched token, and 0 token mismatch
# ## Model validation for 40 tokens : 100.0% similarity, with 40 matched token, and 0 token mismatch
# ## Model validation for 45 tokens : 100.0% similarity, with 45 matched token, and 0 token mismatch
# ## Model validation for 50 tokens : 100.0% similarity, with 50 matched token, and 0 token mismatch
# ## Model validation for 55 tokens : 100.0% similarity, with 55 matched token, and 0 token mismatch
# ## Model validation for 60 tokens : 100.0% similarity, with 60 matched token, and 0 token mismatch
# ## Model validation for 65 tokens : 100.0% similarity, with 65 matched token, and 0 token mismatch
# ## Model validation for 70 tokens : 100.0% similarity, with 70 matched token, and 0 token mismatch
# ## Model validation for 75 tokens : 100.0% similarity, with 75 matched token, and 0 token mismatch
# ## Model validation for 80 tokens : 97.5% similarity, with 78 matched token, and 2 token mismatch
# ## Model validation for 85 tokens : 97.6470588235294% similarity, with 83 matched token, and 2 token mismatch
# ## Model validation for 90 tokens : 96.66666666666667% similarity, with 87 matched token, and 3 token mismatch
# ## Model validation for 95 tokens : 96.84210526315789% similarity, with 92 matched token, and 3 token mismatch
# ## Model validation for 100 tokens : 97.0% similarity, with 97 matched token, and 3 token mismatch
# ## Model validation for 105 tokens : 96.19047619047619% similarity, with 101 matched token, and 4 token mismatch
# ## Model validation for 110 tokens : 96.36363636363636% similarity, with 106 matched token, and 4 token mismatch
# ## Model validation for 115 tokens : 93.04347826086956% similarity, with 107 matched token, and 8 token mismatch
# ## Model validation for 120 tokens : 92.5% similarity, with 111 matched token, and 9 token mismatch
# ## Model validation for 125 tokens : 92.80000000000001% similarity, with 116 matched token, and 9 token mismatch
# ## Model validation for 130 tokens : 91.53846153846153% similarity, with 119 matched token, and 11 token mismatch
# ## Model validation for 135 tokens : 91.11111111111111% similarity, with 123 matched token, and 12 token mismatch
# ## Model validation for 140 tokens : 91.42857142857143% similarity, with 128 matched token, and 12 token mismatch
# ## Model validation for 145 tokens : 91.0344827586207% similarity, with 132 matched token, and 13 token mismatch
# ## Model validation for 150 tokens : 90.66666666666666% similarity, with 136 matched token, and 14 token mismatch
# ## Model validation for 160 tokens : 87.5% similarity, with 140 matched token, and 20 token mismatch
# ## Model validation for 170 tokens : 82.94117647058825% similarity, with 141 matched token, and 29 token mismatch
# ## Model validation for 180 tokens : 82.22222222222221% similarity, with 148 matched token, and 32 token mismatch
# ## Model validation for 190 tokens : 81.05263157894737% similarity, with 154 matched token, and 36 token mismatch
# ## Model validation for 200 tokens : 78.0% similarity, with 156 matched token, and 44 token mismatch
# ## Model validation for 210 tokens : 74.76190476190476% similarity, with 157 matched token, and 53 token mismatch
# ## Model validation for 220 tokens : 69.54545454545455% similarity, with 153 matched token, and 67 token mismatch
# ## Model validation for 230 tokens : 66.08695652173913% similarity, with 152 matched token, and 78 token mismatch
# ## Model validation for 240 tokens : 61.25000000000001% similarity, with 147 matched token, and 93 token mismatch
# ## Model validation for 250 tokens : 60.0% similarity, with 150 matched token, and 100 token mismatch
# ## Model validation for 260 tokens : 56.15384615384615% similarity, with 146 matched token, and 114 token mismatch
# ## Model validation for 270 tokens : 52.96296296296297% similarity, with 143 matched token, and 127 token mismatch
# ## Model validation for 280 tokens : 52.85714285714286% similarity, with 148 matched token, and 132 token mismatch
# ## Model validation for 290 tokens : 50.0% similarity, with 145 matched token, and 145 token mismatch
# ## Model validation for 300 tokens : 48.333333333333336% similarity, with 145 matched token, and 155 token mismatch
# ## Model validation for 325 tokens : 45.230769230769226% similarity, with 147 matched token, and 178 token mismatch
# ## Model validation for 350 tokens : 40.0% similarity, with 140 matched token, and 210 token mismatch
# ## Model validation for 375 tokens : 33.6% similarity, with 126 matched token, and 249 token mismatch
# ## Model validation for 400 tokens : 29.5% similarity, with 118 matched token, and 282 token mismatch
# ## Model validation for 425 tokens : 25.882352941176475% similarity, with 110 matched token, and 315 token mismatch
# ## Model validation for 450 tokens : 24.444444444444443% similarity, with 110 matched token, and 340 token mismatch
# ## Model validation for 475 tokens : 21.263157894736842% similarity, with 101 matched token, and 374 token mismatch
# ## Model validation for 500 tokens : 19.400000000000002% similarity, with 97 matched token, and 403 token mismatch
# ## Model validation for 525 tokens : 17.71428571428571% similarity, with 93 matched token, and 432 token mismatch
# ## Model validation for 550 tokens : 17.272727272727273% similarity, with 95 matched token, and 455 token mismatch
# ## Model validation for 575 tokens : 16.17391304347826% similarity, with 93 matched token, and 482 token mismatch
# ## Model validation for 600 tokens : 13.333333333333334% similarity, with 80 matched token, and 520 token mismatch
# ## Model validation for 625 tokens : 14.56% similarity, with 91 matched token, and 534 token mismatch
# ## Model validation for 650 tokens : 13.692307692307693% similarity, with 89 matched token, and 561 token mismatch
# ## Model validation for 675 tokens : 12.296296296296298% similarity, with 83 matched token, and 592 token mismatch
# ## Model validation for 700 tokens : 12.571428571428573% similarity, with 88 matched token, and 612 token mismatch
# ## Model validation for 750 tokens : 10.266666666666667% similarity, with 77 matched token, and 673 token mismatch
# ## Model validation for 800 tokens : 9.25% similarity, with 74 matched token, and 726 token mismatch
# ## Model validation for 850 tokens : 9.411764705882353% similarity, with 80 matched token, and 770 token mismatch
# ## Model validation for 900 tokens : 8.333333333333332% similarity, with 75 matched token, and 825 token mismatch
# ## Model validation for 950 tokens : 8.0% similarity, with 76 matched token, and 874 token mismatch
# ## Model validation for 1000 tokens : 7.6% similarity, with 76 matched token, and 924 token mismatch
# ## Finished baseline model to eval output predictive matching (aka 0 memory?), for 1000 tokens
