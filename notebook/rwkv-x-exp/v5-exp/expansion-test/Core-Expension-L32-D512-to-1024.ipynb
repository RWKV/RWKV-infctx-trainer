# %%
# -----------------------------------------------------------------
# Your configurable settings
# -----------------------------------------------------------------

# WANDB settings
ENABLE_WANDB=True
WANDB_PREFIX="Core-Expand"
WANDB_PROJECT="RWKV-x-v5-Expansion-Test"

# Project directory offset (you need to modify if, you move the notebook into another dir)
PROJECT_DIR_OFFSET="../../../../"

# GPU count to use
GPU_DEVICES="auto"

# -----------------------------------------------------------------
# Training settings you can use to override the "auto" default above
# -----------------------------------------------------------------
DEEPSPEED_STRAT="deepspeed_stage_2"
TRAINING_CTX_LEN=4096
MICROBATCH_SIZE=8

# -----------------------------------------------------------------
# Model settings
# -----------------------------------------------------------------
LAYER_COUNT=32
DIM_SIZE=1024
HALF_DIM_SIZE=DIM_SIZE // 2

# ---
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("TRAINING_CTX_LEN:", TRAINING_CTX_LEN)
if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, PROJECT_DIR_OFFSET))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Check if the directory exists
if not os.path.exists(TRAINER_DIR):
    raise Exception("The trainer directory does not exists. Did you move the notebook?")
# Out:
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# DEEPSPEED_STRAT: deepspeed_stage_2
# TRAINING_CTX_LEN: 4096
# NOTEBOOK_DIR: /workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test
# TRAINER_DIR: /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/picocreator/RWKV-infctx-trainer

# %% [markdown]
# # Exporting Original models (Epoch 2, and Epoch 5)

# %%
# Export the EPoch 2/5, L{LAYER_COUNT}-D{HALF_DIM_SIZE} model
# !cd "{TRAINER_DIR}" && \
    mkdir -p "../model/expansion-test/"
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "/checkpoint/v5-expansion-test/baseline/L{LAYER_COUNT}-D{HALF_DIM_SIZE}/epoch=1-step=256.ckpt" "../model/expansion-test/Base-L{LAYER_COUNT}-D{HALF_DIM_SIZE}-E02.pth"
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "/checkpoint/v5-expansion-test/baseline/L{LAYER_COUNT}-D{HALF_DIM_SIZE}/epoch=4-step=640.ckpt" "../model/expansion-test/Base-L{LAYER_COUNT}-D{HALF_DIM_SIZE}-E05.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/expansion-test/Base-L{LAYER_COUNT}-D{HALF_DIM_SIZE}-E02.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/expansion-test/Base-L{LAYER_COUNT}-D{HALF_DIM_SIZE}-E05.pth"
# Out:
# [2024-02-12 00:28:19,474] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '/checkpoint/v5-expansion-test/baseline/L32-D512/epoch=1-step=256.ckpt/checkpoint'
# Detected checkpoint of type zero stage 2, world_size: 8
# Parsing checkpoint created by deepspeed==0.12.6
# Reconstructed fp32 state dict with 710 params 176392192 elements
# Saving bf16 state dict to ../model/expansion-test/Base-L32-D512-E02.pth
# [2024-02-12 00:28:24,963] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '/checkpoint/v5-expansion-test/baseline/L32-D512/epoch=4-step=640.ckpt/checkpoint'
# Detected checkpoint of type zero stage 2, world_size: 8
# Parsing checkpoint created by deepspeed==0.12.6
# Reconstructed fp32 state dict with 710 params 176392192 elements
# Saving bf16 state dict to ../model/expansion-test/Base-L32-D512-E05.pth
# -rw-r--r-- 1 nobody root 337M Feb 12 00:28 ../model/expansion-test/Base-L32-D512-E02.pth
# -rw-r--r-- 1 nobody root 337M Feb 12 00:28 ../model/expansion-test/Base-L32-D512-E05.pth

# %%
# Merge the models respectively with the core weights
# !cd "{TRAINER_DIR}" && \
    python3 ./merge_model.py \
        --skip-if-exists --resize_mode "core" \
        "../model/expansion-test/Base-L{LAYER_COUNT}-D{HALF_DIM_SIZE}-E02.pth" \
        "../model/L{LAYER_COUNT}-D{DIM_SIZE}-world-init.pth" \
        "../model/expansion-test/Core-L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E02.pth"

# !cd "{TRAINER_DIR}" && \
    python3 ./merge_model.py \
        --skip-if-exists --resize_mode "core" \
        "../model/expansion-test/Base-L{LAYER_COUNT}-D{HALF_DIM_SIZE}-E05.pth" \
        "../model/L{LAYER_COUNT}-D{DIM_SIZE}-world-init.pth" \
        "../model/expansion-test/Core-L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E05.pth"
# Out:
# ---- Merging models ----
# Source model path: ../model/expansion-test/Base-L32-D512-E02.pth
# Target model path: ../model/L32-D1024-world-init.pth
# Output model path: ../model/expansion-test/Core-L32-D1024-from-D512-E02.pth
#
# Write mode : overwrite
# Resize mode: core
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Output model exists, skipping init_model
# ---- Merging models ----
# Source model path: ../model/expansion-test/Base-L32-D512-E05.pth
# Target model path: ../model/L32-D1024-world-init.pth
# Output model path: ../model/expansion-test/Core-L32-D1024-from-D512-E05.pth
#
# Write mode : overwrite
# Resize mode: core
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Output model exists, skipping init_model

# %% [markdown]
# # Train from the E02

# %%
# Lets start the training
# !mkdir -p "/checkpoint/v5-expansion-test/core/L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E02/"
# !cd "{TRAINER_DIR}" && \
    export RWKV_NO_CUDA=1 && \
    export RWKV_TORCH_COMPILE=0 && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki-100k-world-16k-rechunk.yaml" \
        --model.load_model="../model/expansion-test/Core-L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E02.pth" \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="/checkpoint/v5-expansion-test/core/L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E02/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E02 (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-12 00:39:22,692] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/expansion-test/Core-L32-D1024-from-D512-E02.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/core/L32-D1024-from-D512-E02/', '--trainer.logger.init_args.name=Core-Expand - L32-D1024-from-D512-E02 (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/expansion-test/Core-L32-D1024-from-D512-E02.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/core/L32-D1024-from-D512-E02/', '--trainer.logger.init_args.name=Core-Expand - L32-D1024-from-D512-E02 (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'].
# Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         8
#    - accumulate_grad_batches: 4
#    - effective_batch_size:    256
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-12 00:39:31,606] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 00:39:31,624] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 00:39:31,646] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 00:39:31,741] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 00:39:31,744] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 00:39:31,771] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 00:39:31,798] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [rank: 6] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# [rank: 4] Seed set to 3941088705
# [rank: 1] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# [rank: 2] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in ./wandb/run-20240212_003957-pcoahpsd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Core-Expand - L32-D1024-from-D512-E02 (tctxlen=4096, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/pcoahpsd
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  3.000e-05 (3e-05)
#     - lr_final: 3.000e-05 (3e-05)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.05128812789916992 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1018362045288086 seconds
# Loading extension module fused_adam...
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10188913345336914 seconds
# Time to load fused_adam op: 0.1017148494720459 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10187721252441406 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10195398330688477 seconds
# Time to load fused_adam op: 0.10233759880065918 seconds
# Time to load fused_adam op: 0.10318112373352051 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 67.1 M
# 1 | blocks | ModuleList | 436 M
# 2 | ln_out | LayerNorm  | 2.0 K
# 3 | head   | Linear     | 67.1 M
# --------------------------------------
# 570 M     Trainable params
# 0         Non-trainable params
# 570 M     Total params
# 2,283.553 Total estimated model params size (MB)
# Epoch 0: 100%|██| 513/513 [38:06<00:00,  0.22it/s, v_num=hpsd, train/loss=5.470]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.59it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.60it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:06<00:00,  0.47it/s]
# Epoch 0: 100%|█| 513/513 [38:13<00:00,  0.22it/s, v_num=hpsd, train/loss=5.470, /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 1: 100%|█| 513/513 [37:56<00:00,  0.23it/s, v_num=hpsd, train/loss=5.030,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.59it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.60it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:04<00:00,  0.67it/s]
# Epoch 2: 100%|█| 513/513 [37:56<00:00,  0.23it/s, v_num=hpsd, train/loss=4.750,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.59it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.60it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:04<00:00,  0.67it/s]
# Epoch 3: 100%|█| 513/513 [37:55<00:00,  0.23it/s, v_num=hpsd, train/loss=4.560,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.59it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.61it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:04<00:00,  0.67it/s]
# Epoch 4: 100%|█| 513/513 [37:55<00:00,  0.23it/s, v_num=hpsd, train/loss=4.410,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.58it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.60it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:04<00:00,  0.66it/s]
# Epoch 4: 100%|█| 513/513 [38:00<00:00,  0.22it/s, v_num=hpsd, train/loss=4.410, `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|█| 513/513 [38:19<00:00,  0.22it/s, v_num=hpsd, train/loss=4.410,
# wandb: | 0.041 MB of 0.041 MB uploaded (0.004 MB deduped)
# wandb: Run history:
# wandb:                        batchidx ▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█
# wandb:                           epoch ▁▁▁▃▃▃▃▅▅▅▆▆▆▆███
# wandb:                     global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      perf/kTokens_per_sec.gpu.0 ▁▆▇▇████▇▇▇▇▇███▇▇▇▇▇▇██▇▇▇▇▇▇▇█▇▇▇▇▇▇▇▇
# wandb: perf/kTokens_per_sec_step.gpu.0 ▇▃█▃█▅█▄▆▇█▂▆▃▆▃▇▆▆▃▆▄▆▃▅▃▇▂█▃▇▂▇▄▆▁▇▄▆▆
# wandb:        perf/kTokens_total.gpu.0 ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                         substep ▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█
# wandb:               train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/data_loss █▆▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁
# wandb:                train/learn_loss █▆▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁
# wandb:              train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                      train/loss █▆▅▄▄▃▂▃▁▂▁▁
# wandb:             trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:           trainer/learning_rate ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          validation/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            validation/data_loss ███▅▅▅▄▃▃▂▂▂▁▁▁
# wandb:           validation/learn_loss ███▅▅▅▄▃▃▂▂▂▁▁▁
# wandb:         validation/learn_tokens ██▁██▁██▁██▁██▁
# wandb:                 validation/loss █▅▃▂▁
# wandb:
# wandb: Run summary:
# wandb:                        batchidx 2
# wandb:                           epoch 4
# wandb:                     global_rank 0
# wandb:      perf/kTokens_per_sec.gpu.0 29.28467
# wandb: perf/kTokens_per_sec_step.gpu.0 36.90107
# wandb:        perf/kTokens_total.gpu.0 336199.68
# wandb:                         substep 4096
# wandb:               train/data_ctxlen 16384.0
# wandb:                 train/data_loss 4.40625
# wandb:                train/learn_loss 4.40625
# wandb:              train/learn_tokens 16383.0
# wandb:                      train/loss 4.46875
# wandb:             trainer/global_step 640
# wandb:           trainer/learning_rate 3e-05
# wandb:          validation/data_ctxlen 16383
# wandb:            validation/data_loss 4.3125
# wandb:           validation/learn_loss 4.3125
# wandb:         validation/learn_tokens 65532
# wandb:                 validation/loss 4.33437
# wandb:
# wandb: 🚀 View run Core-Expand - L32-D1024-from-D512-E02 (tctxlen=4096, deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/pcoahpsd
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzODg4MTQxOA==/version_details/v6
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240212_003957-pcoahpsd/logs

# %% [markdown]
# # Train from the E05

# %%
# Lets start the training
# !mkdir -p "/checkpoint/v5-expansion-test/core/L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E05/"
# !cd "{TRAINER_DIR}" && \
    export RWKV_NO_CUDA=1 && \
    export RWKV_TORCH_COMPILE=0 && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki-100k-world-16k-rechunk.yaml" \
        --model.load_model="../model/expansion-test/Core-L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E05.pth" \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="/checkpoint/v5-expansion-test/core/L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E05/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - L{LAYER_COUNT}-D{DIM_SIZE}-from-D{HALF_DIM_SIZE}-E05 (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-12 04:08:11,695] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/expansion-test/Core-L32-D1024-from-D512-E05.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/core/L32-D1024-from-D512-E05/', '--trainer.logger.init_args.name=Core-Expand - L32-D1024-from-D512-E05 (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/expansion-test/Core-L32-D1024-from-D512-E05.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/core/L32-D1024-from-D512-E05/', '--trainer.logger.init_args.name=Core-Expand - L32-D1024-from-D512-E05 (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'].
# Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         8
#    - accumulate_grad_batches: 4
#    - effective_batch_size:    256
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-12 04:08:20,373] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 04:08:20,439] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 04:08:20,440] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 04:08:20,463] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 04:08:20,506] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 04:08:20,539] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 04:08:20,555] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [rank: 7] Seed set to 3941088705
# [rank: 5] Seed set to 3941088705
# [rank: 6] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 3941088705
# [rank: 1] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in ./wandb/run-20240212_040848-spbygepo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Core-Expand - L32-D1024-from-D512-E05 (tctxlen=4096, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/spbygepo
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  3.000e-05 (3e-05)
#     - lr_final: 3.000e-05 (3e-05)
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.057375431060791016 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10181498527526855 seconds
# Time to load fused_adam op: 0.1018834114074707 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10170102119445801 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.1018989086151123 seconds
# Time to load fused_adam op: 0.10182046890258789 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10191011428833008 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10239195823669434 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 67.1 M
# 1 | blocks | ModuleList | 436 M
# 2 | ln_out | LayerNorm  | 2.0 K
# 3 | head   | Linear     | 67.1 M
# --------------------------------------
# 570 M     Trainable params
# 0         Non-trainable params
# 570 M     Total params
# 2,283.553 Total estimated model params size (MB)
# Epoch 0: 100%|██| 513/513 [38:07<00:00,  0.22it/s, v_num=gepo, train/loss=5.030]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.59it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.61it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:06<00:00,  0.47it/s]
# Epoch 0: 100%|█| 513/513 [38:14<00:00,  0.22it/s, v_num=gepo, train/loss=5.030, /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 1: 100%|█| 513/513 [37:57<00:00,  0.23it/s, v_num=gepo, train/loss=4.720,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.58it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.60it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:04<00:00,  0.67it/s]
# Epoch 2: 100%|█| 513/513 [37:57<00:00,  0.23it/s, v_num=gepo, train/loss=4.560,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.59it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.60it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:04<00:00,  0.66it/s]
# Epoch 3: 100%|█| 513/513 [37:58<00:00,  0.23it/s, v_num=gepo, train/loss=4.410,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.59it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.60it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:04<00:00,  0.67it/s]
# Epoch 4: 100%|█| 513/513 [37:57<00:00,  0.23it/s, v_num=gepo, train/loss=4.310,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:01<00:03,  0.60it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:03<00:01,  0.62it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:04<00:00,  0.69it/s]
# Epoch 4: 100%|█| 513/513 [38:02<00:00,  0.22it/s, v_num=gepo, train/loss=4.310, `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|█| 513/513 [38:20<00:00,  0.22it/s, v_num=gepo, train/loss=4.310,
# wandb: | 0.041 MB of 0.041 MB uploaded
# wandb: Run history:
# wandb:                        batchidx ▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█
# wandb:                           epoch ▁▁▁▃▃▃▃▅▅▅▆▆▆▆███
# wandb:                     global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      perf/kTokens_per_sec.gpu.0 ▁▆▇▇████▇▇▇▇▇███▇▇▇▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇
# wandb: perf/kTokens_per_sec_step.gpu.0 █▃▇▃▇▃█▃▇▄▆▄▆▂▇▃▆▄▇▂▆▄▇▁▇▃█▃▇▃▇▃▇▄▇▃█▃▆▅
# wandb:        perf/kTokens_total.gpu.0 ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                         substep ▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█
# wandb:               train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/data_loss █▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:                train/learn_loss █▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:              train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                      train/loss █▅▄▄▃▃▂▃▁▂▁▁
# wandb:             trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:           trainer/learning_rate ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          validation/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            validation/data_loss ███▅▅▅▄▃▃▂▂▂▁▁▁
# wandb:           validation/learn_loss ███▅▅▅▄▃▃▂▂▂▁▁▁
# wandb:         validation/learn_tokens ██▁██▁██▁██▁██▁
# wandb:                 validation/loss █▅▃▂▁
# wandb:
# wandb: Run summary:
# wandb:                        batchidx 2
# wandb:                           epoch 4
# wandb:                     global_rank 0
# wandb:      perf/kTokens_per_sec.gpu.0 29.25538
# wandb: perf/kTokens_per_sec_step.gpu.0 29.51319
# wandb:        perf/kTokens_total.gpu.0 336199.68
# wandb:                         substep 4096
# wandb:               train/data_ctxlen 16384.0
# wandb:                 train/data_loss 4.3125
# wandb:                train/learn_loss 4.3125
# wandb:              train/learn_tokens 16383.0
# wandb:                      train/loss 4.3125
# wandb:             trainer/global_step 640
# wandb:           trainer/learning_rate 3e-05
# wandb:          validation/data_ctxlen 16383
# wandb:            validation/data_loss 4.25
# wandb:           validation/learn_loss 4.25
# wandb:         validation/learn_tokens 65532
# wandb:                 validation/loss 4.2375
# wandb:
# wandb: 🚀 View run Core-Expand - L32-D1024-from-D512-E05 (tctxlen=4096, deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/spbygepo
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzODg4MTQxOA==/version_details/v8
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240212_040848-spbygepo/logs
