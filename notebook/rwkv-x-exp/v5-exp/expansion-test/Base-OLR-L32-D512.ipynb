# %% [markdown]
# # Eagle 7B : Training on 1 more Trillion tokens!

# %%
# -----------------------------------------------------------------
# Your configurable settings
# -----------------------------------------------------------------

# WANDB settings
ENABLE_WANDB=True
WANDB_PREFIX="Baseline-OLR"
WANDB_PROJECT="RWKV-x-v5-Expansion-Test"

# Project directory offset (you need to modify if, you move the notebook into another dir)
PROJECT_DIR_OFFSET="../../../../"

# GPU count to use
GPU_DEVICES="auto"

# -----------------------------------------------------------------
# Training settings you can use to override the "auto" default above
# -----------------------------------------------------------------
DEEPSPEED_STRAT="deepspeed_stage_2"
TRAINING_CTX_LEN=2048
MICROBATCH_SIZE=32

# -----------------------------------------------------------------
# Model settings
# -----------------------------------------------------------------
LAYER_COUNT=32
DIM_SIZE=512

# ---
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("TRAINING_CTX_LEN:", TRAINING_CTX_LEN)
if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, PROJECT_DIR_OFFSET))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Check if the directory exists
if not os.path.exists(TRAINER_DIR):
    raise Exception("The trainer directory does not exists. Did you move the notebook?")
# Out:
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# DEEPSPEED_STRAT: deepspeed_stage_2
# TRAINING_CTX_LEN: 2048
# NOTEBOOK_DIR: /workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test
# TRAINER_DIR: /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/picocreator/RWKV-infctx-trainer

# %% [markdown]
# ## Init the empty model

# %%
# Lets initialized the various models, and their sizes
# !cd "{TRAINER_DIR}" && python3 init_model.py \
    --n_layer {LAYER_COUNT} --n_embd {DIM_SIZE} \
    --vocab_size world \
    --skip-if-exists --safe-init \
    ../model/L{LAYER_COUNT}-D{DIM_SIZE}-world-init.pth
# Out:
# [2024-02-12 19:04:51,377] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# ---- Initializing model ----
# No of layers: 32
# Embedding size: 512
# Output model path: ../model/L32-D512-world-init.pth
# Vocab size: 65536
# Emb scale: 0.0001
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Output model exists, skipping init_model

# %% [markdown]
# ## Start the training run!

# %%
# Setup the checkpoint dir
# !cd "{PROJECT_DIR}" && mkdir -p "/checkpoint/v5-expansion-test/base-olr/L{LAYER_COUNT}-D{DIM_SIZE}/"

# Lets start the training
# !cd "{TRAINER_DIR}" && \
    export RWKV_NO_CUDA=1 && \
    export RWKV_TORCH_COMPILE=1 && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki-100k-world-16k-rechunk.yaml" \
        --model.load_model="../model/L{LAYER_COUNT}-D{DIM_SIZE}-world-init.pth" \
        --model.lr_init="9e-4" \
        --model.lr_final="3e-5" \
        --model.lr_period=5 \
        --trainer.max_epochs=5 \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="/checkpoint/v5-expansion-test/base-olr/L{LAYER_COUNT}-D{DIM_SIZE}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - L{LAYER_COUNT}-D{DIM_SIZE} (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-12 21:57:13,072] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/L32-D512-world-init.pth', '--model.lr_init=9e-4', '--model.lr_final=3e-5', '--model.lr_period=5', '--trainer.max_epochs=5', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/base-olr/L32-D512/', '--trainer.logger.init_args.name=Baseline-OLR - L32-D512 (tctxlen=2048, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=32', '--model.ctx_len=2048', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/L32-D512-world-init.pth', '--model.lr_init=9e-4', '--model.lr_final=3e-5', '--model.lr_period=5', '--trainer.max_epochs=5', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/base-olr/L32-D512/', '--trainer.logger.init_args.name=Baseline-OLR - L32-D512 (tctxlen=2048, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=32', '--model.ctx_len=2048', '--trainer.devices=auto'].
# Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         32
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    256
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-12 21:57:21,289] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 21:57:21,316] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 21:57:21,408] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 21:57:21,455] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 21:57:21,575] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 21:57:21,576] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-12 21:57:21,656] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [rank: 5] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 3941088705
# [rank: 6] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# [rank: 1] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in ./wandb/run-20240212_215742-bgb8963l
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Baseline-OLR - L32-D512 (tctxlen=2048, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/bgb8963l
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:639: Checkpoint directory /checkpoint/v5-expansion-test/base-olr/L32-D512 exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  9.000e-04 (0.0009)
#     - lr_final: 3.000e-05 (3e-05)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.04803800582885742 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10163736343383789 seconds
# Time to load fused_adam op: 0.10147738456726074 seconds
# Time to load fused_adam op: 0.10155940055847168 seconds
# Time to load fused_adam op: 0.10166645050048828 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10157060623168945 seconds
# Time to load fused_adam op: 0.10160493850708008 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1054527759552002 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 109 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 176 M     Trainable params
# 0         Non-trainable params
# 176 M     Total params
# 705.569   Total estimated model params size (MB)
# Epoch 0:   0%|                                          | 0/129 [00:00<?, ?it/s][rank5]:[2024-02-12 22:02:03,420] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-12 22:02:03,420] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank5]:[2024-02-12 22:02:03,420] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-12 22:02:03,420] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-12 22:02:03,420] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank7]:[2024-02-12 22:02:03,420] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank6]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank0]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank1]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank3]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank2]:[2024-02-12 22:02:03,421] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-12 22:02:03,422] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-12 22:02:03,422] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank4]:[2024-02-12 22:02:03,422] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-12 22:02:05,285] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-12 22:02:05,285] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank0]:[2024-02-12 22:02:05,285] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-12 22:02:06,205] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-12 22:02:06,205] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank7]:[2024-02-12 22:02:06,205] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-12 22:02:06,227] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-12 22:02:06,227] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank5]:[2024-02-12 22:02:06,227] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-12 22:02:06,239] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-12 22:02:06,239] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank3]:[2024-02-12 22:02:06,239] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-12 22:02:06,240] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-12 22:02:06,240] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank2]:[2024-02-12 22:02:06,240] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-12 22:02:06,244] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-12 22:02:06,244] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank1]:[2024-02-12 22:02:06,244] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-12 22:02:06,656] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-12 22:02:06,656] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank6]:[2024-02-12 22:02:06,656] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-12 22:02:06,669] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-12 22:02:06,669] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank4]:[2024-02-12 22:02:06,669] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# Epoch 0:   1%| | 1/129 [08:06<17:18:07,  0.00it/s, v_num=963l, train/loss=11.10][rank0]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank0]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank5]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank1]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank2]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank3]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank7]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank4]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank6]:[2024-02-12 22:05:57,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-12 22:05:59,665] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-12 22:05:59,665] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank1]:[2024-02-12 22:05:59,665] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-12 22:05:59,668] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-12 22:05:59,668] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank4]:[2024-02-12 22:05:59,668] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-12 22:05:59,671] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-12 22:05:59,671] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank7]:[2024-02-12 22:05:59,671] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-12 22:05:59,673] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-12 22:05:59,673] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank3]:[2024-02-12 22:05:59,673] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-12 22:05:59,684] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-12 22:05:59,684] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank6]:[2024-02-12 22:05:59,684] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-12 22:05:59,702] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-12 22:05:59,702] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank5]:[2024-02-12 22:05:59,702] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-12 22:05:59,714] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-12 22:05:59,714] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank0]:[2024-02-12 22:05:59,714] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-12 22:05:59,741] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-12 22:05:59,741] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank2]:[2024-02-12 22:05:59,741] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank5]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank7]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank6]:[2024-02-12 22:09:28,846] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank0]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank2]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank4]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank3]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank1]:[2024-02-12 22:09:28,847] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# Epoch 0:  99%|█▉| 128/129 [27:45<00:13,  0.08it/s, v_num=963l, train/loss=5.000][rank0]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING]    function: 'get_rkvgwu' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:351)
# [rank0]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING]    function: 'get_rkvgwu' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:351)
# [rank4]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING]    function: 'get_rkvgwu' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:351)
# [rank7]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING]    function: 'get_rkvgwu' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:351)
# [rank3]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING]    function: 'get_rkvgwu' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:351)
# [rank5]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING]    function: 'get_rkvgwu' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:351)
# [rank2]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING]    function: 'get_rkvgwu' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:351)
# [rank1]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING]    function: 'get_rkvgwu' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:351)
# [rank6]:[2024-02-12 22:25:37,072] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-12 22:25:37,182] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-12 22:25:37,182] torch._dynamo.convert_frame: [WARNING]    function: 'call_rwkv_inner' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:377)
# [rank4]:[2024-02-12 22:25:37,182] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-12 22:25:37,183] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-12 22:25:37,183] torch._dynamo.convert_frame: [WARNING]    function: 'call_rwkv_inner' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:377)
# [rank7]:[2024-02-12 22:25:37,183] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-12 22:25:37,183] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-12 22:25:37,183] torch._dynamo.convert_frame: [WARNING]    function: 'call_rwkv_inner' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:377)
# [rank5]:[2024-02-12 22:25:37,183] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-12 22:25:37,184] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-12 22:25:37,184] torch._dynamo.convert_frame: [WARNING]    function: 'call_rwkv_inner' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:377)
# [rank3]:[2024-02-12 22:25:37,184] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-12 22:25:37,185] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-12 22:25:37,185] torch._dynamo.convert_frame: [WARNING]    function: 'call_rwkv_inner' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:377)
# [rank0]:[2024-02-12 22:25:37,185] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-12 22:25:37,185] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-12 22:25:37,185] torch._dynamo.convert_frame: [WARNING]    function: 'call_rwkv_inner' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:377)
# [rank2]:[2024-02-12 22:25:37,185] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-12 22:25:37,186] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-12 22:25:37,186] torch._dynamo.convert_frame: [WARNING]    function: 'call_rwkv_inner' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:377)
# [rank6]:[2024-02-12 22:25:37,186] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-12 22:25:37,187] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-12 22:25:37,187] torch._dynamo.convert_frame: [WARNING]    function: 'call_rwkv_inner' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:377)
# [rank1]:[2024-02-12 22:25:37,187] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# Epoch 0: 100%|██| 129/129 [27:53<00:00,  0.08it/s, v_num=963l, train/loss=5.030]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /usr/local/lib/python3.10/dist-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
#
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:12<00:00,  0.08it/s]
# Epoch 0: 100%|█| 129/129 [28:06<00:00,  0.08it/s, v_num=963l, train/loss=5.030, /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 4:   0%| | 0/129 [00:01<?, ?it/s, v_num=963l, train/loss=5.030, validation`Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4:   0%| | 0/129 [00:01<?, ?it/s, v_num=963l, train/loss=5.030, validation
# wandb: - 0.031 MB of 0.031 MB uploaded
# wandb: Run history:
# wandb:                        batchidx ▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:                           epoch ▁▁▁
# wandb:                     global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      perf/kTokens_per_sec.gpu.0 ▁▁▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█████
# wandb: perf/kTokens_per_sec_step.gpu.0 ▁█▇█████████████████████████████████████
# wandb:        perf/kTokens_total.gpu.0 ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                         substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:               train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/data_loss █▇▅▅▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                train/learn_loss █▇▅▅▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                      train/loss █▁
# wandb:             trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:           trainer/learning_rate ███████████▇▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▂▂▂▁▁
# wandb:          validation/data_ctxlen ▁
# wandb:            validation/data_loss ▁
# wandb:           validation/learn_loss ▁
# wandb:         validation/learn_tokens ▁
# wandb:                 validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                        batchidx 0
# wandb:                           epoch 0
# wandb:                     global_rank 0
# wandb:      perf/kTokens_per_sec.gpu.0 40.18764
# wandb: perf/kTokens_per_sec_step.gpu.0 16.24347
# wandb:        perf/kTokens_total.gpu.0 67239.936
# wandb:                         substep 1024
# wandb:               train/data_ctxlen 4096.0
# wandb:                 train/data_loss 5.03125
# wandb:                train/learn_loss 5.03125
# wandb:              train/learn_tokens 4095.75
# wandb:                      train/loss 5.25
# wandb:             trainer/global_step 128
# wandb:           trainer/learning_rate 0.00082
# wandb:          validation/data_ctxlen 16383
# wandb:            validation/data_loss 4.9375
# wandb:           validation/learn_loss 4.9375
# wandb:         validation/learn_tokens 327660
# wandb:                 validation/loss 4.94141
# wandb:
# wandb: 🚀 View run Baseline-OLR - L32-D512 (tctxlen=2048, deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/bgb8963l
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzODg4MTQxOA==/version_details/v11
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240212_215742-bgb8963l/logs
