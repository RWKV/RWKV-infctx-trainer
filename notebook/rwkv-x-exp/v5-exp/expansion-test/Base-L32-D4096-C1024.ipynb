# %% [markdown]
# # Eagle 7B : Training on 1 more Trillion tokens!

# %%
# -----------------------------------------------------------------
# Your configurable settings
# -----------------------------------------------------------------

# WANDB settings
ENABLE_WANDB=True
WANDB_PREFIX="Baseline"
WANDB_PROJECT="RWKV-x-v5-Expansion-Test"

# Project directory offset (you need to modify if, you move the notebook into another dir)
PROJECT_DIR_OFFSET="../../../../"

# GPU count to use
GPU_DEVICES="auto"

# -----------------------------------------------------------------
# Training settings you can use to override the "auto" default above
# -----------------------------------------------------------------
DEEPSPEED_STRAT="deepspeed_stage_2"
TRAINING_CTX_LEN=1024
MICROBATCH_SIZE=8

# -----------------------------------------------------------------
# Model settings
# -----------------------------------------------------------------
LAYER_COUNT=32
DIM_SIZE=4096

# ---
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("TRAINING_CTX_LEN:", TRAINING_CTX_LEN)
if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, PROJECT_DIR_OFFSET))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Check if the directory exists
if not os.path.exists(TRAINER_DIR):
    raise Exception("The trainer directory does not exists. Did you move the notebook?")
# Out:
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# DEEPSPEED_STRAT: deepspeed_stage_2
# TRAINING_CTX_LEN: 1024
# NOTEBOOK_DIR: /workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test
# TRAINER_DIR: /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/picocreator/RWKV-infctx-trainer

# %% [markdown]
# ## Init the empty model

# %%
# Lets initialized the various models, and their sizes
# !cd "{TRAINER_DIR}" && python3 init_model.py \
    --n_layer {LAYER_COUNT} --n_embd {DIM_SIZE} \
    --vocab_size world \
    --skip-if-exists --safe-init \
    ../model/L{LAYER_COUNT}-D{DIM_SIZE}-world-init.pth
# Out:
# [2024-02-11 22:20:50,325] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# ---- Initializing model ----
# No of layers: 32
# Embedding size: 4096
# Output model path: ../model/L32-D4096-world-init.pth
# Vocab size: 65536
# Emb scale: 0.0001
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Output model exists, skipping init_model

# %% [markdown]
# ## Start the training run!

# %%
# Setup the checkpoint dir
# !cd "{PROJECT_DIR}" && mkdir -p "/checkpoint/v5-expansion-test/baseline/L{LAYER_COUNT}-D{DIM_SIZE}-C{TRAINING_CTX_LEN}/"

# Lets start the training
# !cd "{TRAINER_DIR}" && \
    export RWKV_NO_CUDA=1 && \
    export RWKV_TORCH_COMPILE=1 && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki-100k-world-16k-rechunk.yaml" \
        --model.load_model="../model/L{LAYER_COUNT}-D{DIM_SIZE}-world-init.pth" \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="/checkpoint/v5-expansion-test/baseline/L{LAYER_COUNT}-D{DIM_SIZE}-C{TRAINING_CTX_LEN}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - L{LAYER_COUNT}-D{DIM_SIZE} (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-11 22:20:55,084] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/L32-D4096-world-init.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/baseline/L32-D4096-C1024/', '--trainer.logger.init_args.name=Baseline - L32-D4096 (tctxlen=1024, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=8', '--model.ctx_len=1024', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/L32-D4096-world-init.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/baseline/L32-D4096-C1024/', '--trainer.logger.init_args.name=Baseline - L32-D4096 (tctxlen=1024, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=8', '--model.ctx_len=1024', '--trainer.devices=auto'].
# Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         8
#    - accumulate_grad_batches: 4
#    - effective_batch_size:    256
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-11 22:21:44,229] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 22:21:44,497] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 22:21:44,600] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 22:21:44,938] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 22:21:44,939] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 22:21:44,951] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 22:21:45,001] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [RWKV.model][WARNING] - torch.compile is enabled, but this has been observed to perform worse, or even crash in some setup. Ensure to test if you actually measure speedups over JIT before using for large training runs'
# [RWKV.model] Running RWKV infctx using 'torch-compile' with torch '2.1.1+cu121'
# [rank: 4] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 6] Seed set to 3941088705
# [rank: 5] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in ./wandb/run-20240211_222248-u3m63ykz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Baseline - L32-D4096 (tctxlen=1024, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/u3m63ykz
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  3.000e-05 (3e-05)
#     - lr_final: 3.000e-05 (3e-05)
#
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.04764914512634277 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1013028621673584 seconds
# Time to load fused_adam op: 0.10121011734008789 seconds
# Time to load fused_adam op: 0.1012122631072998 seconds
# Time to load fused_adam op: 0.1011197566986084 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10141754150390625 seconds
# Time to load fused_adam op: 0.1014401912689209 seconds
# Time to load fused_adam op: 0.10150146484375 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 268 M
# 1 | blocks | ModuleList | 7.0 B
# 2 | ln_out | LayerNorm  | 8.2 K
# 3 | head   | Linear     | 268 M
# --------------------------------------
# 7.5 B     Trainable params
# 0         Non-trainable params
# 7.5 B     Total params
# 30,072.177Total estimated model params size (MB)
# Epoch 0:   0%|                                          | 0/513 [00:00<?, ?it/s][rank6]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank6]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank1]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank4]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank3]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank5]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank0]:[2024-02-11 22:27:43,488] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-11 22:27:43,489] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-11 22:27:43,489] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank7]:[2024-02-11 22:27:43,489] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-11 22:27:43,489] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-11 22:27:43,489] torch._dynamo.convert_frame: [WARNING]    function: 'forward_attention' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:109)
# [rank2]:[2024-02-11 22:27:43,489] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-11 22:27:45,116] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-11 22:27:45,116] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank3]:[2024-02-11 22:27:45,116] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-11 22:27:45,183] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-11 22:27:45,183] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank6]:[2024-02-11 22:27:45,183] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-11 22:27:45,190] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-11 22:27:45,190] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank0]:[2024-02-11 22:27:45,190] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-11 22:27:45,219] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-11 22:27:45,219] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank1]:[2024-02-11 22:27:45,219] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-11 22:27:45,941] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-11 22:27:45,941] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank4]:[2024-02-11 22:27:45,941] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-11 22:27:46,013] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-11 22:27:46,013] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank5]:[2024-02-11 22:27:46,013] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-11 22:27:46,350] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-11 22:27:46,350] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank7]:[2024-02-11 22:27:46,350] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-11 22:27:46,637] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-11 22:27:46,637] torch._dynamo.convert_frame: [WARNING]    function: 'forward_ffn' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:120)
# [rank2]:[2024-02-11 22:27:46,637] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# Epoch 0:   0%| | 1/513 [07:59<68:13:20,  0.00it/s, v_num=3ykz, train/loss=11.10][rank4]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank4]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank5]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank1]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank3]:[2024-02-11 22:31:36,753] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-11 22:31:36,754] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-11 22:31:36,754] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank2]:[2024-02-11 22:31:36,754] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-11 22:31:36,754] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-11 22:31:36,754] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank0]:[2024-02-11 22:31:36,754] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-11 22:31:36,755] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-11 22:31:36,755] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank6]:[2024-02-11 22:31:36,755] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-11 22:31:36,757] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-11 22:31:36,757] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:273)
# [rank7]:[2024-02-11 22:31:36,757] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-11 22:31:38,298] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-11 22:31:38,298] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank3]:[2024-02-11 22:31:38,298] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-11 22:31:38,311] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-11 22:31:38,311] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank4]:[2024-02-11 22:31:38,311] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-11 22:31:38,312] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-11 22:31:38,312] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank5]:[2024-02-11 22:31:38,312] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-11 22:31:38,350] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-11 22:31:38,350] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank2]:[2024-02-11 22:31:38,350] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-11 22:31:38,521] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-11 22:31:38,521] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank0]:[2024-02-11 22:31:38,521] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-11 22:31:38,647] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-11 22:31:38,647] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank7]:[2024-02-11 22:31:38,647] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-11 22:31:39,529] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-11 22:31:39,529] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank1]:[2024-02-11 22:31:39,529] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-11 22:31:39,533] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-11 22:31:39,533] torch._dynamo.convert_frame: [WARNING]    function: 'forward' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/ChannelMix.py:34)
# [rank6]:[2024-02-11 22:31:39,533] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank6]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank6]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank6]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank5]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank5]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank5]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank2]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank2]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank2]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank1]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank1]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank1]:[2024-02-11 22:35:06,877] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank7]:[2024-02-11 22:35:06,878] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank7]:[2024-02-11 22:35:06,878] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank7]:[2024-02-11 22:35:06,878] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank4]:[2024-02-11 22:35:06,878] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank4]:[2024-02-11 22:35:06,878] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank4]:[2024-02-11 22:35:06,878] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank3]:[2024-02-11 22:35:06,879] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank3]:[2024-02-11 22:35:06,879] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank3]:[2024-02-11 22:35:06,879] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [rank0]:[2024-02-11 22:35:06,881] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
# [rank0]:[2024-02-11 22:35:06,881] torch._dynamo.convert_frame: [WARNING]    function: '_forward_nocuda_optimized' (/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/TimeMix.py:320)
# [rank0]:[2024-02-11 22:35:06,881] torch._dynamo.convert_frame: [WARNING] to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# Epoch 0:  68%|▋| 350/513 [2:14:18<1:02:32,  0.04it/s, v_num=3ykz, train/loss=7.0
