# %% [markdown]
# # Eagle 7B : Training on 1 more Trillion tokens!

# %%
# -----------------------------------------------------------------
# Your configurable settings
# -----------------------------------------------------------------

# WANDB settings
ENABLE_WANDB=True
WANDB_PREFIX="Baseline"
WANDB_PROJECT="RWKV-x-v5-Expansion-Test"

# Project directory offset (you need to modify if, you move the notebook into another dir)
PROJECT_DIR_OFFSET="../../../../"

# GPU count to use
GPU_DEVICES="auto"

# -----------------------------------------------------------------
# Training settings you can use to override the "auto" default above
# -----------------------------------------------------------------
DEEPSPEED_STRAT="deepspeed_stage_2"
TRAINING_CTX_LEN=4096
MICROBATCH_SIZE=8

# -----------------------------------------------------------------
# Model settings
# -----------------------------------------------------------------
LAYER_COUNT=32
DIM_SIZE=4096

# ---
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("TRAINING_CTX_LEN:", TRAINING_CTX_LEN)
if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, PROJECT_DIR_OFFSET))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Check if the directory exists
if not os.path.exists(TRAINER_DIR):
    raise Exception("The trainer directory does not exists. Did you move the notebook?")
# Out:
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# DEEPSPEED_STRAT: deepspeed_stage_2
# TRAINING_CTX_LEN: 4096
# NOTEBOOK_DIR: /workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test
# TRAINER_DIR: /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/picocreator/RWKV-infctx-trainer

# %% [markdown]
# ## Init the empty model

# %%
# Lets initialized the various models, and their sizes
# !cd "{TRAINER_DIR}" && python3 init_model.py \
    --n_layer {LAYER_COUNT} --n_embd {DIM_SIZE} \
    --vocab_size world \
    --skip-if-exists --safe-init \
    ../model/L{LAYER_COUNT}-D{DIM_SIZE}-world-init.pth
# Out:
# [2024-02-11 09:31:11,758] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# ---- Initializing model ----
# No of layers: 32
# Embedding size: 4096
# Output model path: ../model/L32-D4096-world-init.pth
# Vocab size: 65536
# Emb scale: 0.0001
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Model exists, skipping init_model

# %% [markdown]
# ## Start the training run!

# %%
# Setup the checkpoint dir
# !cd "{PROJECT_DIR}" && mkdir -p "/checkpoint/v5-expansion-test/baseline/L{LAYER_COUNT}-D{DIM_SIZE}/"

# Lets start the training
# !cd "{TRAINER_DIR}" && \
    export RWKV_NO_CUDA=1 && \
    export RWKV_TORCH_COMPILE=0 && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki-100k-world-16k-rechunk.yaml" \
        --model.load_model="../model/L{LAYER_COUNT}-D{DIM_SIZE}-world-init.pth" \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="/checkpoint/v5-expansion-test/baseline/L{LAYER_COUNT}-D{DIM_SIZE}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - L{LAYER_COUNT}-D{DIM_SIZE} (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-11 17:57:34,033] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/L32-D4096-world-init.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/baseline/L32-D4096/', '--trainer.logger.init_args.name=Baseline - L32-D4096 (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/rwkv-x-exp/v5-exp/expansion-test/config/enwiki-100k-world-16k-rechunk.yaml', '--model.load_model=../model/L32-D4096-world-init.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=/checkpoint/v5-expansion-test/baseline/L32-D4096/', '--trainer.logger.init_args.name=Baseline - L32-D4096 (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-x-v5-Expansion-Test', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'].
# Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       256
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         8
#    - accumulate_grad_batches: 4
#    - effective_batch_size:    256
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-11 17:58:18,863] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 17:58:18,890] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 17:58:18,893] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 17:58:18,942] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 17:58:18,957] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 17:58:19,023] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-11 17:58:19,059] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [rank: 6] Seed set to 3941088705
# [rank: 5] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 3941088705
# [rank: 7] Seed set to 3941088705
# [rank: 2] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in ./wandb/run-20240211_175937-ssp9wa98
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Baseline - L32-D4096 (tctxlen=4096, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/ssp9wa98
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:639: Checkpoint directory /checkpoint/v5-expansion-test/baseline/L32-D4096 exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  3.000e-05 (3e-05)
#     - lr_final: 3.000e-05 (3e-05)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.05401325225830078 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10153627395629883 seconds
# Time to load fused_adam op: 0.10130190849304199 seconds
# Time to load fused_adam op: 0.10145926475524902 seconds
# Loading extension module fused_adam...
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10180950164794922 seconds
# Time to load fused_adam op: 0.10173749923706055 seconds
# Time to load fused_adam op: 0.10169696807861328 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10195064544677734 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 268 M
# 1 | blocks | ModuleList | 7.0 B
# 2 | ln_out | LayerNorm  | 8.2 K
# 3 | head   | Linear     | 268 M
# --------------------------------------
# 7.5 B     Trainable params
# 0         Non-trainable params
# 7.5 B     Total params
# 30,072.177Total estimated model params size (MB)
# Epoch 0: 100%|█| 513/513 [3:21:18<00:00,  0.04it/s, v_num=wa98, train/loss=6.000
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:06<00:12,  0.16it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:12<00:06,  0.16it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:18<00:00,  0.17it/s]
# Epoch 0: 100%|█| 513/513 [3:21:36<00:00,  0.04it/s, v_num=wa98, train/loss=6.000/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 1: 100%|█| 513/513 [3:19:58<00:00,  0.04it/s, v_num=wa98, train/loss=4.880
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:06<00:12,  0.16it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:12<00:06,  0.16it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:16<00:00,  0.19it/s]
# Epoch 2: 100%|█| 513/513 [3:20:01<00:00,  0.04it/s, v_num=wa98, train/loss=4.310
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:06<00:12,  0.16it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:12<00:06,  0.16it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:16<00:00,  0.19it/s]
# Epoch 3: 100%|█| 513/513 [3:20:12<00:00,  0.04it/s, v_num=wa98, train/loss=3.920
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:06<00:12,  0.16it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:12<00:06,  0.16it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:16<00:00,  0.18it/s]
# Epoch 4: 100%|█| 513/513 [3:20:23<00:00,  0.04it/s, v_num=wa98, train/loss=3.660
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|██████▋             | 1/3 [00:06<00:12,  0.16it/s]
# Validation DataLoader 0:  67%|█████████████▎      | 2/3 [00:12<00:06,  0.16it/s]
# Validation DataLoader 0: 100%|████████████████████| 3/3 [00:16<00:00,  0.18it/s]
# Epoch 4: 100%|█| 513/513 [3:20:39<00:00,  0.04it/s, v_num=wa98, train/loss=3.660`Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|█| 513/513 [3:23:49<00:00,  0.04it/s, v_num=wa98, train/loss=3.660
# wandb: - 0.021 MB of 0.029 MB uploaded
# wandb: Run history:
# wandb:                   batchidx ▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█
# wandb:                      epoch ▁▁▁▃▃▃▃▅▅▅▆▆▆▆███
# wandb:                global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/kTokens_per_sec.gpu.0 ███▇▇▇██▁▂▃▃▄▅▅▅▂▂▃▃▃▄▄▄▂▃▃▃▃▄▄▄▂▃▃▃▃▃▄▄
# wandb:   perf/kTokens_total.gpu.0 ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                    substep ▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█▁▂▃▄▅▆▇█
# wandb:          train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            train/data_loss █▆▆▆▆▅▅▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁
# wandb:           train/learn_loss █▆▆▆▆▅▅▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁
# wandb:         train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/loss █▇▄▄▃▃▂▂▁▁▁▁
# wandb:        trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      trainer/learning_rate ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:     validation/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       validation/data_loss ███▄▄▄▃▃▃▂▂▂▁▁▁
# wandb:      validation/learn_loss ███▄▄▄▃▃▃▂▂▂▁▁▁
# wandb:    validation/learn_tokens ██▁██▁██▁██▁██▁
# wandb:            validation/loss █▄▃▂▁
# wandb:
# wandb: Run summary:
# wandb:                   batchidx 2
# wandb:                      epoch 4
# wandb:                global_rank 0
# wandb: perf/kTokens_per_sec.gpu.0 5.51027
# wandb:   perf/kTokens_total.gpu.0 336199.68
# wandb:                    substep 4096
# wandb:          train/data_ctxlen 16384.0
# wandb:            train/data_loss 3.65625
# wandb:           train/learn_loss 3.65625
# wandb:         train/learn_tokens 16383.0
# wandb:                 train/loss 3.70312
# wandb:        trainer/global_step 640
# wandb:      trainer/learning_rate 3e-05
# wandb:     validation/data_ctxlen 16383
# wandb:       validation/data_loss 3.71875
# wandb:      validation/learn_loss 3.71875
# wandb:    validation/learn_tokens 65532
# wandb:            validation/loss 3.66953
# wandb:
# wandb: 🚀 View run Baseline - L32-D4096 (tctxlen=4096, deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/runs/ssp9wa98
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-x-v5-Expansion-Test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzODg4MTQxOA==/version_details/v10
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240211_175937-ssp9wa98/logs
