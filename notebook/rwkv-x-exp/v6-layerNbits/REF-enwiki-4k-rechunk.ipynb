# %% [markdown]
# # Reference Runs
#
# Starting from scratch

# %%
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="REF-"

print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v6/"))


print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Baseline layer count, and embedding size
L_SIZE=6
D_SIZE=512

# Deepspeed and batch size
DEEPSPEED_STAGE="deepspeed_stage_2"
BATCH_SIZE=4
# Out:
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits
# TRAINER_DIR: /home/recursal/RWKV-infctx-trainer/RWKV-v6
# PROJECT_DIR: /home/recursal/RWKV-infctx-trainer

# %% [markdown]
# # Dataset preloading

# %%
# Lets preload the requried dataset 
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/config/enwiki_100k-world-4k-rechunk.yaml"
# Out:
# Map (num_proc=160): 100%|███| 1000000/1000000 [00:37<00:00, 26659.45 examples/s]
# Filter (num_proc=160): 100%|█| 1000000/1000000 [00:06<00:00, 149382.73 examples/
# Map (num_proc=160): 100%|█████| 472276/472276 [00:24<00:00, 19407.40 examples/s]
# Map (num_proc=160): 100%|██████| 124119/124119 [00:20<00:00, 5977.08 examples/s]
# Saving the dataset (7/7 shards): 100%|█| 124119/124119 [00:03<00:00, 39297.29 ex
# Saving the dataset (1/1 shards): 100%|█| 100/100 [00:00<00:00, 4449.34 examples/

# %% [markdown]
# # L6-D512 , 4k reference run

# %%
# Baseline layer count, and embedding size
L_SIZE=6
D_SIZE=512

# Init the model
# !cd "{TRAINER_DIR}" && \
    python3 ./init_model.py \
        --n_layer {L_SIZE} --n_embd {D_SIZE} \
        --vocab_size world --skip-if-exists \
        "../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth"
# !ls -lh "{TRAINER_DIR}/../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth"
# Out:
# [2024-04-22 04:40:33,925] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ---- Initializing model ----
# No of layers: 6
# Embedding size: 512
# Output model path: ../model/L6-D512-world-v6base-init.pth
# Vocab size: 65536
# Emb scale: 0.0001
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Output model exists, skipping init_model
# -rw-rw-r-- 1 recursal recursal 170M Apr 22 02:46 /home/recursal/RWKV-infctx-trainer/RWKV-v6/../model/L6-D512-world-v6base-init.pth

# %%
# Learning rate setting
LR_INIT="4e-3"
LR_FINAL="4e-4"

# Nuke python3 (for back to back run cleanup)
# !killall -9 python3

# Run with the LRX setting
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_100k-world-32k-rechunk.yaml" \
        --model.load_model="../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth" \
        --model.lr_init="{LR_INIT}" \
        --model.lr_final="{LR_FINAL}" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v6-enwiki-100k-L{L_SIZE}-D{D_SIZE}-LRI-{LR_INIT}-LRF-{LR_FINAL}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX}L{L_SIZE}-D{D_SIZE},LRI-{LR_INIT},LRF-{LR_FINAL} (Rechunk 4k, {DEEPSPEED_STAGE})" \
        --trainer.strategy="{DEEPSPEED_STAGE}" \
        --trainer.microbatch_size={BATCH_SIZE} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# python3: no process found
# [2024-04-22 04:43:57,095] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L6-D512-world-v6base-init.pth', '--model.lr_init=3e-4', '--model.lr_final=3e-4', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L6-D512-LRI-3e-4-LRF-3e-4/', '--trainer.logger.init_args.name=REF-L6-D512,LRI-3e-4,LRF-3e-4 (Rechunk 4k, deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'], args=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L6-D512-world-v6base-init.pth', '--model.lr_init=3e-4', '--model.lr_final=3e-4', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L6-D512-LRI-3e-4-LRF-3e-4/', '--trainer.logger.init_args.name=REF-L6-D512,LRI-3e-4,LRF-3e-4 (Rechunk 4k, deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         4
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    32
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-04-22 04:44:02,134] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 04:44:02,135] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 04:44:02,143] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 04:44:02,147] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 04:44:02,184] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 04:44:02,405] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 04:44:02,421] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [rank: 2] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 3941088705
# [rank: 6] Seed set to 3941088705
# [rank: 4] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240422_044413-gupq1fpe
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run REF-L6-D512,LRI-3e-4,LRF-3e-4 (Rechunk 4k, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/gupq1fpe
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  3.000e-04 (0.0003)
#     - lr_final: 3.000e-04 (0.0003)
#
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/recursal/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06667375564575195 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...Loading extension module fused_adam...
#
# Loading extension module fused_adam...
# Loading extension module fused_adam...Loading extension module fused_adam...
#
# Time to load fused_adam op: 0.10187530517578125 seconds
# Time to load fused_adam op: 0.10193991661071777 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10231685638427734 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.1020658016204834 seconds
# Time to load fused_adam op: 0.10183835029602051 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10230135917663574 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10312128067016602 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 21.9 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 89.0 M    Trainable params
# 0         Non-trainable params
# 89.0 M    Total params
# 355.934   Total estimated model params size (MB)
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:104: Total length of `DataLoader` across ranks is zero. Please make sure this was your intention.
# Epoch 0:  32%|▋ | 100/313 [05:22<11:27,  0.31it/s, v_num=1fpe, train/loss=5.690]/home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|██| 313/313 [16:43<00:00,  0.31it/s, v_num=1fpe, train/loss=4.810]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██| 313/313 [16:43<00:00,  0.31it/s, v_num=1fpe, train/loss=4.810]
# wandb: | 0.032 MB of 0.032 MB uploaded
# wandb: Run history:
# wandb:                   batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                      epoch ▁▁▁▁▁▁
# wandb:                global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/kTokens_per_sec.gpu.0 ▁▄▆▇▇▇▇█████████████████████████████████
# wandb:   perf/kTokens_total.gpu.0 ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                    substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            train/data_loss █▇▅▄▄▃▃▃▄▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           train/learn_loss █▇▅▄▄▃▃▃▄▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/loss █▅▃▂▂▁
# wandb:        trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      trainer/learning_rate ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                   batchidx 312
# wandb:                      epoch 0
# wandb:                global_rank 0
# wandb: perf/kTokens_per_sec.gpu.0 40.89596
# wandb:   perf/kTokens_total.gpu.0 41025.536
# wandb:                    substep 2496
# wandb:          train/data_ctxlen 32768.0
# wandb:            train/data_loss 4.8125
# wandb:           train/learn_loss 4.8125
# wandb:         train/learn_tokens 32768.0
# wandb:                 train/loss 4.75
# wandb:        trainer/global_step 312
# wandb:      trainer/learning_rate 0.0003
# wandb:
# wandb: 🚀 View run REF-L6-D512,LRI-3e-4,LRF-3e-4 (Rechunk 4k, deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/gupq1fpe
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE2NTE5NDM4NA==/version_details/v0
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240422_044413-gupq1fpe/logs

# %% [markdown]
# # L12-D512 , 4k reference run

# %%
# Baseline layer count, and embedding size
L_SIZE=12
D_SIZE=512

# Init the model
# !cd "{TRAINER_DIR}" && \
    python3 ./init_model.py \
        --n_layer {L_SIZE} --n_embd {D_SIZE} \
        --vocab_size world --skip-if-exists \
        "../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth"
# !ls -lh "{TRAINER_DIR}/../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth"
# Out:
# [2024-04-22 05:01:13,034] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ---- Initializing model ----
# No of layers: 12
# Embedding size: 512
# Output model path: ../model/L12-D512-world-v6base-init.pth
# Vocab size: 65536
# Emb scale: 0.0001
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Output model exists, skipping init_model
# -rw-rw-r-- 1 recursal recursal 212M Apr 21 06:13 /home/recursal/RWKV-infctx-trainer/RWKV-v6/../model/L12-D512-world-v6base-init.pth

# %%
# Learning rate setting
LR_INIT="4e-3"
LR_FINAL="4e-4"

# Nuke python3 (for back to back run cleanup)
# !killall -9 python3

# Run with the LRX setting
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_100k-world-32k-rechunk.yaml" \
        --model.load_model="../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth" \
        --model.lr_init="{LR_INIT}" \
        --model.lr_final="{LR_FINAL}" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v6-enwiki-100k-L{L_SIZE}-D{D_SIZE}-LRI-{LR_INIT}-LRF-{LR_FINAL}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX}L{L_SIZE}-D{D_SIZE},LRI-{LR_INIT},LRF-{LR_FINAL} (Rechunk 4k, {DEEPSPEED_STAGE})" \
        --trainer.strategy="{DEEPSPEED_STAGE}" \
        --trainer.microbatch_size={BATCH_SIZE} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# python3: no process found
# [2024-04-22 05:01:17,643] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--model.lr_init=3e-4', '--model.lr_final=3e-4', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-LRI-3e-4-LRF-3e-4/', '--trainer.logger.init_args.name=REF-L12-D512,LRI-3e-4,LRF-3e-4 (Rechunk 4k, deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'], args=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--model.lr_init=3e-4', '--model.lr_final=3e-4', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-LRI-3e-4-LRF-3e-4/', '--trainer.logger.init_args.name=REF-L12-D512,LRI-3e-4,LRF-3e-4 (Rechunk 4k, deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         4
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    32
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-04-22 05:01:23,086] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 05:01:23,102] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 05:01:23,125] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 05:01:23,128] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 05:01:23,199] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 05:01:23,345] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-22 05:01:23,348] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [rank: 6] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# [rank: 4] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240422_050141-uk1oa454
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run REF-L12-D512,LRI-3e-4,LRF-3e-4 (Rechunk 4k, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/uk1oa454
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  3.000e-04 (0.0003)
#     - lr_final: 3.000e-04 (0.0003)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/recursal/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.0727388858795166 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...Loading extension module fused_adam...
#
# Time to load fused_adam op: 0.1018533706665039 seconds
# Loading extension module fused_adam...
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10188031196594238 seconds
# Loading extension module fused_adam...
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10213375091552734 seconds
# Time to load fused_adam op: 0.1021413803100586 secondsTime to load fused_adam op: 0.1022329330444336 seconds
#
# Time to load fused_adam op: 0.10202860832214355 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10210537910461426 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 43.7 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 110 M     Trainable params
# 0         Non-trainable params
# 110 M     Total params
# 443.425   Total estimated model params size (MB)
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:104: Total length of `DataLoader` across ranks is zero. Please make sure this was your intention.
# Epoch 0:  32%|▋ | 100/313 [08:02<17:08,  0.21it/s, v_num=a454, train/loss=5.690]/home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|██| 313/313 [25:06<00:00,  0.21it/s, v_num=a454, train/loss=4.810]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██| 313/313 [25:06<00:00,  0.21it/s, v_num=a454, train/loss=4.810]
# wandb: - 0.032 MB of 0.032 MB uploaded
# wandb: Run history:
# wandb:                   batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                      epoch ▁▁▁▁▁▁
# wandb:                global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/kTokens_per_sec.gpu.0 ▁▄▆▇▇▇▇█████████████████████████████████
# wandb:   perf/kTokens_total.gpu.0 ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                    substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            train/data_loss █▇▅▄▄▃▃▃▄▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           train/learn_loss █▇▅▄▄▃▃▃▄▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/loss █▅▃▂▂▁
# wandb:        trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      trainer/learning_rate ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                   batchidx 312
# wandb:                      epoch 0
# wandb:                global_rank 0
# wandb: perf/kTokens_per_sec.gpu.0 27.2405
# wandb:   perf/kTokens_total.gpu.0 41025.536
# wandb:                    substep 2496
# wandb:          train/data_ctxlen 32768.0
# wandb:            train/data_loss 4.8125
# wandb:           train/learn_loss 4.8125
# wandb:         train/learn_tokens 32768.0
# wandb:                 train/loss 4.71875
# wandb:        trainer/global_step 312
# wandb:      trainer/learning_rate 0.0003
# wandb:
# wandb: 🚀 View run REF-L12-D512,LRI-3e-4,LRF-3e-4 (Rechunk 4k, deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/uk1oa454
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE2NTE5NDM4NA==/version_details/v0
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240422_050141-uk1oa454/logs
