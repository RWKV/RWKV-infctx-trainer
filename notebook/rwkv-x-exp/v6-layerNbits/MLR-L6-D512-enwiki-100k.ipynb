# %% [markdown]
# # Mixes (Time & Channel) Layer Reuse test
#
# Starting from scratch

# %%
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="MLR-"

print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v6-TCLR/"))


print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Baseline layer count, and embedding size
L_SIZE=6
D_SIZE=512

# Deepspeed and batch size
DEEPSPEED_STAGE="deepspeed_stage_2"
BATCH_SIZE=4
# Out:
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits
# TRAINER_DIR: /home/recursal/RWKV-infctx-trainer/RWKV-v6-TCLR
# PROJECT_DIR: /home/recursal/RWKV-infctx-trainer

# %%
# Init the model
# !cd "{TRAINER_DIR}" && \
    python3 ./init_model.py \
        --n_layer {L_SIZE} --n_embd {D_SIZE} \
        --vocab_size world --skip-if-exists \
        "../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth"
# !ls -lh "{TRAINER_DIR}/../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth"
# Out:
# [2024-04-21 06:18:50,078] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# ---- Initializing model ----
# No of layers: 12
# Embedding size: 512
# Output model path: ../model/L12-D512-world-v6base-init.pth
# Vocab size: 65536
# Emb scale: 0.0001
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Output model exists, skipping init_model
# -rw-rw-r-- 1 recursal recursal 212M Apr 21 06:13 /home/recursal/RWKV-infctx-trainer/RWKV-v6-TCLR/../model/L12-D512-world-v6base-init.pth

# %% [markdown]
# # Dataset preloading

# %%
# Lets preload the requried dataset 
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/config/enwiki_100k-world-32k-rechunk.yaml"
# Out:
# Saving the dataset (4/4 shards): 100%|█| 10020/10020 [00:06<00:00, 1491.65 examp
# Saving the dataset (1/1 shards): 100%|████| 2/2 [00:00<00:00, 124.56 examples/s]

# %% [markdown]
# # Reference Run

# %%
# Configure the LRX experiment count
TLR_COUNT=1
CLR_COUNT=1

# Nuke python3 (for back to back run cleanup)
# !killall -9 python3

# Run with the LRX setting
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    export RWKV_TMIX_REUSE_MULTIPLIER="{TLR_COUNT}" && \
    export RWKV_CMIX_REUSE_MULTIPLIER="{CLR_COUNT}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_100k-world-32k-rechunk.yaml" \
        --model.load_model="../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v6-enwiki-100k-L{L_SIZE}-D{D_SIZE}-TLR{TLR_COUNT}-CLR{CLR_COUNT}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX}L{L_SIZE}-D{D_SIZE}, TLR={TLR_COUNT}, CLR={CLR_COUNT} (Rechunk 32k {DEEPSPEED_STAGE})" \
        --trainer.strategy="{DEEPSPEED_STAGE}" \
        --trainer.microbatch_size={BATCH_SIZE} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# python3: no process found
# [2024-04-21 08:51:21,934] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-TLR1-CLR1/', '--trainer.logger.init_args.name=TLR-L12-D512, TLR=1, CLR=1 (Rechunk 32k deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'], args=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-TLR1-CLR1/', '--trainer.logger.init_args.name=TLR-L12-D512, TLR=1, CLR=1 (Rechunk 32k deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         4
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    32
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-04-21 08:51:27,346] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 08:51:27,348] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 08:51:27,425] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 08:51:27,426] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 08:51:27,434] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 08:51:27,592] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 08:51:27,683] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 1
# [RWKV] CMIX reuse multiplier : 1
# ====================================================================
# [rank: 2] Seed set to 3941088705
# [rank: 1] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 3941088705
# [rank: 5] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 6] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished: >> Dataset load finished:   ../datapath/enwiki_100k-world-32k-rechunk/../datapath/enwiki_100k-world-32k-rechunk/
#
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240421_085145-8ytftnb1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run TLR-L12-D512, TLR=1, CLR=1 (Rechunk 32k deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/8ytftnb1
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:639: Checkpoint directory /home/recursal/RWKV-infctx-trainer/checkpoint/v6-enwiki-100k-L12-D512-TLR1-CLR1 exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 3.000e-04 (0.0003)
#
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/recursal/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06716036796569824 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Loading extension module fused_adam...
# Loading extension module fused_adam...Loading extension module fused_adam...
#
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10198593139648438 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1022195816040039 seconds
# Time to load fused_adam op: 0.1022806167602539 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam.../home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10217094421386719 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10251998901367188 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10288405418395996 seconds
# Time to load fused_adam op: 0.10277223587036133 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 43.7 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 110 M     Trainable params
# 0         Non-trainable params
# 110 M     Total params
# 443.425   Total estimated model params size (MB)
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:104: Total length of `DataLoader` across ranks is zero. Please make sure this was your intention.
# Epoch 0:  32%|▋ | 100/313 [07:59<17:00,  0.21it/s, v_num=tnb1, train/loss=5.410]/home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|██| 313/313 [24:53<00:00,  0.21it/s, v_num=tnb1, train/loss=4.620]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██| 313/313 [24:53<00:00,  0.21it/s, v_num=tnb1, train/loss=4.620]
# wandb: / 0.033 MB of 0.033 MB uploaded
# wandb: Run history:
# wandb:                   batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                      epoch ▁▁▁▁▁▁
# wandb:                global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/kTokens_per_sec.gpu.0 ▁▄▆▇▇▇▇█████████████████████████████████
# wandb:   perf/kTokens_total.gpu.0 ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                    substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            train/data_loss █▆▅▄▄▃▃▃▄▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           train/learn_loss █▆▅▄▄▃▃▃▄▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/loss █▅▃▂▂▁
# wandb:        trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      trainer/learning_rate ███████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                   batchidx 312
# wandb:                      epoch 0
# wandb:                global_rank 0
# wandb: perf/kTokens_per_sec.gpu.0 27.49008
# wandb:   perf/kTokens_total.gpu.0 41025.536
# wandb:                    substep 2496
# wandb:          train/data_ctxlen 32768.0
# wandb:            train/data_loss 4.625
# wandb:           train/learn_loss 4.625
# wandb:         train/learn_tokens 32768.0
# wandb:                 train/loss 4.53125
# wandb:        trainer/global_step 312
# wandb:      trainer/learning_rate 0.0003
# wandb:
# wandb: 🚀 View run TLR-L12-D512, TLR=1, CLR=1 (Rechunk 32k deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/8ytftnb1
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE2NDkwNzM3OA==/version_details/v2
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240421_085145-8ytftnb1/logs

# %% [markdown]
# # TLR=2, CLR=2

# %%
# Configure the LRX experiment count
TLR_COUNT=2
CLR_COUNT=2

# Nuke python3 (for back to back run cleanup)
# !killall -9 python3

# Run with the LRX setting
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    export RWKV_TMIX_REUSE_MULTIPLIER="{TLR_COUNT}" && \
    export RWKV_CMIX_REUSE_MULTIPLIER="{CLR_COUNT}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_100k-world-32k-rechunk.yaml" \
        --model.load_model="../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v6-enwiki-100k-L{L_SIZE}-D{D_SIZE}-TLR{TLR_COUNT}-CLR{CLR_COUNT}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX}L{L_SIZE}-D{D_SIZE}, TLR={TLR_COUNT}, CLR={CLR_COUNT} (Rechunk 32k {DEEPSPEED_STAGE})" \
        --trainer.strategy="{DEEPSPEED_STAGE}" \
        --trainer.microbatch_size={BATCH_SIZE} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# python3: no process found
# [2024-04-21 12:02:19,099] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 2
# [RWKV] CMIX reuse multiplier : 2
# ====================================================================
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-TLR2-CLR2/', '--trainer.logger.init_args.name=MLR-L12-D512, TLR=2, CLR=2 (Rechunk 32k deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'], args=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-TLR2-CLR2/', '--trainer.logger.init_args.name=MLR-L12-D512, TLR=2, CLR=2 (Rechunk 32k deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         4
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    32
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-04-21 12:02:24,502] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:02:24,518] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:02:24,528] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:02:24,534] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:02:24,536] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:02:24,715] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:02:24,891] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 2
# [RWKV] CMIX reuse multiplier : 2
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 2
# [RWKV] CMIX reuse multiplier : 2
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 2
# [RWKV] CMIX reuse multiplier : 2
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 2
# [RWKV] CMIX reuse multiplier : 2
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 2
# [RWKV] CMIX reuse multiplier : 2
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 2
# [RWKV] CMIX reuse multiplier : 2
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 2
# [RWKV] CMIX reuse multiplier : 2
# ====================================================================
# [rank: 7] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3941088705
# [rank: 1] Seed set to 3941088705
# [rank: 3] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 6] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 5] Seed set to 3941088705
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240421_120243-fk5twuea
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run MLR-L12-D512, TLR=2, CLR=2 (Rechunk 32k deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/fk5twuea
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 3.000e-04 (0.0003)
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
#
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/recursal/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.0640726089477539 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10212516784667969 seconds
# Loading extension module fused_adam...
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10223984718322754 seconds
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10288548469543457 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10338330268859863 seconds
# Time to load fused_adam op: 0.10347914695739746 seconds
# Time to load fused_adam op: 0.10330581665039062 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10455465316772461 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 21.9 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 89.0 M    Trainable params
# 0         Non-trainable params
# 89.0 M    Total params
# 355.983   Total estimated model params size (MB)
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:104: Total length of `DataLoader` across ranks is zero. Please make sure this was your intention.
# Epoch 0:  32%|▋ | 100/313 [07:28<15:55,  0.22it/s, v_num=wuea, train/loss=5.410]/home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|██| 313/313 [23:16<00:00,  0.22it/s, v_num=wuea, train/loss=4.690]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██| 313/313 [23:16<00:00,  0.22it/s, v_num=wuea, train/loss=4.690]
# wandb: | 0.032 MB of 0.032 MB uploaded
# wandb: Run history:
# wandb:                   batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                      epoch ▁▁▁▁▁▁
# wandb:                global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/kTokens_per_sec.gpu.0 ▁▄▆▇▇▇▇█████████████████████████████████
# wandb:   perf/kTokens_total.gpu.0 ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                    substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            train/data_loss █▆▅▄▄▃▃▃▄▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           train/learn_loss █▆▅▄▄▃▃▃▄▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/loss █▅▃▂▂▁
# wandb:        trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      trainer/learning_rate ███████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                   batchidx 312
# wandb:                      epoch 0
# wandb:                global_rank 0
# wandb: perf/kTokens_per_sec.gpu.0 29.38268
# wandb:   perf/kTokens_total.gpu.0 41025.536
# wandb:                    substep 2496
# wandb:          train/data_ctxlen 32768.0
# wandb:            train/data_loss 4.6875
# wandb:           train/learn_loss 4.6875
# wandb:         train/learn_tokens 32768.0
# wandb:                 train/loss 4.5625
# wandb:        trainer/global_step 312
# wandb:      trainer/learning_rate 0.0003
# wandb:
# wandb: 🚀 View run MLR-L12-D512, TLR=2, CLR=2 (Rechunk 32k deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/fk5twuea
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE2NDkwNzM3OA==/version_details/v2
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240421_120243-fk5twuea/logs

# %% [markdown]
# # TLR=4, CLR=4

# %%
# Configure the LRX experiment count
TLR_COUNT=4
CLR_COUNT=4

# Nuke python3 (for back to back run cleanup)
# !killall -9 python3

# Run with the LRX setting
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    export RWKV_TMIX_REUSE_MULTIPLIER="{TLR_COUNT}" && \
    export RWKV_CMIX_REUSE_MULTIPLIER="{CLR_COUNT}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_100k-world-32k-rechunk.yaml" \
        --model.load_model="../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v6-enwiki-100k-L{L_SIZE}-D{D_SIZE}-TLR{TLR_COUNT}-CLR{CLR_COUNT}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX}L{L_SIZE}-D{D_SIZE}, TLR={TLR_COUNT}, CLR={CLR_COUNT} (Rechunk 32k {DEEPSPEED_STAGE})" \
        --trainer.strategy="{DEEPSPEED_STAGE}" \
        --trainer.microbatch_size={BATCH_SIZE} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# python3: no process found
# [2024-04-21 12:26:15,031] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 4
# [RWKV] CMIX reuse multiplier : 4
# ====================================================================
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-TLR4-CLR4/', '--trainer.logger.init_args.name=MLR-L12-D512, TLR=4, CLR=4 (Rechunk 32k deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'], args=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-TLR4-CLR4/', '--trainer.logger.init_args.name=MLR-L12-D512, TLR=4, CLR=4 (Rechunk 32k deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         4
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    32
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-04-21 12:26:21,432] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:26:21,444] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:26:21,454] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:26:21,482] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:26:21,489] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:26:21,514] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:26:21,655] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 4
# [RWKV] CMIX reuse multiplier : 4
# ====================================================================
# ====================================================================
# [RWKV] TMIX reuse multiplier : 4
# [RWKV] CMIX reuse multiplier : 4
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 4
# [RWKV] CMIX reuse multiplier : 4
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 4
# [RWKV] CMIX reuse multiplier : 4
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 4
# [RWKV] CMIX reuse multiplier : 4
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 4
# [RWKV] CMIX reuse multiplier : 4
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 4
# [RWKV] CMIX reuse multiplier : 4
# ====================================================================
# [rank: 6] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 3941088705
# [rank: 5] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# [rank: 4] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 6] Seed set to 3941088705
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240421_122640-b5fzk9kd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run MLR-L12-D512, TLR=4, CLR=4 (Rechunk 32k deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/b5fzk9kd
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)#
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 3.000e-04 (0.0003)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/recursal/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06520652770996094 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...Time to load fused_adam op: 0.10260248184204102 seconds
#
# Time to load fused_adam op: 0.10248589515686035 seconds
# Loading extension module fused_adam...
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10237598419189453 seconds
# Time to load fused_adam op: 0.10254287719726562 secondsTime to load fused_adam op: 0.10288238525390625 seconds
#
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10299134254455566 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10454487800598145 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 11.0 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 78.1 M    Trainable params
# 0         Non-trainable params
# 78.1 M    Total params
# 312.263   Total estimated model params size (MB)
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:104: Total length of `DataLoader` across ranks is zero. Please make sure this was your intention.
# Epoch 0:  26%|▊  | 81/313 [05:43<16:23,  0.24it/s, v_num=k9kd, train/loss=5.690]
# Epoch 0:  32%|▋ | 100/313 [07:02<15:00,  0.24it/s, v_num=k9kd, train/loss=5.440]/home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|██| 313/313 [21:57<00:00,  0.24it/s, v_num=k9kd, train/loss=4.720]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██| 313/313 [21:57<00:00,  0.24it/s, v_num=k9kd, train/loss=4.720]
# wandb: / 0.032 MB of 0.032 MB uploaded
# wandb: Run history:
# wandb:                   batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                      epoch ▁▁▁▁▁▁
# wandb:                global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/kTokens_per_sec.gpu.0 ▁▄▆▇▇▇▇█████████████████████████████████
# wandb:   perf/kTokens_total.gpu.0 ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                    substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            train/data_loss █▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           train/learn_loss █▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/loss █▅▃▂▂▁
# wandb:        trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      trainer/learning_rate ███████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                   batchidx 312
# wandb:                      epoch 0
# wandb:                global_rank 0
# wandb: perf/kTokens_per_sec.gpu.0 31.15752
# wandb:   perf/kTokens_total.gpu.0 41025.536
# wandb:                    substep 2496
# wandb:          train/data_ctxlen 32768.0
# wandb:            train/data_loss 4.71875
# wandb:           train/learn_loss 4.71875
# wandb:         train/learn_tokens 32768.0
# wandb:                 train/loss 4.65625
# wandb:        trainer/global_step 312
# wandb:      trainer/learning_rate 0.0003
# wandb:
# wandb: 🚀 View run MLR-L12-D512, TLR=4, CLR=4 (Rechunk 32k deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/b5fzk9kd
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE2NDkwNzM3OA==/version_details/v2
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240421_122640-b5fzk9kd/logs

# %% [markdown]
# # TLR=6, CLR=6

# %%
# Configure the LRX experiment count
TLR_COUNT=6
CLR_COUNT=6

# Nuke python3 (for back to back run cleanup)
# !killall -9 python3

# Run with the LRX setting
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    export RWKV_TMIX_REUSE_MULTIPLIER="{TLR_COUNT}" && \
    export RWKV_CMIX_REUSE_MULTIPLIER="{CLR_COUNT}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_100k-world-32k-rechunk.yaml" \
        --model.load_model="../model/L{L_SIZE}-D{D_SIZE}-world-v6base-init.pth" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v6-enwiki-100k-L{L_SIZE}-D{D_SIZE}-TLR{TLR_COUNT}-CLR{CLR_COUNT}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX}L{L_SIZE}-D{D_SIZE}, TLR={TLR_COUNT}, CLR={CLR_COUNT} (Rechunk 32k {DEEPSPEED_STAGE})" \
        --trainer.strategy="{DEEPSPEED_STAGE}" \
        --trainer.microbatch_size={BATCH_SIZE} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# python3: no process found
# [2024-04-21 12:48:57,834] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 6
# [RWKV] CMIX reuse multiplier : 6
# ====================================================================
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-TLR6-CLR6/', '--trainer.logger.init_args.name=MLR-L12-D512, TLR=6, CLR=6 (Rechunk 32k deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'], args=['fit', '-c', '/home/recursal/RWKV-infctx-trainer/notebook/rwkv-x-exp/v6-layerNbits/config/enwiki_100k-world-32k-rechunk.yaml', '--model.load_model=../model/L12-D512-world-v6base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v6-enwiki-100k-L12-D512-TLR6-CLR6/', '--trainer.logger.init_args.name=MLR-L12-D512, TLR=6, CLR=6 (Rechunk 32k deepspeed_stage_2)', '--trainer.strategy=deepspeed_stage_2', '--trainer.microbatch_size=4', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         4
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    32
#
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-04-21 12:49:04,094] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:49:04,138] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:49:04,156] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:49:04,212] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:49:04,235] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:49:04,270] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-04-21 12:49:04,272] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 6
# [RWKV] CMIX reuse multiplier : 6
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 6
# [RWKV] CMIX reuse multiplier : 6
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 6
# [RWKV] CMIX reuse multiplier : 6
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 6
# [RWKV] CMIX reuse multiplier : 6
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 6
# [RWKV] CMIX reuse multiplier : 6
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 6
# [RWKV] CMIX reuse multiplier : 6
# ====================================================================
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# ====================================================================
# [RWKV] TMIX reuse multiplier : 6
# [RWKV] CMIX reuse multiplier : 6
# ====================================================================
# [rank: 1] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 6] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 3941088705
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 6] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 5] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 7] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 3] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 2] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# [rank: 4] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Loading dataset from data_path:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# >> Dataset load finished:  ../datapath/enwiki_100k-world-32k-rechunk/
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240421_124923-j308vyp5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run MLR-L12-D512, TLR=6, CLR=6 (Rechunk 32k deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/j308vyp5
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 3.000e-04 (0.0003)
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /home/recursal/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/recursal/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06354904174804688 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10190320014953613 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10254192352294922 seconds
# Time to load fused_adam op: 0.10297226905822754 seconds
# Time to load fused_adam op: 0.10252594947814941 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10348200798034668 seconds
# Loading extension module fused_adam...
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10314011573791504 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.10306382179260254 seconds
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 7.3 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 74.4 M    Trainable params
# 0         Non-trainable params
# 74.4 M    Total params
# 297.689   Total estimated model params size (MB)
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:104: Total length of `DataLoader` across ranks is zero. Please make sure this was your intention.
# Epoch 0:  32%|▋ | 100/313 [06:57<14:48,  0.24it/s, v_num=vyp5, train/loss=5.440]/home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /home/recursal/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|██| 313/313 [21:37<00:00,  0.24it/s, v_num=vyp5, train/loss=4.750]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██| 313/313 [21:37<00:00,  0.24it/s, v_num=vyp5, train/loss=4.750]
# wandb: | 0.032 MB of 0.032 MB uploaded
# wandb: Run history:
# wandb:                   batchidx ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                      epoch ▁▁▁▁▁▁
# wandb:                global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/kTokens_per_sec.gpu.0 ▁▄▆▇▇▇▇█████████████████████████████████
# wandb:   perf/kTokens_total.gpu.0 ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                    substep ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          train/data_ctxlen ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            train/data_loss █▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           train/learn_loss █▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/learn_tokens ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                 train/loss █▅▃▂▂▁
# wandb:        trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      trainer/learning_rate ███████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                   batchidx 312
# wandb:                      epoch 0
# wandb:                global_rank 0
# wandb: perf/kTokens_per_sec.gpu.0 31.64254
# wandb:   perf/kTokens_total.gpu.0 41025.536
# wandb:                    substep 2496
# wandb:          train/data_ctxlen 32768.0
# wandb:            train/data_loss 4.75
# wandb:           train/learn_loss 4.75
# wandb:         train/learn_tokens 32768.0
# wandb:                 train/loss 4.6875
# wandb:        trainer/global_step 312
# wandb:      trainer/learning_rate 0.0003
# wandb:
# wandb: 🚀 View run MLR-L12-D512, TLR=6, CLR=6 (Rechunk 32k deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/runs/j308vyp5
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-v6x-layerNbits/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjE2NDkwNzM3OA==/version_details/v2
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240421_124923-j308vyp5/logs
