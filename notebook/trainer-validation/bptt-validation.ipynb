# %% [markdown]
# # InfCtx trainer validation
#
# This model being trained is the small L6-D512 model with
# - Layer count: 6
# - Embed size: 512
#
# The goal is to validate loss rate change, across the exact same hyper parameters with the following
# - 1024 data chunk size
# - same learningrate / weightdecay / seed
# - "teven/enwiki_10k" dataset, chunked to 1024 token sizes
#
# With only the change in training context size
# - 1024 context vs 128 context chunks
#
# > This project assumes you have the rwkv-infctx conda env setup, and you are executing in that environment - see the main README.md for the conda env setup steps
# >
# > And that you have completed the `baseline-setup.ipynb`

# %% [markdown]
# ## Configure and apply your preferred settings
#
# Adjust your desired deepspeed settings, and gpu device count.
#
# Enable/Disable WANDB here as well ( Enabled by default, as we need the loss curve for this experiment )
#
# ( note you will need to rerun this cell, if you restart your env )

# %%
DEEPSPEED_STRAT="deepspeed_stage_1"
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="infctx-bptt-validation L6-D512"

print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"
# Out:
# DEEPSPEED_STRAT: deepspeed_stage_1
# ENABLE_WANDB: True
# GPU_DEVICES: auto

# %% [markdown]
# # Baseline full context (1024) training
#
# Perform a full 1 epoch training run of training context size = 1024. Ensuring all data samples fit within the allocated training size.

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c ../notebook/trainer-validation/config/L6-D512-neox-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (full, train-ctx=1024, data-ctx=1024, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0.dev20230705'
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230730_144328-7l9nnkus
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-bptt-validation L6-D512 (full, train-ctx=1024, data-ctx=1024, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/7l9nnkus
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=wkv_1024_bf16 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/TH -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 --compiler-options '-fPIC' -t 4 -std=c++17 -res-usage --maxrregcount 60 --use_fast_math -O3 -Xptxas -O3 --extra-device-vectorization -DTmax=1024 -c /home/ubuntu/RWKV-LM-LoRA-merge/RWKV-v4neo/cuda/wkv_cuda_bf16.cu -o wkv_cuda_bf16.cuda.o
# ptxas info    : 1 bytes gmem
# ptxas info    : Compiling entry function '_Z15kernel_backwardiiiPKfPKN3c108BFloat16ES4_S4_S0_S4_S0_PS2_S5_S5_S5_Pf' for 'sm_86'
# ptxas info    : Function properties for _Z15kernel_backwardiiiPKfPKN3c108BFloat16ES4_S4_S0_S4_S0_PS2_S5_S5_S5_Pf
#     12288 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 56 registers, 464 bytes cmem[0], 8 bytes cmem[2]
# ptxas info    : Compiling entry function '_Z14kernel_forwardiiiPKfPKN3c108BFloat16ES4_S4_S0_PS2_Pf' for 'sm_86'
# ptxas info    : Function properties for _Z14kernel_forwardiiiPKfPKN3c108BFloat16ES4_S4_S0_PS2_Pf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 40 registers, 424 bytes cmem[0]
# [2/3] c++ -MMD -MF wkv_op_bf16.o.d -DTORCH_EXTENSION_NAME=wkv_1024_bf16 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/TH -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -std=c++17 -O3 -DTmax=1024 -c /home/ubuntu/RWKV-LM-LoRA-merge/RWKV-v4neo/cuda/wkv_op_bf16.cpp -o wkv_op_bf16.o
# [3/3] c++ wkv_op_bf16.o wkv_cuda_bf16.cuda.o -shared -L/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o wkv_1024_bf16.so
# Loading extension module wkv_1024_bf16...
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    16
#
# Found cached dataset parquet (/home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 920.61it/s]
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-84967162f597a3d4_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-eed57f183fc2dcd0_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-b0500659c137c17a_*_of_00032.arrow
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-30 14:43:53,810] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  6.000e-04 (0.0006)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/csrc/includes -I/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/csrc/adam -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/TH -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 --compiler-options '-fPIC' -O3 -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -lineinfo --use_fast_math -gencode=arch=compute_86,code=sm_86 -gencode=arch=compute_86,code=compute_86 -DBF16_AVAILABLE -std=c++17 -c /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/csrc/adam/multi_tensor_adam.cu -o multi_tensor_adam.cuda.o
# [2/3] c++ -MMD -MF fused_adam_frontend.o.d -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/csrc/includes -I/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/csrc/adam -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/TH -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /home/ubuntu/anaconda3/envs/rwkv-exp/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -O3 -std=c++17 -g -Wno-reorder -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -DBF16_AVAILABLE -c /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/csrc/adam/fused_adam_frontend.cpp -o fused_adam_frontend.o
# [3/3] c++ fused_adam_frontend.o multi_tensor_adam.cuda.o -shared -L/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o fused_adam.so
# Loading extension module fused_adam...
# Time to load fused_adam op: 25.524582862854004 seconds
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1688541715909/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.06198287010192871 seconds
# Rank: 0 partition count [1, 1, 1] and sizes[(71960576, False), (3072, False), (3072, False)]
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005927085876464844 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 25.7 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 25.7 M
# --------------------------------------
# 72.0 M    Trainable params
# 0         Non-trainable params
# 72.0 M    Total params
# 287.867   Total estimated model params size (MB)
# Epoch 0: 100%|█| 5308/5308 [16:29<00:00,  5.36it/s, v_num=nkus, train/loss=5.940
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:00<00:11,  4.67it/s]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:00<00:11,  4.69it/s]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:00<00:10,  5.04it/s]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:00<00:09,  5.24it/s]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:00<00:09,  5.37it/s]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:01<00:08,  5.46it/s]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:01<00:08,  5.53it/s]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:01<00:08,  5.58it/s]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:01<00:08,  5.61it/s]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:01<00:07,  5.64it/s]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:01<00:07,  5.67it/s]
# Validation DataLoader 0:  22%|████              | 12/54 [00:02<00:07,  5.69it/s]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:02<00:07,  5.71it/s]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:02<00:06,  5.72it/s]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:02<00:06,  5.74it/s]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:02<00:06,  5.75it/s]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:02<00:06,  5.76it/s]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:03<00:06,  5.77it/s]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:03<00:06,  5.77it/s]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:03<00:05,  5.78it/s]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:03<00:05,  5.79it/s]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:03<00:05,  5.80it/s]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:03<00:05,  5.81it/s]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:04<00:05,  5.81it/s]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:04<00:04,  5.82it/s]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:04<00:04,  5.82it/s]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:04<00:04,  5.83it/s]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:04<00:04,  5.83it/s]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:04<00:04,  5.83it/s]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:05<00:04,  5.84it/s]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:05<00:03,  5.84it/s]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:05<00:03,  5.84it/s]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:05<00:03,  5.84it/s]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:05<00:03,  5.84it/s]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:05<00:03,  5.84it/s]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:06<00:03,  5.85it/s]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:06<00:02,  5.85it/s]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:06<00:02,  5.85it/s]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:06<00:02,  5.86it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:06<00:02,  5.86it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:06<00:02,  5.86it/s]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:07<00:02,  5.86it/s]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:07<00:01,  5.86it/s]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:07<00:01,  5.87it/s]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:07<00:01,  5.87it/s]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [00:07<00:01,  5.87it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [00:08<00:01,  5.87it/s]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [00:08<00:01,  5.87it/s]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [00:08<00:00,  5.87it/s]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [00:08<00:00,  5.87it/s]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [00:08<00:00,  5.87it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [00:08<00:00,  5.88it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [00:09<00:00,  5.88it/s]
# Epoch 0: 100%|█| 5308/5308 [16:41<00:00,  5.30it/s, v_num=nkus, train/loss=5.940
# Epoch 0: 100%|█| 5308/5308 [16:41<00:00,  5.30it/s, v_num=nkus, train/loss=5.940/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1825: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5308/5308 [16:42<00:00,  5.29it/s, v_num=nkus, train/loss=5.940
# wandb: Waiting for W&B process to finish... (success).
# wandb: - 0.005 MB of 0.005 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:            train/loss █▆▅▅▅▅▅▄▄▄▄▄▅▃▄▃▄▄▃▄▄▃▅▃▃▃▂▃▃▁▃▃▃▃▃▂▃▃▃▃
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 53
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 5.9375
# wandb:   trainer/global_step 331
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 5.63918
# wandb:
# wandb: 🚀 View run infctx-bptt-validation L6-D512 (full, train-ctx=1024, data-ctx=1024, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/7l9nnkus
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230730_144328-7l9nnkus/logs

# %% [markdown]
# # Back-Propagation Through Time (512) training
#
# Perform a full 1 epoch training run of training context size = 512. This is a less exegerated version of the 128 training

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c ../notebook/trainer-validation/config/L6-D512-neox-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (bptt, train-ctx=512, data-ctx=1024, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --model.bptt_learning="true" \
        --model.ctx_len=512
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0.dev20230705'
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230730_150124-eu7jqsi8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-bptt-validation L6-D512 (bptt, train-ctx=512, data-ctx=1024, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/eu7jqsi8
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_512_bf16/build.ninja...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    16
#
# Found cached dataset parquet (/home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 925.49it/s]
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-84967162f597a3d4_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-eed57f183fc2dcd0_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-b0500659c137c17a_*_of_00032.arrow
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-30 15:01:29,635] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:615: UserWarning: Checkpoint directory /home/ubuntu/RWKV-LM-LoRA-merge/checkpoint/trainer-validaiton/infctx-validation-baseline exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  6.000e-04 (0.0006)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.058930397033691406 seconds
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1688541715909/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.061491966247558594 seconds
# Rank: 0 partition count [1, 1, 1] and sizes[(71960576, False), (3072, False), (3072, False)]
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0006530284881591797 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 25.7 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 25.7 M
# --------------------------------------
# 72.0 M    Trainable params
# 0         Non-trainable params
# 72.0 M    Total params
# 287.867   Total estimated model params size (MB)
# Epoch 0: 100%|█| 5308/5308 [32:28<00:00,  2.72it/s, v_num=qsi8, train/loss=5.940
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:00<00:19,  2.65it/s]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:00<00:18,  2.83it/s]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:01<00:17,  2.90it/s]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:01<00:17,  2.93it/s]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:01<00:16,  2.95it/s]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:02<00:16,  2.97it/s]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:02<00:15,  2.98it/s]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:02<00:15,  2.98it/s]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:03<00:15,  2.99it/s]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:03<00:14,  2.99it/s]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:03<00:14,  3.00it/s]
# Validation DataLoader 0:  22%|████              | 12/54 [00:03<00:13,  3.00it/s]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:04<00:13,  3.00it/s]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:04<00:13,  3.00it/s]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:04<00:12,  3.01it/s]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:05<00:12,  3.01it/s]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:05<00:12,  3.01it/s]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:05<00:11,  3.01it/s]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:06<00:11,  3.01it/s]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:06<00:11,  3.01it/s]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:06<00:10,  3.02it/s]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:07<00:10,  3.02it/s]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:07<00:10,  3.02it/s]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:07<00:09,  3.02it/s]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:08<00:09,  3.02it/s]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:08<00:09,  3.02it/s]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:08<00:08,  3.02it/s]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:09<00:08,  3.02it/s]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:09<00:08,  3.02it/s]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:09<00:07,  3.02it/s]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:10<00:07,  3.02it/s]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:10<00:07,  3.02it/s]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:10<00:06,  3.02it/s]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:11<00:06,  3.02it/s]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:11<00:06,  3.02it/s]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:11<00:05,  3.03it/s]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:12<00:05,  3.03it/s]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:12<00:05,  3.03it/s]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:12<00:04,  3.03it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:13<00:04,  3.03it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:13<00:04,  3.03it/s]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:13<00:03,  3.03it/s]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:14<00:03,  3.03it/s]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:14<00:03,  3.03it/s]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:14<00:02,  3.03it/s]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [00:15<00:02,  3.03it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [00:15<00:02,  3.03it/s]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [00:15<00:01,  3.03it/s]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [00:16<00:01,  3.03it/s]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [00:16<00:01,  3.03it/s]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [00:16<00:00,  3.03it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [00:17<00:00,  3.03it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [00:17<00:00,  3.03it/s]
# Epoch 0: 100%|█| 5308/5308 [32:48<00:00,  2.70it/s, v_num=qsi8, train/loss=5.940
# Epoch 0: 100%|█| 5308/5308 [32:48<00:00,  2.70it/s, v_num=qsi8, train/loss=5.940/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1825: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5308/5308 [32:49<00:00,  2.69it/s, v_num=qsi8, train/loss=5.940
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:            train/loss █▆▅▅▅▅▅▄▄▄▄▄▅▄▄▃▄▄▄▄▄▃▅▃▃▃▂▃▃▁▃▃▃▃▃▂▃▃▃▃
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 53
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 5.9375
# wandb:   trainer/global_step 331
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 5.64902
# wandb:
# wandb: 🚀 View run infctx-bptt-validation L6-D512 (bptt, train-ctx=512, data-ctx=1024, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/eu7jqsi8
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230730_150124-eu7jqsi8/logs

# %% [markdown]
# # Back-Propagation Through Time (128) training
#
# Perform a full 1 epoch training run of training context size = 128. Forcing all data samples to be segmented 8 times, via "Truncated Back-Propagation Through Time"

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c ../notebook/trainer-validation/config/L6-D512-neox-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (bptt, train-ctx=128, data-ctx=1024, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --model.bptt_learning="true" \
        --model.ctx_len=128
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0.dev20230705'
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230730_153439-ugeh2yfl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-bptt-validation L6-D512 (bptt, train-ctx=128, data-ctx=1024, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/ugeh2yfl
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_128_bf16/build.ninja...
# Building extension module wkv_128_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_128_bf16...
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    16
#
# Found cached dataset parquet (/home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 918.39it/s]
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-84967162f597a3d4_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-eed57f183fc2dcd0_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-b0500659c137c17a_*_of_00032.arrow
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-30 15:34:44,727] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:615: UserWarning: Checkpoint directory /home/ubuntu/RWKV-LM-LoRA-merge/checkpoint/trainer-validaiton/infctx-validation-baseline exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  6.000e-04 (0.0006)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.059862613677978516 seconds
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1688541715909/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.06095576286315918 seconds
# Rank: 0 partition count [1, 1, 1] and sizes[(71960576, False), (3072, False), (3072, False)]
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005941390991210938 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 25.7 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 25.7 M
# --------------------------------------
# 72.0 M    Trainable params
# 0         Non-trainable params
# 72.0 M    Total params
# 287.867   Total estimated model params size (MB)
# Epoch 0: 100%|█| 5308/5308 [2:07:25<00:00,  1.44s/it, v_num=2yfl, train/loss=5.9
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:01<01:12,  1.37s/it]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:02<01:11,  1.38s/it]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:04<01:09,  1.36s/it]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:05<01:07,  1.35s/it]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:06<01:05,  1.35s/it]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:08<01:04,  1.34s/it]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:09<01:02,  1.33s/it]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:10<01:01,  1.33s/it]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:11<00:59,  1.33s/it]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:13<00:58,  1.33s/it]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:14<00:57,  1.33s/it]
# Validation DataLoader 0:  22%|████              | 12/54 [00:15<00:55,  1.33s/it]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:17<00:54,  1.33s/it]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:18<00:53,  1.33s/it]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:19<00:51,  1.33s/it]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:21<00:50,  1.33s/it]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:22<00:49,  1.33s/it]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:23<00:47,  1.33s/it]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:25<00:46,  1.33s/it]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:26<00:45,  1.33s/it]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:27<00:43,  1.33s/it]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:29<00:42,  1.33s/it]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:30<00:41,  1.33s/it]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:31<00:39,  1.33s/it]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:33<00:38,  1.33s/it]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:34<00:37,  1.33s/it]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:35<00:35,  1.33s/it]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:37<00:34,  1.33s/it]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:38<00:33,  1.33s/it]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:39<00:31,  1.33s/it]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:41<00:30,  1.33s/it]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:42<00:29,  1.33s/it]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:43<00:27,  1.33s/it]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:45<00:26,  1.33s/it]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:46<00:25,  1.33s/it]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:47<00:23,  1.33s/it]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:49<00:22,  1.33s/it]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:50<00:21,  1.33s/it]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:51<00:19,  1.33s/it]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:53<00:18,  1.33s/it]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:54<00:17,  1.33s/it]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:55<00:15,  1.33s/it]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:57<00:14,  1.33s/it]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:58<00:13,  1.33s/it]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:59<00:11,  1.33s/it]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [01:00<00:10,  1.33s/it]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [01:02<00:09,  1.33s/it]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [01:03<00:07,  1.33s/it]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [01:04<00:06,  1.33s/it]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [01:06<00:05,  1.33s/it]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [01:07<00:03,  1.33s/it]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [01:08<00:02,  1.33s/it]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [01:10<00:01,  1.32s/it]
# Epoch 0: 100%|█| 5308/5308 [2:08:39<00:00,  1.45s/it, v_num=2yfl, train/loss=5.9
# Epoch 0: 100%|█| 5308/5308 [2:08:39<00:00,  1.45s/it, v_num=2yfl, train/loss=5.9/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1825: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5308/5308 [2:08:41<00:00,  1.45s/it, v_num=2yfl, train/loss=5.9
# wandb: Waiting for W&B process to finish... (success).
# wandb: - 0.005 MB of 0.005 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:            train/loss █▆▅▅▅▅▅▄▄▄▄▄▅▃▄▃▄▄▃▄▄▃▅▃▃▃▂▃▃▁▃▃▃▂▃▂▃▃▃▃
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 53
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 5.9375
# wandb:   trainer/global_step 331
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 5.66667
# wandb:
# wandb: 🚀 View run infctx-bptt-validation L6-D512 (bptt, train-ctx=128, data-ctx=1024, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/ugeh2yfl
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230730_153439-ugeh2yfl/logs

# %% [markdown]
# # Last 1 segmented (128) training
#
# Perform a full 1 epoch training run of training context size = 128. Only using the last segment. (This replicates previous known regression)

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c ../notebook/trainer-validation/config/L6-D512-neox-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (last-1-bptt, train-ctx=128, data-ctx=1024, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --model.bptt_learning="true" \
        --model.bptt_learning_range=1 \
        --model.ctx_len=128
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0.dev20230705'
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230731_013034-51sg7an7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-bptt-validation L6-D512 (last-1-bptt, train-ctx=128, data-ctx=1024, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/51sg7an7
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_128_bf16/build.ninja...
# Building extension module wkv_128_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_128_bf16...
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    16
#
# Found cached dataset parquet (/home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 919.40it/s]
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-49a2d36b4313ec85_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-58974b5a29b27ba3_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-c5674d9fa24d6694_*_of_00032.arrow
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-31 01:30:40,078] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:615: UserWarning: Checkpoint directory /home/ubuntu/RWKV-LM-LoRA-merge/checkpoint/trainer-validaiton/infctx-validation-baseline exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  6.000e-04 (0.0006)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.05956268310546875 seconds
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1688541715909/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.062230587005615234 seconds
# Rank: 0 partition count [1, 1, 1] and sizes[(71960576, False), (3072, False), (3072, False)]
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0006029605865478516 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 25.7 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 25.7 M
# --------------------------------------
# 72.0 M    Trainable params
# 0         Non-trainable params
# 72.0 M    Total params
# 287.867   Total estimated model params size (MB)
# Epoch 0: 100%|█| 5308/5308 [1:58:13<00:00,  1.34s/it, v_num=7an7, train/loss=6.5
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:01<01:13,  1.38s/it]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:02<01:10,  1.36s/it]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:04<01:08,  1.35s/it]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:05<01:07,  1.35s/it]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:06<01:05,  1.34s/it]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:08<01:04,  1.34s/it]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:09<01:03,  1.34s/it]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:10<01:01,  1.34s/it]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:12<01:00,  1.34s/it]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:13<00:58,  1.34s/it]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:14<00:57,  1.33s/it]
# Validation DataLoader 0:  22%|████              | 12/54 [00:15<00:55,  1.33s/it]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:17<00:54,  1.33s/it]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:18<00:53,  1.33s/it]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:19<00:51,  1.33s/it]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:21<00:50,  1.33s/it]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:22<00:49,  1.33s/it]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:23<00:47,  1.33s/it]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:25<00:46,  1.33s/it]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:26<00:45,  1.32s/it]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:27<00:43,  1.32s/it]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:29<00:42,  1.32s/it]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:30<00:41,  1.32s/it]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:31<00:39,  1.32s/it]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:33<00:38,  1.32s/it]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:34<00:36,  1.32s/it]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:35<00:35,  1.32s/it]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:36<00:34,  1.32s/it]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:38<00:33,  1.32s/it]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:39<00:31,  1.32s/it]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:40<00:30,  1.32s/it]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:42<00:29,  1.32s/it]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:43<00:27,  1.32s/it]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:44<00:26,  1.32s/it]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:46<00:25,  1.32s/it]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:47<00:23,  1.32s/it]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:48<00:22,  1.32s/it]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:50<00:21,  1.32s/it]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:51<00:19,  1.32s/it]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:52<00:18,  1.32s/it]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:54<00:17,  1.32s/it]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:55<00:15,  1.32s/it]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:56<00:14,  1.32s/it]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:58<00:13,  1.32s/it]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:59<00:11,  1.32s/it]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [01:00<00:10,  1.32s/it]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [01:01<00:09,  1.32s/it]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [01:03<00:07,  1.32s/it]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [01:04<00:06,  1.32s/it]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [01:05<00:05,  1.32s/it]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [01:07<00:03,  1.32s/it]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [01:08<00:02,  1.32s/it]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [01:09<00:01,  1.32s/it]
# Epoch 0: 100%|█| 5308/5308 [1:59:27<00:00,  1.35s/it, v_num=7an7, train/loss=6.5
# Epoch 0: 100%|█| 5308/5308 [1:59:27<00:00,  1.35s/it, v_num=7an7, train/loss=6.5/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1825: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5308/5308 [1:59:28<00:00,  1.35s/it, v_num=7an7, train/loss=6.5
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 0.005 MB of 0.005 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:            train/loss █▆▅▅▄▅▅▄▄▄▄▄▅▃▃▃▄▄▃▄▄▃▄▃▃▃▂▃▃▁▃▃▃▂▃▂▂▃▃▃
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 53
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 6.5625
# wandb:   trainer/global_step 331
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 6.32812
# wandb:
# wandb: 🚀 View run infctx-bptt-validation L6-D512 (last-1-bptt, train-ctx=128, data-ctx=1024, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/51sg7an7
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230731_013034-51sg7an7/logs

# %% [markdown]
# # Last 2 segmented (128) training
#
# Last segment + 1 varient, to see the various loss learning differences

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c ../notebook/trainer-validation/config/L6-D512-neox-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (last-2-bptt, train-ctx=128, data-ctx=1024, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --model.bptt_learning="true" \
        --model.bptt_learning_range=2 \
        --model.ctx_len=128
# Out:
# Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0.dev20230705'
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230731_033030-0c82dfa5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-bptt-validation L6-D512 (last-2-bptt, train-ctx=128, data-ctx=1024, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/0c82dfa5
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_128_bf16/build.ninja...
# Building extension module wkv_128_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_128_bf16...
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    16
#
# Found cached dataset parquet (/home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 890.51it/s]
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-49a2d36b4313ec85_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-58974b5a29b27ba3_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-c5674d9fa24d6694_*_of_00032.arrow
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-31 03:30:35,721] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:615: UserWarning: Checkpoint directory /home/ubuntu/RWKV-LM-LoRA-merge/checkpoint/trainer-validaiton/infctx-validation-baseline exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  6.000e-04 (0.0006)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06056332588195801 seconds
# /home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1688541715909/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.06166362762451172 seconds
# Rank: 0 partition count [1, 1, 1] and sizes[(71960576, False), (3072, False), (3072, False)]
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005996227264404297 seconds
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 25.7 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 25.7 M
# --------------------------------------
# 72.0 M    Trainable params
# 0         Non-trainable params
# 72.0 M    Total params
# 287.867   Total estimated model params size (MB)
# Epoch 0:   0%| | 15/5308 [00:25<2:30:16,  1.70s/it, v_num=dfa5, train/loss=10.90
# Epoch 0: 100%|█| 5308/5308 [1:59:11<00:00,  1.35s/it, v_num=dfa5, train/loss=6.3
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:01<01:12,  1.37s/it]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:02<01:09,  1.34s/it]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:03<01:07,  1.33s/it]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:05<01:06,  1.33s/it]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:06<01:05,  1.33s/it]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:07<01:03,  1.33s/it]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:09<01:02,  1.32s/it]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:10<01:00,  1.32s/it]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:11<00:59,  1.33s/it]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:13<00:58,  1.33s/it]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:14<00:56,  1.32s/it]
# Validation DataLoader 0:  22%|████              | 12/54 [00:15<00:55,  1.32s/it]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:17<00:54,  1.32s/it]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:18<00:52,  1.32s/it]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:19<00:51,  1.32s/it]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:21<00:50,  1.32s/it]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:22<00:48,  1.32s/it]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:23<00:47,  1.32s/it]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:24<00:46,  1.31s/it]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:26<00:44,  1.31s/it]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:27<00:43,  1.31s/it]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:28<00:41,  1.31s/it]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:30<00:40,  1.31s/it]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:31<00:39,  1.31s/it]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:32<00:37,  1.31s/it]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:34<00:36,  1.31s/it]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:35<00:35,  1.31s/it]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:36<00:34,  1.31s/it]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:37<00:32,  1.31s/it]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:39<00:31,  1.31s/it]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:40<00:30,  1.31s/it]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:41<00:28,  1.31s/it]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:43<00:27,  1.31s/it]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:44<00:26,  1.31s/it]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:45<00:24,  1.31s/it]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:47<00:23,  1.31s/it]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:48<00:22,  1.31s/it]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:49<00:20,  1.31s/it]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:51<00:19,  1.31s/it]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:52<00:18,  1.31s/it]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:53<00:17,  1.31s/it]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:55<00:15,  1.31s/it]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:56<00:14,  1.31s/it]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:57<00:13,  1.31s/it]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:59<00:11,  1.31s/it]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [01:00<00:10,  1.31s/it]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [01:01<00:09,  1.31s/it]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [01:02<00:07,  1.31s/it]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [01:04<00:06,  1.31s/it]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [01:05<00:05,  1.31s/it]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [01:06<00:03,  1.31s/it]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [01:08<00:02,  1.31s/it]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [01:09<00:01,  1.31s/it]
# Epoch 0: 100%|█| 5308/5308 [2:00:24<00:00,  1.36s/it, v_num=dfa5, train/loss=6.3
# Epoch 0: 100%|█| 5308/5308 [2:00:24<00:00,  1.36s/it, v_num=dfa5, train/loss=6.3/home/ubuntu/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1825: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5308/5308 [2:00:26<00:00,  1.36s/it, v_num=dfa5, train/loss=6.3
# wandb: Waiting for W&B process to finish... (success).
# wandb: / 0.005 MB of 0.005 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:              batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███▁
# wandb:            train/loss █▆▅▅▄▅▅▄▄▄▄▄▅▃▄▃▄▄▃▄▄▃▄▃▃▃▂▃▃▁▃▃▃▂▃▂▂▃▃▃
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:              batchidx 53
# wandb:                 epoch 0
# wandb:           global_rank 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 6.34375
# wandb:   trainer/global_step 331
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 6.10243
# wandb:
# wandb: 🚀 View run infctx-bptt-validation L6-D512 (last-2-bptt, train-ctx=128, data-ctx=1024, deepspeed_stage_1) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/0c82dfa5
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230731_033030-0c82dfa5/logs
