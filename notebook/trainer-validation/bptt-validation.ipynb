# %% [markdown]
# # InfCtx trainer validation
# This model being trained has the same settings as raven 1B5 model.
# - Layer count: 24
# - Embed size: 2048
#
# The goal is to validate loss rate change, across the exact same hyper parameters with the following
# - 1024 data chunk size
# - same learningrate / weightdecay / seed
# - "teven/enwiki_10k" dataset, chunked to 1024 token sizes
#
# With only the change in training context size
# - 1024 context vs 128 context
#
# > This project assumes you have the rwkv-infctx conda env setup, and you are executing in that environment - see the main README.md for the conda env setup steps
# >
# > And that you have completed the `baseline-setup.ipynb`

# %% [markdown]
# ## Configure and apply your preferred settings
#
# Adjust your desired deepspeed settings, and gpu device count.
#
# Enable/Disable WANDB here as well ( Enabled by default, as we need the loss curve for this experiment )
#
# ( note you will need to rerun this cell, if you restart your env )

# %%
DEEPSPEED_STRAT="deepspeed_stage_2_offload"
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="infctx-bptt-validation"

print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"
# Out:
# DEEPSPEED_STRAT: deepspeed_stage_2_offload
# ENABLE_WANDB: True
# GPU_DEVICES: auto

# %% [markdown]
# # (optional) Baseline full context (1024) training
#
# (you can skip this, and use the optional baseline found in `baseline-setup.ipynb`)
#
# Perform a full 1 epoch training run of training context size = 1024. Ensuring all data samples fit within the allocated training size.

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 new_train.py fit \
        -c ../notebook/trainer-validation/config/baseline-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (full, train-ctx=1024, data-ctx=1024)" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2023-07-08 09:06:42,637] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model via the following optimization mode : torch-compile
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.5
# wandb: Run data is saved locally in ./wandb/run-20230708_090644-3bz2cq44
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-bptt-validation (full, train-ctx=1024, data-ctx=1024)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/3bz2cq44
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Found cached dataset parquet (/home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 858.61it/s]
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-85ed41912c749812_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-d919d919e3a12608_*_of_00032.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-f2a6e7ee57d796c9_*_of_00032.arrow
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-08 09:06:59,020] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# [2023-07-08 09:06:59,021] [WARNING] [deepspeed.py:638:_auto_select_batch_size] Tried to infer the batch size for internal deepspeed logging from the `train_dataloader()`. To ensure DeepSpeed logging remains correct, please manually pass the plugin with the batch size, `Trainer(strategy=DeepSpeedStrategy(logging_batch_size_per_gpu=batch_size))`.
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [WARNING]: it is highly recommended to enable bptt_learning when used to deepspeed 2/3/offloading, otherwise an exception will occur when training with dataset records, larger then the configured context length (1024)
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.3396010398864746 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Rank: 0 partition count [1, 1, 1] and sizes[(1515008000, False), (49152, False), (49152, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0:   0%|                                         | 0/5308 [00:00<?, ?it/s][2023-07-08 09:08:12,477] torch._inductor.utils: [WARNING] DeviceCopy in input program
# [2023-07-08 09:08:12,513] torch._inductor.utils: [WARNING] DeviceCopy in input program
# [2023-07-08 09:08:13,365] torch._inductor.utils: [WARNING] DeviceCopy in input program
# Epoch 0:   0%| | 9/5308 [01:25<14:03:12,  9.55s/it, v_num=cq44, train/loss=10.90/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/runtime/zero/stage_1_and_2.py:1828: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1688627653114/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   overflow_gpu = get_accelerator().ByteTensor([overflow])
# Epoch 0:   1%| | 64/5308 [02:44<3:44:36,  2.57s/it, v_num=cq44, train/loss=8.620[2023-07-08 09:10:17,966] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
#    function: '<resume in publish_partial_history>' (/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:572)
# to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# Epoch 0:  11%| | 610/5308 [12:13<1:34:07,  1.20s/it, v_num=cq44, train/loss=7.50[2023-07-08 09:19:46,835] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
#    function: 'wrapper' (/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:358)
# to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [2023-07-08 09:19:46,836] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
#    function: 'wrapper_fn' (/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:337)
# to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [2023-07-08 09:19:46,837] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
#    function: '<resume in wrapper>' (/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:313)
# to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [2023-07-08 09:19:46,838] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
#    function: 'log' (/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1550)
# to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [2023-07-08 09:19:46,839] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
#    function: '_log' (/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1514)
# to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [2023-07-08 09:19:46,840] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
#    function: '_partial_history_callback' (/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1383)
# to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# [2023-07-08 09:19:46,852] torch._dynamo.convert_frame: [WARNING] torch._dynamo hit config.cache_size_limit (64)
#    function: 'publish_partial_history' (/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:555)
# to diagnose recompilation issues, set env variable TORCHDYNAMO_REPORT_GUARD_FAILURES=1 and also see https://pytorch.org/docs/master/compile/troubleshooting.html.
# Epoch 0:  12%| | 635/5308 [12:37<1:32:56,  1.19s/it, v_num=cq44, train/loss=7.41^C
# Process ForkProcess-128:
# Process ForkProcess-127:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkProcess-120:
# Process ForkProcess-124:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# Process ForkProcess-118:
# Process ForkProcess-122:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkProcess-123:
# Process ForkProcess-116:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkProcess-115:
# Process ForkProcess-112:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 103, in get
#     res = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/connection.py", line 215, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/connection.py", line 413, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/connection.py", line 378, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-111:
# Process ForkProcess-109:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-104:
# Process ForkProcess-107:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-102:
# Process ForkProcess-101:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-98:
# Process ForkProcess-99:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-110:
# Process ForkProcess-100:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkProcess-117:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-103:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkProcess-108:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-97:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Process ForkProcess-125:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-126:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# Process ForkProcess-114:
# KeyboardInterrupt
# Process ForkProcess-121:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-106:
# Process ForkProcess-113:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-105:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkProcess-119:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:52: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/concurrent/futures/process.py", line 244, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# # Back-Propagation Through Time (512) training
#
# Perform a full 1 epoch training run of training context size = 512. This is a less exegerated version of the 128 training

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 new_train.py fit \
        -c ../notebook/trainer-validation/config/baseline-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (bptt, train-ctx=512, data-ctx=1024)" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --model.bptt_learning="true" \
        --model.ctx_len=512
# Out:
# [2023-07-02 14:54:47,604] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230702_145449-j9e4ugmm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-validation-512-segmented (train-ctx=512, data-ctx=1024, bs=12)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/j9e4ugmm
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_512_bf16/build.ninja...
# Building extension module wkv_512_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_512_bf16...
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 876.92it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-3d43d1724bef83d7_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-5033407f38c97f24.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-78e7f3a5f1679aa4_*_of_00016.arrow
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-02 14:55:03,562] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.3205106258392334 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Rank: 0 partition count [1, 1, 1] and sizes[(1515008000, False), (49152, False), (49152, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0: 100%|█| 5318/5318 [1:28:42<00:00,  1.00s/it, v_num=ugmm, train/loss=6.6
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:00<00:16,  3.30it/s]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:00<00:14,  3.60it/s]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:00<00:13,  3.67it/s]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:01<00:13,  3.73it/s]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:01<00:12,  3.78it/s]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:01<00:12,  3.81it/s]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:01<00:12,  3.83it/s]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:02<00:11,  3.85it/s]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:02<00:11,  3.86it/s]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:02<00:11,  3.87it/s]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:02<00:11,  3.88it/s]
# Validation DataLoader 0:  22%|████              | 12/54 [00:03<00:10,  3.89it/s]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:03<00:10,  3.90it/s]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:03<00:10,  3.90it/s]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:03<00:09,  3.91it/s]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:04<00:09,  3.91it/s]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:04<00:09,  3.91it/s]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:04<00:09,  3.91it/s]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:04<00:08,  3.91it/s]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:05<00:08,  3.91it/s]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:05<00:08,  3.92it/s]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:05<00:08,  3.92it/s]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:05<00:07,  3.92it/s]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:06<00:07,  3.93it/s]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:06<00:07,  3.93it/s]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:06<00:07,  3.93it/s]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:06<00:06,  3.93it/s]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:07<00:06,  3.94it/s]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:07<00:06,  3.94it/s]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:07<00:06,  3.94it/s]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:07<00:05,  3.94it/s]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:08<00:05,  3.94it/s]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:08<00:05,  3.94it/s]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:08<00:05,  3.94it/s]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:08<00:04,  3.94it/s]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:09<00:04,  3.94it/s]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:09<00:04,  3.94it/s]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:09<00:04,  3.94it/s]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:09<00:03,  3.94it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:10<00:03,  3.95it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:10<00:03,  3.95it/s]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:10<00:03,  3.95it/s]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:10<00:02,  3.95it/s]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:11<00:02,  3.95it/s]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:11<00:02,  3.95it/s]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [00:11<00:02,  3.95it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [00:11<00:01,  3.95it/s]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [00:12<00:01,  3.95it/s]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [00:12<00:01,  3.95it/s]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [00:12<00:01,  3.95it/s]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [00:12<00:00,  3.95it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [00:13<00:00,  3.95it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [00:13<00:00,  3.95it/s]
# Epoch 0: 100%|█| 5318/5318 [1:28:58<00:00,  1.00s/it, v_num=ugmm, train/loss=6.6
# Epoch 0: 100%|█| 5318/5318 [1:28:58<00:00,  1.00s/it, v_num=ugmm, train/loss=6.6`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5318/5318 [1:28:58<00:00,  1.00s/it, v_num=ugmm, train/loss=6.6
# wandb: Waiting for W&B process to finish... (success).
# wandb: / 0.003 MB of 0.003 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss █▇▆▆▇▆▆▅▃▄▃▃▃▄▄▄▂▃▃▃▂▃▃▃▁▃▂▃▂▂▂▂▂▂▂▂▁▁▂▂
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                 epoch 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 6.5625
# wandb:   trainer/global_step 443
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 6.29572
# wandb:
# wandb: 🚀 View run infctx-validation-512-segmented (train-ctx=512, data-ctx=1024, bs=12) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/j9e4ugmm
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230702_145449-j9e4ugmm/logs

# %% [markdown]
# # Back-Propagation Through Time (128) training
#
# Perform a full 1 epoch training run of training context size = 128. Forcing all data samples to be segmented 8 times, via "Truncated Back-Propagation Through Time"

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 new_train.py fit \
        -c ../notebook/trainer-validation/config/baseline-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (bptt, train-ctx=128, data-ctx=1024)" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --model.bptt_learning="true" \
        --model.ctx_len=128
# Out:
# [2023-07-02 11:57:01,839] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230702_115703-g3mffwuh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-validation-first-segment (train-ctx=128, data-ctx=1024, bs=12)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/g3mffwuh
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_128_bf16/build.ninja...
# Building extension module wkv_128_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_128_bf16...
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 542.25it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-3d43d1724bef83d7_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-5033407f38c97f24.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-78e7f3a5f1679aa4_*_of_00016.arrow
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-02 11:57:17,865] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.3168303966522217 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Rank: 0 partition count [1, 1, 1] and sizes[(1515008000, False), (49152, False), (49152, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0: 100%|█| 5318/5318 [2:08:13<00:00,  1.45s/it, v_num=fwuh, train/loss=6.8
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:01<00:55,  1.04s/it]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:02<00:53,  1.03s/it]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:03<00:51,  1.02s/it]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:04<00:50,  1.01s/it]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:05<00:49,  1.01s/it]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:06<00:48,  1.01s/it]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:07<00:47,  1.01s/it]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:08<00:46,  1.01s/it]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:09<00:45,  1.01s/it]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:10<00:44,  1.01s/it]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:11<00:43,  1.01s/it]
# Validation DataLoader 0:  22%|████              | 12/54 [00:12<00:42,  1.01s/it]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:13<00:41,  1.01s/it]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:14<00:40,  1.01s/it]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:15<00:39,  1.01s/it]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:16<00:38,  1.01s/it]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:17<00:37,  1.01s/it]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:18<00:36,  1.01s/it]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:19<00:35,  1.01s/it]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:20<00:34,  1.00s/it]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:21<00:33,  1.00s/it]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:22<00:32,  1.00s/it]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:23<00:31,  1.00s/it]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:24<00:30,  1.00s/it]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:25<00:29,  1.00s/it]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:26<00:28,  1.00s/it]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:27<00:27,  1.00s/it]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:28<00:26,  1.00s/it]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:29<00:25,  1.00s/it]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:30<00:24,  1.00s/it]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:31<00:23,  1.00s/it]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:32<00:22,  1.00s/it]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:33<00:21,  1.00s/it]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:34<00:20,  1.00s/it]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:35<00:19,  1.00s/it]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:36<00:18,  1.00s/it]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:37<00:17,  1.00s/it]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:38<00:16,  1.00s/it]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:39<00:15,  1.00s/it]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:40<00:14,  1.00s/it]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:41<00:13,  1.00s/it]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:42<00:12,  1.00s/it]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:43<00:11,  1.00s/it]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:44<00:10,  1.00s/it]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:45<00:09,  1.00s/it]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [00:46<00:08,  1.00s/it]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [00:47<00:07,  1.00s/it]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [00:48<00:06,  1.00s/it]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [00:49<00:05,  1.00s/it]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [00:50<00:04,  1.00s/it]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [00:51<00:03,  1.00s/it]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [00:52<00:02,  1.00s/it]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [00:53<00:01,  1.00s/it]
# Epoch 0: 100%|█| 5318/5318 [2:09:09<00:00,  1.46s/it, v_num=fwuh, train/loss=6.8
# Epoch 0: 100%|█| 5318/5318 [2:09:09<00:00,  1.46s/it, v_num=fwuh, train/loss=6.8`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5318/5318 [2:09:09<00:00,  1.46s/it, v_num=fwuh, train/loss=6.8
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ██▇▆▇▅▆▆▃▄▄▃▄▄▄▄▃▃▃▃▂▃▃▄▂▂▂▃▂▂▂▂▂▃▂▂▁▁▂▂
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                 epoch 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 6.84375
# wandb:   trainer/global_step 443
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 6.48148
# wandb:
# wandb: 🚀 View run infctx-validation-first-segment (train-ctx=128, data-ctx=1024, bs=12) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/g3mffwuh
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230702_115703-g3mffwuh/logs

# %% [markdown]
# # Last segmented (128) training
#
# Finally perform a full 1 epoch training run of training context size = 128. Only using the last segment. (This replicates previous known regression)

# %%
# !cd ../../RWKV-v4neo && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 new_train.py fit \
        -c ../notebook/trainer-validation/config/baseline-1024.yaml \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (last-bptt, train-ctx=128, data-ctx=1024)" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --model.bptt_learning="true" \
        --model.bptt_learning_range=1 \
        --model.ctx_len=128
# Out:
# [2023-07-01 22:13:03,001] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230701_221304-w0k4pf4n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-validation-last-segment (train-ctx=128, data-ctx=1024, bs=12)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/w0k4pf4n
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_128_bf16/build.ninja...
# Building extension module wkv_128_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_128_bf16...
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 573.38it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-3d43d1724bef83d7_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-5033407f38c97f24.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-78e7f3a5f1679aa4_*_of_00016.arrow
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-01 22:13:19,107] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.3192222118377686 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Rank: 0 partition count [1, 1, 1] and sizes[(1515008000, False), (49152, False), (49152, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0: 100%|█| 5318/5318 [2:06:56<00:00,  1.43s/it, v_num=pf4n, train/loss=6.7
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:01<00:55,  1.05s/it]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:02<00:53,  1.03s/it]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:03<00:52,  1.02s/it]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:04<00:50,  1.02s/it]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:05<00:49,  1.02s/it]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:06<00:48,  1.01s/it]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:07<00:47,  1.01s/it]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:08<00:46,  1.01s/it]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:09<00:45,  1.01s/it]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:10<00:44,  1.01s/it]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:11<00:43,  1.01s/it]
# Validation DataLoader 0:  22%|████              | 12/54 [00:12<00:42,  1.01s/it]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:13<00:41,  1.01s/it]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:14<00:40,  1.01s/it]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:15<00:39,  1.01s/it]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:16<00:38,  1.01s/it]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:17<00:37,  1.01s/it]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:18<00:36,  1.01s/it]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:19<00:35,  1.01s/it]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:20<00:34,  1.01s/it]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:21<00:33,  1.01s/it]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:22<00:32,  1.01s/it]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:23<00:31,  1.01s/it]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:24<00:30,  1.01s/it]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:25<00:29,  1.01s/it]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:26<00:28,  1.01s/it]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:27<00:27,  1.01s/it]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:28<00:26,  1.01s/it]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:29<00:25,  1.01s/it]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:30<00:24,  1.01s/it]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:31<00:23,  1.01s/it]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:32<00:22,  1.01s/it]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:33<00:21,  1.01s/it]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:34<00:20,  1.01s/it]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:35<00:19,  1.01s/it]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:36<00:18,  1.01s/it]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:37<00:17,  1.01s/it]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:38<00:16,  1.01s/it]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:39<00:15,  1.01s/it]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:40<00:14,  1.01s/it]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:41<00:13,  1.01s/it]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:42<00:12,  1.01s/it]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:43<00:11,  1.01s/it]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:44<00:10,  1.01s/it]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:45<00:09,  1.01s/it]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [00:46<00:08,  1.01s/it]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [00:47<00:07,  1.01s/it]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [00:48<00:06,  1.01s/it]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [00:49<00:05,  1.01s/it]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [00:50<00:04,  1.01s/it]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [00:51<00:03,  1.01s/it]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [00:52<00:02,  1.01s/it]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [00:53<00:01,  1.01s/it]
# Epoch 0: 100%|█| 5318/5318 [2:07:53<00:00,  1.44s/it, v_num=pf4n, train/loss=6.7
# Epoch 0: 100%|█| 5318/5318 [2:07:53<00:00,  1.44s/it, v_num=pf4n, train/loss=6.7`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5318/5318 [2:07:53<00:00,  1.44s/it, v_num=pf4n, train/loss=6.7
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ██▅▆▇▅▆▆▃▄▃▃▄▄▄▃▂▃▃▂▂▂▃▄▁▂▂▃▂▂▁▂▂▂▂▂▁▁▂▂
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                 epoch 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 6.78125
# wandb:   trainer/global_step 443
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 6.43345
# wandb:
# wandb: 🚀 View run infctx-validation-last-segment (train-ctx=128, data-ctx=1024, bs=12) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/w0k4pf4n
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230701_221304-w0k4pf4n/logs
