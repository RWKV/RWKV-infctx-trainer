# %% [markdown]
# # InfCtx matmul accuracy validation
# This model being trained has the same settings as raven 1B5 model.
# - Layer count: 24
# - Embed size: 2048
#
# The goal is to validate that lower matmul accuracy has now negative impact on loss training
#
# > This project assumes you have the rwkv-infctx conda env setup, and you are executing in that environment - see the main README.md for the conda env setup steps
# >
# > And that you have completed the `baseline-setup.ipynb`

# %% [markdown]
# # (optional) Baseline full context (1024) training
#
# (you can skip this, and use the optional baseline found in `baseline-setup.ipynb`)
#
# Perform a full 1 epoch training run of training context size = 1024. Ensuring all data samples fit within the allocated training size.

# %%
# !cd ../../RWKV-v4neo && \
    python3 new_train.py fit \
        -c ../notebook/trainer-validation/config/baseline-1024.yaml
# Out:
# [2023-07-01 20:53:18,310] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230701_205320-k8flu72z
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-validation-full (train-ctx=1024, data-ctx=1024, bs=12)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/k8flu72z
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv_1024_bf16...
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 675.41it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-3d43d1724bef83d7_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-5033407f38c97f24.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-78e7f3a5f1679aa4_*_of_00016.arrow
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-01 20:53:34,204] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:615: UserWarning: Checkpoint directory /home/picocreator/rwkv-proj/infctx-dev/checkpoint/trainer-validaiton/infctx-validation-full exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.312431812286377 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Rank: 0 partition count [1, 1, 1] and sizes[(1515008000, False), (49152, False), (49152, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0: 100%|█| 5318/5318 [51:02<00:00,  1.74it/s, v_num=u72z, train/loss=5.940
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:00<00:08,  5.98it/s]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:00<00:07,  6.81it/s]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:00<00:07,  7.14it/s]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:00<00:06,  7.32it/s]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:00<00:06,  7.41it/s]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:00<00:06,  7.48it/s]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:00<00:06,  7.54it/s]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:01<00:06,  7.59it/s]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:01<00:05,  7.60it/s]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:01<00:05,  7.62it/s]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:01<00:05,  7.64it/s]
# Validation DataLoader 0:  22%|████              | 12/54 [00:01<00:05,  7.66it/s]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:01<00:05,  7.68it/s]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:01<00:05,  7.70it/s]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:01<00:05,  7.69it/s]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:02<00:04,  7.71it/s]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:02<00:04,  7.72it/s]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:02<00:04,  7.72it/s]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:02<00:04,  7.73it/s]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:02<00:04,  7.74it/s]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:02<00:04,  7.75it/s]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:02<00:04,  7.75it/s]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:02<00:03,  7.76it/s]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:03<00:03,  7.77it/s]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:03<00:03,  7.78it/s]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:03<00:03,  7.78it/s]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:03<00:03,  7.79it/s]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:03<00:03,  7.80it/s]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:03<00:03,  7.80it/s]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:03<00:03,  7.81it/s]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:03<00:02,  7.81it/s]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:04<00:02,  7.82it/s]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:04<00:02,  7.83it/s]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:04<00:02,  7.83it/s]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:04<00:02,  7.83it/s]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:04<00:02,  7.84it/s]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:04<00:02,  7.84it/s]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:04<00:02,  7.84it/s]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:04<00:01,  7.85it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:05<00:01,  7.85it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:05<00:01,  7.85it/s]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:05<00:01,  7.86it/s]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:05<00:01,  7.86it/s]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:05<00:01,  7.86it/s]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:05<00:01,  7.86it/s]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [00:05<00:01,  7.87it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [00:05<00:00,  7.87it/s]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [00:06<00:00,  7.87it/s]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [00:06<00:00,  7.87it/s]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [00:06<00:00,  7.88it/s]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [00:06<00:00,  7.88it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [00:06<00:00,  7.88it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [00:06<00:00,  7.88it/s]
# Epoch 0: 100%|█| 5318/5318 [51:11<00:00,  1.73it/s, v_num=u72z, train/loss=5.940
# Epoch 0: 100%|█| 5318/5318 [51:11<00:00,  1.73it/s, v_num=u72z, train/loss=5.940`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5318/5318 [51:11<00:00,  1.73it/s, v_num=u72z, train/loss=5.940
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ██▇▇█▆▇▆▄▅▄▃▄▄▄▄▂▃▃▃▃▃▃▄▁▂▂▃▃▂▂▂▂▃▂▂▁▁▂▂
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                 epoch 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 5.96875
# wandb:   trainer/global_step 443
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 5.67332
# wandb:
# wandb: 🚀 View run infctx-validation-full (train-ctx=1024, data-ctx=1024, bs=12) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/k8flu72z
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230701_205320-k8flu72z/logs

# %% [markdown]
# # Baseline with "medium" matmul accuracy
#
# Perform the same training process, with lower accuracy
# > PS: Weights and biases logging is enabled

# %%
# !cd ../../RWKV-v4neo && \
    python3 new_train.py fit \
        -c ../notebook/trainer-validation/config/baseline-1024.yaml
        --trainer.logger.init_args.name="infctx-validation-baseline (matmul_precision='medium', train-ctx=1024, data-ctx=1024, bs=10)" \
        --model.torch_set_float32_matmul_precision="medium"
# Out:
# [2023-07-02 18:30:23,627] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Global seed set to 3941088705
# wandb: Currently logged in as: picocreator. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in ./wandb/run-20230702_183025-nvqmf1js
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-validation-full (matmul=medium, train-ctx=1024, data-ctx=1024, bs=12)
# wandb: ⭐️ View project at https://wandb.ai/picocreator/RWKV-InfCtx-Validation
# wandb: 🚀 View run at https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/nvqmf1js
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/wkv_1024_bf16/build.ninja...
# Building extension module wkv_1024_bf16...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF wkv_op_bf16.o.d -DTORCH_EXTENSION_NAME=wkv_1024_bf16 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include -isystem /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/TH -isystem /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /home/picocreator/anaconda3/envs/rwkv-exp/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -std=c++17 -O3 -DTmax=1024 -c /home/picocreator/rwkv-proj/infctx-dev/RWKV-v4neo/cuda/wkv_op_bf16.cpp -o wkv_op_bf16.o
# [2/2] c++ wkv_op_bf16.o wkv_cuda_bf16.cuda.o -shared -L/home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o wkv_1024_bf16.so
# Loading extension module wkv_1024_bf16...
# Found cached dataset parquet (/home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 919.00it/s]
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-e4cc6a1335c36775_*_of_00016.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-37a2fa7498f01de6.arrow
# Loading cached processed dataset at /home/picocreator/.cache/huggingface/datasets/teven___parquet/teven--enwiki_10k-de63a925546e70ab/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-120b4276954261d5_*_of_00016.arrow
# /home/picocreator/anaconda3/envs/rwkv-exp/lib/python3.11/site-packages/lightning/fabric/connector.py:555: UserWarning: bf16 is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [rank: 0] Global seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2023-07-02 18:30:57,152] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# Enabling DeepSpeed BF16.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [WARNING]: it is highly recommended to enable tbptt_learning when used to deepspeed 2/3/offloading, otherwise an exception will occur when training with dataset records, larger then the configured context length ({self.ctx_len})
#  [WARNING]  cpu_adam cuda is missing or is incompatible with installed torch, only cpu ops can be compiled!
# Using /home/picocreator/.cache/torch_extensions/py311_cu117 as PyTorch extensions root...
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 2.306368589401245 seconds
# Loading `train_dataloader` to estimate number of stepping batches.
# Rank: 0 partition count [1, 1, 1] and sizes[(1515008000, False), (49152, False), (49152, False)]
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 102 M
# 1 | blocks | ModuleList | 1.3 B
# 2 | ln_out | LayerNorm  | 4.1 K
# 3 | head   | Linear     | 102 M
# --------------------------------------
# 1.5 B     Trainable params
# 0         Non-trainable params
# 1.5 B     Total params
# 6,060.425 Total estimated model params size (MB)
# Epoch 0: 100%|█| 5318/5318 [52:00<00:00,  1.70it/s, v_num=f1js, train/loss=5.880
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/54 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎                  | 1/54 [00:00<00:09,  5.74it/s]
# Validation DataLoader 0:   4%|▋                  | 2/54 [00:00<00:07,  6.51it/s]
# Validation DataLoader 0:   6%|█                  | 3/54 [00:00<00:07,  6.92it/s]
# Validation DataLoader 0:   7%|█▍                 | 4/54 [00:00<00:06,  7.14it/s]
# Validation DataLoader 0:   9%|█▊                 | 5/54 [00:00<00:06,  7.29it/s]
# Validation DataLoader 0:  11%|██                 | 6/54 [00:00<00:06,  7.36it/s]
# Validation DataLoader 0:  13%|██▍                | 7/54 [00:00<00:06,  7.42it/s]
# Validation DataLoader 0:  15%|██▊                | 8/54 [00:01<00:06,  7.47it/s]
# Validation DataLoader 0:  17%|███▏               | 9/54 [00:01<00:06,  7.49it/s]
# Validation DataLoader 0:  19%|███▎              | 10/54 [00:01<00:05,  7.53it/s]
# Validation DataLoader 0:  20%|███▋              | 11/54 [00:01<00:05,  7.55it/s]
# Validation DataLoader 0:  22%|████              | 12/54 [00:01<00:05,  7.57it/s]
# Validation DataLoader 0:  24%|████▎             | 13/54 [00:01<00:05,  7.59it/s]
# Validation DataLoader 0:  26%|████▋             | 14/54 [00:01<00:05,  7.61it/s]
# Validation DataLoader 0:  28%|█████             | 15/54 [00:01<00:05,  7.63it/s]
# Validation DataLoader 0:  30%|█████▎            | 16/54 [00:02<00:04,  7.64it/s]
# Validation DataLoader 0:  31%|█████▋            | 17/54 [00:02<00:04,  7.66it/s]
# Validation DataLoader 0:  33%|██████            | 18/54 [00:02<00:04,  7.67it/s]
# Validation DataLoader 0:  35%|██████▎           | 19/54 [00:02<00:04,  7.68it/s]
# Validation DataLoader 0:  37%|██████▋           | 20/54 [00:02<00:04,  7.70it/s]
# Validation DataLoader 0:  39%|███████           | 21/54 [00:02<00:04,  7.71it/s]
# Validation DataLoader 0:  41%|███████▎          | 22/54 [00:02<00:04,  7.71it/s]
# Validation DataLoader 0:  43%|███████▋          | 23/54 [00:02<00:04,  7.72it/s]
# Validation DataLoader 0:  44%|████████          | 24/54 [00:03<00:03,  7.73it/s]
# Validation DataLoader 0:  46%|████████▎         | 25/54 [00:03<00:03,  7.74it/s]
# Validation DataLoader 0:  48%|████████▋         | 26/54 [00:03<00:03,  7.75it/s]
# Validation DataLoader 0:  50%|█████████         | 27/54 [00:03<00:03,  7.75it/s]
# Validation DataLoader 0:  52%|█████████▎        | 28/54 [00:03<00:03,  7.76it/s]
# Validation DataLoader 0:  54%|█████████▋        | 29/54 [00:03<00:03,  7.76it/s]
# Validation DataLoader 0:  56%|██████████        | 30/54 [00:03<00:03,  7.77it/s]
# Validation DataLoader 0:  57%|██████████▎       | 31/54 [00:03<00:02,  7.77it/s]
# Validation DataLoader 0:  59%|██████████▋       | 32/54 [00:04<00:02,  7.78it/s]
# Validation DataLoader 0:  61%|███████████       | 33/54 [00:04<00:02,  7.78it/s]
# Validation DataLoader 0:  63%|███████████▎      | 34/54 [00:04<00:02,  7.79it/s]
# Validation DataLoader 0:  65%|███████████▋      | 35/54 [00:04<00:02,  7.79it/s]
# Validation DataLoader 0:  67%|████████████      | 36/54 [00:04<00:02,  7.79it/s]
# Validation DataLoader 0:  69%|████████████▎     | 37/54 [00:04<00:02,  7.80it/s]
# Validation DataLoader 0:  70%|████████████▋     | 38/54 [00:04<00:02,  7.80it/s]
# Validation DataLoader 0:  72%|█████████████     | 39/54 [00:04<00:01,  7.80it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 40/54 [00:05<00:01,  7.80it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 41/54 [00:05<00:01,  7.81it/s]
# Validation DataLoader 0:  78%|██████████████    | 42/54 [00:05<00:01,  7.81it/s]
# Validation DataLoader 0:  80%|██████████████▎   | 43/54 [00:05<00:01,  7.81it/s]
# Validation DataLoader 0:  81%|██████████████▋   | 44/54 [00:05<00:01,  7.82it/s]
# Validation DataLoader 0:  83%|███████████████   | 45/54 [00:05<00:01,  7.82it/s]
# Validation DataLoader 0:  85%|███████████████▎  | 46/54 [00:05<00:01,  7.82it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 47/54 [00:06<00:00,  7.83it/s]
# Validation DataLoader 0:  89%|████████████████  | 48/54 [00:06<00:00,  7.83it/s]
# Validation DataLoader 0:  91%|████████████████▎ | 49/54 [00:06<00:00,  7.83it/s]
# Validation DataLoader 0:  93%|████████████████▋ | 50/54 [00:06<00:00,  7.83it/s]
# Validation DataLoader 0:  94%|█████████████████ | 51/54 [00:06<00:00,  7.83it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 52/54 [00:06<00:00,  7.84it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 53/54 [00:06<00:00,  7.84it/s]
# Epoch 0: 100%|█| 5318/5318 [52:11<00:00,  1.70it/s, v_num=f1js, train/loss=5.880
# Epoch 0: 100%|█| 5318/5318 [52:11<00:00,  1.70it/s, v_num=f1js, train/loss=5.880`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 5318/5318 [52:11<00:00,  1.70it/s, v_num=f1js, train/loss=5.880
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:                 epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          real_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/loss ██▇▇█▆▇▆▄▅▄▃▄▄▄▄▂▃▃▃▂▃▃▄▁▂▂▃▃▂▂▂▂▃▂▂▁▁▂▂
# wandb:   trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: trainer/learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:       validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                 epoch 0
# wandb:          real_ctx_len 1023
# wandb:               substep 53
# wandb:            train/loss 5.9375
# wandb:   trainer/global_step 443
# wandb: trainer/learning_rate 0.0004
# wandb:       validation/loss 5.6114
# wandb:
# wandb: 🚀 View run infctx-validation-full (matmul=medium, train-ctx=1024, data-ctx=1024, bs=12) at: https://wandb.ai/picocreator/RWKV-InfCtx-Validation/runs/nvqmf1js
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230702_183025-nvqmf1js/logs
