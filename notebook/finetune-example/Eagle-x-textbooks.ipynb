# %% [markdown]
# # Eagle 7B : Finetuning on textbooks!
#
# The following showcases an example of Training the RWKV-v5 7B model, on tiny-strange-textbooks
# - https://huggingface.co/datasets/nampdn-ai/tiny-strange-textbooks
#
# In this example, we will be training the model with 16k sample sizes
#
# ## Configure the env variable below
# The default auto strategy, should work on a single 4090, scaling up all the way to 8xH100s

# %%
# -----------------------------------------------------------------
# Your configurable settings
# -----------------------------------------------------------------

# WANDB settings
ENABLE_WANDB=True
WANDB_PREFIX="RWKV-v5-Finetune"
WANDB_PROJECT="RWKV-v5-Finetune"

# Project directory offset (you need to modify if, you move the notebook into another dir)
PROJECT_DIR_OFFSET="../../"

# Config dir (relative to the notebook, excluding ending slash)
# to use, with the config filename
CONFIG_FILE_DIR="."
CONFIG_FILE_NAME="Eagle-x-textbooks"

# The model to use
MODEL_NAME="RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth"
MODEL_URL="https://huggingface.co/RWKV/v5-Eagle-7B/resolve/main/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth?download=true"

# GPU count to use
GPU_DEVICES="auto"

# -----------------------------------------------------------------
# Lets detect the GPU vram sizes, and suggest a resonable default
# based on the detected VRAM sizes
# -----------------------------------------------------------------
import torch
GPU_0_VRAM_SIZE_GB=torch.cuda.get_device_properties(0).total_memory / 1024**3
GPU_COUNT=torch.cuda.device_count()
if GPU_DEVICES != "auto":
    GPU_COUNT=int(GPU_DEVICES)
print("GPU_COUNT:", GPU_COUNT)
print("GPU_0_VRAM_SIZE (GB):", GPU_0_VRAM_SIZE_GB)

# -----------------------------------------------------------------
# Auto select the strategy based on the detected VRAM size
# -----------------------------------------------------------------

# Default settings
DEEPSPEED_STRAT="deepspeed_stage_2_offload"
TRAINING_CTX_LEN=2048
MICROBATCH_SIZE=1

if GPU_0_VRAM_SIZE_GB < 17:
    assert False, "For the Eagle-7B model, you need atleast 18GB vram"
elif GPU_0_VRAM_SIZE_GB < 23:
    # This takes about 17.5GB vram on a single GPU
    # We DO NOT recommend training with ctx_len=128, as the training
    # quality will degrade noticably. But it will work!
    DEEPSPEED_STRAT="deepspeed_stage_2_offload"
    TRAINING_CTX_LEN=128
    MICROBATCH_SIZE=1
elif GPU_0_VRAM_SIZE_GB < 25:
    # This takes about 21GB vram on a single GPU
    DEEPSPEED_STRAT="deepspeed_stage_2_offload"
    TRAINING_CTX_LEN=2048
    MICROBATCH_SIZE=2
elif GPU_0_VRAM_SIZE_GB < 78:
    # This takes about 23GB vram on a single GPU
    DEEPSPEED_STRAT="deepspeed_stage_2"
    TRAINING_CTX_LEN=4096
    MICROBATCH_SIZE=2
    if GPU_COUNT >= 8:
        MICROBATCH_SIZE=4
else:
    # This is now the 80GB vram class
    DEEPSPEED_STRAT="deepspeed_stage_2"
    TRAINING_CTX_LEN=4096
    MICROBATCH_SIZE=4
    if GPU_COUNT >= 8:
        MICROBATCH_SIZE=8

# -----------------------------------------------------------------
# # Training settings you can use to override the "auto" default above
# -----------------------------------------------------------------
# DEEPSPEED_STRAT="deepspeed_stage_1"
# TRAINING_CTX_LEN=4096
# MICROBATCH_SIZE=8

# ---
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("TRAINING_CTX_LEN:", TRAINING_CTX_LEN)
if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, PROJECT_DIR_OFFSET))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Check if the directory exists
if not os.path.exists(TRAINER_DIR):
    raise Exception("The trainer directory does not exists. Did you move the notebook?")
# Out:
# GPU_COUNT: 8
# GPU_0_VRAM_SIZE (GB): 79.10931396484375
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# DEEPSPEED_STRAT: deepspeed_stage_2
# TRAINING_CTX_LEN: 4096
# NOTEBOOK_DIR: /workspace/RWKV-infctx-trainer/notebook/finetune-example
# TRAINER_DIR: /workspace/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/RWKV-infctx-trainer

# %% [markdown]
# ## Lets download the model

# %%
# !cd "{PROJECT_DIR}" && mkdir -p "./model" && \
    cd "./model" && \
    wget -nc "{MODEL_URL}" -O "{MODEL_NAME}"
# Out:
# File ‘RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth’ already there; not retrieving.

# %%
# Lets preload the requried dataset
# !cd "{TRAINER_DIR}" && python3 preload_datapath.py "{NOTEBOOK_DIR}/{CONFIG_FILE_DIR}/{CONFIG_FILE_NAME}.yaml"
# Out:
# Downloading readme: 100%|██████████████████| 1.10k/1.10k [00:00<00:00, 7.56MB/s]
# Resolving data files: 100%|█████████████████| 1267/1267 [00:21<00:00, 60.05it/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 27.8MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 42.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 45.8MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 33.7MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:01<00:00, 4.03MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 41.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 22.6MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 28.9MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 11.8MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 41.0MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 25.7MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 33.4MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 10.1MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 24.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 22.4MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 32.1MB/s]
# Downloading data: 100%|████████████████████| 5.25M/5.25M [00:00<00:00, 29.1MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 24.5MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 38.2MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 26.4MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 22.7MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 17.0MB/s]
# Downloading data: 100%|████████████████████| 5.22M/5.22M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 7.69MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 21.5MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 26.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 22.7MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 30.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 22.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 27.4MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 9.11MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 28.9MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 8.90MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 24.0MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 47.0MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 25.2MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 10.5MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 18.5MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 6.62MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 31.8MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 14.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 20.5MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 29.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 9.09MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 12.9MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 27.6MB/s]
# Downloading data: 100%|████████████████████| 5.22M/5.22M [00:00<00:00, 28.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 31.5MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 26.2MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 30.9MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 33.1MB/s]
# Downloading data: 100%|████████████████████| 5.21M/5.21M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.23M/5.23M [00:00<00:00, 29.4MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 22.6MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 26.0MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 36.9MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 44.5MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 29.9MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 26.5MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 21.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 28.6MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 25.5MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 5.24M/5.24M [00:00<00:00, 26.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 32.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 28.9MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 31.1MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 33.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 13.9MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 28.3MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 35.4MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 44.7MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 39.7MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 22.0MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 13.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 32.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 32.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 22.9MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 25.4MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 13.4MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 24.5MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 39.1MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 31.5MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 30.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 28.4MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 40.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 23.6MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 8.52MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 29.4MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 30.0MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 32.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 9.50MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 24.8MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 25.6MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 31.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 29.0MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 27.0MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 34.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 29.0MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 11.3MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 28.1MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 29.7MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 40.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 24.6MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 24.5MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 24.5MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 24.9MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 32.8MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 23.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 16.5MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 41.0MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 41.6MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 23.9MB/s]
# Downloading data: 100%|████████████████████| 5.22M/5.22M [00:00<00:00, 13.8MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 27.1MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 18.5MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 31.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 27.9MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 30.2MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 37.4MB/s]
# Downloading data: 100%|████████████████████| 5.23M/5.23M [00:00<00:00, 28.1MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 22.0MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 5.33MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 24.5MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 28.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 21.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 27.7MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 29.0MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 23.1MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 32.5MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 37.9MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 28.4MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 26.4MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 27.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 28.3MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 30.1MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 36.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 36.3MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 29.5MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 28.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 22.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 37.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.7MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 29.3MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 13.9MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 26.7MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 22.4MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 31.6MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 38.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 36.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 26.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 28.5MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 37.6MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 24.4MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 9.53MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 29.0MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 40.0MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 27.5MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 24.6MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 32.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 40.1MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 30.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 27.6MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 26.5MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 24.9MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 3.85M/3.85M [00:00<00:00, 28.0MB/s]
# Downloading data: 100%|████████████████████| 4.67M/4.67M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.0MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 22.6MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 29.1MB/s]
# Downloading data: 100%|████████████████████| 4.14M/4.14M [00:00<00:00, 23.6MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 23.4MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 24.3MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 18.0MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 32.5MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 18.0MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 22.7MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 26.0MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 30.3MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 20.5MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 3.82M/3.82M [00:00<00:00, 12.8MB/s]
# Downloading data: 100%|████████████████████| 3.47M/3.47M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 3.53M/3.53M [00:00<00:00, 10.3MB/s]
# Downloading data: 100%|████████████████████| 3.49M/3.49M [00:00<00:00, 12.5MB/s]
# Downloading data: 100%|████████████████████| 3.50M/3.50M [00:00<00:00, 24.7MB/s]
# Downloading data: 100%|████████████████████| 3.59M/3.59M [00:00<00:00, 7.73MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 42.9MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 37.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 35.8MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 23.4MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 28.2MB/s]
# Downloading data: 100%|████████████████████| 3.57M/3.57M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 3.54M/3.54M [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|████████████████████| 3.54M/3.54M [00:00<00:00, 3.82MB/s]
# Downloading data: 100%|████████████████████| 4.28M/4.28M [00:00<00:00, 24.6MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 37.2MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 10.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 50.9MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 27.8MB/s]
# Downloading data: 100%|████████████████████| 4.34M/4.34M [00:00<00:00, 12.1MB/s]
# Downloading data: 100%|████████████████████| 3.49M/3.49M [00:00<00:00, 26.8MB/s]
# Downloading data: 100%|████████████████████| 4.19M/4.19M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 28.7MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 24.0MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 10.9MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 4.10M/4.10M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 3.56M/3.56M [00:00<00:00, 10.0MB/s]
# Downloading data: 100%|████████████████████| 3.54M/3.54M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 3.75M/3.75M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 22.8MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 35.1MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 30.4MB/s]
# Downloading data: 100%|████████████████████| 5.21M/5.21M [00:00<00:00, 41.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:01<00:00, 4.02MB/s]
# Downloading data: 100%|████████████████████| 3.58M/3.58M [00:00<00:00, 20.5MB/s]
# Downloading data: 100%|████████████████████| 3.54M/3.54M [00:00<00:00, 28.9MB/s]
# Downloading data: 100%|████████████████████| 3.56M/3.56M [00:00<00:00, 27.0MB/s]
# Downloading data: 100%|████████████████████| 3.68M/3.68M [00:00<00:00, 23.4MB/s]
# Downloading data: 100%|████████████████████| 3.61M/3.61M [00:00<00:00, 20.1MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 12.4MB/s]
# Downloading data: 100%|████████████████████| 5.23M/5.23M [00:00<00:00, 32.5MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 31.3MB/s]
# Downloading data: 100%|████████████████████| 5.21M/5.21M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 30.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 4.80M/4.80M [00:00<00:00, 30.7MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 45.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 29.2MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 27.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 19.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 41.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 13.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 31.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 36.8MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 12.3MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 7.65MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 29.3MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 25.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 25.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 31.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 29.8MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 23.9MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 30.3MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 26.3MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 18.5MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 10.2MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 23.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 14.1MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 6.44MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 24.3MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 34.8MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 28.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 7.98MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 44.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 42.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 33.7MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 33.2MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 40.7MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 33.1MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 23.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 44.8MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 30.1MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 25.5MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 12.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 25.3MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 42.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 22.7MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 24.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:01<00:00, 4.90MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 39.6MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 23.1MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 22.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 28.4MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 22.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 27.3MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 39.3MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 29.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 17.4MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 45.0MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 21.5MB/s]
# Downloading data: 100%|████████████████████| 5.23M/5.23M [00:00<00:00, 22.6MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 29.8MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 28.8MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 22.7MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 34.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:02<00:00, 2.12MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 22.9MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 24.4MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 25.3MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 28.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 26.0MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 30.8MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:01<00:00, 5.11MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 14.9MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 24.0MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 27.9MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 27.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 37.3MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 12.2MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 26.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 30.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 29.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 8.84MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 29.3MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 30.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 33.5MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 42.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 11.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 32.9MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 34.4MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 13.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 22.0MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 36.5MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 24.7MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 31.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 23.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 23.4MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 22.8MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 31.4MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 44.4MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 29.7MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 35.3MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 18.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 39.7MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 22.6MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 35.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 10.1MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 39.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 38.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 32.6MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 26.7MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 15.2MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 36.6MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 16.2MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 30.6MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 29.5MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 25.6MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 9.86MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 29.0MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 23.6MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 28.6MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 28.6MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 28.7MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 25.6MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 26.6MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 20.1MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 20.6MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 26.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 23.0MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 29.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 43.8MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 29.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 17.8MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 18.7MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 30.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 28.5MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 40.2MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 25.3MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 23.0MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 30.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 26.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 28.3MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 12.2MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 27.5MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 25.3MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 31.0MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 23.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.9MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 30.8MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 15.2MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 34.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 36.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 26.5MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 32.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 19.3MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 32.3MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 35.3MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 27.9MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:01<00:00, 4.20MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 24.7MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.4MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 24.5MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 6.25MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 22.6MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 31.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:01<00:00, 4.40MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 8.39MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 23.1MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 35.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 29.9MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 42.3MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 32.3MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 46.0MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 31.6MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 12.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.9MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 41.6MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 24.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 39.9MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 29.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 31.4MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 16.6MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 34.5MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 40.6MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 35.9MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 36.2MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 33.1MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 44.5MB/s]
# Downloading data: 100%|████████████████████| 4.94M/4.94M [00:00<00:00, 21.9MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 25.2MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 29.1MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 23.0MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 30.0MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 54.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 23.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 26.6MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 6.16MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 28.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 22.4MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 29.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 51.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 23.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 33.5MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 38.5MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 26.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 30.9MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 27.5MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 31.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 40.0MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 42.9MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 28.8MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 28.8MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 12.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 30.9MB/s]
# ...
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 30.7MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 26.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 25.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 21.4MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 29.7MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 23.0MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 28.0MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 21.5MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 13.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 26.4MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 12.5MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 22.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:01<00:00, 4.93MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 14.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 34.6MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 38.4MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 27.7MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 13.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 28.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 25.3MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 25.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 28.1MB/s]
# Downloading data: 100%|████████████████████| 4.88M/4.88M [00:00<00:00, 15.6MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 37.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 23.7MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 38.0MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 14.5MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 30.4MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:01<00:00, 4.07MB/s]
# Downloading data: 100%|████████████████████| 4.88M/4.88M [00:00<00:00, 29.6MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 31.3MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 16.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 37.3MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 30.6MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 30.8MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 37.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 25.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 23.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 27.2MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 23.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 21.4MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 22.7MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 27.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 27.2MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 20.5MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 8.16MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 43.1MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 18.7MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 28.2MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 29.1MB/s]
# Downloading data: 100%|████████████████████| 4.88M/4.88M [00:00<00:00, 27.1MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 26.8MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 35.9MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 4.87M/4.87M [00:00<00:00, 32.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 5.31MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 12.0MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 35.7MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 30.4MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 26.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 37.3MB/s]
# Downloading data: 100%|████████████████████| 4.87M/4.87M [00:00<00:00, 26.2MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 18.7MB/s]
# Downloading data: 100%|████████████████████| 4.84M/4.84M [00:00<00:00, 20.5MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 28.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 20.5MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 12.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 23.1MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 20.6MB/s]
# Downloading data: 100%|████████████████████| 4.94M/4.94M [00:00<00:00, 29.1MB/s]
# Downloading data: 100%|████████████████████| 4.88M/4.88M [00:00<00:00, 45.3MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 38.3MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 35.4MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 28.7MB/s]
# Downloading data: 100%|████████████████████| 4.82M/4.82M [00:00<00:00, 11.3MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 8.03MB/s]
# Downloading data: 100%|████████████████████| 4.85M/4.85M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 4.85M/4.85M [00:00<00:00, 21.5MB/s]
# Downloading data: 100%|████████████████████| 4.55M/4.55M [00:00<00:00, 30.1MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 14.9MB/s]
# Downloading data: 100%|████████████████████| 4.70M/4.70M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 40.2MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 3.90M/3.90M [00:00<00:00, 14.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 7.47MB/s]
# Downloading data: 100%|████████████████████| 4.86M/4.86M [00:00<00:00, 21.9MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 23.3MB/s]
# Downloading data: 100%|████████████████████| 4.46M/4.46M [00:00<00:00, 32.0MB/s]
# Downloading data: 100%|████████████████████| 4.89M/4.89M [00:00<00:00, 30.1MB/s]
# Downloading data: 100%|████████████████████| 4.81M/4.81M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 35.3MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 6.96MB/s]
# Downloading data: 100%|████████████████████| 4.55M/4.55M [00:00<00:00, 30.7MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 38.9MB/s]
# Downloading data: 100%|████████████████████| 4.84M/4.84M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 4.84M/4.84M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 4.94M/4.94M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 41.0MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 23.1MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 39.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 29.4MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 31.4MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 12.1MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 31.4MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 7.73MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 15.6MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 28.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 4.63M/4.63M [00:00<00:00, 12.3MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 30.7MB/s]
# Downloading data: 100%|████████████████████| 4.94M/4.94M [00:00<00:00, 35.8MB/s]
# Downloading data: 100%|████████████████████| 4.19M/4.19M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 4.28M/4.28M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 27.4MB/s]
# Downloading data: 100%|████████████████████| 4.19M/4.19M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 29.8MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 31.9MB/s]
# Downloading data: 100%|████████████████████| 4.79M/4.79M [00:00<00:00, 30.5MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 33.7MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 30.7MB/s]
# Downloading data: 100%|████████████████████| 4.45M/4.45M [00:00<00:00, 29.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 4.86M/4.86M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 16.5MB/s]
# Downloading data: 100%|████████████████████| 4.59M/4.59M [00:00<00:00, 29.1MB/s]
# Downloading data: 100%|████████████████████| 4.55M/4.55M [00:00<00:00, 21.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 25.7MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 11.9MB/s]
# Downloading data: 100%|████████████████████| 4.86M/4.86M [00:00<00:00, 24.6MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 29.7MB/s]
# Downloading data: 100%|████████████████████| 4.60M/4.60M [00:00<00:00, 11.3MB/s]
# Downloading data: 100%|████████████████████| 4.62M/4.62M [00:00<00:00, 29.9MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 12.6MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 8.70MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 4.85M/4.85M [00:00<00:00, 24.0MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 32.2MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 4.76M/4.76M [00:00<00:00, 29.1MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 18.2MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 41.9MB/s]
# Downloading data: 100%|████████████████████| 4.74M/4.74M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 36.5MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 16.5MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 38.4MB/s]
# Downloading data: 100%|████████████████████| 4.69M/4.69M [00:00<00:00, 26.5MB/s]
# Downloading data: 100%|████████████████████| 4.60M/4.60M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 4.77M/4.77M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 4.82M/4.82M [00:00<00:00, 13.1MB/s]
# Downloading data: 100%|████████████████████| 4.43M/4.43M [00:00<00:00, 28.9MB/s]
# Downloading data: 100%|████████████████████| 4.89M/4.89M [00:00<00:00, 23.2MB/s]
# Generating train split: 1268803 examples [00:27, 46827.82 examples/s]
# Map (num_proc=252): 100%|███| 1268803/1268803 [00:52<00:00, 24240.22 examples/s]
# Filter (num_proc=252): 100%|█| 1268803/1268803 [00:10<00:00, 115954.63 examples/
# Map (num_proc=252): 100%|███| 1268790/1268790 [00:22<00:00, 56732.92 examples/s]
# Map (num_proc=252): 100%|████████| 76483/76483 [00:11<00:00, 6906.37 examples/s]
# Map (num_proc=252): 100%|███████| 76483/76483 [00:02<00:00, 36324.90 examples/s]
# Map (num_proc=252): 100%|█████████████| 773/773 [00:02<00:00, 354.31 examples/s]
# Saving the dataset (16/16 shards): 100%|█| 76483/76483 [00:06<00:00, 11792.72 ex
# Saving the dataset (1/1 shards): 100%|█| 773/773 [00:00<00:00, 7066.72 examples/

# %% [markdown]
# ## Start the training run!

# %%
# Setup the checkpoint dir
# !cd "{PROJECT_DIR}" && mkdir -p "./checkpoint/{CONFIG_FILE_NAME}/"

# Lets start the training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/{CONFIG_FILE_DIR}/{CONFIG_FILE_NAME}.yaml" \
        --model.load_model="../model/{MODEL_NAME}" \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="../checkpoint/{CONFIG_FILE_NAME}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - {CONFIG_FILE_NAME} (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.target_batch_size=64 \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-01-31 13:02:54,007] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-textbooks.yaml', '--model.load_model=../model/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=../checkpoint/Eagle-x-textbooks/', '--trainer.logger.init_args.name=Eagle-X-Training - Eagle-x-textbooks (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-v5-Finetune', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=64', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-textbooks.yaml', '--model.load_model=../model/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=../checkpoint/Eagle-x-textbooks/', '--trainer.logger.init_args.name=Eagle-X-Training - Eagle-x-textbooks (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-v5-Finetune', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=64', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'].
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/utilities/seed.py:40: No seed found, seed set to 353897075
# Seed set to 353897075
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       64
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         8
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    64
#
# [rank: 0] Seed set to 353897075
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-01-31 13:03:59,926] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-01-31 13:04:00,185] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-01-31 13:04:00,262] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-01-31 13:04:00,287] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-01-31 13:04:00,401] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-01-31 13:04:00,635] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [2024-01-31 13:04:00,833] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [rank: 1] Seed set to 353897075
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 353897075
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 353897075
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 353897075
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 353897075
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 353897075
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 6] Seed set to 353897075
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/wkv5/build.ninja...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/wkv5/build.ninja...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/wkv5/build.ninja...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# [rank: 1] Seed set to 353897075
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [rank: 3] Seed set to 353897075
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 4] Seed set to 353897075
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [rank: 7] Seed set to 353897075
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 5] Seed set to 353897075
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 6] Seed set to 353897075
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [rank: 2] Seed set to 353897075
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240131_130539-qkcoz6ph
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Eagle-X-Training - Eagle-x-textbooks (tctxlen=4096, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune/runs/qkcoz6ph
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
#
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
#
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  5.000e-05 (5e-05)
#     - lr_final: 5.000e-05 (5e-05)
#
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.12548398971557617 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.20168566703796387 seconds
# Time to load fused_adam op: 0.20176315307617188 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.2018299102783203 seconds
# Loading extension module fused_adam...Loading extension module fused_adam.../usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
# Loading extension module fused_adam...
#
# Time to load fused_adam op: 0.20259308815002441 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 0.2029120922088623 seconds
# Time to load fused_adam op: 0.2031393051147461 seconds
# Time to load fused_adam op: 0.20351624488830566 seconds
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /usr/local/lib/python3.10/dist-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 268 M
# 1 | blocks | ModuleList | 7.0 B
# 2 | ln_out | LayerNorm  | 8.2 K
# 3 | head   | Linear     | 268 M
# --------------------------------------
# 7.5 B     Trainable params
# 0         Non-trainable params
# 7.5 B     Total params
# 30,072.177Total estimated model params size (MB)
# Epoch 0:   2%| | 20/1196 [16:06<15:47:30,  0.02it/s, v_num=z6ph, train/loss=0.93^C

# %% [markdown]
# ## Export the model

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/{CONFIG_FILE_NAME}/last.ckpt" "../model/{CONFIG_FILE_NAME}.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/{CONFIG_FILE_NAME}.pth"
# Out:
# [2024-01-31 12:39:24,276] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/Eagle-x-tiny-textbook/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage 2, world_size: 8
# Parsing checkpoint created by deepspeed==0.12.6
# Reconstructed fp32 state dict with 710 params 7518044160 elements
# Saving bf16 state dict to ../model/Eagle-x-tiny-textbook.pth
# -rw-r--r-- 1 root root 15G Jan 31 12:40 ../model/Eagle-x-tiny-textbook.pth

# %% [markdown]
# ## Sanity check (that the model actually output stuff)

# %%
# Lets do a quick dragon prompt validation
# !cd "{TRAINER_DIR}" && \
    python3 dragon_test.py "../model/{CONFIG_FILE_NAME}.pth" "cuda bf16"
# Out:
# [2024-01-31 12:40:23,791] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [SimpleRWKV] Warning: dtype mismatch, only fp32 is supported (for now)
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# /workspace/RWKV-infctx-trainer/RWKV-v5/src/model.py:1448: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_tokens = torch.tensor(
# --- DRAGON PROMPT ---
# In a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese. What they didn't know was that the dragons were actually a lost tribe of Chinese refugees.
# 2. The Most Famous Author In The World
# By 2020, only one book would be read by every person on the planet. It was a book about dragons that had sold more than a trillion copies. It was called "The Dragon's Guide to the Perfectly Perfect Life."
# 3. The World's First Online Poker Tournament
# In 2019, a group of online poker enthusiasts got together to hold the world's first online poker tournament. The event was a huge success, with more than 10,000 players from around the world participating.
# 4. The Most Expensive Novel Ever Written
# In 2019, a man named William Shakespeare wrote a novel called "The Most Expensive Novel Ever Written." The book sold for $500 million.
# 5. The Most Popular TV Show Ever
# In 2019, a new TV show called "The Most Popular TV Show Ever
