# %% [markdown]
# # Eagle 7B : Finetuning on textbooks!
#
# The following showcases an example of Training the RWKV-v5 7B model, on tiny-strange-textbooks
# - https://huggingface.co/datasets/nampdn-ai/tiny-strange-textbooks
#
# In this example, we will be training the model with 16k sample sizes
#
# ## Configure the env variable below
# The default auto strategy, should work on a single 4090, scaling up all the way to 8xH100s

# %%
# -----------------------------------------------------------------
# Your configurable settings
# -----------------------------------------------------------------

# WANDB settings
ENABLE_WANDB=True
WANDB_PREFIX="RWKV-v5-Finetune"
WANDB_PROJECT="RWKV-v5-Finetune"

# Project directory offset (you need to modify if, you move the notebook into another dir)
PROJECT_DIR_OFFSET="../../"

# Config dir (relative to the notebook, excluding ending slash)
# to use, with the config filename
CONFIG_FILE_DIR="."
CONFIG_FILE_NAME="Eagle-x-textbooks"

# The model to use
MODEL_NAME="RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth"
MODEL_URL="https://huggingface.co/RWKV/v5-Eagle-7B/resolve/main/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth?download=true"

# GPU count to use
GPU_DEVICES="auto"

# -----------------------------------------------------------------
# Lets detect the GPU vram sizes, and suggest a resonable default
# based on the detected VRAM sizes
# -----------------------------------------------------------------

# Default settings
# NOTE: If your not using cuda, you may want to manually change this around
DEEPSPEED_STRAT="deepspeed_stage_2"
TRAINING_CTX_LEN=2048
MICROBATCH_SIZE=1

import torch
if torch.cuda is None or not torch.cuda.is_available() or torch.cuda.device_count() <= 0:
    print("No CUDA compatible GPU found, using default settings")
else:
    # -----------------------------------------------------------------
    # Auto select the strategy based on the detected VRAM size
    # -----------------------------------------------------------------

    GPU_COUNT=torch.cuda.device_count()
    GPU_0_VRAM_SIZE_GB=torch.cuda.get_device_properties(0).total_memory / 1024**3
    if GPU_DEVICES != "auto":
        GPU_COUNT=int(GPU_DEVICES)
    print("GPU_COUNT:", GPU_COUNT)
    print("GPU_0_VRAM_SIZE (GB):", GPU_0_VRAM_SIZE_GB)

    if GPU_0_VRAM_SIZE_GB < 17:
        assert False, "For the Eagle-7B model, you need atleast 18GB vram"
    elif GPU_0_VRAM_SIZE_GB < 23:
        # This takes about 17.5GB vram on a single GPU
        # We DO NOT recommend training with ctx_len=128, as the training
        # quality will degrade noticably. But it will work!
        DEEPSPEED_STRAT="deepspeed_stage_2_offload"
        TRAINING_CTX_LEN=128
        MICROBATCH_SIZE=1
    elif GPU_0_VRAM_SIZE_GB < 25:
        # This takes about 21GB vram on a single GPU
        DEEPSPEED_STRAT="deepspeed_stage_2_offload"
        TRAINING_CTX_LEN=2048
        MICROBATCH_SIZE=2
    elif GPU_0_VRAM_SIZE_GB < 78:
        # This takes about 23GB vram on a single GPU
        DEEPSPEED_STRAT="deepspeed_stage_2"
        TRAINING_CTX_LEN=4096
        MICROBATCH_SIZE=2
        if GPU_COUNT >= 8:
            MICROBATCH_SIZE=4
    else:
        # This is now the 80GB vram class
        DEEPSPEED_STRAT="deepspeed_stage_2"
        TRAINING_CTX_LEN=4096
        MICROBATCH_SIZE=4
        if GPU_COUNT >= 8:
            MICROBATCH_SIZE=8

# -----------------------------------------------------------------
# # Training settings you can use to override the "auto" default above
# -----------------------------------------------------------------
# DEEPSPEED_STRAT="deepspeed_stage_1"
# TRAINING_CTX_LEN=4096
# MICROBATCH_SIZE=8

# ---
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("TRAINING_CTX_LEN:", TRAINING_CTX_LEN)
if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, PROJECT_DIR_OFFSET))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Check if the directory exists
if not os.path.exists(TRAINER_DIR):
    raise Exception("The trainer directory does not exists. Did you move the notebook?")
# Out:
# GPU_COUNT: 8
# GPU_0_VRAM_SIZE (GB): 79.10943603515625
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# DEEPSPEED_STRAT: deepspeed_stage_2
# TRAINING_CTX_LEN: 4096
# NOTEBOOK_DIR: /workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example
# TRAINER_DIR: /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/picocreator/RWKV-infctx-trainer

# %% [markdown]
# ## Lets download the model

# %%
# !cd "{PROJECT_DIR}" && mkdir -p "./model" && \
    cd "./model" && \
    wget -nc "{MODEL_URL}" -O "{MODEL_NAME}"
# Out:
# File ‘RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth’ already there; not retrieving.

# %%
# Lets preload the requried dataset
# !cd "{TRAINER_DIR}" && python3 preload_datapath.py "{NOTEBOOK_DIR}/{CONFIG_FILE_DIR}/{CONFIG_FILE_NAME}.yaml"
# Out:
# Downloading readme: 100%|██████████████████| 1.10k/1.10k [00:00<00:00, 12.8MB/s]
# Resolving data files: 100%|███████████████| 1267/1267 [00:00<00:00, 2591.88it/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 7.67MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 5.96MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 5.30MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 8.45MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 6.00MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 6.90MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 8.37MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 17.4MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 11.8MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 17.8MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 6.90MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 12.6MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 16.6MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 5.26MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 12.6MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 5.25M/5.25M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 19.3MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 18.5MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 18.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.22M/5.22M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 19.3MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 12.9MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 22.0MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 17.4MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 25.7MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 11.4MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 22.8MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 20.1MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:01<00:00, 4.32MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 15.6MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 16.2MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 23.1MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 15.6MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 12.5MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 5.45MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.22M/5.22M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 10.1MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.21M/5.21M [00:00<00:00, 17.8MB/s]
# Downloading data: 100%|████████████████████| 5.23M/5.23M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.6MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.5MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 8.28MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 11.6MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 5.38MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 14.6MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 14.7MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 13.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 12.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 15.3MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 5.24M/5.24M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 12.8MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 16.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 5.49MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 13.5MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 9.67MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 12.0MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 13.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 9.97MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 17.0MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 5.44MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 13.0MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 5.30MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 22.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 16.5MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 24.8MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 15.3MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 13.7MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 19.3MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 14.6MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 12.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 12.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 22.4MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 14.6MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:01<00:00, 5.14MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 11.7MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 14.5MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 13.9MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 26.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 13.8MB/s]
# Downloading data: 100%|████████████████████| 5.22M/5.22M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 17.4MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 23.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 5.23M/5.23M [00:00<00:00, 13.4MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 17.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 12.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 23.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 8.63MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.6MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 12.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 23.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 23.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 10.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 13.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 25.2MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 14.6MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 17.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 9.70MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 16.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 17.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 14.7MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.1MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 23.2MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 16.6MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 7.06MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 13.9MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 3.85M/3.85M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 4.67M/4.67M [00:00<00:00, 14.7MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 14.0MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 4.14M/4.14M [00:00<00:00, 11.5MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:01<00:00, 4.56MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 17.2MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 5.48MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 5.03MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 13.3MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 11.5MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 13.1MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 14.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 3.82M/3.82M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 3.47M/3.47M [00:00<00:00, 13.7MB/s]
# Downloading data: 100%|████████████████████| 3.53M/3.53M [00:00<00:00, 13.9MB/s]
# Downloading data: 100%|████████████████████| 3.49M/3.49M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 3.50M/3.50M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 3.59M/3.59M [00:00<00:00, 12.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 14.5MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 15.2MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 17.0MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 22.7MB/s]
# Downloading data: 100%|████████████████████| 3.57M/3.57M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 3.54M/3.54M [00:00<00:00, 13.8MB/s]
# Downloading data: 100%|████████████████████| 3.54M/3.54M [00:00<00:00, 13.5MB/s]
# Downloading data: 100%|████████████████████| 4.28M/4.28M [00:00<00:00, 14.7MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 4.34M/4.34M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 3.49M/3.49M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 4.19M/4.19M [00:00<00:00, 11.6MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 22.4MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 4.10M/4.10M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 3.56M/3.56M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 3.54M/3.54M [00:00<00:00, 11.8MB/s]
# Downloading data: 100%|████████████████████| 3.75M/3.75M [00:01<00:00, 3.58MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 9.83MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.21M/5.21M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 3.58M/3.58M [00:00<00:00, 17.4MB/s]
# Downloading data: 100%|████████████████████| 3.54M/3.54M [00:00<00:00, 13.8MB/s]
# Downloading data: 100%|████████████████████| 3.56M/3.56M [00:00<00:00, 16.6MB/s]
# Downloading data: 100%|████████████████████| 3.68M/3.68M [00:00<00:00, 16.2MB/s]
# Downloading data: 100%|████████████████████| 3.61M/3.61M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 5.23M/5.23M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.21M/5.21M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 15.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 14.1MB/s]
# Downloading data: 100%|████████████████████| 4.80M/4.80M [00:00<00:00, 22.0MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 25.0MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 11.1MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 11.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 23.1MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 13.3MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 22.0MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 17.8MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 17.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.2MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 13.7MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 14.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 11.4MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 20.1MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 11.0MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 11.3MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 25.3MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 5.43MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 11.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 12.2MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 13.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 12.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 22.6MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 15.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 24.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 14.1MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 19.3MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 12.6MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 23.7MB/s]
# Downloading data: 100%|████████████████████| 5.23M/5.23M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 9.98MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 24.6MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 13.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 5.17MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 23.3MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 17.4MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 17.2MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 24.0MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 18.7MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 18.0MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 5.35MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.4MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 5.43MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:02<00:00, 2.47MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 5.41MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 11.6MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 23.7MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 12.2MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 18.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 14.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 15.3MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 16.5MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.17M/5.17M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.20M/5.20M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 12.3MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 18.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 13.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 13.4MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 11.7MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 10.8MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 23.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 12.1MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 5.32MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 11.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 19.3MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 14.9MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 13.5MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 18.2MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 14.6MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 21.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 22.0MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 8.79MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 15.2MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 20.4MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 15.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 14.9MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 9.88MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 5.18M/5.18M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 21.1MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 11.7MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 22.3MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 23.1MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 22.2MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 15.3MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 19.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 12.8MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 21.5MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 24.2MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 11.6MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 22.1MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 19.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 14.1MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 10.9MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 18.2MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 22.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 14.0MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 15.6MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 5.33MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 12.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 17.2MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 11.7MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 13.9MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 17.0MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 23.3MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 21.4MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 23.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 14.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 9.45MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 5.14MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 23.2MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 7.80MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 14.7MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 25.5MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 5.21MB/s]
# Downloading data: 100%|████████████████████| 4.94M/4.94M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 17.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 12.6MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 13.8MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 12.8MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 21.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 15.5MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 16.2MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 20.9MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 17.0MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 5.31MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.2MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 23.6MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 6.00MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 18.2MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 5.42MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 15.3MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 9.02MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 23.0MB/s]
# ...
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 20.6MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 23.3MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 23.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 14.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 17.3MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 18.7MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 8.53MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 6.04MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 13.5MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 5.06M/5.06M [00:00<00:00, 18.0MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 20.3MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 14.5MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 22.5MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 12.8MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 11.2MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 19.4MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 10.2MB/s]
# Downloading data: 100%|████████████████████| 5.19M/5.19M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 18.2MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 17.3MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 15.6MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 5.37MB/s]
# Downloading data: 100%|████████████████████| 4.88M/4.88M [00:00<00:00, 10.4MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 14.1MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 14.6MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 17.8MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 23.8MB/s]
# Downloading data: 100%|████████████████████| 5.15M/5.15M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 4.88M/4.88M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 5.36MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 7.11MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 21.0MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 5.14M/5.14M [00:00<00:00, 24.9MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 18.2MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 20.8MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 18.4MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 12.3MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 21.5MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 5.32MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 13.9MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 12.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 17.2MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 20.6MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:01<00:00, 4.29MB/s]
# Downloading data: 100%|████████████████████| 4.88M/4.88M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.03M/5.03M [00:00<00:00, 13.9MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 13.8MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 13.7MB/s]
# Downloading data: 100%|████████████████████| 4.87M/4.87M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 14.9MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.04M/5.04M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 15.2MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 16.3MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 4.87M/4.87M [00:00<00:00, 16.7MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 12.2MB/s]
# Downloading data: 100%|████████████████████| 4.84M/4.84M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 5.27MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|████████████████████| 4.95M/4.95M [00:00<00:00, 20.6MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 14.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 14.7MB/s]
# Downloading data: 100%|████████████████████| 4.94M/4.94M [00:00<00:00, 10.0MB/s]
# Downloading data: 100%|████████████████████| 4.88M/4.88M [00:00<00:00, 13.7MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 19.2MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 20.0MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 4.82M/4.82M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 4.85M/4.85M [00:00<00:00, 8.29MB/s]
# Downloading data: 100%|████████████████████| 4.85M/4.85M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 4.55M/4.55M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 17.8MB/s]
# Downloading data: 100%|████████████████████| 4.70M/4.70M [00:00<00:00, 4.94MB/s]
# Downloading data: 100%|████████████████████| 5.11M/5.11M [00:00<00:00, 5.42MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 3.90M/3.90M [00:00<00:00, 17.3MB/s]
# Downloading data: 100%|████████████████████| 5.10M/5.10M [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 4.86M/4.86M [00:03<00:00, 1.50MB/s]
# Downloading data: 100%|████████████████████| 4.91M/4.91M [00:00<00:00, 11.8MB/s]
# Downloading data: 100%|████████████████████| 4.46M/4.46M [00:00<00:00, 13.1MB/s]
# Downloading data: 100%|████████████████████| 4.89M/4.89M [00:00<00:00, 17.9MB/s]
# Downloading data: 100%|████████████████████| 4.81M/4.81M [00:00<00:00, 14.3MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 20.2MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 21.5MB/s]
# Downloading data: 100%|████████████████████| 4.55M/4.55M [00:00<00:00, 17.5MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 18.8MB/s]
# Downloading data: 100%|████████████████████| 4.84M/4.84M [00:00<00:00, 14.9MB/s]
# Downloading data: 100%|████████████████████| 4.84M/4.84M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 4.94M/4.94M [00:00<00:00, 14.6MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 15.2MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 16.8MB/s]
# Downloading data: 100%|████████████████████| 5.16M/5.16M [00:00<00:00, 19.6MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.09M/5.09M [00:00<00:00, 12.2MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 12.4MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 23.4MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 14.4MB/s]
# Downloading data: 100%|████████████████████| 5.12M/5.12M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 19.8MB/s]
# Downloading data: 100%|████████████████████| 5.13M/5.13M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 4.63M/4.63M [00:00<00:00, 18.3MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 15.8MB/s]
# Downloading data: 100%|████████████████████| 5.07M/5.07M [00:00<00:00, 17.1MB/s]
# Downloading data: 100%|████████████████████| 4.94M/4.94M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 4.19M/4.19M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 4.28M/4.28M [00:00<00:00, 16.9MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 16.4MB/s]
# Downloading data: 100%|████████████████████| 4.19M/4.19M [00:00<00:00, 17.6MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 10.5MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 16.0MB/s]
# Downloading data: 100%|████████████████████| 4.79M/4.79M [00:00<00:00, 18.6MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 14.2MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 21.3MB/s]
# Downloading data: 100%|████████████████████| 4.45M/4.45M [00:00<00:00, 5.14MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 4.86M/4.86M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 13.6MB/s]
# Downloading data: 100%|████████████████████| 4.59M/4.59M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 4.55M/4.55M [00:00<00:00, 10.6MB/s]
# Downloading data: 100%|████████████████████| 5.08M/5.08M [00:00<00:00, 12.1MB/s]
# Downloading data: 100%|████████████████████| 5.01M/5.01M [00:00<00:00, 12.9MB/s]
# Downloading data: 100%|████████████████████| 4.86M/4.86M [00:00<00:00, 23.2MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 17.7MB/s]
# Downloading data: 100%|████████████████████| 4.60M/4.60M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 4.62M/4.62M [00:00<00:00, 15.4MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 18.9MB/s]
# Downloading data: 100%|████████████████████| 4.98M/4.98M [00:00<00:00, 15.9MB/s]
# Downloading data: 100%|████████████████████| 4.93M/4.93M [00:00<00:00, 18.1MB/s]
# Downloading data: 100%|████████████████████| 5.02M/5.02M [00:00<00:00, 17.3MB/s]
# Downloading data: 100%|████████████████████| 4.85M/4.85M [00:00<00:00, 19.1MB/s]
# Downloading data: 100%|████████████████████| 5.00M/5.00M [00:00<00:00, 15.7MB/s]
# Downloading data: 100%|████████████████████| 4.97M/4.97M [00:00<00:00, 15.1MB/s]
# Downloading data: 100%|████████████████████| 5.05M/5.05M [00:00<00:00, 12.4MB/s]
# Downloading data: 100%|████████████████████| 4.76M/4.76M [00:00<00:00, 11.2MB/s]
# Downloading data: 100%|████████████████████| 4.92M/4.92M [00:00<00:00, 14.8MB/s]
# Downloading data: 100%|████████████████████| 4.96M/4.96M [00:00<00:00, 21.2MB/s]
# Downloading data: 100%|████████████████████| 4.74M/4.74M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 19.5MB/s]
# Downloading data: 100%|████████████████████| 4.90M/4.90M [00:00<00:00, 20.7MB/s]
# Downloading data: 100%|████████████████████| 4.99M/4.99M [00:00<00:00, 14.6MB/s]
# Downloading data: 100%|████████████████████| 4.69M/4.69M [00:00<00:00, 22.8MB/s]
# Downloading data: 100%|████████████████████| 4.60M/4.60M [00:00<00:00, 19.0MB/s]
# Downloading data: 100%|████████████████████| 4.77M/4.77M [00:00<00:00, 20.5MB/s]
# Downloading data: 100%|████████████████████| 4.82M/4.82M [00:00<00:00, 17.3MB/s]
# Downloading data: 100%|████████████████████| 4.43M/4.43M [00:00<00:00, 19.9MB/s]
# Downloading data: 100%|████████████████████| 4.89M/4.89M [00:00<00:00, 14.8MB/s]
# Generating train split: 1268803 examples [00:09, 139361.35 examples/s]
# Map (num_proc=160): 100%|███| 1268803/1268803 [00:51<00:00, 24663.48 examples/s]
# Filter (num_proc=160): 100%|█| 1268803/1268803 [00:13<00:00, 97013.11 examples/s
# Map (num_proc=160): 100%|███| 1268790/1268790 [00:36<00:00, 34777.07 examples/s]
# Map (num_proc=160): 100%|████████| 76543/76543 [00:25<00:00, 3018.38 examples/s]
# Map (num_proc=160): 100%|████████| 76543/76543 [00:18<00:00, 4121.97 examples/s]
# Map (num_proc=160): 100%|████████████| 774/774 [00:00<00:00, 1331.23 examples/s]
# Saving the dataset (16/16 shards): 100%|█| 76543/76543 [00:27<00:00, 2773.70 exa
# Saving the dataset (1/1 shards): 100%|█| 774/774 [00:00<00:00, 3993.48 examples/

# %% [markdown]
# ## Start the training run!

# %%
# Setup the checkpoint dir
# !cd "{PROJECT_DIR}" && mkdir -p "./checkpoint/{CONFIG_FILE_NAME}/"

# Lets start the training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/{CONFIG_FILE_DIR}/{CONFIG_FILE_NAME}.yaml" \
        --model.load_model="../model/{MODEL_NAME}" \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="../checkpoint/{CONFIG_FILE_NAME}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - {CONFIG_FILE_NAME} (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.target_batch_size=64 \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-02 08:24:28,979] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-textbooks.yaml', '--model.load_model=../model/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=../checkpoint/Eagle-x-textbooks/', '--trainer.logger.init_args.name=RWKV-v5-Finetune - Eagle-x-textbooks (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-v5-Finetune', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=64', '--trainer.microbatch_size=7', '--model.ctx_len=4096', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-textbooks.yaml', '--model.load_model=../model/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=../checkpoint/Eagle-x-textbooks/', '--trainer.logger.init_args.name=RWKV-v5-Finetune - Eagle-x-textbooks (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-v5-Finetune', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=64', '--trainer.microbatch_size=7', '--model.ctx_len=4096', '--trainer.devices=auto'].
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/utilities/seed.py:40: No seed found, seed set to 1023964978
# Seed set to 1023964978
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu121/wkv5...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] c++ -MMD -MF wkv5_op.o.d -DTORCH_EXTENSION_NAME=wkv5 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/TH -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /root/miniconda3/envs/rwkv-infctx/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -c /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/cuda/wkv5_op.cpp -o wkv5_op.o
# /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/cuda/wkv5_op.cpp:48:51: note: ‘#pragma message: No SIMD is supported’
#    48 |             #pragma message("No SIMD is supported")
#       |                                                   ^
# [2/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=wkv5 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/TH -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /root/miniconda3/envs/rwkv-infctx/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_90,code=compute_90 -gencode=arch=compute_90,code=sm_90 --compiler-options '-fPIC' -res-usage --use_fast_math -O3 -Xptxas -O3 --extra-device-vectorization -D_N_=64 -std=c++17 -c /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/module/cuda/wkv5_cuda.cu -o wkv5_cuda.cuda.o
# ptxas info    : 1 bytes gmem
# ptxas info    : Compiling entry function '_Z15kernel_backwardIfEviiiiPfPKT_S3_S3_PKfS5_S3_S3_PS1_S6_S6_S6_S6_' for 'sm_90'
# ptxas info    : Function properties for _Z15kernel_backwardIfEviiiiPfPKT_S3_S3_PKfS5_S3_S3_PS1_S6_S6_S6_S6_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 166 registers, 1536 bytes smem
# ptxas info    : Compiling entry function '_Z15kernel_backwardIN3c104HalfEEviiiiPfPKT_S5_S5_PKfS7_S5_S5_PS3_S8_S8_S8_S8_' for 'sm_90'
# ptxas info    : Function properties for _Z15kernel_backwardIN3c104HalfEEviiiiPfPKT_S5_S5_PKfS7_S5_S5_PS3_S8_S8_S8_S8_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 166 registers, 1536 bytes smem
# ptxas info    : Compiling entry function '_Z15kernel_backwardIN3c108BFloat16EEviiiiPfPKT_S5_S5_PKfS7_S5_S5_PS3_S8_S8_S8_S8_' for 'sm_90'
# ptxas info    : Function properties for _Z15kernel_backwardIN3c108BFloat16EEviiiiPfPKT_S5_S5_PKfS7_S5_S5_PS3_S8_S8_S8_S8_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 166 registers, 1536 bytes smem
# ptxas info    : Compiling entry function '_Z24kernel_forward_inferenceIfEviiiiPfPKT_S3_S3_PKfS3_PS1_' for 'sm_90'
# ptxas info    : Function properties for _Z24kernel_forward_inferenceIfEviiiiPfPKT_S3_S3_PKfS3_PS1_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 130 registers, 1024 bytes smem
# ptxas info    : Compiling entry function '_Z24kernel_forward_inferenceIN3c104HalfEEviiiiPfPKT_S5_S5_PKfS5_PS3_' for 'sm_90'
# ptxas info    : Function properties for _Z24kernel_forward_inferenceIN3c104HalfEEviiiiPfPKT_S5_S5_PKfS5_PS3_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 131 registers, 1024 bytes smem
# ptxas info    : Compiling entry function '_Z24kernel_forward_inferenceIN3c108BFloat16EEviiiiPfPKT_S5_S5_PKfS5_PS3_' for 'sm_90'
# ptxas info    : Function properties for _Z24kernel_forward_inferenceIN3c108BFloat16EEviiiiPfPKT_S5_S5_PKfS5_PS3_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 131 registers, 1024 bytes smem
# ptxas info    : Compiling entry function '_Z15kernelc_mm8_oneIfEvyyPKT_PKhyPfPKfS7_yy' for 'sm_90'
# ptxas info    : Function properties for _Z15kernelc_mm8_oneIfEvyyPKT_PKhyPfPKfS7_yy
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 32 registers
# [3/3] c++ wkv5_op.o wkv5_cuda.cuda.o -shared -L/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o wkv5.so
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       64
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         7
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    56
#
# [rank: 0] Seed set to 1023964978
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-02 08:25:29,525] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 08:25:29,590] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 08:25:29,620] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 08:25:29,621] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 08:25:29,645] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 08:25:29,709] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 08:25:29,712] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [rank: 1] Seed set to 1023964978
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 6] Seed set to 1023964978
# [rank: 3] Seed set to 1023964978
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 1023964978
# [rank: 4] Seed set to 1023964978
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 1023964978
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 1023964978
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# [rank: 3] Seed set to 1023964978
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 5] Seed set to 1023964978
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 2] Seed set to 1023964978
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 7] Seed set to 1023964978
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 4] Seed set to 1023964978
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [rank: 1] Seed set to 1023964978
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [rank: 6] Seed set to 1023964978
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240202_082635-ejk6yuup
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RWKV-v5-Finetune - Eagle-x-textbooks (tctxlen=4096, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune/runs/ejk6yuup
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  5.000e-05 (5e-05)
#     - lr_final: 5.000e-05 (5e-05)
#
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
#
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...Creating extension directory /root/.cache/torch_extensions/py311_cu121/fused_adam...
# Creating extension directory /root/.cache/torch_extensions/py311_cu121/fused_adam...
#
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/csrc/includes -I/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/csrc/adam -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/TH -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /root/miniconda3/envs/rwkv-infctx/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_90,code=compute_90 -gencode=arch=compute_90,code=sm_90 --compiler-options '-fPIC' -O3 -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -lineinfo --use_fast_math -gencode=arch=compute_90,code=sm_90 -gencode=arch=compute_90,code=compute_90 -DBF16_AVAILABLE -U__CUDA_NO_BFLOAT16_OPERATORS__ -U__CUDA_NO_BFLOAT162_OPERATORS__ -std=c++17 -c /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/csrc/adam/multi_tensor_adam.cu -o multi_tensor_adam.cuda.o
# [2/3] c++ -MMD -MF fused_adam_frontend.o.d -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/csrc/includes -I/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/csrc/adam -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/torch/csrc/api/include -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/TH -isystem /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /root/miniconda3/envs/rwkv-infctx/include/python3.11 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -O3 -std=c++17 -g -Wno-reorder -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -DBF16_AVAILABLE -c /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/csrc/adam/fused_adam_frontend.cpp -o fused_adam_frontend.o
# [3/3] c++ fused_adam_frontend.o multi_tensor_adam.cuda.o -shared -L/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o fused_adam.so
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.2004451751709 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.21921157836914 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.22280478477478 seconds
# Time to load fused_adam op: 20.22321367263794 seconds
# Loading extension module fused_adam...
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 20.222553491592407 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Time to load fused_adam op: 20.223615884780884 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...
# Time to load fused_adam op: 20.224947214126587 seconds
# Time to load fused_adam op: 20.224921464920044 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 268 M
# 1 | blocks | ModuleList | 7.0 B
# 2 | ln_out | LayerNorm  | 8.2 K
# 3 | head   | Linear     | 268 M
# --------------------------------------
# 7.5 B     Trainable params
# 0         Non-trainable params
# 7.5 B     Total params
# 30,072.177Total estimated model params size (MB)
# Epoch 0:  23%|▏| 320/1367 [1:27:06<4:45:00,  0.06it/s, v_num=yuup, train/loss=0.^C
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...

# %% [markdown]
# ## Export the model

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/{CONFIG_FILE_NAME}/last.ckpt" "../model/{CONFIG_FILE_NAME}.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/{CONFIG_FILE_NAME}.pth"
# Out:
# [2024-02-02 07:30:25,424] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Traceback (most recent call last):
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/export_checkpoint.py", line 651, in <module>
#     convert_zero_checkpoint_to_fp32_state_dict(args.checkpoint_dir, output_file, save_dtype=args.dtype)
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/export_checkpoint.py", line 542, in convert_zero_checkpoint_to_fp32_state_dict
#     state_dict = get_fp32_state_dict_from_zero_checkpoint(checkpoint_dir, tag)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/export_checkpoint.py", line 516, in get_fp32_state_dict_from_zero_checkpoint
#     raise ValueError(f"Unable to find 'latest' file at {latest_path}")
# ValueError: Unable to find 'latest' file at ../checkpoint/Eagle-x-textbooks/last.ckpt/latest
# ls: cannot access '../model/Eagle-x-textbooks.pth': No such file or directory

# %% [markdown]
# ## Sanity check (that the model actually output stuff)

# %%
# Lets do a quick dragon prompt validation
# !cd "{TRAINER_DIR}" && \
    python3 dragon_test.py "../model/{CONFIG_FILE_NAME}.pth" "cuda bf16"
# Out:
# [2024-02-02 07:30:29,014] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [SimpleRWKV] Warning: dtype mismatch, only fp32 is supported (for now)
# Traceback (most recent call last):
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/dragon_test.py", line 57, in <module>
#     model = SimpleRWKV(MODEL_PATH, device=DEVICE, dtype=DTYPE)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 1391, in __init__
#     self.model = RWKV(**model_config)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py", line 238, in __init__
#     raise ValueError(f"load_model file '{load_model}' does not exist")
# ValueError: load_model file '../model/Eagle-x-textbooks.pth' does not exist
