# %% [markdown]
# # Eagle 7B : Finetuning on textbooks!
#
# The following showcases an example of Training the RWKV-v5 7B model, on a simple prompt-completion translation set
# - https://huggingface.co/datasets/kristaller486/ALMA-prompt-completion
#
# In this example, we will be training the model with 16k sample sizes
#
# ## Configure the env variable below
# The default auto strategy, should work on a single 4090, scaling up all the way to 8xH100s

# %%
# -----------------------------------------------------------------
# Your configurable settings
# -----------------------------------------------------------------

# WANDB settings
ENABLE_WANDB=True
WANDB_PREFIX="RWKV-v5-Finetune"
WANDB_PROJECT="RWKV-v5-Finetune"

# Project directory offset (you need to modify if, you move the notebook into another dir)
PROJECT_DIR_OFFSET="../../"

# Config dir (relative to the notebook, excluding ending slash)
# to use, with the config filename
CONFIG_FILE_DIR="."
CONFIG_FILE_NAME="Eagle-x-ALMA-prompt-completion"

# The model to use
MODEL_NAME="RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth"
MODEL_URL="https://huggingface.co/RWKV/v5-Eagle-7B/resolve/main/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth?download=true"

# GPU count to use
GPU_DEVICES="auto"

# -----------------------------------------------------------------
# Lets detect the GPU vram sizes, and suggest a resonable default
# based on the detected VRAM sizes
# -----------------------------------------------------------------

# Default settings
# NOTE: If your not using cuda, you may want to manually change this around
DEEPSPEED_STRAT="deepspeed_stage_2"
TRAINING_CTX_LEN=2048
MICROBATCH_SIZE=1

import torch
if torch.cuda is None or not torch.cuda.is_available() or torch.cuda.device_count() <= 0:
    print("No CUDA compatible GPU found, using default settings")
else:
    # -----------------------------------------------------------------
    # Auto select the strategy based on the detected VRAM size
    # -----------------------------------------------------------------

    GPU_COUNT=torch.cuda.device_count()
    GPU_0_VRAM_SIZE_GB=torch.cuda.get_device_properties(0).total_memory / 1024**3
    if GPU_DEVICES != "auto":
        GPU_COUNT=int(GPU_DEVICES)
    print("GPU_COUNT:", GPU_COUNT)
    print("GPU_0_VRAM_SIZE (GB):", GPU_0_VRAM_SIZE_GB)

    if GPU_0_VRAM_SIZE_GB < 17:
        assert False, "For the Eagle-7B model, you need atleast 18GB vram"
    elif GPU_0_VRAM_SIZE_GB < 23:
        # This takes about 17.5GB vram on a single GPU
        # We DO NOT recommend training with ctx_len=128, as the training
        # quality will degrade noticably. But it will work!
        DEEPSPEED_STRAT="deepspeed_stage_2_offload"
        TRAINING_CTX_LEN=128
        MICROBATCH_SIZE=1
    elif GPU_0_VRAM_SIZE_GB < 25:
        # This takes about 21GB vram on a single GPU
        DEEPSPEED_STRAT="deepspeed_stage_2_offload"
        TRAINING_CTX_LEN=2048
        MICROBATCH_SIZE=2
    elif GPU_0_VRAM_SIZE_GB < 78:
        # This takes about 23GB vram on a single GPU
        DEEPSPEED_STRAT="deepspeed_stage_2"
        TRAINING_CTX_LEN=4096
        MICROBATCH_SIZE=2
        if GPU_COUNT >= 8:
            MICROBATCH_SIZE=4
    else:
        # This is now the 80GB vram class
        DEEPSPEED_STRAT="deepspeed_stage_2"
        TRAINING_CTX_LEN=4096
        MICROBATCH_SIZE=4
        if GPU_COUNT >= 8:
            MICROBATCH_SIZE=8

# -----------------------------------------------------------------
# # Training settings you can use to override the "auto" default above
# -----------------------------------------------------------------
# DEEPSPEED_STRAT="deepspeed_stage_1"
# TRAINING_CTX_LEN=4096
# MICROBATCH_SIZE=8

# ---
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("TRAINING_CTX_LEN:", TRAINING_CTX_LEN)
if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, PROJECT_DIR_OFFSET))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Check if the directory exists
if not os.path.exists(TRAINER_DIR):
    raise Exception("The trainer directory does not exists. Did you move the notebook?")
# Out:
# GPU_COUNT: 8
# GPU_0_VRAM_SIZE (GB): 79.10943603515625
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# DEEPSPEED_STRAT: deepspeed_stage_2
# TRAINING_CTX_LEN: 4096
# NOTEBOOK_DIR: /workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example
# TRAINER_DIR: /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/picocreator/RWKV-infctx-trainer

# %% [markdown]
# ## Lets download the model

# %%
# !cd "{PROJECT_DIR}" && mkdir -p "./model" && \
    cd "./model" && \
    wget -nc "{MODEL_URL}" -O "{MODEL_NAME}"
# Out:
# File ‘RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth’ already there; not retrieving.

# %%
# Lets preload the requried dataset
# !cd "{TRAINER_DIR}" && python3 preload_datapath.py "{NOTEBOOK_DIR}/{CONFIG_FILE_DIR}/{CONFIG_FILE_NAME}.yaml"
# Out:
# Downloading readme: 100%|██████████████████████| 730/730 [00:00<00:00, 10.5MB/s]
# Downloading data: 100%|████████████████████| 25.0M/25.0M [00:02<00:00, 9.03MB/s]
# Setting num_proc from 160 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 117404 examples [00:00, 1594046.51 examples/s]
# Map (num_proc=160): 100%|████| 117404/117404 [00:00<00:00, 152733.02 examples/s]
# Filter (num_proc=160): 100%|█| 117404/117404 [00:00<00:00, 209335.41 examples/s]
# Map (num_proc=160): 100%|█████| 116229/116229 [00:01<00:00, 61084.35 examples/s]
# Map (num_proc=160): 100%|█████| 116229/116229 [00:01<00:00, 94090.29 examples/s]
# Map (num_proc=160): 100%|██████████| 1342/1342 [00:00<00:00, 2423.46 examples/s]
# Map (num_proc=160): 100%|███████████| 1175/1175 [00:01<00:00, 888.66 examples/s]
# Saving the dataset (1/1 shards): 100%|█| 1342/1342 [00:00<00:00, 7721.03 example
# Saving the dataset (1/1 shards): 100%|█| 1175/1175 [00:00<00:00, 46458.84 exampl

# %% [markdown]
# ## Start the training run!

# %%
# Setup the checkpoint dir
# !cd "{PROJECT_DIR}" && mkdir -p "./checkpoint/{CONFIG_FILE_NAME}/"

# Lets start the training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/{CONFIG_FILE_DIR}/{CONFIG_FILE_NAME}.yaml" \
        --model.load_model="../model/{MODEL_NAME}" \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="../checkpoint/{CONFIG_FILE_NAME}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - {CONFIG_FILE_NAME} (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.target_batch_size=64 \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-02 09:01:42,340] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-ALMA-prompt-completion.yaml', '--model.load_model=../model/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=../checkpoint/Eagle-x-ALMA-prompt-completion/', '--trainer.logger.init_args.name=RWKV-v5-Finetune - Eagle-x-ALMA-prompt-completion (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-v5-Finetune', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=64', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'], args=['fit', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-ALMA-prompt-completion.yaml', '--model.load_model=../model/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=../checkpoint/Eagle-x-ALMA-prompt-completion/', '--trainer.logger.init_args.name=RWKV-v5-Finetune - Eagle-x-ALMA-prompt-completion (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-v5-Finetune', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=64', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'].
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/fabric/utilities/seed.py:40: No seed found, seed set to 3744174825
# Seed set to 3744174825
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       64
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         8
#    - accumulate_grad_batches: 1
#    - effective_batch_size:    64
#
# [rank: 0] Seed set to 3744174825
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-02 09:02:38,823] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 09:02:38,933] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 09:02:38,939] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 09:02:39,065] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 09:02:39,065] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 09:02:39,071] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-02 09:02:39,072] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [rank: 1] Seed set to 3744174825
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 3744174825
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 3744174825
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 6] Seed set to 3744174825
# [rank: 4] Seed set to 3744174825
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 7] Seed set to 3744174825
# [rank: 2] Seed set to 3744174825
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# [rank: 3] Seed set to 3744174825
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 7] Seed set to 3744174825
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 1] Seed set to 3744174825
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [rank: 2] Seed set to 3744174825
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 4] Seed set to 3744174825
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# [rank: 5] Seed set to 3744174825
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 6] Seed set to 3744174825
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240202_090341-5cqe4mk9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RWKV-v5-Finetune - Eagle-x-ALMA-prompt-completion (tctxlen=4096, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune/runs/5cqe4mk9
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)[WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  5.000e-05 (5e-05)
#     - lr_final: 5.000e-05 (5e-05)
#
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# [WARNING]: unlimited bptt_learning_range across multiple GPU's has a performance penalty with datasets of mixed sizes due to its constant need to keep all GPU's in sync (consider using bptt_learning_range=1 instead)
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.050560951232910156 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Loading extension module fused_adam...Loading extension module fused_adam...
#
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10113310813903809 seconds
# Time to load fused_adam op: 0.1012270450592041 seconds
# Time to load fused_adam op: 0.1012418270111084 seconds
# Time to load fused_adam op: 0.10120534896850586 seconds
# Loading extension module fused_adam...
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10156774520874023 seconds
# Time to load fused_adam op: 0.10125231742858887 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10164904594421387 seconds
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400430266/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 268 M
# 1 | blocks | ModuleList | 7.0 B
# 2 | ln_out | LayerNorm  | 8.2 K
# 3 | head   | Linear     | 268 M
# --------------------------------------
# 7.5 B     Trainable params
# 0         Non-trainable params
# 7.5 B     Total params
# 30,072.177Total estimated model params size (MB)
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py:293: The number of training batches (21) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0: 100%|████| 21/21 [03:17<00:00,  0.11it/s, v_num=4mk9, train/loss=0.953]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/19 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/19 [00:00<?, ?it/s]/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#
# Validation DataLoader 0:   5%|█                  | 1/19 [00:00<00:04,  3.86it/s]
# Validation DataLoader 0:  11%|██                 | 2/19 [00:00<00:03,  4.69it/s]
# Validation DataLoader 0:  16%|███                | 3/19 [00:00<00:03,  4.89it/s]
# Validation DataLoader 0:  21%|████               | 4/19 [00:00<00:03,  4.91it/s]
# Validation DataLoader 0:  26%|█████              | 5/19 [00:01<00:02,  4.91it/s]
# Validation DataLoader 0:  32%|██████             | 6/19 [00:01<00:02,  5.02it/s]
# Validation DataLoader 0:  37%|███████            | 7/19 [00:01<00:02,  5.12it/s]
# Validation DataLoader 0:  42%|████████           | 8/19 [00:01<00:02,  5.20it/s]
# Validation DataLoader 0:  47%|█████████          | 9/19 [00:01<00:01,  5.29it/s]
# Validation DataLoader 0:  53%|█████████▍        | 10/19 [00:01<00:01,  5.35it/s]
# Validation DataLoader 0:  58%|██████████▍       | 11/19 [00:02<00:01,  5.39it/s]
# Validation DataLoader 0:  63%|███████████▎      | 12/19 [00:02<00:01,  5.44it/s]
# Validation DataLoader 0:  68%|████████████▎     | 13/19 [00:02<00:01,  5.46it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 14/19 [00:02<00:00,  5.50it/s]
# Validation DataLoader 0:  79%|██████████████▏   | 15/19 [00:02<00:00,  5.53it/s]
# Validation DataLoader 0:  84%|███████████████▏  | 16/19 [00:02<00:00,  5.55it/s]
# Validation DataLoader 0:  89%|████████████████  | 17/19 [00:03<00:00,  5.54it/s]
# Validation DataLoader 0:  95%|█████████████████ | 18/19 [00:03<00:00,  5.56it/s]/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#
# Validation DataLoader 0: 100%|██████████████████| 19/19 [00:03<00:00,  5.59it/s]
# Epoch 0: 100%|█| 21/21 [03:21<00:00,  0.10it/s, v_num=4mk9, train/loss=0.953, va/root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 21/21 [06:52<00:00,  0.05it/s, v_num=4mk9, train/loss=0.953, va
# wandb: \ 0.032 MB of 0.032 MB uploaded
# wandb: Run history:
# wandb:                       batchidx ▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇
# wandb:        dataset/train/0.ctx_len ▆█▆██▃▇█▅█▁▇██▄█▅██▃█
# wandb:      dataset/train/0.data_loss ██▅▅▃▃▃▃▃▂▂▂▂▂▁▁▃▂▂▁▂
# wandb:           dataset/train/0.loss ██▅▅▃▃▃▃▃▂▂▂▂▂▁▁▃▂▂▁▂
# wandb:         dataset/train/0.tokens ▆▇▅▇█▃▇▇▅█▁▇█▇▄█▅▇▇▃█
# wandb:   dataset/validation/0.ctx_len ▃▂▅█▄▂▁▂▂▂▃▂▃▃▂▂▅▁▁
# wandb: dataset/validation/0.data_loss ▁▂▃▂█▆▁▆▅▂▂▅▄▃▅▇▅▅▂
# wandb:      dataset/validation/0.loss ▁▂▃▂█▆▁▆▅▂▂▅▄▃▅▇▅▅▂
# wandb:                          epoch ▁
# wandb:                    global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:     perf/kTokens_per_sec.gpu.0 █▄▂▂▂▁▂▂▁▂▁▁▁▁▁▁▁▂▂▁▁
# wandb:       perf/kTokens_total.gpu.0 ▁▁▂▂▂▃▃▃▄▄▄▅▅▆▆▆▇▇▇██
# wandb:                        substep ▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██
# wandb:                  train/ctx_len ▆█▆██▃▇█▅█▁▇██▄█▅██▃█
# wandb:                train/data_loss ██▅▅▃▃▃▃▃▂▂▂▂▂▁▁▃▂▂▁▂
# wandb:            train/dataset_index ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                     train/loss ██▅▅▃▃▃▃▃▂▂▂▂▂▁▁▃▂▂▁▂
# wandb:                   train/tokens ▆▇▅▇█▃▇▇▅█▁▇█▇▄█▅▇▇▃█
# wandb:            trainer/global_step ▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇████████████████████
# wandb:          trainer/learning_rate ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:             validation/ctx_len ▃▂▅█▄▂▁▂▂▂▃▂▃▃▂▂▅▁▁
# wandb:           validation/data_loss ▁▂▃▂█▆▁▆▅▂▂▅▄▃▅▇▅▅▂
# wandb:       validation/dataset_index ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                validation/loss ▁▂▃▂█▆▁▆▅▂▂▅▄▃▅▇▅▅▂▆
# wandb:              validation/tokens ▅▆▅█▇▆▄▅▆▇▅▅▆▇▆▅▇▄▁
# wandb:
# wandb: Run summary:
# wandb:                       batchidx 18
# wandb:        dataset/train/0.ctx_len 8180.5
# wandb:      dataset/train/0.data_loss 0.95312
# wandb:           dataset/train/0.loss 0.95312
# wandb:         dataset/train/0.tokens 3559.0
# wandb:   dataset/validation/0.ctx_len 88
# wandb: dataset/validation/0.data_loss 1.07812
# wandb:      dataset/validation/0.loss 1.07812
# wandb:                          epoch 0
# wandb:                    global_rank 0
# wandb:     perf/kTokens_per_sec.gpu.0 6.63892
# wandb:       perf/kTokens_total.gpu.0 1287.819
# wandb:                        substep 160
# wandb:                  train/ctx_len 8180.5
# wandb:                train/data_loss 0.95312
# wandb:            train/dataset_index 0
# wandb:                     train/loss 0.95312
# wandb:                   train/tokens 3559.0
# wandb:            trainer/global_step 20
# wandb:          trainer/learning_rate 5e-05
# wandb:             validation/ctx_len 88
# wandb:           validation/data_loss 1.07812
# wandb:       validation/dataset_index 0
# wandb:                validation/loss 1.22477
# wandb:              validation/tokens 126
# wandb:
# wandb: 🚀 View run RWKV-v5-Finetune - Eagle-x-ALMA-prompt-completion (tctxlen=4096, deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune/runs/5cqe4mk9
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzNTU3NTUxNw==/version_details/v5
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240202_090341-5cqe4mk9/logs

# %% [markdown]
# ## Export the model

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/{CONFIG_FILE_NAME}/last.ckpt" "../model/{CONFIG_FILE_NAME}.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/{CONFIG_FILE_NAME}.pth"
# Out:
# [2024-02-02 09:11:53,866] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Processing zero checkpoint '../checkpoint/Eagle-x-ALMA-prompt-completion/last.ckpt/checkpoint'
# Detected checkpoint of type zero stage ZeroStageEnum.gradients, world_size: 8
# Parsing checkpoint created by deepspeed==0.12.6
# Reconstructed fp32 state dict with 710 params 7518044160 elements
# Saving bf16 state dict to ../model/Eagle-x-ALMA-prompt-completion.pth
# -rw-r--r-- 1 nobody root 15G Feb  2 09:13 ../model/Eagle-x-ALMA-prompt-completion.pth

# %% [markdown]
# ## Sanity check (that the model actually output stuff)

# %%
# Lets do a quick dragon prompt validation
# !cd "{TRAINER_DIR}" && \
    python3 dragon_test.py "../model/{CONFIG_FILE_NAME}.pth" "cuda bf16"
# Out:
# [2024-02-02 09:13:12,595] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.2'
# [SimpleRWKV] Warning: dtype mismatch, only fp32 is supported (for now)
# /root/miniconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5/src/model.py:1458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_tokens = torch.tensor(
# --- DRAGON PROMPT ---
# In a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese. When asked about the discovery, one of the dragons said, "We are just here to enjoy the scenery and have a few beers."<|endoftext|>A Brief History of Hemp in America
# Posted on November 5, 2019 by dheagen
# In America, hemp has been an integral part of our culture for centuries. It was one of the first crops planted by early settlers, and it's been a staple in the American diet for thousands of years. But what is hemp, and how did it become such an integral part of our culture?
# Hemp is a plant that is related to cannabis, but it contains very low levels of THC. It is used for a variety of purposes, including textiles, food, and fuel. In ancient times, hemp was used for everything from clothing to rope to paper. In fact, it was one of the first crops to be cultivated by humans.
# Today, hemp is still used for many of the same purposes. It is used for textile
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
