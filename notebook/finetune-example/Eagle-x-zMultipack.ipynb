# %% [markdown]
# # Eagle 7B : Finetuning on capybara chat!
#
# The following showcases an example of Training the RWKV-v5 7B model, on openhermes1 instruct dataset
# - https://huggingface.co/datasets/nampdn-ai/tiny-strange-textbooks
#
# In this example, we will be training the model with 16k packings sizes
#
# ## Configure the env variable below
# The default auto strategy, should work on a single 4090, scaling up all the way to 8xH100s

# %%
# -----------------------------------------------------------------
# Your configurable settings
# -----------------------------------------------------------------

# WANDB settings
ENABLE_WANDB=True
WANDB_PREFIX="RWKV-v5-Finetune"
WANDB_PROJECT="RWKV-v5-Finetune"

# Project directory offset (you need to modify if, you move the notebook into another dir)
PROJECT_DIR_OFFSET="../../"

# Config dir (relative to the notebook, excluding ending slash)
# to use, with the config filename
CONFIG_FILE_DIR="."
CONFIG_FILE_NAME="Eagle-x-zMultipack"

# The model to use
MODEL_NAME="RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth"
MODEL_URL="https://huggingface.co/RWKV/v5-Eagle-7B/resolve/main/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth?download=true"

# GPU count to use
GPU_DEVICES="auto"

# -----------------------------------------------------------------
# Lets detect the GPU vram sizes, and suggest a resonable default
# based on the detected VRAM sizes
# -----------------------------------------------------------------

# Default settings
# NOTE: If your not using cuda, you may want to manually change this around
DEEPSPEED_STRAT="deepspeed_stage_2"
TRAINING_CTX_LEN=2048
MICROBATCH_SIZE=1

import torch
if torch.cuda is None or not torch.cuda.is_available() or torch.cuda.device_count() <= 0:
    print("No CUDA compatible GPU found, using default settings")
else:
    # -----------------------------------------------------------------
    # Auto select the strategy based on the detected VRAM size
    # -----------------------------------------------------------------

    GPU_COUNT=torch.cuda.device_count()
    GPU_0_VRAM_SIZE_GB=torch.cuda.get_device_properties(0).total_memory / 1024**3
    if GPU_DEVICES != "auto":
        GPU_COUNT=int(GPU_DEVICES)
    print("GPU_COUNT:", GPU_COUNT)
    print("GPU_0_VRAM_SIZE (GB):", GPU_0_VRAM_SIZE_GB)

    if GPU_0_VRAM_SIZE_GB < 17:
        assert False, "For the Eagle-7B model, you need atleast 18GB vram"
    elif GPU_0_VRAM_SIZE_GB < 23:
        # This takes about 17.5GB vram on a single GPU
        # We DO NOT recommend training with ctx_len=128, as the training
        # quality will degrade noticably. But it will work!
        DEEPSPEED_STRAT="deepspeed_stage_2_offload"
        TRAINING_CTX_LEN=128
        MICROBATCH_SIZE=1
    elif GPU_0_VRAM_SIZE_GB < 25:
        # This takes about 21GB vram on a single GPU
        DEEPSPEED_STRAT="deepspeed_stage_2_offload"
        TRAINING_CTX_LEN=2048
        MICROBATCH_SIZE=2
    elif GPU_0_VRAM_SIZE_GB < 78:
        # This takes about 23GB vram on a single GPU
        DEEPSPEED_STRAT="deepspeed_stage_2"
        TRAINING_CTX_LEN=4096
        MICROBATCH_SIZE=2
        if GPU_COUNT >= 8:
            MICROBATCH_SIZE=4
    else:
        # This is now the 80GB vram class
        DEEPSPEED_STRAT="deepspeed_stage_2"
        TRAINING_CTX_LEN=4096
        MICROBATCH_SIZE=4
        if GPU_COUNT >= 8:
            MICROBATCH_SIZE=8

# -----------------------------------------------------------------
# # Training settings you can use to override the "auto" default above
# -----------------------------------------------------------------
# DEEPSPEED_STRAT="deepspeed_stage_1"
# TRAINING_CTX_LEN=4096
# MICROBATCH_SIZE=8

# ---
print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)
print("DEEPSPEED_STRAT:", DEEPSPEED_STRAT)
print("TRAINING_CTX_LEN:", TRAINING_CTX_LEN)
if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, PROJECT_DIR_OFFSET))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)

# Check if the directory exists
if not os.path.exists(TRAINER_DIR):
    raise Exception("The trainer directory does not exists. Did you move the notebook?")
# Out:
# GPU_COUNT: 8
# GPU_0_VRAM_SIZE (GB): 79.10943603515625
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# DEEPSPEED_STRAT: deepspeed_stage_2
# TRAINING_CTX_LEN: 4096
# NOTEBOOK_DIR: /workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example
# TRAINER_DIR: /workspace/picocreator/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /workspace/picocreator/RWKV-infctx-trainer

# %% [markdown]
# ## Lets download the model

# %%
# !cd "{PROJECT_DIR}" && mkdir -p "./model" && \
    cd "./model" && \
    wget -nc "{MODEL_URL}" -O "{MODEL_NAME}"
# Out:
# File ‘RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth’ already there; not retrieving.

# %%
# Lets build the giant datapack
# !cd "{TRAINER_DIR}" && python3 datapack_build.py "{NOTEBOOK_DIR}/{CONFIG_FILE_DIR}/{CONFIG_FILE_NAME}-build.yaml"
# Out:
# >> Starting datapack build process for: /workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-zMultipack-build.yaml
# >> Preparing dataset - index:  0
# Resolving data files: 100%|████████████████| 1267/1267 [00:10<00:00, 117.29it/s]
# Saving the dataset (16/16 shards): 100%|█| 38611/38611 [00:17<00:00, 2224.06 exa
# Saving the dataset (1/1 shards): 100%|████| 8/8 [00:00<00:00, 244.09 examples/s]
# >> Preparing dataset - index:  1
# Saving the dataset (1/1 shards): 100%|█| 160/160 [00:00<00:00, 4260.66 examples/
# Saving the dataset (1/1 shards): 100%|████| 8/8 [00:00<00:00, 367.43 examples/s]
# >> Preparing dataset - index:  2
# Saving the dataset (1/1 shards): 100%|█| 411/411 [00:00<00:00, 1751.08 examples/
# Saving the dataset (1/1 shards): 100%|████| 8/8 [00:00<00:00, 327.06 examples/s]
# >> Preparing dataset - index:  3
# Saving the dataset (20/20 shards): 100%|█| 48977/48977 [00:20<00:00, 2405.22 exa
# Saving the dataset (1/1 shards): 100%|████| 8/8 [00:00<00:00, 187.17 examples/s]
# >> Preparing dataset - index:  4
# Saving the dataset (1/1 shards): 100%|█| 2394/2394 [00:01<00:00, 2182.00 example
# Saving the dataset (1/1 shards): 100%|████| 8/8 [00:00<00:00, 316.65 examples/s]
# >> Preparing dataset - index:  5
# Saving the dataset (5/5 shards): 100%|█| 11780/11780 [00:04<00:00, 2496.27 examp
# Saving the dataset (1/1 shards): 100%|████| 8/8 [00:00<00:00, 248.64 examples/s]
# >> Preparing dataset - index:  6
# Saving the dataset (1/1 shards): 100%|█| 548/548 [00:00<00:00, 1666.78 examples/
# Saving the dataset (1/1 shards): 100%|████| 8/8 [00:00<00:00, 320.96 examples/s]
# >> Preparing dataset - index:  7
# Saving the dataset (1/1 shards): 100%|█| 160/160 [00:00<00:00, 1899.38 examples/
# Saving the dataset (1/1 shards): 100%|████| 8/8 [00:00<00:00, 340.16 examples/s]
# >> Dataset Mixing mode:  shuffle
# >> Saving dataset to data_path :  ../datapath/world/Eagle-x-multipack/
# Saving the dataset (41/41 shards): 100%|█| 103041/103041 [00:48<00:00, 2115.24 e
# Saving the dataset (1/1 shards): 100%|██| 64/64 [00:00<00:00, 107.20 examples/s]
# >> Dataset saved to data_path
# >> -----------------------------------
# >> Performing dataset counting
# >> -----------------------------------
# >> Final dataset count ( train ) : 103,041
# >> Final dataset count ( test  ) : 64
# >> -----------------------------------
# Map (num_proc=160): 100%|██████| 103041/103041 [00:42<00:00, 2417.83 examples/s]
# num_proc must be <= 64. Reducing num_proc to 64 for dataset of size 64.
# Map (num_proc=64): 100%|█████████████████| 64/64 [00:06<00:00, 10.16 examples/s]
# >> -----------------------------------
# >> Final 'train' dataset token count ...
# >> - Total tokens : 3,354,691,235
# >> - Valid tokens : 2,073,274,062
# >> - Hidden tokens : 1,281,417,173
# >> -----------------------------------
# >> Final 'test' dataset token count ...
# >> - Total tokens : 281,239
# >> - Valid tokens : 276,273
# >> - Hidden tokens : 4,966
# >> -----------------------------------

# %%
# Lets load the datapath at {PROJECT_DIR}/datapath/world/Eagle-x-multipack/ via HF dataset
# and iterate the first 10 documents
import datasets
datapath = f"{PROJECT_DIR}/datapath/world/Eagle-x-multipack/"
print(f"Loading the dataset... {datapath}")

# Load the dataset
full_dataset = datasets.load_from_disk(datapath)
print(f"Dataset loaded, {len(full_dataset)} documents")

# Train dataset
train_dataset = full_dataset["train"]

# Lets iterate the first 10 documents
iterate_limit = 10
for idx, doc in enumerate(train_dataset):
    print(f"Document {idx+1}:")
    # Print the keys
    print("- Keys:", doc.keys())
    print("- input_ids length:", len(doc["input_ids"]))
    print("- input_ids sample:", doc["input_ids"][:512])
    print("- attention_mask length:", len(doc["attention_mask"]))
    print("- token_type_ids length:", len(doc["token_type_ids"]))
    # print("- sample_length:", doc["sample_length"])

    if idx >= iterate_limit:
        break
# Out:
# Loading the dataset... /workspace/picocreator/RWKV-infctx-trainer/datapath/world/Eagle-x-multipack/
# Dataset loaded, 2 documents
# Document 1:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32768
# - input_ids sample: [5201, 289, 47, 54943, 101, 55044, 44281, 49344, 28663, 50210, 261, 23727, 4600, 332, 44742, 30469, 51668, 4811, 59828, 59392, 56277, 45950, 49344, 21700, 52033, 45950, 49344, 59, 261, 6884, 42114, 11, 41613, 59740, 261, 7334, 59392, 96, 54010, 96, 41403, 49344, 41, 111, 501, 28352, 36, 58973, 345, 4423, 332, 59392, 56277, 28352, 1789, 296, 59740, 47, 53539, 41, 111, 499, 35006, 96, 7339, 26451, 24762, 472, 36208, 36, 29137, 7066, 31601, 22590, 59392, 56277, 4811, 30858, 332, 45950, 4706, 345, 28352, 7579, 340, 4596, 39438, 41, 50, 45, 21998, 41, 1789, 5297, 54807, 36, 36463, 4588, 22590, 60069, 21265, 63450, 21286, 21457, 8614, 102, 54807, 1942, 31385, 47, 7610, 41, 1789, 92, 106, 1687, 35117, 24762, 45, 4457, 92, 106, 1687, 7339, 26451, 24762, 42, 3590, 284, 59, 64158, 36, 20996, 60069, 21265, 63450, 21286, 21457, 8614, 102, 45, 4788, 32232, 21286, 332, 45950, 4706, 345, 64158, 42178, 4457, 92, 106, 1687, 35117, 24762, 45, 4457, 92, 106, 1687, 7339, 26451, 24762, 261, 36, 19963, 22590, 46685, 4811, 45950, 7946, 11, 111, 296, 21888, 41, 34795, 465, 33075, 22590, 46685, 4811, 45950, 7946, 59, 3351, 42, 261, 36, 44281, 7946, 22590, 46685, 40085, 59392, 56277, 45950, 49344, 11, 49139, 296, 59392, 96, 54010, 96, 41403, 49344, 41, 111, 42, 261, 36, 37201, 22590, 51703, 11, 1942, 62164, 41, 49139, 45, 40037, 501, 28352, 35433, 465, 40477, 116, 4706, 384, 345, 45, 269, 7036, 5380, 51703, 92, 49, 1685, 269, 7005, 384, 51703, 92, 50, 1682, 11, 25229, 59, 28352, 35433, 41, 111, 45, 269, 1955, 332, 39352, 46685, 5351, 11, 6884, 261, 5201, 290, 47, 44414, 21265, 3878, 49816, 54838, 1858, 261, 1136, 55452, 4811, 22590, 30469, 62035, 62633, 59546, 37599, 45, 39934, 21286, 30135, 46234, 21265, 59792, 61590, 32227, 51239, 59513, 62633, 4811, 51982, 61923, 47, 37453, 61590, 39171, 22681, 56679, 30469, 62035, 62633, 4596, 57195, 4715, 4596, 56812, 4811, 56433, 22590, 51163, 4706, 51746, 51703, 52628, 47, 261, 5201, 291, 47, 63159, 21265, 55220, 28663, 61379, 261, 23573, 49657, 21265, 56812, 30469, 62035, 62633, 21413, 4435, 32354, 4811, 45950, 7946, 32386, 38864, 56471, 47, 37453, 62633, 52051, 64370, 22590, 63370, 45093, 56679, 59345, 4715, 62380, 4811, 47030, 22590, 32251, 57101, 4811, 30858, 51703, 47, 261, 5201, 292, 47, 58702, 7856, 21265, 63205, 54833, 261, 48784, 62633, 21413, 4435, 32354, 4811, 59226, 21265, 50904, 22590, 63750, 4706, 52033, 45950, 49344, 61559, 47, 37453, 62633, 21413, 4435, 32354, 4811, 51250, 22590, 61923, 4706, 59513, 61559, 21265, 4811, 56394, 51703, 32227, 45115, 22590, 63750, 4706, 39936, 61559, 47, 261, 5201, 3483, 47, 64166, 4596, 44172, 34519, 122, 261, 48550, 45950, 49344, 21800, 56729, 64251, 4596, 64341, 47, 19907, 51668, 45, 4601, 4600, 32354, 4596, 46946, 46, 8020, 64341, 45, 51470, 62552, 45, 21265, 46992, 46685, 62035, 47, 20996, 61865, 4706, 45950, 7856, 38864, 56471, 4600, 22590, 62018, 4706, 22590, 57181, 4706, 31370, 45628, 49196, 61559, 47, 0, 520, 50, 47, 64194, 4811, 50589, 58761, 520, 261, 43, 50589, 59345, 53251, 22590, 62370, 4706, 52622, 59993, 45, 32139, 4423, 39855, 54246, 21265, 21621, 33792, 26234, 45, 4811, 52571, 63637, 47, 11, 43]
# - attention_mask length: 32768
# - token_type_ids length: 32768
# Document 2:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32760
# - input_ids sample: [62994, 59, 11, 6833, 21286, 4419, 3609, 59179, 47, 29956, 32475, 22799, 30972, 22799, 332, 32202, 47, 30076, 30985, 4600, 4811, 55801, 22590, 32202, 4423, 62000, 4423, 22799, 21413, 47, 37564, 62304, 22590, 32202, 39942, 32115, 46, 1782, 46, 27074, 21265, 52069, 32515, 39815, 47, 261, 40301, 22590, 59725, 57009, 59, 55267, 59, 21151, 38821, 22590, 4273, 21265, 4267, 56639, 64, 3908, 39934, 4600, 4692, 45175, 45, 46842, 46731, 269, 6122, 58476, 63637, 4811, 52597, 4419, 45175, 575, 47, 37054, 39966, 59, 63237, 116, 59, 29675, 2065, 102, 4706, 22590, 28870, 1853, 50116, 59, 3913, 3490, 45, 620, 49, 301, 47, 68, 583, 22590, 37333, 37199, 116, 57458, 22590, 46072, 4811, 45616, 3785, 7492, 2098, 32487, 32111, 46, 6898, 8396, 7856, 56567, 45395, 20936, 50296, 7500, 47, 20996, 37199, 116, 56255, 332, 31907, 4596, 40186, 4811, 39115, 51453, 52482, 32487, 31293, 45, 21400, 22226, 4706, 32229, 45, 38869, 38848, 4423, 20996, 28870, 1853, 45, 21515, 7789, 22590, 31907, 21265, 31989, 4833, 332, 20936, 50296, 1857, 4712, 36608, 45, 332, 46834, 32487, 55425, 31293, 47, 36250, 59460, 50907, 46227, 45, 20996, 28870, 1853, 4600, 61748, 4450, 22590, 39193, 37199, 116, 45, 22762, 45685, 21265, 56416, 21820, 45285, 4569, 21413, 51904, 22590, 46834, 460, 20936, 32487, 22590, 44566, 4706, 61409, 47, 20996, 37199, 116, 32230, 60438, 62643, 4811, 31080, 22590, 44566, 52889, 61552, 47, 21042, 40237, 37634, 29373, 27194, 460, 45695, 45, 22590, 28441, 7176, 116, 31189, 22590, 320, 47, 84, 47, 21265, 320, 47, 76, 47, 56639, 4811, 30899, 22590, 20524, 46, 5637, 49387, 36654, 8795, 54318, 50691, 44986, 275, 6313, 85, 497, 332, 61678, 32202, 38536, 51951, 30678, 60605, 19727, 7484, 34627, 45, 21994, 4450, 50817, 20278, 8264, 21265, 44796, 3786, 2128, 47, 44235, 332, 52244, 4596, 55323, 45, 37115, 2243, 37199, 4600, 47766, 4450, 28755, 26156, 1857, 4706, 20996, 28870, 1853, 460, 47102, 47, 55191, 55315, 36247, 1857, 55374, 28943, 8448, 122, 22444, 2010, 116, 22590, 32202, 38536, 21700, 39931, 53092, 45, 60378, 32229, 32227, 29373, 27194, 460, 45589, 4600, 39820, 4596, 22590, 50387, 7745, 3626, 2337, 116, 21265, 22590, 31254, 38848, 19407, 33452, 31997, 101, 4600, 46463, 4833, 4596, 22590, 4040, 1445, 460, 64405, 47, 20894, 35862, 25297, 2030, 45, 37370, 27460, 31034, 116, 31162, 332, 320, 47, 84, 47, 56639, 60443, 45, 31601, 7676, 2168, 22590, 63637, 45, 21265, 39630, 20727, 6935, 4811, 57129, 22590, 31997, 101, 47, 58898, 45, 20851, 21161, 27480, 122, 56915, 4811, 45235, 51232, 45, 52115, 21823, 62039, 20419, 6927, 98, 19490, 1858, 21265, 56337, 3680, 2035, 2011, 7135, 45290, 47, 37564, 60233, 45, 4569, 59543, 332, 52932, 19407, 33452, 31997, 101, 4596, 21823, 46344, 47, 3878, 39277, 4833, 22590, 31997, 101, 45, 40186, 45434, 21820, 4811, 22449, 36545, 27194, 7745, 53083, 21265, 64611, 45359, 52085, 61585, 4811, 31293, 47, 36250, 3680, 2035, 2011, 7135, 55972, 22590, 31822, 33672, 61585, 45, 20851, 38595, 22590, 31997, 101, 4811, 20419, 6927, 98, 45, 22762, 38869, 55690, 19727, 7484, 25681, 37561, 1941, 32465, 4569, 40014, 4811, 39809, 4601, 47, 20996, 58766, 34627, 22377, 27361, 1803, 29373, 27194, 4450, 40085, 22590, 31997, 101, 60421, 4450, 20727, 6935, 21265, 45364]
# - attention_mask length: 32760
# - token_type_ids length: 32760
# Document 3:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32740
# - input_ids sample: [261, 40812, 59, 33, 6833, 21286, 4419, 3609, 59179, 47, 50582, 332, 55975, 45175, 4788, 32355, 21556, 28310, 31506, 4811, 47202, 52391, 4811, 62683, 22590, 45175, 47, 261, 33161, 59, 33, 48496, 22590, 45175, 4811, 22590, 59725, 57009, 30917, 22590, 39073, 31705, 47, 3908, 22590, 57009, 21896, 461, 45175, 24381, 45, 46842, 46731, 269, 5719, 461, 45175, 386, 55267, 59, 21151, 4600, 46368, 4596, 22590, 45233, 64, 37466, 59, 19783, 102, 37054, 31705, 59, 3913, 22590, 51502, 46064, 45, 22590, 38848, 57490, 4600, 39556, 4450, 20619, 25946, 105, 50196, 20884, 1817, 1745, 3904, 47, 20996, 31461, 59829, 60582, 4596, 22590, 45848, 4600, 22590, 30686, 38848, 4423, 38998, 1895, 4715, 269, 8801, 39764, 386, 3918, 21800, 31370, 52964, 62404, 45, 32139, 4423, 59694, 31293, 21265, 59678, 64868, 47, 20996, 31461, 62387, 21265, 59829, 4706, 21902, 62404, 4600, 21902, 50836, 4811, 45221, 22590, 20914, 25010, 36764, 32487, 51773, 39750, 45, 40186, 45143, 31926, 45, 64937, 46318, 27127, 1750, 47609, 47, 29758, 7856, 332, 60211, 47546, 4811, 39764, 62382, 45, 22590, 20914, 25010, 36764, 39630, 4419, 4516, 25963, 2174, 4811, 45694, 4419, 63560, 30917, 22590, 50196, 45, 22762, 64305, 2030, 47255, 21823, 39295, 4811, 51453, 36807, 3642, 8584, 7342, 47, 20996, 62331, 4706, 28803, 20282, 112, 3642, 8584, 7342, 21800, 38641, 47544, 22590, 45848, 45, 21265, 4569, 4600, 60607, 4811, 4435, 21259, 2194, 7856, 332, 47206, 30181, 56144, 32487, 22499, 1939, 46, 34011, 53324, 45, 40186, 50196, 20884, 1817, 1745, 31969, 332, 60211, 47546, 4811, 21823, 31907, 47, 20884, 1817, 1745, 460, 31699, 4600, 4811, 30972, 36807, 3642, 8584, 7342, 51316, 4706, 22590, 46834, 19437, 24500, 275, 24532, 38848, 4423, 19783, 102, 497, 22590, 31581, 47342, 4706, 39764, 47, 29511, 59882, 4712, 19437, 24500, 45, 4569, 52034, 4811, 31059, 32229, 21260, 35924, 4450, 39931, 56565, 37737, 8229, 7789, 45, 22590, 20022, 8033, 8230, 116, 45, 32487, 61601, 30917, 22590, 50196, 460, 38349, 47622, 45, 22590, 20854, 1814, 8903, 115, 47, 20996, 36764, 20498, 41574, 30135, 55786, 22590, 50196, 4811, 31213, 28803, 20282, 112, 460, 22499, 45, 29558, 3642, 8584, 7342, 45, 332, 40240, 22068, 22762, 45793, 52587, 1939, 53297, 4706, 21823, 52610, 47, 20996, 59670, 39189, 38298, 22590, 59193, 4706, 22590, 28487, 19962, 8704, 1956, 47290, 25610, 45, 4423, 29558, 4600, 32245, 21902, 59276, 46, 26170, 28487, 19962, 8704, 1956, 55656, 52580, 40186, 39619, 4811, 52573, 22590, 57490, 460, 47469, 25206, 45, 22590, 3964, 7906, 2225, 20014, 7487, 1791, 47, 44019, 4569, 46421, 21700, 19437, 24500, 45, 29558, 4600, 47529, 4450, 22590, 28487, 19962, 8704, 1956, 37258, 7463, 44607, 3845, 7936, 36785, 20432, 7744, 4450, 37832, 46021, 4811, 39291, 21823, 31044, 4596, 332, 21383, 40186, 51995, 21649, 2170, 7241, 27166, 31613, 47, 4255, 21811, 22535, 26910, 45, 4569, 46771, 22590, 32223, 4811, 20432, 7744, 460, 64561, 47, 58898, 45, 4712, 22590, 62106, 40213, 4706, 3848, 7414, 37199, 45, 22590, 22428, 34864, 36331, 55404, 20022, 8033, 8230, 39909, 21823, 46655, 116, 36738, 118, 20713, 7123, 21265, 3818, 2326, 46, 1416, 8986, 98, 37598, 21823, 31699, 4811, 59606, 22590, 3642, 8584, 7342, 4450, 64476, 52952, 4596, 36807, 3642, 8584, 7342, 31162, 45300, 7856, 22590, 28803, 47, 20996]
# - attention_mask length: 32740
# - token_type_ids length: 32740
# Document 4:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32755
# - input_ids sample: [62994, 59, 11, 6833, 21286, 4419, 3609, 59179, 32227, 51775, 63654, 59699, 32458, 47, 29054, 4423, 31466, 4423, 22799, 21413, 47, 261, 82, 59, 62992, 59, 267, 46, 28908, 39082, 56428, 30322, 63933, 39082, 21265, 22590, 38586, 32227, 51662, 30917, 4601, 45805, 22590, 3493, 2209, 51158, 30887, 52753, 47, 20996, 32219, 62276, 4596, 22590, 3492, 2209, 51158, 21400, 4600, 39171, 50937, 4811, 39082, 32227, 4600, 39174, 32226, 32227, 47, 29804, 40050, 4706, 30887, 39082, 21286, 30135, 45395, 40213, 39082, 47, 269, 24254, 49331, 30887, 39082, 35, 21800, 30259, 51412, 4596, 52869, 32448, 59, 4423, 39082, 63945, 46715, 45, 39082, 32487, 53235, 55803, 116, 45, 4715, 39082, 60152, 4450, 45645, 31601, 332, 31323, 46790, 4706, 32251, 47, 3918, 21800, 30259, 55856, 1843, 32487, 61699, 21265, 59296, 47444, 47, 267, 46, 20996, 50030, 64170, 63152, 275, 5601, 42, 4600, 332, 50030, 46946, 52860, 59245, 1857, 47, 3918, 4600, 31060, 49600, 1843, 4424, 64170, 36807, 4596, 44527, 45, 4600, 22590, 40213, 460, 46703, 56700, 64267, 64499, 45, 21265, 4600, 22590, 52095, 59245, 1857, 4596, 22590, 40213, 4450, 46685, 4706, 59618, 45, 32487, 31601, 3493, 45, 715, 49, 39787, 4596, 39984, 45, 4706, 32469, 3489, 45, 687, 51, 21286, 4596, 46946, 47207, 64267, 60, 59841, 31633, 46, 27165, 45, 56248, 4423, 32458, 4423, 38501, 55854, 39787, 45, 22590, 39984, 46685, 4600, 3508, 45, 660, 51, 47, 267, 46, 63215, 31891, 275, 35638, 25260, 4423, 269, 26745, 389, 60523, 269, 7048, 31891, 384, 269, 34135, 25660, 31891, 35, 4715, 269, 8770, 26682, 1939, 31891, 381, 4600, 332, 37913, 22525, 34502, 4706, 31891, 39082, 32227, 59506, 4596, 22590, 45010, 50373, 21265, 45010, 44910, 62650, 22590, 22089, 4811, 31255, 3492, 680, 116, 47, 58864, 47525, 269, 54265, 7938, 22313, 384, 22590, 39844, 22748, 4419, 22249, 41480, 4706, 39383, 7413, 8087, 37807, 22762, 59051, 57291, 22313, 62655, 4596, 45966, 4706, 65269, 21265, 63367, 1744, 62633, 31458, 62024, 61603, 32487, 31183, 45, 30887, 4715, 59296, 39082, 47, 61279, 56089, 63410, 4811, 21902, 269, 54265, 7938, 35, 38852, 59, 46486, 32462, 31458, 46851, 45, 62634, 22748, 51903, 1843, 21700, 22168, 47341, 45, 39082, 61589, 22590, 59354, 4706, 269, 7048, 384, 21265, 22590, 47440, 45, 47001, 32226, 22590, 39788, 45, 45283, 22590, 38530, 4706, 52280, 55447, 45, 40186, 39171, 56500, 55882, 39082, 21700, 59961, 45, 22187, 51386, 47, 267, 46, 20996, 321, 37348, 4600, 332, 31310, 37653, 48, 5788, 57041, 4424, 22590, 44527, 19445, 26528, 4450, 31891, 30228, 29425, 2030, 19455, 8928, 47, 3918, 22748, 57041, 4712, 22590, 32280, 62616, 39931, 3493, 623, 52697, 269, 24008, 41329, 386, 20996, 19711, 21700, 32234, 32006, 22748, 30135, 56427, 4596, 39931, 3493, 625, 19711, 52697, 269, 6459, 108, 36692, 20743, 7912, 8789, 386, 28402, 45, 32234, 4600, 22590, 38499, 29425, 2030, 19455, 8928, 52697, 4811, 51725, 51540, 43959, 55109, 47, 267, 46, 29587, 36692, 32462, 4419, 50199, 31891, 30228, 46029, 4596, 44527, 47, 29893, 55437, 64941, 21222, 26093, 32487, 39931, 63798, 21265, 39383, 7413, 8087, 39082, 47, 28781, 49282, 1843, 4450, 39931, 22681, 4706, 64981, 46486, 45, 22499, 1939, 65265, 45, 56189, 64296, 21265, 59595, 31310, 39680, 45, 32232, 21286, 22226, 4706, 22590, 31461, 64287, 62603]
# - attention_mask length: 32755
# - token_type_ids length: 32755
# Document 5:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32758
# - input_ids sample: [62994, 59, 11, 6833, 21286, 4419, 3609, 59179, 47, 21189, 32475, 4435, 38594, 332, 32202, 47, 21189, 31475, 56305, 332, 55975, 21265, 31323, 45175, 47, 261, 40674, 45175, 22590, 59725, 57009, 59, 308, 31223, 32227, 22590, 45175, 4811, 22590, 57009, 269, 33575, 32462, 47302, 45953, 4811, 4435, 38554, 799, 4600, 4596, 269, 24327, 22590, 3784, 7004, 49300, 29623, 8055, 33944, 22748, 59141, 45, 59019, 22748, 46602, 31070, 4450, 37510, 46022, 47, 29898, 45, 59019, 22748, 22187, 37694, 22590, 47398, 61949, 4596, 22590, 29623, 8055, 33944, 45, 21265, 22590, 29623, 8055, 33944, 21532, 22187, 30911, 21273, 47302, 39934, 47, 63199, 45, 21620, 8061, 1843, 49941, 58669, 51645, 4811, 37510, 38905, 4811, 30938, 51799, 53356, 53310, 21700, 56751, 45095, 47, 20554, 21265, 40240, 45, 22080, 45, 40208, 21265, 55734, 30384, 1843, 31503, 37510, 47622, 47, 4252, 49507, 4706, 46030, 47302, 38367, 4833, 56228, 4712, 22590, 37510, 32011, 45, 46647, 3493, 49, 45, 620, 49, 4596, 39984, 45093, 22590, 37371, 575, 47, 19617, 22799, 32213, 4660, 32464, 4601, 4600, 64, 11, 66, 59, 261, 1136, 22590, 32224, 56976, 45, 4601, 4600, 59684, 32227, 59019, 22748, 22187, 37694, 22590, 47398, 61949, 4596, 22590, 3784, 7004, 49300, 29623, 8055, 33944, 45, 40186, 38989, 32227, 22590, 47302, 4596, 59019, 32462, 45953, 4811, 4435, 38554, 4450, 32234, 31759, 8055, 33944, 47, 20996, 3784, 7004, 49300, 29623, 8055, 33944, 22748, 59141, 45805, 22590, 54830, 36484, 21138, 21265, 37646, 4811, 30911, 22590, 47302, 4596, 63143, 46, 25577, 63926, 45, 21400, 39690, 59019, 22748, 46602, 31070, 4450, 37510, 46022, 4424, 32227, 32251, 45, 4601, 22748, 22187, 56427, 4596, 22590, 31759, 8055, 33944, 47, 261, 48465, 22590, 56751, 31759, 8055, 33944, 22187, 55531, 4811, 59019, 45, 21620, 8061, 1843, 49941, 58669, 39934, 21532, 22187, 32430, 21700, 56751, 45095, 4811, 47208, 39931, 51799, 47, 50342, 45, 32232, 51645, 4811, 37510, 38905, 45, 40185, 32232, 32462, 30093, 4811, 30858, 62410, 21265, 51799, 47, 44696, 4706, 21256, 30118, 21265, 46085, 116, 45, 4423, 32458, 4423, 56206, 45, 56300, 31503, 37510, 47622, 47, 261, 6699, 57328, 21700, 51799, 4596, 59019, 22748, 51868, 37644, 4450, 22590, 38864, 46685, 4706, 46030, 47302, 22762, 46350, 22590, 37510, 46022, 4811, 38482, 50870, 22590, 54934, 6910, 47, 37451, 32462, 64830, 3493, 49, 45, 620, 49, 46030, 47302, 22762, 46036, 4712, 22590, 37510, 32011, 45093, 22590, 45873, 37371, 45, 40186, 46840, 332, 63870, 31894, 4596, 22590, 56154, 53283, 4706, 22590, 37510, 21265, 22590, 57481, 59055, 4706, 52926, 4596, 22590, 45010, 44910, 47, 261, 1136, 53060, 45, 22590, 45175, 4811, 22590, 57009, 269, 33575, 32462, 47302, 45953, 4811, 4435, 38554, 799, 4600, 59019, 45, 4423, 4601, 22748, 22187, 37694, 22590, 47398, 46450, 4596, 22590, 3784, 7004, 49300, 29623, 8055, 33944, 47, 50153, 22590, 56751, 31759, 8055, 33944, 22187, 60289, 21700, 39931, 51799, 45, 31370, 47302, 4596, 59019, 52176, 4811, 45889, 21265, 30858, 51799, 4450, 52062, 22590, 37510, 46022, 45805, 22590, 54830, 36484, 21138, 47, 261, 0, 62994, 59, 11, 6833, 21286, 4419, 3609, 59179, 47, 21189, 32475, 4435, 38594, 332, 32202, 47, 21189, 31475, 56305, 332, 55975, 21265, 31323, 45175, 47, 261, 24093, 22590, 59725, 51310, 21265, 45464, 22590, 51328, 46713, 4811, 45175, 22590]
# - attention_mask length: 32758
# - token_type_ids length: 32758
# Document 6:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32768
# - input_ids sample: [46, 3448, 60820, 32487, 44055, 29810, 5383, 29651, 121, 29810, 22249, 49540, 116, 44055, 29810, 4596, 39920, 4706, 61923, 45, 4423, 21902, 46442, 32251, 61720, 275, 80, 41, 2069, 494, 4600, 65012, 45301, 32226, 44055, 29810, 460, 60307, 32251, 61720, 275, 80, 41, 111, 95, 51, 5295, 11, 46, 3448, 60820, 32487, 37017, 29810, 21265, 37223, 29810, 5383, 29651, 121, 29810, 460, 32251, 61720, 4600, 61705, 4811, 37017, 29810, 21265, 37223, 29810, 45, 40186, 30135, 51679, 314, 41, 111, 22025, 345, 42, 61720, 47, 50318, 45, 29651, 121, 29810, 460, 60547, 21265, 22184, 46, 41193, 33948, 46642, 22459, 4601, 37722, 45, 46500, 4601, 57346, 21700, 57271, 60448, 47, 261, 402, 295, 25442, 32031, 296, 286, 63, 58, 47, 44028, 29651, 121, 29810, 59, 63130, 29810, 7856, 61492, 754, 25442, 63, 261, 40329, 29651, 121, 29810, 45, 56729, 39193, 52954, 61559, 0, 5983, 34415, 116, 45, 30780, 25235, 57330, 47, 37468, 45, 4858, 45843, 4712, 332, 30393, 7937, 27166, 52065, 4811, 51691, 22590, 38919, 21265, 64237, 4706, 31828, 37087, 37204, 53353, 47, 37453, 64913, 63630, 31059, 31269, 4419, 31150, 8086, 2011, 31376, 4712, 51929, 53140, 39931, 46129, 53823, 32499, 45, 22668, 24801, 7856, 61817, 45, 21265, 59881, 53019, 47, 261, 50, 47, 3448, 64005, 5331, 19242, 46, 20996, 37087, 37204, 59, 300, 63783, 64941, 37792, 63822, 63737, 64878, 4596, 53265, 45976, 47, 19242, 46, 44265, 34836, 4596, 3491, 715, 4450, 43944, 37087, 45, 332, 50721, 30436, 7919, 45, 56119, 45, 21265, 56493, 47, 19242, 46, 28899, 61661, 59, 50546, 45, 58737, 45, 29580, 41654, 4715, 55154, 45, 61413, 45, 21265, 37151, 47, 19242, 46, 54954, 59, 58815, 1744, 64237, 32227, 51030, 56387, 21265, 50862, 22248, 59943, 47, 261, 51, 47, 3448, 891, 7780, 50309, 4706, 22590, 37087, 37204, 5331, 19242, 46, 36682, 37087, 37204, 50989, 4596, 3492, 621, 4596, 50546, 21265, 58737, 47, 19242, 46, 58864, 45, 31581, 22080, 32462, 50989, 22590, 39358, 45, 62456, 57254, 39135, 4706, 22590, 32251, 47, 19242, 46, 29521, 22590, 40237, 45, 22590, 37087, 61377, 21800, 47432, 101, 4811, 52584, 59565, 21265, 59842, 47, 261, 52, 47, 3448, 23793, 34829, 50704, 5331, 19242, 46, 3448, 98, 47, 29165, 460, 37408, 5331, 36210, 46, 300, 62477, 60455, 22762, 31601, 24948, 61669, 4811, 31358, 46129, 53823, 63484, 47, 36210, 46, 36320, 1843, 22590, 37087, 37204, 21700, 21823, 60666, 33948, 57103, 4596, 52622, 59993, 47, 36210, 46, 20048, 61817, 21265, 62499, 39637, 4423, 4419, 63649, 4811, 37757, 7856, 62532, 47, 28350, 46, 3448, 99, 47, 36991, 19672, 1941, 5331, 36210, 46, 300, 62322, 60173, 21265, 30436, 7919, 22762, 60491, 57254, 55600, 4811, 50848, 59777, 47, 36210, 46, 36682, 40207, 4811, 22770, 332, 37087, 37204, 21265, 22590, 31581, 46795, 4811, 22770, 37087, 37204, 116, 4596, 22638, 59513, 62531, 45976, 47, 36210, 46, 20035, 62322, 32499, 4712, 39430, 53751, 63938, 22248, 65034, 4706, 22590, 30191, 47, 28350, 46, 3448, 100, 47, 20384, 6976, 21189, 8677, 2345, 106, 5331, 36210, 46, 300, 30832, 26127, 55472, 21700, 59591, 21265, 22590, 47120, 4706, 38593, 47, 36210, 46, 37586, 7513, 37087, 37204, 38873, 7066, 45, 60327, 22590, 37151, 37204, 4424, 22590, 21238, 4706, 3490, 47, 36210, 46]
# - attention_mask length: 32768
# - token_type_ids length: 32768
# Document 7:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32768
# - input_ids sample: [36, 19963, 22590, 31269, 38017, 4706, 22590, 31526, 47, 28352, 26118, 96, 34115, 296, 31526, 47, 26118, 36208, 36, 29428, 22590, 31269, 38017, 460, 39523, 38017, 4811, 22590, 31526, 460, 31269, 38017, 56893, 47, 28352, 26325, 47, 26118, 296, 31269, 96, 34115, 47, 35551, 36208, 36, 29428, 22590, 31269, 38017, 4811, 22590, 31526, 460, 56893, 47, 28352, 26118, 96, 34115, 47, 35551, 296, 31526, 36208, 36, 44788, 22590, 22168, 31899, 31526, 4706, 22590, 53048, 47, 28352, 42178, 31269, 96, 34115, 11, 6884, 261, 402, 291, 47, 28663, 50210, 59, 44225, 55300, 11, 6884, 11, 7334, 45786, 96, 42205, 41, 26325, 501, 28352, 5170, 28352, 48640, 332, 45786, 57147, 4712, 332, 31526, 4596, 332, 45308, 32298, 47, 36208, 23402, 59, 28352, 26325, 59, 20996, 31526, 4811, 52446, 22590, 45786, 57147, 4712, 47, 36208, 48693, 59, 28352, 6699, 22168, 31899, 31526, 4706, 22590, 53048, 37634, 22590, 45786, 57147, 47, 28352, 5170, 36208, 36, 50535, 332, 31269, 57147, 4712, 22590, 31526, 460, 39523, 38017, 47, 28352, 26325, 47, 35551, 296, 31269, 96, 42205, 41, 26325, 47, 35551, 42, 36208, 36, 50535, 332, 39523, 57147, 4712, 22590, 31526, 47, 28352, 42178, 39523, 96, 42205, 41, 26325, 42, 11, 6884, 261, 402, 292, 47, 64166, 4706, 49995, 101, 44030, 37489, 11, 48370, 101, 45308, 40008, 21286, 32354, 4596, 53265, 64251, 45, 59841, 59, 11, 46, 3448, 40754, 7856, 5383, 49995, 101, 45308, 40008, 21286, 32354, 4596, 47202, 61559, 4811, 63508, 30858, 332, 31526, 4596, 332, 32298, 47, 11, 46, 3448, 24182, 7856, 5383, 49995, 101, 45308, 40008, 21286, 32354, 4596, 52954, 61559, 4811, 63508, 32082, 332, 61689, 4706, 30579, 47, 11, 46, 3448, 33188, 7856, 5383, 49995, 101, 45308, 40008, 21286, 32354, 4596, 56436, 30579, 62586, 4811, 63508, 57129, 30579, 30917, 332, 55912, 47, 261, 402, 3483, 47, 61324, 11, 48370, 101, 45308, 40008, 21286, 332, 56900, 30579, 60572, 32227, 46700, 52869, 61544, 31601, 22655, 40936, 101, 45308, 40008, 47, 29893, 21286, 59594, 45, 31059, 52371, 46182, 45, 21265, 53061, 30826, 60463, 21265, 59877, 47, 37564, 32232, 31059, 32074, 64892, 45, 32139, 4423, 47313, 59877, 21265, 55946, 21265, 59846, 46543, 40083, 45, 32232, 21286, 47792, 32354, 4596, 53265, 64251, 47, 64817, 55596, 45308, 40008, 4600, 59644, 21700, 55809, 52814, 57330, 21265, 64993, 53362, 32487, 30579, 62586, 21265, 61559, 47, 0, 36, 37055, 8706, 29536, 7856, 55253, 4596, 44294, 44289, 261, 402, 64194, 4811, 37055, 8706, 29536, 7856, 55253, 261, 1136, 55809, 52814, 45, 332, 39079, 8706, 52400, 52569, 4600, 332, 52569, 4596, 40186, 4858, 21286, 38594, 332, 39079, 8706, 4706, 56089, 21265, 332, 45994, 38478, 45, 21265, 22590, 60076, 4600, 4811, 30858, 332, 47448, 4706, 56089, 32139, 32227, 4692, 22638, 56089, 4596, 22590, 47448, 21286, 38386, 21265, 22590, 22532, 4706, 22590, 56089, 4596, 22590, 47448, 4600, 38386, 4811, 332, 38594, 40093, 47, 261, 402, 61343, 4706, 332, 37055, 8706, 29536, 7856, 50570, 261, 66, 39079, 8706, 52400, 52569, 4600, 51412, 4450, 332, 39079, 8706, 4706, 56089, 271, 84, 412, 332, 45994, 38478, 271, 71, 412, 21265, 332, 40093, 271, 108, 413, 20996, 60076, 4600, 4811, 30858, 332, 47448, 271, 84, 40, 327, 54375, 318, 37, 32139, 32227]
# - attention_mask length: 32768
# - token_type_ids length: 32768
# Document 8:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32752
# - input_ids sample: [62994, 59, 11, 6833, 21286, 4419, 3609, 59179, 47, 29956, 32475, 22799, 30972, 22799, 332, 32202, 47, 30076, 30985, 4600, 4811, 55801, 22590, 32202, 4423, 62000, 4423, 22799, 21413, 47, 37564, 62304, 22590, 32202, 39942, 32115, 46, 1782, 46, 27074, 21265, 52069, 32515, 39815, 47, 261, 74, 4418, 332, 39073, 56004, 21265, 308, 31198, 57033, 22590, 59725, 39073, 31705, 47, 36523, 22799, 31073, 4660, 45175, 32234, 57009, 64, 3908, 22187, 45, 22001, 4660, 31223, 4450, 53371, 269, 6338, 45175, 24381, 386, 267, 24025, 39966, 59, 4255, 29211, 332, 29409, 7856, 24884, 37054, 31705, 59, 20996, 30855, 460, 40240, 63810, 116, 45, 29151, 44528, 269, 1453, 8440, 35, 19894, 1791, 275, 23909, 19483, 7664, 42, 21265, 21811, 51096, 44450, 19448, 25687, 269, 1160, 110, 35, 19894, 1791, 275, 24016, 8097, 19404, 8398, 497, 31310, 4596, 22590, 59711, 32283, 4706, 20394, 25048, 45, 49945, 45, 45805, 22590, 38328, 3492, 650, 116, 47, 20996, 39831, 45608, 39946, 40237, 45, 45805, 40186, 37322, 21265, 3933, 110, 53224, 51165, 4596, 39931, 38919, 47, 29893, 37829, 4423, 56460, 55734, 45, 22762, 39761, 39931, 30582, 51898, 52491, 38576, 32487, 30719, 39193, 21265, 47377, 4712, 43983, 269, 890, 112, 35, 20715, 8083, 275, 40724, 3752, 9006, 109, 497, 22762, 21800, 22187, 30259, 31968, 21700, 31370, 40237, 4450, 50930, 4423, 332, 47092, 4706, 39115, 52115, 21823, 38717, 21265, 37598, 32469, 31370, 47149, 45476, 7066, 47, 37449, 40193, 1843, 45962, 45, 19448, 25687, 275, 23700, 8412, 20634, 108, 497, 4600, 332, 32283, 46409, 21265, 21800, 332, 47436, 45294, 32227, 21256, 46787, 21286, 4811, 4435, 53190, 45954, 45, 4811, 32321, 22590, 39193, 38009, 45, 21265, 4811, 39797, 21700, 32464, 22799, 51025, 47, 3878, 30135, 45143, 21823, 55734, 4811, 30380, 21820, 4450, 21823, 38499, 31496, 47, 36607, 4596, 22590, 30855, 45, 22590, 55734, 22449, 39931, 45962, 45084, 4571, 7255, 2174, 31552, 45, 21265, 39193, 52573, 45, 30917, 4031, 47, 61341, 275, 927, 24471, 28757, 2098, 42, 21700, 38881, 32499, 51018, 22590, 45492, 21800, 4692, 39052, 592, 52, 94, 50737, 39931, 45962, 460, 32499, 4423, 332, 46409, 45, 37322, 21265, 3933, 110, 37829, 4811, 38877, 4706, 22590, 46982, 21265, 30791, 4596, 39931, 32283, 45, 61553, 4450, 52529, 60, 32232, 46531, 52628, 4423, 32232, 21286, 51693, 4811, 4601, 47, 20996, 38924, 38825, 275, 24011, 19897, 42, 50939, 116, 19448, 25687, 4811, 45687, 332, 37850, 22068, 45, 21015, 55298, 275, 5651, 1794, 44700, 497, 50870, 4419, 61527, 4706, 31826, 4706, 332, 40189, 30971, 45, 20394, 25220, 304, 27469, 275, 23513, 1950, 21157, 7281, 499, 19448, 25687, 50842, 22590, 30405, 47, 3933, 110, 21265, 37322, 61979, 47188, 27517, 22571, 2077, 116, 21700, 39931, 45962, 460, 55924, 47, 36918, 45, 4423, 19448, 25687, 4600, 52915, 4596, 38559, 4706, 22590, 38924, 31179, 4811, 60439, 21015, 55298, 45, 4569, 38436, 22590, 50954, 4706, 332, 4653, 2061, 105, 22100, 45, 40186, 56428, 4031, 47, 61341, 47, 37322, 45, 3933, 110, 21265, 39931, 46047, 45, 19748, 109, 275, 23813, 20404, 2059, 497, 59905, 22590, 64866, 47, 37322, 45, 53221, 4706, 22590, 22100, 460, 52610, 45, 62439, 61341, 4423, 22590, 22068, 22762, 31612, 21811, 45962, 4596, 4571, 7255, 2174, 31552, 21265, 39909, 21820, 4811]
# - attention_mask length: 32752
# - token_type_ids length: 32752
# Document 9:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32768
# - input_ids sample: [7933, 39688, 34684, 60323, 37598, 22590, 52580, 460, 55615, 21265, 38875, 4811, 31458, 63775, 21265, 57075, 30469, 47, 261, 23266, 20732, 42461, 261, 6525, 42461, 4600, 332, 63591, 60624, 4596, 62030, 63795, 47, 3918, 56501, 55940, 332, 56292, 32227, 37949, 46342, 4811, 39740, 52932, 59884, 4706, 22590, 31937, 52569, 40076, 332, 30243, 30405, 4600, 52643, 47, 20732, 42461, 45143, 21700, 51575, 21265, 51276, 60521, 4811, 53265, 56939, 45, 59841, 52427, 59499, 39898, 47, 261, 5201, 50528, 36998, 7856, 4596, 61378, 63214, 58884, 261, 48634, 56595, 4600, 332, 56900, 51725, 4706, 62030, 63795, 59946, 32227, 51597, 22590, 61707, 4706, 30579, 62586, 50870, 62344, 56832, 47, 29894, 45143, 21700, 60471, 61995, 4706, 30579, 37810, 4712, 22590, 60572, 4706, 22590, 30579, 47, 261, 23266, 64194, 4811, 50528, 36998, 7856, 261, 48634, 56595, 56501, 55940, 332, 52427, 21265, 32230, 40085, 4601, 4811, 38981, 50870, 332, 30579, 60572, 47, 3908, 22590, 52427, 52200, 22590, 30579, 60572, 45, 22590, 61603, 30469, 61603, 32487, 22590, 52427, 4600, 56168, 47, 261, 23266, 58784, 37504, 4706, 50528, 116, 261, 60860, 63795, 59946, 53061, 53265, 40050, 4706, 56832, 45, 59841, 59, 261, 46, 3448, 48566, 50528, 116, 5331, 37453, 56832, 38981, 52146, 47700, 45, 32139, 4423, 53031, 45, 52333, 45, 4715, 51071, 116, 47, 11, 46, 3448, 53724, 50528, 116, 5331, 37453, 56832, 38981, 21273, 40093, 21265, 30284, 4601, 4811, 332, 57518, 47, 11, 46, 3448, 62972, 50528, 116, 5331, 37453, 56832, 38981, 30579, 62586, 32227, 21286, 63397, 40085, 57271, 63398, 116, 47, 11, 46, 3448, 24331, 24956, 50528, 116, 5331, 37453, 56832, 38981, 21273, 40093, 53356, 51042, 4601, 4811, 332, 57518, 47, 261, 23266, 37519, 50528, 36998, 7856, 4811, 50214, 28741, 261, 48634, 56595, 21413, 4435, 32354, 4811, 51698, 30579, 30917, 30579, 62586, 4596, 332, 51276, 21265, 59594, 46505, 47, 19907, 56467, 45, 22590, 59725, 30469, 32356, 52427, 56595, 4811, 51698, 22590, 38499, 31496, 21265, 21238, 30917, 332, 46795, 47024, 59, 261, 6884, 42114, 11, 7334, 51698, 96, 26290, 96, 7005, 96, 6935, 41, 42045, 501, 28352, 35047, 46795, 59, 54807, 24960, 4896, 34453, 96, 26290, 448, 31496, 45, 274, 6935, 448, 21238, 2395, 64158, 42178, 31496, 45, 21238, 54807, 24960, 330, 59, 64158, 42178, 29487, 45, 29487, 11, 6884, 261, 5201, 36998, 7856, 50528, 116, 4596, 36950, 21265, 37498, 116, 261, 48634, 56595, 21413, 4435, 50937, 4811, 38914, 21265, 47636, 4811, 51698, 57271, 56089, 4715, 22525, 35016, 47, 261, 23266, 50528, 36998, 7856, 32487, 36950, 261, 6699, 59725, 30469, 32356, 52427, 56595, 4811, 51698, 22590, 38499, 21265, 31254, 56089, 30917, 332, 31307, 59, 261, 6884, 42114, 11, 7334, 51698, 96, 34453, 96, 7005, 96, 26102, 41, 26157, 501, 28352, 35047, 31307, 59, 54807, 24960, 326, 34453, 45, 277, 1714, 31254, 1689, 64158, 42178, 38499, 45, 31254, 54807, 24960, 330, 59, 64158, 42178, 29487, 45, 29487, 11, 6884, 261, 23266, 50528, 36998, 7856, 32487, 37498, 116, 261, 33536, 116, 21413, 30135, 4435, 52199, 40085, 56832, 47, 20996, 59725, 30469, 56192, 22590, 38499, 21265, 47205, 56089, 30917, 332, 40037, 59, 261, 6884, 42114, 11, 7334, 51698, 96, 34453, 96, 7005, 96, 42235, 41, 35806, 501, 28352, 35047, 40037, 59, 54807, 24960, 275]
# - attention_mask length: 32768
# - token_type_ids length: 32768
# Document 10:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 869
# - input_ids sample: [58118, 32234, 30917, 50640, 31162, 50199, 59, 11, 48701, 59, 269, 2781, 42803, 2805, 48102, 32663, 43190, 32756, 47967, 43055, 42728, 2802, 2824, 62933, 64076, 57738, 2794, 269, 2768, 42768, 2811, 384, 64687, 54523, 2807, 42962, 48002, 32671, 27981, 27989, 28135, 54532, 47, 11, 48487, 59, 33, 35, 74, 38674, 21835, 30819, 60107, 332, 56678, 4811, 47110, 22590, 4357, 25275, 56258, 30463, 47, 0, 58118, 30917, 50199, 31162, 36547, 59, 11, 48487, 59, 4331, 21286, 30135, 38606, 4811, 40007, 21265, 56920, 22590, 53064, 47, 11, 68, 27548, 59, 33, 2535, 1850, 2495, 4607, 22563, 8854, 2605, 346, 9437, 117, 9432, 8274, 332, 21962, 9157, 9004, 102, 22318, 2153, 1933, 47, 0, 58118, 30917, 50199, 31162, 44340, 59, 11, 48487, 59, 19555, 22590, 59921, 32227, 37823, 21823, 31496, 38919, 4712, 47, 11, 40508, 59, 33, 838, 1857, 21533, 3788, 25423, 8937, 45, 21533, 39621, 111, 29456, 111, 4813, 27621, 45, 32483, 47780, 7697, 22700, 27470, 1859, 47, 0, 58118, 30917, 50199, 31162, 50072, 59, 11, 48487, 59, 20996, 3493, 2209, 39551, 4706, 3683, 66, 52690, 47203, 32475, 37829, 53152, 45, 40186, 30135, 38989, 22590, 39801, 4706, 22590, 47205, 31040, 4706, 3683, 66, 46414, 4596, 3493, 636, 127, 640, 637, 47203, 47, 11, 48407, 59, 33, 10381, 13115, 19137, 896, 66, 15162, 640, 17085, 12182, 16521, 16925, 14734, 13637, 16925, 10953, 11967, 12266, 11726, 19137, 17148, 10322, 12522, 11110, 14808, 640, 636, 127, 640, 637, 16925, 11869, 14734, 896, 66, 15671, 16925, 10258, 10923, 15052, 12266, 11726, 10080, 0, 58118, 30917, 50199, 31162, 36547, 59, 11, 48487, 59, 3635, 20379, 7719, 1767, 22748, 55545, 22638, 30582, 37634, 22590, 30971, 460, 64893, 4712, 3500, 29179, 47, 11, 68, 27548, 59, 33, 847, 20379, 7719, 1767, 4450, 109, 4885, 117, 27749, 4498, 98, 4490, 122, 4738, 21587, 119, 9406, 8278, 357, 2042, 9156, 2507, 3500, 47, 4990, 7502, 2059, 47, 0, 58118, 32234, 30917, 50328, 1939, 31162, 50199, 59, 11, 6107, 26096, 1939, 59, 4959, 25366, 4520, 4512, 2219, 105, 2251, 2510, 22453, 4985, 2520, 4985, 7037, 117, 21256, 2202, 103, 332, 2510, 4567, 1866, 4974, 21840, 98, 45, 22599, 332, 2510, 21700, 2510, 7061, 22723, 1775, 1943, 2510, 106, 336, 2510, 98, 31201, 8726, 4606, 1879, 9016, 4978, 24859, 4962, 4962, 4985, 9054, 4579, 7496, 1943, 4569, 7842, 8162, 111, 21749, 98, 4572, 8987, 2059, 47, 11, 48487, 59, 33, 24242, 4600, 60522, 22799, 45150, 31506, 4811, 31205, 4596, 31427, 45, 4811, 37786, 65126, 4715, 52448, 30788, 30653, 24726, 31601, 38924, 32448, 4811, 4491, 47539, 47, 0, 58118, 30917, 50199, 31162, 50640, 59, 11, 48487, 59, 63222, 30917, 58952, 61502, 4596, 22590, 45010, 44910, 21265, 4287, 2128, 6976, 61502, 4596, 44942, 57097, 22590, 22168, 52965, 51662, 4596, 31198, 22638, 63595, 45, 47544, 32234, 52571, 21795, 30259, 55616, 4811, 32187, 31466, 46470, 45, 21572, 4811, 55656, 51035, 4419, 51605, 44189, 21683, 1791, 45, 19960, 8738, 2345, 38542, 116, 45, 21265, 22590, 59819, 21408, 2220, 116, 21683, 1791, 45, 19960, 8738, 2345, 21456, 25928, 8838, 116, 47, 11, 48701, 59, 33, 2770, 28064, 42860, 42976, 54736, 32710, 47914, 2807, 43110, 2807, 61212, 65438, 275, 2779, 27861, 42]
# - attention_mask length: 869
# - token_type_ids length: 869
# Document 11:
# - Keys: dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# - input_ids length: 32768
# - input_ids sample: [32458, 46, 34177, 1843, 21265, 62647, 2030, 55966, 47, 3681, 55882, 56945, 32227, 52731, 30322, 61548, 21265, 64915, 45, 59491, 21413, 45184, 4811, 22590, 55839, 460, 59892, 21265, 39631, 4706, 51481, 26234, 47, 261, 33392, 59, 308, 56572, 32227, 61548, 32475, 45150, 40025, 64915, 4596, 22590, 55839, 460, 31427, 47, 44696, 21286, 38297, 4811, 45282, 45, 21265, 32232, 21286, 53350, 4811, 22269, 332, 52540, 21700, 4601, 47, 61378, 7933, 45, 4712, 22590, 39193, 31044, 45, 4600, 39171, 39887, 21700, 51863, 47, 54940, 116, 45926, 56945, 4811, 32499, 32458, 45, 21400, 32232, 21286, 22187, 53350, 4811, 22269, 38434, 21700, 4601, 47, 261, 5584, 1853, 59, 21189, 65032, 22590, 39339, 4706, 30992, 45717, 45, 37266, 47, 30032, 61548, 21265, 64915, 21286, 57172, 2030, 62141, 45, 22590, 47092, 4600, 332, 52574, 32227, 4600, 22187, 31581, 57541, 59154, 21400, 30135, 332, 56875, 4811, 22681, 47, 29834, 56945, 51242, 332, 52540, 51018, 32232, 39169, 332, 57350, 32355, 61979, 47, 261, 33392, 59, 37564, 308, 37640, 32227, 30992, 45717, 21413, 51618, 22590, 32355, 61979, 45, 308, 51307, 32227, 64915, 52701, 22590, 31458, 59829, 45950, 4596, 63466, 332, 52574, 460, 53052, 47, 300, 52574, 32227, 4600, 59219, 21400, 59516, 4811, 22681, 32475, 52628, 4435, 59051, 4450, 59382, 47, 261, 5584, 1853, 59, 308, 39332, 32227, 332, 52574, 32227, 4600, 30322, 59219, 21265, 30724, 4811, 22681, 32475, 4435, 31458, 62603, 4596, 22590, 31323, 22418, 32226, 332, 52574, 32227, 4600, 46548, 62030, 47, 54940, 116, 21286, 31458, 46439, 4811, 51456, 4419, 59615, 61752, 32487, 332, 52574, 32227, 32232, 30858, 59100, 24525, 56874, 45, 21265, 32232, 21286, 31458, 46439, 4811, 60336, 4601, 4811, 46726, 47, 261, 33392, 59, 308, 51270, 32227, 61548, 21413, 31702, 332, 31894, 4596, 55666, 37900, 52164, 45, 21400, 308, 56572, 32227, 64915, 4600, 22590, 62018, 32350, 40186, 53052, 4600, 37924, 47, 300, 52574, 32227, 4600, 59219, 21400, 30659, 22187, 52446, 4423, 56175, 32475, 52628, 22568, 8250, 105, 332, 37900, 460, 62493, 47, 261, 5584, 1853, 59, 308, 37640, 32227, 64915, 4600, 59644, 45, 21400, 308, 51025, 32227, 4601, 4600, 56895, 4811, 45616, 56945, 32227, 21286, 30322, 59219, 21265, 62030, 47, 3681, 59262, 63389, 22590, 32355, 460, 39105, 21265, 4450, 40085, 62128, 45717, 62633, 45, 59491, 21413, 45616, 56945, 32227, 39169, 332, 57172, 37860, 4706, 30899, 21265, 56292, 47, 261, 33392, 59, 37564, 308, 61588, 32515, 56768, 45, 308, 47059, 40061, 9033, 7219, 47, 20996, 51929, 4706, 52574, 45717, 4600, 46453, 1843, 32487, 56162, 4706, 56945, 32227, 32462, 30322, 59219, 21265, 62030, 45, 22797, 45953, 4811, 50848, 61699, 53052, 47, 20996, 46517, 4600, 332, 51258, 21265, 65037, 37824, 45, 21265, 39934, 4600, 4692, 59778, 32227, 332, 52574, 32227, 4600, 30322, 59219, 21265, 62030, 32475, 4435, 62603, 47, 261, 5584, 1853, 59, 308, 62683, 32515, 62561, 45, 37266, 45, 21400, 308, 51025, 32227, 22590, 46064, 4706, 52574, 45717, 31291, 4596, 55882, 56945, 32227, 57172, 2030, 59890, 61548, 21265, 64915, 47, 3641, 59382, 45284, 31458, 65014, 21265, 51481, 7856, 45, 32232, 32475, 45694, 56945, 32227, 39169, 30322, 45282, 21265, 63750, 47, 54970, 116, 22762, 21286, 30093, 4811, 31397, 32234, 45694, 32475, 4435, 22590, 31580, 22762, 53051, 47, 0, 61, 41156, 790]
# - attention_mask length: 32768
# - token_type_ids length: 32768

# %% [markdown]
# ## Start the training run!

# %%
# Setup the checkpoint dir
# !cd "{PROJECT_DIR}" && mkdir -p "./checkpoint/{CONFIG_FILE_NAME}/"

# Lets start the training
# !cd "{TRAINER_DIR}" && \
    export RWKV_NO_CUDA=1 && \
    export RWKV_TORCH_COMPILE=0 && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py validate \
        -c "{NOTEBOOK_DIR}/{CONFIG_FILE_DIR}/{CONFIG_FILE_NAME}.yaml" \
        --model.load_model="../model/{MODEL_NAME}" \
        --data.skip_datapath_setup=True \
        --trainer.callbacks.init_args.dirpath="../checkpoint/{CONFIG_FILE_NAME}/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - {CONFIG_FILE_NAME} (tctxlen={TRAINING_CTX_LEN}, {DEEPSPEED_STRAT})" \
        --trainer.logger.init_args.project="{WANDB_PROJECT}" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.target_batch_size=512 \
        --trainer.microbatch_size={MICROBATCH_SIZE} \
        --model.ctx_len={TRAINING_CTX_LEN} \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-02-04 08:34:18,886] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['validate', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-zMultipack.yaml', '--model.load_model=../model/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=../checkpoint/Eagle-x-zMultipack/', '--trainer.logger.init_args.name=RWKV-v5-Finetune - Eagle-x-zMultipack (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-v5-Finetune', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=512', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'], args=['validate', '-c', '/workspace/picocreator/RWKV-infctx-trainer/notebook/finetune-example/./Eagle-x-zMultipack.yaml', '--model.load_model=../model/RWKV-v5-Eagle-World-7B-v2-20240128-ctx4096.pth', '--data.skip_datapath_setup=True', '--trainer.callbacks.init_args.dirpath=../checkpoint/Eagle-x-zMultipack/', '--trainer.logger.init_args.name=RWKV-v5-Finetune - Eagle-x-zMultipack (tctxlen=4096, deepspeed_stage_2)', '--trainer.logger.init_args.project=RWKV-v5-Finetune', '--trainer.strategy=deepspeed_stage_2', '--trainer.target_batch_size=512', '--trainer.microbatch_size=8', '--model.ctx_len=4096', '--trainer.devices=auto'].
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/utilities/seed.py:40: No seed found, seed set to 1905585026
# Seed set to 1905585026
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       512
#    - num_nodes:               1
#    - num_devices:             8
#    - microbatch_size:         8
#    - accumulate_grad_batches: 8
#    - effective_batch_size:    512
#
# [rank: 0] Seed set to 1905585026
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/8
# [2024-02-04 08:34:59,839] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 08:34:59,839] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 08:34:59,840] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 08:35:00,029] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 08:35:00,030] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 08:35:00,034] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-02-04 08:35:00,034] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [RWKV.model] Running RWKV infctx using 'torch-jit' with torch '2.1.1+cu121'
# [rank: 7] Seed set to 1905585026
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 3] Seed set to 1905585026
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 1] Seed set to 1905585026
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 4] Seed set to 1905585026
# [rank: 5] Seed set to 1905585026
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 2] Seed set to 1905585026
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 6] Seed set to 1905585026
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# [rank: 5] Seed set to 1905585026
# initializing deepspeed distributed: GLOBAL_RANK: 5, MEMBER: 6/8
# [rank: 7] Seed set to 1905585026
# initializing deepspeed distributed: GLOBAL_RANK: 7, MEMBER: 8/8
# [rank: 2] Seed set to 1905585026
# initializing deepspeed distributed: GLOBAL_RANK: 2, MEMBER: 3/8
# [rank: 1] Seed set to 1905585026
# initializing deepspeed distributed: GLOBAL_RANK: 1, MEMBER: 2/8
# [rank: 6] Seed set to 1905585026
# initializing deepspeed distributed: GLOBAL_RANK: 6, MEMBER: 7/8
# [rank: 3] Seed set to 1905585026
# initializing deepspeed distributed: GLOBAL_RANK: 3, MEMBER: 4/8
# [rank: 4] Seed set to 1905585026
# initializing deepspeed distributed: GLOBAL_RANK: 4, MEMBER: 5/8
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in ./wandb/run-20240204_083602-741gp1cd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RWKV-v5-Finetune - Eagle-x-zMultipack (tctxlen=4096, deepspeed_stage_2)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune/runs/741gp1cd
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# Validation DataLoader 0: 100%|████████████████████| 1/1 [00:14<00:00,  0.07it/s]
# ────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#      validation/loss           0.9912109375
# ────────────────────────────────────────────────────────────────────────────────
# wandb: \ 0.029 MB of 0.029 MB uploaded (0.004 MB deduped)
# wandb: Run history:
# wandb:                batchidx ▁
# wandb:                   epoch ▁
# wandb:             global_rank ▁
# wandb:     trainer/global_step ▁▁
# wandb:  validation/data_ctxlen ▁
# wandb:    validation/data_loss ▁
# wandb:   validation/learn_loss ▁
# wandb: validation/learn_tokens ▁
# wandb:         validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                batchidx 0
# wandb:                   epoch 0
# wandb:             global_rank 0
# wandb:     trainer/global_step 0
# wandb:  validation/data_ctxlen 32767
# wandb:    validation/data_loss 0.98438
# wandb:   validation/learn_loss 0.98438
# wandb: validation/learn_tokens 34108
# wandb:         validation/loss 0.99121
# wandb:
# wandb: 🚀 View run RWKV-v5-Finetune - Eagle-x-zMultipack (tctxlen=4096, deepspeed_stage_2) at: https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune/runs/741gp1cd
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-v5-Finetune/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjEzNTU3NTUxNw==/version_details/v10
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240204_083602-741gp1cd/logs

# %% [markdown]
# ## Export the model

# %%
# Lets export the model from the checkpoint
# !cd "{TRAINER_DIR}" && \
    python export_checkpoint.py "../checkpoint/{CONFIG_FILE_NAME}/last.ckpt" "../model/{CONFIG_FILE_NAME}.pth"
# !cd "{TRAINER_DIR}" && ls -alh "../model/{CONFIG_FILE_NAME}.pth"

# %% [markdown]
# ## Sanity check (that the model actually output stuff)

# %%
# Lets do a quick dragon prompt validation
# !cd "{TRAINER_DIR}" && \
    python3 dragon_test.py "../model/{CONFIG_FILE_NAME}.pth" "cuda bf16"
