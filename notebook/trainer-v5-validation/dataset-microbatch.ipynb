# %% [markdown]
# # Dataset microbatch testing
#
# Testing runs on multiple micro batch settings

# %%
GPU_DEVICES="auto"
ENABLE_WANDB=False
WANDB_PREFIX="infctx-v5-microbatch"

print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# ENABLE_WANDB: False
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /home/picocreator/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation
# TRAINER_DIR: /home/picocreator/rwkv-proj/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /home/picocreator/rwkv-proj/RWKV-infctx-trainer

# %%
# Init the model
# !cd "{TRAINER_DIR}" && \
    python3 ./init_model.py \
        --n_layer 6 --n_embd 512 \
        --vocab_size world --skip-if-exists \
        "../model/L6-D512-world-v5base-init.pth"
# Out:
# [2024-01-18 11:19:39,010] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.1'
# ---- Initializing model ----
# No of layers: 6
# Embedding size: 512
# Output model path: ../model/L6-D512-world-v5base-init.pth
# Vocab size: 65536
# Emb scale: 0.0001
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Model exists, skipping init_model

# %%
# Lets preload the requried dataset 
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/config/enwiki_10k-world-full.yaml"
# Out:
# Map (num_proc=16): 100%|█████████| 10000/10000 [00:01<00:00, 9575.14 examples/s]
# Filter (num_proc=16): 100%|█████| 10000/10000 [00:00<00:00, 12203.75 examples/s]
# Map (num_proc=16): 100%|██████████| 9892/9892 [00:00<00:00, 20646.21 examples/s]
# Saving the dataset (1/1 shards): 100%|█| 9892/9892 [00:00<00:00, 241357.37 examp
# Saving the dataset (1/1 shards): 100%|█| 100/100 [00:00<00:00, 28064.93 examples

# %% [markdown]
# # microbatch=1
#
# Note: We are intentionally testing without rechunk, as that has known edge case issues.

# %%
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_10k-world-full.yaml" \
        --model.load_model="../model/L6-D512-world-v5base-init.pth" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v5-enwiki-10k-full/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Microbatch 1 - (deepspeed_stage_1)" \
        --trainer.strategy="deepspeed_stage_1" \
        --trainer.microbatch_size=1 \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-01-18 12:00:55,830] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.1'
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/picocreator/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-full.yaml', '--model.load_model=../model/L6-D512-world-v5base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v5-enwiki-10k-full/', '--trainer.logger.init_args.name=infctx-v5-microbatch - Microbatch 1 - (deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.microbatch_size=1', '--trainer.devices=auto'], args=['fit', '-c', '/home/picocreator/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-full.yaml', '--model.load_model=../model/L6-D512-world-v5base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v5-enwiki-10k-full/', '--trainer.logger.init_args.name=infctx-v5-microbatch - Microbatch 1 - (deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.microbatch_size=1', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /home/picocreator/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - microbatch_size:         1
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    16
#
# Saving the dataset (1/1 shards): 100%|█| 9892/9892 [00:00<00:00, 595479.80 examp
# Saving the dataset (1/1 shards): 100%|█| 100/100 [00:00<00:00, 28472.64 examples
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:639: Checkpoint directory ../checkpoint/v5-enwiki-10k-full/ exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/picocreator/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.05255270004272461 seconds
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1699449201450/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 87.6 M    Trainable params
# 0         Non-trainable params
# 87.6 M    Total params
# 350.405   Total estimated model params size (MB)
# Epoch 0:  16%|▏| 1600/9892 [00:55<04:49, 28.62it/s, v_num=mu7h, train/loss=5.310/home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 9892/9892 [05:45<00:00, 28.62it/s, v_num=mu7h, train/loss=4.090
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/100 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/100 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/100 [00:00<00:30,  3.23it/s]
# Validation DataLoader 0:   2%|▎                 | 2/100 [00:00<00:28,  3.44it/s]
# Validation DataLoader 0:   3%|▌                 | 3/100 [00:00<00:27,  3.49it/s]
# Validation DataLoader 0:   4%|▋                 | 4/100 [00:01<00:27,  3.54it/s]
# Validation DataLoader 0:   5%|▉                 | 5/100 [00:01<00:26,  3.57it/s]
# Validation DataLoader 0:   6%|█                 | 6/100 [00:01<00:26,  3.59it/s]
# Validation DataLoader 0:   7%|█▎                | 7/100 [00:01<00:25,  3.60it/s]
# Validation DataLoader 0:   8%|█▍                | 8/100 [00:02<00:25,  3.62it/s]
# Validation DataLoader 0:   9%|█▌                | 9/100 [00:02<00:25,  3.62it/s]
# Validation DataLoader 0:  10%|█▋               | 10/100 [00:02<00:24,  3.63it/s]
# Validation DataLoader 0:  11%|█▊               | 11/100 [00:03<00:24,  3.64it/s]
# Validation DataLoader 0:  12%|██               | 12/100 [00:03<00:24,  3.64it/s]
# Validation DataLoader 0:  13%|██▏              | 13/100 [00:03<00:23,  3.65it/s]
# Validation DataLoader 0:  14%|██▍              | 14/100 [00:03<00:23,  3.65it/s]
# Validation DataLoader 0:  15%|██▌              | 15/100 [00:04<00:23,  3.66it/s]
# Validation DataLoader 0:  16%|██▋              | 16/100 [00:04<00:22,  3.66it/s]
# Validation DataLoader 0:  17%|██▉              | 17/100 [00:04<00:22,  3.66it/s]
# Validation DataLoader 0:  18%|███              | 18/100 [00:04<00:22,  3.66it/s]
# Validation DataLoader 0:  19%|███▏             | 19/100 [00:05<00:22,  3.67it/s]
# Validation DataLoader 0:  20%|███▍             | 20/100 [00:05<00:21,  3.67it/s]
# Validation DataLoader 0:  21%|███▌             | 21/100 [00:05<00:21,  3.67it/s]
# Validation DataLoader 0:  22%|███▋             | 22/100 [00:06<00:21,  3.66it/s]
# Validation DataLoader 0:  23%|███▉             | 23/100 [00:06<00:21,  3.67it/s]
# Validation DataLoader 0:  24%|████             | 24/100 [00:06<00:20,  3.67it/s]
# Validation DataLoader 0:  25%|████▎            | 25/100 [00:07<00:22,  3.39it/s]
# Validation DataLoader 0:  26%|████▍            | 26/100 [00:07<00:21,  3.40it/s]
# Validation DataLoader 0:  27%|████▌            | 27/100 [00:07<00:21,  3.41it/s]
# Validation DataLoader 0:  28%|████▊            | 28/100 [00:08<00:21,  3.42it/s]
# Validation DataLoader 0:  29%|████▉            | 29/100 [00:08<00:20,  3.43it/s]
# Validation DataLoader 0:  30%|█████            | 30/100 [00:08<00:20,  3.44it/s]
# Validation DataLoader 0:  31%|█████▎           | 31/100 [00:08<00:20,  3.44it/s]
# Validation DataLoader 0:  32%|█████▍           | 32/100 [00:09<00:19,  3.45it/s]
# Validation DataLoader 0:  33%|█████▌           | 33/100 [00:09<00:19,  3.46it/s]
# Validation DataLoader 0:  34%|█████▊           | 34/100 [00:09<00:19,  3.47it/s]
# Validation DataLoader 0:  35%|█████▉           | 35/100 [00:10<00:18,  3.47it/s]
# Validation DataLoader 0:  36%|██████           | 36/100 [00:10<00:18,  3.48it/s]
# Validation DataLoader 0:  37%|██████▎          | 37/100 [00:10<00:18,  3.49it/s]
# Validation DataLoader 0:  38%|██████▍          | 38/100 [00:10<00:17,  3.49it/s]
# Validation DataLoader 0:  39%|██████▋          | 39/100 [00:11<00:17,  3.50it/s]
# Validation DataLoader 0:  40%|██████▊          | 40/100 [00:11<00:17,  3.50it/s]
# Validation DataLoader 0:  41%|██████▉          | 41/100 [00:11<00:16,  3.51it/s]
# Validation DataLoader 0:  42%|███████▏         | 42/100 [00:11<00:16,  3.51it/s]
# Validation DataLoader 0:  43%|███████▎         | 43/100 [00:12<00:16,  3.51it/s]
# Validation DataLoader 0:  44%|███████▍         | 44/100 [00:12<00:15,  3.52it/s]
# Validation DataLoader 0:  45%|███████▋         | 45/100 [00:12<00:15,  3.52it/s]
# Validation DataLoader 0:  46%|███████▊         | 46/100 [00:13<00:15,  3.53it/s]
# Validation DataLoader 0:  47%|███████▉         | 47/100 [00:13<00:15,  3.53it/s]
# Validation DataLoader 0:  48%|████████▏        | 48/100 [00:13<00:14,  3.53it/s]
# Validation DataLoader 0:  49%|████████▎        | 49/100 [00:13<00:14,  3.54it/s]
# Validation DataLoader 0:  50%|████████▌        | 50/100 [00:14<00:14,  3.54it/s]
# Validation DataLoader 0:  51%|████████▋        | 51/100 [00:14<00:13,  3.54it/s]
# Validation DataLoader 0:  52%|████████▊        | 52/100 [00:14<00:13,  3.54it/s]
# Validation DataLoader 0:  53%|█████████        | 53/100 [00:14<00:13,  3.55it/s]
# Validation DataLoader 0:  54%|█████████▏       | 54/100 [00:15<00:12,  3.55it/s]
# Validation DataLoader 0:  55%|█████████▎       | 55/100 [00:15<00:12,  3.55it/s]
# Validation DataLoader 0:  56%|█████████▌       | 56/100 [00:15<00:12,  3.56it/s]
# Validation DataLoader 0:  57%|█████████▋       | 57/100 [00:16<00:12,  3.56it/s]
# Validation DataLoader 0:  58%|█████████▊       | 58/100 [00:16<00:11,  3.56it/s]
# Validation DataLoader 0:  59%|██████████       | 59/100 [00:16<00:11,  3.56it/s]
# Validation DataLoader 0:  60%|██████████▏      | 60/100 [00:16<00:11,  3.57it/s]
# Validation DataLoader 0:  61%|██████████▎      | 61/100 [00:17<00:10,  3.57it/s]
# Validation DataLoader 0:  62%|██████████▌      | 62/100 [00:17<00:10,  3.57it/s]
# Validation DataLoader 0:  63%|██████████▋      | 63/100 [00:17<00:10,  3.57it/s]
# Validation DataLoader 0:  64%|██████████▉      | 64/100 [00:17<00:10,  3.58it/s]
# Validation DataLoader 0:  65%|███████████      | 65/100 [00:18<00:09,  3.58it/s]
# Validation DataLoader 0:  66%|███████████▏     | 66/100 [00:18<00:09,  3.58it/s]
# Validation DataLoader 0:  67%|███████████▍     | 67/100 [00:18<00:09,  3.58it/s]
# Validation DataLoader 0:  68%|███████████▌     | 68/100 [00:18<00:08,  3.58it/s]
# Validation DataLoader 0:  69%|███████████▋     | 69/100 [00:19<00:08,  3.58it/s]
# Validation DataLoader 0:  70%|███████████▉     | 70/100 [00:19<00:08,  3.59it/s]
# Validation DataLoader 0:  71%|████████████     | 71/100 [00:19<00:08,  3.59it/s]
# Validation DataLoader 0:  72%|████████████▏    | 72/100 [00:20<00:07,  3.59it/s]
# Validation DataLoader 0:  73%|████████████▍    | 73/100 [00:20<00:07,  3.59it/s]
# Validation DataLoader 0:  74%|████████████▌    | 74/100 [00:20<00:07,  3.59it/s]
# Validation DataLoader 0:  75%|████████████▊    | 75/100 [00:20<00:06,  3.60it/s]
# Validation DataLoader 0:  76%|████████████▉    | 76/100 [00:21<00:06,  3.60it/s]
# Validation DataLoader 0:  77%|█████████████    | 77/100 [00:21<00:06,  3.60it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 78/100 [00:21<00:06,  3.60it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 79/100 [00:21<00:05,  3.60it/s]
# Validation DataLoader 0:  80%|█████████████▌   | 80/100 [00:22<00:05,  3.60it/s]
# Validation DataLoader 0:  81%|█████████████▊   | 81/100 [00:22<00:05,  3.61it/s]
# Validation DataLoader 0:  82%|█████████████▉   | 82/100 [00:22<00:04,  3.61it/s]
# Validation DataLoader 0:  83%|██████████████   | 83/100 [00:22<00:04,  3.61it/s]
# Validation DataLoader 0:  84%|██████████████▎  | 84/100 [00:23<00:04,  3.61it/s]
# Validation DataLoader 0:  85%|██████████████▍  | 85/100 [00:23<00:04,  3.61it/s]
# Validation DataLoader 0:  86%|██████████████▌  | 86/100 [00:23<00:03,  3.61it/s]
# Validation DataLoader 0:  87%|██████████████▊  | 87/100 [00:24<00:03,  3.61it/s]
# Validation DataLoader 0:  88%|██████████████▉  | 88/100 [00:24<00:03,  3.61it/s]
# Validation DataLoader 0:  89%|███████████████▏ | 89/100 [00:24<00:03,  3.62it/s]
# Validation DataLoader 0:  90%|███████████████▎ | 90/100 [00:24<00:02,  3.62it/s]
# Validation DataLoader 0:  91%|███████████████▍ | 91/100 [00:25<00:02,  3.62it/s]
# Validation DataLoader 0:  92%|███████████████▋ | 92/100 [00:25<00:02,  3.62it/s]
# Validation DataLoader 0:  93%|███████████████▊ | 93/100 [00:25<00:01,  3.62it/s]
# Validation DataLoader 0:  94%|███████████████▉ | 94/100 [00:25<00:01,  3.62it/s]
# Validation DataLoader 0:  95%|████████████████▏| 95/100 [00:26<00:01,  3.62it/s]
# Validation DataLoader 0:  96%|████████████████▎| 96/100 [00:26<00:01,  3.62it/s]
# Validation DataLoader 0:  97%|████████████████▍| 97/100 [00:26<00:00,  3.63it/s]
# Validation DataLoader 0:  98%|████████████████▋| 98/100 [00:27<00:00,  3.63it/s]
# Validation DataLoader 0:  99%|████████████████▊| 99/100 [00:27<00:00,  3.63it/s]
# Validation DataLoader 0: 100%|████████████████| 100/100 [00:27<00:00,  3.63it/s]
# Epoch 0: 100%|█| 9892/9892 [06:13<00:00, 26.50it/s, v_num=mu7h, train/loss=4.090`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 9892/9892 [06:13<00:00, 26.50it/s, v_num=mu7h, train/loss=4.090

# %% [markdown]
# # microbatch=2

# %%
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_10k-world-full.yaml" \
        --model.load_model="../model/L6-D512-world-v5base-init.pth" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v5-enwiki-10k-full/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Microbatch 2 - (deepspeed_stage_1)" \
        --trainer.strategy="deepspeed_stage_1" \
        --trainer.microbatch_size=2 \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-01-18 12:11:50,734] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.1'
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/picocreator/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-full.yaml', '--model.load_model=../model/L6-D512-world-v5base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v5-enwiki-10k-full/', '--trainer.logger.init_args.name=infctx-v5-microbatch - Microbatch 2 - (deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.microbatch_size=2', '--trainer.devices=auto'], args=['fit', '-c', '/home/picocreator/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-full.yaml', '--model.load_model=../model/L6-D512-world-v5base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v5-enwiki-10k-full/', '--trainer.logger.init_args.name=infctx-v5-microbatch - Microbatch 2 - (deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.microbatch_size=2', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /home/picocreator/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - microbatch_size:         2
#    - accumulate_grad_batches: 8
#    - effective_batch_size:    16
#
# Saving the dataset (1/1 shards): 100%|█| 9892/9892 [00:00<00:00, 530522.66 examp
# Saving the dataset (1/1 shards): 100%|█| 100/100 [00:00<00:00, 28455.25 examples
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:639: Checkpoint directory ../checkpoint/v5-enwiki-10k-full/ exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/picocreator/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.05180692672729492 seconds
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1699449201450/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 87.6 M    Trainable params
# 0         Non-trainable params
# 87.6 M    Total params
# 350.405   Total estimated model params size (MB)
# Epoch 0:  16%|▏| 800/4946 [00:35<03:05, 22.41it/s, v_num=3o87, train/loss=5.060]/home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 4946/4946 [03:42<00:00, 22.19it/s, v_num=3o87, train/loss=5.720
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/100 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/100 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/100 [00:00<00:30,  3.21it/s]
# Validation DataLoader 0:   2%|▎                 | 2/100 [00:00<00:28,  3.41it/s]
# Validation DataLoader 0:   3%|▌                 | 3/100 [00:00<00:27,  3.51it/s]
# Validation DataLoader 0:   4%|▋                 | 4/100 [00:01<00:26,  3.56it/s]
# Validation DataLoader 0:   5%|▉                 | 5/100 [00:01<00:26,  3.59it/s]
# Validation DataLoader 0:   6%|█                 | 6/100 [00:01<00:26,  3.61it/s]
# Validation DataLoader 0:   7%|█▎                | 7/100 [00:01<00:25,  3.61it/s]
# Validation DataLoader 0:   8%|█▍                | 8/100 [00:02<00:25,  3.61it/s]
# Validation DataLoader 0:   9%|█▌                | 9/100 [00:02<00:25,  3.61it/s]
# Validation DataLoader 0:  10%|█▋               | 10/100 [00:02<00:24,  3.63it/s]
# Validation DataLoader 0:  11%|█▊               | 11/100 [00:03<00:24,  3.63it/s]
# Validation DataLoader 0:  12%|██               | 12/100 [00:03<00:24,  3.64it/s]
# Validation DataLoader 0:  13%|██▏              | 13/100 [00:03<00:23,  3.65it/s]
# Validation DataLoader 0:  14%|██▍              | 14/100 [00:03<00:23,  3.65it/s]
# Validation DataLoader 0:  15%|██▌              | 15/100 [00:04<00:23,  3.66it/s]
# Validation DataLoader 0:  16%|██▋              | 16/100 [00:04<00:22,  3.66it/s]
# Validation DataLoader 0:  17%|██▉              | 17/100 [00:04<00:22,  3.67it/s]
# Validation DataLoader 0:  18%|███              | 18/100 [00:04<00:22,  3.67it/s]
# Validation DataLoader 0:  19%|███▏             | 19/100 [00:05<00:22,  3.67it/s]
# Validation DataLoader 0:  20%|███▍             | 20/100 [00:05<00:21,  3.68it/s]
# Validation DataLoader 0:  21%|███▌             | 21/100 [00:05<00:21,  3.68it/s]
# Validation DataLoader 0:  22%|███▋             | 22/100 [00:05<00:21,  3.68it/s]
# Validation DataLoader 0:  23%|███▉             | 23/100 [00:06<00:20,  3.68it/s]
# Validation DataLoader 0:  24%|████             | 24/100 [00:06<00:20,  3.68it/s]
# Validation DataLoader 0:  25%|████▎            | 25/100 [00:07<00:22,  3.40it/s]
# Validation DataLoader 0:  26%|████▍            | 26/100 [00:07<00:21,  3.41it/s]
# Validation DataLoader 0:  27%|████▌            | 27/100 [00:07<00:21,  3.42it/s]
# Validation DataLoader 0:  28%|████▊            | 28/100 [00:08<00:20,  3.43it/s]
# Validation DataLoader 0:  29%|████▉            | 29/100 [00:08<00:20,  3.44it/s]
# Validation DataLoader 0:  30%|█████            | 30/100 [00:08<00:20,  3.45it/s]
# Validation DataLoader 0:  31%|█████▎           | 31/100 [00:08<00:19,  3.46it/s]
# Validation DataLoader 0:  32%|█████▍           | 32/100 [00:09<00:19,  3.47it/s]
# Validation DataLoader 0:  33%|█████▌           | 33/100 [00:09<00:19,  3.47it/s]
# Validation DataLoader 0:  34%|█████▊           | 34/100 [00:09<00:18,  3.48it/s]
# Validation DataLoader 0:  35%|█████▉           | 35/100 [00:10<00:18,  3.49it/s]
# Validation DataLoader 0:  36%|██████           | 36/100 [00:10<00:18,  3.49it/s]
# Validation DataLoader 0:  37%|██████▎          | 37/100 [00:10<00:17,  3.50it/s]
# Validation DataLoader 0:  38%|██████▍          | 38/100 [00:10<00:17,  3.51it/s]
# Validation DataLoader 0:  39%|██████▋          | 39/100 [00:11<00:17,  3.51it/s]
# Validation DataLoader 0:  40%|██████▊          | 40/100 [00:11<00:17,  3.52it/s]
# Validation DataLoader 0:  41%|██████▉          | 41/100 [00:11<00:16,  3.52it/s]
# Validation DataLoader 0:  42%|███████▏         | 42/100 [00:11<00:16,  3.53it/s]
# Validation DataLoader 0:  43%|███████▎         | 43/100 [00:12<00:16,  3.53it/s]
# Validation DataLoader 0:  44%|███████▍         | 44/100 [00:12<00:15,  3.53it/s]
# Validation DataLoader 0:  45%|███████▋         | 45/100 [00:12<00:15,  3.54it/s]
# Validation DataLoader 0:  46%|███████▊         | 46/100 [00:12<00:15,  3.54it/s]
# Validation DataLoader 0:  47%|███████▉         | 47/100 [00:13<00:14,  3.55it/s]
# Validation DataLoader 0:  48%|████████▏        | 48/100 [00:13<00:14,  3.55it/s]
# Validation DataLoader 0:  49%|████████▎        | 49/100 [00:13<00:14,  3.55it/s]
# Validation DataLoader 0:  50%|████████▌        | 50/100 [00:14<00:14,  3.56it/s]
# Validation DataLoader 0:  51%|████████▋        | 51/100 [00:14<00:13,  3.56it/s]
# Validation DataLoader 0:  52%|████████▊        | 52/100 [00:14<00:13,  3.56it/s]
# Validation DataLoader 0:  53%|█████████        | 53/100 [00:14<00:13,  3.56it/s]
# Validation DataLoader 0:  54%|█████████▏       | 54/100 [00:15<00:12,  3.57it/s]
# Validation DataLoader 0:  55%|█████████▎       | 55/100 [00:15<00:12,  3.57it/s]
# Validation DataLoader 0:  56%|█████████▌       | 56/100 [00:15<00:12,  3.57it/s]
# Validation DataLoader 0:  57%|█████████▋       | 57/100 [00:15<00:12,  3.58it/s]
# Validation DataLoader 0:  58%|█████████▊       | 58/100 [00:16<00:11,  3.58it/s]
# Validation DataLoader 0:  59%|██████████       | 59/100 [00:16<00:11,  3.58it/s]
# Validation DataLoader 0:  60%|██████████▏      | 60/100 [00:16<00:11,  3.58it/s]
# Validation DataLoader 0:  61%|██████████▎      | 61/100 [00:17<00:10,  3.59it/s]
# Validation DataLoader 0:  62%|██████████▌      | 62/100 [00:17<00:10,  3.59it/s]
# Validation DataLoader 0:  63%|██████████▋      | 63/100 [00:17<00:10,  3.59it/s]
# Validation DataLoader 0:  64%|██████████▉      | 64/100 [00:17<00:10,  3.59it/s]
# Validation DataLoader 0:  65%|███████████      | 65/100 [00:18<00:09,  3.59it/s]
# Validation DataLoader 0:  66%|███████████▏     | 66/100 [00:18<00:09,  3.60it/s]
# Validation DataLoader 0:  67%|███████████▍     | 67/100 [00:18<00:09,  3.60it/s]
# Validation DataLoader 0:  68%|███████████▌     | 68/100 [00:18<00:08,  3.60it/s]
# Validation DataLoader 0:  69%|███████████▋     | 69/100 [00:19<00:08,  3.60it/s]
# Validation DataLoader 0:  70%|███████████▉     | 70/100 [00:19<00:08,  3.60it/s]
# Validation DataLoader 0:  71%|████████████     | 71/100 [00:19<00:08,  3.60it/s]
# Validation DataLoader 0:  72%|████████████▏    | 72/100 [00:19<00:07,  3.61it/s]
# Validation DataLoader 0:  73%|████████████▍    | 73/100 [00:20<00:07,  3.61it/s]
# Validation DataLoader 0:  74%|████████████▌    | 74/100 [00:20<00:07,  3.61it/s]
# Validation DataLoader 0:  75%|████████████▊    | 75/100 [00:20<00:06,  3.61it/s]
# Validation DataLoader 0:  76%|████████████▉    | 76/100 [00:21<00:06,  3.61it/s]
# Validation DataLoader 0:  77%|█████████████    | 77/100 [00:21<00:06,  3.61it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 78/100 [00:21<00:06,  3.62it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 79/100 [00:21<00:05,  3.62it/s]
# Validation DataLoader 0:  80%|█████████████▌   | 80/100 [00:22<00:05,  3.62it/s]
# Validation DataLoader 0:  81%|█████████████▊   | 81/100 [00:22<00:05,  3.62it/s]
# Validation DataLoader 0:  82%|█████████████▉   | 82/100 [00:22<00:04,  3.62it/s]
# Validation DataLoader 0:  83%|██████████████   | 83/100 [00:22<00:04,  3.62it/s]
# Validation DataLoader 0:  84%|██████████████▎  | 84/100 [00:23<00:04,  3.62it/s]
# Validation DataLoader 0:  85%|██████████████▍  | 85/100 [00:23<00:04,  3.63it/s]
# Validation DataLoader 0:  86%|██████████████▌  | 86/100 [00:23<00:03,  3.63it/s]
# Validation DataLoader 0:  87%|██████████████▊  | 87/100 [00:23<00:03,  3.63it/s]
# Validation DataLoader 0:  88%|██████████████▉  | 88/100 [00:24<00:03,  3.63it/s]
# Validation DataLoader 0:  89%|███████████████▏ | 89/100 [00:24<00:03,  3.63it/s]
# Validation DataLoader 0:  90%|███████████████▎ | 90/100 [00:24<00:02,  3.63it/s]
# Validation DataLoader 0:  91%|███████████████▍ | 91/100 [00:25<00:02,  3.63it/s]
# Validation DataLoader 0:  92%|███████████████▋ | 92/100 [00:25<00:02,  3.63it/s]
# Validation DataLoader 0:  93%|███████████████▊ | 93/100 [00:25<00:01,  3.64it/s]
# Validation DataLoader 0:  94%|███████████████▉ | 94/100 [00:25<00:01,  3.64it/s]
# Validation DataLoader 0:  95%|████████████████▏| 95/100 [00:26<00:01,  3.64it/s]
# Validation DataLoader 0:  96%|████████████████▎| 96/100 [00:26<00:01,  3.64it/s]
# Validation DataLoader 0:  97%|████████████████▍| 97/100 [00:26<00:00,  3.64it/s]
# Validation DataLoader 0:  98%|████████████████▋| 98/100 [00:26<00:00,  3.64it/s]
# Validation DataLoader 0:  99%|████████████████▊| 99/100 [00:27<00:00,  3.64it/s]
# Validation DataLoader 0: 100%|████████████████| 100/100 [00:27<00:00,  3.64it/s]
# Epoch 0: 100%|█| 4946/4946 [04:10<00:00, 19.74it/s, v_num=3o87, train/loss=5.720`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 4946/4946 [04:10<00:00, 19.74it/s, v_num=3o87, train/loss=5.720

# %% [markdown]
# # microbatch=8

# %%
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_10k-world-full.yaml" \
        --model.load_model="../model/L6-D512-world-v5base-init.pth" \
        --trainer.callbacks.init_args.dirpath="../checkpoint/v5-enwiki-10k-full/" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - Microbatch 2 - (deepspeed_stage_1)" \
        --trainer.strategy="deepspeed_stage_1" \
        --trainer.microbatch_size=4 \
        --trainer.devices="{GPU_DEVICES}"
# Out:
# [2024-01-18 12:18:03,234] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.1'
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/picocreator/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-full.yaml', '--model.load_model=../model/L6-D512-world-v5base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v5-enwiki-10k-full/', '--trainer.logger.init_args.name=infctx-v5-microbatch - Microbatch 2 - (deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.microbatch_size=4', '--trainer.devices=auto'], args=['fit', '-c', '/home/picocreator/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-full.yaml', '--model.load_model=../model/L6-D512-world-v5base-init.pth', '--trainer.callbacks.init_args.dirpath=../checkpoint/v5-enwiki-10k-full/', '--trainer.logger.init_args.name=infctx-v5-microbatch - Microbatch 2 - (deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.microbatch_size=4', '--trainer.devices=auto'].
# Seed set to 3941088705
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /home/picocreator/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu121/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - microbatch_size:         4
#    - accumulate_grad_batches: 4
#    - effective_batch_size:    16
#
# Saving the dataset (1/1 shards): 100%|█| 9892/9892 [00:00<00:00, 583184.18 examp
# Saving the dataset (1/1 shards): 100%|█| 100/100 [00:00<00:00, 28878.44 examples
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:639: Checkpoint directory ../checkpoint/v5-enwiki-10k-full/ exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/picocreator/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/picocreator/.cache/torch_extensions/py311_cu121/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.05039358139038086 seconds
# /home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1699449201450/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 87.6 M    Trainable params
# 0         Non-trainable params
# 87.6 M    Total params
# 350.405   Total estimated model params size (MB)
# Epoch 0:  16%|▏| 400/2473 [00:30<02:37, 13.12it/s, v_num=jp9a, train/loss=6.780]/home/picocreator/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/nn/modules/module.py:1879: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
#   warnings.warn(
# Epoch 0: 100%|█| 2473/2473 [03:04<00:00, 13.41it/s, v_num=jp9a, train/loss=6.660
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/100 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/100 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▏                 | 1/100 [00:00<00:33,  2.99it/s]
# Validation DataLoader 0:   2%|▎                 | 2/100 [00:00<00:30,  3.25it/s]
# Validation DataLoader 0:   3%|▌                 | 3/100 [00:00<00:28,  3.37it/s]
# Validation DataLoader 0:   4%|▋                 | 4/100 [00:01<00:27,  3.45it/s]
# Validation DataLoader 0:   5%|▉                 | 5/100 [00:01<00:27,  3.49it/s]
# Validation DataLoader 0:   6%|█                 | 6/100 [00:01<00:26,  3.53it/s]
# Validation DataLoader 0:   7%|█▎                | 7/100 [00:01<00:26,  3.54it/s]
# Validation DataLoader 0:   8%|█▍                | 8/100 [00:02<00:25,  3.56it/s]
# Validation DataLoader 0:   9%|█▌                | 9/100 [00:02<00:25,  3.57it/s]
# Validation DataLoader 0:  10%|█▋               | 10/100 [00:02<00:25,  3.58it/s]
# Validation DataLoader 0:  11%|█▊               | 11/100 [00:03<00:24,  3.60it/s]
# Validation DataLoader 0:  12%|██               | 12/100 [00:03<00:24,  3.60it/s]
# Validation DataLoader 0:  13%|██▏              | 13/100 [00:03<00:24,  3.61it/s]
# Validation DataLoader 0:  14%|██▍              | 14/100 [00:03<00:23,  3.62it/s]
# Validation DataLoader 0:  15%|██▌              | 15/100 [00:04<00:23,  3.63it/s]
# Validation DataLoader 0:  16%|██▋              | 16/100 [00:04<00:23,  3.63it/s]
# Validation DataLoader 0:  17%|██▉              | 17/100 [00:04<00:22,  3.63it/s]
# Validation DataLoader 0:  18%|███              | 18/100 [00:04<00:22,  3.64it/s]
# Validation DataLoader 0:  19%|███▏             | 19/100 [00:05<00:22,  3.64it/s]
# Validation DataLoader 0:  20%|███▍             | 20/100 [00:05<00:21,  3.64it/s]
# Validation DataLoader 0:  21%|███▌             | 21/100 [00:05<00:21,  3.64it/s]
# Validation DataLoader 0:  22%|███▋             | 22/100 [00:06<00:21,  3.64it/s]
# Validation DataLoader 0:  23%|███▉             | 23/100 [00:06<00:21,  3.64it/s]
# Validation DataLoader 0:  24%|████             | 24/100 [00:06<00:20,  3.65it/s]
# Validation DataLoader 0:  25%|████▎            | 25/100 [00:07<00:22,  3.37it/s]
# Validation DataLoader 0:  26%|████▍            | 26/100 [00:07<00:21,  3.38it/s]
# Validation DataLoader 0:  27%|████▌            | 27/100 [00:07<00:21,  3.39it/s]
# Validation DataLoader 0:  28%|████▊            | 28/100 [00:08<00:21,  3.40it/s]
# Validation DataLoader 0:  29%|████▉            | 29/100 [00:08<00:20,  3.41it/s]
# Validation DataLoader 0:  30%|█████            | 30/100 [00:08<00:20,  3.42it/s]
# Validation DataLoader 0:  31%|█████▎           | 31/100 [00:09<00:20,  3.42it/s]
# Validation DataLoader 0:  32%|█████▍           | 32/100 [00:09<00:19,  3.43it/s]
# Validation DataLoader 0:  33%|█████▌           | 33/100 [00:09<00:19,  3.44it/s]
# Validation DataLoader 0:  34%|█████▊           | 34/100 [00:09<00:19,  3.45it/s]
# Validation DataLoader 0:  35%|█████▉           | 35/100 [00:10<00:18,  3.45it/s]
# Validation DataLoader 0:  36%|██████           | 36/100 [00:10<00:18,  3.46it/s]
# Validation DataLoader 0:  37%|██████▎          | 37/100 [00:10<00:18,  3.46it/s]
# Validation DataLoader 0:  38%|██████▍          | 38/100 [00:10<00:17,  3.47it/s]
# Validation DataLoader 0:  39%|██████▋          | 39/100 [00:11<00:17,  3.48it/s]
# Validation DataLoader 0:  40%|██████▊          | 40/100 [00:11<00:17,  3.48it/s]
# Validation DataLoader 0:  41%|██████▉          | 41/100 [00:11<00:16,  3.49it/s]
# Validation DataLoader 0:  42%|███████▏         | 42/100 [00:12<00:16,  3.49it/s]
# Validation DataLoader 0:  43%|███████▎         | 43/100 [00:12<00:16,  3.49it/s]
# Validation DataLoader 0:  44%|███████▍         | 44/100 [00:12<00:16,  3.50it/s]
# Validation DataLoader 0:  45%|███████▋         | 45/100 [00:12<00:15,  3.50it/s]
# Validation DataLoader 0:  46%|███████▊         | 46/100 [00:13<00:15,  3.51it/s]
# Validation DataLoader 0:  47%|███████▉         | 47/100 [00:13<00:15,  3.51it/s]
# Validation DataLoader 0:  48%|████████▏        | 48/100 [00:13<00:14,  3.51it/s]
# Validation DataLoader 0:  49%|████████▎        | 49/100 [00:13<00:14,  3.52it/s]
# Validation DataLoader 0:  50%|████████▌        | 50/100 [00:14<00:14,  3.52it/s]
# Validation DataLoader 0:  51%|████████▋        | 51/100 [00:14<00:13,  3.52it/s]
# Validation DataLoader 0:  52%|████████▊        | 52/100 [00:14<00:13,  3.53it/s]
# Validation DataLoader 0:  53%|█████████        | 53/100 [00:15<00:13,  3.53it/s]
# Validation DataLoader 0:  54%|█████████▏       | 54/100 [00:15<00:13,  3.53it/s]
# Validation DataLoader 0:  55%|█████████▎       | 55/100 [00:15<00:12,  3.53it/s]
# Validation DataLoader 0:  56%|█████████▌       | 56/100 [00:15<00:12,  3.54it/s]
# Validation DataLoader 0:  57%|█████████▋       | 57/100 [00:16<00:12,  3.54it/s]
# Validation DataLoader 0:  58%|█████████▊       | 58/100 [00:16<00:11,  3.54it/s]
# Validation DataLoader 0:  59%|██████████       | 59/100 [00:16<00:11,  3.54it/s]
# Validation DataLoader 0:  60%|██████████▏      | 60/100 [00:16<00:11,  3.55it/s]
# Validation DataLoader 0:  61%|██████████▎      | 61/100 [00:17<00:10,  3.55it/s]
# Validation DataLoader 0:  62%|██████████▌      | 62/100 [00:17<00:10,  3.55it/s]
# Validation DataLoader 0:  63%|██████████▋      | 63/100 [00:17<00:10,  3.55it/s]
# Validation DataLoader 0:  64%|██████████▉      | 64/100 [00:18<00:10,  3.56it/s]
# Validation DataLoader 0:  65%|███████████      | 65/100 [00:18<00:09,  3.56it/s]
# Validation DataLoader 0:  66%|███████████▏     | 66/100 [00:18<00:09,  3.56it/s]
# Validation DataLoader 0:  67%|███████████▍     | 67/100 [00:18<00:09,  3.56it/s]
# Validation DataLoader 0:  68%|███████████▌     | 68/100 [00:19<00:08,  3.56it/s]
# Validation DataLoader 0:  69%|███████████▋     | 69/100 [00:19<00:08,  3.56it/s]
# Validation DataLoader 0:  70%|███████████▉     | 70/100 [00:19<00:08,  3.57it/s]
# Validation DataLoader 0:  71%|████████████     | 71/100 [00:19<00:08,  3.57it/s]
# Validation DataLoader 0:  72%|████████████▏    | 72/100 [00:20<00:07,  3.57it/s]
# Validation DataLoader 0:  73%|████████████▍    | 73/100 [00:20<00:07,  3.57it/s]
# Validation DataLoader 0:  74%|████████████▌    | 74/100 [00:20<00:07,  3.57it/s]
# Validation DataLoader 0:  75%|████████████▊    | 75/100 [00:20<00:06,  3.57it/s]
# Validation DataLoader 0:  76%|████████████▉    | 76/100 [00:21<00:06,  3.58it/s]
# Validation DataLoader 0:  77%|█████████████    | 77/100 [00:21<00:06,  3.58it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 78/100 [00:21<00:06,  3.58it/s]
# Validation DataLoader 0:  79%|█████████████▍   | 79/100 [00:22<00:05,  3.58it/s]
# Validation DataLoader 0:  80%|█████████████▌   | 80/100 [00:22<00:05,  3.58it/s]
# Validation DataLoader 0:  81%|█████████████▊   | 81/100 [00:22<00:05,  3.58it/s]
# Validation DataLoader 0:  82%|█████████████▉   | 82/100 [00:22<00:05,  3.58it/s]
# Validation DataLoader 0:  83%|██████████████   | 83/100 [00:23<00:04,  3.59it/s]
# Validation DataLoader 0:  84%|██████████████▎  | 84/100 [00:23<00:04,  3.59it/s]
# Validation DataLoader 0:  85%|██████████████▍  | 85/100 [00:23<00:04,  3.59it/s]
# Validation DataLoader 0:  86%|██████████████▌  | 86/100 [00:23<00:03,  3.59it/s]
# Validation DataLoader 0:  87%|██████████████▊  | 87/100 [00:24<00:03,  3.59it/s]
# Validation DataLoader 0:  88%|██████████████▉  | 88/100 [00:24<00:03,  3.59it/s]
# Validation DataLoader 0:  89%|███████████████▏ | 89/100 [00:24<00:03,  3.59it/s]
# Validation DataLoader 0:  90%|███████████████▎ | 90/100 [00:25<00:02,  3.59it/s]
# Validation DataLoader 0:  91%|███████████████▍ | 91/100 [00:25<00:02,  3.59it/s]
# Validation DataLoader 0:  92%|███████████████▋ | 92/100 [00:25<00:02,  3.60it/s]
# Validation DataLoader 0:  93%|███████████████▊ | 93/100 [00:25<00:01,  3.60it/s]
# Validation DataLoader 0:  94%|███████████████▉ | 94/100 [00:26<00:01,  3.60it/s]
# Validation DataLoader 0:  95%|████████████████▏| 95/100 [00:26<00:01,  3.60it/s]
# Validation DataLoader 0:  96%|████████████████▎| 96/100 [00:26<00:01,  3.60it/s]
# Validation DataLoader 0:  97%|████████████████▍| 97/100 [00:26<00:00,  3.60it/s]
# Validation DataLoader 0:  98%|████████████████▋| 98/100 [00:27<00:00,  3.60it/s]
# Validation DataLoader 0:  99%|████████████████▊| 99/100 [00:27<00:00,  3.60it/s]
# Validation DataLoader 0: 100%|████████████████| 100/100 [00:27<00:00,  3.60it/s]
# Epoch 0: 100%|█| 2473/2473 [03:32<00:00, 11.65it/s, v_num=jp9a, train/loss=6.660`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 2473/2473 [03:32<00:00, 11.65it/s, v_num=jp9a, train/loss=6.660
