# %% [markdown]
# # Short enwiki batch testing
#
# Test that the training code, batching mode, works with
#
# **L6-D512 model with**
# - Layer count: 6
# - Embed size: 512
#
# ## The following are the performance numbers on a single AWS A10G
#
# | Batch Size | Peak Tokens / Sec | Peak VRAM  | Time taken (include setup/validation) |
# |------------|-------------------|------------|---------------------------------------|
# | 8          | 53.71 kt/sec      | ~ 20.09 GB | 71.45 sec                             |
# | 4          | 44.17 kt/sec      | ~ 13.24 GB | 83.63 sec                             |
# | 2          | 32.51 kt/sec      | ~ 7.74 GB  | 108.472 sec                           |
# | 1          | 21.73 kt/sec      | ~ 4.91 GB  | 153.902 sec                           |
#
# The general advice is increase your microbatch_size size until your vram maxes out. Then increase target_batch_size to match, or scale in multiples of GPU count & microbatch_size.
#
# Additionally, because you get marginal returns for each bump in microbatch_size, it is highly recommended to aim for atleast microbatch_size of 2 or 4

# %% [markdown]
# ## Preparing the init model and test dataset

# %%
GPU_DEVICES="auto"
ENABLE_WANDB=True
WANDB_PREFIX="infctx-v5-validation"
DEEPSPEED_STRAT="deepspeed_stage_1"

print("ENABLE_WANDB:", ENABLE_WANDB)
print("GPU_DEVICES:", GPU_DEVICES)

if ENABLE_WANDB:
    WANDB_MODE="online"
else:
    WANDB_MODE="disabled"

# Computing the notebook, and various paths
import os
NOTEBOOK_DIR=os.path.dirname(os.path.abspath("__file__"))
PROJECT_DIR=os.path.abspath(os.path.join(NOTEBOOK_DIR, "../../"))
TRAINER_DIR=os.path.abspath(os.path.join(PROJECT_DIR, "./RWKV-v5/"))

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("TRAINER_DIR:", TRAINER_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# ENABLE_WANDB: True
# GPU_DEVICES: auto
# NOTEBOOK_DIR: /home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation
# TRAINER_DIR: /home/ubuntu/rwkv-proj/RWKV-infctx-trainer/RWKV-v5
# PROJECT_DIR: /home/ubuntu/rwkv-proj/RWKV-infctx-trainer

# %%
# First lets setup the various directories
# !mkdir -p "{PROJECT_DIR}/model/"
# !mkdir -p "{PROJECT_DIR}/datapath/"
# !mkdir -p "{PROJECT_DIR}/checkpoint/"

# %%
# Lets initialized the L6-D512 model with the init_model.py code
# !cd "{TRAINER_DIR}" && python3 init_model.py \
    --n_layer 6 --n_embd 512 \
    --vocab_size world \
    --skip-if-exists --safe-init \
    ../model/L6-D512-world-init.pth
# Out:
# [2023-11-19 02:13:21,497] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0'
# ---- Initializing model ----
# No of layers: 6
# Embedding size: 512
# Output model path: ../model/L6-D512-world-init.pth
# Vocab size: 65536
# Emb scale: 0.0001
# Note: this process takes a significant time (and ram) for large models
# ---- ----- ----
# Model exists, skipping init_model

# %%
# Preload the dataset
# !cd "{TRAINER_DIR}" && \
    python3 preload_datapath.py "{NOTEBOOK_DIR}/config/enwiki_10k-world-4096.yaml"
# Out:
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Saving the dataset (1/1 shards): 100%|█| 751/751 [00:00<00:00, 9869.41 examples/
# Saving the dataset (1/1 shards): 100%|███| 8/8 [00:00<00:00, 2474.88 examples/s]

# %%
# Short training process - for quick testing / debugging
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="disabled" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_10k-world-4096.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} (train-ctx=4096, data-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --trainer.fast_dev_run=2 \
        --model.load_model="../model/L6-D512-world-init.pth"
# Out:
# [2023-11-19 02:13:36,847] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0'
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.fast_dev_run=2', '--model.load_model=../model/L6-D512-world-init.pth'], args=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.fast_dev_run=2', '--model.load_model=../model/L6-D512-world-init.pth'].
# Seed set to 3941088705
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Running in `fast_dev_run` mode: will run the requested loop using 2 batch(es). Logging and checkpointing is suppressed.
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - microbatch_size:         1
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    16
#
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Saving the dataset (1/1 shards): 100%|█| 751/751 [00:00<00:00, 12857.46 examples
# Saving the dataset (1/1 shards): 100%|███| 8/8 [00:00<00:00, 2420.61 examples/s]
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.07299375534057617 seconds
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1695392026823/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 87.6 M    Trainable params
# 0         Non-trainable params
# 87.6 M    Total params
# 350.405   Total estimated model params size (MB)
# Epoch 0: 100%|██████████████████| 2/2 [00:02<00:00,  0.78it/s, train/loss=11.20]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|██████████          | 1/2 [00:00<00:00,  1.67it/s]
# Validation DataLoader 0: 100%|████████████████████| 2/2 [00:01<00:00,  1.73it/s]
# Epoch 0: 100%|█| 2/2 [00:03<00:00,  0.51it/s, train/loss=11.20, validation/loss=`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 2/2 [00:03<00:00,  0.51it/s, train/loss=11.20, validation/loss=

# %%
# Empty out the checkpoint
# !cd "{PROJECT_DIR}" && rm -rf "./checkpoint/infctx-v5-unit-test-baseline-4096/"

# Microbatch 1 training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_10k-world-4096.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - microbatch 1 (train-ctx=4096, data-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --trainer.microbatch_size=1 \
        --model.load_model="../model/L6-D512-world-init.pth"
# Out:
# [2023-11-19 02:13:59,508] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0'
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation - microbatch 1 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.microbatch_size=1', '--model.load_model=../model/L6-D512-world-init.pth'], args=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation - microbatch 1 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.microbatch_size=1', '--model.load_model=../model/L6-D512-world-init.pth'].
# Seed set to 3941088705
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - microbatch_size:         1
#    - accumulate_grad_batches: 16
#    - effective_batch_size:    16
#
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Saving the dataset (1/1 shards): 100%|█| 751/751 [00:00<00:00, 13520.66 examples
# Saving the dataset (1/1 shards): 100%|███| 8/8 [00:00<00:00, 2512.12 examples/s]
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./wandb/run-20231119_021406-ecnw9v5g
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-v5-validation - microbatch 1 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/runs/ecnw9v5g
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06810188293457031 seconds
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1695392026823/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 87.6 M    Trainable params
# 0         Non-trainable params
# 87.6 M    Total params
# 350.405   Total estimated model params size (MB)
# Epoch 0: 100%|██| 751/751 [02:21<00:00,  5.30it/s, v_num=9v5g, train/loss=6.810]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:04,  1.63it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:01<00:03,  1.70it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:01<00:02,  1.73it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:02<00:02,  1.74it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:02<00:01,  1.75it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:03<00:01,  1.75it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:03<00:00,  1.76it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:04<00:00,  1.76it/s]
# Epoch 0: 100%|█| 751/751 [02:26<00:00,  5.13it/s, v_num=9v5g, train/loss=6.810, `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 751/751 [02:26<00:00,  5.13it/s, v_num=9v5g, train/loss=6.810,
# wandb: Waiting for W&B process to finish... (success).
# wandb: / 0.005 MB of 0.005 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:                  batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:              data_ctx_len ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                     epoch ▁
# wandb:               global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/tokens_per_sec.gpu.0 ▁▄▆▆▇▇▇▇▇▇██████████████████████████████
# wandb:   perf/tokens_total.gpu.0 ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                   substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                train/loss █▇▆▆▅▄▄▃▃▃▃▃▂▂▂▂▂▃▂▂▁▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▂▂
# wandb:       trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:     trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:           validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                  batchidx 750
# wandb:              data_ctx_len 4096.0
# wandb:                     epoch 0
# wandb:               global_rank 0
# wandb: perf/tokens_per_sec.gpu.0 21730.81796
# wandb:   perf/tokens_total.gpu.0 3076096
# wandb:                   substep 750
# wandb:                train/loss 6.8125
# wandb:       trainer/global_step 46
# wandb:     trainer/learning_rate 0.00041
# wandb:           validation/loss 6.77734
# wandb:
# wandb: 🚀 View run infctx-v5-validation - microbatch 1 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1) at: https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/runs/ecnw9v5g
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNjk3NDc5Mw==/version_details/v0
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231119_021406-ecnw9v5g/logs

# %%
# Empty out the checkpoint
# !cd "{PROJECT_DIR}" && rm -rf "./checkpoint/infctx-v5-unit-test-baseline-4096/"

# Microbatch 1 training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_10k-world-4096.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - microbatch 2 (train-ctx=4096, data-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --trainer.microbatch_size=2 \
        --model.load_model="../model/L6-D512-world-init.pth"
# Out:
# [2023-11-19 02:16:53,648] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0'
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation - microbatch 2 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.microbatch_size=2', '--model.load_model=../model/L6-D512-world-init.pth'], args=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation - microbatch 2 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.microbatch_size=2', '--model.load_model=../model/L6-D512-world-init.pth'].
# Seed set to 3941088705
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - microbatch_size:         2
#    - accumulate_grad_batches: 8
#    - effective_batch_size:    16
#
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Saving the dataset (1/1 shards): 100%|█| 751/751 [00:00<00:00, 13080.69 examples
# Saving the dataset (1/1 shards): 100%|███| 8/8 [00:00<00:00, 2619.80 examples/s]
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./wandb/run-20231119_021701-zfo56uux
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-v5-validation - microbatch 2 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/runs/zfo56uux
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06867575645446777 seconds
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1695392026823/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 87.6 M    Trainable params
# 0         Non-trainable params
# 87.6 M    Total params
# 350.405   Total estimated model params size (MB)
# Epoch 0: 100%|██| 376/376 [01:36<00:00,  3.89it/s, v_num=6uux, train/loss=6.620]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:04,  1.67it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:01<00:03,  1.74it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:01<00:02,  1.77it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:02<00:02,  1.79it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:02<00:01,  1.79it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:03<00:01,  1.80it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:03<00:00,  1.80it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:04<00:00,  1.80it/s]
# Epoch 0: 100%|█| 376/376 [01:41<00:00,  3.71it/s, v_num=6uux, train/loss=6.620, `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 376/376 [01:41<00:00,  3.71it/s, v_num=6uux, train/loss=6.620,
# wandb: Waiting for W&B process to finish... (success).
# wandb: \ 0.017 MB of 0.017 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:                  batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:              data_ctx_len ███████████████████████████████████████▁
# wandb:                     epoch ▁
# wandb:               global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/tokens_per_sec.gpu.0 ▁▄▅▆▆▇▇▇▇▇▇▇▇███████████████████████████
# wandb:   perf/tokens_total.gpu.0 ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                   substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                train/loss █▇▆▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▂▁▂▂▂▂▂▂▁▁▁▁▁▁▁▂▂▁▁
# wandb:       trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:     trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:           validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                  batchidx 375
# wandb:              data_ctx_len 2048.0
# wandb:                     epoch 0
# wandb:               global_rank 0
# wandb: perf/tokens_per_sec.gpu.0 32231.84758
# wandb:   perf/tokens_total.gpu.0 3076096
# wandb:                   substep 375
# wandb:                train/loss 6.625
# wandb:       trainer/global_step 46
# wandb:     trainer/learning_rate 0.00041
# wandb:           validation/loss 6.55469
# wandb:
# wandb: 🚀 View run infctx-v5-validation - microbatch 2 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1) at: https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/runs/zfo56uux
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNjk3NDc5Mw==/version_details/v0
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231119_021701-zfo56uux/logs

# %%
# Empty out the checkpoint
# !cd "{PROJECT_DIR}" && rm -rf "./checkpoint/infctx-v5-unit-test-baseline-4096/"

# Microbatch 1 training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_10k-world-4096.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - microbatch 4 (train-ctx=4096, data-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --trainer.microbatch_size=4 \
        --model.load_model="../model/L6-D512-world-init.pth"
# Out:
# [2023-11-19 02:19:00,550] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0'
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation - microbatch 4 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.microbatch_size=4', '--model.load_model=../model/L6-D512-world-init.pth'], args=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation - microbatch 4 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.microbatch_size=4', '--model.load_model=../model/L6-D512-world-init.pth'].
# Seed set to 3941088705
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - microbatch_size:         4
#    - accumulate_grad_batches: 4
#    - effective_batch_size:    16
#
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Saving the dataset (1/1 shards): 100%|█| 751/751 [00:00<00:00, 12358.60 examples
# Saving the dataset (1/1 shards): 100%|███| 8/8 [00:00<00:00, 2425.86 examples/s]
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./wandb/run-20231119_021907-gozsvbkj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-v5-validation - microbatch 4 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/runs/gozsvbkj
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.06836247444152832 seconds
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1695392026823/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 87.6 M    Trainable params
# 0         Non-trainable params
# 87.6 M    Total params
# 350.405   Total estimated model params size (MB)
# Epoch 0: 100%|██| 188/188 [01:11<00:00,  2.62it/s, v_num=vbkj, train/loss=6.500]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:04,  1.64it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:01<00:03,  1.70it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:01<00:02,  1.73it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:02<00:02,  1.75it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:02<00:01,  1.76it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:03<00:01,  1.77it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:03<00:00,  1.77it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:04<00:00,  1.77it/s]
# Epoch 0: 100%|█| 188/188 [01:16<00:00,  2.46it/s, v_num=vbkj, train/loss=6.500, `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 188/188 [01:16<00:00,  2.46it/s, v_num=vbkj, train/loss=6.500,
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 0.017 MB of 0.017 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:                  batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:              data_ctx_len ███████████████████████████████████████▁
# wandb:                     epoch ▁
# wandb:               global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/tokens_per_sec.gpu.0 ▁▄▅▆▆▆▇▇▇▇▇▇▇███████████████████████████
# wandb:   perf/tokens_total.gpu.0 ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                   substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                train/loss █▇▆▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:       trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:     trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:           validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                  batchidx 187
# wandb:              data_ctx_len 3072.0
# wandb:                     epoch 0
# wandb:               global_rank 0
# wandb: perf/tokens_per_sec.gpu.0 43646.67269
# wandb:   perf/tokens_total.gpu.0 3076096
# wandb:                   substep 187
# wandb:                train/loss 6.5
# wandb:       trainer/global_step 46
# wandb:     trainer/learning_rate 0.00041
# wandb:           validation/loss 6.53516
# wandb:
# wandb: 🚀 View run infctx-v5-validation - microbatch 4 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1) at: https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/runs/gozsvbkj
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNjk3NDc5Mw==/version_details/v0
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231119_021907-gozsvbkj/logs

# %%
# Empty out the checkpoint
# !cd "{PROJECT_DIR}" && rm -rf "./checkpoint/infctx-v5-unit-test-baseline-4096/"

# Microbatch 1 training
# !cd "{TRAINER_DIR}" && \
    export WANDB_MODE="{WANDB_MODE}" && \
    python3 lightning_trainer.py fit \
        -c "{NOTEBOOK_DIR}/config/enwiki_10k-world-4096.yaml" \
        --trainer.logger.init_args.name="{WANDB_PREFIX} - microbatch 8 (train-ctx=4096, data-ctx=4096, {DEEPSPEED_STRAT})" \
        --trainer.strategy="{DEEPSPEED_STRAT}" \
        --trainer.devices="{GPU_DEVICES}" \
        --trainer.microbatch_size=8 \
        --model.load_model="../model/L6-D512-world-init.pth"
# Out:
# [2023-11-19 02:20:44,542] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [RWKV.model] Running RWKV model using 'torch-jit' with torch '2.1.0'
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/lightning/pytorch/cli.py:518: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation - microbatch 8 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.microbatch_size=8', '--model.load_model=../model/L6-D512-world-init.pth'], args=['fit', '-c', '/home/ubuntu/rwkv-proj/RWKV-infctx-trainer/notebook/trainer-v5-validation/config/enwiki_10k-world-4096.yaml', '--trainer.logger.init_args.name=infctx-v5-validation - microbatch 8 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)', '--trainer.strategy=deepspeed_stage_1', '--trainer.devices=auto', '--trainer.microbatch_size=8', '--model.load_model=../model/L6-D512-world-init.pth'].
# Seed set to 3941088705
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ---
# [RWKV.TimeMix] Compiling CUDA kernel with HEAD_SIZE=64
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/wkv5/build.ninja...
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module wkv5...
# [RWKV.TimeMix] CUDA kernel compiled & loaded globally
# ---
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#
# [RWKV.Trainer] Applying 'target_batch_size' with the following:
#    - target_batch_size:       16
#    - num_nodes:               1
#    - num_devices:             1
#    - microbatch_size:         8
#    - accumulate_grad_batches: 2
#    - effective_batch_size:    16
#
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Saving the dataset (1/1 shards): 100%|█| 751/751 [00:00<00:00, 12554.94 examples
# Saving the dataset (1/1 shards): 100%|███| 8/8 [00:00<00:00, 2501.82 examples/s]
# [rank: 0] Seed set to 3941088705
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# wandb: Currently logged in as: picocreator (rwkv-x-dev). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./wandb/run-20231119_022051-hu0v4l51
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run infctx-v5-validation - microbatch 8 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1)
# wandb: ⭐️ View project at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test
# wandb: 🚀 View run at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/runs/hu0v4l51
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# #
# # RWKV lighting_trainer.py important notes
# # https://github.com/RWKV/RWKV-infctx-trainer
# #
# # - Ensure your host is not running cuda 12.0 (use either 11.8, or >=12.1), as this is known to have freeze issues
# # - The terms used in wandb / the progress bar can be confusing, see the github README.md for beter clarifications
# # - When resuming from checkpoint, the estimated time is inaccurate
# #
#
# [RWKV.model] Configuring optimizer with
#     - lr_init:  8.000e-04 (0.0008)
#     - lr_final: 4.000e-04 (0.0004)
#
# Using /home/ubuntu/.cache/torch_extensions/py311_cu118 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ubuntu/.cache/torch_extensions/py311_cu118/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.0675058364868164 seconds
# /home/ubuntu/anaconda3/envs/rwkv-infctx/lib/python3.11/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /opt/conda/conda-bld/pytorch_1695392026823/work/torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name   | Type       | Params
# --------------------------------------
# 0 | emb    | Embedding  | 33.6 M
# 1 | blocks | ModuleList | 20.5 M
# 2 | ln_out | LayerNorm  | 1.0 K
# 3 | head   | Linear     | 33.6 M
# --------------------------------------
# 87.6 M    Trainable params
# 0         Non-trainable params
# 87.6 M    Total params
# 350.405   Total estimated model params size (MB)
# Epoch 0: 100%|████| 94/94 [00:59<00:00,  1.58it/s, v_num=4l51, train/loss=6.560]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:04,  1.65it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:01<00:03,  1.72it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:01<00:02,  1.76it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:02<00:02,  1.77it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:02<00:01,  1.78it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:03<00:01,  1.79it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:03<00:00,  1.79it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:04<00:00,  1.79it/s]
# Epoch 0: 100%|█| 94/94 [01:04<00:00,  1.47it/s, v_num=4l51, train/loss=6.560, va`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 94/94 [01:04<00:00,  1.47it/s, v_num=4l51, train/loss=6.560, va
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 0.017 MB of 0.017 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:                  batchidx ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:              data_ctx_len ███████████████████████████████████████▁
# wandb:                     epoch ▁
# wandb:               global_rank ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: perf/tokens_per_sec.gpu.0 ▂▁▃▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇██████████████████████
# wandb:   perf/tokens_total.gpu.0 ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                   substep ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                train/loss █▇▆▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:       trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:     trainer/learning_rate ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:           validation/loss ▁
# wandb:
# wandb: Run summary:
# wandb:                  batchidx 93
# wandb:              data_ctx_len 3584.0
# wandb:                     epoch 0
# wandb:               global_rank 0
# wandb: perf/tokens_per_sec.gpu.0 52928.30149
# wandb:   perf/tokens_total.gpu.0 3076096
# wandb:                   substep 93
# wandb:                train/loss 6.5625
# wandb:       trainer/global_step 46
# wandb:     trainer/learning_rate 0.00041
# wandb:           validation/loss 6.52734
# wandb:
# wandb: 🚀 View run infctx-v5-validation - microbatch 8 (train-ctx=4096, data-ctx=4096, deepspeed_stage_1) at: https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/runs/hu0v4l51
# wandb: ️⚡ View job at https://wandb.ai/rwkv-x-dev/RWKV-infctx-unit-test/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExNjk3NDc5Mw==/version_details/v0
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231119_022051-hu0v4l51/logs
